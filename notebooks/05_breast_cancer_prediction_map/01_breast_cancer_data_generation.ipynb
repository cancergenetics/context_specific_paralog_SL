# %%
# import modules
import os
import re
import pandas as pd
import numpy as np

# %%
cwd = os.getcwd()
BASE_DIR = os.path.abspath(os.path.join(cwd, "..", ".."))

# build paths inside the repo
get_data_path = lambda folders, fname: os.path.normpath(
    os.path.join(BASE_DIR, *folders, fname)
)

# breast cancer cell lines
paralog_pairs_path = get_data_path(['data','input', 'other'], 'processed_DeKegel_TableS8.csv')
mutation_data_path = get_data_path(['data', 'input', 'DepMap22Q4'], 'OmicsSomaticMutations.csv')
model_info_path = get_data_path(['data','input', 'DepMap22Q4'], 'Model.csv')

# %%
model_info_df = pd.read_csv(model_info_path, low_memory=False)
model_info_df[:3]
# Out:
#       ModelID  PatientID CellLineName StrippedCellLineName DepmapModelType  \
# 0  ACH-000001  PT-gj46wT  NIH:OVCAR-3            NIHOVCAR3           HGSOC
# 1  ACH-000002  PT-5qa3uk        HL-60                 HL60             AML
# 2  ACH-000003  PT-puKIyc        CACO2                CACO2            COAD
#
#         OncotreeLineage     OncotreePrimaryDisease  \
# 0  Ovary/Fallopian Tube   Ovarian Epithelial Tumor
# 1               Myeloid     Acute Myeloid Leukemia
# 2                 Bowel  Colorectal Adenocarcinoma
#
#                     OncotreeSubtype OncotreeCode LegacyMolecularSubtype  ...  \
# 0  High-Grade Serous Ovarian Cancer        HGSOC                    NaN  ...
# 1            Acute Myeloid Leukemia          AML                    NaN  ...
# 2              Colon Adenocarcinoma         COAD                    NaN  ...
#
#    TissueOrigin                                 CCLEName  CatalogNumber  \
# 0           NaN                          NIHOVCAR3_OVARY         HTB-71
# 1           NaN  HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        CCL-240
# 2           NaN                    CACO2_LARGE_INTESTINE         HTB-37
#
#   PlateCoating ModelDerivationMaterial PublicComments WTSIMasterCellID  \
# 0          NaN                     NaN            NaN           2201.0
# 1          NaN                     NaN            NaN             55.0
# 2          NaN                     NaN            NaN              NaN
#
#   SangerModelID  COSMICID   LegacySubSubtype
# 0     SIDM00105  905933.0  high_grade_serous
# 1     SIDM00829  905938.0                 M3
# 2     SIDM00891       NaN                NaN
#
# [3 rows x 36 columns]

# %%
breast_cancer_cell_lines = model_info_df.loc[model_info_df['OncotreeLineage'] == 'Breast', 'ModelID']
print(f'# of breast cancer cell lines:{len(breast_cancer_cell_lines)}')
# Out:
# # of breast cancer cell lines:94

# %%
paralog_pairs = pd.read_csv(paralog_pairs_path)

paralog_pairs_breast = paralog_pairs.loc[paralog_pairs.index.repeat(len(breast_cancer_cell_lines))].reset_index(drop=True)
breast_cancer_cell_lines_df = pd.concat([breast_cancer_cell_lines] * paralog_pairs['genepair'].nunique(), ignore_index=True)
paralog_pairs_breast.insert(paralog_pairs_breast.shape[1], 'DepMap_ID', breast_cancer_cell_lines_df)
paralog_pairs_breast.insert(paralog_pairs_breast.shape[1], 'cell_line', 
                                      paralog_pairs_breast['DepMap_ID'].map(dict(zip(model_info_df['ModelID'], model_info_df['StrippedCellLineName']))))
paralog_pairs_breast.insert(paralog_pairs_breast.shape[1], 'cancer_type', 'Breast')
display(paralog_pairs_breast.head())
# Out:
#    prediction_rank  prediction_percentile     old_genepair         genepair  \
# 0                1                    0.1  SMARCA2_SMARCA4  SMARCA2_SMARCA4
# 1                1                    0.1  SMARCA2_SMARCA4  SMARCA2_SMARCA4
# 2                1                    0.1  SMARCA2_SMARCA4  SMARCA2_SMARCA4
# 3                1                    0.1  SMARCA2_SMARCA4  SMARCA2_SMARCA4
# 4                1                    0.1  SMARCA2_SMARCA4  SMARCA2_SMARCA4
#
#         A1       A2  A1_entrez  A2_entrez       A1_ensembl       A2_ensembl  \
# 0  SMARCA2  SMARCA4       6595       6597  ENSG00000080503  ENSG00000127616
# 1  SMARCA2  SMARCA4       6595       6597  ENSG00000080503  ENSG00000127616
# 2  SMARCA2  SMARCA4       6595       6597  ENSG00000080503  ENSG00000127616
# 3  SMARCA2  SMARCA4       6595       6597  ENSG00000080503  ENSG00000127616
# 4  SMARCA2  SMARCA4       6595       6597  ENSG00000080503  ENSG00000127616
#
#    ...  gtex_max_mean_expr  A1_entrez_new  A2_entrez_new   A1_new   A2_new  \
# 0  ...           34.302868         6595.0         6597.0  SMARCA2  SMARCA4
# 1  ...           34.302868         6595.0         6597.0  SMARCA2  SMARCA4
# 2  ...           34.302868         6595.0         6597.0  SMARCA2  SMARCA4
# 3  ...           34.302868         6595.0         6597.0  SMARCA2  SMARCA4
# 4  ...           34.302868         6595.0         6597.0  SMARCA2  SMARCA4
#
#     A1_ensembl_new   A2_ensembl_new   DepMap_ID   cell_line  cancer_type
# 0  ENSG00000080503  ENSG00000127616  ACH-000017       SKBR3       Breast
# 1  ENSG00000080503  ENSG00000127616  ACH-000019        MCF7       Breast
# 2  ENSG00000080503  ENSG00000127616  ACH-000028        KPL1       Breast
# 3  ENSG00000080503  ENSG00000127616  ACH-000044  MDAMB134VI       Breast
# 4  ENSG00000080503  ENSG00000127616  ACH-000097       ZR751       Breast
#
# [5 rows x 46 columns]

# %%
# Filter mutations for the cell lines of interest
CCLE_mutations_raw = pd.read_csv(mutation_data_path, low_memory=False)
mutated_cell_lines = CCLE_mutations_raw[['HugoSymbol','EntrezGeneID', 'VariantInfo', 'LikelyLoF', 'CCLEDeleterious', 'DepMap_ID']]
mutated_cell_lines = mutated_cell_lines.rename(columns={'HugoSymbol':'symbol', 'EntrezGeneID':'entrez_id'})

breast_mutated_cell_lines = mutated_cell_lines.loc[mutated_cell_lines['DepMap_ID'].isin(paralog_pairs_breast['DepMap_ID']),]
display(breast_mutated_cell_lines.head())
# Out:
#          symbol  entrez_id VariantInfo LikelyLoF CCLEDeleterious   DepMap_ID
# 15886   PRAMEF4   400735.0    MISSENSE       NaN             NaN  ACH-000117
# 15887  PRAMEF18   391003.0    MISSENSE       NaN             NaN  ACH-000117
# 15888  PRAMEF18   391003.0    MISSENSE       NaN             NaN  ACH-000117
# 15889  PRAMEF18   391003.0      SILENT       NaN             NaN  ACH-000117
# 15890  PRAMEF18   391003.0      SILENT       NaN             NaN  ACH-000117

# %%
breast_mutated_cell_lines_df = breast_mutated_cell_lines.loc[(breast_mutated_cell_lines['symbol'] == 'RB1') | (breast_mutated_cell_lines['symbol'] == 'PTEN') | (breast_mutated_cell_lines['symbol'] == 'PIK3CA'),]
print(f"# of breast cell lines with RB1 mutation: {breast_mutated_cell_lines_df.loc[breast_mutated_cell_lines_df.symbol == 'RB1', ].shape[0]}")
print(f"# of breast cell lines with PIK3CA mutation: {breast_mutated_cell_lines_df.loc[breast_mutated_cell_lines_df.symbol == 'PIK3CA', ].shape[0]}")
print(f"# of breast cell lines with PTEN mutation: {breast_mutated_cell_lines_df.loc[breast_mutated_cell_lines_df.symbol == 'PTEN', ].shape[0]}")
breast_mutated_cell_lines_df.head()
# Out:
# # of breast cell lines with RB1 mutation: 6
# # of breast cell lines with PIK3CA mutation: 27
# # of breast cell lines with PTEN mutation: 14
#        symbol  entrez_id      VariantInfo LikelyLoF CCLEDeleterious  \
# 15951  PIK3CA     5290.0         MISSENSE       NaN             NaN
# 21847  PIK3CA     5290.0         MISSENSE       NaN             NaN
# 27001  PIK3CA     5290.0         MISSENSE       NaN             NaN
# 27257    PTEN     5728.0  FRAME_SHIFT_DEL         Y               Y
# 27258    PTEN     5728.0  FRAME_SHIFT_INS         Y               Y
#
#         DepMap_ID
# 15951  ACH-000117
# 21847  ACH-001393
# 27001  ACH-000856
# 27257  ACH-000856
# 27258  ACH-000856

# %%
def check_mutation_status(row):
    if row['symbol'] == 'RB1' and pd.notna(row['VariantInfo']):
         return 'RB1 mutated'
    elif row['symbol'] == 'BRAF' and pd.notna(row['VariantInfo']):
         return 'BRAF mutated'
    elif row['symbol'] == 'NRAS' and pd.notna(row['VariantInfo']):
         return 'NRAS mutated'
    elif row['symbol'] == 'KRAS' and pd.notna(row['VariantInfo']):
         return 'KRAS mutated'
    elif row['symbol'] == 'PIK3CA' and pd.notna(row['VariantInfo']):
          return 'PIK3CA mutated'
    elif row['symbol'] == 'PTEN' and pd.notna(row['VariantInfo']):
         return 'PTEN mutated'
    else:
         return 'No mutation'

# %%
breast_mutated_cell_lines_df = breast_mutated_cell_lines_df.copy()
breast_mutated_cell_lines_df['mutation_status'] = breast_mutated_cell_lines_df.apply(check_mutation_status, axis=1)
breast_mutated_cell_lines_df.sort_values(by=['DepMap_ID'], inplace=True)

# %%
breast_mutated_cell_lines_df
# Out:
#          symbol  entrez_id      VariantInfo LikelyLoF CCLEDeleterious  \
# 264757   PIK3CA     5290.0         MISSENSE       NaN             NaN
# 1104279  PIK3CA     5290.0         MISSENSE       NaN             NaN
# 69081      PTEN     5728.0         MISSENSE       NaN             NaN
# 15951    PIK3CA     5290.0         MISSENSE       NaN             NaN
# 345794   PIK3CA     5290.0         MISSENSE       NaN             NaN
# 338982   PIK3CA     5290.0         MISSENSE       NaN             NaN
# 1164218    PTEN     5728.0  FRAME_SHIFT_DEL         Y               Y
# 294055   PIK3CA     5290.0         MISSENSE       NaN             NaN
# 141976      RB1     5925.0         MISSENSE       NaN             NaN
# 141701   PIK3CA     5290.0         MISSENSE       NaN             NaN
# 141702   PIK3CA     5290.0         MISSENSE       NaN             NaN
# 141975      RB1     5925.0         MISSENSE       NaN             NaN
# 345076   PIK3CA     5290.0         MISSENSE       NaN             NaN
# 179830      RB1     5925.0     IN_FRAME_DEL       NaN             NaN
# 179761     PTEN     5728.0  FRAME_SHIFT_DEL         Y               Y
# 401539   PIK3CA     5290.0         MISSENSE       NaN             NaN
# 116631   PIK3CA     5290.0         MISSENSE       NaN             NaN
# 116632   PIK3CA     5290.0         MISSENSE       NaN             NaN
# 87093      PTEN     5728.0         MISSENSE       NaN             NaN
# 162485   PIK3CA     5290.0         MISSENSE       NaN             NaN
# 698495     PTEN     5728.0      SPLICE_SITE       NaN             NaN
# 27258      PTEN     5728.0  FRAME_SHIFT_INS         Y               Y
# 27257      PTEN     5728.0  FRAME_SHIFT_DEL         Y               Y
# 27001    PIK3CA     5290.0         MISSENSE       NaN             NaN
# 318656      RB1     5925.0  FRAME_SHIFT_DEL         Y               Y
# 293318   PIK3CA     5290.0         MISSENSE       NaN             NaN
# 745815     PTEN     5728.0         MISSENSE       NaN             NaN
# 512927     PTEN     5728.0         NONSENSE         Y               Y
# 512926     PTEN     5728.0         MISSENSE       NaN             NaN
# 512702   PIK3CA     5290.0         MISSENSE       NaN             NaN
# 512703   PIK3CA     5290.0         MISSENSE       NaN             NaN
# 171645   PIK3CA     5290.0         MISSENSE       NaN             NaN
# 171948     PTEN     5728.0         MISSENSE       NaN             NaN
# 214172   PIK3CA     5290.0         MISSENSE       NaN             NaN
# 160683     PTEN     5728.0  FRAME_SHIFT_DEL         Y               Y
# 198486   PIK3CA     5290.0         MISSENSE       NaN             NaN
# 198487   PIK3CA     5290.0         MISSENSE       NaN             NaN
# 1368995    PTEN     5728.0  FRAME_SHIFT_DEL         Y               Y
# 1121638  PIK3CA     5290.0         MISSENSE       NaN             NaN
# 1362996  PIK3CA     5290.0         MISSENSE       NaN             NaN
# 1363156     RB1     5925.0         MISSENSE       NaN             NaN
# 410783   PIK3CA     5290.0         MISSENSE       NaN             NaN
# 21847    PIK3CA     5290.0         MISSENSE       NaN             NaN
# 813761   PIK3CA     5290.0         MISSENSE       NaN             NaN
# 1117838     RB1     5925.0      SPLICE_SITE       NaN             NaN
# 1383223  PIK3CA     5290.0         MISSENSE       NaN             NaN
# 1268939    PTEN     5728.0         MISSENSE       NaN             NaN
#
#           DepMap_ID mutation_status
# 264757   ACH-000019  PIK3CA mutated
# 1104279  ACH-000028  PIK3CA mutated
# 69081    ACH-000097    PTEN mutated
# 15951    ACH-000117  PIK3CA mutated
# 345794   ACH-000147  PIK3CA mutated
# 338982   ACH-000276  PIK3CA mutated
# 1164218  ACH-000288    PTEN mutated
# 294055   ACH-000330  PIK3CA mutated
# 141976   ACH-000536     RB1 mutated
# 141701   ACH-000536  PIK3CA mutated
# 141702   ACH-000536  PIK3CA mutated
# 141975   ACH-000536     RB1 mutated
# 345076   ACH-000554  PIK3CA mutated
# 179830   ACH-000668     RB1 mutated
# 179761   ACH-000668    PTEN mutated
# 401539   ACH-000711  PIK3CA mutated
# 116631   ACH-000725  PIK3CA mutated
# 116632   ACH-000725  PIK3CA mutated
# 87093    ACH-000783    PTEN mutated
# 162485   ACH-000818  PIK3CA mutated
# 698495   ACH-000849    PTEN mutated
# 27258    ACH-000856    PTEN mutated
# 27257    ACH-000856    PTEN mutated
# 27001    ACH-000856  PIK3CA mutated
# 318656   ACH-000857     RB1 mutated
# 293318   ACH-000859  PIK3CA mutated
# 745815   ACH-000876    PTEN mutated
# 512927   ACH-000902    PTEN mutated
# 512926   ACH-000902    PTEN mutated
# 512702   ACH-000902  PIK3CA mutated
# 512703   ACH-000902  PIK3CA mutated
# 171645   ACH-000910  PIK3CA mutated
# 171948   ACH-000910    PTEN mutated
# 214172   ACH-000927  PIK3CA mutated
# 160683   ACH-000930    PTEN mutated
# 198486   ACH-000934  PIK3CA mutated
# 198487   ACH-000934  PIK3CA mutated
# 1368995  ACH-001065    PTEN mutated
# 1121638  ACH-001388  PIK3CA mutated
# 1362996  ACH-001391  PIK3CA mutated
# 1363156  ACH-001391     RB1 mutated
# 410783   ACH-001392  PIK3CA mutated
# 21847    ACH-001393  PIK3CA mutated
# 813761   ACH-001819  PIK3CA mutated
# 1117838  ACH-001820     RB1 mutated
# 1383223  ACH-002179  PIK3CA mutated
# 1268939  ACH-002208    PTEN mutated

# %%
breast_mutated_cell_lines_df = breast_mutated_cell_lines_df.drop_duplicates(subset=['DepMap_ID'], keep='first')
breast_mutated_cell_lines_df.loc[breast_mutated_cell_lines_df['DepMap_ID'] == 'ACH-000536', 'mutation_status'] = 'RB1 mutated, PIK3CA mutated'
breast_mutated_cell_lines_df.loc[breast_mutated_cell_lines_df['DepMap_ID'] == 'ACH-000668', 'mutation_status'] = 'RB1 mutated, PTEN mutated'
breast_mutated_cell_lines_df.loc[breast_mutated_cell_lines_df['DepMap_ID'] == 'ACH-000856', 'mutation_status'] = 'PTEN mutated, PIK3CA mutated'
breast_mutated_cell_lines_df.loc[breast_mutated_cell_lines_df['DepMap_ID'] == 'ACH-000902', 'mutation_status'] = 'PTEN mutated, PIK3CA mutated'
breast_mutated_cell_lines_df.loc[breast_mutated_cell_lines_df['DepMap_ID'] == 'ACH-000910', 'mutation_status'] = 'PTEN mutated, PIK3CA mutated'
breast_mutated_cell_lines_df.loc[breast_mutated_cell_lines_df['DepMap_ID'] == 'ACH-001391', 'mutation_status'] = 'RB1 mutated, PIK3CA mutated'
dict_breast_mut_cell_line = dict(zip(breast_mutated_cell_lines_df['DepMap_ID'], breast_mutated_cell_lines_df['mutation_status']))

# %%
paralog_pairs_breast.insert(paralog_pairs_breast.shape[1], 'mutation_status', 
                            paralog_pairs_breast['DepMap_ID'].map(dict_breast_mut_cell_line))
paralog_pairs_breast['mutation_status'] = paralog_pairs_breast['mutation_status'].fillna('No mutation')

# %%
# label cell lines based on HER2 status
her2_neg = model_info_df.loc[(model_info_df['LegacySubSubtype'] == 'ERneg_HER2neg') |
                             (model_info_df['LegacySubSubtype'] == 'ERpos_HER2neg'),]

her2_pos = model_info_df.loc[(model_info_df['LegacySubSubtype'] == 'ERneg_HER2pos') |
                             (model_info_df['LegacySubSubtype'] == 'ERpos_HER2pos'),]

her2_neg_cell = her2_neg['ModelID'].unique()
her2_pos_cell = her2_pos['ModelID'].unique()   

# Define a function to label cells
def label_cell(cell_name):
    if cell_name in her2_neg_cell:
        return 'her2_neg'
    elif cell_name in her2_pos_cell:
        return 'her2_pos'
    else:
        return 'unknown'
    
paralog_pairs_breast['her_label'] = paralog_pairs_breast['DepMap_ID'].apply(label_cell)
paralog_pairs_breast['her_label'].value_counts()
# Out:
# her_label
# her2_neg    1722456
# unknown     1026144
# her2_pos     696312
# Name: count, dtype: int64

# %%
# label breast cancer cell lines based on RB1 deficiency status

# reference paper 
# https://www.nature.com/articles/s41388-018-0368-z

rb1_defects_dict = {"ACH-000258":"RB1 defective", 
                    "ACH-000849":"RB1 defective",
                    "ACH-000643":"RB1 defective",
                    "ACH-000288":"RB1 defective",
                    "ACH-000902":"RB1 defective",
                    "ACH-000223":"RB1 defective",
                    "ACH-000573":"RB1 defective",
                    "ACH-000857":"RB1 defective",
                    "ACH-001390":"RB1 defective",
                    "ACH-000111":"RB1 defective",
                    "ACH-002324":"RB1 defective",
                    "ACH-000768":"wt",
                    "ACH-000374":"wt",
                    "ACH-000148":"wt",
                    "ACH-000276":"wt",
                    "ACH-000536":"wt",
                    "ACH-000624":"wt",
                    "ACH-000910":"wt",
                    "ACH-000699":"wt",
                    "ACH-002328":"wt",
                    "ACH-002329":"wt",
                    "ACH-000212":"wt",
                    "ACH-002321":"wt",
                    "ACH-001819":"wt",
                    "ACH-000196":"wt",
                    "ACH-002322":"wt",
                    "ACH-002323":"wt",
                    "ACH-001388":"wt",
                    "ACH-001396":"wt",
                    "ACH-000668":"wt",
                    "ACH-001391":"wt",
                    "ACH-001825":"wt",
                    "ACH-002330":"wt",
                    "ACH-001827":"wt",
                    "ACH-001389":"wt",
                    "ACH-000856":"wt",
                    "ACH-001392":"wt",
                    "ACH-002319":"wt",
                    "ACH-002326":"wt",
                    "ACH-000621":"wt",
                    "ACH-001394":"wt"}

# mb157 - defective is missing

# Add a default label for missing entries
def label_rb1_status_with_dict(cell_name):
    # Use the dictionary to get the RB1 status, default to 'unknown' if not found
    return rb1_defects_dict.get(cell_name, 'unknown')

# Apply the function to your dataframe
paralog_pairs_breast_cancer_df = paralog_pairs_breast.copy()
paralog_pairs_breast_cancer_df['rb1_defects'] = paralog_pairs_breast_cancer_df['DepMap_ID'].apply(label_rb1_status_with_dict)
paralog_pairs_breast_cancer_df['rb1_defects'].value_counts()
# Out:
# rb1_defects
# unknown          1978992
# wt               1062792
# RB1 defective     403128
# Name: count, dtype: int64

# %%
print(paralog_pairs_breast_cancer_df.genepair.nunique())
display(paralog_pairs_breast_cancer_df['mutation_status'].value_counts())
# Out:
# 36648
# mutation_status
# No mutation                     2198880
# PIK3CA mutated                   659664
# PTEN mutated                     293184
# PTEN mutated, PIK3CA mutated     109944
# RB1 mutated, PIK3CA mutated       73296
# RB1 mutated                       73296
# RB1 mutated, PTEN mutated         36648
# Name: count, dtype: int64

# %%
paralog_pairs_breast_cancer_df[:3]
# Out:
#    prediction_rank  prediction_percentile     old_genepair         genepair  \
# 0                1                    0.1  SMARCA2_SMARCA4  SMARCA2_SMARCA4
# 1                1                    0.1  SMARCA2_SMARCA4  SMARCA2_SMARCA4
# 2                1                    0.1  SMARCA2_SMARCA4  SMARCA2_SMARCA4
#
#         A1       A2  A1_entrez  A2_entrez       A1_ensembl       A2_ensembl  \
# 0  SMARCA2  SMARCA4       6595       6597  ENSG00000080503  ENSG00000127616
# 1  SMARCA2  SMARCA4       6595       6597  ENSG00000080503  ENSG00000127616
# 2  SMARCA2  SMARCA4       6595       6597  ENSG00000080503  ENSG00000127616
#
#    ...   A1_new   A2_new   A1_ensembl_new   A2_ensembl_new   DepMap_ID  \
# 0  ...  SMARCA2  SMARCA4  ENSG00000080503  ENSG00000127616  ACH-000017
# 1  ...  SMARCA2  SMARCA4  ENSG00000080503  ENSG00000127616  ACH-000019
# 2  ...  SMARCA2  SMARCA4  ENSG00000080503  ENSG00000127616  ACH-000028
#
#    cell_line  cancer_type  mutation_status  her_label  rb1_defects
# 0      SKBR3       Breast      No mutation   her2_pos      unknown
# 1       MCF7       Breast   PIK3CA mutated   her2_neg      unknown
# 2       KPL1       Breast   PIK3CA mutated   her2_neg      unknown
#
# [3 rows x 49 columns]

# %%
paralog_pairs_breast_cancer_df.to_csv(get_data_path(['data', 'output', 'breast_cancer'], 'paralog_pairs_breast_cancer_df.csv'), index=False)
