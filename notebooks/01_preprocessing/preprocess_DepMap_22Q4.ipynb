# %% [markdown]
# ### DepMap 22Q4 Data Preprocessing
#
# This notebook processes data from the DepMap 22Q4 release to prepare standardized datasets for synthetic lethality prediction. It handles gene expression, copy number, gene essentiality, mutations, and sample information data.
#
# **Inputs:**
# - DepMap 22Q4 gene expression data (TPM log+1 transformed)
# - DepMap 22Q4 copy number data
# - DepMap 22Q4 CRISPR gene effect scores
# - DepMap 22Q4 mutations
# - DepMap 22Q4 common essential genes
# - Gene symbol mapping file for standardization
# - Sample information metadata
#
# **Outputs:**
# - Standardized gene expression data (raw and z-score normalized)
# - Copy number data
# - Gene essentiality scores (raw and z-score normalized)
# - Filtered mutation data with damaging variants
# - Common essential genes list
# - All datasets mapped to consistent Entrez IDs
#
# ### Setup and File Paths
#
# **Import required libraries and set up file paths:**

# %%
# import modules
import os
import re
import pandas as pd
import numpy as np

# %%
cwd = os.getcwd()
BASE_DIR = os.path.abspath(os.path.join(cwd, "..", ".."))

# build paths inside the repo
get_data_path = lambda folders, fname: os.path.normpath(
    os.path.join(BASE_DIR, *folders, fname)
)

file_path_gene_expression = get_data_path(['data', 'input', 'DepMap22Q4'], 'OmicsExpressionProteinCodingGenesTPMLogp1.csv')
file_path_gene_essentiality = get_data_path(['data','input', 'DepMap22Q4'], 'CRISPRGeneEffect.csv')
file_path_copy_number = get_data_path(['data', 'input', 'DepMap22Q4'], 'OmicsCNGene.csv')
file_path_mutation = get_data_path(['data', 'input', 'DepMap22Q4'], 'OmicsSomaticMutations.csv')
file_common_essential_genes = get_data_path(['data', 'input', 'DepMap22Q4'], 'CRISPRInferredCommonEssentials.csv')

file_path_genenames = get_data_path(['data', 'input', 'other'], 'approved_and_previous_symbols.csv')

file_path_sample_info = get_data_path(['data', 'input', 'DepMap22Q4'], 'sample_info.csv')

# %% [markdown]
# ### Process Gene Expression Data

# %%
CCLE_expression_raw = pd.read_csv(file_path_gene_expression, index_col=0)

# %%
CCLE_expression_raw[:3]
# Out:
#             TSPAN6 (7105)  TNMD (64102)  DPM1 (8813)  SCYL3 (57147)  \
# ACH-001113       4.331992      0.000000     7.364660       2.792855
# ACH-001289       4.567424      0.584963     7.106641       2.543496
# ACH-001339       3.150560      0.000000     7.379118       2.333424
#
#             C1orf112 (55732)  FGR (2268)  CFH (3075)  FUCA2 (2519)  \
# ACH-001113          4.471187    0.028569    1.226509      3.044394
# ACH-001289          3.504620    0.000000    0.189034      3.813525
# ACH-001339          4.228049    0.056584    1.310340      6.687201
#
#             GCLC (2729)  NFYA (4800)  ...  H3C2 (8358)  H3C3 (8352)  \
# ACH-001113     6.500005     4.739848  ...     2.689299     0.189034
# ACH-001289     4.221877     3.481557  ...     1.286881     1.049631
# ACH-001339     3.682573     3.273516  ...     0.594549     1.097611
#
#             AC098582.1 (8916)  DUS4L-BCAP29 (115253422)  \
# ACH-001113           0.201634                  2.130931
# ACH-001289           0.321928                  1.464668
# ACH-001339           0.831877                  2.946731
#
#             C8orf44-SGK3 (100533105)  ELOA3B (728929)  NPBWR1 (2831)  \
# ACH-001113                  0.555816              0.0       0.275007
# ACH-001289                  0.632268              0.0       0.014355
# ACH-001339                  0.475085              0.0       0.084064
#
#             ELOA3D (100506888)  ELOA3 (162699)  CDR1 (1038)
# ACH-001113                 0.0             0.0     0.000000
# ACH-001289                 0.0             0.0     0.000000
# ACH-001339                 0.0             0.0     0.042644
#
# [3 rows x 19193 columns]

# %%
get_entrez_id = lambda x : re.search(r'\((.*?)\)', x).group(1) #regex to fetch the entrez_id in the column
CCLE_expression = CCLE_expression_raw.rename(columns=get_entrez_id)
print('Number of genes:', CCLE_expression.shape[1], ', num of cell lines:', CCLE_expression.shape[0])
# Out:
# Number of genes: 19193 , num of cell lines: 1408

# %%
CCLE_expression[:2]
# Out:
#                 7105     64102      8813     57147     55732      2268  \
# ACH-001113  4.331992  0.000000  7.364660  2.792855  4.471187  0.028569
# ACH-001289  4.567424  0.584963  7.106641  2.543496  3.504620  0.000000
#
#                 3075      2519      2729      4800  ...      8358      8352  \
# ACH-001113  1.226509  3.044394  6.500005  4.739848  ...  2.689299  0.189034
# ACH-001289  0.189034  3.813525  4.221877  3.481557  ...  1.286881  1.049631
#
#                 8916  115253422  100533105  728929      2831  100506888  \
# ACH-001113  0.201634   2.130931   0.555816     0.0  0.275007        0.0
# ACH-001289  0.321928   1.464668   0.632268     0.0  0.014355        0.0
#
#             162699  1038
# ACH-001113     0.0   0.0
# ACH-001289     0.0   0.0
#
# [2 rows x 19193 columns]

# %% [markdown]
# ### Process Copy Number Data

# %%
CCLE_gene_cn_raw = pd.read_csv(file_path_copy_number, index_col=0)

# %%
CCLE_gene_cn_raw[:3]
# Out:
#             DDX11L1 (84771)  WASH7P (653635)  MIR6859-1 (102466751)  \
# ACH-000759         1.675758         1.675758               1.675758
# ACH-000681         0.775472         0.775472               0.775472
# ACH-000769         2.988233         2.988233               2.988233
#
#             MIR1302-2 (100302278)  FAM138A (645520)  OR4F5 (79501)  \
# ACH-000759               1.675758          1.675758       1.675758
# ACH-000681               0.775472          0.775472       0.775472
# ACH-000769               2.988233          2.988233       2.988233
#
#             WASH9P (102723897)  MIR6859-2 (102465909)  OR4F29 (729759)  \
# ACH-000759            1.675758               1.675758         1.675758
# ACH-000681            0.775472               0.775472         0.775472
# ACH-000769            0.831376               0.831376         0.831376
#
#             AL669831.3 (101928626)  ...  BPY2C (442868)  TTTY4C (474150)  \
# ACH-000759                1.285546  ...             NaN              NaN
# ACH-000681                0.775472  ...             NaN              NaN
# ACH-000769                0.831376  ...             NaN              NaN
#
#             CSPG4P1Y (114758)  CDY1 (9085)  TTTY3 (114760)  SNORD38B (94163)  \
# ACH-000759                NaN          NaN             NaN               NaN
# ACH-000681                NaN          NaN             NaN               NaN
# ACH-000769                NaN          NaN             NaN               NaN
#
#             SCARNA4 (677771)  SNORA50A (677830)  SNORD3D (780854)  \
# ACH-000759               NaN                NaN               NaN
# ACH-000681               NaN                NaN               NaN
# ACH-000769               NaN                NaN               NaN
#
#             POLR2J3 (548644)
# ACH-000759               NaN
# ACH-000681               NaN
# ACH-000769               NaN
#
# [3 rows x 25368 columns]

# %%
CCLE_gene_cn = CCLE_gene_cn_raw.rename(columns=get_entrez_id)
print('Number of genes:', CCLE_gene_cn.shape[1], ', num of cell lines:', CCLE_gene_cn.shape[0])
# Out:
# Number of genes: 25368 , num of cell lines: 1775

# %%
CCLE_gene_cn[:2]
# Out:
#                84771    653635  102466751  100302278    645520     79501  \
# ACH-000759  1.675758  1.675758   1.675758   1.675758  1.675758  1.675758
# ACH-000681  0.775472  0.775472   0.775472   0.775472  0.775472  0.775472
#
#             102723897  102465909    729759  101928626  ...  442868  474150  \
# ACH-000759   1.675758   1.675758  1.675758   1.285546  ...     NaN     NaN
# ACH-000681   0.775472   0.775472  0.775472   0.775472  ...     NaN     NaN
#
#             114758  9085  114760  94163  677771  677830  780854  548644
# ACH-000759     NaN   NaN     NaN    NaN     NaN     NaN     NaN     NaN
# ACH-000681     NaN   NaN     NaN    NaN     NaN     NaN     NaN     NaN
#
# [2 rows x 25368 columns]

# %% [markdown]
# ### Process Gene Essentiality Data

# %%
CRISPR_gene_effect_raw = pd.read_csv(file_path_gene_essentiality, index_col=0)

# %%
CRISPR_gene_effect_raw[:3]
# Out:
#             A1BG (1)  A1CF (29974)   A2M (2)  A2ML1 (144568)  \
# ACH-000004  0.014633     -0.032777 -0.151299       -0.071388
# ACH-000005 -0.261566      0.174833  0.106526        0.135635
# ACH-000007 -0.028717     -0.117017  0.030971        0.083795
#
#             A3GALT2 (127550)  A4GALT (53947)  A4GNT (51146)  AAAS (8086)  \
# ACH-000004          0.046511       -0.162850       0.290698    -0.240991
# ACH-000005         -0.076753       -0.278640       0.239279    -0.325967
# ACH-000007          0.032668       -0.035709       0.012355    -0.192436
#
#             AACS (65985)  AADAC (13)  ...  ZWILCH (55055)  ZWINT (11130)  \
# ACH-000004      0.176710    0.159418  ...       -0.188857      -0.389649
# ACH-000005     -0.116848    0.022227  ...       -0.195492      -0.360578
# ACH-000007     -0.077174    0.164877  ...       -0.200402      -0.382707
#
#             ZXDA (7789)  ZXDB (158586)  ZXDC (79364)  ZYG11A (440590)  \
# ACH-000004     0.112266      -0.002883      0.155729         0.077283
# ACH-000005    -0.126277      -0.059287      0.080543        -0.161894
# ACH-000007     0.006843       0.199553      0.064425        -0.031683
#
#             ZYG11B (79699)  ZYX (7791)  ZZEF1 (23140)  ZZZ3 (26009)
# ACH-000004       -0.294451    0.143978       0.197069     -0.003338
# ACH-000005       -0.070230   -0.006275       0.002458      0.014259
# ACH-000007       -0.291406   -0.065945      -0.260946     -0.329018
#
# [3 rows x 17453 columns]

# %%
CRISPR_gene_effect = CRISPR_gene_effect_raw.rename(columns=get_entrez_id)
print('Number of genes:', CRISPR_gene_effect.shape[1], ', num of cell lines:', CRISPR_gene_effect.shape[0])
# Out:
# Number of genes: 17453 , num of cell lines: 1078

# %%
CRISPR_gene_effect[:2]
# Out:
#                    1     29974         2    144568    127550    53947  \
# ACH-000004  0.014633 -0.032777 -0.151299 -0.071388  0.046511 -0.16285
# ACH-000005 -0.261566  0.174833  0.106526  0.135635 -0.076753 -0.27864
#
#                51146      8086     65985        13  ...     55055     11130  \
# ACH-000004  0.290698 -0.240991  0.176710  0.159418  ... -0.188857 -0.389649
# ACH-000005  0.239279 -0.325967 -0.116848  0.022227  ... -0.195492 -0.360578
#
#                 7789    158586     79364    440590     79699      7791  \
# ACH-000004  0.112266 -0.002883  0.155729  0.077283 -0.294451  0.143978
# ACH-000005 -0.126277 -0.059287  0.080543 -0.161894 -0.070230 -0.006275
#
#                23140     26009
# ACH-000004  0.197069 -0.003338
# ACH-000005  0.002458  0.014259
#
# [2 rows x 17453 columns]

# %% [markdown]
# ### Process Mutation Data

# %%
CCLE_mutations_raw = pd.read_csv(file_path_mutation, low_memory=False)

# %%
CCLE_mutations_raw[:3]
# Out:
#   Chrom       Pos Ref Alt     AF  RefCount  AltCount   GT          PS  \
# 0  chr1   1242864  GC  CT  0.310        19         8  0/1         NaN
# 1  chr1  10647969   A   G  0.400        29        19  0|1  10647969.0
# 2  chr1  10648097   T   G  0.349        21        10  0/1         NaN
#
#   VariantType  ... RevelScore Funseq2Score PharmgkbID DidaID DidaName  \
# 0         DNP  ...        NaN          NaN        NaN    NaN      NaN
# 1         SNP  ...      0.234          3.0        NaN    NaN      NaN
# 2         SNP  ...        NaN          0.0        NaN    NaN      NaN
#
#   GwasDisease GwasPmID  GTexGene   DepMap_ID EntrezGeneID
# 0         NaN      NaN       NaN  ACH-000839     388581.0
# 1         NaN      NaN       NaN  ACH-000839      54897.0
# 2         NaN      NaN       NaN  ACH-000839      54897.0
#
# [3 rows x 56 columns]

# %%
# Filter rows where CCLEDeleterious or LikelyLoF is 'Y'
CCLE_mutations = CCLE_mutations_raw[['HugoSymbol','VariantType', 'VariantInfo', 'CCLEDeleterious', 'LikelyLoF', 'DannScore', 'DepMap_ID', 'EntrezGeneID']]
CCLE_mutations = CCLE_mutations.dropna(subset=['EntrezGeneID'])
CCLE_mutations['EntrezGeneID'] = CCLE_mutations['EntrezGeneID'].astype(int)

# %%
CCLE_mutations['Damaging'] = np.where(
    (CCLE_mutations['CCLEDeleterious'] == 'Y') | (CCLE_mutations['LikelyLoF'] == 'Y'),
    1,
    0
)

# %%
CCLE_mutations[:3]
# Out:
#   HugoSymbol VariantType VariantInfo CCLEDeleterious LikelyLoF  DannScore  \
# 0   C1QTNF12         DNP    MISSENSE             NaN       NaN        NaN
# 1      CASZ1         SNP    MISSENSE             NaN       NaN   0.731644
# 2      CASZ1         SNP      SILENT             NaN       NaN   0.711158
#
#     DepMap_ID  EntrezGeneID  Damaging
# 0  ACH-000839        388581         0
# 1  ACH-000839         54897         0
# 2  ACH-000839         54897         0

# %%
#CCLE_mutations.loc[CCLE_mutations.symbol == 'MUC12']

# %% [markdown]
# ### Load Common Essential Genes

# %%
common_essentials_raw = pd.read_csv(file_common_essential_genes, index_col=0)

# %%
common_essentials = common_essentials_raw.rename(index=get_entrez_id)
print('Number of genes:', common_essentials.index.nunique())
# Out:
# Number of genes: 1855

# %% [markdown]
# ### Load Sample Information
#
# **Load cell line metadata:**
# - DepMap_ID: Static primary key assigned by DepMap to each cell line
# - CCLE_Name: Previous naming system using stripped cell line name + lineage

# %%
sample_info = pd.read_csv(file_path_sample_info, index_col=0, usecols= ['DepMap_ID', 'CCLE_Name'])

# %%
print('num of cell lines with Gene Exp TPM value:', CCLE_expression.shape[0])
print('num of cell lines:', sample_info.shape[0])
sample_info[:2]
# Out:
# num of cell lines with Gene Exp TPM value: 1408
# num of cell lines: 1829
#                                           CCLE_Name
# DepMap_ID
# ACH-000001                          NIHOVCAR3_OVARY
# ACH-000002  HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE

# %% [markdown]
# ### Map Genes to Standard Identifiers

# %%
# read the gene names mapping file
id_map = pd.read_csv(file_path_genenames)
id_map['entrez_id'] = id_map['entrez_id'].astype(str)

# %%
id_map.head()
# Out:
#   Approved symbol Previous symbol entrez_id       ensembl_id  \
# 0            A1BG             NaN         1  ENSG00000121410
# 1        A1BG-AS1      NCRNA00181    503538  ENSG00000268895
# 2        A1BG-AS1          A1BGAS    503538  ENSG00000268895
# 3        A1BG-AS1         A1BG-AS    503538  ENSG00000268895
# 4            A1CF             NaN     29974  ENSG00000148584
#
#   UniProt ID(supplied by UniProt)
# 0                          P04217
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                          Q9NQ94

# %%
# Filter gene expression data for genes with valid mappings
mapped_CCLE_expression = CCLE_expression.loc[:,CCLE_expression.columns.isin(id_map["entrez_id"])]
unmapped_CCLE_expression = CCLE_expression.loc[:,~CCLE_expression.columns.isin(id_map["entrez_id"])]
print(len(mapped_CCLE_expression.columns), "genes in CCLE_expression file are present in HGNC database with the same entrez_ID")
print(len(unmapped_CCLE_expression.columns), "genes are missing.")
mapped_CCLE_expression[:3]
# Out:
# 19171 genes in CCLE_expression file are present in HGNC database with the same entrez_ID
# 22 genes are missing.
#                 7105     64102      8813     57147     55732      2268  \
# ACH-001113  4.331992  0.000000  7.364660  2.792855  4.471187  0.028569
# ACH-001289  4.567424  0.584963  7.106641  2.543496  3.504620  0.000000
# ACH-001339  3.150560  0.000000  7.379118  2.333424  4.228049  0.056584
#
#                 3075      2519      2729      4800  ...      8358      8352  \
# ACH-001113  1.226509  3.044394  6.500005  4.739848  ...  2.689299  0.189034
# ACH-001289  0.189034  3.813525  4.221877  3.481557  ...  1.286881  1.049631
# ACH-001339  1.310340  6.687201  3.682573  3.273516  ...  0.594549  1.097611
#
#                 8916  115253422  100533105  728929      2831  100506888  \
# ACH-001113  0.201634   2.130931   0.555816     0.0  0.275007        0.0
# ACH-001289  0.321928   1.464668   0.632268     0.0  0.014355        0.0
# ACH-001339  0.831877   2.946731   0.475085     0.0  0.084064        0.0
#
#             162699      1038
# ACH-001113     0.0  0.000000
# ACH-001289     0.0  0.000000
# ACH-001339     0.0  0.042644
#
# [3 rows x 19171 columns]

# %%
# Filter copy number data for genes with valid mappings
mapped_CCLE_gene_cn = CCLE_gene_cn.loc[:,CCLE_gene_cn.columns.isin(id_map["entrez_id"])]
unmapped_CCLE_gene_cn = CCLE_gene_cn.loc[:,~CCLE_gene_cn.columns.isin(id_map["entrez_id"])]
print(len(mapped_CCLE_gene_cn.columns), "genes in CCLE_gene_cn file are present in HGNC database with the same entrez_ID")
print(len(unmapped_CCLE_gene_cn.columns), "genes are missing.")
mapped_CCLE_gene_cn[:3]
# Out:
# 24733 genes in CCLE_gene_cn file are present in HGNC database with the same entrez_ID
# 635 genes are missing.
#                84771    653635  102466751  100302278    645520     79501  \
# ACH-000759  1.675758  1.675758   1.675758   1.675758  1.675758  1.675758
# ACH-000681  0.775472  0.775472   0.775472   0.775472  0.775472  0.775472
# ACH-000769  2.988233  2.988233   2.988233   2.988233  2.988233  2.988233
#
#             102465909    729759     81399  105378580  ...  442868  474150  \
# ACH-000759   1.675758  1.675758  1.675758   0.589654  ...     NaN     NaN
# ACH-000681   0.775472  0.775472  0.775472   0.775472  ...     NaN     NaN
# ACH-000769   0.831376  0.831376  0.831376   0.831376  ...     NaN     NaN
#
#             114758  9085  114760  94163  677771  677830  780854  548644
# ACH-000759     NaN   NaN     NaN    NaN     NaN     NaN     NaN     NaN
# ACH-000681     NaN   NaN     NaN    NaN     NaN     NaN     NaN     NaN
# ACH-000769     NaN   NaN     NaN    NaN     NaN     NaN     NaN     NaN
#
# [3 rows x 24733 columns]

# %%
# Filter gene essentiality data for genes with valid mappings
mapped_CRISPR_gene_effect = CRISPR_gene_effect.loc[:,CRISPR_gene_effect.columns.isin(id_map["entrez_id"])]
unmapped_CRISPR_gene_effect = CRISPR_gene_effect.loc[:,~CRISPR_gene_effect.columns.isin(id_map["entrez_id"])]
print(len(mapped_CRISPR_gene_effect.columns), "genes in CRISPR_gene_effect file are present in HGNC database with the same entrez_ID")
print(len(unmapped_CRISPR_gene_effect.columns), "genes are missing.")
mapped_CRISPR_gene_effect[:3]
# Out:
# 17453 genes in CRISPR_gene_effect file are present in HGNC database with the same entrez_ID
# 0 genes are missing.
#                    1     29974         2    144568    127550     53947  \
# ACH-000004  0.014633 -0.032777 -0.151299 -0.071388  0.046511 -0.162850
# ACH-000005 -0.261566  0.174833  0.106526  0.135635 -0.076753 -0.278640
# ACH-000007 -0.028717 -0.117017  0.030971  0.083795  0.032668 -0.035709
#
#                51146      8086     65985        13  ...     55055     11130  \
# ACH-000004  0.290698 -0.240991  0.176710  0.159418  ... -0.188857 -0.389649
# ACH-000005  0.239279 -0.325967 -0.116848  0.022227  ... -0.195492 -0.360578
# ACH-000007  0.012355 -0.192436 -0.077174  0.164877  ... -0.200402 -0.382707
#
#                 7789    158586     79364    440590     79699      7791  \
# ACH-000004  0.112266 -0.002883  0.155729  0.077283 -0.294451  0.143978
# ACH-000005 -0.126277 -0.059287  0.080543 -0.161894 -0.070230 -0.006275
# ACH-000007  0.006843  0.199553  0.064425 -0.031683 -0.291406 -0.065945
#
#                23140     26009
# ACH-000004  0.197069 -0.003338
# ACH-000005  0.002458  0.014259
# ACH-000007 -0.260946 -0.329018
#
# [3 rows x 17453 columns]

# %%
# Filter mutation data for genes with valid mappings
CCLE_mutations = CCLE_mutations.rename(columns={'EntrezGeneID': 'entrez_id'})
CCLE_mutations['entrez_id'] = CCLE_mutations['entrez_id'].astype(str)

filtered_CCLE_mutations = CCLE_mutations.loc[CCLE_mutations['entrez_id'].isin(id_map['entrez_id']),:]

print('Number of cell lines:', len(np.unique(filtered_CCLE_mutations.DepMap_ID)))
print('Number of genes:', len(np.unique(filtered_CCLE_mutations.entrez_id)))

filtered_CCLE_mutations.sort_values(by=['entrez_id']).reset_index(drop=True)[:4]
# Out:
# Number of cell lines: 1702
# Number of genes: 19613
#   HugoSymbol VariantType VariantInfo CCLEDeleterious LikelyLoF  DannScore  \
# 0       A1BG         SNP    MISSENSE             NaN       NaN   0.699240
# 1       A1BG         SNP      SILENT             NaN       NaN   0.597227
# 2       A1BG         SNP      SILENT             NaN         Y   0.969591
# 3       A1BG         SNP    MISSENSE             NaN       NaN   0.478322
#
#     DepMap_ID entrez_id  Damaging
# 0  ACH-000281         1         0
# 1  ACH-000876         1         0
# 2  ACH-002166         1         1
# 3  ACH-000865         1         0

# %%
# check the entrez_id of common essentials 
mapped_common_essentials = common_essentials.loc[common_essentials.index.isin(id_map['entrez_id'])]
len(mapped_common_essentials.index) == len(common_essentials.index)
# Out:
# True

# %% [markdown]
# ### Handle Duplicate Genes
#
# **Check for and handle duplicate Entrez IDs in expression data:**
# - Some genes may appear multiple times due to different symbols mapping to same Entrez ID

# %%
# check the uniqueness of CCLE expression dataset
f = mapped_CCLE_expression.columns.nunique()
print(f, "genes out of", len(mapped_CCLE_expression.columns), "are unique")
print(len(mapped_CCLE_expression.columns)-f, "genes are duplicated")
# Out:
# 19154 genes out of 19171 are unique
# 17 genes are duplicated

# %%
duplicated_CCLE_expression = mapped_CCLE_expression.loc[:,mapped_CCLE_expression.columns.duplicated()] #duplicated genes
cleared_mapped_CCLE_expression = mapped_CCLE_expression.loc[:,~mapped_CCLE_expression.columns.isin(duplicated_CCLE_expression.columns)] #drop duplicated genes

# %%
duplicates = id_map.loc[id_map["entrez_id"].isin(duplicated_CCLE_expression.columns), ["Approved symbol", "entrez_id"]]
duplicates["Format"] = duplicates["Approved symbol"] + " " + "(" + duplicates["entrez_id"] + ")"
duplicates.head()
# Out:
#       Approved symbol entrez_id          Format
# 2881            BOLA2    552900  BOLA2 (552900)
# 5095             CHN2      1124     CHN2 (1124)
# 6037            CRHR1      1394    CRHR1 (1394)
# 12681           HERC3      8916    HERC3 (8916)
# 15956           KYAT1       883     KYAT1 (883)

# %%
mapped_duplicates = CCLE_expression_raw.loc[:,CCLE_expression_raw.columns.isin(duplicates.Format)]
mapped_duplicates = mapped_duplicates.rename(columns=get_entrez_id)

# %%
# concat two dataset as df
expression_data = pd.concat([cleared_mapped_CCLE_expression, mapped_duplicates], axis=1)
print("Is dataset cleared from duplicates?", expression_data.columns.is_unique)
print("Number of unique genes in the dataset:", len(np.unique(expression_data.columns)))
# Out:
# Is dataset cleared from duplicates? True
# Number of unique genes in the dataset: 19154

# %%
# check the uniqueness of CCLE gene copy number dataset
g = np.unique(mapped_CCLE_gene_cn.columns)
print(len(g), "genes out of", len(mapped_CCLE_gene_cn.columns), "are unique")
print(len(mapped_CCLE_gene_cn.columns)-len(g), "genes are duplicated")
# Out:
# 24703 genes out of 24733 are unique
# 30 genes are duplicated

# %%
duplicated_gene_cn = mapped_CCLE_gene_cn.loc[:,mapped_CCLE_gene_cn.columns.duplicated()] #duplicated genes
cleared_gene_cn = mapped_CCLE_gene_cn.loc[:,~mapped_CCLE_gene_cn.columns.isin(duplicated_gene_cn.columns)] #drop duplicated genes

# %%
duplicate_gene_cn = id_map.loc[id_map["entrez_id"].isin(duplicated_CCLE_expression.columns), ["Approved symbol", "entrez_id"]]
duplicate_gene_cn["Format"] = duplicate_gene_cn["Approved symbol"] + " " + "(" + duplicate_gene_cn["entrez_id"] + ")"
duplicate_gene_cn.head()
# Out:
#       Approved symbol entrez_id          Format
# 2881            BOLA2    552900  BOLA2 (552900)
# 5095             CHN2      1124     CHN2 (1124)
# 6037            CRHR1      1394    CRHR1 (1394)
# 12681           HERC3      8916    HERC3 (8916)
# 15956           KYAT1       883     KYAT1 (883)

# %%
mapped_duplicates_gene_cn = CCLE_gene_cn_raw.loc[:,CCLE_gene_cn_raw.columns.isin(duplicate_gene_cn.Format)]
mapped_duplicates_gene_cn = mapped_duplicates_gene_cn.rename(columns=get_entrez_id)

# %%
# concat two dataset as df
copy_number_data = pd.concat([cleared_gene_cn, mapped_duplicates_gene_cn], axis=1)
print("Is dataset cleared from duplicates?", copy_number_data.columns.is_unique)
print("Number of unique genes in the dataset:", len(np.unique(copy_number_data.columns)))
# Out:
# Is dataset cleared from duplicates? True
# Number of unique genes in the dataset: 24690

# %%
# check the uniqueness of CRISPR gene effect
f = mapped_CRISPR_gene_effect.columns.nunique()
print(f, "genes out of", len(mapped_CRISPR_gene_effect.columns), "are unique")
print(len(mapped_CRISPR_gene_effect.columns)-f, "genes are duplicated")
# Out:
# 17453 genes out of 17453 are unique
# 0 genes are duplicated

# %% [markdown]
# ### Calculate Z-Score Normalization
#
# **Normalize gene expression data:**
# - Z-score normalization enables comparison across genes with different expression ranges

# %%
# calculate z-score
zexpression_data = expression_data.apply(lambda x: ((x-x.mean())/x.std(ddof=0)))

# %% [markdown]
# **Normalize gene essentiality data:**

# %%
# calculate z-score
zCRISPR_gene_effect = mapped_CRISPR_gene_effect.apply(lambda x: ((x-x.mean())/x.std(ddof=0)))

# %% [markdown]
# ### Add Cell Line Names
#
# **Map DepMap IDs to cell line names for all datasets:**

# %%
# add CCLE_Name as a new column by mapping
ID_to_cell_name = dict(zip(sample_info.index, sample_info.CCLE_Name))

# %%
expression_data.insert(0, "cell_name", expression_data.index.map(ID_to_cell_name))
expression_data[:3]
# Out:
#                        cell_name      7105     64102      8813     57147  \
# ACH-001113          LC1SQSF_LUNG  4.331992  0.000000  7.364660  2.792855
# ACH-001289  COGAR359_SOFT_TISSUE  4.567424  0.584963  7.106641  2.543496
# ACH-001339          COLO794_SKIN  3.150560  0.000000  7.379118  2.333424
#
#                55732      2268      3075      2519      2729  ...      8916  \
# ACH-001113  4.471187  0.028569  1.226509  3.044394  6.500005  ...  1.367371
# ACH-001289  3.504620  0.000000  0.189034  3.813525  4.221877  ...  3.053111
# ACH-001339  4.228049  0.056584  1.310340  6.687201  3.682573  ...  2.596935
#
#                29970    255027       883    221468     55486    552900  \
# ACH-001113  1.201634  0.000000  1.659925  0.286881  6.397974  4.149747
# ACH-001289  6.179710  0.748461  3.019702  1.807355  5.778734  3.134221
# ACH-001339  1.000000  0.000000  1.815575  0.622930  6.204180  3.363171
#
#               220074    440519    284391
# ACH-001113  2.831877  2.153805  0.000000
# ACH-001289  3.689299  1.669027  1.485427
# ACH-001339  1.895303  0.150560  1.269033
#
# [3 rows x 19155 columns]

# %%
zexpression_data.insert(0, "cell_name", zexpression_data.index.map(ID_to_cell_name))
zexpression_data[:3]
# Out:
#                        cell_name      7105     64102      8813     57147  \
# ACH-001113          LC1SQSF_LUNG  0.588734 -0.202156  1.341424  0.782413
# ACH-001289  COGAR359_SOFT_TISSUE  0.731947  1.493293  0.942510  0.325524
# ACH-001339          COLO794_SKIN -0.129934 -0.202156  1.363777 -0.059381
#
#                55732      2268      3075      2519      2729  ...      8916  \
# ACH-001113  1.015674 -0.333763 -0.419278 -1.154559  1.615601  ... -1.225467
# ACH-001289 -0.214189 -0.356637 -0.882359 -0.730890 -0.360896  ...  0.631138
# ACH-001339  0.706304 -0.311333 -0.381860  0.852051 -0.828794  ...  0.128724
#
#                29970    255027       883    221468     55486    552900  \
# ACH-001113 -0.143460 -0.692331 -1.157672 -0.770213  1.149857  1.662524
# ACH-001289  3.312879  0.182974  0.446167  1.850917  0.027580  0.242377
# ACH-001339 -0.283457 -0.692331 -0.974084 -0.190901  0.798635  0.562549
#
#               220074    440519    284391
# ACH-001113 -0.122769  0.979970 -1.078924
# ACH-001289  1.015032  0.405184  0.672085
# ACH-001339 -1.365604 -1.395212  0.417002
#
# [3 rows x 19155 columns]

# %%
# add CCLE_Name as a new column by mapping
copy_number_data.insert(0, "cell_name", copy_number_data.index.map(ID_to_cell_name))
copy_number_data[:3]
# Out:
#                      cell_name     84771    653635  102466751  100302278  \
# ACH-000759  MDAMB175VII_BREAST  1.675758  1.675758   1.675758   1.675758
# ACH-000681           A549_LUNG  0.775472  0.775472   0.775472   0.775472
# ACH-000769            LK2_LUNG  2.988233  2.988233   2.988233   2.988233
#
#               645520     79501  102465909    729759     81399  ...    440519  \
# ACH-000759  1.675758  1.675758   1.675758  1.675758  1.675758  ...  1.022433
# ACH-000681  0.775472  0.775472   0.775472  0.775472  0.775472  ...  1.174576
# ACH-000769  2.988233  2.988233   0.831376  0.831376  0.831376  ...  0.803640
#
#                29970     55486      8916      8622    221468      1124  \
# ACH-000759  1.080296  1.067112  1.018016  1.016425  0.847287  1.286626
# ACH-000681  1.113181  0.812579  0.839096  1.097764  0.797870  1.115526
# ACH-000769  1.375480  1.375480  0.884088  0.875004  0.848061  1.155236
#
#                 6013     11046       883
# ACH-000759  0.896685  0.853836  1.160203
# ACH-000681  1.373560  0.811848  1.034136
# ACH-000769  1.176019  1.152539  1.120476
#
# [3 rows x 24691 columns]

# %%
# add CCLE_Name as a new column by mapping
mapped_CRISPR_gene_effect.insert(0, "cell_name", mapped_CRISPR_gene_effect.index.map(ID_to_cell_name))
mapped_CRISPR_gene_effect[:3]
# Out:
#                                              cell_name         1     29974  \
# ACH-000004      HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  0.014633 -0.032777
# ACH-000005  HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE -0.261566  0.174833
# ACH-000007                       LS513_LARGE_INTESTINE -0.028717 -0.117017
#
#                    2    144568    127550     53947     51146      8086  \
# ACH-000004 -0.151299 -0.071388  0.046511 -0.162850  0.290698 -0.240991
# ACH-000005  0.106526  0.135635 -0.076753 -0.278640  0.239279 -0.325967
# ACH-000007  0.030971  0.083795  0.032668 -0.035709  0.012355 -0.192436
#
#                65985  ...     55055     11130      7789    158586     79364  \
# ACH-000004  0.176710  ... -0.188857 -0.389649  0.112266 -0.002883  0.155729
# ACH-000005 -0.116848  ... -0.195492 -0.360578 -0.126277 -0.059287  0.080543
# ACH-000007 -0.077174  ... -0.200402 -0.382707  0.006843  0.199553  0.064425
#
#               440590     79699      7791     23140     26009
# ACH-000004  0.077283 -0.294451  0.143978  0.197069 -0.003338
# ACH-000005 -0.161894 -0.070230 -0.006275  0.002458  0.014259
# ACH-000007 -0.031683 -0.291406 -0.065945 -0.260946 -0.329018
#
# [3 rows x 17454 columns]

# %%
zCRISPR_gene_effect.insert(0, "cell_name", zCRISPR_gene_effect.index.map(ID_to_cell_name))
zCRISPR_gene_effect[:3]
# Out:
#                                              cell_name         1     29974  \
# ACH-000004      HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  0.575990  0.134966
# ACH-000005  HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE -2.213047  1.492787
# ACH-000007                       LS513_LARGE_INTESTINE  0.138239 -0.415983
#
#                    2    144568    127550     53947     51146      8086  \
# ACH-000004 -1.846143 -1.416198  0.995485 -0.954077  2.368073  0.137700
# ACH-000005  0.998212  0.570649  0.045985 -2.069485  1.892161 -0.334780
# ACH-000007  0.164679  0.073134  0.888849  0.270677 -0.208148  0.407672
#
#                65985  ...     55055     11130      7789    158586     79364  \
# ACH-000004  1.605523  ... -0.114486  0.495168  1.185707 -0.371118  1.466923
# ACH-000005 -1.093151  ... -0.152088  0.588743 -1.177411 -0.836542  0.824541
# ACH-000007 -0.728426  ... -0.179913  0.517514  0.141338  1.299305  0.686829
#
#               440590     79699      7791     23140     26009
# ACH-000004  1.176361 -1.232019  1.494891  2.650380  1.856408
# ACH-000005 -1.331145  0.641920  0.174599  1.005407  1.968815
# ACH-000007  0.033970 -1.206567 -0.349732 -1.221051 -0.224039
#
# [3 rows x 17454 columns]

# %% [markdown]
# ### Save Processed Data
#
# **Export all processed datasets:**

# %%
output_path = get_data_path(['data', 'output', 'processed_DepMap22Q4'], '')

expression_data.to_csv(os.path.join(output_path, 'expression_data.csv'))
zexpression_data.to_csv(os.path.join(output_path, 'zexpression_data.csv'))
mapped_CRISPR_gene_effect.to_csv(os.path.join(output_path, 'gene_effect_data.csv'))
zCRISPR_gene_effect.to_csv(os.path.join(output_path, 'zgene_effect_data.csv'))
copy_number_data.to_csv(os.path.join(output_path, 'copy_number_data.csv'))
filtered_CCLE_mutations.to_csv(os.path.join(output_path, 'mutation_data.csv'), index=False)
mapped_common_essentials.to_csv(os.path.join(output_path, 'common_essentials.csv'))
