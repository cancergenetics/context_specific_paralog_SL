# %%
# import modules
import os
import pandas as pd
import numpy as np
import random
import pickle

# import scikit-learn modules
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import RocCurveDisplay, PrecisionRecallDisplay, roc_auc_score, average_precision_score, precision_recall_curve, auc, roc_curve

# import visualization modules
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cwd = os.getcwd()
BASE_DIR = os.path.abspath(os.path.join(cwd, "..", ".."))

# build paths inside the repo
get_data_path = lambda folders, fname: os.path.normpath(
    os.path.join(BASE_DIR, *folders, fname)
)

file_path_training_data = get_data_path(['data', 'output', 'models'], 'training_data.csv')
klingbeil_file_path = get_data_path(['data', 'output', 'models'], 'testing_data.csv')
parrish_file_path = get_data_path(['data', 'output', 'models'], 'testing_data_parrish.csv')
harle_file_path = get_data_path(['data', 'output', 'models'], 'testing_data_harle.csv')
chymera_file_path = get_data_path(['data', 'output', 'models'], 'testing_data_chymera.csv')

# Output
file_RF_model_contextualised = get_data_path(['data', 'output', 'models'], 'contextualised_model.pickle')
file_RF_model_full = get_data_path(['data', 'output', 'models'], 'full_model.pickle')

figure_path_roc_auc = get_data_path(['figures', 'model_on_GEMINI'], '4a_roc_auc_klingbeil.png')
figure_path_pr_auc = get_data_path(['figures', 'model_on_GEMINI'], '4b_pr_auc_klingbeil.png')

figure_path_parrish_roc_auc = get_data_path(['figures', 'model_on_GEMINI'], '4a_roc_auc_parrish.png')
figure_path_parrish_pr_auc = get_data_path(['figures', 'model_on_GEMINI'], '4b_pr_auc_parrish.png')

figure_path_harle_roc_auc = get_data_path(['figures', 'model_on_GEMINI'], '4a_roc_auc_harle.png')
figure_path_harle_pr_auc = get_data_path(['figures', 'model_on_GEMINI'], '4b_pr_auc_harle.png')

figure_path_chymera_roc_auc = get_data_path(['figures', 'model_on_GEMINI'], '4a_roc_auc_chymera_validated_GEMINI.png')
figure_path_chymera_pr_auc = get_data_path(['figures', 'model_on_GEMINI'], '4b_pr_auc_chymera_validated_GEMINI.png')

# %%
training_df = pd.read_csv(file_path_training_data)
training_df[:3]
# Out:
#       genepair       A1   A2  A1_entrez  A2_entrez   DepMap_ID  \
# 0  A3GALT2_ABO  A3GALT2  ABO   127550.0       28.0  ACH-000022
# 1  A3GALT2_ABO  A3GALT2  ABO   127550.0       28.0  ACH-000307
# 2  A3GALT2_ABO  A3GALT2  ABO   127550.0       28.0  ACH-000632
#
#             cell_line  Gemini_FDR   raw_LFC     SL  ... colocalisation  \
# 0  PATU8988S_PANCREAS    0.998944  0.088856  False  ...            0.0
# 1        PK1_PANCREAS    0.986587  0.201704  False  ...            0.0
# 2         HS944T_SKIN    1.000000  0.069772  False  ...            0.0
#
#   interact  n_total_ppi  fet_ppi_overlap  gtex_spearman_corr  \
# 0    False          3.0              0.0            0.114847
# 1    False          3.0              0.0            0.114847
# 2    False          3.0              0.0            0.114847
#
#    gtex_min_mean_expr  gtex_max_mean_expr    GEMINI       LFC  SL_new
# 0            0.258739              11.702  0.118768  0.088856   False
# ...

# %%
test_df = pd.read_csv(klingbeil_file_path)
test_df[:3]
# Out:
#                          GENE_COMBINATION           domain_combination  \
# 0  AAK1:Kinase_domain;BMP2K:Kinase_domain  Kinase_domain_Kinase_domain
# 1  AAK1:Kinase_domain;BMP2K:Kinase_domain  Kinase_domain_Kinase_domain
# 2  AAK1:Kinase_domain;BMP2K:Kinase_domain  Kinase_domain_Kinase_domain
#
#      genepair    A1     A2  A1_entrez  A2_entrez cell_line   DepMap_ID  \
# 0  AAK1_BMP2K  AAK1  BMP2K    22848.0    55589.0       HEL  ACH-000004
# 1  AAK1_BMP2K  AAK1  BMP2K    22848.0    55589.0      T3M4  ACH-000085
# 2  AAK1_BMP2K  AAK1  BMP2K    22848.0    55589.0    HPAFII  ACH-000094
#
#      GEMINI  ...  either_in_complex  mean_complex_essentiality  \
# 0  0.218665  ...              False                        0.0
# 1  0.205641  ...              False                        0.0
# 2  0.044486  ...              False                        0.0
#
#    colocalisation interact n_total_ppi  fet_ppi_overlap  gtex_spearman_corr  \
# ...

# %%
test_df_parrish = pd.read_csv(parrish_file_path)
test_df_parrish[:3]
# Out:
#           genepair       A1       A2  A1_entrez  A2_entrez  PC9_GI_score  \
# 0          A2M_PZP      A2M      PZP        2.0     5858.0      0.264313
# 1          A2M_PZP      A2M      PZP        2.0     5858.0      0.264313
# 2  AADACL3_AADACL4  AADACL3  AADACL4   126767.0   343066.0     -0.000281
#
#    PC9_GI_fdr  HeLa_GI_score  HeLa_GI_fdr   DepMap_ID  ... colocalisation  \
# 0    0.138809      -0.154320     0.424612  ACH-000779  ...            0.0
# 1    0.138809      -0.154320     0.424612  ACH-001086  ...            0.0
# 2    0.992873       0.120862     0.433194  ACH-000779  ...            0.0
#
#    interact  n_total_ppi  fet_ppi_overlap  gtex_spearman_corr  \
# 0      True        122.0          2.97235            0.601651
# 1      True        122.0          2.97235            0.601651
# 2     False          0.0          0.00000            0.141775
#
#    gtex_min_mean_expr  gtex_max_mean_expr    GEMINI       LFC  SL_new
# ...

# %%
test_df_harle = pd.read_csv(harle_file_path)
test_df_harle[:3]
# Out:
#     genepair sorted_gene_pair    A1    A2 cell_line   DepMap_ID  mean_norm_gi  \
# 0  ABL1_ABL2        ABL1|ABL2  ABL1  ABL2   HPAF-II  ACH-000094      0.461745
# 1  ABL1_ABL2        ABL1|ABL2  ABL1  ABL2  SU.86.86  ACH-000114      0.281467
# 2  ABL1_ABL2        ABL1|ABL2  ABL1  ABL2   CFPAC-1  ACH-000138      0.273686
#
#         fdr  is_bassik_hit  targetA__is_single_depleted  ...  \
# 0  0.992489              0                            0  ...
# 1  0.940366              0                            0  ...
# 2  0.839309              0                            0  ...
#
#    either_in_complex  mean_complex_essentiality colocalisation interact  \
# 0                1.0                   0.238134            0.5      1.0
# 1                1.0                   0.238134            0.5      1.0
# 2                1.0                   0.238134            0.5      1.0
#
#    n_total_ppi  fet_ppi_overlap  gtex_spearman_corr  gtex_min_mean_expr  \
# ...

# %%
test_df_chymera = pd.read_csv(chymera_file_path)
test_df_chymera = test_df_chymera.dropna(subset=['SL_new'])
test_df_chymera[:3]
# Out:
#          genepair      A1       A2   DepMap_ID cell_line     SL  org_A1  \
# 0  ABHD12_ABHD12B  ABHD12  ABHD12B  ACH-002463  RPE1SS77  False  ABHD12
# 1  ABHD12_ABHD12B  ABHD12  ABHD12B  ACH-002475      HAP1  False  ABHD12
# 2       ABL1_ABL2    ABL1     ABL2  ACH-002463  RPE1SS77  False    ABL1
#
#     org_A2  A1_copy_number_data  A1_expression_data  ...  colocalisation  \
# 0  ABHD12B             1.024866            5.874463  ...             0.0
# 1  ABHD12B             1.034937            4.736599  ...             0.0
# 2     ABL2             1.001701            5.482642  ...             0.5
#
#    interact  n_total_ppi  fet_ppi_overlap  gtex_spearman_corr  \
# 0       0.0         19.0          0.00000            0.405972
# 1       0.0         19.0          0.00000            0.405972
# 2       1.0        208.0         40.51941            0.693160
#
#    gtex_min_mean_expr  gtex_max_mean_expr    GEMINI       LFC  SL_new
# ...

# %%
feature_columns_1 = ['rMaxExp_A1A2', 'rMinExp_A1A2',
                     'max_ranked_A1A2', 'min_ranked_A1A2',
                     'max_cn', 'min_cn', 'Protein_Altering', 'Damaging', 
                     'min_sequence_identity',
                     'prediction_score', 
                     'weighted_PPI_essentiality', 'weighted_PPI_expression',
                     'smallest_BP_GO_essentiality', 'smallest_CC_GO_essentiality',
                     'smallest_BP_GO_expression', 'go_CC_expression'
                     ]

target_column = 'SL_new'

print('num of features:', len(feature_columns_1))
# Out:
# num of features: 16

# %%
feature_columns_2 = feature_columns_1 + ['closest', 'WGD', 'family_size',
                                         'cds_length_ratio', 'shared_domains', 'has_pombe_ortholog',
                                         'has_essential_pombe_ortholog', 'has_cerevisiae_ortholog',
                                         'has_essential_cerevisiae_ortholog', 'conservation_score', 'mean_age',
                                         'either_in_complex', 'mean_complex_essentiality', 'colocalisation',
                                         'interact', 'n_total_ppi', 'fet_ppi_overlap',
                                         'gtex_spearman_corr', 'gtex_min_mean_expr', 'gtex_max_mean_expr']
feature_columns_2.remove('prediction_score')
print('num of features:', len(feature_columns_2))
# Out:
# num of features: 35

# %% [markdown]
# ### Prepare Seen and Unseen subsets

# %%
def resolve_sl_label(df):
    label_map = df.groupby(['genepair', 'DepMap_ID'])['SL_new'].any()
    df = df.drop_duplicates(subset=['genepair', 'DepMap_ID']).copy()
    df['SL_new_new'] = df.set_index(['genepair', 'DepMap_ID']).index.map(label_map)
    return df.reset_index(drop=True)

test_df_resolved = resolve_sl_label(test_df)

# %%
# Check if SL_new and SL_new_new agree for every (genepair, cell_line_name)
mismatch = test_df_resolved[test_df_resolved['SL_new'] != test_df_resolved['SL_new_new']]

print(f"Total rows: {len(test_df_resolved)}")
print(f"Matching labels: {len(test_df_resolved) - len(mismatch)}")
print(f"Mismatched labels: {len(mismatch)}")

mismatch[['genepair', 'cell_line', 'SL_new', 'SL_new_new']]
# Out:
# Total rows: 35467
# Matching labels: 35380
# Mismatched labels: 87
#             genepair cell_line  SL_new  SL_new_new
# 1710       AKT1_AKT3     H1048   False        True
# 4399   ATP2B1_ATP2B3  PATU8902   False        True
# 5412     BAZ2A_BAZ2B    HPAFII   False        True
# 5425     BAZ2A_BAZ2B  PATU8902   False        True
# 5902      BRD1_BRPF1      H211   False        True
# ...              ...       ...     ...         ...
# 34849  TRIM28_TRIM33  PATU8902   False        True
# 34857  TRIM33_TRIM66    HPAFII   False        True
# 34861  TRIM33_TRIM66   CORL311   False        True
# 34874  TRIM33_TRIM66      RH30   False        True
# 35067    UHRF1_UHRF2     NOMO1   False        True
#
# [87 rows x 4 columns]

# %%
test_df = test_df_resolved.drop(columns=['SL_new']).rename(columns={'SL_new_new': 'SL_new'})
test_df.loc[test_df['genepair'] == 'AKT1_AKT2', ]
# Out:
#                            GENE_COMBINATION           domain_combination  \
# 1669  AKT1:Kinase_domain;AKT2:Kinase_domain  Kinase_domain_Kinase_domain
# 1670  AKT1:Kinase_domain;AKT2:Kinase_domain  Kinase_domain_Kinase_domain
# 1671  AKT1:Kinase_domain;AKT2:Kinase_domain  Kinase_domain_Kinase_domain
# 1672  AKT1:Kinase_domain;AKT2:Kinase_domain  Kinase_domain_Kinase_domain
# 1673  AKT1:Kinase_domain;AKT2:Kinase_domain  Kinase_domain_Kinase_domain
# 1674  AKT1:Kinase_domain;AKT2:Kinase_domain  Kinase_domain_Kinase_domain
# 1675  AKT1:Kinase_domain;AKT2:Kinase_domain  Kinase_domain_Kinase_domain
# 1676  AKT1:Kinase_domain;AKT2:Kinase_domain  Kinase_domain_Kinase_domain
# 1677  AKT1:Kinase_domain;AKT2:Kinase_domain  Kinase_domain_Kinase_domain
# 1678  AKT1:Kinase_domain;AKT2:Kinase_domain  Kinase_domain_Kinase_domain
# 1679  AKT1:Kinase_domain;AKT2:Kinase_domain  Kinase_domain_Kinase_domain
# 1680  AKT1:Kinase_domain;AKT2:Kinase_domain  Kinase_domain_Kinase_domain
# ...

# %%
# splitting data for Klingbeil Screen

def split_seen_unseen(test_df, training_df):
    """
    Split test_df into seen and unseen pairs based on genepair only.
    Exclude the overlapping cell lines between training and test sets to ensure that the split is based on genepair novelty rather than cell line novelty.
    Returns: seen_df, unseen_df
    """
    common_cell_line = set(training_df['DepMap_ID'].unique()).intersection(set(test_df['DepMap_ID'].unique()))
    novel_test_df = test_df[~test_df['DepMap_ID'].isin(common_cell_line)]

    train_genepairs = set(training_df['genepair'])
    seen_mask = novel_test_df['genepair'].isin(train_genepairs)
    unseen_mask = ~seen_mask

    seen_df = novel_test_df[seen_mask].copy()
    unseen_df = novel_test_df[unseen_mask].copy()

    print(f"Seen pairs (by genepair): {seen_df.shape[0]}")
    print(f"Unseen pairs (by genepair): {unseen_df.shape[0]}")
    return seen_df, unseen_df

# %%
klingbeil_seen, klingbeil_unseen = split_seen_unseen(test_df, training_df)
# Out:
# Seen pairs (by genepair): 20080
# Unseen pairs (by genepair): 13684

# %%
harle_seen, harle_unseen = split_seen_unseen(test_df_harle, training_df)

harle_seen = harle_seen.dropna(subset=['SL_new'])
harle_unseen = harle_unseen.dropna(subset=['SL_new'])

harle_seen = harle_seen.dropna(subset=['SL_new'])
harle_seen['SL_new'] = harle_seen['SL_new'].astype(bool)

harle_unseen = harle_unseen.dropna(subset=['SL_new'])
harle_unseen['SL_new'] = harle_unseen['SL_new'].astype(bool)
# Out:
# Seen pairs (by genepair): 1600
# Unseen pairs (by genepair): 3120

# %%
# splitting data for Parrish Screen

def split_seen_unseen_by_genepair(test_df, training_df):
    """
    Split test_df into seen and unseen pairs based on genepair only.
    Returns: seen_df, unseen_df
    """
    train_genepairs = set(training_df['genepair'])
    seen_mask = test_df['genepair'].isin(train_genepairs)
    unseen_mask = ~seen_mask

    seen_df = test_df[seen_mask].copy()
    unseen_df = test_df[unseen_mask].copy()

    print(f"Seen pairs (by genepair): {seen_df.shape[0]}")
    print(f"Unseen pairs (by genepair): {unseen_df.shape[0]}")
    return seen_df, unseen_df

# %%
parrish_seen, parrish_unseen = split_seen_unseen_by_genepair(test_df_parrish, training_df)
# Out:
# Seen pairs (by genepair): 549
# Unseen pairs (by genepair): 1216

# %%
chymera_seen, chymera_unseen = split_seen_unseen_by_genepair(test_df_chymera, training_df)
# Out:
# Seen pairs (by genepair): 363
# Unseen pairs (by genepair): 754

# %%
splits = {
    'Klingbeil': (klingbeil_seen, klingbeil_unseen),
    'Parrish':   (parrish_seen,   parrish_unseen),
    'Harle':     (harle_seen,     harle_unseen),
    'CHyMErA':   (chymera_seen,   chymera_unseen),
}

# raw test_df for each dataset (before split) so we can count dropped overlapping cell lines
raw_test_dfs = {
    'Klingbeil': test_df,
    'Parrish':   test_df_parrish,
    'Harle':     test_df_harle,
    'CHyMErA':   test_df_chymera,
}

train_cls = set(training_df['DepMap_ID'].unique())

rows = []
for dataset, (seen, unseen) in splits.items():
    raw = raw_test_dfs[dataset]
    overlap_cls = set(raw['DepMap_ID'].unique()) & train_cls
    for split_name, df in [('Seen', seen), ('Unseen', unseen)]:
        rows.append({
            'dataset':                       dataset,
            'split':                         split_name,
            'n_rows':                        len(df),
            'n_cell_lines':                  df['DepMap_ID'].nunique(),
            'n_cell_lines_dropped_overlap':  len(overlap_cls),
            'n_gene_pairs':                  df['genepair'].nunique(),
        })

split_counts = pd.DataFrame(rows)
print(split_counts.to_string(index=False))

#split_counts.to_csv(get_data_path(['data','output','models'],
#                                  'dataset_split_counts.csv'), index=False)
# Out:
#   dataset  split  n_rows  n_cell_lines  n_cell_lines_dropped_overlap  n_gene_pairs
# Klingbeil   Seen   20080            20                             1          1012
# Klingbeil Unseen   13684            20                             1           692
#   Parrish   Seen     549             2                             0           282
#   Parrish Unseen    1216             2                             0           626
#     Harle   Seen    1523            20                             1            80
#     Harle Unseen    3011            20                             1           156
#   CHyMErA   Seen     363             2                             0           197
#   CHyMErA Unseen     754             2                             0           398

# %% [markdown]
# ### Run RF Classifier

# %%
def calc_auc(df, RF, feature_columns, target_column):
    ypred = RF.predict_proba(df[feature_columns])[:,1]
    auc_pr_df = pd.DataFrame({
        'SL':df[target_column],
        'ypred':ypred,
        'prediction_score':df['prediction_score'],
        'rMinExp_A1A2': df['rMinExp_A1A2'],
        'min_ranked_A1A2': df['min_ranked_A1A2'],
        'transformed_gene_essentiality': -df['min_ranked_A1A2'],
        'min_sequence_identity': df['min_sequence_identity']
        })
    return auc_pr_df

# %%
# Define feature sets
data_1 = training_df[feature_columns_1]
data_2 = training_df[feature_columns_2]
target = training_df[target_column]

# %%
RF = RandomForestClassifier(n_estimators=600, random_state=8, max_features=0.2, max_depth=20, min_samples_leaf=4)

# %%
contextualised = RF.fit(data_1, target)

# %%
with open(file_RF_model_contextualised, 'wb') as f:
    pickle.dump(contextualised, f)

# %%
# Load RF classifier from file
with open(file_RF_model_contextualised, 'rb') as file:
    contextualised = pickle.load(file)

# %%
full = RF.fit(data_2, target)

# %%
with open(file_RF_model_full, 'wb') as f:
    pickle.dump(full, f)

# %%
# Load RF classifier from file
with open(file_RF_model_full, 'rb') as file:
    full = pickle.load(file)

# %%
# Collect all validation datasets
validation_datasets = [
     ("Klingbeil Seen", klingbeil_seen),
     ("Klingbeil Unseen", klingbeil_unseen),
     ("Parrish Seen", parrish_seen),
     ("Parrish Unseen", parrish_unseen),
     ("Harle Seen", harle_seen),
     ("Harle Unseen", harle_unseen),
     ("CHyMErA Seen", chymera_seen),
     ("CHyMErA Unseen", chymera_unseen),
]

# Evaluate contextualised model
print("Evaluating contextualised Integration Model...")
auc_pr_data_all_contextualised = []
for name, dataset in validation_datasets:
    if len(dataset) > 0:
        print(f"  Processing {name}: {len(dataset)} samples")
        result = calc_auc(dataset, contextualised, feature_columns_1, target_column)
        auc_pr_data_all_contextualised.append(result)
    else:
        print(f"Skipping {name}: No samples")
        empty_df = pd.DataFrame(columns=['SL', 'ypred', 'prediction_score',
                                         'rMinExp_A1A2', 'min_ranked_A1A2',
                                         'transformed_gene_essentiality',
                                         'min_sequence_identity'])
        auc_pr_data_all_contextualised.append(empty_df)

# Evaluate full model
print("\nEvaluating Full Integration Model...")
auc_pr_data_all_full = []
for name, dataset in validation_datasets:
    if len(dataset) > 0:
        print(f"  Processing {name}: {len(dataset)} samples")
        result = calc_auc(dataset, full, feature_columns_2, target_column)
        auc_pr_data_all_full.append(result)
    else:
        print(f"Skipping {name}: No samples")
        empty_df = pd.DataFrame(columns=['SL', 'ypred', 'prediction_score',
                                         'rMinExp_A1A2', 'min_ranked_A1A2',
                                         'transformed_gene_essentiality',
                                         'min_sequence_identity'])
        auc_pr_data_all_full.append(empty_df)

# Prepare validation_data_df for visualization
print("\nPREPARING VALIDATION DATA FOR VISUALIZATION")

validation_data_df = []
dataset_names = [
                "Klingbeil Seen", "Klingbeil Unseen", 
                 "Parrish Seen", "Parrish Unseen",
                 "Harle Seen", "Harle Unseen",
                 "CHyMErA Seen", "CHyMErA Unseen",
               ]

for i, name in enumerate(dataset_names):
    if len(auc_pr_data_all_contextualised[i]) > 0 and len(auc_pr_data_all_full[i]) > 0:
        contextualised_df = auc_pr_data_all_contextualised[i].loc[:, ['SL', 'ypred', 'prediction_score', 'min_sequence_identity']]
        full_df = auc_pr_data_all_full[i].loc[:, ['SL', 'ypred']]
        concat_df = pd.concat([
            contextualised_df.rename(columns={'SL': 'SL_contextualised', 'ypred': 'ypred_contextualised'}),
            full_df.rename(columns={'SL': 'SL_full', 'ypred': 'ypred_full'})
        ], axis=1)
        validation_data_df.append(concat_df)
        print(f"{name}: {len(concat_df)} samples prepared")
    else:
        print(f"{name}: Skipped due to insufficient data")
        empty_df = pd.DataFrame(columns=['SL_contextualised', 'ypred_contextualised', 'SL_full', 'ypred_full',
                                         'prediction_score', 'min_sequence_identity'])
        validation_data_df.append(empty_df)

print(f"\nTotal validation sets prepared: {len([df for df in validation_data_df if len(df) > 0])}")
# Out:
# Evaluating contextualised Integration Model...
#   Processing Klingbeil Seen: 20080 samples
#   Processing Klingbeil Unseen: 13684 samples
#   Processing Parrish Seen: 549 samples
#   Processing Parrish Unseen: 1216 samples
#   Processing Harle Seen: 1523 samples
#   Processing Harle Unseen: 3011 samples
#   Processing CHyMErA Seen: 363 samples
#   Processing CHyMErA Unseen: 754 samples
#
# Evaluating Full Integration Model...
#   Processing Klingbeil Seen: 20080 samples
#   Processing Klingbeil Unseen: 13684 samples
#   Processing Parrish Seen: 549 samples
#   Processing Parrish Unseen: 1216 samples
#   Processing Harle Seen: 1523 samples
#   Processing Harle Unseen: 3011 samples
#   Processing CHyMErA Seen: 363 samples
#   Processing CHyMErA Unseen: 754 samples
#
# PREPARING VALIDATION DATA FOR VISUALIZATION
# Klingbeil Seen: 20080 samples prepared
# Klingbeil Unseen: 13684 samples prepared
# Parrish Seen: 549 samples prepared
# Parrish Unseen: 1216 samples prepared
# ...

# %%
# Add comprehensive performance summary:

def generate_validation_summary():
    """Generate a comprehensive summary of validation performance."""
    print("\n📊 VALIDATION PERFORMANCE SUMMARY")
    print("=" * 60)
    
    summary_data = []
    
    for i, (name, df) in enumerate(zip(dataset_names, validation_data_df)):
        if len(df) > 0:
            # Calculate metrics for each approach
            try:
                # contextualised model ROC AUC
                contextualised_roc = roc_auc_score(df['SL_contextualised'], df['ypred_contextualised'])
                contextualised_pr = average_precision_score(df['SL_contextualised'], df['ypred_contextualised'])
                
                # full model ROC AUC  
                full_roc = roc_auc_score(df['SL_full'], df['ypred_full'])
                full_pr = average_precision_score(df['SL_full'], df['ypred_full'])
                
                # Baseline methods
                pred_score_roc = roc_auc_score(df['SL_contextualised'], df['prediction_score'])
                pred_score_pr = average_precision_score(df['SL_contextualised'], df['prediction_score'])
                
                seq_id_roc = roc_auc_score(df['SL_contextualised'], df['min_sequence_identity'])
                seq_id_pr = average_precision_score(df['SL_contextualised'], df['min_sequence_identity'])
                
                summary_data.append({
                    'Dataset': name,
                    'Samples': len(df),
                    'SL_Rate': df['SL_contextualised'].mean(),
                    'contextualised_ROC': contextualised_roc,
                    'contextualised_PR': contextualised_pr,
                    'full_ROC': full_roc,
                    'full_PR': full_pr,
                    'PredScore_ROC': pred_score_roc,
                    'PredScore_PR': pred_score_pr,
                    'SeqID_ROC': seq_id_roc,
                    'SeqID_PR': seq_id_pr
                })
                
            except Exception as e:
                print(f"Error calculating metrics for {name}: {e}")
    
    # Create summary DataFrame
    if summary_data:
        summary_df = pd.DataFrame(summary_data)
        
        print("🎯 ROC AUC Performance:")
        print("-" * 40)
        for _, row in summary_df.iterrows():
            print(f"{row['Dataset']:<15} contextualised: {row['contextualised_ROC']:.3f} | full: {row['full_ROC']:.3f} | PredScore: {row['PredScore_ROC']:.3f} | SeqID: {row['SeqID_ROC']:.3f}")
        
        print("\n📏 PR AUC Performance:")
        print("-" * 40)
        for _, row in summary_df.iterrows():
            print(f"{row['Dataset']:<15} contextualised: {row['contextualised_PR']:.3f} | full: {row['full_PR']:.3f} | PredScore: {row['PredScore_PR']:.3f} | SeqID: {row['SeqID_PR']:.3f}")
        
        return summary_df
    else:
        print("No valid data for summary")
        return None

# Generate the summary
validation_summary_df = generate_validation_summary()
# Out:
# 📊 VALIDATION PERFORMANCE SUMMARY
# ...
# 🎯 ROC AUC Performance:
# ----------------------------------------
# Klingbeil Seen  contextualised: 0.866 | full: 0.869 | PredScore: 0.717 | SeqID: 0.581
# Klingbeil Unseen contextualised: 0.816 | full: 0.819 | PredScore: 0.729 | SeqID: 0.548
# Parrish Seen    contextualised: 0.750 | full: 0.743 | PredScore: 0.672 | SeqID: 0.590
# Parrish Unseen  contextualised: 0.750 | full: 0.751 | PredScore: 0.713 | SeqID: 0.533
# Harle Seen      contextualised: 0.853 | full: 0.871 | PredScore: 0.777 | SeqID: 0.650
# Harle Unseen    contextualised: 0.818 | full: 0.809 | PredScore: 0.810 | SeqID: 0.634
# CHyMErA Seen    contextualised: 0.826 | full: 0.830 | PredScore: 0.738 | SeqID: 0.701
# CHyMErA Unseen  contextualised: 0.796 | full: 0.823 | PredScore: 0.791 | SeqID: 0.694
#
# 📏 PR AUC Performance:
# ----------------------------------------
# Klingbeil Seen  contextualised: 0.300 | full: 0.315 | PredScore: 0.148 | SeqID: 0.065
# ...

# %%
full_validation_datasets = [
    ("Klingbeil et al.", test_df),
    ("Parrish et al.",   test_df_parrish),
    ("Harle et al.",     test_df_harle.dropna(subset=['SL_new']).assign(SL_new=lambda d: d['SL_new'].astype(bool))),
    ("CHyMErA",          test_df_chymera),
]

full_validation_data_df = []
for name, ds in full_validation_datasets:
    ctx  = calc_auc(ds, contextualised, feature_columns_1, target_column)
    fll  = calc_auc(ds, full,           feature_columns_2, target_column)
    full_validation_data_df.append(pd.concat([
        ctx[['SL', 'ypred', 'prediction_score', 'min_sequence_identity']]
            .rename(columns={'SL':'SL_contextualised','ypred':'ypred_contextualised'}),
        fll[['SL', 'ypred']]
            .rename(columns={'SL':'SL_full','ypred':'ypred_full'}),
    ], axis=1))
    print(f"{name}: {len(full_validation_data_df[-1])} samples")
# Out:
# Klingbeil et al.: 35467 samples
# Parrish et al.: 1765 samples
# Harle et al.: 4759 samples
# CHyMErA: 1117 samples

# %% [markdown]
# ### Draw ROC and PR Curves

# %%
def plot_roc_curve(ax, data, true_label, probas, label, color,
                   line_style="solid", draw_style="steps-post", zorder=10, labels_only=False):

    # Drop rows with NaNs in true or predicted columns
    valid_data = data[[true_label, probas]].dropna()

    # Make sure we have enough valid data to compute ROC
    y_true = valid_data[true_label].values
    y_score = valid_data[probas].values

    if len(np.unique(y_true)) < 2:
        print(f"Skipping {label}: not enough class variation after dropping NaNs.")
        return

    # Calculate ROC and AUC
    fpr, tpr, _ = roc_curve(y_true, y_score)
    roc_auc = auc(fpr, tpr)

    # Plot the ROC curve
    legend_label = f"{roc_auc:.2f}"
    ax.step(fpr, tpr, label=legend_label, color=color,
            linestyle=line_style, drawstyle=draw_style, zorder=zorder, linewidth=1.25)

def draw_roc_curves(data, true_labels, probas, labels, title, colors, ax, labels_only=False):
    for true_label, probas, label, color in zip(true_labels, probas, labels, colors):
        plot_roc_curve(ax, data, true_label, probas, label, color, labels_only=labels_only)

    ax.plot([0, 1], [0, 1], linestyle='--', color='gray', label='0.50')
    # ax.set_xlabel('False Positive Rate', fontsize=16)
    # ax.set_ylabel('True Positive Rate', fontsize=16)
    # ax.set_title(f'{title}', fontsize=14)
    # ax.tick_params(axis='x', labelsize=8)
    # ax.tick_params(axis='y', labelsize=8)
    # ax.spines.top.set(visible=False)
    # ax.spines.right.set(visible=False)
    # ax.set_ylim([-0.025, 1.025])
    # ax.set_xlim([-0.025, 1.025])
    # ax.legend(loc='lower right', fontsize=16)

    ax.set_xlabel('False Positive Rate', fontsize=12)
    ax.set_ylabel('True Positive Rate', fontsize=12)
    ax.set_title(f'{title}', fontsize=12)
    ax.tick_params(axis='x', labelsize=10)
    ax.tick_params(axis='y', labelsize=10)
    ax.spines.top.set(visible=False)
    ax.spines.right.set(visible=False)
    ax.set_ylim([-0.025, 1.025])
    ax.set_xlim([-0.025, 1.025])
    ax.legend(loc='lower right', fontsize=10)

def draw_validation_curves(validation_data_df, title_list, save_path:None):
    sns.set_context('paper')
    fig, ax = plt.subplots(1, 2, figsize=(5.85, 3.75))

    true_labels = ['SL_contextualised', 'SL_full', 'SL_contextualised', 'SL_contextualised']
    predictions = ['ypred_contextualised', 'ypred_full', 'prediction_score', 'min_sequence_identity']
    custom_labels = ['Context-Specific Classifier (contextualised)', 'Context-Specific Classifier (full)', 'General Classifier', 'Sequence Identity']
    colors = ['#009E73', '#CC79A7', '#777777', '#E69F00']

    for i, df in enumerate(validation_data_df):
        draw_roc_curves(df, true_labels, predictions, custom_labels, title_list[i], colors, ax[i])

    # Extract handles and labels from the first subplot
    handles, labels = ax[0].get_legend_handles_labels()
    
    # Create a shared legend for the figure
    #fig.legend(handles=handles, labels=custom_labels + ['Chance'], ncol=5, loc='upper center', 
    #           bbox_to_anchor=[0.5, 1.2], fontsize=20, fancybox=True, facecolor='#efefef', borderpad=0.5)

    #fig.legend(handles=handles, labels=custom_labels + ['Chance'], ncol=5, loc='upper center', 
    #           bbox_to_anchor=[0.5, 1.1], fontsize=12, fancybox=True, facecolor='#efefef', borderpad=0.5)

    plt.tight_layout(h_pad=0.5)

    #if save_path:
    #    plt.savefig(save_path, bbox_inches='tight', dpi=500)
    #plt.close()
    plt.show()

# %%
# Klingbeil only (indices 0 and 1)
draw_validation_curves(validation_data_df[0:2], 
                       ["Klingbeil et al. - Seen", "Klingbeil et al. - Unseen"],
                       figure_path_roc_auc)

# %%
# Parrish only (indices 2 and 3)
draw_validation_curves(validation_data_df[2:4], 
                       ["Parrish et al. - Seen", "Parrish et al. - Unseen"],
                       figure_path_parrish_roc_auc)

# %%
# Harle only (indices 4 and 5)
draw_validation_curves(validation_data_df[4:6], 
                       ["Harle et al. - Seen", "Harle et al. - Unseen"],
                       figure_path_harle_roc_auc)

# %%
# CHyMErA only (indices 6 and 7)
draw_validation_curves(validation_data_df[6:8], 
                       ["CHyMErA Seen", "CHyMErA Unseen"],
                       figure_path_chymera_roc_auc)

# %%
def plot_pr_curve(ax, data, true_label, probas, label, color,
                  line_style="solid", draw_style="default", zorder=10,
                  labels_only=False, subplot_index=None):
    # Drop rows with NaNs in either column
    valid_data = data[[true_label, probas]].dropna()

    y_true = valid_data[true_label].values
    y_score = valid_data[probas].values

    # Skip if there aren't enough valid samples or variation in labels
    if len(y_true) < 2 or len(np.unique(y_true)) < 2:
        print(f"Skipping {label}: insufficient valid data.")
        return

    precision, recall, _ = precision_recall_curve(y_true, y_score)
    ap_score = average_precision_score(y_true, y_score)
    legend_label = f"{ap_score:.2f}"

    ax.plot(recall, precision, label=legend_label, color=color,
            linestyle=line_style, drawstyle=draw_style, zorder=zorder, linewidth=1.25)

    # Optional: annotate with X marker on a fixed point
    #if subplot_index in [0, 1]:
    #    ax.scatter(0.325, 0.4, color='red', marker="X", s=70, zorder=15)
    #     ax.scatter(0.21, 0.61, color='red', marker="X", s=70, zorder=15)

def draw_pr_curves(data, true_labels, probas, labels, title, colors, ax, labels_only=False, subplot_index=None):
    for true_label, probas, label, color in zip(true_labels, probas, labels, colors):
        plot_pr_curve(ax, data, true_label, probas, label, color, labels_only=labels_only, subplot_index=subplot_index)

    no_skill = sum(data[true_labels[0]]) / len(data[true_labels[0]])
    ax.plot([0, 1], [no_skill, no_skill], linestyle='--', color='gray', label=f'{no_skill:.2f}')
    # ax.set_xlabel('Recall', fontsize=16)
    # ax.set_ylabel('Precision', fontsize=16)
    # ax.set_title(f'{title}', fontsize=14)
    # ax.tick_params(axis='x', labelsize=8)
    # ax.tick_params(axis='y', labelsize=8)
    # ax.spines.top.set(visible=False)
    # ax.spines.right.set(visible=False)
    # ax.set_ylim([-0.025, 1.025])
    # ax.set_xlim([-0.025, 1.025])
    # ax.legend(loc='upper right', fontsize=16)

    ax.set_xlabel('Recall', fontsize=12)
    ax.set_ylabel('Precision', fontsize=12)
    ax.set_title(f'{title}', fontsize=12)
    ax.tick_params(axis='x', labelsize=10)
    ax.tick_params(axis='y', labelsize=10)
    ax.spines.top.set(visible=False)
    ax.spines.right.set(visible=False)
    ax.set_ylim([-0.025, 1.025])
    ax.set_xlim([-0.025, 1.025])
    ax.legend(loc='upper right', fontsize=10)

def draw_pr_validation_curves(validation_data_df, title_list, save_path:None):
    sns.set_context('paper')
    fig, ax = plt.subplots(1, 2, figsize=(5.85, 3.75))

    true_labels = ['SL_contextualised', 'SL_full', 'SL_contextualised', 'SL_contextualised']
    predictions = ['ypred_contextualised', 'ypred_full', 'prediction_score', 'min_sequence_identity']
    custom_labels = ['Context-Specific Classifier (contextualised)', 'Context-Specific Classifier (full)', 'General Classifier', 'Sequence Identity']
    colors = ['#009E73', '#CC79A7', '#777777', '#E69F00']

    for i, df in enumerate(validation_data_df):
        draw_pr_curves(df, true_labels, predictions, custom_labels, title_list[i], colors, ax[i], subplot_index=i)

    # Extract handles and labels from the first subplot
    handles, labels = ax[0].get_legend_handles_labels()
    
    # Create a shared legend for the figure
    #fig.legend(handles=handles, labels=custom_labels + ['Chance'], ncol=5, loc='upper center', 
    #           bbox_to_anchor=[0.5, 1.2], fontsize=20, fancybox=True, facecolor='#efefef', borderpad=0.5)

    #fig.legend(handles=handles, labels=custom_labels + ['Chance'], ncol=5, loc='upper center', 
    #           bbox_to_anchor=[0.5, 1.1], fontsize=10, fancybox=True, facecolor='#efefef', borderpad=0.5)

    plt.tight_layout(h_pad=0.5)
    #if save_path:
    #    plt.savefig(save_path, bbox_inches='tight', dpi=500)
    #plt.close()
    plt.show()

# %%
# Klingbeil only (indices 0 and 1)
draw_pr_validation_curves(validation_data_df[0:2], 
                          ["Klingbeil et al. - Seen", "Klingbeil et al. - Unseen"],
                          figure_path_pr_auc)

# %%
# Parrish only (indices 2 and 3)
draw_pr_validation_curves(validation_data_df[2:4], 
                       ["Parrish et al. - Seen", "Parrish et al. - Unseen"],
                       figure_path_parrish_pr_auc)

# %%
# Harle only (indices 4 and 5)
draw_pr_validation_curves(validation_data_df[4:6], 
                       ["Harle et al. - Seen", "Harle et al. - Unseen"],
                       figure_path_harle_pr_auc)

# %%
# CHyMErA only (indices 6 and 7)
draw_pr_validation_curves(validation_data_df[6:8], 
                         ["CHyMErA Seen", "CHyMErA Unseen"],
                         figure_path_chymera_pr_auc)

# %% [markdown]
# ### Cancer-Type specific validation

# %%
## cancer type mapping

cancer_type_map = {
    'YAPC': 'PDAC',
    'HPAFII': 'PDAC',
    'ASPC1': 'PDAC',
    'PATU8902': 'PDAC',
    'KP2': 'PDAC',
    'PANC1': 'PDAC',
    'T3M4': 'PDAC',
    'PATU8988T': 'PDAC',
    'KLM1': 'PDAC',
    'MIAPACA2': 'PDAC',
    'NCIH211':'SCLC',
    'CORL311':'SCLC',
    'NCIH209':'SCLC',
    'NCIH1836':'SCLC',
    'NCIH1436':'SCLC',
    'NOMO1':"AML",
    'HEL':"AML",
    'SET2':"AML",
    'OCIAML3':"AML",
    'MOLM13':"AML",
    'THP1':"AML"}    

klingbeil_seen['cancer_type'] = klingbeil_seen['cell_line'].map(cancer_type_map)
klingbeil_unseen['cancer_type'] = klingbeil_unseen['cell_line'].map(cancer_type_map)

# %%
cancer_types = ['PDAC', 'SCLC', 'AML']

klingbeil_cancer_type_validation = pd.concat([klingbeil_seen, klingbeil_unseen], ignore_index=True)

validation_data_cancer_type = []
for ct in cancer_types:
    ct_df = klingbeil_cancer_type_validation[klingbeil_cancer_type_validation['cancer_type'] == ct].copy()
    print(f"{ct}: {len(ct_df)} samples, SL rate: {ct_df[target_column].mean():.3f}")

    result_ctx  = calc_auc(ct_df, contextualised, feature_columns_1, target_column)
    result_full = calc_auc(ct_df, full,           feature_columns_2, target_column)

    ctx_cols  = result_ctx[['SL', 'ypred', 'prediction_score', 'min_sequence_identity']].rename(
                    columns={'SL': 'SL_contextualised', 'ypred': 'ypred_contextualised'})
    full_cols = result_full[['SL', 'ypred']].rename(
                    columns={'SL': 'SL_full', 'ypred': 'ypred_full'})

    combined = pd.concat([ctx_cols.reset_index(drop=True),
                          full_cols.reset_index(drop=True)], axis=1)
    validation_data_cancer_type.append(combined)
# Out:
# PDAC: 8437 samples, SL rate: 0.063
# SCLC: 1671 samples, SL rate: 0.071
# AML: 8458 samples, SL rate: 0.026

# %%
def draw_cancer_type_validation(validation_data, cancer_types, save_path=None):
    sns.set_context('paper')
    fig, axes = plt.subplots(2, 3, figsize=(8.75, 5.5))

    true_labels  = ['SL_contextualised', 'SL_full', 'SL_contextualised', 'SL_contextualised']
    predictions  = ['ypred_contextualised', 'ypred_full', 'prediction_score', 'min_sequence_identity']
    custom_labels = ['Context-Specific Classifier (contextualised)',
                     'Context-Specific Classifier (full)',
                     'General Classifier', 'Sequence Identity']
    colors = ['#009E73', '#CC79A7', '#777777', '#E69F00']

    for i, (ct, df) in enumerate(zip(cancer_types, validation_data)):
        draw_roc_curves(df, true_labels, predictions, custom_labels, ct, colors, axes[0, i])
        draw_pr_curves (df, true_labels, predictions, custom_labels, ct, colors, axes[1, i])

        # remove this line ↓
        # axes[0, i].set_xlabel('')

        if i > 0:
            axes[0, i].set_ylabel('')
            axes[1, i].set_ylabel('')

    plt.tight_layout(h_pad=2.5, w_pad=0.5)
    if save_path:
        plt.savefig(save_path, bbox_inches='tight', dpi=500)
    plt.show()

figure_path_cancer_type = get_data_path(['figures', 'supp_figures'], 'fig5_klingbeil_cancer_type.png')
draw_cancer_type_validation(validation_data_cancer_type, cancer_types, figure_path_cancer_type)
