# %% [markdown]
# # Random Forest Classification via cross-validation

# %%
# import modules
import os
import pandas as pd
import numpy as np
import random
import pickle

# import scikit-learn modules
from sklearn.model_selection import StratifiedKFold, StratifiedGroupKFold, RepeatedStratifiedKFold, StratifiedShuffleSplit
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import RocCurveDisplay, PrecisionRecallDisplay, roc_auc_score, average_precision_score, precision_recall_curve, auc, roc_curve

from collections import Counter

import time

# import visualization modules
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cwd = os.getcwd()
BASE_DIR = os.path.abspath(os.path.join(cwd, "..", ".."))

# build paths inside the repo
get_data_path = lambda folders, fname: os.path.normpath(
    os.path.join(BASE_DIR, *folders, fname)
)

file_path_training_data = get_data_path(['output', 'models'], 'training_data.csv')

file_RF_model_I_context_reduced = get_data_path(['output', 'models', 'model_I'], 'RF_model_contextualised_reduced.pickle')
file_RF_model_I_full_reduced = get_data_path(['output', 'models', 'model_I'], 'RF_model_full_reduced.pickle')

file_RF_model_II_contextualised_reduced = get_data_path(['output', 'models', 'model_II'], 'RF_model_context_reduced.pickle')
file_RF_model_II_full_reduced = get_data_path(['output', 'models', 'model_II'], 'RF_model_full_reduced.pickle')

file_RF_model_III_contextualised_reduced = get_data_path(['output', 'models', 'model_III'], 'RF_model_contextualised_reduced.pickle')
file_RF_model_III_full_reduced = get_data_path(['output', 'models', 'model_III'], 'RF_model_full_reduced.pickle')

file_RF_model_IV_contextualised = get_data_path(['output', 'models', 'model_IV'], 'RF_model_contextualised.pickle')
file_RF_model_IV_full = get_data_path(['output', 'models', 'model_IV'], 'RF_model_full.pickle')

# %%
training_df = pd.read_csv(file_path_training_data)
training_df.head()
# Out:
#       genepair       A1   A2  A1_entrez  A2_entrez   DepMap_ID  \
# 0  A3GALT2_ABO  A3GALT2  ABO   127550.0       28.0  ACH-000022
# 1  A3GALT2_ABO  A3GALT2  ABO   127550.0       28.0  ACH-000307
# 2  A3GALT2_ABO  A3GALT2  ABO   127550.0       28.0  ACH-000632
# 3  A3GALT2_ABO  A3GALT2  ABO   127550.0       28.0  ACH-000681
# 4  A3GALT2_ABO  A3GALT2  ABO   127550.0       28.0  ACH-000756
#
#                     cell_line  Gemini_FDR   raw_LFC     SL  ...  \
# 0          PATU8988S_PANCREAS    0.998944  0.088856  False  ...
# 1                PK1_PANCREAS    0.986587  0.201704  False  ...
# 2                 HS944T_SKIN    1.000000  0.069772  False  ...
# 3                   A549_LUNG    0.977988  0.379455  False  ...
# 4  GI1_CENTRAL_NERVOUS_SYSTEM    0.999586 -0.077118  False  ...
#
#   colocalisation interact  n_total_ppi  fet_ppi_overlap  gtex_spearman_corr  \
# 0            0.0    False          3.0              0.0            0.114847
# 1            0.0    False          3.0              0.0            0.114847
# 2            0.0    False          3.0              0.0            0.114847
# 3            0.0    False          3.0              0.0            0.114847
# 4            0.0    False          3.0              0.0            0.114847
#
#    gtex_min_mean_expr  gtex_max_mean_expr    GEMINI       LFC  SL_new
# 0            0.258739              11.702  0.118768  0.088856   False
# 1            0.258739              11.702  0.132501  0.201704   False
# 2            0.258739              11.702  0.024593  0.069772   False
# 3            0.258739              11.702 -0.241323  0.379455   False
# 4            0.258739              11.702  0.299715 -0.077118   False
#
# [5 rows x 83 columns]

# %%
feature_columns_1 = ['rMaxExp_A1A2', 'rMinExp_A1A2',
                     'max_ranked_A1A2', 'min_ranked_A1A2',
                     'max_cn', 'min_cn', 'Protein_Altering', 'Damaging', 
                     'min_sequence_identity',
                     'prediction_score', 
                     'weighted_PPI_essentiality', 'weighted_PPI_expression',
                     'smallest_BP_GO_essentiality', 'smallest_CC_GO_essentiality',
                     'smallest_BP_GO_expression', 'go_CC_expression'
                     ]

target_column = 'SL_new'

print('num of features:', len(feature_columns_1))
# Out:
# num of features: 16

# %%
feature_columns_2 = feature_columns_1 + ['closest', 'WGD', 'family_size',
                                         'cds_length_ratio', 'shared_domains', 'has_pombe_ortholog',
                                         'has_essential_pombe_ortholog', 'has_cerevisiae_ortholog', 'has_essential_cerevisiae_ortholog', 
                                         'conservation_score', 'mean_age', 'either_in_complex', 'mean_complex_essentiality', 'colocalisation',
                                         'interact', 'n_total_ppi', 'fet_ppi_overlap',
                                         'gtex_spearman_corr', 'gtex_min_mean_expr', 'gtex_max_mean_expr']
feature_columns_2.remove('prediction_score')
print('num of features:', len(feature_columns_2))
# Out:
# num of features: 35

# %%
# Load splits_IV from pickle file to determine average train and test set sizes
with open('/Users/narod/Library/CloudStorage/GoogleDrive-narod.kebabci@ucdconnect.ie/My Drive/GitRepos/context_specific_SL_prediction/output/models/model_IV/splits_IV.pkl', 'rb') as f:
    splits_IV = pickle.load(f)

# Calculate average train and test set sizes
train_sizes = []
test_sizes = []

for train_idx, test_idx in splits_IV:
    train_sizes.append(len(train_idx))
    test_sizes.append(len(test_idx))

avg_train_size = sum(train_sizes) / len(train_sizes)
avg_test_size = sum(test_sizes) / len(test_sizes)

print(f"Average training set size: {avg_train_size:.2f}")
print(f"Average test set size: {avg_test_size:.2f}")
# Out:
# Average training set size: 26396.04
# Average test set size: 1649.64

# %% [markdown]
# ## Model I - Random Selection

# %%
def safe_roc_auc(y_true, y_score):
    mask = ~np.isnan(y_score)
    if np.sum(mask) < 2 or len(np.unique(y_true[mask])) < 2:
        return np.nan
    return roc_auc_score(y_true[mask], y_score[mask])

def safe_average_precision(y_true, y_score):
    mask = ~np.isnan(y_score)
    if np.sum(mask) == 0:
        return np.nan
    return average_precision_score(y_true[mask], y_score[mask])

# %%
def validate_stratification(y_train, y_test, fold_num, model_name, tolerance=0.05):
    """
    Validate that stratification is working correctly across train/test splits.
    
    Parameters:
    - y_train, y_test: target arrays for train and test sets
    - fold_num: current fold number
    - model_name: name of the model for logging
    - tolerance: acceptable difference in class proportions (default 5%)
    """
    # Calculate class proportions
    train_pos_rate = y_train.mean()
    test_pos_rate = y_test.mean()
    overall_pos_rate = np.concatenate([y_train, y_test]).mean()
    
    # Calculate differences from overall rate
    train_diff = abs(train_pos_rate - overall_pos_rate)
    test_diff = abs(test_pos_rate - overall_pos_rate)
    train_test_diff = abs(train_pos_rate - test_pos_rate)
    
    # Print detailed information
    print(f"  [{model_name} - Fold {fold_num}] Stratification Check:")
    print(f"    Overall SL rate: {overall_pos_rate:.4f}")
    print(f"    Train SL rate:   {train_pos_rate:.4f} (diff: {train_diff:.4f})")
    print(f"    Test SL rate:    {test_pos_rate:.4f} (diff: {test_diff:.4f})")
    print(f"    Train/Test diff: {train_test_diff:.4f}")
    
    # Check for violations
    warnings = []
    if train_diff > tolerance:
        warnings.append(f"Train set deviation ({train_diff:.4f}) exceeds tolerance ({tolerance})")
    if test_diff > tolerance:
        warnings.append(f"Test set deviation ({test_diff:.4f}) exceeds tolerance ({tolerance})")
    if train_test_diff > tolerance:
        warnings.append(f"Train/Test difference ({train_test_diff:.4f}) exceeds tolerance ({tolerance})")
    
    if warnings:
        print(f"WARNINGS:")
        for warning in warnings:
            print(f"      - {warning}")
    else:
        print(f"Stratification OK")
    
    return {
        'train_pos_rate': train_pos_rate,
        'test_pos_rate': test_pos_rate,
        'overall_pos_rate': overall_pos_rate,
        'train_diff': train_diff,
        'test_diff': test_diff,
        'train_test_diff': train_test_diff,
        'warnings': warnings
    }

def validate_group_splits(train_groups, test_groups, fold_num, model_name, group_type="groups"):
    """
    Validate that groups don't leak between train and test sets.
    """
    train_set = set(train_groups)
    test_set = set(test_groups)
    overlap = train_set & test_set
    
    print(f"  [{model_name} - Fold {fold_num}] Group Validation:")
    print(f"    Train {group_type}: {len(train_set)}")
    print(f"    Test {group_type}:  {len(test_set)}")
    print(f"    Overlapping {group_type}: {len(overlap)}")
    
    if len(overlap) > 0:
        print(f"GROUP LEAKAGE DETECTED: {overlap}")
        return False
    else:
        print(f"No group leakage")
        return True

# %%
def stratified_downsample_indices(y, train_indices, target_n, random_state=42):
    train_indices = np.asarray(train_indices)
    if train_indices.size <= target_n:
        return train_indices
    y_fold = np.asarray(y)[train_indices]
    sss = StratifiedShuffleSplit(n_splits=1, train_size=target_n, random_state=random_state)
    sub_idx, _ = next(sss.split(np.zeros_like(y_fold), y_fold))
    return train_indices[sub_idx]

# %%
def model_contextualised_cross_validation(
    classifier, data, target, splits, verbose=True, model_name="Model",
    downsample_train_to=None, downsample_random_state=42
):
    print(f"[DEBUG] model_contextualised_cross_validation v4 — downsample={downsample_train_to}")  # signature

    tprs, fprs, aucs = [], [], []
    mean_fpr = np.linspace(0, 1, 100)

    pred_aucs, seq_aucs, gene_expr_aucs, gene_ess_aucs = [], [], [], []
    aps, pred_aps, seq_aps, gene_expr_aps, gene_ess_aps = [], [], [], [], []

    y_real, y_proba = [], []

    stratification_results = []
    skipped_folds = []
    effective_train_sizes = []   # collect sizes

    total_splits = len(splits)
    start_time = time.time()

    # Ensure NumPy array for fast indexing
    y_all = target.values if hasattr(target, "values") else np.asarray(target)

    for fold_num, (train, test) in enumerate(splits, start=1):
        # ----- Print original sizes -----
        print(f"Fold {fold_num}:")
        print(f"  Original train size = {len(train)}, Test size = {len(test)}")

        if len(test) == 0:
            print(f"  Skipping fold {fold_num}: Empty test set")
            skipped_folds.append(fold_num)
            continue

        # ----- Downsample the TRAIN indices if requested -----
        if downsample_train_to is not None:
            train_sub = stratified_downsample_indices(
                y_all, train, target_n=downsample_train_to, random_state=downsample_random_state
            )
        else:
            train_sub = np.asarray(train)

        # ----- Print effective size (what we actually train on) -----
        eff_sz = len(train_sub)
        effective_train_sizes.append(eff_sz)
        print(
            f"  Effective train size after downsampling = {eff_sz}"
            f"{' (cap: ' + str(downsample_train_to) + ')' if downsample_train_to else ''}",
            flush=True
        )

        # Hard guard: when original > cap, ensure we hit exactly the cap
        if downsample_train_to is not None and len(train) > downsample_train_to:
            assert eff_sz == downsample_train_to, f"Expected {downsample_train_to}, got {eff_sz}"

        # Targets for this fold (downsampled train, full test)
        y_train = y_all[train_sub]
        y_test  = y_all[np.asarray(test)]

        # Validate stratification AFTER downsampling
        stratification_result = validate_stratification(y_train, y_test, fold_num, model_name)
        stratification_results.append(stratification_result)

        if np.unique(y_test).size < 2:
            print(f"  Skipping fold {fold_num}: Insufficient positive/negative samples in test set")
            print(f"  Test set classes: {np.unique(y_test)}")
            skipped_folds.append(fold_num)
            continue

        # ----- Fit on downsampled train; evaluate on full test -----
        y_pred_proba = classifier.fit(data.iloc[train_sub], target.iloc[train_sub]) \
                                  .predict_proba(data.iloc[test])[:, 1]

        fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
        tprs.append(tpr); fprs.append(fpr)

        aucs.append(roc_auc_score(y_test, y_pred_proba))
        aps.append(average_precision_score(y_test, y_pred_proba))

        # Baseline feature scores on test
        pred_aucs.append(safe_roc_auc(y_test, data.iloc[test]['prediction_score'].values))
        seq_aucs.append(safe_roc_auc(y_test, data.iloc[test]['min_sequence_identity'].values))
        gene_expr_aucs.append(safe_roc_auc(y_test, data.iloc[test]['rMinExp_A1A2'].values))
        gene_ess_aucs.append(1 - safe_roc_auc(y_test, data.iloc[test]['min_ranked_A1A2'].values))

        pred_aps.append(safe_average_precision(y_test, data.iloc[test]['prediction_score'].values))
        seq_aps.append(safe_average_precision(y_test, data.iloc[test]['min_sequence_identity'].values))
        gene_expr_aps.append(safe_average_precision(y_test, data.iloc[test]['rMinExp_A1A2'].values))
        gene_ess_aps.append(safe_average_precision(y_test, data.iloc[test]['min_ranked_A1A2'].values))

        y_real.append(y_test); y_proba.append(y_pred_proba)

        if verbose:
            elapsed_time = time.time() - start_time
            print(f"  ROC AUC = {aucs[-1]:.4f}, Elapsed time = {elapsed_time:.2f} seconds")

    # ----- Aggregate curves/metrics -----
    if len(tprs) > 0:
        mean_tpr = np.mean([np.interp(mean_fpr, fprs[i], tprs[i]) for i in range(len(tprs))], axis=0)
        mean_tpr[-1] = 1.0
        mean_auc = auc(mean_fpr, mean_tpr)
        std_auc = np.std(aucs)
    else:
        mean_tpr, mean_auc, std_auc = np.array([]), np.nan, np.nan

    if len(y_real) > 0 and len(y_proba) > 0:
        y_real = np.concatenate(y_real); y_proba = np.concatenate(y_proba)
        precision, recall, _ = precision_recall_curve(y_real, y_proba)
    else:
        precision, recall = np.array([]), np.array([])

    # ----- Summary -----
    print(f"\n=== {model_name} Summary ===")
    if not np.isnan(mean_auc):
        print(f"Mean ROC AUC = {mean_auc:.4f} ± {std_auc:.4f}")
    print(f"Successful folds: {len(aucs)}/{total_splits}")
    if skipped_folds:
        print(f"Skipped folds: {skipped_folds}")

    if stratification_results:
        train_diffs = [r['train_diff'] for r in stratification_results]
        test_diffs  = [r['test_diff']  for r in stratification_results]
        print("Stratification quality:")
        print(f"  Mean train deviation: {np.mean(train_diffs):.4f} ± {np.std(train_diffs):.4f}")
        print(f"  Mean test deviation:  {np.mean(test_diffs):.4f} ± {np.std(test_diffs):.4f}")

    return {
        'tprs': tprs, 'fprs': fprs, 'aucs': aucs,
        'mean_tpr': mean_tpr, 'mean_fpr': mean_fpr, 'mean_auc': mean_auc, 'std_auc': std_auc,
        'seq_auc': np.nanmean(seq_aucs), 'seq_std_auc': np.nanstd(seq_aucs),
        'pred_auc': np.nanmean(pred_aucs), 'pred_std_auc': np.nanstd(pred_aucs),
        'gene_expr_auc': np.nanmean(gene_expr_aucs), 'gene_expr_std_auc': np.nanstd(gene_expr_aucs),
        'gene_ess_auc': np.nanmean(gene_ess_aucs), 'gene_ess_std_auc': np.nanstd(gene_ess_aucs),
        'precision': precision, 'recall': recall, 'aps': aps,
        'mean_aps': np.nanmean(aps), 'std_ap': np.nanstd(aps),
        'pred_ap': np.nanmean(pred_aps), 'pred_std_ap': np.nanstd(pred_aps),
        'seq_ap': np.nanmean(seq_aps), 'seq_std_ap': np.nanstd(seq_aps),
        'gene_expr_ap': np.nanmean(gene_expr_aps), 'gene_expr_std_ap': np.nanstd(gene_expr_aps),
        'gene_ess_ap': np.nanmean(gene_ess_aps), 'gene_ess_std_ap': np.nanstd(gene_ess_aps),
        'stratification_results': stratification_results,
        'skipped_folds': skipped_folds,
        'effective_folds': len(aucs),
        'effective_train_sizes': effective_train_sizes,
    }

# %%
def model_full_cross_validation(
    classifier, data, target, splits, verbose=True, model_name="Model",
    downsample_train_to=None, downsample_random_state=42
):
    print(f"[DEBUG] model_full_cross_validation v2 — downsample={downsample_train_to}")  # signature

    tprs, fprs, aucs = [], [], []
    mean_fpr = np.linspace(0, 1, 100)

    y_real, y_proba, aps = [], [], []

    stratification_results = []
    skipped_folds = []
    effective_train_sizes = []   # NEW

    total_splits = len(splits)
    start_time = time.time()

    # Ensure NumPy for reliable indexing
    y_all = target.values if hasattr(target, "values") else np.asarray(target)

    for fold_num, (train, test) in enumerate(splits, start=1):
        print(f"\n=== {model_name} - Fold {fold_num}/{total_splits} ===")
        print(f"  Original train size = {len(train)}, Test size = {len(test)}")

        if len(test) == 0:
            print(f"  Skipping fold {fold_num}: Empty test set")
            skipped_folds.append(fold_num)
            continue

        # --- Downsample TRAIN if requested ---
        if downsample_train_to is not None:
            train_sub = stratified_downsample_indices(
                y_all, train, target_n=downsample_train_to, random_state=downsample_random_state
            )
        else:
            train_sub = np.asarray(train)

        # Print effective size (what we actually train on)
        eff_sz = len(train_sub)
        effective_train_sizes.append(eff_sz)
        print(
            f"  Effective train size after downsampling = {eff_sz}"
            f"{' (cap: ' + str(downsample_train_to) + ')' if downsample_train_to else ''}",
            flush=True
        )

        # Guard: if the original was larger than the cap, ensure we hit the cap
        if downsample_train_to is not None and len(train) > downsample_train_to:
            assert eff_sz == downsample_train_to, f"Expected {downsample_train_to}, got {eff_sz}"

        # Targets for this fold (downsampled train, full test)
        y_train = y_all[train_sub]
        y_test  = y_all[np.asarray(test)]

        # Validate stratification AFTER downsampling
        stratification_result = validate_stratification(y_train, y_test, fold_num, model_name)
        stratification_results.append(stratification_result)

        if np.unique(y_test).size < 2:
            print(f"  Skipping fold {fold_num}: Insufficient positive/negative samples in test set")
            print(f"  Test set classes: {np.unique(y_test)}")
            skipped_folds.append(fold_num)
            continue

        # --- Train on downsampled train; evaluate on full test ---
        y_pred_proba = classifier.fit(data.iloc[train_sub], target.iloc[train_sub]) \
                                  .predict_proba(data.iloc[test])[:, 1]

        fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
        tprs.append(tpr); fprs.append(fpr)

        aucs.append(safe_roc_auc(y_test, y_pred_proba))
        aps.append(safe_average_precision(y_test, y_pred_proba))

        y_real.append(y_test)
        y_proba.append(y_pred_proba)

        if verbose:
            elapsed_time = time.time() - start_time
            print(f"  ROC AUC = {aucs[-1]:.4f}, Elapsed time = {elapsed_time:.2f} seconds")

    # Aggregate metrics
    if len(tprs) > 0:
        mean_tpr = np.mean([np.interp(mean_fpr, fprs[i], tprs[i]) for i in range(len(tprs))], axis=0)
        mean_tpr[-1] = 1.0
        mean_auc = auc(mean_fpr, mean_tpr)
        std_auc = np.std(aucs)
    else:
        mean_tpr, mean_auc, std_auc = np.array([]), np.nan, np.nan

    if len(y_real) > 0 and len(y_proba) > 0:
        y_real = np.concatenate(y_real)
        y_proba = np.concatenate(y_proba)
        precision, recall, _ = precision_recall_curve(y_real, y_proba)
    else:
        precision, recall = np.array([]), np.array([])

    # Summary
    print(f"\n=== {model_name} Summary ===")
    if not np.isnan(mean_auc):
        print(f"Mean ROC AUC = {mean_auc:.4f} ± {std_auc:.4f}")
    print(f"Successful folds: {len(aucs)}/{total_splits}")
    if skipped_folds:
        print(f"Skipped folds: {skipped_folds}")

    if stratification_results:
        train_diffs = [r['train_diff'] for r in stratification_results]
        test_diffs  = [r['test_diff']  for r in stratification_results]
        print("Stratification quality:")
        print(f"  Mean train deviation: {np.mean(train_diffs):.4f} ± {np.std(train_diffs):.4f}")
        print(f"  Mean test deviation:  {np.mean(test_diffs):.4f} ± {np.std(test_diffs):.4f}")

    return {
        'tprs': tprs, 'fprs': fprs, 'aucs': aucs,
        'mean_tpr': mean_tpr, 'mean_fpr': mean_fpr, 'mean_auc': mean_auc, 'std_auc': std_auc,
        'precision': precision, 'recall': recall, 'aps': aps,
        'mean_aps': np.nanmean(aps),
        'std_ap': np.nanstd(aps),
        'stratification_results': stratification_results,
        'skipped_folds': skipped_folds,
        'effective_folds': len(aucs),
        'effective_train_sizes': effective_train_sizes,   # NEW
    }

# %%
# Define feature sets
data_1 = training_df[feature_columns_1]
data_2 = training_df[feature_columns_2]
target = training_df[target_column]

# Define your Random Forest classifier
RF = RandomForestClassifier(n_estimators=600, random_state=42, max_features=0.2, max_depth=20, min_samples_leaf=4)

# %%
import pickle

with open("/Users/narod/Library/CloudStorage/GoogleDrive-narod.kebabci@ucdconnect.ie/My Drive/GitRepos/context_specific_SL_prediction/output/models/model_I/repeated_splits_I.pkl", "rb") as f:
    repeated_splits_I = pickle.load(f)

# %%
model_I_contextualised_reduced = model_contextualised_cross_validation(
    classifier=RF,
    data=training_df[feature_columns_1],
    target=training_df[target_column],
    splits=repeated_splits_I,
    model_name="Model_I_contextualised_repeated",
    downsample_train_to=26400,
    downsample_random_state=42,
)
# Out:
# [DEBUG] model_early_cross_validation v4 — downsample=26400
# Fold 1:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 1] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9053, Elapsed time = 35.15 seconds
# Fold 2:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 2] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9123, Elapsed time = 71.48 seconds
# Fold 3:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 3] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9201, Elapsed time = 107.63 seconds
# Fold 4:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 4] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9090, Elapsed time = 144.75 seconds
# Fold 5:
#   Original train size = 32996, Test size = 8248
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 5] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9243, Elapsed time = 186.65 seconds
# Fold 6:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 6] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9401, Elapsed time = 226.25 seconds
# Fold 7:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 7] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9252, Elapsed time = 264.39 seconds
# Fold 8:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 8] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9237, Elapsed time = 305.69 seconds
# Fold 9:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 9] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9003, Elapsed time = 376.84 seconds
# Fold 10:
#   Original train size = 32996, Test size = 8248
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 10] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.8903, Elapsed time = 422.98 seconds
# Fold 11:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 11] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9247, Elapsed time = 463.00 seconds
# Fold 12:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 12] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9220, Elapsed time = 504.07 seconds
# Fold 13:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 13] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9014, Elapsed time = 549.97 seconds
# Fold 14:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 14] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9048, Elapsed time = 590.49 seconds
# Fold 15:
#   Original train size = 32996, Test size = 8248
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 15] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9259, Elapsed time = 631.47 seconds
# Fold 16:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 16] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9226, Elapsed time = 676.27 seconds
# Fold 17:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 17] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9031, Elapsed time = 727.51 seconds
# Fold 18:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 18] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9329, Elapsed time = 772.00 seconds
# Fold 19:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 19] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9181, Elapsed time = 814.23 seconds
# Fold 20:
#   Original train size = 32996, Test size = 8248
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 20] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9117, Elapsed time = 854.10 seconds
# Fold 21:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 21] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9249, Elapsed time = 897.91 seconds
# Fold 22:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 22] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9142, Elapsed time = 937.72 seconds
# Fold 23:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 23] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9092, Elapsed time = 977.72 seconds
# Fold 24:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 24] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9197, Elapsed time = 1020.66 seconds
# Fold 25:
#   Original train size = 32996, Test size = 8248
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 25] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9240, Elapsed time = 1062.21 seconds
# Fold 26:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 26] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9155, Elapsed time = 1099.92 seconds
# Fold 27:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 27] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9251, Elapsed time = 1139.36 seconds
# Fold 28:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 28] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9146, Elapsed time = 1180.64 seconds
# Fold 29:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 29] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9131, Elapsed time = 1219.29 seconds
# Fold 30:
#   Original train size = 32996, Test size = 8248
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 30] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9107, Elapsed time = 1259.56 seconds
# Fold 31:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 31] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9011, Elapsed time = 1302.02 seconds
# Fold 32:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 32] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9339, Elapsed time = 1342.17 seconds
# Fold 33:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 33] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9226, Elapsed time = 1380.16 seconds
# Fold 34:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 34] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9195, Elapsed time = 1418.96 seconds
# Fold 35:
#   Original train size = 32996, Test size = 8248
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 35] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9099, Elapsed time = 1458.06 seconds
# Fold 36:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 36] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9200, Elapsed time = 1502.67 seconds
# Fold 37:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 37] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9191, Elapsed time = 1546.80 seconds
# Fold 38:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 38] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9277, Elapsed time = 1592.99 seconds
# Fold 39:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 39] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9257, Elapsed time = 1649.40 seconds
# Fold 40:
#   Original train size = 32996, Test size = 8248
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 40] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9044, Elapsed time = 1690.78 seconds
# Fold 41:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 41] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9140, Elapsed time = 1732.90 seconds
# Fold 42:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 42] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9151, Elapsed time = 1783.54 seconds
# Fold 43:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 43] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9171, Elapsed time = 1824.80 seconds
# Fold 44:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 44] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9139, Elapsed time = 1862.90 seconds
# Fold 45:
#   Original train size = 32996, Test size = 8248
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 45] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9199, Elapsed time = 1902.46 seconds
# Fold 46:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 46] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9233, Elapsed time = 1939.18 seconds
# Fold 47:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 47] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9144, Elapsed time = 1974.64 seconds
# Fold 48:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 48] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9043, Elapsed time = 2014.93 seconds
# Fold 49:
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 49] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9217, Elapsed time = 2051.24 seconds
# Fold 50:
#   Original train size = 32996, Test size = 8248
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_early_repeated - Fold 50] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9156, Elapsed time = 2090.69 seconds
#
# === Model_I_early_repeated Summary ===
# Mean ROC AUC = 0.9161 ± 0.0095
# Successful folds: 50/50
# Stratification quality:
#   Mean train deviation: 0.0000 ± 0.0000
#   Mean test deviation:  0.0001 ± 0.0000

# %%
model_I_full_reduced = model_full_cross_validation(
    classifier=RF,
    data=training_df[feature_columns_2],  
    target=training_df[target_column],
    splits=repeated_splits_I,                   
    model_name="Model_I_full_reduced",
    downsample_train_to=26400,                 
    downsample_random_state=42,
    verbose=True
)
# Out:
# [DEBUG] model_late_cross_validation v2 — downsample=26400
#
# === Model_I_late_reduced - Fold 1/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 1] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9169, Elapsed time = 62.55 seconds
#
# === Model_I_late_reduced - Fold 2/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 2] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9252, Elapsed time = 124.13 seconds
#
# === Model_I_late_reduced - Fold 3/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 3] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9347, Elapsed time = 183.26 seconds
#
# === Model_I_late_reduced - Fold 4/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 4] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9207, Elapsed time = 245.23 seconds
#
# === Model_I_late_reduced - Fold 5/50 ===
#   Original train size = 32996, Test size = 8248
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 5] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9371, Elapsed time = 312.11 seconds
#
# === Model_I_late_reduced - Fold 6/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 6] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9472, Elapsed time = 374.30 seconds
#
# === Model_I_late_reduced - Fold 7/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 7] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9327, Elapsed time = 439.41 seconds
#
# === Model_I_late_reduced - Fold 8/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 8] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9325, Elapsed time = 498.78 seconds
#
# === Model_I_late_reduced - Fold 9/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 9] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9151, Elapsed time = 560.30 seconds
#
# === Model_I_late_reduced - Fold 10/50 ===
#   Original train size = 32996, Test size = 8248
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 10] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9026, Elapsed time = 621.27 seconds
#
# === Model_I_late_reduced - Fold 11/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 11] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9338, Elapsed time = 677.21 seconds
#
# === Model_I_late_reduced - Fold 12/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 12] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9345, Elapsed time = 741.90 seconds
#
# === Model_I_late_reduced - Fold 13/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 13] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9141, Elapsed time = 803.86 seconds
#
# === Model_I_late_reduced - Fold 14/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 14] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9169, Elapsed time = 862.95 seconds
#
# === Model_I_late_reduced - Fold 15/50 ===
#   Original train size = 32996, Test size = 8248
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 15] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9312, Elapsed time = 927.66 seconds
#
# === Model_I_late_reduced - Fold 16/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 16] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9344, Elapsed time = 1023.17 seconds
#
# === Model_I_late_reduced - Fold 17/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 17] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9164, Elapsed time = 1113.89 seconds
#
# === Model_I_late_reduced - Fold 18/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 18] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9367, Elapsed time = 1176.43 seconds
#
# === Model_I_late_reduced - Fold 19/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 19] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9349, Elapsed time = 1234.80 seconds
#
# === Model_I_late_reduced - Fold 20/50 ===
#   Original train size = 32996, Test size = 8248
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 20] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9266, Elapsed time = 1295.79 seconds
#
# === Model_I_late_reduced - Fold 21/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 21] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9422, Elapsed time = 1355.71 seconds
#
# === Model_I_late_reduced - Fold 22/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 22] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9202, Elapsed time = 1410.44 seconds
#
# === Model_I_late_reduced - Fold 23/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 23] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9233, Elapsed time = 1468.64 seconds
#
# === Model_I_late_reduced - Fold 24/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 24] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9306, Elapsed time = 1525.24 seconds
#
# === Model_I_late_reduced - Fold 25/50 ===
#   Original train size = 32996, Test size = 8248
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 25] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9330, Elapsed time = 1583.12 seconds
#
# === Model_I_late_reduced - Fold 26/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 26] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9323, Elapsed time = 1636.64 seconds
#
# === Model_I_late_reduced - Fold 27/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 27] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9338, Elapsed time = 1693.57 seconds
#
# === Model_I_late_reduced - Fold 28/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 28] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9343, Elapsed time = 1749.31 seconds
#
# === Model_I_late_reduced - Fold 29/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 29] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9204, Elapsed time = 1806.25 seconds
#
# === Model_I_late_reduced - Fold 30/50 ===
#   Original train size = 32996, Test size = 8248
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 30] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9238, Elapsed time = 1863.94 seconds
#
# === Model_I_late_reduced - Fold 31/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 31] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9189, Elapsed time = 1922.45 seconds
#
# === Model_I_late_reduced - Fold 32/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 32] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9433, Elapsed time = 1974.85 seconds
#
# === Model_I_late_reduced - Fold 33/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 33] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9303, Elapsed time = 2025.90 seconds
#
# === Model_I_late_reduced - Fold 34/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 34] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9305, Elapsed time = 2078.77 seconds
#
# === Model_I_late_reduced - Fold 35/50 ===
#   Original train size = 32996, Test size = 8248
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 35] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9197, Elapsed time = 2129.72 seconds
#
# === Model_I_late_reduced - Fold 36/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 36] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9304, Elapsed time = 2182.61 seconds
#
# === Model_I_late_reduced - Fold 37/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 37] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9302, Elapsed time = 2236.68 seconds
#
# === Model_I_late_reduced - Fold 38/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 38] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9388, Elapsed time = 2289.10 seconds
#
# === Model_I_late_reduced - Fold 39/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 39] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9403, Elapsed time = 2342.82 seconds
#
# === Model_I_late_reduced - Fold 40/50 ===
#   Original train size = 32996, Test size = 8248
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 40] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9121, Elapsed time = 2395.92 seconds
#
# === Model_I_late_reduced - Fold 41/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 41] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9281, Elapsed time = 2448.23 seconds
#
# === Model_I_late_reduced - Fold 42/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 42] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9184, Elapsed time = 2500.61 seconds
#
# === Model_I_late_reduced - Fold 43/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 43] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9339, Elapsed time = 2553.39 seconds
#
# === Model_I_late_reduced - Fold 44/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 44] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9324, Elapsed time = 2609.02 seconds
#
# === Model_I_late_reduced - Fold 45/50 ===
#   Original train size = 32996, Test size = 8248
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 45] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9288, Elapsed time = 2675.69 seconds
#
# === Model_I_late_reduced - Fold 46/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 46] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9303, Elapsed time = 2738.73 seconds
#
# === Model_I_late_reduced - Fold 47/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 47] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9229, Elapsed time = 2803.83 seconds
#
# === Model_I_late_reduced - Fold 48/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 48] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9204, Elapsed time = 2873.20 seconds
#
# === Model_I_late_reduced - Fold 49/50 ===
#   Original train size = 32995, Test size = 8249
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 49] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9320, Elapsed time = 2938.66 seconds
#
# === Model_I_late_reduced - Fold 50/50 ===
#   Original train size = 32996, Test size = 8248
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_I_late_reduced - Fold 50] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9294, Elapsed time = 3002.74 seconds
#
# === Model_I_late_reduced Summary ===
# Mean ROC AUC = 0.9275 ± 0.0088
# Successful folds: 50/50
# Stratification quality:
#   Mean train deviation: 0.0000 ± 0.0000
#   Mean test deviation:  0.0001 ± 0.0000

# %%
# save results of cross validation
with open(file_RF_model_I_contextualised_reduced, 'wb') as f:
   pickle.dump(model_I_contextualised_reduced, f)

with open(file_RF_model_I_full_reduced, 'wb') as f:
    pickle.dump(model_I_full_reduced, f)

# %% [markdown]
# ## Model II
# #### Same paralog pairs, different cell lines

# %%
# Read splits
with open('/Users/narod/Library/CloudStorage/GoogleDrive-narod.kebabci@ucdconnect.ie/My Drive/GitRepos/context_specific_SL_prediction/output/models/model_II/repeated_splits_II.pkl', 'rb') as f:
    repeated_splits_II = pickle.load(f)

# %%
for i, (tr, te) in enumerate(repeated_splits_II, 1):
    train_cells = training_df.loc[tr, 'cell_line'].unique()
    test_cells  = training_df.loc[te, 'cell_line'].unique()
    validate_group_splits(train_cells, test_cells, i, "Model II", "cell lines")
# Out:
#   [Model II - Fold 1] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 2] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 3] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 4] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 5] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 6] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 7] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 8] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 9] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 10] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 11] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 12] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 13] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 14] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 15] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 16] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 17] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 18] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 19] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 20] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 21] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 22] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 23] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 24] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 25] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 26] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 27] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 28] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 29] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 30] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 31] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 32] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 33] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 34] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 35] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 36] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 37] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 38] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 39] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 40] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 41] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 42] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 43] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 44] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 45] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 46] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 47] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 48] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 49] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 50] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage

# %%
model_II_contextualised_reduced = model_contextualised_cross_validation(
    classifier=RF,
    data=training_df[feature_columns_1],      # or training_df if easier
    target=training_df[target_column],
    splits=repeated_splits_II,                # <-- group CV splits (unseen cell lines in test)
    model_name="Model_II_contextualised_reduced",
    downsample_train_to=26_400,               # cap train fold size
    downsample_random_state=42,
    verbose=True
)
# Out:
# [DEBUG] model_early_cross_validation v4 — downsample=26400
# Fold 1:
#   Original train size = 32973, Test size = 8271
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 1] Stratification Check:
#     Overall SL rate: 0.0226
#     Train SL rate:   0.0266 (diff: 0.0040)
#     Test SL rate:    0.0097 (diff: 0.0129)
#     Train/Test diff: 0.0170
# Stratification OK
#   ROC AUC = 0.9554, Elapsed time = 39.67 seconds
# Fold 2:
#   Original train size = 32978, Test size = 8266
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 2] Stratification Check:
#     Overall SL rate: 0.0236
#     Train SL rate:   0.0213 (diff: 0.0023)
#     Test SL rate:    0.0311 (diff: 0.0075)
#     Train/Test diff: 0.0098
# Stratification OK
#   ROC AUC = 0.9183, Elapsed time = 80.04 seconds
# Fold 3:
#   Original train size = 33018, Test size = 8226
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 3] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0235 (diff: 0.0004)
#     Test SL rate:    0.0220 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.8798, Elapsed time = 120.61 seconds
# Fold 4:
#   Original train size = 32992, Test size = 8252
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 4] Stratification Check:
#     Overall SL rate: 0.0235
#     Train SL rate:   0.0220 (diff: 0.0015)
#     Test SL rate:    0.0281 (diff: 0.0047)
#     Train/Test diff: 0.0061
# Stratification OK
#   ROC AUC = 0.8837, Elapsed time = 161.01 seconds
# Fold 5:
#   Original train size = 33015, Test size = 8229
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 5] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0227 (diff: 0.0006)
#     Test SL rate:    0.0253 (diff: 0.0019)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.8604, Elapsed time = 197.76 seconds
# Fold 6:
#   Original train size = 33032, Test size = 8212
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 6] Stratification Check:
#     Overall SL rate: 0.0229
#     Train SL rate:   0.0251 (diff: 0.0022)
#     Test SL rate:    0.0158 (diff: 0.0071)
#     Train/Test diff: 0.0092
# Stratification OK
#   ROC AUC = 0.9014, Elapsed time = 232.71 seconds
# Fold 7:
#   Original train size = 33032, Test size = 8212
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 7] Stratification Check:
#     Overall SL rate: 0.0228
#     Train SL rate:   0.0253 (diff: 0.0024)
#     Test SL rate:    0.0150 (diff: 0.0078)
#     Train/Test diff: 0.0103
# Stratification OK
#   ROC AUC = 0.9248, Elapsed time = 267.19 seconds
# Fold 8:
#   Original train size = 32954, Test size = 8290
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 8] Stratification Check:
#     Overall SL rate: 0.0234
#     Train SL rate:   0.0221 (diff: 0.0013)
#     Test SL rate:    0.0276 (diff: 0.0042)
#     Train/Test diff: 0.0055
# Stratification OK
#   ROC AUC = 0.8575, Elapsed time = 301.18 seconds
# Fold 9:
#   Original train size = 32993, Test size = 8251
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 9] Stratification Check:
#     Overall SL rate: 0.0238
#     Train SL rate:   0.0205 (diff: 0.0033)
#     Test SL rate:    0.0343 (diff: 0.0105)
#     Train/Test diff: 0.0138
# Stratification OK
#   ROC AUC = 0.9083, Elapsed time = 335.92 seconds
# Fold 10:
#   Original train size = 32965, Test size = 8279
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 10] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.8876, Elapsed time = 371.18 seconds
# Fold 11:
#   Original train size = 32973, Test size = 8271
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 11] Stratification Check:
#     Overall SL rate: 0.0226
#     Train SL rate:   0.0266 (diff: 0.0040)
#     Test SL rate:    0.0097 (diff: 0.0129)
#     Train/Test diff: 0.0170
# Stratification OK
#   ROC AUC = 0.9554, Elapsed time = 406.08 seconds
# Fold 12:
#   Original train size = 33013, Test size = 8231
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 12] Stratification Check:
#     Overall SL rate: 0.0237
#     Train SL rate:   0.0206 (diff: 0.0032)
#     Test SL rate:    0.0339 (diff: 0.0102)
#     Train/Test diff: 0.0133
# Stratification OK
#   ROC AUC = 0.8422, Elapsed time = 439.92 seconds
# Fold 13:
#   Original train size = 32993, Test size = 8251
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 13] Stratification Check:
#     Overall SL rate: 0.0238
#     Train SL rate:   0.0205 (diff: 0.0033)
#     Test SL rate:    0.0343 (diff: 0.0105)
#     Train/Test diff: 0.0138
# Stratification OK
#   ROC AUC = 0.9083, Elapsed time = 474.75 seconds
# Fold 14:
#   Original train size = 32970, Test size = 8274
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 14] Stratification Check:
#     Overall SL rate: 0.0231
#     Train SL rate:   0.0239 (diff: 0.0008)
#     Test SL rate:    0.0207 (diff: 0.0024)
#     Train/Test diff: 0.0032
# Stratification OK
#   ROC AUC = 0.8820, Elapsed time = 511.94 seconds
# Fold 15:
#   Original train size = 33027, Test size = 8217
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 15] Stratification Check:
#     Overall SL rate: 0.0230
#     Train SL rate:   0.0246 (diff: 0.0017)
#     Test SL rate:    0.0176 (diff: 0.0053)
#     Train/Test diff: 0.0070
# Stratification OK
#   ROC AUC = 0.9092, Elapsed time = 546.54 seconds
# Fold 16:
#   Original train size = 32979, Test size = 8265
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 16] Stratification Check:
#     Overall SL rate: 0.0229
#     Train SL rate:   0.0247 (diff: 0.0018)
#     Test SL rate:    0.0172 (diff: 0.0058)
#     Train/Test diff: 0.0076
# Stratification OK
#   ROC AUC = 0.9022, Elapsed time = 580.48 seconds
# Fold 17:
#   Original train size = 33080, Test size = 8164
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 17] Stratification Check:
#     Overall SL rate: 0.0229
#     Train SL rate:   0.0249 (diff: 0.0020)
#     Test SL rate:    0.0163 (diff: 0.0066)
#     Train/Test diff: 0.0086
# Stratification OK
#   ROC AUC = 0.9080, Elapsed time = 614.99 seconds
# Fold 18:
#   Original train size = 32971, Test size = 8273
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 18] Stratification Check:
#     Overall SL rate: 0.0230
#     Train SL rate:   0.0247 (diff: 0.0017)
#     Test SL rate:    0.0174 (diff: 0.0056)
#     Train/Test diff: 0.0073
# Stratification OK
#   ROC AUC = 0.9108, Elapsed time = 650.21 seconds
# Fold 19:
#   Original train size = 32966, Test size = 8278
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 19] Stratification Check:
#     Overall SL rate: 0.0235
#     Train SL rate:   0.0217 (diff: 0.0019)
#     Test SL rate:    0.0295 (diff: 0.0059)
#     Train/Test diff: 0.0078
# Stratification OK
#   ROC AUC = 0.9194, Elapsed time = 684.67 seconds
# Fold 20:
#   Original train size = 32980, Test size = 8264
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 20] Stratification Check:
#     Overall SL rate: 0.0238
#     Train SL rate:   0.0201 (diff: 0.0037)
#     Test SL rate:    0.0357 (diff: 0.0119)
#     Train/Test diff: 0.0156
# Stratification OK
#   ROC AUC = 0.8377, Elapsed time = 717.78 seconds
# Fold 21:
#   Original train size = 32961, Test size = 8283
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 21] Stratification Check:
#     Overall SL rate: 0.0241
#     Train SL rate:   0.0187 (diff: 0.0054)
#     Test SL rate:    0.0413 (diff: 0.0172)
#     Train/Test diff: 0.0226
# Stratification OK
#   ROC AUC = 0.8706, Elapsed time = 750.50 seconds
# Fold 22:
#   Original train size = 33018, Test size = 8226
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 22] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0235 (diff: 0.0004)
#     Test SL rate:    0.0220 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.8798, Elapsed time = 786.75 seconds
# Fold 23:
#   Original train size = 32973, Test size = 8271
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 23] Stratification Check:
#     Overall SL rate: 0.0226
#     Train SL rate:   0.0266 (diff: 0.0040)
#     Test SL rate:    0.0097 (diff: 0.0129)
#     Train/Test diff: 0.0170
# Stratification OK
#   ROC AUC = 0.9554, Elapsed time = 821.75 seconds
# Fold 24:
#   Original train size = 32977, Test size = 8267
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 24] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0228 (diff: 0.0005)
#     Test SL rate:    0.0249 (diff: 0.0016)
#     Train/Test diff: 0.0021
# Stratification OK
#   ROC AUC = 0.8904, Elapsed time = 857.01 seconds
# Fold 25:
#   Original train size = 33047, Test size = 8197
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 25] Stratification Check:
#     Overall SL rate: 0.0230
#     Train SL rate:   0.0245 (diff: 0.0015)
#     Test SL rate:    0.0182 (diff: 0.0048)
#     Train/Test diff: 0.0063
# Stratification OK
#   ROC AUC = 0.8971, Elapsed time = 898.41 seconds
# Fold 26:
#   Original train size = 32970, Test size = 8274
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 26] Stratification Check:
#     Overall SL rate: 0.0231
#     Train SL rate:   0.0239 (diff: 0.0008)
#     Test SL rate:    0.0207 (diff: 0.0024)
#     Train/Test diff: 0.0032
# Stratification OK
#   ROC AUC = 0.8820, Elapsed time = 936.08 seconds
# Fold 27:
#   Original train size = 33025, Test size = 8219
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 27] Stratification Check:
#     Overall SL rate: 0.0234
#     Train SL rate:   0.0225 (diff: 0.0009)
#     Test SL rate:    0.0263 (diff: 0.0029)
#     Train/Test diff: 0.0038
# Stratification OK
#   ROC AUC = 0.8844, Elapsed time = 970.81 seconds
# Fold 28:
#   Original train size = 33028, Test size = 8216
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 28] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0231 (diff: 0.0002)
#     Test SL rate:    0.0239 (diff: 0.0006)
#     Train/Test diff: 0.0008
# Stratification OK
#   ROC AUC = 0.9455, Elapsed time = 1004.73 seconds
# Fold 29:
#   Original train size = 32973, Test size = 8271
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 29] Stratification Check:
#     Overall SL rate: 0.0226
#     Train SL rate:   0.0266 (diff: 0.0040)
#     Test SL rate:    0.0097 (diff: 0.0129)
#     Train/Test diff: 0.0170
# Stratification OK
#   ROC AUC = 0.9554, Elapsed time = 1039.50 seconds
# Fold 30:
#   Original train size = 32980, Test size = 8264
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 30] Stratification Check:
#     Overall SL rate: 0.0238
#     Train SL rate:   0.0201 (diff: 0.0037)
#     Test SL rate:    0.0357 (diff: 0.0119)
#     Train/Test diff: 0.0156
# Stratification OK
#   ROC AUC = 0.8377, Elapsed time = 1072.77 seconds
# Fold 31:
#   Original train size = 32979, Test size = 8265
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 31] Stratification Check:
#     Overall SL rate: 0.0229
#     Train SL rate:   0.0247 (diff: 0.0018)
#     Test SL rate:    0.0172 (diff: 0.0058)
#     Train/Test diff: 0.0076
# Stratification OK
#   ROC AUC = 0.9022, Elapsed time = 1106.79 seconds
# Fold 32:
#   Original train size = 33045, Test size = 8199
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 32] Stratification Check:
#     Overall SL rate: 0.0234
#     Train SL rate:   0.0223 (diff: 0.0011)
#     Test SL rate:    0.0268 (diff: 0.0034)
#     Train/Test diff: 0.0045
# Stratification OK
#   ROC AUC = 0.8778, Elapsed time = 1147.12 seconds
# Fold 33:
#   Original train size = 32978, Test size = 8266
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 33] Stratification Check:
#     Overall SL rate: 0.0236
#     Train SL rate:   0.0213 (diff: 0.0023)
#     Test SL rate:    0.0311 (diff: 0.0075)
#     Train/Test diff: 0.0098
# Stratification OK
#   ROC AUC = 0.9183, Elapsed time = 1194.90 seconds
# Fold 34:
#   Original train size = 32954, Test size = 8290
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 34] Stratification Check:
#     Overall SL rate: 0.0234
#     Train SL rate:   0.0221 (diff: 0.0013)
#     Test SL rate:    0.0276 (diff: 0.0042)
#     Train/Test diff: 0.0055
# Stratification OK
#   ROC AUC = 0.8575, Elapsed time = 1253.58 seconds
# Fold 35:
#   Original train size = 33020, Test size = 8224
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 35] Stratification Check:
#     Overall SL rate: 0.0228
#     Train SL rate:   0.0257 (diff: 0.0029)
#     Test SL rate:    0.0134 (diff: 0.0094)
#     Train/Test diff: 0.0123
# Stratification OK
#   ROC AUC = 0.9146, Elapsed time = 1314.07 seconds
# Fold 36:
#   Original train size = 32980, Test size = 8264
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 36] Stratification Check:
#     Overall SL rate: 0.0238
#     Train SL rate:   0.0201 (diff: 0.0037)
#     Test SL rate:    0.0357 (diff: 0.0119)
#     Train/Test diff: 0.0156
# Stratification OK
#   ROC AUC = 0.8377, Elapsed time = 1355.25 seconds
# Fold 37:
#   Original train size = 32978, Test size = 8266
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 37] Stratification Check:
#     Overall SL rate: 0.0236
#     Train SL rate:   0.0213 (diff: 0.0023)
#     Test SL rate:    0.0311 (diff: 0.0075)
#     Train/Test diff: 0.0098
# Stratification OK
#   ROC AUC = 0.9183, Elapsed time = 1412.53 seconds
# Fold 38:
#   Original train size = 33025, Test size = 8219
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 38] Stratification Check:
#     Overall SL rate: 0.0234
#     Train SL rate:   0.0225 (diff: 0.0009)
#     Test SL rate:    0.0263 (diff: 0.0029)
#     Train/Test diff: 0.0038
# Stratification OK
#   ROC AUC = 0.8844, Elapsed time = 1461.18 seconds
# Fold 39:
#   Original train size = 33034, Test size = 8210
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 39] Stratification Check:
#     Overall SL rate: 0.0225
#     Train SL rate:   0.0272 (diff: 0.0047)
#     Test SL rate:    0.0072 (diff: 0.0153)
#     Train/Test diff: 0.0200
# Stratification OK
#   ROC AUC = 0.9687, Elapsed time = 1522.82 seconds
# Fold 40:
#   Original train size = 32959, Test size = 8285
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 40] Stratification Check:
#     Overall SL rate: 0.0229
#     Train SL rate:   0.0251 (diff: 0.0022)
#     Test SL rate:    0.0158 (diff: 0.0071)
#     Train/Test diff: 0.0093
# Stratification OK
#   ROC AUC = 0.9030, Elapsed time = 1562.74 seconds
# Fold 41:
#   Original train size = 33027, Test size = 8217
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 41] Stratification Check:
#     Overall SL rate: 0.0230
#     Train SL rate:   0.0246 (diff: 0.0017)
#     Test SL rate:    0.0176 (diff: 0.0053)
#     Train/Test diff: 0.0070
# Stratification OK
#   ROC AUC = 0.9092, Elapsed time = 1607.31 seconds
# Fold 42:
#   Original train size = 33019, Test size = 8225
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 42] Stratification Check:
#     Overall SL rate: 0.0230
#     Train SL rate:   0.0244 (diff: 0.0013)
#     Test SL rate:    0.0187 (diff: 0.0043)
#     Train/Test diff: 0.0056
# Stratification OK
#   ROC AUC = 0.9101, Elapsed time = 1652.84 seconds
# Fold 43:
#   Original train size = 32967, Test size = 8277
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 43] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0228 (diff: 0.0005)
#     Test SL rate:    0.0248 (diff: 0.0015)
#     Train/Test diff: 0.0019
# Stratification OK
#   ROC AUC = 0.8493, Elapsed time = 1692.33 seconds
# Fold 44:
#   Original train size = 32985, Test size = 8259
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 44] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0231 (diff: 0.0002)
#     Test SL rate:    0.0239 (diff: 0.0006)
#     Train/Test diff: 0.0008
# Stratification OK
#   ROC AUC = 0.8721, Elapsed time = 1733.43 seconds
# Fold 45:
#   Original train size = 32978, Test size = 8266
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 45] Stratification Check:
#     Overall SL rate: 0.0236
#     Train SL rate:   0.0213 (diff: 0.0023)
#     Test SL rate:    0.0311 (diff: 0.0075)
#     Train/Test diff: 0.0098
# Stratification OK
#   ROC AUC = 0.9183, Elapsed time = 1769.97 seconds
# Fold 46:
#   Original train size = 33080, Test size = 8164
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 46] Stratification Check:
#     Overall SL rate: 0.0229
#     Train SL rate:   0.0249 (diff: 0.0020)
#     Test SL rate:    0.0163 (diff: 0.0066)
#     Train/Test diff: 0.0086
# Stratification OK
#   ROC AUC = 0.9080, Elapsed time = 1804.61 seconds
# Fold 47:
#   Original train size = 32997, Test size = 8247
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 47] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0227 (diff: 0.0007)
#     Test SL rate:    0.0255 (diff: 0.0021)
#     Train/Test diff: 0.0028
# Stratification OK
#   ROC AUC = 0.8773, Elapsed time = 1840.04 seconds
# Fold 48:
#   Original train size = 32973, Test size = 8271
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 48] Stratification Check:
#     Overall SL rate: 0.0237
#     Train SL rate:   0.0206 (diff: 0.0031)
#     Test SL rate:    0.0337 (diff: 0.0100)
#     Train/Test diff: 0.0131
# Stratification OK
#   ROC AUC = 0.9229, Elapsed time = 1874.62 seconds
# Fold 49:
#   Original train size = 32973, Test size = 8271
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 49] Stratification Check:
#     Overall SL rate: 0.0226
#     Train SL rate:   0.0266 (diff: 0.0040)
#     Test SL rate:    0.0097 (diff: 0.0129)
#     Train/Test diff: 0.0170
# Stratification OK
#   ROC AUC = 0.9554, Elapsed time = 1910.62 seconds
# Fold 50:
#   Original train size = 32953, Test size = 8291
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_early_reduced - Fold 50] Stratification Check:
#     Overall SL rate: 0.0236
#     Train SL rate:   0.0213 (diff: 0.0023)
#     Test SL rate:    0.0309 (diff: 0.0073)
#     Train/Test diff: 0.0096
# Stratification OK
#   ROC AUC = 0.8380, Elapsed time = 1962.19 seconds
#
# === Model_II_early_reduced Summary ===
# Mean ROC AUC = 0.8974 ± 0.0339
# Successful folds: 50/50
# Stratification quality:
#   Mean train deviation: 0.0021 ± 0.0013
#   Mean test deviation:  0.0067 ± 0.0043

# %%
model_II_full_reduced = model_full_cross_validation(
    classifier=RF,
    data=training_df[feature_columns_2],  
    target=training_df[target_column],
    splits=repeated_splits_II,
    model_name="Model_II_full_reduced",
    downsample_train_to=26_400,
    downsample_random_state=42,
    verbose=True
)
# Out:
# [DEBUG] model_late_cross_validation v2 — downsample=26400
#
# === Model_II_late_reduced - Fold 1/50 ===
#   Original train size = 32973, Test size = 8271
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 1] Stratification Check:
#     Overall SL rate: 0.0226
#     Train SL rate:   0.0266 (diff: 0.0040)
#     Test SL rate:    0.0097 (diff: 0.0129)
#     Train/Test diff: 0.0170
# Stratification OK
#   ROC AUC = 0.9660, Elapsed time = 63.88 seconds
#
# === Model_II_late_reduced - Fold 2/50 ===
#   Original train size = 32978, Test size = 8266
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 2] Stratification Check:
#     Overall SL rate: 0.0236
#     Train SL rate:   0.0213 (diff: 0.0023)
#     Test SL rate:    0.0311 (diff: 0.0075)
#     Train/Test diff: 0.0098
# Stratification OK
#   ROC AUC = 0.9323, Elapsed time = 116.17 seconds
#
# === Model_II_late_reduced - Fold 3/50 ===
#   Original train size = 33018, Test size = 8226
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 3] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0235 (diff: 0.0004)
#     Test SL rate:    0.0220 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.9044, Elapsed time = 174.22 seconds
#
# === Model_II_late_reduced - Fold 4/50 ===
#   Original train size = 32992, Test size = 8252
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 4] Stratification Check:
#     Overall SL rate: 0.0235
#     Train SL rate:   0.0220 (diff: 0.0015)
#     Test SL rate:    0.0281 (diff: 0.0047)
#     Train/Test diff: 0.0061
# Stratification OK
#   ROC AUC = 0.9063, Elapsed time = 231.98 seconds
#
# === Model_II_late_reduced - Fold 5/50 ===
#   Original train size = 33015, Test size = 8229
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 5] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0227 (diff: 0.0006)
#     Test SL rate:    0.0253 (diff: 0.0019)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.8716, Elapsed time = 281.81 seconds
#
# === Model_II_late_reduced - Fold 6/50 ===
#   Original train size = 33032, Test size = 8212
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 6] Stratification Check:
#     Overall SL rate: 0.0229
#     Train SL rate:   0.0251 (diff: 0.0022)
#     Test SL rate:    0.0158 (diff: 0.0071)
#     Train/Test diff: 0.0092
# Stratification OK
#   ROC AUC = 0.9229, Elapsed time = 334.01 seconds
#
# === Model_II_late_reduced - Fold 7/50 ===
#   Original train size = 33032, Test size = 8212
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 7] Stratification Check:
#     Overall SL rate: 0.0228
#     Train SL rate:   0.0253 (diff: 0.0024)
#     Test SL rate:    0.0150 (diff: 0.0078)
#     Train/Test diff: 0.0103
# Stratification OK
#   ROC AUC = 0.9347, Elapsed time = 386.79 seconds
#
# === Model_II_late_reduced - Fold 8/50 ===
#   Original train size = 32954, Test size = 8290
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 8] Stratification Check:
#     Overall SL rate: 0.0234
#     Train SL rate:   0.0221 (diff: 0.0013)
#     Test SL rate:    0.0276 (diff: 0.0042)
#     Train/Test diff: 0.0055
# Stratification OK
#   ROC AUC = 0.8762, Elapsed time = 441.07 seconds
#
# === Model_II_late_reduced - Fold 9/50 ===
#   Original train size = 32993, Test size = 8251
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 9] Stratification Check:
#     Overall SL rate: 0.0238
#     Train SL rate:   0.0205 (diff: 0.0033)
#     Test SL rate:    0.0343 (diff: 0.0105)
#     Train/Test diff: 0.0138
# Stratification OK
#   ROC AUC = 0.9257, Elapsed time = 502.08 seconds
#
# === Model_II_late_reduced - Fold 10/50 ===
#   Original train size = 32965, Test size = 8279
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 10] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9041, Elapsed time = 557.38 seconds
#
# === Model_II_late_reduced - Fold 11/50 ===
#   Original train size = 32973, Test size = 8271
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 11] Stratification Check:
#     Overall SL rate: 0.0226
#     Train SL rate:   0.0266 (diff: 0.0040)
#     Test SL rate:    0.0097 (diff: 0.0129)
#     Train/Test diff: 0.0170
# Stratification OK
#   ROC AUC = 0.9660, Elapsed time = 615.88 seconds
#
# === Model_II_late_reduced - Fold 12/50 ===
#   Original train size = 33013, Test size = 8231
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 12] Stratification Check:
#     Overall SL rate: 0.0237
#     Train SL rate:   0.0206 (diff: 0.0032)
#     Test SL rate:    0.0339 (diff: 0.0102)
#     Train/Test diff: 0.0133
# Stratification OK
#   ROC AUC = 0.8663, Elapsed time = 671.38 seconds
#
# === Model_II_late_reduced - Fold 13/50 ===
#   Original train size = 32993, Test size = 8251
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 13] Stratification Check:
#     Overall SL rate: 0.0238
#     Train SL rate:   0.0205 (diff: 0.0033)
#     Test SL rate:    0.0343 (diff: 0.0105)
#     Train/Test diff: 0.0138
# Stratification OK
#   ROC AUC = 0.9257, Elapsed time = 728.84 seconds
#
# === Model_II_late_reduced - Fold 14/50 ===
#   Original train size = 32970, Test size = 8274
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 14] Stratification Check:
#     Overall SL rate: 0.0231
#     Train SL rate:   0.0239 (diff: 0.0008)
#     Test SL rate:    0.0207 (diff: 0.0024)
#     Train/Test diff: 0.0032
# Stratification OK
#   ROC AUC = 0.8937, Elapsed time = 793.22 seconds
#
# === Model_II_late_reduced - Fold 15/50 ===
#   Original train size = 33027, Test size = 8217
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 15] Stratification Check:
#     Overall SL rate: 0.0230
#     Train SL rate:   0.0246 (diff: 0.0017)
#     Test SL rate:    0.0176 (diff: 0.0053)
#     Train/Test diff: 0.0070
# Stratification OK
#   ROC AUC = 0.9218, Elapsed time = 852.72 seconds
#
# === Model_II_late_reduced - Fold 16/50 ===
#   Original train size = 32979, Test size = 8265
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 16] Stratification Check:
#     Overall SL rate: 0.0229
#     Train SL rate:   0.0247 (diff: 0.0018)
#     Test SL rate:    0.0172 (diff: 0.0058)
#     Train/Test diff: 0.0076
# Stratification OK
#   ROC AUC = 0.9146, Elapsed time = 918.07 seconds
#
# === Model_II_late_reduced - Fold 17/50 ===
#   Original train size = 33080, Test size = 8164
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 17] Stratification Check:
#     Overall SL rate: 0.0229
#     Train SL rate:   0.0249 (diff: 0.0020)
#     Test SL rate:    0.0163 (diff: 0.0066)
#     Train/Test diff: 0.0086
# Stratification OK
#   ROC AUC = 0.9275, Elapsed time = 990.06 seconds
#
# === Model_II_late_reduced - Fold 18/50 ===
#   Original train size = 32971, Test size = 8273
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 18] Stratification Check:
#     Overall SL rate: 0.0230
#     Train SL rate:   0.0247 (diff: 0.0017)
#     Test SL rate:    0.0174 (diff: 0.0056)
#     Train/Test diff: 0.0073
# Stratification OK
#   ROC AUC = 0.9321, Elapsed time = 1045.07 seconds
#
# === Model_II_late_reduced - Fold 19/50 ===
#   Original train size = 32966, Test size = 8278
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 19] Stratification Check:
#     Overall SL rate: 0.0235
#     Train SL rate:   0.0217 (diff: 0.0019)
#     Test SL rate:    0.0295 (diff: 0.0059)
#     Train/Test diff: 0.0078
# Stratification OK
#   ROC AUC = 0.9321, Elapsed time = 1100.62 seconds
#
# === Model_II_late_reduced - Fold 20/50 ===
#   Original train size = 32980, Test size = 8264
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 20] Stratification Check:
#     Overall SL rate: 0.0238
#     Train SL rate:   0.0201 (diff: 0.0037)
#     Test SL rate:    0.0357 (diff: 0.0119)
#     Train/Test diff: 0.0156
# Stratification OK
#   ROC AUC = 0.8582, Elapsed time = 1154.34 seconds
#
# === Model_II_late_reduced - Fold 21/50 ===
#   Original train size = 32961, Test size = 8283
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 21] Stratification Check:
#     Overall SL rate: 0.0241
#     Train SL rate:   0.0187 (diff: 0.0054)
#     Test SL rate:    0.0413 (diff: 0.0172)
#     Train/Test diff: 0.0226
# Stratification OK
#   ROC AUC = 0.8896, Elapsed time = 1208.28 seconds
#
# === Model_II_late_reduced - Fold 22/50 ===
#   Original train size = 33018, Test size = 8226
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 22] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0235 (diff: 0.0004)
#     Test SL rate:    0.0220 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.9044, Elapsed time = 1269.48 seconds
#
# === Model_II_late_reduced - Fold 23/50 ===
#   Original train size = 32973, Test size = 8271
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 23] Stratification Check:
#     Overall SL rate: 0.0226
#     Train SL rate:   0.0266 (diff: 0.0040)
#     Test SL rate:    0.0097 (diff: 0.0129)
#     Train/Test diff: 0.0170
# Stratification OK
#   ROC AUC = 0.9660, Elapsed time = 1327.70 seconds
#
# === Model_II_late_reduced - Fold 24/50 ===
#   Original train size = 32977, Test size = 8267
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 24] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0228 (diff: 0.0005)
#     Test SL rate:    0.0249 (diff: 0.0016)
#     Train/Test diff: 0.0021
# Stratification OK
#   ROC AUC = 0.8998, Elapsed time = 1380.19 seconds
#
# === Model_II_late_reduced - Fold 25/50 ===
#   Original train size = 33047, Test size = 8197
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 25] Stratification Check:
#     Overall SL rate: 0.0230
#     Train SL rate:   0.0245 (diff: 0.0015)
#     Test SL rate:    0.0182 (diff: 0.0048)
#     Train/Test diff: 0.0063
# Stratification OK
#   ROC AUC = 0.9237, Elapsed time = 1434.19 seconds
#
# === Model_II_late_reduced - Fold 26/50 ===
#   Original train size = 32970, Test size = 8274
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 26] Stratification Check:
#     Overall SL rate: 0.0231
#     Train SL rate:   0.0239 (diff: 0.0008)
#     Test SL rate:    0.0207 (diff: 0.0024)
#     Train/Test diff: 0.0032
# Stratification OK
#   ROC AUC = 0.8937, Elapsed time = 1491.53 seconds
#
# === Model_II_late_reduced - Fold 27/50 ===
#   Original train size = 33025, Test size = 8219
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 27] Stratification Check:
#     Overall SL rate: 0.0234
#     Train SL rate:   0.0225 (diff: 0.0009)
#     Test SL rate:    0.0263 (diff: 0.0029)
#     Train/Test diff: 0.0038
# Stratification OK
#   ROC AUC = 0.9061, Elapsed time = 1543.61 seconds
#
# === Model_II_late_reduced - Fold 28/50 ===
#   Original train size = 33028, Test size = 8216
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 28] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0231 (diff: 0.0002)
#     Test SL rate:    0.0239 (diff: 0.0006)
#     Train/Test diff: 0.0008
# Stratification OK
#   ROC AUC = 0.9588, Elapsed time = 1595.81 seconds
#
# === Model_II_late_reduced - Fold 29/50 ===
#   Original train size = 32973, Test size = 8271
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 29] Stratification Check:
#     Overall SL rate: 0.0226
#     Train SL rate:   0.0266 (diff: 0.0040)
#     Test SL rate:    0.0097 (diff: 0.0129)
#     Train/Test diff: 0.0170
# Stratification OK
#   ROC AUC = 0.9660, Elapsed time = 1648.99 seconds
#
# === Model_II_late_reduced - Fold 30/50 ===
#   Original train size = 32980, Test size = 8264
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 30] Stratification Check:
#     Overall SL rate: 0.0238
#     Train SL rate:   0.0201 (diff: 0.0037)
#     Test SL rate:    0.0357 (diff: 0.0119)
#     Train/Test diff: 0.0156
# Stratification OK
#   ROC AUC = 0.8582, Elapsed time = 1697.58 seconds
#
# === Model_II_late_reduced - Fold 31/50 ===
#   Original train size = 32979, Test size = 8265
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 31] Stratification Check:
#     Overall SL rate: 0.0229
#     Train SL rate:   0.0247 (diff: 0.0018)
#     Test SL rate:    0.0172 (diff: 0.0058)
#     Train/Test diff: 0.0076
# Stratification OK
#   ROC AUC = 0.9146, Elapsed time = 1750.29 seconds
#
# === Model_II_late_reduced - Fold 32/50 ===
#   Original train size = 33045, Test size = 8199
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 32] Stratification Check:
#     Overall SL rate: 0.0234
#     Train SL rate:   0.0223 (diff: 0.0011)
#     Test SL rate:    0.0268 (diff: 0.0034)
#     Train/Test diff: 0.0045
# Stratification OK
#   ROC AUC = 0.9031, Elapsed time = 1804.34 seconds
#
# === Model_II_late_reduced - Fold 33/50 ===
#   Original train size = 32978, Test size = 8266
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 33] Stratification Check:
#     Overall SL rate: 0.0236
#     Train SL rate:   0.0213 (diff: 0.0023)
#     Test SL rate:    0.0311 (diff: 0.0075)
#     Train/Test diff: 0.0098
# Stratification OK
#   ROC AUC = 0.9323, Elapsed time = 1860.81 seconds
#
# === Model_II_late_reduced - Fold 34/50 ===
#   Original train size = 32954, Test size = 8290
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 34] Stratification Check:
#     Overall SL rate: 0.0234
#     Train SL rate:   0.0221 (diff: 0.0013)
#     Test SL rate:    0.0276 (diff: 0.0042)
#     Train/Test diff: 0.0055
# Stratification OK
#   ROC AUC = 0.8762, Elapsed time = 1925.40 seconds
#
# === Model_II_late_reduced - Fold 35/50 ===
#   Original train size = 33020, Test size = 8224
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 35] Stratification Check:
#     Overall SL rate: 0.0228
#     Train SL rate:   0.0257 (diff: 0.0029)
#     Test SL rate:    0.0134 (diff: 0.0094)
#     Train/Test diff: 0.0123
# Stratification OK
#   ROC AUC = 0.9255, Elapsed time = 2026.98 seconds
#
# === Model_II_late_reduced - Fold 36/50 ===
#   Original train size = 32980, Test size = 8264
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 36] Stratification Check:
#     Overall SL rate: 0.0238
#     Train SL rate:   0.0201 (diff: 0.0037)
#     Test SL rate:    0.0357 (diff: 0.0119)
#     Train/Test diff: 0.0156
# Stratification OK
#   ROC AUC = 0.8582, Elapsed time = 2081.56 seconds
#
# === Model_II_late_reduced - Fold 37/50 ===
#   Original train size = 32978, Test size = 8266
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 37] Stratification Check:
#     Overall SL rate: 0.0236
#     Train SL rate:   0.0213 (diff: 0.0023)
#     Test SL rate:    0.0311 (diff: 0.0075)
#     Train/Test diff: 0.0098
# Stratification OK
#   ROC AUC = 0.9323, Elapsed time = 2135.63 seconds
#
# === Model_II_late_reduced - Fold 38/50 ===
#   Original train size = 33025, Test size = 8219
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 38] Stratification Check:
#     Overall SL rate: 0.0234
#     Train SL rate:   0.0225 (diff: 0.0009)
#     Test SL rate:    0.0263 (diff: 0.0029)
#     Train/Test diff: 0.0038
# Stratification OK
#   ROC AUC = 0.9061, Elapsed time = 2195.64 seconds
#
# === Model_II_late_reduced - Fold 39/50 ===
#   Original train size = 33034, Test size = 8210
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 39] Stratification Check:
#     Overall SL rate: 0.0225
#     Train SL rate:   0.0272 (diff: 0.0047)
#     Test SL rate:    0.0072 (diff: 0.0153)
#     Train/Test diff: 0.0200
# Stratification OK
#   ROC AUC = 0.9746, Elapsed time = 2252.68 seconds
#
# === Model_II_late_reduced - Fold 40/50 ===
#   Original train size = 32959, Test size = 8285
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 40] Stratification Check:
#     Overall SL rate: 0.0229
#     Train SL rate:   0.0251 (diff: 0.0022)
#     Test SL rate:    0.0158 (diff: 0.0071)
#     Train/Test diff: 0.0093
# Stratification OK
#   ROC AUC = 0.9238, Elapsed time = 2310.17 seconds
#
# === Model_II_late_reduced - Fold 41/50 ===
#   Original train size = 33027, Test size = 8217
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 41] Stratification Check:
#     Overall SL rate: 0.0230
#     Train SL rate:   0.0246 (diff: 0.0017)
#     Test SL rate:    0.0176 (diff: 0.0053)
#     Train/Test diff: 0.0070
# Stratification OK
#   ROC AUC = 0.9218, Elapsed time = 2364.85 seconds
#
# === Model_II_late_reduced - Fold 42/50 ===
#   Original train size = 33019, Test size = 8225
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 42] Stratification Check:
#     Overall SL rate: 0.0230
#     Train SL rate:   0.0244 (diff: 0.0013)
#     Test SL rate:    0.0187 (diff: 0.0043)
#     Train/Test diff: 0.0056
# Stratification OK
#   ROC AUC = 0.9286, Elapsed time = 2419.29 seconds
#
# === Model_II_late_reduced - Fold 43/50 ===
#   Original train size = 32967, Test size = 8277
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 43] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0228 (diff: 0.0005)
#     Test SL rate:    0.0248 (diff: 0.0015)
#     Train/Test diff: 0.0019
# Stratification OK
#   ROC AUC = 0.8571, Elapsed time = 2472.87 seconds
#
# === Model_II_late_reduced - Fold 44/50 ===
#   Original train size = 32985, Test size = 8259
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 44] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0231 (diff: 0.0002)
#     Test SL rate:    0.0239 (diff: 0.0006)
#     Train/Test diff: 0.0008
# Stratification OK
#   ROC AUC = 0.8992, Elapsed time = 2533.13 seconds
#
# === Model_II_late_reduced - Fold 45/50 ===
#   Original train size = 32978, Test size = 8266
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 45] Stratification Check:
#     Overall SL rate: 0.0236
#     Train SL rate:   0.0213 (diff: 0.0023)
#     Test SL rate:    0.0311 (diff: 0.0075)
#     Train/Test diff: 0.0098
# Stratification OK
#   ROC AUC = 0.9323, Elapsed time = 2585.53 seconds
#
# === Model_II_late_reduced - Fold 46/50 ===
#   Original train size = 33080, Test size = 8164
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 46] Stratification Check:
#     Overall SL rate: 0.0229
#     Train SL rate:   0.0249 (diff: 0.0020)
#     Test SL rate:    0.0163 (diff: 0.0066)
#     Train/Test diff: 0.0086
# Stratification OK
#   ROC AUC = 0.9275, Elapsed time = 2636.76 seconds
#
# === Model_II_late_reduced - Fold 47/50 ===
#   Original train size = 32997, Test size = 8247
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 47] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0227 (diff: 0.0007)
#     Test SL rate:    0.0255 (diff: 0.0021)
#     Train/Test diff: 0.0028
# Stratification OK
#   ROC AUC = 0.9024, Elapsed time = 2688.37 seconds
#
# === Model_II_late_reduced - Fold 48/50 ===
#   Original train size = 32973, Test size = 8271
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 48] Stratification Check:
#     Overall SL rate: 0.0237
#     Train SL rate:   0.0206 (diff: 0.0031)
#     Test SL rate:    0.0337 (diff: 0.0100)
#     Train/Test diff: 0.0131
# Stratification OK
#   ROC AUC = 0.9314, Elapsed time = 2737.69 seconds
#
# === Model_II_late_reduced - Fold 49/50 ===
#   Original train size = 32973, Test size = 8271
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 49] Stratification Check:
#     Overall SL rate: 0.0226
#     Train SL rate:   0.0266 (diff: 0.0040)
#     Test SL rate:    0.0097 (diff: 0.0129)
#     Train/Test diff: 0.0170
# Stratification OK
#   ROC AUC = 0.9660, Elapsed time = 2789.24 seconds
#
# === Model_II_late_reduced - Fold 50/50 ===
#   Original train size = 32953, Test size = 8291
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_II_late_reduced - Fold 50] Stratification Check:
#     Overall SL rate: 0.0236
#     Train SL rate:   0.0213 (diff: 0.0023)
#     Test SL rate:    0.0309 (diff: 0.0073)
#     Train/Test diff: 0.0096
# Stratification OK
#   ROC AUC = 0.8592, Elapsed time = 2841.60 seconds
#
# === Model_II_late_reduced Summary ===
# Mean ROC AUC = 0.9138 ± 0.0311
# Successful folds: 50/50
# Stratification quality:
#   Mean train deviation: 0.0021 ± 0.0013
#   Mean test deviation:  0.0067 ± 0.0043

# %%
# save results of cross validation
with open(file_RF_model_II_contextualised_reduced, 'wb') as f:
    pickle.dump(model_II_contextualised_reduced, f)

with open(file_RF_model_II_full_reduced, 'wb') as f:
    pickle.dump(model_II_full_reduced, f)

# %% [markdown]
# ## Model III
# #### Different paralog pairs, same cell lines

# %%
# Read splits
with open('/Users/narod/Library/CloudStorage/GoogleDrive-narod.kebabci@ucdconnect.ie/My Drive/GitRepos/context_specific_SL_prediction/output/models/model_III/repeated_splits_III.pkl', 'rb') as f:
    repeated_splits_III = pickle.load(f)

# %%
for i, (tr, te) in enumerate(repeated_splits_III, 1):
    train_cells = training_df.loc[tr, 'genepair'].unique()
    test_cells  = training_df.loc[te, 'genepair'].unique()
    validate_group_splits(train_cells, test_cells, i, "Model III", "genepair")
# Out:
#   [Model III - Fold 1] Group Validation:
#     Train genepair: 3337
#     Test genepair:  833
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 2] Group Validation:
#     Train genepair: 3334
#     Test genepair:  836
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 3] Group Validation:
#     Train genepair: 3336
#     Test genepair:  834
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 4] Group Validation:
#     Train genepair: 3336
#     Test genepair:  834
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 5] Group Validation:
#     Train genepair: 3337
#     Test genepair:  833
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 6] Group Validation:
#     Train genepair: 3337
#     Test genepair:  833
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 7] Group Validation:
#     Train genepair: 3333
#     Test genepair:  837
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 8] Group Validation:
#     Train genepair: 3336
#     Test genepair:  834
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 9] Group Validation:
#     Train genepair: 3336
#     Test genepair:  834
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 10] Group Validation:
#     Train genepair: 3338
#     Test genepair:  832
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 11] Group Validation:
#     Train genepair: 3336
#     Test genepair:  834
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 12] Group Validation:
#     Train genepair: 3337
#     Test genepair:  833
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 13] Group Validation:
#     Train genepair: 3338
#     Test genepair:  832
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 14] Group Validation:
#     Train genepair: 3336
#     Test genepair:  834
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 15] Group Validation:
#     Train genepair: 3333
#     Test genepair:  837
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 16] Group Validation:
#     Train genepair: 3337
#     Test genepair:  833
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 17] Group Validation:
#     Train genepair: 3336
#     Test genepair:  834
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 18] Group Validation:
#     Train genepair: 3337
#     Test genepair:  833
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 19] Group Validation:
#     Train genepair: 3339
#     Test genepair:  831
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 20] Group Validation:
#     Train genepair: 3331
#     Test genepair:  839
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 21] Group Validation:
#     Train genepair: 3336
#     Test genepair:  834
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 22] Group Validation:
#     Train genepair: 3333
#     Test genepair:  837
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 23] Group Validation:
#     Train genepair: 3335
#     Test genepair:  835
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 24] Group Validation:
#     Train genepair: 3337
#     Test genepair:  833
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 25] Group Validation:
#     Train genepair: 3339
#     Test genepair:  831
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 26] Group Validation:
#     Train genepair: 3336
#     Test genepair:  834
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 27] Group Validation:
#     Train genepair: 3336
#     Test genepair:  834
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 28] Group Validation:
#     Train genepair: 3335
#     Test genepair:  835
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 29] Group Validation:
#     Train genepair: 3336
#     Test genepair:  834
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 30] Group Validation:
#     Train genepair: 3337
#     Test genepair:  833
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 31] Group Validation:
#     Train genepair: 3332
#     Test genepair:  838
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 32] Group Validation:
#     Train genepair: 3338
#     Test genepair:  832
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 33] Group Validation:
#     Train genepair: 3337
#     Test genepair:  833
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 34] Group Validation:
#     Train genepair: 3338
#     Test genepair:  832
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 35] Group Validation:
#     Train genepair: 3335
#     Test genepair:  835
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 36] Group Validation:
#     Train genepair: 3336
#     Test genepair:  834
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 37] Group Validation:
#     Train genepair: 3333
#     Test genepair:  837
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 38] Group Validation:
#     Train genepair: 3335
#     Test genepair:  835
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 39] Group Validation:
#     Train genepair: 3335
#     Test genepair:  835
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 40] Group Validation:
#     Train genepair: 3341
#     Test genepair:  829
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 41] Group Validation:
#     Train genepair: 3336
#     Test genepair:  834
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 42] Group Validation:
#     Train genepair: 3335
#     Test genepair:  835
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 43] Group Validation:
#     Train genepair: 3335
#     Test genepair:  835
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 44] Group Validation:
#     Train genepair: 3338
#     Test genepair:  832
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 45] Group Validation:
#     Train genepair: 3336
#     Test genepair:  834
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 46] Group Validation:
#     Train genepair: 3338
#     Test genepair:  832
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 47] Group Validation:
#     Train genepair: 3337
#     Test genepair:  833
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 48] Group Validation:
#     Train genepair: 3332
#     Test genepair:  838
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 49] Group Validation:
#     Train genepair: 3337
#     Test genepair:  833
#     Overlapping genepair: 0
# No group leakage
#   [Model III - Fold 50] Group Validation:
#     Train genepair: 3336
#     Test genepair:  834
#     Overlapping genepair: 0
# No group leakage

# %%
#Run cross-validation on both feature set
model_III_contextualised_reduced = model_contextualised_cross_validation(
    classifier=RF,
    data=training_df[feature_columns_1],     
    target=training_df[target_column],
    splits=repeated_splits_III,                
    model_name="Model_III_contextualised_reduced",
    downsample_train_to=26_400,               
    downsample_random_state=42,
    verbose=True
)
# Out:
# [DEBUG] model_early_cross_validation v4 — downsample=26400
# Fold 1:
#   Original train size = 33027, Test size = 8217
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 1] Stratification Check:
#     Overall SL rate: 0.0234
#     Train SL rate:   0.0223 (diff: 0.0011)
#     Test SL rate:    0.0269 (diff: 0.0035)
#     Train/Test diff: 0.0046
# Stratification OK
#   ROC AUC = 0.8733, Elapsed time = 40.77 seconds
# Fold 2:
#   Original train size = 32987, Test size = 8257
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 2] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0002)
#     Test SL rate:    0.0224 (diff: 0.0008)
#     Train/Test diff: 0.0010
# Stratification OK
#   ROC AUC = 0.9057, Elapsed time = 79.34 seconds
# Fold 3:
#   Original train size = 32975, Test size = 8269
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 3] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0003)
#     Test SL rate:    0.0224 (diff: 0.0008)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9080, Elapsed time = 122.18 seconds
# Fold 4:
#   Original train size = 32987, Test size = 8257
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 4] Stratification Check:
#     Overall SL rate: 0.0231
#     Train SL rate:   0.0239 (diff: 0.0008)
#     Test SL rate:    0.0206 (diff: 0.0025)
#     Train/Test diff: 0.0033
# Stratification OK
#   ROC AUC = 0.9139, Elapsed time = 158.51 seconds
# Fold 5:
#   Original train size = 33000, Test size = 8244
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 5] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0231 (diff: 0.0002)
#     Test SL rate:    0.0239 (diff: 0.0006)
#     Train/Test diff: 0.0008
# Stratification OK
#   ROC AUC = 0.9011, Elapsed time = 194.75 seconds
# Fold 6:
#   Original train size = 32999, Test size = 8245
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 6] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0227 (diff: 0.0006)
#     Test SL rate:    0.0252 (diff: 0.0019)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.8878, Elapsed time = 229.27 seconds
# Fold 7:
#   Original train size = 32975, Test size = 8269
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 7] Stratification Check:
#     Overall SL rate: 0.0234
#     Train SL rate:   0.0224 (diff: 0.0010)
#     Test SL rate:    0.0265 (diff: 0.0031)
#     Train/Test diff: 0.0041
# Stratification OK
#   ROC AUC = 0.9293, Elapsed time = 264.04 seconds
# Fold 8:
#   Original train size = 32979, Test size = 8265
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 8] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0001)
#     Test SL rate:    0.0230 (diff: 0.0002)
#     Train/Test diff: 0.0003
# Stratification OK
#   ROC AUC = 0.8967, Elapsed time = 298.90 seconds
# Fold 9:
#   Original train size = 33010, Test size = 8234
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 9] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0001)
#     Test SL rate:    0.0234 (diff: 0.0002)
#     Train/Test diff: 0.0003
# Stratification OK
#   ROC AUC = 0.8993, Elapsed time = 334.77 seconds
# Fold 10:
#   Original train size = 33013, Test size = 8231
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 10] Stratification Check:
#     Overall SL rate: 0.0230
#     Train SL rate:   0.0245 (diff: 0.0016)
#     Test SL rate:    0.0180 (diff: 0.0050)
#     Train/Test diff: 0.0066
# Stratification OK
#   ROC AUC = 0.8845, Elapsed time = 368.62 seconds
# Fold 11:
#   Original train size = 33002, Test size = 8242
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 11] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0237 (diff: 0.0006)
#     Test SL rate:    0.0214 (diff: 0.0018)
#     Train/Test diff: 0.0024
# Stratification OK
#   ROC AUC = 0.9032, Elapsed time = 402.61 seconds
# Fold 12:
#   Original train size = 32987, Test size = 8257
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 12] Stratification Check:
#     Overall SL rate: 0.0234
#     Train SL rate:   0.0225 (diff: 0.0008)
#     Test SL rate:    0.0260 (diff: 0.0027)
#     Train/Test diff: 0.0035
# Stratification OK
#   ROC AUC = 0.8983, Elapsed time = 440.50 seconds
# Fold 13:
#   Original train size = 33005, Test size = 8239
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 13] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0003)
#     Test SL rate:    0.0223 (diff: 0.0008)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9095, Elapsed time = 478.17 seconds
# Fold 14:
#   Original train size = 33014, Test size = 8230
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 14] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0227 (diff: 0.0007)
#     Test SL rate:    0.0255 (diff: 0.0022)
#     Train/Test diff: 0.0029
# Stratification OK
#   ROC AUC = 0.8933, Elapsed time = 515.12 seconds
# Fold 15:
#   Original train size = 32968, Test size = 8276
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 15] Stratification Check:
#     Overall SL rate: 0.0231
#     Train SL rate:   0.0238 (diff: 0.0007)
#     Test SL rate:    0.0209 (diff: 0.0022)
#     Train/Test diff: 0.0029
# Stratification OK
#   ROC AUC = 0.9026, Elapsed time = 551.32 seconds
# Fold 16:
#   Original train size = 33025, Test size = 8219
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 16] Stratification Check:
#     Overall SL rate: 0.0231
#     Train SL rate:   0.0236 (diff: 0.0005)
#     Test SL rate:    0.0215 (diff: 0.0016)
#     Train/Test diff: 0.0021
# Stratification OK
#   ROC AUC = 0.8823, Elapsed time = 588.57 seconds
# Fold 17:
#   Original train size = 33017, Test size = 8227
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 17] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0227 (diff: 0.0006)
#     Test SL rate:    0.0252 (diff: 0.0019)
#     Train/Test diff: 0.0024
# Stratification OK
#   ROC AUC = 0.9080, Elapsed time = 622.70 seconds
# Fold 18:
#   Original train size = 32994, Test size = 8250
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 18] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0230 (diff: 0.0003)
#     Test SL rate:    0.0241 (diff: 0.0009)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.8974, Elapsed time = 659.06 seconds
# Fold 19:
#   Original train size = 33018, Test size = 8226
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 19] Stratification Check:
#     Overall SL rate: 0.0231
#     Train SL rate:   0.0236 (diff: 0.0005)
#     Test SL rate:    0.0215 (diff: 0.0016)
#     Train/Test diff: 0.0021
# Stratification OK
#   ROC AUC = 0.9220, Elapsed time = 696.92 seconds
# Fold 20:
#   Original train size = 32922, Test size = 8322
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 20] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0231 (diff: 0.0002)
#     Test SL rate:    0.0238 (diff: 0.0006)
#     Train/Test diff: 0.0007
# Stratification OK
#   ROC AUC = 0.8883, Elapsed time = 736.57 seconds
# Fold 21:
#   Original train size = 32982, Test size = 8262
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 21] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0227 (diff: 0.0006)
#     Test SL rate:    0.0253 (diff: 0.0020)
#     Train/Test diff: 0.0026
# Stratification OK
#   ROC AUC = 0.8832, Elapsed time = 776.00 seconds
# Fold 22:
#   Original train size = 32974, Test size = 8270
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 22] Stratification Check:
#     Overall SL rate: 0.0235
#     Train SL rate:   0.0217 (diff: 0.0018)
#     Test SL rate:    0.0291 (diff: 0.0056)
#     Train/Test diff: 0.0074
# Stratification OK
#   ROC AUC = 0.8845, Elapsed time = 814.76 seconds
# Fold 23:
#   Original train size = 32973, Test size = 8271
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 23] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0003)
#     Test SL rate:    0.0224 (diff: 0.0008)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9255, Elapsed time = 855.66 seconds
# Fold 24:
#   Original train size = 33012, Test size = 8232
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 24] Stratification Check:
#     Overall SL rate: 0.0231
#     Train SL rate:   0.0239 (diff: 0.0008)
#     Test SL rate:    0.0205 (diff: 0.0026)
#     Train/Test diff: 0.0034
# Stratification OK
#   ROC AUC = 0.9090, Elapsed time = 896.30 seconds
# Fold 25:
#   Original train size = 33035, Test size = 8209
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 25] Stratification Check:
#     Overall SL rate: 0.0230
#     Train SL rate:   0.0244 (diff: 0.0013)
#     Test SL rate:    0.0188 (diff: 0.0043)
#     Train/Test diff: 0.0056
# Stratification OK
#   ROC AUC = 0.9043, Elapsed time = 932.21 seconds
# Fold 26:
#   Original train size = 32977, Test size = 8267
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 26] Stratification Check:
#     Overall SL rate: 0.0231
#     Train SL rate:   0.0239 (diff: 0.0008)
#     Test SL rate:    0.0207 (diff: 0.0024)
#     Train/Test diff: 0.0032
# Stratification OK
#   ROC AUC = 0.9041, Elapsed time = 970.70 seconds
# Fold 27:
#   Original train size = 32993, Test size = 8251
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 27] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0230 (diff: 0.0002)
#     Test SL rate:    0.0240 (diff: 0.0007)
#     Train/Test diff: 0.0010
# Stratification OK
#   ROC AUC = 0.8982, Elapsed time = 1008.07 seconds
# Fold 28:
#   Original train size = 33001, Test size = 8243
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 28] Stratification Check:
#     Overall SL rate: 0.0234
#     Train SL rate:   0.0224 (diff: 0.0010)
#     Test SL rate:    0.0264 (diff: 0.0031)
#     Train/Test diff: 0.0040
# Stratification OK
#   ROC AUC = 0.8758, Elapsed time = 1044.33 seconds
# Fold 29:
#   Original train size = 33012, Test size = 8232
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 29] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0003)
#     Test SL rate:    0.0224 (diff: 0.0008)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9031, Elapsed time = 1082.56 seconds
# Fold 30:
#   Original train size = 32993, Test size = 8251
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 30] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0002)
#     Test SL rate:    0.0227 (diff: 0.0005)
#     Train/Test diff: 0.0007
# Stratification OK
#   ROC AUC = 0.9127, Elapsed time = 1119.67 seconds
# Fold 31:
#   Original train size = 32941, Test size = 8303
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 31] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0236 (diff: 0.0004)
#     Test SL rate:    0.0219 (diff: 0.0012)
#     Train/Test diff: 0.0016
# Stratification OK
#   ROC AUC = 0.8904, Elapsed time = 1155.73 seconds
# Fold 32:
#   Original train size = 33029, Test size = 8215
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 32] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0227 (diff: 0.0006)
#     Test SL rate:    0.0252 (diff: 0.0019)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9082, Elapsed time = 1191.83 seconds
# Fold 33:
#   Original train size = 32996, Test size = 8248
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 33] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0002)
#     Test SL rate:    0.0227 (diff: 0.0005)
#     Train/Test diff: 0.0007
# Stratification OK
#   ROC AUC = 0.9129, Elapsed time = 1228.90 seconds
# Fold 34:
#   Original train size = 33023, Test size = 8221
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 34] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0001)
#     Test SL rate:    0.0230 (diff: 0.0002)
#     Train/Test diff: 0.0003
# Stratification OK
#   ROC AUC = 0.8929, Elapsed time = 1265.87 seconds
# Fold 35:
#   Original train size = 32987, Test size = 8257
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 35] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0234 (diff: 0.0001)
#     Train/Test diff: 0.0002
# Stratification OK
#   ROC AUC = 0.9159, Elapsed time = 1302.03 seconds
# Fold 36:
#   Original train size = 32996, Test size = 8248
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 36] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0230 (diff: 0.0003)
#     Test SL rate:    0.0241 (diff: 0.0009)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.8783, Elapsed time = 1337.15 seconds
# Fold 37:
#   Original train size = 32979, Test size = 8265
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 37] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0227 (diff: 0.0006)
#     Test SL rate:    0.0252 (diff: 0.0019)
#     Train/Test diff: 0.0024
# Stratification OK
#   ROC AUC = 0.8994, Elapsed time = 1372.50 seconds
# Fold 38:
#   Original train size = 32993, Test size = 8251
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 38] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.8842, Elapsed time = 1407.66 seconds
# Fold 39:
#   Original train size = 32969, Test size = 8275
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 39] Stratification Check:
#     Overall SL rate: 0.0229
#     Train SL rate:   0.0247 (diff: 0.0018)
#     Test SL rate:    0.0172 (diff: 0.0058)
#     Train/Test diff: 0.0076
# Stratification OK
#   ROC AUC = 0.9033, Elapsed time = 1441.60 seconds
# Fold 40:
#   Original train size = 33039, Test size = 8205
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 40] Stratification Check:
#     Overall SL rate: 0.0234
#     Train SL rate:   0.0224 (diff: 0.0010)
#     Test SL rate:    0.0264 (diff: 0.0031)
#     Train/Test diff: 0.0040
# Stratification OK
#   ROC AUC = 0.9262, Elapsed time = 1475.03 seconds
# Fold 41:
#   Original train size = 32989, Test size = 8255
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 41] Stratification Check:
#     Overall SL rate: 0.0231
#     Train SL rate:   0.0239 (diff: 0.0008)
#     Test SL rate:    0.0205 (diff: 0.0026)
#     Train/Test diff: 0.0034
# Stratification OK
#   ROC AUC = 0.9084, Elapsed time = 1509.02 seconds
# Fold 42:
#   Original train size = 32973, Test size = 8271
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 42] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0002)
#     Test SL rate:    0.0227 (diff: 0.0005)
#     Train/Test diff: 0.0006
# Stratification OK
#   ROC AUC = 0.9343, Elapsed time = 1543.59 seconds
# Fold 43:
#   Original train size = 32975, Test size = 8269
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 43] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0236 (diff: 0.0005)
#     Test SL rate:    0.0216 (diff: 0.0015)
#     Train/Test diff: 0.0020
# Stratification OK
#   ROC AUC = 0.9041, Elapsed time = 1579.09 seconds
# Fold 44:
#   Original train size = 33018, Test size = 8226
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 44] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0231 (diff: 0.0001)
#     Test SL rate:    0.0237 (diff: 0.0005)
#     Train/Test diff: 0.0006
# Stratification OK
#   ROC AUC = 0.8928, Elapsed time = 1613.74 seconds
# Fold 45:
#   Original train size = 33021, Test size = 8223
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 45] Stratification Check:
#     Overall SL rate: 0.0234
#     Train SL rate:   0.0221 (diff: 0.0013)
#     Test SL rate:    0.0276 (diff: 0.0042)
#     Train/Test diff: 0.0055
# Stratification OK
#   ROC AUC = 0.8860, Elapsed time = 1649.86 seconds
# Fold 46:
#   Original train size = 33000, Test size = 8244
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 46] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0235 (diff: 0.0003)
#     Test SL rate:    0.0222 (diff: 0.0010)
#     Train/Test diff: 0.0013
# Stratification OK
#   ROC AUC = 0.8660, Elapsed time = 1686.00 seconds
# Fold 47:
#   Original train size = 33006, Test size = 8238
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 47] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0236 (diff: 0.0005)
#     Test SL rate:    0.0216 (diff: 0.0015)
#     Train/Test diff: 0.0020
# Stratification OK
#   ROC AUC = 0.8863, Elapsed time = 1720.43 seconds
# Fold 48:
#   Original train size = 32954, Test size = 8290
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 48] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0231 (diff: 0.0001)
#     Test SL rate:    0.0235 (diff: 0.0003)
#     Train/Test diff: 0.0004
# Stratification OK
#   ROC AUC = 0.9367, Elapsed time = 1757.04 seconds
# Fold 49:
#   Original train size = 33022, Test size = 8222
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 49] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0230 (diff: 0.0003)
#     Test SL rate:    0.0243 (diff: 0.0010)
#     Train/Test diff: 0.0014
# Stratification OK
#   ROC AUC = 0.8981, Elapsed time = 1794.21 seconds
# Fold 50:
#   Original train size = 32994, Test size = 8250
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_early_reduced - Fold 50] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0229 (diff: 0.0004)
#     Test SL rate:    0.0245 (diff: 0.0012)
#     Train/Test diff: 0.0016
# Stratification OK
#   ROC AUC = 0.9148, Elapsed time = 1830.94 seconds
#
# === Model_III_early_reduced Summary ===
# Mean ROC AUC = 0.9004 ± 0.0154
# Successful folds: 50/50
# Stratification quality:
#   Mean train deviation: 0.0005 ± 0.0004
#   Mean test deviation:  0.0018 ± 0.0014

# %%
#Run cross-validation on both feature set
model_III_full_reduced = model_full_cross_validation(
    classifier=RF,
    data=training_df[feature_columns_2],     
    target=training_df[target_column],
    splits=repeated_splits_III,                
    model_name="Model_III_full_reduced",
    downsample_train_to=26_400,               
    downsample_random_state=42,
    verbose=True
)
# Out:
# [DEBUG] model_late_cross_validation v2 — downsample=26400
#
# === Model_III_late_reduced - Fold 1/50 ===
#   Original train size = 33027, Test size = 8217
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 1] Stratification Check:
#     Overall SL rate: 0.0234
#     Train SL rate:   0.0223 (diff: 0.0011)
#     Test SL rate:    0.0269 (diff: 0.0035)
#     Train/Test diff: 0.0046
# Stratification OK
#   ROC AUC = 0.8870, Elapsed time = 53.39 seconds
#
# === Model_III_late_reduced - Fold 2/50 ===
#   Original train size = 32987, Test size = 8257
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 2] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0002)
#     Test SL rate:    0.0224 (diff: 0.0008)
#     Train/Test diff: 0.0010
# Stratification OK
#   ROC AUC = 0.9003, Elapsed time = 102.67 seconds
#
# === Model_III_late_reduced - Fold 3/50 ===
#   Original train size = 32975, Test size = 8269
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 3] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0003)
#     Test SL rate:    0.0224 (diff: 0.0008)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9154, Elapsed time = 153.15 seconds
#
# === Model_III_late_reduced - Fold 4/50 ===
#   Original train size = 32987, Test size = 8257
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 4] Stratification Check:
#     Overall SL rate: 0.0231
#     Train SL rate:   0.0239 (diff: 0.0008)
#     Test SL rate:    0.0206 (diff: 0.0025)
#     Train/Test diff: 0.0033
# Stratification OK
#   ROC AUC = 0.9189, Elapsed time = 203.76 seconds
#
# === Model_III_late_reduced - Fold 5/50 ===
#   Original train size = 33000, Test size = 8244
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 5] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0231 (diff: 0.0002)
#     Test SL rate:    0.0239 (diff: 0.0006)
#     Train/Test diff: 0.0008
# Stratification OK
#   ROC AUC = 0.9023, Elapsed time = 256.40 seconds
#
# === Model_III_late_reduced - Fold 6/50 ===
#   Original train size = 32999, Test size = 8245
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 6] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0227 (diff: 0.0006)
#     Test SL rate:    0.0252 (diff: 0.0019)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.8992, Elapsed time = 307.27 seconds
#
# === Model_III_late_reduced - Fold 7/50 ===
#   Original train size = 32975, Test size = 8269
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 7] Stratification Check:
#     Overall SL rate: 0.0234
#     Train SL rate:   0.0224 (diff: 0.0010)
#     Test SL rate:    0.0265 (diff: 0.0031)
#     Train/Test diff: 0.0041
# Stratification OK
#   ROC AUC = 0.9296, Elapsed time = 362.90 seconds
#
# === Model_III_late_reduced - Fold 8/50 ===
#   Original train size = 32979, Test size = 8265
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 8] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0001)
#     Test SL rate:    0.0230 (diff: 0.0002)
#     Train/Test diff: 0.0003
# Stratification OK
#   ROC AUC = 0.8980, Elapsed time = 415.43 seconds
#
# === Model_III_late_reduced - Fold 9/50 ===
#   Original train size = 33010, Test size = 8234
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 9] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0001)
#     Test SL rate:    0.0234 (diff: 0.0002)
#     Train/Test diff: 0.0003
# Stratification OK
#   ROC AUC = 0.9040, Elapsed time = 467.17 seconds
#
# === Model_III_late_reduced - Fold 10/50 ===
#   Original train size = 33013, Test size = 8231
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 10] Stratification Check:
#     Overall SL rate: 0.0230
#     Train SL rate:   0.0245 (diff: 0.0016)
#     Test SL rate:    0.0180 (diff: 0.0050)
#     Train/Test diff: 0.0066
# Stratification OK
#   ROC AUC = 0.8993, Elapsed time = 516.80 seconds
#
# === Model_III_late_reduced - Fold 11/50 ===
#   Original train size = 33002, Test size = 8242
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 11] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0237 (diff: 0.0006)
#     Test SL rate:    0.0214 (diff: 0.0018)
#     Train/Test diff: 0.0024
# Stratification OK
#   ROC AUC = 0.9001, Elapsed time = 566.43 seconds
#
# === Model_III_late_reduced - Fold 12/50 ===
#   Original train size = 32987, Test size = 8257
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 12] Stratification Check:
#     Overall SL rate: 0.0234
#     Train SL rate:   0.0225 (diff: 0.0008)
#     Test SL rate:    0.0260 (diff: 0.0027)
#     Train/Test diff: 0.0035
# Stratification OK
#   ROC AUC = 0.9042, Elapsed time = 617.50 seconds
#
# === Model_III_late_reduced - Fold 13/50 ===
#   Original train size = 33005, Test size = 8239
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 13] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0003)
#     Test SL rate:    0.0223 (diff: 0.0008)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9114, Elapsed time = 669.54 seconds
#
# === Model_III_late_reduced - Fold 14/50 ===
#   Original train size = 33014, Test size = 8230
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 14] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0227 (diff: 0.0007)
#     Test SL rate:    0.0255 (diff: 0.0022)
#     Train/Test diff: 0.0029
# Stratification OK
#   ROC AUC = 0.9009, Elapsed time = 723.30 seconds
#
# === Model_III_late_reduced - Fold 15/50 ===
#   Original train size = 32968, Test size = 8276
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 15] Stratification Check:
#     Overall SL rate: 0.0231
#     Train SL rate:   0.0238 (diff: 0.0007)
#     Test SL rate:    0.0209 (diff: 0.0022)
#     Train/Test diff: 0.0029
# Stratification OK
#   ROC AUC = 0.9015, Elapsed time = 774.02 seconds
#
# === Model_III_late_reduced - Fold 16/50 ===
#   Original train size = 33025, Test size = 8219
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 16] Stratification Check:
#     Overall SL rate: 0.0231
#     Train SL rate:   0.0236 (diff: 0.0005)
#     Test SL rate:    0.0215 (diff: 0.0016)
#     Train/Test diff: 0.0021
# Stratification OK
#   ROC AUC = 0.8906, Elapsed time = 825.34 seconds
#
# === Model_III_late_reduced - Fold 17/50 ===
#   Original train size = 33017, Test size = 8227
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 17] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0227 (diff: 0.0006)
#     Test SL rate:    0.0252 (diff: 0.0019)
#     Train/Test diff: 0.0024
# Stratification OK
#   ROC AUC = 0.9106, Elapsed time = 876.21 seconds
#
# === Model_III_late_reduced - Fold 18/50 ===
#   Original train size = 32994, Test size = 8250
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 18] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0230 (diff: 0.0003)
#     Test SL rate:    0.0241 (diff: 0.0009)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9020, Elapsed time = 926.78 seconds
#
# === Model_III_late_reduced - Fold 19/50 ===
#   Original train size = 33018, Test size = 8226
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 19] Stratification Check:
#     Overall SL rate: 0.0231
#     Train SL rate:   0.0236 (diff: 0.0005)
#     Test SL rate:    0.0215 (diff: 0.0016)
#     Train/Test diff: 0.0021
# Stratification OK
#   ROC AUC = 0.9275, Elapsed time = 979.14 seconds
#
# === Model_III_late_reduced - Fold 20/50 ===
#   Original train size = 32922, Test size = 8322
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 20] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0231 (diff: 0.0002)
#     Test SL rate:    0.0238 (diff: 0.0006)
#     Train/Test diff: 0.0007
# Stratification OK
#   ROC AUC = 0.8974, Elapsed time = 1035.90 seconds
#
# === Model_III_late_reduced - Fold 21/50 ===
#   Original train size = 32982, Test size = 8262
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 21] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0227 (diff: 0.0006)
#     Test SL rate:    0.0253 (diff: 0.0020)
#     Train/Test diff: 0.0026
# Stratification OK
#   ROC AUC = 0.8928, Elapsed time = 1092.02 seconds
#
# === Model_III_late_reduced - Fold 22/50 ===
#   Original train size = 32974, Test size = 8270
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 22] Stratification Check:
#     Overall SL rate: 0.0235
#     Train SL rate:   0.0217 (diff: 0.0018)
#     Test SL rate:    0.0291 (diff: 0.0056)
#     Train/Test diff: 0.0074
# Stratification OK
#   ROC AUC = 0.8937, Elapsed time = 1146.73 seconds
#
# === Model_III_late_reduced - Fold 23/50 ===
#   Original train size = 32973, Test size = 8271
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 23] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0003)
#     Test SL rate:    0.0224 (diff: 0.0008)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9329, Elapsed time = 1202.24 seconds
#
# === Model_III_late_reduced - Fold 24/50 ===
#   Original train size = 33012, Test size = 8232
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 24] Stratification Check:
#     Overall SL rate: 0.0231
#     Train SL rate:   0.0239 (diff: 0.0008)
#     Test SL rate:    0.0205 (diff: 0.0026)
#     Train/Test diff: 0.0034
# Stratification OK
#   ROC AUC = 0.9180, Elapsed time = 1260.16 seconds
#
# === Model_III_late_reduced - Fold 25/50 ===
#   Original train size = 33035, Test size = 8209
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 25] Stratification Check:
#     Overall SL rate: 0.0230
#     Train SL rate:   0.0244 (diff: 0.0013)
#     Test SL rate:    0.0188 (diff: 0.0043)
#     Train/Test diff: 0.0056
# Stratification OK
#   ROC AUC = 0.9026, Elapsed time = 1315.40 seconds
#
# === Model_III_late_reduced - Fold 26/50 ===
#   Original train size = 32977, Test size = 8267
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 26] Stratification Check:
#     Overall SL rate: 0.0231
#     Train SL rate:   0.0239 (diff: 0.0008)
#     Test SL rate:    0.0207 (diff: 0.0024)
#     Train/Test diff: 0.0032
# Stratification OK
#   ROC AUC = 0.9191, Elapsed time = 1372.25 seconds
#
# === Model_III_late_reduced - Fold 27/50 ===
#   Original train size = 32993, Test size = 8251
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 27] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0230 (diff: 0.0002)
#     Test SL rate:    0.0240 (diff: 0.0007)
#     Train/Test diff: 0.0010
# Stratification OK
#   ROC AUC = 0.9098, Elapsed time = 1428.55 seconds
#
# === Model_III_late_reduced - Fold 28/50 ===
#   Original train size = 33001, Test size = 8243
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 28] Stratification Check:
#     Overall SL rate: 0.0234
#     Train SL rate:   0.0224 (diff: 0.0010)
#     Test SL rate:    0.0264 (diff: 0.0031)
#     Train/Test diff: 0.0040
# Stratification OK
#   ROC AUC = 0.8774, Elapsed time = 1482.42 seconds
#
# === Model_III_late_reduced - Fold 29/50 ===
#   Original train size = 33012, Test size = 8232
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 29] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0003)
#     Test SL rate:    0.0224 (diff: 0.0008)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9038, Elapsed time = 1537.67 seconds
#
# === Model_III_late_reduced - Fold 30/50 ===
#   Original train size = 32993, Test size = 8251
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 30] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0002)
#     Test SL rate:    0.0227 (diff: 0.0005)
#     Train/Test diff: 0.0007
# Stratification OK
#   ROC AUC = 0.9216, Elapsed time = 1595.22 seconds
#
# === Model_III_late_reduced - Fold 31/50 ===
#   Original train size = 32941, Test size = 8303
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 31] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0236 (diff: 0.0004)
#     Test SL rate:    0.0219 (diff: 0.0012)
#     Train/Test diff: 0.0016
# Stratification OK
#   ROC AUC = 0.8921, Elapsed time = 1649.10 seconds
#
# === Model_III_late_reduced - Fold 32/50 ===
#   Original train size = 33029, Test size = 8215
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 32] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0227 (diff: 0.0006)
#     Test SL rate:    0.0252 (diff: 0.0019)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9136, Elapsed time = 1705.61 seconds
#
# === Model_III_late_reduced - Fold 33/50 ===
#   Original train size = 32996, Test size = 8248
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 33] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0002)
#     Test SL rate:    0.0227 (diff: 0.0005)
#     Train/Test diff: 0.0007
# Stratification OK
#   ROC AUC = 0.9088, Elapsed time = 1762.70 seconds
#
# === Model_III_late_reduced - Fold 34/50 ===
#   Original train size = 33023, Test size = 8221
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 34] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0001)
#     Test SL rate:    0.0230 (diff: 0.0002)
#     Train/Test diff: 0.0003
# Stratification OK
#   ROC AUC = 0.8996, Elapsed time = 1820.21 seconds
#
# === Model_III_late_reduced - Fold 35/50 ===
#   Original train size = 32987, Test size = 8257
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 35] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0234 (diff: 0.0001)
#     Train/Test diff: 0.0002
# Stratification OK
#   ROC AUC = 0.9227, Elapsed time = 1876.62 seconds
#
# === Model_III_late_reduced - Fold 36/50 ===
#   Original train size = 32996, Test size = 8248
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 36] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0230 (diff: 0.0003)
#     Test SL rate:    0.0241 (diff: 0.0009)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.8808, Elapsed time = 1932.00 seconds
#
# === Model_III_late_reduced - Fold 37/50 ===
#   Original train size = 32979, Test size = 8265
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 37] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0227 (diff: 0.0006)
#     Test SL rate:    0.0252 (diff: 0.0019)
#     Train/Test diff: 0.0024
# Stratification OK
#   ROC AUC = 0.9068, Elapsed time = 1987.73 seconds
#
# === Model_III_late_reduced - Fold 38/50 ===
#   Original train size = 32993, Test size = 8251
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 38] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.8859, Elapsed time = 2044.97 seconds
#
# === Model_III_late_reduced - Fold 39/50 ===
#   Original train size = 32969, Test size = 8275
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 39] Stratification Check:
#     Overall SL rate: 0.0229
#     Train SL rate:   0.0247 (diff: 0.0018)
#     Test SL rate:    0.0172 (diff: 0.0058)
#     Train/Test diff: 0.0076
# Stratification OK
#   ROC AUC = 0.8999, Elapsed time = 2100.42 seconds
#
# === Model_III_late_reduced - Fold 40/50 ===
#   Original train size = 33039, Test size = 8205
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 40] Stratification Check:
#     Overall SL rate: 0.0234
#     Train SL rate:   0.0224 (diff: 0.0010)
#     Test SL rate:    0.0264 (diff: 0.0031)
#     Train/Test diff: 0.0040
# Stratification OK
#   ROC AUC = 0.9308, Elapsed time = 2155.16 seconds
#
# === Model_III_late_reduced - Fold 41/50 ===
#   Original train size = 32989, Test size = 8255
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 41] Stratification Check:
#     Overall SL rate: 0.0231
#     Train SL rate:   0.0239 (diff: 0.0008)
#     Test SL rate:    0.0205 (diff: 0.0026)
#     Train/Test diff: 0.0034
# Stratification OK
#   ROC AUC = 0.9179, Elapsed time = 2211.38 seconds
#
# === Model_III_late_reduced - Fold 42/50 ===
#   Original train size = 32973, Test size = 8271
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 42] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0002)
#     Test SL rate:    0.0227 (diff: 0.0005)
#     Train/Test diff: 0.0006
# Stratification OK
#   ROC AUC = 0.9298, Elapsed time = 2268.63 seconds
#
# === Model_III_late_reduced - Fold 43/50 ===
#   Original train size = 32975, Test size = 8269
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 43] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0236 (diff: 0.0005)
#     Test SL rate:    0.0216 (diff: 0.0015)
#     Train/Test diff: 0.0020
# Stratification OK
#   ROC AUC = 0.9089, Elapsed time = 2327.50 seconds
#
# === Model_III_late_reduced - Fold 44/50 ===
#   Original train size = 33018, Test size = 8226
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 44] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0231 (diff: 0.0001)
#     Test SL rate:    0.0237 (diff: 0.0005)
#     Train/Test diff: 0.0006
# Stratification OK
#   ROC AUC = 0.8946, Elapsed time = 2384.21 seconds
#
# === Model_III_late_reduced - Fold 45/50 ===
#   Original train size = 33021, Test size = 8223
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 45] Stratification Check:
#     Overall SL rate: 0.0234
#     Train SL rate:   0.0221 (diff: 0.0013)
#     Test SL rate:    0.0276 (diff: 0.0042)
#     Train/Test diff: 0.0055
# Stratification OK
#   ROC AUC = 0.8899, Elapsed time = 2439.24 seconds
#
# === Model_III_late_reduced - Fold 46/50 ===
#   Original train size = 33000, Test size = 8244
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 46] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0235 (diff: 0.0003)
#     Test SL rate:    0.0222 (diff: 0.0010)
#     Train/Test diff: 0.0013
# Stratification OK
#   ROC AUC = 0.8779, Elapsed time = 2495.54 seconds
#
# === Model_III_late_reduced - Fold 47/50 ===
#   Original train size = 33006, Test size = 8238
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 47] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0236 (diff: 0.0005)
#     Test SL rate:    0.0216 (diff: 0.0015)
#     Train/Test diff: 0.0020
# Stratification OK
#   ROC AUC = 0.8848, Elapsed time = 2551.95 seconds
#
# === Model_III_late_reduced - Fold 48/50 ===
#   Original train size = 32954, Test size = 8290
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 48] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0231 (diff: 0.0001)
#     Test SL rate:    0.0235 (diff: 0.0003)
#     Train/Test diff: 0.0004
# Stratification OK
#   ROC AUC = 0.9348, Elapsed time = 2608.34 seconds
#
# === Model_III_late_reduced - Fold 49/50 ===
#   Original train size = 33022, Test size = 8222
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 49] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0230 (diff: 0.0003)
#     Test SL rate:    0.0243 (diff: 0.0010)
#     Train/Test diff: 0.0014
# Stratification OK
#   ROC AUC = 0.9024, Elapsed time = 2665.65 seconds
#
# === Model_III_late_reduced - Fold 50/50 ===
#   Original train size = 32994, Test size = 8250
#   Effective train size after downsampling = 26400 (cap: 26400)
#   [Model_III_late_reduced - Fold 50] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0229 (diff: 0.0004)
#     Test SL rate:    0.0245 (diff: 0.0012)
#     Train/Test diff: 0.0016
# Stratification OK
#   ROC AUC = 0.9187, Elapsed time = 2725.01 seconds
#
# === Model_III_late_reduced Summary ===
# Mean ROC AUC = 0.9050 ± 0.0144
# Successful folds: 50/50
# Stratification quality:
#   Mean train deviation: 0.0005 ± 0.0004
#   Mean test deviation:  0.0018 ± 0.0014

# %%
# Downsample cap verified
print(min(model_III_contextualised_reduced['effective_train_sizes']),
      max(model_III_contextualised_reduced['effective_train_sizes']))
print(min(model_III_full_reduced['effective_train_sizes']),
      max(model_III_full_reduced['effective_train_sizes']))
# Out:
# 26400 26400
# 26400 26400

# %%
# save results of cross validation
with open(file_RF_model_III_contextualised_reduced, 'wb') as f:
    pickle.dump(model_III_contextualised_reduced, f)

with open(file_RF_model_III_full_reduced, 'wb') as f:
    pickle.dump(model_III_full_reduced, f)

# %% [markdown]
# ## Model IV
# #### Different paralog pairs, different cell lines

# %%
# --- Custom split functions ---
def create_disjoint_splits(df, n_splits=5, num_test_cell_lines=2, test_gene_fraction=0.25, random_state=None):
    splits = []

    # Get the unique cell lines and gene pairs
    unique_cell_lines = df['cell_line'].unique()
    unique_gene_pairs = df['genepair'].unique()

    # Set the random seed if provided
    if random_state is not None:
        np.random.seed(random_state)

    # Shuffle and split cell lines and gene pairs into mutually exclusive groups
    np.random.shuffle(unique_cell_lines)
    cell_line_splits = np.array_split(unique_cell_lines, n_splits)

    np.random.shuffle(unique_gene_pairs)
    gene_pair_splits = np.array_split(unique_gene_pairs, n_splits)

    # Create the splits
    for fold in range(n_splits):
        test_cell_lines = cell_line_splits[fold]
        test_gene_pairs = gene_pair_splits[fold]

        train_cell_lines = np.concatenate([cell_line_splits[i] for i in range(n_splits) if i != fold])
        train_gene_pairs = np.concatenate([gene_pair_splits[i] for i in range(n_splits) if i != fold])

        # Define train/test indices
        test_index = df[(df['cell_line'].isin(test_cell_lines)) & (df['genepair'].isin(test_gene_pairs))].index
        train_index = df[(df['cell_line'].isin(train_cell_lines)) & (df['genepair'].isin(train_gene_pairs))].index

        splits.append((train_index, test_index))

        print(f'[Fold {fold+1}] '
              f'# pairs (train): {df.loc[train_index, "genepair"].nunique()} | '
              f'# pairs (test): {df.loc[test_index, "genepair"].nunique()} | '
              f'# overlapping: {np.isin(df.loc[test_index, "genepair"].unique(), df.loc[train_index, "genepair"].unique()).sum()} | '
              f'# cells (train): {df.loc[train_index, "cell_line"].nunique()} | '
              f'# cells (test): {df.loc[test_index, "cell_line"].nunique()}')

        # Add validation after creating splits
        train_cells = set(df.loc[train_index, 'cell_line'].unique())
        test_cells = set(df.loc[test_index, 'cell_line'].unique())
        train_pairs = set(df.loc[train_index, 'genepair'].unique())
        test_pairs = set(df.loc[test_index, 'genepair'].unique())

        assert len(train_cells & test_cells) == 0, "Cell line leakage detected!"
        assert len(train_pairs & test_pairs) == 0, "Gene pair leakage detected!"

    return splits

def repeated_custom_cv(df, n_splits=5, n_repeats=3, num_test_cell_lines=2, test_gene_fraction=0.25, random_state=None):
    all_splits = []

    for repeat in range(n_repeats):
        current_seed = random_state + repeat if random_state is not None else None
        splits = create_disjoint_splits(
            df,
            n_splits=n_splits,
            num_test_cell_lines=num_test_cell_lines,
            test_gene_fraction=test_gene_fraction,
            random_state=current_seed
        )
        all_splits.extend(splits)

    return all_splits

# %%
splits_IV = repeated_custom_cv(df=training_df, n_splits=5, n_repeats=10, random_state=42)

# Add validation for Model IV splits
print("\n=== MODEL IV: COMBINED VALIDATION ===")
for i, (train_index, test_index) in enumerate(splits_IV[:5]):  # Just first 5 for brevity
    train_cells = training_df.loc[train_index, 'cell_line'].unique()  # Use correct column name
    test_cells = training_df.loc[test_index, 'cell_line'].unique()    # Use correct column name
    train_pairs = training_df.loc[train_index, 'genepair'].unique()
    test_pairs = training_df.loc[test_index, 'genepair'].unique()
    
    print(f"\n--- Fold {i+1} ---")
    validate_group_splits(train_cells, test_cells, i+1, "Model IV", "cell lines")
    validate_group_splits(train_pairs, test_pairs, i+1, "Model IV", "gene pairs")

# %%
# Save splits
with open('/Users/narod/Library/CloudStorage/GoogleDrive-narod.kebabci@ucdconnect.ie/My Drive/GitRepos/context_specific_SL_prediction/output/models/model_IV/splits_IV.pkl', 'wb') as f:
    pickle.dump(splits_IV, f)

# %%
model_IV_contextualised = model_contextualised_cross_validation(RF, data_1, target, splits_IV, model_name="Model IV contextualised")
model_IV_full = model_full_cross_validation(RF, data_2, target, splits_IV, model_name="Model IV Full")

# %%
# save results of cross validation
with open(file_RF_model_IV_contextualised, 'wb') as f:
    pickle.dump(model_IV_contextualised, f)

with open(file_RF_model_IV_full, 'wb') as f:
    pickle.dump(model_IV_full, f)

# %% [markdown]
# ## Plot ROC and PR Curves

# %%
def plot_model_performance(df, data, target, model_contextualised, model_full, file_path):
    sns.set_context('paper')
    f, ax = plt.subplots(1, 2, figsize=(9.5, 4.5))  # ROC and PR side by side

    # --- contextualised model ---
    roc_display = RocCurveDisplay(
        fpr=model_contextualised['mean_fpr'],
        tpr=model_contextualised['mean_tpr'],
        roc_auc=model_contextualised['mean_auc']
    )
    roc_display.plot(ax=ax[0], color='#009E73', linewidth=1.75, label=f"{model_contextualised['mean_auc']:.2f}")

    pr_display = PrecisionRecallDisplay(
        precision=model_contextualised['precision'],
        recall=model_contextualised['recall'],
        average_precision=model_contextualised['mean_aps']
    )
    pr_display.plot(ax=ax[1], color='#009E73', linewidth=1.75, label=f"{model_contextualised['mean_aps']:.2f}")

    # --- Full model ---
    roc_display = RocCurveDisplay(
        fpr=model_full['mean_fpr'],
        tpr=model_full['mean_tpr'],
        roc_auc=model_full['mean_auc']
    )
    roc_display.plot(ax=ax[0], alpha=0.8, color='#CC79A7', linewidth=1.75, label=f"{model_full['mean_auc']:.2f}")

    pr_display = PrecisionRecallDisplay(
        precision=model_full['precision'],
        recall=model_full['recall'],
        average_precision=model_full['mean_aps']
    )
    pr_display.plot(ax=ax[1], alpha=0.8, color='#CC79A7', linewidth=1.75, label=f"{model_full['mean_aps']:.2f}")

    # --- Additional classifier-like metrics ---
    metrics = ['prediction_score', 'min_sequence_identity']
    colors = ['#777777', '#E69F00']
    auc_labels = ['pred_auc', 'seq_auc']
    ap_labels = ['pred_ap', 'seq_ap']

    for metric, color, auc_label, ap_label in zip(metrics, colors, auc_labels, ap_labels):
        score = data[metric] if metric != 'min_ranked_A1A2' else -data[metric]
        mask = ~score.isna()
        y_true = target[mask]
        y_score = score[mask]

        if len(np.unique(y_true)) < 2:
            print(f"Skipping {metric}: not enough label variation after NaN removal.")
            continue

        # ROC Curve
        fpr, tpr, _ = roc_curve(y_true, y_score)
        roc_auc = model_contextualised[auc_label]
        roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc)
        roc_display.plot(ax=ax[0], color=color, linewidth=1.75, label=f"{roc_auc:.3f}")

        # PR Curve
        precision, recall, _ = precision_recall_curve(y_true, y_score)
        pr_auc = model_contextualised[ap_label]
        pr_display = PrecisionRecallDisplay(precision=precision, recall=recall, average_precision=pr_auc)
        pr_display.plot(ax=ax[1], color=color, linewidth=1.75, label=f"{pr_auc:.3f}")

    # --- ROC chance line ---
    ax[0].plot([0, 1], [0, 1], color="lightgrey", linestyle="--", label="0.50")
    ax[0].set_xlim([-0.025, 1.025])
    ax[0].set_ylim([-0.025, 1.025])
    ax[0].spines.top.set(visible=False)
    ax[0].spines.right.set(visible=False)
    ax[0].tick_params(axis='both', which='major', labelsize=11)
    ax[0].set_xlabel('False Positive Rate', fontsize=12)
    ax[0].set_ylabel('True Positive Rate', fontsize=12)
    ax[0].legend(loc='lower right', fontsize=12, bbox_to_anchor=(1.02, 0))

    # --- PR baseline ---
    no_skill = round(sum(df['SL_new']) / len(df['SL_new']), 3)
    ax[1].plot([0, 1], [no_skill, no_skill], linestyle='--', color='lightgrey', label=f"{no_skill:.2f}")
    ax[1].set_xlim([-0.025, 1.025])
    ax[1].set_ylim([-0.025, 1.025])
    ax[1].spines.top.set(visible=False)
    ax[1].spines.right.set(visible=False)
    ax[1].set_xlabel('Recall', fontsize=12)
    ax[1].set_ylabel('Precision', fontsize=12)
    ax[1].tick_params(axis='both', which='major', labelsize=11)
    ax[1].legend(loc='upper right', fontsize=12)

    plt.tight_layout(h_pad=0.7)
    plt.savefig(file_path, bbox_inches='tight', dpi=400)
    plt.close(f)

# %%
figure_path_model1 = figure_path_model1 = get_data_path(['figures'], 'supp3_a_model_I.png')
plot_model_performance(training_df, data_1, target, model_I_contextualised_reduced, model_I_full_reduced, figure_path_model1)

# %%
figure_path_model2 = get_data_path(['figures'], 'supp3_a_model_II.png')
plot_model_performance(training_df, data_1, target, model_II_contextualised_reduced, model_II_full_reduced, figure_path_model2)

# %%
figure_path_model3 = get_data_path(['figures'], 'supp3_a_model_III.png')
plot_model_performance(training_df, data_1, target, model_III_contextualised_reduced, model_III_full_reduced, figure_path_model3)

# %%
def generate_validation_report(model_results, model_name):
    """Generate a comprehensive validation report for a model."""
    print(f"\n{'='*50}")
    print(f"VALIDATION REPORT: {model_name}")
    print(f"{'='*50}")
    
    # Performance summary
    print(f"Performance:")
    print(f"  Mean ROC AUC: {model_results['mean_auc']:.4f} ± {model_results['std_auc']:.4f}")
    print(f"  Mean PR AUC:  {model_results['mean_aps']:.4f} ± {model_results['std_ap']:.4f}")
    print(f"  Effective folds: {model_results['effective_folds']}")
    
    if 'skipped_folds' in model_results and model_results['skipped_folds']:
        print(f"  Skipped folds: {model_results['skipped_folds']}")
    
    # Stratification summary
    if 'stratification_results' in model_results:
        strat_results = model_results['stratification_results']
        if strat_results:
            train_diffs = [r['train_diff'] for r in strat_results]
            test_diffs = [r['test_diff'] for r in strat_results]
            warnings_count = sum(len(r['warnings']) for r in strat_results)
            
            print(f"\nStratification Quality:")
            print(f"  Mean train deviation: {np.mean(train_diffs):.4f} ± {np.std(train_diffs):.4f}")
            print(f"  Mean test deviation:  {np.mean(test_diffs):.4f} ± {np.std(test_diffs):.4f}")
            print(f"  Total warnings: {warnings_count}")
            
            if warnings_count > 0:
                print(f"Some folds had stratification issues")
            else:
                print(f"All folds passed stratification checks")

with open(file_RF_model_IV_contextualised, 'rb') as file:
    model_IV_contextualised = pickle.load(file)

with open(file_RF_model_IV_full, 'rb') as file:
    model_IV_full = pickle.load(file)

# Generate reports for all models
all_models = [
    (model_I_contextualised_reduced, "Model I contextualised"),
    (model_I_full_reduced, "Model I Full"),
    (model_II_contextualised_reduced, "Model II contextualised"),
    (model_II_full_reduced, "Model II Full"),
    (model_III_contextualised_reduced, "Model III contextualised"),
    (model_III_full_reduced, "Model III Full"),
    (model_IV_contextualised, "Model IV contextualised"),
    (model_IV_full, "Model IV Full")
]

for model_result, model_name in all_models:
    generate_validation_report(model_result, model_name)
# Out:
# ==================================================
# VALIDATION REPORT: Model I Early
# ==================================================
# Performance:
#   Mean ROC AUC: 0.9161 ± 0.0095
#   Mean PR AUC:  0.3429 ± 0.0349
#   Effective folds: 50
#
# Stratification Quality:
#   Mean train deviation: 0.0000 ± 0.0000
#   Mean test deviation:  0.0001 ± 0.0000
#   Total warnings: 0
# All folds passed stratification checks
#
# ==================================================
# VALIDATION REPORT: Model I Late
# ==================================================
# Performance:
#   Mean ROC AUC: 0.9275 ± 0.0088
#   Mean PR AUC:  0.3924 ± 0.0351
#   Effective folds: 50
#
# Stratification Quality:
#   Mean train deviation: 0.0000 ± 0.0000
#   Mean test deviation:  0.0001 ± 0.0000
#   Total warnings: 0
# All folds passed stratification checks
#
# ==================================================
# VALIDATION REPORT: Model II Early
# ==================================================
# Performance:
#   Mean ROC AUC: 0.8974 ± 0.0339
#   Mean PR AUC:  0.2751 ± 0.0598
#   Effective folds: 50
#
# Stratification Quality:
#   Mean train deviation: 0.0021 ± 0.0013
#   Mean test deviation:  0.0067 ± 0.0043
#   Total warnings: 0
# All folds passed stratification checks
#
# ==================================================
# VALIDATION REPORT: Model II Late
# ==================================================
# Performance:
#   Mean ROC AUC: 0.9138 ± 0.0311
#   Mean PR AUC:  0.3312 ± 0.0696
#   Effective folds: 50
#
# Stratification Quality:
#   Mean train deviation: 0.0021 ± 0.0013
#   Mean test deviation:  0.0067 ± 0.0043
#   Total warnings: 0
# All folds passed stratification checks
#
# ==================================================
# VALIDATION REPORT: Model III Early
# ==================================================
# Performance:
#   Mean ROC AUC: 0.9004 ± 0.0154
#   Mean PR AUC:  0.2961 ± 0.0502
#   Effective folds: 50
#
# Stratification Quality:
#   Mean train deviation: 0.0005 ± 0.0004
#   Mean test deviation:  0.0018 ± 0.0014
#   Total warnings: 0
# All folds passed stratification checks
#
# ==================================================
# VALIDATION REPORT: Model III Late
# ==================================================
# Performance:
#   Mean ROC AUC: 0.9050 ± 0.0144
#   Mean PR AUC:  0.3183 ± 0.0458
#   Effective folds: 50
#
# Stratification Quality:
#   Mean train deviation: 0.0005 ± 0.0004
#   Mean test deviation:  0.0018 ± 0.0014
#   Total warnings: 0
# All folds passed stratification checks
#
# ==================================================
# VALIDATION REPORT: Model IV Early
# ==================================================
# Performance:
#   Mean ROC AUC: 0.8741 ± 0.0402
#   Mean PR AUC:  0.2200 ± 0.0812
#   Effective folds: 50
#
# Stratification Quality:
#   Mean train deviation: 0.0005 ± 0.0003
#   Mean test deviation:  0.0079 ± 0.0050
#   Total warnings: 0
# All folds passed stratification checks
#
# ==================================================
# VALIDATION REPORT: Model IV Late
# ==================================================
# Performance:
#   Mean ROC AUC: 0.8842 ± 0.0406
#   Mean PR AUC:  0.2337 ± 0.0783
#   Effective folds: 50
#
# Stratification Quality:
#   Mean train deviation: 0.0005 ± 0.0003
#   Mean test deviation:  0.0079 ± 0.0050
#   Total warnings: 0
# All folds passed stratification checks
