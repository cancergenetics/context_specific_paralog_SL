# %% [markdown]
# # Random Forest Classification via cross-validation
#
# - classification task: SL (1) or not SL (0)
# - classification tree can handle all types of data, all types of relationships among the independent variables (the data we're using to make predictions), and all kinds of relationships with the dependent variable (the thing we want to predict)
# - The column named SL is my target variable (i.e., the variable which I want to predict). There are two possible classes: 0 (non-SL) and 1 (SL). The resulting prediction problem is therefore a binary classification problem, while I will use the other columns (feature columns) as input variables for the model.
#
# *StratifiedKFold* is a variation of k-fold which returns stratified folds: each set contains approximately the same percentage of samples of each target class as the complete set.
#
# *StratifiedKFold* preserves the class ratios (approximately 1 / 10) in both train and test dataset.
#
# *StratifiedGroupKFold* is used to generate the train and test sets for model 2 and model 3
#
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedGroupKFold.html#sklearn.model_selection.StratifiedGroupKFold
#
# The implementation is designed to:
# - Generate test sets such that all contain the same distribution of classes, or as close as possible.
# - Be invariant to class label: relabelling y = ["Happy", "Sad"] to y = [1, 0] should not change the indices generated.
# - Preserve order dependencies in the dataset ordering, when shuffle=False: all samples from class k in some test set were contiguous in y, or separated in y by samples from classes other than k.
# - Generate test sets where the smallest and largest differ by at most one sample.
#
# *type_of_target* : Determine the type of data indicated by the target, binary, multiclass, etc.

# %%
# import modules
import os
import pandas as pd
import numpy as np
import random
import pickle

# import scikit-learn modules
from sklearn.model_selection import StratifiedKFold, StratifiedGroupKFold, RepeatedStratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import RocCurveDisplay, PrecisionRecallDisplay, roc_auc_score, average_precision_score, precision_recall_curve, auc, roc_curve

import time

# %%
cwd = os.getcwd()
BASE_DIR = os.path.abspath(os.path.join(cwd, ".."))

# build paths inside the repo
get_data_path = lambda folders, fname: os.path.normpath(
    os.path.join(BASE_DIR, *folders, fname)
)

file_path_training_data = get_data_path(['output', 'models'], 'training_data.csv')

file_RF_model_I_early = get_data_path(['output', 'models', 'model_I'], 'RF_model_early.pickle')
file_RF_model_I_late = get_data_path(['output', 'models', 'model_I'], 'RF_model_late.pickle')
file_RF_model_I_early_repeated = get_data_path(['output', 'models', 'model_I'], 'RF_model_early_repeated.pickle')
file_RF_model_I_late_repeated = get_data_path(['output', 'models', 'model_I'], 'RF_model_late_repeated.pickle')

file_RF_model_II_early = get_data_path(['output', 'models', 'model_II'], 'RF_model_early.pickle')
file_RF_model_II_late = get_data_path(['output', 'models', 'model_II'], 'RF_model_late.pickle')
file_RF_model_II_early_repeated = get_data_path(['output', 'models', 'model_II'], 'RF_model_early_repeated.pickle')
file_RF_model_II_late_repeated = get_data_path(['output', 'models', 'model_II'], 'RF_model_late_repeated.pickle')

file_RF_model_III_early = get_data_path(['output', 'models', 'model_III'], 'RF_model_early.pickle')
file_RF_model_III_late = get_data_path(['output', 'models', 'model_III'], 'RF_model_late.pickle')
file_RF_model_III_early_repeated = get_data_path(['output', 'models', 'model_III'], 'RF_model_early_repeated.pickle')
file_RF_model_III_late_repeated = get_data_path(['output', 'models', 'model_III'], 'RF_model_late_repeated.pickle')

file_RF_model_IV_early = get_data_path(['output', 'models', 'model_IV'], 'RF_model_early.pickle')
file_RF_model_IV_late = get_data_path(['output', 'models', 'model_IV'], 'RF_model_late.pickle')

# %%
training_df = pd.read_csv(file_path_training_data)
training_df.head()
# Out:
#       genepair       A1   A2  A1_entrez  A2_entrez   DepMap_ID  \
# 0  A3GALT2_ABO  A3GALT2  ABO   127550.0       28.0  ACH-000022
# 1  A3GALT2_ABO  A3GALT2  ABO   127550.0       28.0  ACH-000307
# 2  A3GALT2_ABO  A3GALT2  ABO   127550.0       28.0  ACH-000632
# 3  A3GALT2_ABO  A3GALT2  ABO   127550.0       28.0  ACH-000681
# 4  A3GALT2_ABO  A3GALT2  ABO   127550.0       28.0  ACH-000756
#
#                     cell_line  Gemini_FDR   raw_LFC     SL  ...  \
# 0          PATU8988S_PANCREAS    0.998944  0.088856  False  ...
# 1                PK1_PANCREAS    0.986587  0.201704  False  ...
# 2                 HS944T_SKIN    1.000000  0.069772  False  ...
# 3                   A549_LUNG    0.977988  0.379455  False  ...
# 4  GI1_CENTRAL_NERVOUS_SYSTEM    0.999586 -0.077118  False  ...
#
#   colocalisation interact  n_total_ppi  fet_ppi_overlap  gtex_spearman_corr  \
# 0            0.0    False          3.0              0.0            0.114847
# 1            0.0    False          3.0              0.0            0.114847
# 2            0.0    False          3.0              0.0            0.114847
# 3            0.0    False          3.0              0.0            0.114847
# 4            0.0    False          3.0              0.0            0.114847
#
#    gtex_min_mean_expr  gtex_max_mean_expr    GEMINI       LFC  SL_new
# 0            0.258739              11.702  0.118768  0.088856   False
# 1            0.258739              11.702  0.132501  0.201704   False
# 2            0.258739              11.702  0.024593  0.069772   False
# 3            0.258739              11.702 -0.241323  0.379455   False
# 4            0.258739              11.702  0.299715 -0.077118   False
#
# [5 rows x 83 columns]

# %%
feature_columns_1 = ['rMaxExp_A1A2', 'rMinExp_A1A2',
                     'max_ranked_A1A2', 'min_ranked_A1A2',
                     'max_cn', 'min_cn', 'Protein_Altering', 'Damaging', 
                     'min_sequence_identity',
                     'prediction_score', 
                     'weighted_PPI_essentiality', 'weighted_PPI_expression',
                     'smallest_BP_GO_essentiality', 'smallest_CC_GO_essentiality',
                     'smallest_BP_GO_expression', 'go_CC_expression'
                     ]

target_column = 'SL_new'

print('num of features:', len(feature_columns_1))
# Out:
# num of features: 16

# %%
feature_columns_2 = feature_columns_1 + ['closest', 'WGD', 'family_size',
                                         'cds_length_ratio', 'shared_domains', 'has_pombe_ortholog',
                                         'has_essential_pombe_ortholog', 'has_cerevisiae_ortholog', 'has_essential_cerevisiae_ortholog', 
                                         'conservation_score', 'mean_age', 'either_in_complex', 'mean_complex_essentiality', 'colocalisation',
                                         'interact', 'n_total_ppi', 'fet_ppi_overlap',
                                         'gtex_spearman_corr', 'gtex_min_mean_expr', 'gtex_max_mean_expr']
feature_columns_2.remove('prediction_score')
print('num of features:', len(feature_columns_2))
# Out:
# num of features: 35

# %% [markdown]
# ### Model I - Random Selection

# %%
def safe_roc_auc(y_true, y_score):
    mask = ~np.isnan(y_score)
    if np.sum(mask) < 2 or len(np.unique(y_true[mask])) < 2:
        return np.nan
    return roc_auc_score(y_true[mask], y_score[mask])

def safe_average_precision(y_true, y_score):
    mask = ~np.isnan(y_score)
    if np.sum(mask) == 0:
        return np.nan
    return average_precision_score(y_true[mask], y_score[mask])

# %%
def validate_stratification(y_train, y_test, fold_num, model_name, tolerance=0.05):
    """
    Validate that stratification is working correctly across train/test splits.
    
    Parameters:
    - y_train, y_test: target arrays for train and test sets
    - fold_num: current fold number
    - model_name: name of the model for logging
    - tolerance: acceptable difference in class proportions (default 5%)
    """
    # Calculate class proportions
    train_pos_rate = y_train.mean()
    test_pos_rate = y_test.mean()
    overall_pos_rate = np.concatenate([y_train, y_test]).mean()
    
    # Calculate differences from overall rate
    train_diff = abs(train_pos_rate - overall_pos_rate)
    test_diff = abs(test_pos_rate - overall_pos_rate)
    train_test_diff = abs(train_pos_rate - test_pos_rate)
    
    # Print detailed information
    print(f"  [{model_name} - Fold {fold_num}] Stratification Check:")
    print(f"    Overall SL rate: {overall_pos_rate:.4f}")
    print(f"    Train SL rate:   {train_pos_rate:.4f} (diff: {train_diff:.4f})")
    print(f"    Test SL rate:    {test_pos_rate:.4f} (diff: {test_diff:.4f})")
    print(f"    Train/Test diff: {train_test_diff:.4f}")
    
    # Check for violations
    warnings = []
    if train_diff > tolerance:
        warnings.append(f"Train set deviation ({train_diff:.4f}) exceeds tolerance ({tolerance})")
    if test_diff > tolerance:
        warnings.append(f"Test set deviation ({test_diff:.4f}) exceeds tolerance ({tolerance})")
    if train_test_diff > tolerance:
        warnings.append(f"Train/Test difference ({train_test_diff:.4f}) exceeds tolerance ({tolerance})")
    
    if warnings:
        print(f"WARNINGS:")
        for warning in warnings:
            print(f"      - {warning}")
    else:
        print(f"Stratification OK")
    
    return {
        'train_pos_rate': train_pos_rate,
        'test_pos_rate': test_pos_rate,
        'overall_pos_rate': overall_pos_rate,
        'train_diff': train_diff,
        'test_diff': test_diff,
        'train_test_diff': train_test_diff,
        'warnings': warnings
    }

def validate_group_splits(train_groups, test_groups, fold_num, model_name, group_type="groups"):
    """
    Validate that groups don't leak between train and test sets.
    """
    train_set = set(train_groups)
    test_set = set(test_groups)
    overlap = train_set & test_set
    
    print(f"  [{model_name} - Fold {fold_num}] Group Validation:")
    print(f"    Train {group_type}: {len(train_set)}")
    print(f"    Test {group_type}:  {len(test_set)}")
    print(f"    Overlapping {group_type}: {len(overlap)}")
    
    if len(overlap) > 0:
        print(f"GROUP LEAKAGE DETECTED: {overlap}")
        return False
    else:
        print(f"No group leakage")
        return True

# %%
def model_early_cross_validation(classifier, data, target, splits, verbose=True, model_name="Model"):
    tprs = []
    fprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    pred_aucs, seq_aucs, gene_expr_aucs, gene_ess_aucs = [], [], [], []
    aps, pred_aps, seq_aps, gene_expr_aps, gene_ess_aps = [], [], [], [], []

    y_real = []
    y_proba = []

    stratification_results = []
    skipped_folds = []

    total_splits = len(splits)
    start_time = time.time()

    for fold_num, (train, test) in enumerate(splits, start=1):
        print(f"Fold {fold_num}: Train size = {len(train)}, Test size = {len(test)}")

        #print(f"\n=== {model_name} - Fold {fold_num}/{total_splits} ===")
        #print(f"Train size = {len(train)}, Test size = {len(test)}")

        if len(test) == 0:
            print(f"Skipping fold {fold_num}: Empty test set")
            skipped_folds.append(fold_num)
            continue

        # Get train/test data
        y_train = target.iloc[train].values
        y_test = target.iloc[test].values

        # validate stratification
        stratification_result = validate_stratification(y_train, y_test, fold_num, model_name)
        stratification_results.append(stratification_result)

        if np.unique(y_test).size < 2:
            print(f"Skipping fold {fold_num}: Insufficient positive/negative samples in test set")
            print(f"Test set classes: {np.unique(y_test)}")
            skipped_folds.append(fold_num)
            continue

        # Train the classifier and predict probabilities
        y_pred_proba = classifier.fit(data.iloc[train], target.iloc[train]).predict_proba(data.iloc[test])[:, 1]

        fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
        tprs.append(tpr)
        fprs.append(fpr)

        aucs.append(roc_auc_score(y_test, y_pred_proba))
        aps.append(average_precision_score(y_test, y_pred_proba))

        # Scores from input data columns
        pred_aucs.append(safe_roc_auc(y_test, data.iloc[test]['prediction_score'].values))
        seq_aucs.append(safe_roc_auc(y_test, data.iloc[test]['min_sequence_identity'].values))
        gene_expr_aucs.append(safe_roc_auc(y_test, data.iloc[test]['rMinExp_A1A2'].values))
        gene_ess_aucs.append(1 - safe_roc_auc(y_test, data.iloc[test]['min_ranked_A1A2'].values))

        pred_aps.append(safe_average_precision(y_test, data.iloc[test]['prediction_score'].values))
        seq_aps.append(safe_average_precision(y_test, data.iloc[test]['min_sequence_identity'].values))
        gene_expr_aps.append(safe_average_precision(y_test, data.iloc[test]['rMinExp_A1A2'].values))
        gene_ess_aps.append(safe_average_precision(y_test, data.iloc[test]['min_ranked_A1A2'].values))

        y_real.append(y_test)
        y_proba.append(y_pred_proba)

        if verbose:
            elapsed_time = time.time() - start_time
            print(f"  ROC AUC = {aucs[-1]:.4f}, Elapsed time = {elapsed_time:.2f} seconds")

    if len(tprs) > 0:
        mean_tpr = np.mean([np.interp(mean_fpr, fprs[i], tprs[i]) for i in range(len(tprs))], axis=0)
        mean_tpr[-1] = 1.0
        mean_auc = auc(mean_fpr, mean_tpr)
        std_auc = np.std(aucs)
    else:
        mean_tpr, mean_auc, std_auc = np.array([]), np.nan, np.nan

    if len(y_real) > 0 and len(y_proba) > 0:
        y_real = np.concatenate(y_real)
        y_proba = np.concatenate(y_proba)
        precision, recall, _ = precision_recall_curve(y_real, y_proba)
    else:
        precision, recall = np.array([]), np.array([])

    # Print summary
    print(f"\n=== {model_name} Summary ===")
    if not np.isnan(mean_auc):
        print(f"Mean ROC AUC = {mean_auc:.4f} ± {std_auc:.4f}")
    print(f"Successful folds: {len(aucs)}/{total_splits}")
    if skipped_folds:
        print(f"Skipped folds: {skipped_folds}")

    # Stratification summary
    if stratification_results:
        train_diffs = [r['train_diff'] for r in stratification_results]
        test_diffs = [r['test_diff'] for r in stratification_results]
        print(f"Stratification quality:")
        print(f"  Mean train deviation: {np.mean(train_diffs):.4f} ± {np.std(train_diffs):.4f}")
        print(f"  Mean test deviation:  {np.mean(test_diffs):.4f} ± {np.std(test_diffs):.4f}")


    return {
        'tprs': tprs, 'fprs': fprs, 'aucs': aucs,
        'mean_tpr': mean_tpr, 'mean_fpr': mean_fpr, 'mean_auc': mean_auc, 'std_auc': std_auc,
        'seq_auc': np.nanmean(seq_aucs), 'seq_std_auc': np.nanstd(seq_aucs),
        'pred_auc': np.nanmean(pred_aucs), 'pred_std_auc': np.nanstd(pred_aucs),
        'gene_expr_auc': np.nanmean(gene_expr_aucs), 'gene_expr_std_auc': np.nanstd(gene_expr_aucs),
        'gene_ess_auc': np.nanmean(gene_ess_aucs), 'gene_ess_std_auc': np.nanstd(gene_ess_aucs),
        'precision': precision, 'recall': recall, 'aps': aps,
        'mean_aps': np.nanmean(aps), 'std_ap': np.nanstd(aps),
        'pred_ap': np.nanmean(pred_aps), 'pred_std_ap': np.nanstd(pred_aps),
        'seq_ap': np.nanmean(seq_aps), 'seq_std_ap': np.nanstd(seq_aps),
        'gene_expr_ap': np.nanmean(gene_expr_aps), 'gene_expr_std_ap': np.nanstd(gene_expr_aps),
        'gene_ess_ap': np.nanmean(gene_ess_aps), 'gene_ess_std_ap': np.nanstd(gene_ess_aps),
        'stratification_results': stratification_results,
        'skipped_folds': skipped_folds,
        'effective_folds': len(aucs)
    }

# %%
def model_late_cross_validation(classifier, data, target, splits, verbose=True, model_name="Model"):
    tprs = []
    fprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)
    
    y_real = []
    y_proba = []
    aps = []

    # Track stratification validation results
    stratification_results = []
    skipped_folds = []
    
    total_splits = len(splits)
    start_time = time.time()

    for fold_num, (train, test) in enumerate(splits, start=1):
        print(f"\n=== {model_name} - Fold {fold_num}/{total_splits} ===")
        print(f"Train size = {len(train)}, Test size = {len(test)}")
        
        if len(test) == 0:
            print(f"Skipping fold {fold_num}: Empty test set")
            skipped_folds.append(fold_num)
            continue

        # Get train/test data
        y_train = target.iloc[train].values
        y_test = target.iloc[test].values

        # Validate stratification
        stratification_result = validate_stratification(y_train, y_test, fold_num, model_name)
        stratification_results.append(stratification_result)

        if np.unique(y_test).size < 2:
            print(f"Skipping fold {fold_num}: Insufficient positive/negative samples in test set")
            print(f"Test set classes: {np.unique(y_test)}")
            skipped_folds.append(fold_num)
            continue

        # Train model and get predictions
        y_pred_proba = classifier.fit(data.iloc[train], target.iloc[train]).predict_proba(data.iloc[test])[:, 1]

        fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
        tprs.append(tpr)
        fprs.append(fpr)

        aucs.append(safe_roc_auc(y_test, y_pred_proba))
        aps.append(safe_average_precision(y_test, y_pred_proba))

        y_real.append(y_test)
        y_proba.append(y_pred_proba)

        if verbose:
            elapsed_time = time.time() - start_time
            print(f"  ROC AUC = {aucs[-1]:.4f}, Elapsed time = {elapsed_time:.2f} seconds")
    
    if len(tprs) > 0:
        mean_tpr = np.mean([np.interp(mean_fpr, fprs[i], tprs[i]) for i in range(len(tprs))], axis=0)
        mean_tpr[-1] = 1.0
        mean_auc = auc(mean_fpr, mean_tpr)
        std_auc = np.std(aucs)
    else:
        mean_tpr, mean_auc, std_auc = np.array([]), np.nan, np.nan
    
    if len(y_real) > 0 and len(y_proba) > 0:
        y_real = np.concatenate(y_real)
        y_proba = np.concatenate(y_proba)
        precision, recall, _ = precision_recall_curve(y_real, y_proba)
    else:
        precision, recall = np.array([]), np.array([])

    # Print summary
    print(f"\n=== {model_name} Summary ===")
    if not np.isnan(mean_auc):
        print(f"Mean ROC AUC = {mean_auc:.4f} ± {std_auc:.4f}")
    print(f"Successful folds: {len(aucs)}/{total_splits}")
    if skipped_folds:
        print(f"Skipped folds: {skipped_folds}")

    # Stratification summary
    if stratification_results:
        train_diffs = [r['train_diff'] for r in stratification_results]
        test_diffs = [r['test_diff'] for r in stratification_results]
        print(f"Stratification quality:")
        print(f"Mean train deviation: {np.mean(train_diffs):.4f} ± {np.std(train_diffs):.4f}")
        print(f"Mean test deviation: {np.mean(test_diffs):.4f} ± {np.std(test_diffs):.4f}")

    return {
        'tprs': tprs, 'fprs': fprs, 'aucs': aucs,
        'mean_tpr': mean_tpr, 'mean_fpr': mean_fpr, 'mean_auc': mean_auc, 'std_auc': std_auc,
        'precision': precision, 'recall': recall, 'aps': aps,
        'mean_aps': np.nanmean(aps), 
        'std_ap': np.nanstd(aps),
        'stratification_results': stratification_results,
        'skipped_folds': skipped_folds,
        'effective_folds': len(aucs)
    }

# %%
# Define feature sets
data_1 = training_df[feature_columns_1]
data_2 = training_df[feature_columns_2]
target = training_df[target_column]

# Define your Random Forest classifier
RF = RandomForestClassifier(n_estimators=600, random_state=42, max_features=0.2, max_depth=20, min_samples_leaf=4)

# %%
# Define number of folds
nfolds = 5

# Generate StratifiedKFold splits
kf = StratifiedKFold(n_splits=nfolds, shuffle=True, random_state=42)
splits_I = list(kf.split(training_df[feature_columns_1], training_df[target_column]))

# %%
# Save splits
with open('/Users/narod/Library/CloudStorage/GoogleDrive-narod.kebabci@ucdconnect.ie/My Drive/GitRepos/context_specific_SL_prediction/output/models/model_I/splits.pkl', 'wb') as f:
    pickle.dump(splits_I, f)

# %%
#Run cross-validation on both feature set
model_I_early = model_early_cross_validation(RF, data_1, target, splits_I, model_name="Model I Early")
model_I_late = model_late_cross_validation(RF, data_2, target, splits_I, model_name="Model I Late")
# Out:
# Fold 1: Train size = 32995, Test size = 8249
#   [Model I Early - Fold 1] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9075, Elapsed time = 47.84 seconds
# Fold 2: Train size = 32995, Test size = 8249
#   [Model I Early - Fold 2] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9183, Elapsed time = 92.61 seconds
# Fold 3: Train size = 32995, Test size = 8249
#   [Model I Early - Fold 3] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9257, Elapsed time = 137.40 seconds
# Fold 4: Train size = 32995, Test size = 8249
#   [Model I Early - Fold 4] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9121, Elapsed time = 182.25 seconds
# Fold 5: Train size = 32996, Test size = 8248
#   [Model I Early - Fold 5] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9276, Elapsed time = 226.76 seconds
#
# === Model I Early Summary ===
# Mean ROC AUC = 0.9177 ± 0.0077
# Successful folds: 5/5
# Stratification quality:
#   Mean train deviation: 0.0000 ± 0.0000
#   Mean test deviation:  0.0001 ± 0.0000
#
# === Model I Late - Fold 1/5 ===
# Train size = 32995, Test size = 8249
#   [Model I Late - Fold 1] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9199, Elapsed time = 64.98 seconds
#
# === Model I Late - Fold 2/5 ===
# Train size = 32995, Test size = 8249
#   [Model I Late - Fold 2] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9327, Elapsed time = 133.15 seconds
#
# === Model I Late - Fold 3/5 ===
# Train size = 32995, Test size = 8249
#   [Model I Late - Fold 3] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9386, Elapsed time = 204.49 seconds
#
# === Model I Late - Fold 4/5 ===
# Train size = 32995, Test size = 8249
#   [Model I Late - Fold 4] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9277, Elapsed time = 274.78 seconds
#
# === Model I Late - Fold 5/5 ===
# Train size = 32996, Test size = 8248
#   [Model I Late - Fold 5] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9401, Elapsed time = 347.47 seconds
#
# === Model I Late Summary ===
# Mean ROC AUC = 0.9310 ± 0.0074
# Successful folds: 5/5
# Stratification quality:
# Mean train deviation: 0.0000 ± 0.0000
# Mean test deviation: 0.0001 ± 0.0000

# %%
# save results of cross validation
with open(file_RF_model_I_early, 'wb') as f:
   pickle.dump(model_I_early, f)


with open(file_RF_model_I_late, 'wb') as f:
    pickle.dump(model_I_late, f)

# %%
# Define RepeatedStratifiedKFold with 5 folds and 20 repeats
nfolds = 5
n_repeats = 10

rskf = RepeatedStratifiedKFold(n_splits=nfolds, n_repeats=n_repeats, random_state=42)
repeated_splits_I = list(rskf.split(training_df[feature_columns_1], training_df[target_column]))

# %%
# Save splits
with open('/Users/narod/Library/CloudStorage/GoogleDrive-narod.kebabci@ucdconnect.ie/My Drive/GitRepos/context_specific_SL_prediction/output/models/model_I/repeated_splits_I.pkl', 'wb') as f:
    pickle.dump(repeated_splits_I, f)

# %%
#Run cross-validation on both feature set
model_I_early_repeated = model_early_cross_validation(RF, data_1, target, repeated_splits_I, model_name="Model I Early Repeated")
model_I_late_repeated = model_late_cross_validation(RF, data_2, target, repeated_splits_I, model_name="Model I Late Repeated")
# Out:
# Fold 1: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 1] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9075, Elapsed time = 48.85 seconds
# Fold 2: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 2] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9183, Elapsed time = 98.27 seconds
# Fold 3: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 3] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9257, Elapsed time = 148.79 seconds
# Fold 4: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 4] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9121, Elapsed time = 198.51 seconds
# Fold 5: Train size = 32996, Test size = 8248
#   [Model I Early Repeated - Fold 5] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9276, Elapsed time = 280.40 seconds
# Fold 6: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 6] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9433, Elapsed time = 330.14 seconds
# Fold 7: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 7] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9243, Elapsed time = 400.51 seconds
# Fold 8: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 8] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9306, Elapsed time = 457.58 seconds
# Fold 9: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 9] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9052, Elapsed time = 509.28 seconds
# Fold 10: Train size = 32996, Test size = 8248
#   [Model I Early Repeated - Fold 10] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.8907, Elapsed time = 570.23 seconds
# Fold 11: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 11] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9311, Elapsed time = 629.86 seconds
# Fold 12: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 12] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9275, Elapsed time = 684.95 seconds
# Fold 13: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 13] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9067, Elapsed time = 748.80 seconds
# Fold 14: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 14] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9154, Elapsed time = 810.41 seconds
# Fold 15: Train size = 32996, Test size = 8248
#   [Model I Early Repeated - Fold 15] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9303, Elapsed time = 866.83 seconds
# Fold 16: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 16] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9261, Elapsed time = 924.76 seconds
# Fold 17: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 17] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9109, Elapsed time = 974.35 seconds
# Fold 18: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 18] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9353, Elapsed time = 1021.03 seconds
# Fold 19: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 19] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9222, Elapsed time = 1072.33 seconds
# Fold 20: Train size = 32996, Test size = 8248
#   [Model I Early Repeated - Fold 20] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9155, Elapsed time = 1116.60 seconds
# Fold 21: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 21] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9329, Elapsed time = 1160.95 seconds
# Fold 22: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 22] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9178, Elapsed time = 1204.53 seconds
# Fold 23: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 23] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9176, Elapsed time = 1248.51 seconds
# Fold 24: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 24] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9237, Elapsed time = 1292.78 seconds
# Fold 25: Train size = 32996, Test size = 8248
#   [Model I Early Repeated - Fold 25] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9249, Elapsed time = 1337.16 seconds
# Fold 26: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 26] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9218, Elapsed time = 1380.66 seconds
# Fold 27: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 27] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9295, Elapsed time = 1424.97 seconds
# Fold 28: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 28] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9170, Elapsed time = 1471.96 seconds
# Fold 29: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 29] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9184, Elapsed time = 1520.54 seconds
# Fold 30: Train size = 32996, Test size = 8248
#   [Model I Early Repeated - Fold 30] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9176, Elapsed time = 1568.49 seconds
# Fold 31: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 31] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9059, Elapsed time = 1617.03 seconds
# Fold 32: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 32] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9395, Elapsed time = 1664.96 seconds
# Fold 33: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 33] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9255, Elapsed time = 1712.27 seconds
# Fold 34: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 34] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9249, Elapsed time = 1761.01 seconds
# Fold 35: Train size = 32996, Test size = 8248
#   [Model I Early Repeated - Fold 35] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9147, Elapsed time = 1808.77 seconds
# Fold 36: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 36] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9247, Elapsed time = 1856.84 seconds
# Fold 37: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 37] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9200, Elapsed time = 1903.89 seconds
# Fold 38: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 38] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9324, Elapsed time = 1951.79 seconds
# Fold 39: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 39] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9333, Elapsed time = 1999.16 seconds
# Fold 40: Train size = 32996, Test size = 8248
#   [Model I Early Repeated - Fold 40] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9036, Elapsed time = 2047.02 seconds
# Fold 41: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 41] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9184, Elapsed time = 2094.17 seconds
# Fold 42: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 42] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9245, Elapsed time = 2142.07 seconds
# Fold 43: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 43] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9193, Elapsed time = 2189.23 seconds
# Fold 44: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 44] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9200, Elapsed time = 2236.60 seconds
# Fold 45: Train size = 32996, Test size = 8248
#   [Model I Early Repeated - Fold 45] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9250, Elapsed time = 2285.25 seconds
# Fold 46: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 46] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9323, Elapsed time = 2333.22 seconds
# Fold 47: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 47] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9194, Elapsed time = 2381.03 seconds
# Fold 48: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 48] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9092, Elapsed time = 2428.33 seconds
# Fold 49: Train size = 32995, Test size = 8249
#   [Model I Early Repeated - Fold 49] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9248, Elapsed time = 2474.94 seconds
# Fold 50: Train size = 32996, Test size = 8248
#   [Model I Early Repeated - Fold 50] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9189, Elapsed time = 2522.90 seconds
#
# === Model I Early Repeated Summary ===
# Mean ROC AUC = 0.9207 ± 0.0098
# Successful folds: 50/50
# Stratification quality:
#   Mean train deviation: 0.0000 ± 0.0000
#   Mean test deviation:  0.0001 ± 0.0000
#
# === Model I Late Repeated - Fold 1/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 1] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9199, Elapsed time = 69.27 seconds
#
# === Model I Late Repeated - Fold 2/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 2] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9327, Elapsed time = 139.59 seconds
#
# === Model I Late Repeated - Fold 3/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 3] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9386, Elapsed time = 208.17 seconds
#
# === Model I Late Repeated - Fold 4/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 4] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9277, Elapsed time = 276.82 seconds
#
# === Model I Late Repeated - Fold 5/50 ===
# Train size = 32996, Test size = 8248
#   [Model I Late Repeated - Fold 5] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9401, Elapsed time = 347.04 seconds
#
# === Model I Late Repeated - Fold 6/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 6] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9512, Elapsed time = 415.94 seconds
#
# === Model I Late Repeated - Fold 7/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 7] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9337, Elapsed time = 485.65 seconds
#
# === Model I Late Repeated - Fold 8/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 8] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9376, Elapsed time = 555.15 seconds
#
# === Model I Late Repeated - Fold 9/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 9] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9205, Elapsed time = 625.47 seconds
#
# === Model I Late Repeated - Fold 10/50 ===
# Train size = 32996, Test size = 8248
#   [Model I Late Repeated - Fold 10] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9067, Elapsed time = 696.35 seconds
#
# === Model I Late Repeated - Fold 11/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 11] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9417, Elapsed time = 765.03 seconds
#
# === Model I Late Repeated - Fold 12/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 12] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9397, Elapsed time = 834.53 seconds
#
# === Model I Late Repeated - Fold 13/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 13] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9160, Elapsed time = 905.86 seconds
#
# === Model I Late Repeated - Fold 14/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 14] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9284, Elapsed time = 975.52 seconds
#
# === Model I Late Repeated - Fold 15/50 ===
# Train size = 32996, Test size = 8248
#   [Model I Late Repeated - Fold 15] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9403, Elapsed time = 1043.87 seconds
#
# === Model I Late Repeated - Fold 16/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 16] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9384, Elapsed time = 1113.26 seconds
#
# === Model I Late Repeated - Fold 17/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 17] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9220, Elapsed time = 1182.41 seconds
#
# === Model I Late Repeated - Fold 18/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 18] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9431, Elapsed time = 1251.33 seconds
#
# === Model I Late Repeated - Fold 19/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 19] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9368, Elapsed time = 1320.46 seconds
#
# === Model I Late Repeated - Fold 20/50 ===
# Train size = 32996, Test size = 8248
#   [Model I Late Repeated - Fold 20] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9271, Elapsed time = 1389.40 seconds
#
# === Model I Late Repeated - Fold 21/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 21] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9446, Elapsed time = 1459.83 seconds
#
# === Model I Late Repeated - Fold 22/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 22] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9220, Elapsed time = 1528.03 seconds
#
# === Model I Late Repeated - Fold 23/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 23] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9302, Elapsed time = 1597.53 seconds
#
# === Model I Late Repeated - Fold 24/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 24] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9355, Elapsed time = 1666.44 seconds
#
# === Model I Late Repeated - Fold 25/50 ===
# Train size = 32996, Test size = 8248
#   [Model I Late Repeated - Fold 25] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9373, Elapsed time = 1736.58 seconds
#
# === Model I Late Repeated - Fold 26/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 26] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9396, Elapsed time = 1804.43 seconds
#
# === Model I Late Repeated - Fold 27/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 27] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9375, Elapsed time = 1874.16 seconds
#
# === Model I Late Repeated - Fold 28/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 28] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9384, Elapsed time = 1942.63 seconds
#
# === Model I Late Repeated - Fold 29/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 29] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9264, Elapsed time = 2012.49 seconds
#
# === Model I Late Repeated - Fold 30/50 ===
# Train size = 32996, Test size = 8248
#   [Model I Late Repeated - Fold 30] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9329, Elapsed time = 2081.77 seconds
#
# === Model I Late Repeated - Fold 31/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 31] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9206, Elapsed time = 2153.24 seconds
#
# === Model I Late Repeated - Fold 32/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 32] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9468, Elapsed time = 2221.82 seconds
#
# === Model I Late Repeated - Fold 33/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 33] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9333, Elapsed time = 2290.39 seconds
#
# === Model I Late Repeated - Fold 34/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 34] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9372, Elapsed time = 2357.11 seconds
#
# === Model I Late Repeated - Fold 35/50 ===
# Train size = 32996, Test size = 8248
#   [Model I Late Repeated - Fold 35] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9294, Elapsed time = 2420.48 seconds
#
# === Model I Late Repeated - Fold 36/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 36] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9345, Elapsed time = 2491.56 seconds
#
# === Model I Late Repeated - Fold 37/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 37] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9320, Elapsed time = 2561.99 seconds
#
# === Model I Late Repeated - Fold 38/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 38] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9428, Elapsed time = 2632.91 seconds
#
# === Model I Late Repeated - Fold 39/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 39] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9483, Elapsed time = 2704.37 seconds
#
# === Model I Late Repeated - Fold 40/50 ===
# Train size = 32996, Test size = 8248
#   [Model I Late Repeated - Fold 40] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9183, Elapsed time = 2775.73 seconds
#
# === Model I Late Repeated - Fold 41/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 41] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9343, Elapsed time = 2847.53 seconds
#
# === Model I Late Repeated - Fold 42/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 42] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9282, Elapsed time = 2919.40 seconds
#
# === Model I Late Repeated - Fold 43/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 43] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9383, Elapsed time = 2988.71 seconds
#
# === Model I Late Repeated - Fold 44/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 44] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9348, Elapsed time = 3058.41 seconds
#
# === Model I Late Repeated - Fold 45/50 ===
# Train size = 32996, Test size = 8248
#   [Model I Late Repeated - Fold 45] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9323, Elapsed time = 3130.13 seconds
#
# === Model I Late Repeated - Fold 46/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 46] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9382, Elapsed time = 3200.86 seconds
#
# === Model I Late Repeated - Fold 47/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 47] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9306, Elapsed time = 3271.58 seconds
#
# === Model I Late Repeated - Fold 48/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 48] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9258, Elapsed time = 3340.63 seconds
#
# === Model I Late Repeated - Fold 49/50 ===
# Train size = 32995, Test size = 8249
#   [Model I Late Repeated - Fold 49] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9373, Elapsed time = 3410.90 seconds
#
# === Model I Late Repeated - Fold 50/50 ===
# Train size = 32996, Test size = 8248
#   [Model I Late Repeated - Fold 50] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0232 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9362, Elapsed time = 3483.66 seconds
#
# === Model I Late Repeated Summary ===
# Mean ROC AUC = 0.9327 ± 0.0087
# Successful folds: 50/50
# Stratification quality:
# Mean train deviation: 0.0000 ± 0.0000
# Mean test deviation: 0.0001 ± 0.0000

# %%
# save results of cross validation
with open(file_RF_model_I_early_repeated, 'wb') as f:
    pickle.dump(model_I_early_repeated, f)

with open(file_RF_model_I_late_repeated, 'wb') as f:
    pickle.dump(model_I_late_repeated, f)

# %% [markdown]
# ## Model II
# #### Same paralog pairs, different cell lines

# %%
# Define group feature for cell lines
cell_line_groups = training_df['cell_line']

sgkf = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=42)
splits_II = list(sgkf.split(training_df, target, cell_line_groups))

# Model II - Cell line validation
print("=== MODEL II: CELL LINE VALIDATION ===")
for i, (train_index, test_index) in enumerate(splits_II):
    train_cells = training_df.loc[train_index, 'cell_line'].unique()
    test_cells = training_df.loc[test_index, 'cell_line'].unique()
    validate_group_splits(train_cells, test_cells, i+1, "Model II", "cell lines")
# Out:
# === MODEL II: CELL LINE VALIDATION ===
#   [Model II - Fold 1] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 2] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 3] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 4] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 5] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage

# %%
# Save splits
with open('/Users/narod/Library/CloudStorage/GoogleDrive-narod.kebabci@ucdconnect.ie/My Drive/GitRepos/context_specific_SL_prediction/output/models/model_II/splits_II.pkl', 'wb') as f:
    pickle.dump(splits_II, f)

# %%
model_II_early = model_early_cross_validation(RF, data_1, target, splits_II, model_name="Model II Early")
model_II_late = model_late_cross_validation(RF, data_2, target, splits_II, model_name="Model II Late")
# Out:
# Fold 1: Train size = 32973, Test size = 8271
#   [Model II Early - Fold 1] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0266 (diff: 0.0034)
#     Test SL rate:    0.0097 (diff: 0.0136)
#     Train/Test diff: 0.0170
# Stratification OK
#   ROC AUC = 0.9577, Elapsed time = 49.50 seconds
# Fold 2: Train size = 32978, Test size = 8266
#   [Model II Early - Fold 2] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0213 (diff: 0.0020)
#     Test SL rate:    0.0311 (diff: 0.0079)
#     Train/Test diff: 0.0098
# Stratification OK
#   ROC AUC = 0.9269, Elapsed time = 96.91 seconds
# Fold 3: Train size = 33018, Test size = 8226
#   [Model II Early - Fold 3] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0235 (diff: 0.0003)
#     Test SL rate:    0.0220 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.8787, Elapsed time = 146.10 seconds
# Fold 4: Train size = 32992, Test size = 8252
#   [Model II Early - Fold 4] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0220 (diff: 0.0012)
#     Test SL rate:    0.0281 (diff: 0.0049)
#     Train/Test diff: 0.0061
# Stratification OK
#   ROC AUC = 0.8837, Elapsed time = 193.28 seconds
# Fold 5: Train size = 33015, Test size = 8229
#   [Model II Early - Fold 5] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0227 (diff: 0.0005)
#     Test SL rate:    0.0253 (diff: 0.0020)
#     Train/Test diff: 0.0026
# Stratification OK
#   ROC AUC = 0.8556, Elapsed time = 239.99 seconds
#
# === Model II Early Summary ===
# Mean ROC AUC = 0.8999 ± 0.0367
# Successful folds: 5/5
# Stratification quality:
#   Mean train deviation: 0.0015 ± 0.0011
#   Mean test deviation:  0.0059 ± 0.0045
#
# === Model II Late - Fold 1/5 ===
# Train size = 32973, Test size = 8271
#   [Model II Late - Fold 1] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0266 (diff: 0.0034)
#     Test SL rate:    0.0097 (diff: 0.0136)
#     Train/Test diff: 0.0170
# Stratification OK
#   ROC AUC = 0.9710, Elapsed time = 70.41 seconds
#
# === Model II Late - Fold 2/5 ===
# Train size = 32978, Test size = 8266
#   [Model II Late - Fold 2] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0213 (diff: 0.0020)
#     Test SL rate:    0.0311 (diff: 0.0079)
#     Train/Test diff: 0.0098
# Stratification OK
#   ROC AUC = 0.9412, Elapsed time = 139.70 seconds
#
# === Model II Late - Fold 3/5 ===
# Train size = 33018, Test size = 8226
#   [Model II Late - Fold 3] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0235 (diff: 0.0003)
#     Test SL rate:    0.0220 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.9010, Elapsed time = 212.35 seconds
#
# === Model II Late - Fold 4/5 ===
# Train size = 32992, Test size = 8252
#   [Model II Late - Fold 4] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0220 (diff: 0.0012)
#     Test SL rate:    0.0281 (diff: 0.0049)
#     Train/Test diff: 0.0061
# Stratification OK
#   ROC AUC = 0.9078, Elapsed time = 281.31 seconds
#
# === Model II Late - Fold 5/5 ===
# Train size = 33015, Test size = 8229
#   [Model II Late - Fold 5] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0227 (diff: 0.0005)
#     Test SL rate:    0.0253 (diff: 0.0020)
#     Train/Test diff: 0.0026
# Stratification OK
#   ROC AUC = 0.8732, Elapsed time = 348.82 seconds
#
# === Model II Late Summary ===
# Mean ROC AUC = 0.9182 ± 0.0339
# Successful folds: 5/5
# Stratification quality:
# Mean train deviation: 0.0015 ± 0.0011
# Mean test deviation: 0.0059 ± 0.0045

# %%
# save results of cross validation
with open(file_RF_model_II_early, 'wb') as f:
    pickle.dump(model_II_early, f)

with open(file_RF_model_II_late, 'wb') as f:
    pickle.dump(model_II_late, f)

# %%
def repeated_stratified_group_kfold(data, target, groups, n_folds, n_repeats=n_repeats, random_state=42):
    
    all_splits = []
    
    for repeat in range(n_repeats):
        # Set up StratifiedGroupKFold with an incremented random state for each repeat
        sgkf = StratifiedGroupKFold(n_splits=n_folds, shuffle=True, random_state=random_state + repeat)
        splits = list(sgkf.split(data, target, groups))
        
        # Append each split (train_index, test_index) to all_splits
        for fold_num, (train_index, test_index) in enumerate(splits, start=1):
            all_splits.append((train_index, test_index))
            
            # Print fold details for tracking
            print(f"Repeat {repeat + 1}, Fold {fold_num}:")
            print(f"  TRAIN groups: {groups.iloc[train_index].unique()}")
            print(f"  TEST groups: {groups.iloc[test_index].unique()}")

    return all_splits

# Generate the repeated stratified group k-fold splits
repeated_splits_II = repeated_stratified_group_kfold(
    data=training_df,
    target=target,
    groups=cell_line_groups,
    n_folds=5,
    n_repeats=10,
    random_state=42
)
# Out:
# Repeat 1, Fold 1:
#   TRAIN groups: ['PK1_PANCREAS' 'A549_LUNG' 'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN'
#  'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['PATU8988S_PANCREAS' 'HS944T_SKIN']
# Repeat 1, Fold 2:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'MEL202_UVEA']
#   TEST groups: ['IPC298_SKIN' 'HSC5_SKIN']
# Repeat 1, Fold 3:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN'
#  'HSC5_SKIN']
#   TEST groups: ['A549_LUNG' 'MEL202_UVEA']
# Repeat 1, Fold 4:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN'
#  'MEL202_UVEA']
#   TEST groups: ['PK1_PANCREAS' 'HS936T_SKIN']
# Repeat 1, Fold 5:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'HS936T_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['GI1_CENTRAL_NERVOUS_SYSTEM' 'MELJUSO_SKIN']
# Repeat 2, Fold 1:
#   TRAIN groups: ['PK1_PANCREAS' 'HS944T_SKIN' 'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN'
#  'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['PATU8988S_PANCREAS' 'A549_LUNG']
# Repeat 2, Fold 2:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'IPC298_SKIN' 'MEL202_UVEA']
#   TEST groups: ['MELJUSO_SKIN' 'HSC5_SKIN']
# Repeat 2, Fold 3:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'A549_LUNG' 'HS936T_SKIN'
#  'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['HS944T_SKIN' 'GI1_CENTRAL_NERVOUS_SYSTEM']
# Repeat 2, Fold 4:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'MELJUSO_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['HS936T_SKIN' 'IPC298_SKIN']
# Repeat 2, Fold 5:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN'
#  'HSC5_SKIN']
#   TEST groups: ['PK1_PANCREAS' 'MEL202_UVEA']
# Repeat 3, Fold 1:
#   TRAIN groups: ['PK1_PANCREAS' 'A549_LUNG' 'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN'
#  'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['PATU8988S_PANCREAS' 'HS944T_SKIN']
# Repeat 3, Fold 2:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'HS936T_SKIN'
#  'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['A549_LUNG' 'GI1_CENTRAL_NERVOUS_SYSTEM']
# Repeat 3, Fold 3:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'MELJUSO_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['HS936T_SKIN' 'IPC298_SKIN']
# Repeat 3, Fold 4:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN']
#   TEST groups: ['HSC5_SKIN' 'MEL202_UVEA']
# Repeat 3, Fold 5:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'IPC298_SKIN' 'HSC5_SKIN'
#  'MEL202_UVEA']
#   TEST groups: ['PK1_PANCREAS' 'MELJUSO_SKIN']
# Repeat 4, Fold 1:
#   TRAIN groups: ['HS944T_SKIN' 'A549_LUNG' 'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN'
#  'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS']
# Repeat 4, Fold 2:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'IPC298_SKIN' 'HSC5_SKIN'
#  'MEL202_UVEA']
#   TEST groups: ['A549_LUNG' 'MELJUSO_SKIN']
# Repeat 4, Fold 3:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN'
#  'MEL202_UVEA']
#   TEST groups: ['HS944T_SKIN' 'HSC5_SKIN']
# Repeat 4, Fold 4:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'HSC5_SKIN']
#   TEST groups: ['IPC298_SKIN' 'MEL202_UVEA']
# Repeat 4, Fold 5:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN']
# Repeat 5, Fold 1:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'HS936T_SKIN' 'MELJUSO_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['GI1_CENTRAL_NERVOUS_SYSTEM' 'IPC298_SKIN']
# Repeat 5, Fold 2:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN'
#  'HSC5_SKIN']
#   TEST groups: ['A549_LUNG' 'MEL202_UVEA']
# Repeat 5, Fold 3:
#   TRAIN groups: ['PK1_PANCREAS' 'A549_LUNG' 'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN'
#  'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['PATU8988S_PANCREAS' 'HS944T_SKIN']
# Repeat 5, Fold 4:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN'
#  'MEL202_UVEA']
#   TEST groups: ['PK1_PANCREAS' 'HSC5_SKIN']
# Repeat 5, Fold 5:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['HS936T_SKIN' 'MELJUSO_SKIN']
# Repeat 6, Fold 1:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN']
#   TEST groups: ['HSC5_SKIN' 'MEL202_UVEA']
# Repeat 6, Fold 2:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'HS944T_SKIN' 'GI1_CENTRAL_NERVOUS_SYSTEM'
#  'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['PK1_PANCREAS' 'A549_LUNG']
# Repeat 6, Fold 3:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['MELJUSO_SKIN' 'IPC298_SKIN']
# Repeat 6, Fold 4:
#   TRAIN groups: ['PK1_PANCREAS' 'A549_LUNG' 'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN'
#  'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['PATU8988S_PANCREAS' 'HS944T_SKIN']
# Repeat 6, Fold 5:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN']
# Repeat 7, Fold 1:
#   TRAIN groups: ['HS944T_SKIN' 'A549_LUNG' 'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN'
#  'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS']
# Repeat 7, Fold 2:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN'
#  'MEL202_UVEA']
#   TEST groups: ['A549_LUNG' 'HS936T_SKIN']
# Repeat 7, Fold 3:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'MEL202_UVEA']
#   TEST groups: ['IPC298_SKIN' 'HSC5_SKIN']
# Repeat 7, Fold 4:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'A549_LUNG' 'HS936T_SKIN'
#  'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['HS944T_SKIN' 'GI1_CENTRAL_NERVOUS_SYSTEM']
# Repeat 7, Fold 5:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'IPC298_SKIN' 'HSC5_SKIN']
#   TEST groups: ['MELJUSO_SKIN' 'MEL202_UVEA']
# Repeat 8, Fold 1:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN']
# Repeat 8, Fold 2:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'MEL202_UVEA']
#   TEST groups: ['IPC298_SKIN' 'HSC5_SKIN']
# Repeat 8, Fold 3:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'HS944T_SKIN' 'GI1_CENTRAL_NERVOUS_SYSTEM'
#  'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['PK1_PANCREAS' 'A549_LUNG']
# Repeat 8, Fold 4:
#   TRAIN groups: ['PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG' 'GI1_CENTRAL_NERVOUS_SYSTEM'
#  'HS936T_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['PATU8988S_PANCREAS' 'MELJUSO_SKIN']
# Repeat 8, Fold 5:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN'
#  'HSC5_SKIN']
#   TEST groups: ['HS944T_SKIN' 'MEL202_UVEA']
# Repeat 9, Fold 1:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'IPC298_SKIN' 'HSC5_SKIN'
#  'MEL202_UVEA']
#   TEST groups: ['PK1_PANCREAS' 'MELJUSO_SKIN']
# Repeat 9, Fold 2:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'GI1_CENTRAL_NERVOUS_SYSTEM'
#  'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['HS944T_SKIN' 'A549_LUNG']
# Repeat 9, Fold 3:
#   TRAIN groups: ['PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG' 'HS936T_SKIN' 'MELJUSO_SKIN'
#  'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['PATU8988S_PANCREAS' 'GI1_CENTRAL_NERVOUS_SYSTEM']
# Repeat 9, Fold 4:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN']
#   TEST groups: ['HS936T_SKIN' 'MEL202_UVEA']
# Repeat 9, Fold 5:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'MEL202_UVEA']
#   TEST groups: ['IPC298_SKIN' 'HSC5_SKIN']
# Repeat 10, Fold 1:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'IPC298_SKIN' 'HSC5_SKIN'
#  'MEL202_UVEA']
#   TEST groups: ['A549_LUNG' 'MELJUSO_SKIN']
# Repeat 10, Fold 2:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'MELJUSO_SKIN' 'IPC298_SKIN' 'MEL202_UVEA']
#   TEST groups: ['HS936T_SKIN' 'HSC5_SKIN']
# Repeat 10, Fold 3:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'HSC5_SKIN'
#  'MEL202_UVEA']
#   TEST groups: ['PK1_PANCREAS' 'IPC298_SKIN']
# Repeat 10, Fold 4:
#   TRAIN groups: ['PK1_PANCREAS' 'A549_LUNG' 'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN'
#  'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['PATU8988S_PANCREAS' 'HS944T_SKIN']
# Repeat 10, Fold 5:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN']
#   TEST groups: ['GI1_CENTRAL_NERVOUS_SYSTEM' 'MEL202_UVEA']

# %%
# Save splits
with open('/Users/narod/Library/CloudStorage/GoogleDrive-narod.kebabci@ucdconnect.ie/My Drive/GitRepos/context_specific_SL_prediction/output/models/model_II/repeated_splits_II.pkl', 'wb') as f:
    pickle.dump(repeated_splits_II, f)

# %%
#Run cross-validation on both feature set
model_II_early_repeated = model_early_cross_validation(RF, data_1, target, repeated_splits_II, model_name="Model II Early Repeated")
model_II_late_repeated = model_late_cross_validation(RF, data_2, target, repeated_splits_II, model_name="Model II Late Repeated")
# Out:
# Fold 1: Train size = 32973, Test size = 8271
#   [Model II Early Repeated - Fold 1] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0266 (diff: 0.0034)
#     Test SL rate:    0.0097 (diff: 0.0136)
#     Train/Test diff: 0.0170
# Stratification OK
#   ROC AUC = 0.9577, Elapsed time = 49.36 seconds
# Fold 2: Train size = 32978, Test size = 8266
#   [Model II Early Repeated - Fold 2] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0213 (diff: 0.0020)
#     Test SL rate:    0.0311 (diff: 0.0079)
#     Train/Test diff: 0.0098
# Stratification OK
#   ROC AUC = 0.9269, Elapsed time = 97.50 seconds
# Fold 3: Train size = 33018, Test size = 8226
#   [Model II Early Repeated - Fold 3] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0235 (diff: 0.0003)
#     Test SL rate:    0.0220 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.8787, Elapsed time = 146.91 seconds
# Fold 4: Train size = 32992, Test size = 8252
#   [Model II Early Repeated - Fold 4] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0220 (diff: 0.0012)
#     Test SL rate:    0.0281 (diff: 0.0049)
#     Train/Test diff: 0.0061
# Stratification OK
#   ROC AUC = 0.8837, Elapsed time = 194.33 seconds
# Fold 5: Train size = 33015, Test size = 8229
#   [Model II Early Repeated - Fold 5] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0227 (diff: 0.0005)
#     Test SL rate:    0.0253 (diff: 0.0020)
#     Train/Test diff: 0.0026
# Stratification OK
#   ROC AUC = 0.8556, Elapsed time = 241.29 seconds
# Fold 6: Train size = 33032, Test size = 8212
#   [Model II Early Repeated - Fold 6] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0251 (diff: 0.0018)
#     Test SL rate:    0.0158 (diff: 0.0074)
#     Train/Test diff: 0.0092
# Stratification OK
#   ROC AUC = 0.9055, Elapsed time = 289.01 seconds
# Fold 7: Train size = 33032, Test size = 8212
#   [Model II Early Repeated - Fold 7] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0253 (diff: 0.0021)
#     Test SL rate:    0.0150 (diff: 0.0082)
#     Train/Test diff: 0.0103
# Stratification OK
#   ROC AUC = 0.9239, Elapsed time = 337.93 seconds
# Fold 8: Train size = 32954, Test size = 8290
#   [Model II Early Repeated - Fold 8] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0221 (diff: 0.0011)
#     Test SL rate:    0.0276 (diff: 0.0044)
#     Train/Test diff: 0.0055
# Stratification OK
#   ROC AUC = 0.8586, Elapsed time = 384.49 seconds
# Fold 9: Train size = 32993, Test size = 8251
#   [Model II Early Repeated - Fold 9] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0205 (diff: 0.0028)
#     Test SL rate:    0.0343 (diff: 0.0111)
#     Train/Test diff: 0.0138
# Stratification OK
#   ROC AUC = 0.9091, Elapsed time = 432.32 seconds
# Fold 10: Train size = 32965, Test size = 8279
#   [Model II Early Repeated - Fold 10] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.8901, Elapsed time = 480.97 seconds
# Fold 11: Train size = 32973, Test size = 8271
#   [Model II Early Repeated - Fold 11] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0266 (diff: 0.0034)
#     Test SL rate:    0.0097 (diff: 0.0136)
#     Train/Test diff: 0.0170
# Stratification OK
#   ROC AUC = 0.9577, Elapsed time = 529.10 seconds
# Fold 12: Train size = 33013, Test size = 8231
#   [Model II Early Repeated - Fold 12] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0206 (diff: 0.0027)
#     Test SL rate:    0.0339 (diff: 0.0107)
#     Train/Test diff: 0.0133
# Stratification OK
#   ROC AUC = 0.8505, Elapsed time = 574.97 seconds
# Fold 13: Train size = 32993, Test size = 8251
#   [Model II Early Repeated - Fold 13] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0205 (diff: 0.0028)
#     Test SL rate:    0.0343 (diff: 0.0111)
#     Train/Test diff: 0.0138
# Stratification OK
#   ROC AUC = 0.9091, Elapsed time = 622.68 seconds
# Fold 14: Train size = 32970, Test size = 8274
#   [Model II Early Repeated - Fold 14] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0239 (diff: 0.0006)
#     Test SL rate:    0.0207 (diff: 0.0026)
#     Train/Test diff: 0.0032
# Stratification OK
#   ROC AUC = 0.8865, Elapsed time = 673.15 seconds
# Fold 15: Train size = 33027, Test size = 8217
#   [Model II Early Repeated - Fold 15] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0246 (diff: 0.0014)
#     Test SL rate:    0.0176 (diff: 0.0056)
#     Train/Test diff: 0.0070
# Stratification OK
#   ROC AUC = 0.9125, Elapsed time = 720.46 seconds
# Fold 16: Train size = 32979, Test size = 8265
#   [Model II Early Repeated - Fold 16] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0247 (diff: 0.0015)
#     Test SL rate:    0.0172 (diff: 0.0060)
#     Train/Test diff: 0.0076
# Stratification OK
#   ROC AUC = 0.9042, Elapsed time = 767.50 seconds
# Fold 17: Train size = 33080, Test size = 8164
#   [Model II Early Repeated - Fold 17] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0249 (diff: 0.0017)
#     Test SL rate:    0.0163 (diff: 0.0069)
#     Train/Test diff: 0.0086
# Stratification OK
#   ROC AUC = 0.9083, Elapsed time = 815.17 seconds
# Fold 18: Train size = 32971, Test size = 8273
#   [Model II Early Repeated - Fold 18] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0247 (diff: 0.0015)
#     Test SL rate:    0.0174 (diff: 0.0058)
#     Train/Test diff: 0.0073
# Stratification OK
#   ROC AUC = 0.9179, Elapsed time = 864.01 seconds
# Fold 19: Train size = 32966, Test size = 8278
#   [Model II Early Repeated - Fold 19] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0217 (diff: 0.0016)
#     Test SL rate:    0.0295 (diff: 0.0062)
#     Train/Test diff: 0.0078
# Stratification OK
#   ROC AUC = 0.9217, Elapsed time = 912.55 seconds
# Fold 20: Train size = 32980, Test size = 8264
#   [Model II Early Repeated - Fold 20] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0201 (diff: 0.0031)
#     Test SL rate:    0.0357 (diff: 0.0125)
#     Train/Test diff: 0.0156
# Stratification OK
#   ROC AUC = 0.8424, Elapsed time = 958.85 seconds
# Fold 21: Train size = 32961, Test size = 8283
#   [Model II Early Repeated - Fold 21] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0187 (diff: 0.0045)
#     Test SL rate:    0.0413 (diff: 0.0181)
#     Train/Test diff: 0.0226
# Stratification OK
#   ROC AUC = 0.8704, Elapsed time = 1004.86 seconds
# Fold 22: Train size = 33018, Test size = 8226
#   [Model II Early Repeated - Fold 22] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0235 (diff: 0.0003)
#     Test SL rate:    0.0220 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.8787, Elapsed time = 1054.33 seconds
# Fold 23: Train size = 32973, Test size = 8271
#   [Model II Early Repeated - Fold 23] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0266 (diff: 0.0034)
#     Test SL rate:    0.0097 (diff: 0.0136)
#     Train/Test diff: 0.0170
# Stratification OK
#   ROC AUC = 0.9577, Elapsed time = 1102.36 seconds
# Fold 24: Train size = 32977, Test size = 8267
#   [Model II Early Repeated - Fold 24] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0228 (diff: 0.0004)
#     Test SL rate:    0.0249 (diff: 0.0017)
#     Train/Test diff: 0.0021
# Stratification OK
#   ROC AUC = 0.8891, Elapsed time = 1149.61 seconds
# Fold 25: Train size = 33047, Test size = 8197
#   [Model II Early Repeated - Fold 25] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0245 (diff: 0.0013)
#     Test SL rate:    0.0182 (diff: 0.0051)
#     Train/Test diff: 0.0063
# Stratification OK
#   ROC AUC = 0.8991, Elapsed time = 1198.20 seconds
# Fold 26: Train size = 32970, Test size = 8274
#   [Model II Early Repeated - Fold 26] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0239 (diff: 0.0006)
#     Test SL rate:    0.0207 (diff: 0.0026)
#     Train/Test diff: 0.0032
# Stratification OK
#   ROC AUC = 0.8865, Elapsed time = 1248.82 seconds
# Fold 27: Train size = 33025, Test size = 8219
#   [Model II Early Repeated - Fold 27] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0225 (diff: 0.0008)
#     Test SL rate:    0.0263 (diff: 0.0031)
#     Train/Test diff: 0.0038
# Stratification OK
#   ROC AUC = 0.8800, Elapsed time = 1295.57 seconds
# Fold 28: Train size = 33028, Test size = 8216
#   [Model II Early Repeated - Fold 28] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0231 (diff: 0.0002)
#     Test SL rate:    0.0239 (diff: 0.0006)
#     Train/Test diff: 0.0008
# Stratification OK
#   ROC AUC = 0.9501, Elapsed time = 1344.26 seconds
# Fold 29: Train size = 32973, Test size = 8271
#   [Model II Early Repeated - Fold 29] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0266 (diff: 0.0034)
#     Test SL rate:    0.0097 (diff: 0.0136)
#     Train/Test diff: 0.0170
# Stratification OK
#   ROC AUC = 0.9577, Elapsed time = 1393.17 seconds
# Fold 30: Train size = 32980, Test size = 8264
#   [Model II Early Repeated - Fold 30] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0201 (diff: 0.0031)
#     Test SL rate:    0.0357 (diff: 0.0125)
#     Train/Test diff: 0.0156
# Stratification OK
#   ROC AUC = 0.8424, Elapsed time = 1440.21 seconds
# Fold 31: Train size = 32979, Test size = 8265
#   [Model II Early Repeated - Fold 31] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0247 (diff: 0.0015)
#     Test SL rate:    0.0172 (diff: 0.0060)
#     Train/Test diff: 0.0076
# Stratification OK
#   ROC AUC = 0.9042, Elapsed time = 1487.91 seconds
# Fold 32: Train size = 33045, Test size = 8199
#   [Model II Early Repeated - Fold 32] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0223 (diff: 0.0009)
#     Test SL rate:    0.0268 (diff: 0.0036)
#     Train/Test diff: 0.0045
# Stratification OK
#   ROC AUC = 0.8807, Elapsed time = 1537.04 seconds
# Fold 33: Train size = 32978, Test size = 8266
#   [Model II Early Repeated - Fold 33] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0213 (diff: 0.0020)
#     Test SL rate:    0.0311 (diff: 0.0079)
#     Train/Test diff: 0.0098
# Stratification OK
#   ROC AUC = 0.9269, Elapsed time = 1585.08 seconds
# Fold 34: Train size = 32954, Test size = 8290
#   [Model II Early Repeated - Fold 34] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0221 (diff: 0.0011)
#     Test SL rate:    0.0276 (diff: 0.0044)
#     Train/Test diff: 0.0055
# Stratification OK
#   ROC AUC = 0.8586, Elapsed time = 1632.74 seconds
# Fold 35: Train size = 33020, Test size = 8224
#   [Model II Early Repeated - Fold 35] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0257 (diff: 0.0025)
#     Test SL rate:    0.0134 (diff: 0.0099)
#     Train/Test diff: 0.0123
# Stratification OK
#   ROC AUC = 0.9151, Elapsed time = 1683.13 seconds
# Fold 36: Train size = 32980, Test size = 8264
#   [Model II Early Repeated - Fold 36] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0201 (diff: 0.0031)
#     Test SL rate:    0.0357 (diff: 0.0125)
#     Train/Test diff: 0.0156
# Stratification OK
#   ROC AUC = 0.8424, Elapsed time = 1731.07 seconds
# Fold 37: Train size = 32978, Test size = 8266
#   [Model II Early Repeated - Fold 37] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0213 (diff: 0.0020)
#     Test SL rate:    0.0311 (diff: 0.0079)
#     Train/Test diff: 0.0098
# Stratification OK
#   ROC AUC = 0.9269, Elapsed time = 1775.14 seconds
# Fold 38: Train size = 33025, Test size = 8219
#   [Model II Early Repeated - Fold 38] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0225 (diff: 0.0008)
#     Test SL rate:    0.0263 (diff: 0.0031)
#     Train/Test diff: 0.0038
# Stratification OK
#   ROC AUC = 0.8800, Elapsed time = 1818.25 seconds
# Fold 39: Train size = 33034, Test size = 8210
#   [Model II Early Repeated - Fold 39] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0272 (diff: 0.0040)
#     Test SL rate:    0.0072 (diff: 0.0160)
#     Train/Test diff: 0.0200
# Stratification OK
#   ROC AUC = 0.9708, Elapsed time = 1862.95 seconds
# Fold 40: Train size = 32959, Test size = 8285
#   [Model II Early Repeated - Fold 40] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0251 (diff: 0.0019)
#     Test SL rate:    0.0158 (diff: 0.0074)
#     Train/Test diff: 0.0093
# Stratification OK
#   ROC AUC = 0.9132, Elapsed time = 1909.38 seconds
# Fold 41: Train size = 33027, Test size = 8217
#   [Model II Early Repeated - Fold 41] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0246 (diff: 0.0014)
#     Test SL rate:    0.0176 (diff: 0.0056)
#     Train/Test diff: 0.0070
# Stratification OK
#   ROC AUC = 0.9125, Elapsed time = 1953.07 seconds
# Fold 42: Train size = 33019, Test size = 8225
#   [Model II Early Repeated - Fold 42] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0243 (diff: 0.0011)
#     Test SL rate:    0.0187 (diff: 0.0045)
#     Train/Test diff: 0.0056
# Stratification OK
#   ROC AUC = 0.9103, Elapsed time = 1997.34 seconds
# Fold 43: Train size = 32967, Test size = 8277
#   [Model II Early Repeated - Fold 43] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0228 (diff: 0.0004)
#     Test SL rate:    0.0248 (diff: 0.0015)
#     Train/Test diff: 0.0019
# Stratification OK
#   ROC AUC = 0.8466, Elapsed time = 2039.36 seconds
# Fold 44: Train size = 32985, Test size = 8259
#   [Model II Early Repeated - Fold 44] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0231 (diff: 0.0002)
#     Test SL rate:    0.0239 (diff: 0.0006)
#     Train/Test diff: 0.0008
# Stratification OK
#   ROC AUC = 0.8763, Elapsed time = 2085.16 seconds
# Fold 45: Train size = 32978, Test size = 8266
#   [Model II Early Repeated - Fold 45] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0213 (diff: 0.0020)
#     Test SL rate:    0.0311 (diff: 0.0079)
#     Train/Test diff: 0.0098
# Stratification OK
#   ROC AUC = 0.9269, Elapsed time = 2128.68 seconds
# Fold 46: Train size = 33080, Test size = 8164
#   [Model II Early Repeated - Fold 46] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0249 (diff: 0.0017)
#     Test SL rate:    0.0163 (diff: 0.0069)
#     Train/Test diff: 0.0086
# Stratification OK
#   ROC AUC = 0.9083, Elapsed time = 2172.43 seconds
# Fold 47: Train size = 32997, Test size = 8247
#   [Model II Early Repeated - Fold 47] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0227 (diff: 0.0006)
#     Test SL rate:    0.0255 (diff: 0.0022)
#     Train/Test diff: 0.0028
# Stratification OK
#   ROC AUC = 0.8817, Elapsed time = 2217.73 seconds
# Fold 48: Train size = 32973, Test size = 8271
#   [Model II Early Repeated - Fold 48] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0206 (diff: 0.0026)
#     Test SL rate:    0.0337 (diff: 0.0105)
#     Train/Test diff: 0.0131
# Stratification OK
#   ROC AUC = 0.9233, Elapsed time = 2265.70 seconds
# Fold 49: Train size = 32973, Test size = 8271
#   [Model II Early Repeated - Fold 49] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0266 (diff: 0.0034)
#     Test SL rate:    0.0097 (diff: 0.0136)
#     Train/Test diff: 0.0170
# Stratification OK
#   ROC AUC = 0.9577, Elapsed time = 2316.61 seconds
# Fold 50: Train size = 32953, Test size = 8291
#   [Model II Early Repeated - Fold 50] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0213 (diff: 0.0019)
#     Test SL rate:    0.0309 (diff: 0.0076)
#     Train/Test diff: 0.0096
# Stratification OK
#   ROC AUC = 0.8439, Elapsed time = 2366.10 seconds
#
# === Model II Early Repeated Summary ===
# Mean ROC AUC = 0.8999 ± 0.0343
# Successful folds: 50/50
# Stratification quality:
#   Mean train deviation: 0.0018 ± 0.0011
#   Mean test deviation:  0.0071 ± 0.0045
#
# === Model II Late Repeated - Fold 1/50 ===
# Train size = 32973, Test size = 8271
#   [Model II Late Repeated - Fold 1] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0266 (diff: 0.0034)
#     Test SL rate:    0.0097 (diff: 0.0136)
#     Train/Test diff: 0.0170
# Stratification OK
#   ROC AUC = 0.9710, Elapsed time = 71.85 seconds
#
# === Model II Late Repeated - Fold 2/50 ===
# Train size = 32978, Test size = 8266
#   [Model II Late Repeated - Fold 2] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0213 (diff: 0.0020)
#     Test SL rate:    0.0311 (diff: 0.0079)
#     Train/Test diff: 0.0098
# Stratification OK
#   ROC AUC = 0.9412, Elapsed time = 142.11 seconds
#
# === Model II Late Repeated - Fold 3/50 ===
# Train size = 33018, Test size = 8226
#   [Model II Late Repeated - Fold 3] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0235 (diff: 0.0003)
#     Test SL rate:    0.0220 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.9010, Elapsed time = 216.03 seconds
#
# === Model II Late Repeated - Fold 4/50 ===
# Train size = 32992, Test size = 8252
#   [Model II Late Repeated - Fold 4] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0220 (diff: 0.0012)
#     Test SL rate:    0.0281 (diff: 0.0049)
#     Train/Test diff: 0.0061
# Stratification OK
#   ROC AUC = 0.9078, Elapsed time = 286.33 seconds
#
# === Model II Late Repeated - Fold 5/50 ===
# Train size = 33015, Test size = 8229
#   [Model II Late Repeated - Fold 5] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0227 (diff: 0.0005)
#     Test SL rate:    0.0253 (diff: 0.0020)
#     Train/Test diff: 0.0026
# Stratification OK
#   ROC AUC = 0.8732, Elapsed time = 354.82 seconds
#
# === Model II Late Repeated - Fold 6/50 ===
# Train size = 33032, Test size = 8212
#   [Model II Late Repeated - Fold 6] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0251 (diff: 0.0018)
#     Test SL rate:    0.0158 (diff: 0.0074)
#     Train/Test diff: 0.0092
# Stratification OK
#   ROC AUC = 0.9280, Elapsed time = 426.52 seconds
#
# === Model II Late Repeated - Fold 7/50 ===
# Train size = 33032, Test size = 8212
#   [Model II Late Repeated - Fold 7] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0253 (diff: 0.0021)
#     Test SL rate:    0.0150 (diff: 0.0082)
#     Train/Test diff: 0.0103
# Stratification OK
#   ROC AUC = 0.9403, Elapsed time = 498.91 seconds
#
# === Model II Late Repeated - Fold 8/50 ===
# Train size = 32954, Test size = 8290
#   [Model II Late Repeated - Fold 8] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0221 (diff: 0.0011)
#     Test SL rate:    0.0276 (diff: 0.0044)
#     Train/Test diff: 0.0055
# Stratification OK
#   ROC AUC = 0.8770, Elapsed time = 567.53 seconds
#
# === Model II Late Repeated - Fold 9/50 ===
# Train size = 32993, Test size = 8251
#   [Model II Late Repeated - Fold 9] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0205 (diff: 0.0028)
#     Test SL rate:    0.0343 (diff: 0.0111)
#     Train/Test diff: 0.0138
# Stratification OK
#   ROC AUC = 0.9295, Elapsed time = 637.82 seconds
#
# === Model II Late Repeated - Fold 10/50 ===
# Train size = 32965, Test size = 8279
#   [Model II Late Repeated - Fold 10] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9131, Elapsed time = 711.03 seconds
#
# === Model II Late Repeated - Fold 11/50 ===
# Train size = 32973, Test size = 8271
#   [Model II Late Repeated - Fold 11] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0266 (diff: 0.0034)
#     Test SL rate:    0.0097 (diff: 0.0136)
#     Train/Test diff: 0.0170
# Stratification OK
#   ROC AUC = 0.9710, Elapsed time = 783.00 seconds
#
# === Model II Late Repeated - Fold 12/50 ===
# Train size = 33013, Test size = 8231
#   [Model II Late Repeated - Fold 12] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0206 (diff: 0.0027)
#     Test SL rate:    0.0339 (diff: 0.0107)
#     Train/Test diff: 0.0133
# Stratification OK
#   ROC AUC = 0.8685, Elapsed time = 850.19 seconds
#
# === Model II Late Repeated - Fold 13/50 ===
# Train size = 32993, Test size = 8251
#   [Model II Late Repeated - Fold 13] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0205 (diff: 0.0028)
#     Test SL rate:    0.0343 (diff: 0.0111)
#     Train/Test diff: 0.0138
# Stratification OK
#   ROC AUC = 0.9295, Elapsed time = 920.14 seconds
#
# === Model II Late Repeated - Fold 14/50 ===
# Train size = 32970, Test size = 8274
#   [Model II Late Repeated - Fold 14] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0239 (diff: 0.0006)
#     Test SL rate:    0.0207 (diff: 0.0026)
#     Train/Test diff: 0.0032
# Stratification OK
#   ROC AUC = 0.9056, Elapsed time = 995.12 seconds
#
# === Model II Late Repeated - Fold 15/50 ===
# Train size = 33027, Test size = 8217
#   [Model II Late Repeated - Fold 15] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0246 (diff: 0.0014)
#     Test SL rate:    0.0176 (diff: 0.0056)
#     Train/Test diff: 0.0070
# Stratification OK
#   ROC AUC = 0.9244, Elapsed time = 1066.25 seconds
#
# === Model II Late Repeated - Fold 16/50 ===
# Train size = 32979, Test size = 8265
#   [Model II Late Repeated - Fold 16] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0247 (diff: 0.0015)
#     Test SL rate:    0.0172 (diff: 0.0060)
#     Train/Test diff: 0.0076
# Stratification OK
#   ROC AUC = 0.9229, Elapsed time = 1136.97 seconds
#
# === Model II Late Repeated - Fold 17/50 ===
# Train size = 33080, Test size = 8164
#   [Model II Late Repeated - Fold 17] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0249 (diff: 0.0017)
#     Test SL rate:    0.0163 (diff: 0.0069)
#     Train/Test diff: 0.0086
# Stratification OK
#   ROC AUC = 0.9291, Elapsed time = 1209.07 seconds
#
# === Model II Late Repeated - Fold 18/50 ===
# Train size = 32971, Test size = 8273
#   [Model II Late Repeated - Fold 18] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0247 (diff: 0.0015)
#     Test SL rate:    0.0174 (diff: 0.0058)
#     Train/Test diff: 0.0073
# Stratification OK
#   ROC AUC = 0.9362, Elapsed time = 1281.56 seconds
#
# === Model II Late Repeated - Fold 19/50 ===
# Train size = 32966, Test size = 8278
#   [Model II Late Repeated - Fold 19] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0217 (diff: 0.0016)
#     Test SL rate:    0.0295 (diff: 0.0062)
#     Train/Test diff: 0.0078
# Stratification OK
#   ROC AUC = 0.9352, Elapsed time = 1352.81 seconds
#
# === Model II Late Repeated - Fold 20/50 ===
# Train size = 32980, Test size = 8264
#   [Model II Late Repeated - Fold 20] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0201 (diff: 0.0031)
#     Test SL rate:    0.0357 (diff: 0.0125)
#     Train/Test diff: 0.0156
# Stratification OK
#   ROC AUC = 0.8630, Elapsed time = 1419.11 seconds
#
# === Model II Late Repeated - Fold 21/50 ===
# Train size = 32961, Test size = 8283
#   [Model II Late Repeated - Fold 21] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0187 (diff: 0.0045)
#     Test SL rate:    0.0413 (diff: 0.0181)
#     Train/Test diff: 0.0226
# Stratification OK
#   ROC AUC = 0.8939, Elapsed time = 1484.42 seconds
#
# === Model II Late Repeated - Fold 22/50 ===
# Train size = 33018, Test size = 8226
#   [Model II Late Repeated - Fold 22] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0235 (diff: 0.0003)
#     Test SL rate:    0.0220 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.9010, Elapsed time = 1558.18 seconds
#
# === Model II Late Repeated - Fold 23/50 ===
# Train size = 32973, Test size = 8271
#   [Model II Late Repeated - Fold 23] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0266 (diff: 0.0034)
#     Test SL rate:    0.0097 (diff: 0.0136)
#     Train/Test diff: 0.0170
# Stratification OK
#   ROC AUC = 0.9710, Elapsed time = 1629.86 seconds
#
# === Model II Late Repeated - Fold 24/50 ===
# Train size = 32977, Test size = 8267
#   [Model II Late Repeated - Fold 24] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0228 (diff: 0.0004)
#     Test SL rate:    0.0249 (diff: 0.0017)
#     Train/Test diff: 0.0021
# Stratification OK
#   ROC AUC = 0.9043, Elapsed time = 1700.95 seconds
#
# === Model II Late Repeated - Fold 25/50 ===
# Train size = 33047, Test size = 8197
#   [Model II Late Repeated - Fold 25] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0245 (diff: 0.0013)
#     Test SL rate:    0.0182 (diff: 0.0051)
#     Train/Test diff: 0.0063
# Stratification OK
#   ROC AUC = 0.9212, Elapsed time = 1772.41 seconds
#
# === Model II Late Repeated - Fold 26/50 ===
# Train size = 32970, Test size = 8274
#   [Model II Late Repeated - Fold 26] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0239 (diff: 0.0006)
#     Test SL rate:    0.0207 (diff: 0.0026)
#     Train/Test diff: 0.0032
# Stratification OK
#   ROC AUC = 0.9056, Elapsed time = 1847.49 seconds
#
# === Model II Late Repeated - Fold 27/50 ===
# Train size = 33025, Test size = 8219
#   [Model II Late Repeated - Fold 27] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0225 (diff: 0.0008)
#     Test SL rate:    0.0263 (diff: 0.0031)
#     Train/Test diff: 0.0038
# Stratification OK
#   ROC AUC = 0.9024, Elapsed time = 1917.46 seconds
#
# === Model II Late Repeated - Fold 28/50 ===
# Train size = 33028, Test size = 8216
#   [Model II Late Repeated - Fold 28] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0231 (diff: 0.0002)
#     Test SL rate:    0.0239 (diff: 0.0006)
#     Train/Test diff: 0.0008
# Stratification OK
#   ROC AUC = 0.9622, Elapsed time = 1988.46 seconds
#
# === Model II Late Repeated - Fold 29/50 ===
# Train size = 32973, Test size = 8271
#   [Model II Late Repeated - Fold 29] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0266 (diff: 0.0034)
#     Test SL rate:    0.0097 (diff: 0.0136)
#     Train/Test diff: 0.0170
# Stratification OK
#   ROC AUC = 0.9710, Elapsed time = 2060.28 seconds
#
# === Model II Late Repeated - Fold 30/50 ===
# Train size = 32980, Test size = 8264
#   [Model II Late Repeated - Fold 30] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0201 (diff: 0.0031)
#     Test SL rate:    0.0357 (diff: 0.0125)
#     Train/Test diff: 0.0156
# Stratification OK
#   ROC AUC = 0.8630, Elapsed time = 2127.05 seconds
#
# === Model II Late Repeated - Fold 31/50 ===
# Train size = 32979, Test size = 8265
#   [Model II Late Repeated - Fold 31] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0247 (diff: 0.0015)
#     Test SL rate:    0.0172 (diff: 0.0060)
#     Train/Test diff: 0.0076
# Stratification OK
#   ROC AUC = 0.9229, Elapsed time = 2197.45 seconds
#
# === Model II Late Repeated - Fold 32/50 ===
# Train size = 33045, Test size = 8199
#   [Model II Late Repeated - Fold 32] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0223 (diff: 0.0009)
#     Test SL rate:    0.0268 (diff: 0.0036)
#     Train/Test diff: 0.0045
# Stratification OK
#   ROC AUC = 0.9120, Elapsed time = 2268.77 seconds
#
# === Model II Late Repeated - Fold 33/50 ===
# Train size = 32978, Test size = 8266
#   [Model II Late Repeated - Fold 33] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0213 (diff: 0.0020)
#     Test SL rate:    0.0311 (diff: 0.0079)
#     Train/Test diff: 0.0098
# Stratification OK
#   ROC AUC = 0.9412, Elapsed time = 2339.20 seconds
#
# === Model II Late Repeated - Fold 34/50 ===
# Train size = 32954, Test size = 8290
#   [Model II Late Repeated - Fold 34] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0221 (diff: 0.0011)
#     Test SL rate:    0.0276 (diff: 0.0044)
#     Train/Test diff: 0.0055
# Stratification OK
#   ROC AUC = 0.8770, Elapsed time = 2407.94 seconds
#
# === Model II Late Repeated - Fold 35/50 ===
# Train size = 33020, Test size = 8224
#   [Model II Late Repeated - Fold 35] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0257 (diff: 0.0025)
#     Test SL rate:    0.0134 (diff: 0.0099)
#     Train/Test diff: 0.0123
# Stratification OK
#   ROC AUC = 0.9317, Elapsed time = 2481.80 seconds
#
# === Model II Late Repeated - Fold 36/50 ===
# Train size = 32980, Test size = 8264
#   [Model II Late Repeated - Fold 36] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0201 (diff: 0.0031)
#     Test SL rate:    0.0357 (diff: 0.0125)
#     Train/Test diff: 0.0156
# Stratification OK
#   ROC AUC = 0.8630, Elapsed time = 2547.93 seconds
#
# === Model II Late Repeated - Fold 37/50 ===
# Train size = 32978, Test size = 8266
#   [Model II Late Repeated - Fold 37] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0213 (diff: 0.0020)
#     Test SL rate:    0.0311 (diff: 0.0079)
#     Train/Test diff: 0.0098
# Stratification OK
#   ROC AUC = 0.9412, Elapsed time = 2617.86 seconds
#
# === Model II Late Repeated - Fold 38/50 ===
# Train size = 33025, Test size = 8219
#   [Model II Late Repeated - Fold 38] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0225 (diff: 0.0008)
#     Test SL rate:    0.0263 (diff: 0.0031)
#     Train/Test diff: 0.0038
# Stratification OK
#   ROC AUC = 0.9024, Elapsed time = 2687.66 seconds
#
# === Model II Late Repeated - Fold 39/50 ===
# Train size = 33034, Test size = 8210
#   [Model II Late Repeated - Fold 39] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0272 (diff: 0.0040)
#     Test SL rate:    0.0072 (diff: 0.0160)
#     Train/Test diff: 0.0200
# Stratification OK
#   ROC AUC = 0.9785, Elapsed time = 2758.77 seconds
#
# === Model II Late Repeated - Fold 40/50 ===
# Train size = 32959, Test size = 8285
#   [Model II Late Repeated - Fold 40] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0251 (diff: 0.0019)
#     Test SL rate:    0.0158 (diff: 0.0074)
#     Train/Test diff: 0.0093
# Stratification OK
#   ROC AUC = 0.9276, Elapsed time = 2833.41 seconds
#
# === Model II Late Repeated - Fold 41/50 ===
# Train size = 33027, Test size = 8217
#   [Model II Late Repeated - Fold 41] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0246 (diff: 0.0014)
#     Test SL rate:    0.0176 (diff: 0.0056)
#     Train/Test diff: 0.0070
# Stratification OK
#   ROC AUC = 0.9244, Elapsed time = 2904.00 seconds
#
# === Model II Late Repeated - Fold 42/50 ===
# Train size = 33019, Test size = 8225
#   [Model II Late Repeated - Fold 42] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0243 (diff: 0.0011)
#     Test SL rate:    0.0187 (diff: 0.0045)
#     Train/Test diff: 0.0056
# Stratification OK
#   ROC AUC = 0.9291, Elapsed time = 2975.95 seconds
#
# === Model II Late Repeated - Fold 43/50 ===
# Train size = 32967, Test size = 8277
#   [Model II Late Repeated - Fold 43] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0228 (diff: 0.0004)
#     Test SL rate:    0.0248 (diff: 0.0015)
#     Train/Test diff: 0.0019
# Stratification OK
#   ROC AUC = 0.8615, Elapsed time = 3043.45 seconds
#
# === Model II Late Repeated - Fold 44/50 ===
# Train size = 32985, Test size = 8259
#   [Model II Late Repeated - Fold 44] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0231 (diff: 0.0002)
#     Test SL rate:    0.0239 (diff: 0.0006)
#     Train/Test diff: 0.0008
# Stratification OK
#   ROC AUC = 0.8998, Elapsed time = 3117.10 seconds
#
# === Model II Late Repeated - Fold 45/50 ===
# Train size = 32978, Test size = 8266
#   [Model II Late Repeated - Fold 45] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0213 (diff: 0.0020)
#     Test SL rate:    0.0311 (diff: 0.0079)
#     Train/Test diff: 0.0098
# Stratification OK
#   ROC AUC = 0.9412, Elapsed time = 3187.54 seconds
#
# === Model II Late Repeated - Fold 46/50 ===
# Train size = 33080, Test size = 8164
#   [Model II Late Repeated - Fold 46] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0249 (diff: 0.0017)
#     Test SL rate:    0.0163 (diff: 0.0069)
#     Train/Test diff: 0.0086
# Stratification OK
#   ROC AUC = 0.9291, Elapsed time = 3259.23 seconds
#
# === Model II Late Repeated - Fold 47/50 ===
# Train size = 32997, Test size = 8247
#   [Model II Late Repeated - Fold 47] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0227 (diff: 0.0006)
#     Test SL rate:    0.0255 (diff: 0.0022)
#     Train/Test diff: 0.0028
# Stratification OK
#   ROC AUC = 0.9059, Elapsed time = 3330.05 seconds
#
# === Model II Late Repeated - Fold 48/50 ===
# Train size = 32973, Test size = 8271
#   [Model II Late Repeated - Fold 48] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0206 (diff: 0.0026)
#     Test SL rate:    0.0337 (diff: 0.0105)
#     Train/Test diff: 0.0131
# Stratification OK
#   ROC AUC = 0.9385, Elapsed time = 3399.26 seconds
#
# === Model II Late Repeated - Fold 49/50 ===
# Train size = 32973, Test size = 8271
#   [Model II Late Repeated - Fold 49] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0266 (diff: 0.0034)
#     Test SL rate:    0.0097 (diff: 0.0136)
#     Train/Test diff: 0.0170
# Stratification OK
#   ROC AUC = 0.9710, Elapsed time = 3469.64 seconds
#
# === Model II Late Repeated - Fold 50/50 ===
# Train size = 32953, Test size = 8291
#   [Model II Late Repeated - Fold 50] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0213 (diff: 0.0019)
#     Test SL rate:    0.0309 (diff: 0.0076)
#     Train/Test diff: 0.0096
# Stratification OK
#   ROC AUC = 0.8679, Elapsed time = 3540.02 seconds
#
# === Model II Late Repeated Summary ===
# Mean ROC AUC = 0.9180 ± 0.0316
# Successful folds: 50/50
# Stratification quality:
# Mean train deviation: 0.0018 ± 0.0011
# Mean test deviation: 0.0071 ± 0.0045

# %%
# save results of cross validation
with open(file_RF_model_II_early_repeated, 'wb') as f:
    pickle.dump(model_II_early_repeated, f)

with open(file_RF_model_II_late_repeated, 'wb') as f:
    pickle.dump(model_II_late_repeated, f)

# %% [markdown]
# ## Model III
# #### Different paralog pairs, same cell lines

# %%
# Define group feature for gene pairs
gene_groups = training_df['genepair']

sgkf2 = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=42)
splits_III = list(sgkf2.split(training_df, target, gene_groups))

# Model III - Gene pair validation  
print("\n=== MODEL III: GENE PAIR VALIDATION ===")
for i, (train_index, test_index) in enumerate(splits_III):
    train_pairs = training_df.loc[train_index, 'genepair'].unique()
    test_pairs = training_df.loc[test_index, 'genepair'].unique()
    validate_group_splits(train_pairs, test_pairs, i+1, "Model III", "gene pairs")
# Out:
# === MODEL III: GENE PAIR VALIDATION ===
#   [Model III - Fold 1] Group Validation:
#     Train gene pairs: 3337
#     Test gene pairs:  833
#     Overlapping gene pairs: 0
# No group leakage
#   [Model III - Fold 2] Group Validation:
#     Train gene pairs: 3334
#     Test gene pairs:  836
#     Overlapping gene pairs: 0
# No group leakage
#   [Model III - Fold 3] Group Validation:
#     Train gene pairs: 3336
#     Test gene pairs:  834
#     Overlapping gene pairs: 0
# No group leakage
#   [Model III - Fold 4] Group Validation:
#     Train gene pairs: 3336
#     Test gene pairs:  834
#     Overlapping gene pairs: 0
# No group leakage
#   [Model III - Fold 5] Group Validation:
#     Train gene pairs: 3337
#     Test gene pairs:  833
#     Overlapping gene pairs: 0
# No group leakage

# %%
# Save splits
with open('/Users/narod/Library/CloudStorage/GoogleDrive-narod.kebabci@ucdconnect.ie/My Drive/GitRepos/context_specific_SL_prediction/output/models/model_III/splits_III.pkl', 'wb') as f:
    pickle.dump(splits_III, f)

# %%
model_III_early = model_early_cross_validation(RF, data_1, target, splits_III, model_name="Model III Early")
model_III_late = model_late_cross_validation(RF, data_2, target, splits_III, model_name="Model III Late")
# Out:
# Fold 1: Train size = 33027, Test size = 8217
#   [Model III Early - Fold 1] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0223 (diff: 0.0009)
#     Test SL rate:    0.0269 (diff: 0.0037)
#     Train/Test diff: 0.0046
# Stratification OK
#   ROC AUC = 0.8773, Elapsed time = 48.40 seconds
# Fold 2: Train size = 32987, Test size = 8257
#   [Model III Early - Fold 2] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0002)
#     Test SL rate:    0.0224 (diff: 0.0008)
#     Train/Test diff: 0.0010
# Stratification OK
#   ROC AUC = 0.9094, Elapsed time = 97.79 seconds
# Fold 3: Train size = 32975, Test size = 8269
#   [Model III Early - Fold 3] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0002)
#     Test SL rate:    0.0224 (diff: 0.0009)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9182, Elapsed time = 160.20 seconds
# Fold 4: Train size = 32987, Test size = 8257
#   [Model III Early - Fold 4] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0239 (diff: 0.0007)
#     Test SL rate:    0.0206 (diff: 0.0026)
#     Train/Test diff: 0.0033
# Stratification OK
#   ROC AUC = 0.9188, Elapsed time = 213.90 seconds
# Fold 5: Train size = 33000, Test size = 8244
#   [Model III Early - Fold 5] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0231 (diff: 0.0002)
#     Test SL rate:    0.0239 (diff: 0.0007)
#     Train/Test diff: 0.0008
# Stratification OK
#   ROC AUC = 0.9052, Elapsed time = 265.37 seconds
#
# === Model III Early Summary ===
# Mean ROC AUC = 0.9053 ± 0.0151
# Successful folds: 5/5
# Stratification quality:
#   Mean train deviation: 0.0004 ± 0.0003
#   Mean test deviation:  0.0017 ± 0.0012
#
# === Model III Late - Fold 1/5 ===
# Train size = 33027, Test size = 8217
#   [Model III Late - Fold 1] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0223 (diff: 0.0009)
#     Test SL rate:    0.0269 (diff: 0.0037)
#     Train/Test diff: 0.0046
# Stratification OK
#   ROC AUC = 0.8820, Elapsed time = 80.23 seconds
#
# === Model III Late - Fold 2/5 ===
# Train size = 32987, Test size = 8257
#   [Model III Late - Fold 2] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0002)
#     Test SL rate:    0.0224 (diff: 0.0008)
#     Train/Test diff: 0.0010
# Stratification OK
#   ROC AUC = 0.9069, Elapsed time = 162.75 seconds
#
# === Model III Late - Fold 3/5 ===
# Train size = 32975, Test size = 8269
#   [Model III Late - Fold 3] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0002)
#     Test SL rate:    0.0224 (diff: 0.0009)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9222, Elapsed time = 240.11 seconds
#
# === Model III Late - Fold 4/5 ===
# Train size = 32987, Test size = 8257
#   [Model III Late - Fold 4] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0239 (diff: 0.0007)
#     Test SL rate:    0.0206 (diff: 0.0026)
#     Train/Test diff: 0.0033
# Stratification OK
#   ROC AUC = 0.9210, Elapsed time = 310.42 seconds
#
# === Model III Late - Fold 5/5 ===
# Train size = 33000, Test size = 8244
#   [Model III Late - Fold 5] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0231 (diff: 0.0002)
#     Test SL rate:    0.0239 (diff: 0.0007)
#     Train/Test diff: 0.0008
# Stratification OK
#   ROC AUC = 0.9078, Elapsed time = 395.64 seconds
#
# === Model III Late Summary ===
# Mean ROC AUC = 0.9076 ± 0.0145
# Successful folds: 5/5
# Stratification quality:
# Mean train deviation: 0.0004 ± 0.0003
# Mean test deviation: 0.0017 ± 0.0012

# %%
# save results of cross validation
with open(file_RF_model_III_early, 'wb') as f:
    pickle.dump(model_III_early, f)

with open(file_RF_model_III_late, 'wb') as f:
    pickle.dump(model_III_late, f)

# %%
# Generate the repeated stratified group k-fold splits

repeated_splits_III = repeated_stratified_group_kfold(
    data=training_df,
    target=target,
    groups=gene_groups,
    n_folds=5,
    n_repeats=10,
    random_state=42
)
# Out:
# Repeat 1, Fold 1:
#   TRAIN groups: ['A3GALT2_GLT6D1' 'AADACL2_AADACL3' 'AADACL2_AADACL4' ... 'ZNRF1_ZNRF2'
#  'ZXDA_ZXDC' 'ZXDB_ZXDC']
#   TEST groups: ['A3GALT2_ABO' 'A3GALT2_GBGT1' 'AADAC_AADACL2' 'ABHD4_ABHD5' 'ABL1_MATK'
#  'ABL2_CSK' 'ABTB2_ABTB3' 'ACAD10_ACAD11' 'ACAD9_ACADS' 'ACADL_ACADS'
#  'ACADSB_IVD' 'ACADVL_IVD' 'ACHE_BCHE' 'ACHE_CES4A' 'ACP3_ACP4'
#  'ACR_TMPRSS12' 'ACSM1_ACSM2B' 'ACSM2A_ACSM2B' 'ACSM2A_ACSM6'
#  'ACSM3_ACSM4' 'ACSM5_ACSM6' 'ACVR1B_TGFBR1' 'ACVR1C_BMPR1B'
#  'ACVR1_BMPR1A' 'ACVR2B_TGFBR2' 'ADAM11_ADAM19' 'ADAM11_ADAM22'
#  'ADAM15_ADAM28' 'ADAM20_ADAM29' 'ADAM28_ADAM33' 'ADAM7_ADAM28'
#  'ADAM9_ADAM18' 'ADAM9_ADAM20' 'ADAMTS10_ADAMTS17' 'ADAMTS12_ADAMTS18'
#  'ADAMTS1_ADAMTS15' 'ADAMTS2_ADAMTS3' 'ADAMTS4_ADAMTS5' 'ADAMTS6_ADAMTS16'
#  'ADAMTS7_ADAMTS10' 'ADAMTS8_ADAMTS20' 'ADAMTSL1_ADAMTSL3' 'ADCK1_ADCK5'
#  'ADSS1_ADSS2' 'AEBP1_CPE' 'AFF1_AFF4' 'AFF2_AFF4' 'AGBL1_AGBL4'
#  'AGBL3_AGBL4' 'AHCYL1_AHCYL2' 'AICDA_APOBEC3F' 'AKT1_AKT2' 'AKT1_RPS6KA4'
#  'AKT1_SGK1' 'AKT2_RPS6KA2' 'AKT2_SGK1' 'AKT3_RPS6KA4' 'AKT3_RPS6KA5'
#  'AKT3_SGK3' 'ALPI_ALPL' 'AMPD1_AMPD3' 'ANKRD28_ANKRD52' 'ANP32A_ANP32E'
#  'ANP32D_ANP32E' 'ANPEP_TRHDE' 'APOBEC2_APOBEC3C' 'APOBEC3A_APOBEC3F'
#  'APOBEC3B_APOBEC3G' 'APOBEC3D_APOBEC3F' 'APOBEC3D_APOBEC3G' 'ARAF_BRAF'
#  'ARK2C_RNF111' 'ARSA_ARSH' 'ARSB_ARSJ' 'ARSD_ARSF' 'ARSD_STS' 'ARSF_ARSH'
#  'ARSG_GALNS' 'ARSL_STS' 'ART1_ART4' 'ART1_ART5' 'ASB11_ASB13'
#  'ASB4_ASB16' 'ASB9_ASB13' 'ATAD3A_ATAD3B' 'ATG16L1_ATG16L2'
#  'ATP10A_ATP10B' 'ATP13A2_ATP13A3' 'ATP1A2_ATP12A' 'ATP1A3_ATP4A'
#  'ATP1A4_ATP12A' 'ATP2B1_ATP2B4' 'ATP4A_ATP12A' 'ATP6V0A2_TCIRG1'
#  'ATP8A1_ATP11B' 'ATP8A1_ATP8B3' 'ATP8A2_ATP8B1' 'ATP8B1_ATP11B'
#  'ATP8B2_ATP11B' 'ATP8B3_ATP8B4' 'ATRX_RAD54L' 'ATXN1_ATXN1L'
#  'AWAT1_AWAT2' 'AWAT2_MOGAT1' 'AZU1_ELANE' 'B3GALT1_B3GALT5'
#  'B3GAT2_B3GAT3' 'B3GNT3_B3GNT6' 'B3GNT4_B3GNT8' 'B3GNT7_B3GNT8'
#  'BAP1_UCHL5' 'BCL2_BCL2L2' 'BIRC3_BIRC7' 'BLK_FGR' 'BLK_FRK' 'BLK_PTK6'
#  'BMI1_PCGF2' 'BMPR1A_BMPR1B' 'BMX_CSK' 'BMX_TXK' 'BRD2_BRD3' 'BRD2_BRDT'
#  'BRWD3_PHIP' 'BTBD2_BTBD6' 'BTK_CSK' 'BTK_TEC' 'C1RL_MASP1' 'C1S_HPR'
#  'CABP2_CALM1' 'CABP5_CALM1' 'CALM1_CALM2' 'CALM1_CALML5' 'CALM2_CALML5'
#  'CALM3_CALML4' 'CAMK1D_CAMK1G' 'CAMK1D_CAMK4' 'CAMK1G_CAMK2B'
#  'CAMK1G_PSKH1' 'CAMK1_CAMK2B' 'CAMK1_PNCK' 'CAMK2A_CAMK2G'
#  'CAMK2B_CAMK2G' 'CAMK2B_PNCK' 'CAMK4_PSKH2' 'CAMKV_PNCK' 'CAPN11_CAPN14'
#  'CAPN1_CAPN12' 'CAPN1_CAPN8' 'CAPN2_CAPN12' 'CAPN2_CAPN5' 'CAPN3_CAPN5'
#  'CAPN5_CAPN6' 'CAPN8_CAPN11' 'CAPN9_CAPN11' 'CARD16_CARD17P' 'CASK_MPP2'
#  'CASP3_CASP10' 'CASP3_CASP9' 'CASP8_CASP10' 'CBX6_CBX8' 'CCL2_CCL8'
#  'CCL3L3_CCL5' 'CCL3_CCL3L3' 'CCL5_CCL16' 'CCNE1_CCNE2' 'CD163_DMBT1'
#  'CD5L_CD163' 'CD5L_SSC5D' 'CDC42BPA_CDC42BPB' 'CDC42BPB_CDC42BPG'
#  'CDC42BPG_STK38L' 'CDK14_CDK17' 'CDK16_CDK17' 'CDK20_CDKL5' 'CDK3_CDK6'
#  'CDKL1_CDKL4' 'CDKL3_CDKL4' 'CDKN2B_CDKN2C' 'CDY1_CDYL2' 'CDYL_ECI2'
#  'CEACAM4_CEACAM7' 'CEACAM6_CEACAM7' 'CEACAM7_PSG11' 'CELA1_CELA2A'
#  'CELA1_CTRC' 'CELA2A_CTRB2' 'CELA2B_CTRC' 'CELA3A_CTRL' 'CEPT1_CHPT1'
#  'CES1_NLGN2' 'CES2_CES4A' 'CES2_NLGN4Y' 'CES3_NLGN1' 'CES3_NLGN4X'
#  'CES5A_NLGN1' 'CFD_GZMB' 'CHAT_CRAT' 'CHI3L2_CHIA' 'CHKA_CHKB'
#  'CHP1_TESC' 'CHP2_PPP3R1' 'CHST12_CHST13' 'CHST9_CHST11' 'CIB1_CIB3'
#  'CILK1_MAK' 'CKB_CKMT1A' 'CKB_CKMT1B' 'CKM_CKMT2' 'CMA1_CTSG'
#  'CMA1_PRSS57' 'COMT_LRTOMT' 'CORO1A_CORO6' 'CORO1B_CORO6' 'CORO1C_CORO2A'
#  'CORO2B_CORO6' 'CPA1_CPA6' 'CPA2_CPA5' 'CPA3_CPA6' 'CPA4_CPO' 'CPB1_CPB2'
#  'CPB1_CPO' 'CPD_CPZ' 'CPE_CPXM1' 'CPM_CPXM2' 'CPNE1_CPNE3' 'CPNE3_CPNE7'
#  'CPT1B_CPT1C' 'CREBBP_EP300' 'CSF1R_KIT' 'CSK_ITK' 'CSNK1A1L_CSNK1D'
#  'CSNK1A1L_CSNK1E' 'CSNK1G1_CSNK1G3' 'CSNK1G2_CSNK1G3' 'CSRNP2_CSRNP3'
#  'CT47A2_CT47B1' 'CT47A8_CT47B1' 'CTRB1_CTRL' 'CTSD_PGA4' 'CTSE_PGA3'
#  'CTSF_CTSH' 'CTSG_GZMA' 'CTSG_PRSS57' 'CTSK_CTSL' 'CTSS_CTSV'
#  'DAPK1_DAPK2' 'DAPK2_DAPK3' 'DAPK2_MYLK2' 'DAPK2_STK17B' 'DAW1_WDR38'
#  'DAW1_WDR5B' 'DCAF8L1_DCAF8L2' 'DCBLD2_RS1' 'DCLK2_DCLK3' 'DDHD2_SEC23IP'
#  'DDR1_DDR2' 'DGAT2_DGAT2L6' 'DGKB_DGKE' 'DGKE_DGKG' 'DGKI_DGKZ'
#  'DLG1_DLG4' 'DMPK_ROCK1' 'DNAH11_DNAH17' 'DNAH2_DNAH3' 'DNAH3_DNAH10'
#  'DNAH3_DNAH6' 'DNASE2_DNASE2B' 'DPF1_DPF2' 'DPP4_DPP6' 'DPP6_DPP10'
#  'DPYSL2_DPYSL4' 'DPYS_DPYSL2' 'DTX2_DTX4' 'DUSP14_DUSP21' 'DUSP1_DUSP5'
#  'DUSP26_STYXL2' 'DUSP2_DUSP8' 'DUSP3_STYXL2' 'DUSP7_DUSP9' 'DUSP8_DUSP16'
#  'DYRK4_HIPK1' 'ECE1_MMEL1' 'ECE2_MMEL1' 'ECHDC3_ECHS1' 'EFNA1_EFNA3'
#  'EFNA3_EFNA5' 'EGFR_ERBB2' 'EGF_LRP5L' 'EHMT1_SUV39H2' 'ELOA_ELOA3BP'
#  'ELOVL1_ELOVL7' 'ELOVL4_ELOVL5' 'EML1_EML6' 'EML5_EML6' 'ENPEP_ERAP2'
#  'ENPP1_ENPP5' 'ENPP4_ENPP5' 'ENTPD1_ENTPD3' 'ENTPD4_ENTPD7'
#  'EPHA10_EPHB3' 'EPHA1_EPHA2' 'EPHA1_EPHA7' 'EPHA2_EPHA10' 'EPHA2_EPHA8'
#  'EPHA3_EPHA10' 'EPHA3_EPHA8' 'EPHA4_EPHA6' 'EPHA5_EPHA6' 'EPHA6_EPHA8'
#  'EPHA7_EPHA10' 'EPHA7_EPHB4' 'EPHA8_EPHB1' 'EPHB2_EPHB6' 'EPS8_EPS8L1'
#  'ERAP2_TRHDE' 'ERBB2_ERBB4' 'ETNK1_ETNK2' 'EXT1_EXT2' 'EYA1_EYA2'
#  'EZH1_EZH2' 'F12_HGFAC' 'F13A1_TGM4' 'F7_F9' 'FAHD1_FAHD2B' 'FARP1_FARP2'
#  'FBXO17_FBXO27' 'FBXO34_FBXO46' 'FBXO6_FBXO44' 'FBXW10_FBXW10B' 'FES_TXK'
#  'FGFR3_FGFR4' 'FGR_LCK' 'FGR_YES1' 'FLT4_KDR' 'FOXP1_FOXP2' 'FRK_LYN'
#  'FRK_YES1' 'FSTL4_FSTL5' 'FURIN_PCSK6' 'FUT4_FUT9' 'FUT6_FUT7' 'FYN_PTK6'
#  'G6PC1_G6PC3' 'GALK1_GALK2' 'GALNT10_GALNTL6' 'GALNT11_GALNT16'
#  'GALNT12_GALNT16' 'GALNT14_GALNT16' 'GALNT1_GALNT13' 'GALNT1_GALNT4'
#  'GALNT2_GALNT13' 'GALNT2_GALNT4' 'GALNT3_GALNT5' 'GALNT4_GALNT14'
#  'GALNT4_GALNT5' 'GALNT5_GALNT14' 'GALNT6_GALNT12' 'GALNT6_GALNT14'
#  'GALNT6_GALNTL5' 'GALNT8_GALNT9' 'GCA_SRI' 'GCNT1_GCNT2' 'GCNT3_GCNT4'
#  'GDPD2_GDPD4' 'GGT1_GGT5' 'GGT2P_GGTLC1' 'GLB1L2_GLB1L3' 'GLS_GLS2'
#  'GNB1_GNB2' 'GNB2_GNB5' 'GNPDA1_GNPDA2' 'GPATCH2_GPATCH2L' 'GRAPL_GRB2'
#  'GRK1_GRK6' 'GRK3_GRK4' 'GRK6_GRK7' 'GSK3A_GSK3B' 'GUCY2D_GUCY2F'
#  'GXYLT1_GXYLT2' 'GZMA_PRSS57' 'GZMH_GZMK' 'GZMH_GZMM' 'HABP2_PLG'
#  'HAS1_HAS3' 'HCK_SRC' 'HDAC4_HDAC7' 'HDAC7_HDAC9' 'HECW1_SMURF2'
#  'HECW2_ITCH' 'HECW2_WWP2' 'HERC4_HERC6' 'HGF_MST1' 'HIPK1_HIPK4'
#  'HK1_HK3' 'HPN_TMPRSS3' 'HPSE_HPSE2' 'HSPB6_HSPB8' 'HTRA2_HTRA4'
#  'HUS1_HUS1B' 'HYAL2_SPAM1' 'IGF1R_INSRR' 'IMPDH1_IMPDH2' 'INMT_PNMT'
#  'IP6K1_IP6K3' 'ITCH_NEDD4L' 'ITCH_WWP2' 'ITPKA_ITPKB' 'JAK1_JAK3'
#  'JMJD1C_KDM3A' 'KAT6A_KAT7' 'KBTBD2_KBTBD8' 'KCNA1_KCNA2' 'KCNA1_KCNA7'
#  'KCNA1_KCNC2' 'KCNA1_KCND2' 'KCNA2_KCNC1' 'KCNA2_KCND3' 'KCNA3_KCNC4'
#  'KCNA4_KCNC1' 'KCNA7_KCNC3' 'KCNA7_KCNC4' 'KCNB1_KCNG1' 'KCNB1_KCNS2'
#  'KCNB2_KCNG2' 'KCNB2_KCNS2' 'KCNC2_KCNC3' 'KCNF1_KCNS1' 'KCNF1_KCNS3'
#  'KCNG1_KCNG4' 'KCNG1_KCNS1' 'KCNG1_KCNS2' 'KCNG1_KCNV1' 'KCNG3_KCNS1'
#  'KCNG3_KCNV2' 'KCNH1_KCNH2' 'KCNH1_KCNH8' 'KCNH2_KCNH7' 'KCNH3_KCNH8'
#  'KCNH4_KCNH8' 'KCNH7_KCNH8' 'KCNS1_KCNS3' 'KCNS3_KCNV1' 'KCTD12_KCTD16'
#  'KCTD2_KCTD5' 'KCTD5_KCTD17' 'KCTD5_SHKBP1' 'KDM3A_KDM3B' 'KDM4B_KDM4C'
#  'KDM5A_KDM5C' 'KDM7A_PHF2' 'KEAP1_KLHL17' 'KEAP1_KLHL4' 'KLHDC1_KLHDC2'
#  'KLHL13_KLHL26' 'KLHL14_KLHL36' 'KLHL18_KLHL20' 'KLHL1_KLHL18'
#  'KLHL1_KLHL3' 'KLHL21_KLHL35' 'KLHL24_KLHL29' 'KLHL26_KLHL32'
#  'KLHL2_KLHL20' 'KLHL2_KLHL5' 'KLHL32_KLHL36' 'KLHL3_KLHL20'
#  'KLHL40_KLHL41' 'KLHL5_KLHL12' 'KLHL5_KLHL8' 'KLHL8_KLHL17'
#  'KLHL9_KLHL15' 'KLK11_KLK12' 'KLK11_PRSS1' 'KLK12_PRSS1' 'KLK13_KLK14'
#  'KLK14_KLK15' 'KLK14_PRSS3' 'KLK15_PRSS3' 'KLK2_KLK7' 'KLK6_KLK9'
#  'KLK6_PRSS3' 'KLK8_KLK9' 'KLK9_KLK11' 'KLK9_PRSS2' 'KYAT1_KYAT3'
#  'LATS1_STK38L' 'LCK_SRC' 'LCP1_PLS3' 'LDHC_UEVLD' 'LDLR_LRP2' 'LFNG_RFNG'
#  'LIPA_LIPM' 'LIPF_LIPJ' 'LIPH_PLA1A' 'LIPK_LIPM' 'LIPK_LIPN'
#  'LOXL2_LOXL4' 'LPA_MST1' 'LPCAT1_LPCAT4' 'LRBA_NBEA' 'LRP1_LRP2'
#  'LRP2_LRP8' 'LRP4_VLDLR' 'LTA4H_RNPEPL1' 'LTBP3_LTBP4' 'LYN_PTK6'
#  'LYN_YES1' 'LYZL6_SPACA5B' 'MAGT1_TUSC3' 'MAP2K1_MAP2K3' 'MAP2K1_MAP2K7'
#  'MAP2K2_MAP2K6' 'MAP2K4_MAP2K5' 'MAP3K10_MAP3K21' 'MAP3K5_MAP3K6'
#  'MAP3K9_MAP3K11' 'MAP4K1_STK25' 'MAP4K2_MAP4K3' 'MAP4K2_STK26'
#  'MAP4K4_MINK1' 'MAPK10_MAPK14' 'MAPK11_MAPK14' 'MAPK1_MAPK4'
#  'MAPK8IP1_MAPK8IP2' 'MAPK8_MAPK13' 'MAPK9_MAPK12' 'MAPKAPK2_MAPKAPK5'
#  'MARK1_MARK2' 'MARK2_MARK4' 'MARK3_SIK3' 'MAST1_MAST3' 'MCCC1_PCCA'
#  'ME1_ME3' 'METTL2A_METTL6' 'MEX3B_MEX3C' 'MFNG_RFNG' 'MGAT5_MGAT5B'
#  'MKNK1_MKNK2' 'MME_MMEL1' 'MMP10_MMP14' 'MMP10_MMP24' 'MMP11_MMP13'
#  'MMP11_MMP16' 'MMP12_MMP14' 'MMP12_MMP25' 'MMP13_MMP17' 'MMP13_MMP27'
#  'MMP14_MMP15' 'MMP14_MMP17' 'MMP15_MMP17' 'MMP16_MMP20' 'MMP17_MMP24'
#  'MMP1_MMP13' 'MMP1_MMP20' 'MMP20_MMP24' 'MMP24_MMP27' 'MMP3_MMP13'
#  'MMP3_MMP24' 'MMP7_MMP14' 'MMP7_MMP25' 'MMP7_MMP27' 'MMP8_MMP13'
#  'MMP8_MMP20' 'MOB1B_MOB3A' 'MOGAT2_MOGAT3' 'MPP1_PALS2' 'MPP3_MPP4'
#  'MPP3_PALS1' 'MST1_PLG' 'MTHFD1_MTHFD2L' 'MTM1_MTMR2' 'MTM1_MTMR8'
#  'MTMR1_MTMR6' 'MTMR2_MTMR8' 'MTMR4_MTMR6' 'MTMR7_MTMR9' 'MYLK2_STK17B'
#  'MYO3A_MYO3B' 'NABP1_NABP2' 'NAPSA_PGA4' 'NAPSA_PGA5' 'NCOA2_NCOA3'
#  'NEDD4L_SMURF2' 'NEDD4_SMURF2' 'NEK1_NEK7' 'NEK3_NEK7' 'NEK5_NEK7'
#  'NEK8_NEK9' 'NFE2L1_NFE2L2' 'NIM1K_SIK2' 'NME1_NME3' 'NME6_NME7'
#  'NOMO1_NOMO2' 'NRIP2_NRIP3' 'NRP1_NRP2' 'NT5C2_NT5DC4' 'NTRK2_NTRK3'
#  'NUDT3_NUDT11' 'OAS1_OAS3' 'OLFM1_OLFM3' 'OXCT1_OXCT2' 'PACSIN2_PACSIN3'
#  'PADI2_PADI4' 'PADI3_PADI4' 'PAK1_PAK2' 'PAK2_PAK5' 'PANK1_PANK3'
#  'PAPSS1_PAPSS2' 'PASK_PIM1' 'PCGF1_PCGF5' 'PCGF5_PCGF6' 'PCSK1_PCSK6'
#  'PCSK2_PCSK7' 'PCSK4_PCSK6' 'PCSK6_PCSK7' 'PDIK1L_STK35' 'PDK3_PDK4'
#  'PDZRN3_PDZRN4' 'PFKFB2_PFKFB3' 'PGA3_REN' 'PGAM1_PGAM2'
#  'PHACTR1_PHACTR2' 'PHC1_PHC2' 'PHKA1_PHKA2' 'PI4K2A_PI4K2B' 'PIAS3_PIAS4'
#  'PIK3CB_PIK3CG' 'PIM1_PIM2' 'PIM1_PIM3' 'PIP4K2B_PIP5K1B' 'PKN1_PKN3'
#  'PLA2G1B_PLA2G2A' 'PLA2G2A_PLA2G2D' 'PLA2G2D_PLA2G2E' 'PLA2G2E_PLA2G5'
#  'PLA2G2F_PLA2G5' 'PLA2G4D_PLA2G4E' 'PLAG1_PLAGL2' 'PLCB1_PLCB2'
#  'PLCB2_PLCD4' 'PLCB3_PLCZ1' 'PLCD1_PLCL1' 'PLCD3_PLCL2' 'PLCH1_PLCH2'
#  'PLCL1_PLCZ1' 'PLPP1_PLPP2' 'PLPP1_PLPP3' 'PLPPR1_PLPPR4' 'PLPPR4_PLPPR5'
#  'PLXNA1_PLXNB3' 'PLXNA2_PLXNA4' 'PLXNA2_PLXND1' 'PLXNA4_PLXNB1'
#  'PLXNB1_PLXND1' 'PLXNB2_PLXND1' 'PNLIPRP1_PNLIPRP3' 'PNPLA2_PNPLA5'
#  'PON1_PON2' 'POU2F2_POU3F2' 'POU3F2_POU5F1' 'PPEF1_PPEF2' 'PPM1E_PPM1F'
#  'PPP1R13B_TP53BP2' 'PPP1R3D_PPP1R3G' 'PPP2R5A_PPP2R5B' 'PPP2R5A_PPP2R5E'
#  'PPP2R5B_PPP2R5E' 'PPP3CA_PPP3CC' 'PRB1_PRB2' 'PRKAA1_PRKAA2'
#  'PRKACA_PRKX' 'PRKACG_PRKG1' 'PRKACG_PRKX' 'PRKCA_PRKCB' 'PRKCA_PRKCD'
#  'PRKCA_PRKCQ' 'PRKCB_PRKCH' 'PRKCD_PRKCQ' 'PRKCG_PRKCH' 'PRKCH_PRKCZ'
#  'PRKD1_PRKD3' 'PRKD2_PRKD3' 'PRMT2_PRMT6' 'PRPS1L1_PRPS2' 'PRPS1_PRPSAP1'
#  'PRRG1_PRRG3' 'PRSS21_PRSS27' 'PRSS22_PRSS27' 'PRSS23_PRSS35'
#  'PRSS2_PRSS3' 'PRSS36_PRSS53' 'PRSS41_TPSG1' 'PRSS8_PRSS33' 'PSEN1_PSEN2'
#  'PTEN_TPTE2' 'PTP4A1_PTP4A2' 'PTP4A1_PTP4A3' 'PTPN14_PTPN21'
#  'PTPN5_PTPRR' 'PTPRA_PTPRK' 'PTPRD_PTPRF' 'PTPRE_PTPRS' 'PTPRK_PTPRM'
#  'PYCARD_PYDC1' 'RAB40AL_RAB40B' 'RAB40B_RAB40C' 'RFPL1_RFPL2'
#  'RFPL1_RFPL4AL1' 'RFPL2_RFPL4B' 'RFPL3_RFPL4AL1' 'RHBDF1_RHBDF2'
#  'RIOX1_RIOX2' 'RNASE2_RNASE3' 'RNASE3_RNASE7' 'RNF115_RNF126'
#  'RNF125_RNF166' 'RNF128_RNF150' 'RNF133_RNF150' 'RNF149_RNF150'
#  'RNF223_RNF225' 'ROCK1_ROCK2' 'RPS27_RPS27L' 'RPS6KA1_RPS6KB1'
#  'RPS6KA2_RPS6KA3' 'RPS6KA2_SGK1' 'RPS6KA3_RPS6KB1' 'RPS6KA4_RPS6KA6'
#  'RPS6KA4_RPS6KB2' 'RPS6KA5_SGK2' 'RPS6KA6_RPS6KB1' 'RPS6KB1_SGK2'
#  'S100A1_S100A2' 'SCAMP1_SCAMP2' 'SCAMP2_SCAMP4' 'SCRN1_SCRN3'
#  'SEMA3A_SEMA3C' 'SEMA3A_SEMA4C' 'SEMA3B_SEMA3E' 'SEMA3C_SEMA3E'
#  'SEMA3D_SEMA3G' 'SEMA3E_SEMA3G' 'SEMA4A_SEMA4G' 'SEMA4C_SEMA4F'
#  'SEMA5A_SEMA5B' 'SEMA6B_SEMA6D' 'SET_SETSIP' 'SGK1_SGK2' 'SGK2_SGK3'
#  'SH3GLB1_SH3GLB2' 'SHC1_SHC4' 'SIAH1_SIAH3' 'SLA_SLA2' 'SLC27A1_SLC27A3'
#  'SLC27A2_SLC27A4' 'SLC27A2_SLC27A6' 'SLC27A4_SLC27A5' 'SLK_STK26'
#  'SMURF1_WWP1' 'SMYD1_SMYD3' 'SOX8_SOX9' 'SPPL2A_SPPL2B' 'SPSB2_SPSB4'
#  'SRC_SRMS' 'SSH1_SSH2' 'ST3GAL3_ST3GAL5' 'ST6GALNAC3_ST6GALNAC4'
#  'STK10_STK24' 'STK24_STK25' 'STK32A_STK32B' 'STK3_STK25' 'STK4_STK26'
#  'STT3A_STT3B' 'SULT1A1_SULT1A3' 'SULT1A1_SULT1C2' 'SULT1A2_SULT1A3'
#  'SULT1A2_SULT2A1' 'SULT1A3_SULT1E1' 'SULT1A4_SULT1C3' 'SULT1B1_SULT1C2'
#  'SULT1C2_SULT1C3' 'SULT1C3_SULT1C4' 'SULT1C4_SULT2A1' 'SUV39H1_SUV39H2'
#  'TAOK1_TAOK3' 'TAOK2_TAOK3' 'TBC1D15_TBC1D17' 'TBC1D8B_TBC1D9'
#  'TBC1D9_TBC1D9B' 'TENM1_TENM3' 'TENM1_TENM4' 'TGFB1_TGFB2' 'TGM1_TGM4'
#  'TGM2_TGM4' 'TGM3_TGM6' 'TGM5_TGM7' 'TKT_TKTL2' 'TLE2_TLE5'
#  'TMEM59_TMEM59L' 'TMPRSS11A_TMPRSS11B' 'TMPRSS11A_TMPRSS11D'
#  'TMPRSS11D_TMPRSS11F' 'TMPRSS3_TMPRSS4' 'TMPRSS9_TMPRSS11E' 'TNS1_TNS4'
#  'TOR1A_TOR3A' 'TPTE_TPTE2' 'TRAF2_TRAF3' 'TRIB1_TRIB3' 'TSPAN14_TSPAN17'
#  'TSSK1B_TSSK4' 'TSSK3_TSSK6' 'TUT4_TUT7' 'UBE2D1_UBE2D2' 'UBE2D4_UBE2E1'
#  'UBE2Q1_UBE2QL1' 'UCK1_UCK2' 'UHRF1_UHRF2' 'UPP1_UPP2' 'USP12_USP35'
#  'USP15_USP32' 'USP20_USP33' 'USP27X_USP51' 'USP31_USP43' 'USP38_USP46'
#  'USP4_USP15' 'USP9Y_USP24' 'VNN1_VNN3P' 'WDR45_WDR45B' 'WSB1_WSB2'
#  'ZBTB10_ZBTB46' 'ZBTB34_ZBTB37' 'ZBTB7B_ZBTB7C' 'ZFYVE16_ZFYVE21'
#  'ZNF362_ZNF384']
# Repeat 1, Fold 2:
#   TRAIN groups: ['A3GALT2_ABO' 'A3GALT2_GBGT1' 'AADACL2_AADACL3' ... 'ZNRF1_ZNRF2'
#  'ZXDA_ZXDC' 'ZXDB_ZXDC']
#   TEST groups: ['A3GALT2_GLT6D1' 'AADAC_AADACL3' 'ABL1_ABL2' 'ABL2_MATK' 'ACAA2_ACAT1'
#  'ACAD8_ACADL' 'ACAD8_ACADM' 'ACAD9_ACADSB' 'ACADL_IVD' 'ACADS_ACADSB'
#  'ACAT1_ACAT2' 'ACHE_CES1' 'ACHE_CES5A' 'ACSBG1_ACSBG2' 'ACSM1_ACSM3'
#  'ACSM2A_ACSM3' 'ACSM2B_ACSM3' 'ACSM3_ACSM5' 'ACVR1B_ACVRL1'
#  'ACVR1C_ACVR2A' 'ACVR1_ACVR1B' 'ACVR1_BMPR1B' 'ACVRL1_BMPR1B'
#  'ADAM12_ADAM19' 'ADAM19_ADAM28' 'ADAM21_ADAM29' 'ADAM29_ADAM30'
#  'ADAM8_ADAM19' 'ADAM9_ADAM21' 'ADAMTS10_ADAMTS19' 'ADAMTS12_ADAMTS19'
#  'ADAMTS1_ADAMTS5' 'ADAMTS1_ADAMTS8' 'ADAMTS3_ADAMTS6' 'ADAMTS5_ADAMTS15'
#  'ADAMTS6_ADAMTS17' 'ADAMTS7_ADAMTS12' 'ADAMTS7_ADAMTS17'
#  'ADAMTS9_ADAMTS15' 'ADAMTS9_ADAMTS20' 'ADGRE3_ADGRL1' 'ADGRL1_ADGRL2'
#  'AEBP1_CPN1' 'AFF3_AFF4' 'AGBL4_AGBL5' 'AICDA_APOBEC3A' 'AICDA_APOBEC3H'
#  'AKAP13_ARHGEF18' 'AKT1_RPS6KA1' 'AKT1_RPS6KA6' 'AKT1_SGK2'
#  'AKT2_RPS6KA4' 'AKT2_SGK2' 'AKT3_RPS6KA6' 'ALAS1_ALAS2' 'ALPG_ALPP'
#  'ALPL_ALPP' 'AMZ1_AMZ2' 'ANKRD44_ANKRD52' 'ANP32A_ANP32B' 'ANPEP_ERAP1'
#  'ANXA1_ANXA2' 'APOBEC2_APOBEC3F' 'APOBEC3A_APOBEC3G' 'APOBEC3B_APOBEC3H'
#  'APOBEC3F_APOBEC3G' 'ARAF_RAF1' 'ARPC1A_ARPC1B' 'ARSA_ARSL' 'ARSD_ARSH'
#  'ARSF_ARSL' 'ARSH_ARSL' 'ART3_ART5' 'ASB14_ASB15' 'ASB5_ASB11'
#  'ASB5_ASB13' 'ASRGL1_TASP1' 'ATG4A_ATG4B' 'ATP10A_ATP10D' 'ATP10B_ATP10D'
#  'ATP13A2_ATP13A5' 'ATP1A2_ATP4A' 'ATP2A1_ATP2C1' 'ATP2A3_ATP2C2'
#  'ATP2B2_ATP2B3' 'ATP6V0A1_ATP6V0A2' 'ATP6V1G2_ATP6V1G3' 'ATP8A1_ATP11C'
#  'ATP8A1_ATP8B4' 'ATP8A2_ATP8B2' 'ATP8B1_ATP11C' 'ATP8B2_ATP8B3'
#  'ATP8B4_ATP11A' 'ATXN3_ATXN3L' 'AWAT1_MOGAT1' 'AWAT2_MOGAT3' 'AZU1_PRTN3'
#  'B3GALT1_B3GNT2' 'B3GNT2_B3GNT4' 'B3GNT2_B3GNT6' 'B3GNT2_B3GNT7'
#  'B3GNT3_B3GNT8' 'B3GNT6_B3GNT7' 'B4GALNT3_B4GALNT4' 'BAZ2A_BAZ2B'
#  'BCAT1_BCAT2' 'BCL6_BCL6B' 'BIRC3_BIRC8' 'BLK_HCK' 'BLK_SRMS'
#  'BMI1_PCGF3' 'BMPR1A_TGFBR1' 'BPGM_PGAM1' 'BRD3_BRDT' 'BTBD1_BTBD3'
#  'BTD_VNN1' 'BTK_ITK' 'C1R_C1S' 'C1S_MASP1' 'C1S_MASP2' 'C2_CFB'
#  'CABP2_CALM2' 'CABP5_CALM2' 'CALM1_TNNC1' 'CALM2_CALML4' 'CALM2_TNNC1'
#  'CALM3_CALML5' 'CAMK1D_CAMK2A' 'CAMK1D_CAMKV' 'CAMK1D_PSKH2'
#  'CAMK1G_CAMK2G' 'CAMK1G_PSKH2' 'CAMK1_CAMK2D' 'CAMK1_PSKH1'
#  'CAMK2A_CAMK4' 'CAMK2D_CAMK4' 'CAMK4_PNCK' 'CAMKK1_CAMKK2'
#  'CAPN12_CAPN13' 'CAPN1_CAPN13' 'CAPN2_CAPN13' 'CAPN2_CAPN8'
#  'CAPN3_CAPN14' 'CAPN3_CAPN6' 'CAPN5_CAPN8' 'CAPN8_CAPN12' 'CAPN9_CAPN12'
#  'CAPN9_CAPN13' 'CARD16_CARD18' 'CASK_MPP7' 'CASP3_CASP14' 'CASP4_CASP5'
#  'CBLB_CBLC' 'CBX7_CBX8' 'CCL3_CCL16' 'CCL3_CCL4' 'CCL5_CCL18'
#  'CD163L1_SSC4D' 'CD5L_CD163L1' 'CDC25A_CDC25B' 'CDC42BPA_CDC42BPG'
#  'CDC42BPB_DMPK' 'CDCP2_TLL2' 'CDK14_CDK18' 'CDK20_CDKL1' 'CDK5R1_CDK5R2'
#  'CDKL1_CDKL5' 'CDKL4_CDKL5' 'CDKN2B_CDKN2D' 'CDY2A_CDYL2' 'CDY2B_CDYL'
#  'CEACAM1_CEACAM21' 'CEACAM5_CEACAM21' 'CEACAM7_PSG2' 'CEACAM7_PSG4'
#  'CEACAM7_PSG6' 'CELA1_CELA2B' 'CELA1_CTRL' 'CELA2A_CTRC' 'CELA2B_CTRL'
#  'CELA3B_CTRB1' 'CELA3B_CTRB2' 'CES1_CES2' 'CES1_NLGN3' 'CES2_CES5A'
#  'CES2_NLGN1' 'CES3_CES4A' 'CES4A_CES5A' 'CES5A_NLGN2' 'CFD_GZMH'
#  'CHCHD3_CHCHD6' 'CHI3L2_CHIT1' 'CHIA_CHIT1' 'CHMP1A_CHMP1B' 'CHPF_CHPF2'
#  'CHST13_CHST14' 'CHST8_CHST12' 'CHST9_CHST13' 'CIB1_CIB4' 'CILK1_MOK'
#  'CKB_CKMT2' 'CKMT1B_CKMT2' 'CLCN6_CLCN7' 'CMA1_GZMA' 'CNDP1_CNDP2'
#  'CORO1A_CORO1C' 'CORO1A_CORO7' 'CORO1C_CORO2B' 'CPA1_CPA2' 'CPA1_CPB2'
#  'CPA2_CPB1' 'CPA3_CPA5' 'CPA3_CPB1' 'CPA4_CPB1' 'CPA5_CPA6' 'CPD_CPE'
#  'CPD_CPN1' 'CPE_CPN1' 'CPN1_CPXM1' 'CPNE2_CPNE3' 'CPNE3_CPNE8'
#  'CPT1B_CRAT' 'CPXM1_CPZ' 'CRMP1_DPYS' 'CRMP1_DPYSL3' 'CSF1R_PDGFRA'
#  'CSK_MATK' 'CSNK1A1L_TTBK2' 'CSNK1D_TTBK1' 'CSNK2A1_CSNK2A3'
#  'CT47A10_CT47B1' 'CT47A3_CT47B1' 'CT47A9_CT47B1' 'CTRB2_CTRL'
#  'CTSB_TINAG' 'CTSD_CTSE' 'CTSD_PGC' 'CTSE_PGA4' 'CTSF_CTSK' 'CTSG_GZMB'
#  'CTSH_CTSL' 'CTSK_CTSS' 'CTSV_CTSW' 'DAPK1_DAPK3' 'DAPK2_MYLK'
#  'DAPK3_MYLK' 'DCAF12_DCAF12L2' 'DCAF8_DCAF8L1' 'DCK_DGUOK' 'DCLK2_DCX'
#  'DENND4A_DENND4B' 'DGAT2_MOGAT1' 'DGAT2_MOGAT2' 'DGKB_DGKG' 'DGKE_DGKH'
#  'DHH_IHH' 'DLG2_DLG3' 'DMPK_STK38' 'DNAH1_DNAH2' 'DNAH2_DNAH6'
#  'DNM1_DNM3' 'DPF1_DPF3' 'DPP4_FAP' 'DPYSL2_DPYSL5' 'DPYS_DPYSL3'
#  'DTX3_DTX3L' 'DUSP13B_STYXL2' 'DUSP18_DUSP21' 'DUSP1_DUSP2' 'DUSP1_DUSP6'
#  'DUSP2_DUSP16' 'DUSP2_DUSP9' 'DUSP4_DUSP5' 'DYRK1B_DYRK4' 'DYRK4_HIPK2'
#  'ECE2_ECEL1' 'ECE2_PHEX' 'EDIL3_NRP1' 'EFNA2_EFNA3' 'EFNA4_EFNA5'
#  'EIF2AK2_EIF2AK3' 'ELANE_PRTN3' 'ELOA_ELOA3CP' 'ELOA_ELOA3DP'
#  'ELOVL2_ELOVL4' 'ELOVL4_ELOVL7' 'EML1_EML4' 'EML2_EML3' 'EML3_EML4'
#  'ENAH_VASP' 'ENPEP_LNPEP' 'ENPP2_ENPP3' 'ENPP4_ENPP6' 'ENTPD1_ENTPD8'
#  'ENTPD5_ENTPD6' 'EPHA1_EPHA3' 'EPHA1_EPHA8' 'EPHA2_EPHA3' 'EPHA2_EPHB1'
#  'EPHA3_EPHA4' 'EPHA3_EPHB1' 'EPHA4_EPHA7' 'EPHA4_EPHB4' 'EPHA5_EPHA7'
#  'EPHA6_EPHB1' 'EPHA7_EPHA8' 'EPHA8_EPHB3' 'EPHB3_EPHB4' 'EPS8_EPS8L2'
#  'ERAP1_TRHDE' 'ERBB2_ERBB3' 'ETNPPL_PHYKPL' 'EYA1_EYA3' 'EYA3_EYA4'
#  'F10_PROC' 'F12_PLAT' 'F13A1_TGM5' 'F7_PROC' 'FAHD2A_FAHD2B'
#  'FARP1_FRMD7' 'FBXO25_FBXO32' 'FBXO45_SPSB2' 'FBXO6_FBXO27'
#  'FERMT1_FERMT2' 'FGFR1_FGFR2' 'FGFR3_FLT4' 'FGR_LYN' 'FKBP1A_FKBP1B'
#  'FMN1_FMN2' 'FOXP2_FOXP3' 'FOXP2_FOXP4' 'FRK_PTK6' 'FUBP1_KHSRP'
#  'FURIN_PCSK5' 'FUT10_FUT11' 'FUT1_FUT2' 'FUT3_FUT9' 'FUT4_FUT7'
#  'FUT5_FUT6' 'FUT7_FUT9' 'FYN_SRMS' 'G6PC2_G6PC3' 'GALNS_STS'
#  'GALNT11_GALNTL5' 'GALNT12_GALNTL5' 'GALNT14_GALNTL5' 'GALNT1_GALNT14'
#  'GALNT1_GALNT5' 'GALNT2_GALNT14' 'GALNT2_GALNT6' 'GALNT2_GALNTL5'
#  'GALNT3_GALNT6' 'GALNT4_GALNT6' 'GALNT4_GALNTL5' 'GALNT5_GALNT16'
#  'GALNT7_GALNT10' 'GALNT7_GALNTL6' 'GALNT9_GALNT17' 'GCK_HK1'
#  'GCNT1_GCNT3' 'GCNT3_GCNT7' 'GGT1_GGT7' 'GIGYF1_GIGYF2' 'GIPC1_GIPC2'
#  'GLB1L_GLB1L2' 'GLYATL1_GLYATL2' 'GNB1_GNB3' 'GNB3_GNB4' 'GNS_SULF1'
#  'GRAP_GRAP2' 'GRK1_GRK3' 'GRK2_GRK3' 'GRK3_GRK6' 'GSPT2_HBS1L'
#  'GUCY2D_NPR1' 'GYG1_GYG2' 'GZMB_GZMH' 'GZMK_GZMM' 'HABP2_LPA'
#  'HACD1_HACD2' 'HAS2_HAS3' 'HCK_SRMS' 'HDAC4_HDAC9' 'HECW1_HECW2'
#  'HECW1_ITCH' 'HECW2_NEDD4L' 'HERC3_HERC4' 'HERC5_HERC6' 'HGF_PLG'
#  'HIPK2_HIPK3' 'HK1_HKDC1' 'HK2_HK3' 'HPN_TMPRSS4' 'HPN_TMPRSS5' 'HP_HPR'
#  'HTRA1_HTRA2' 'HYAL1_HYAL2' 'HYAL3_HYAL4' 'IHH_SHH' 'IKBKE_TBK1'
#  'INPP5B_OCRL' 'IP6K2_IP6K3' 'IRF2BP1_IRF2BP2' 'ITCH_SMURF1' 'ITGA3_ITGA5'
#  'ITPKA_ITPKC' 'JAK1_TYK2' 'JAKMIP1_JAKMIP2' 'JMJD1C_KDM3B' 'KAT6B_KAT7'
#  'KBTBD6_KBTBD7' 'KCNA1_KCNA3' 'KCNA1_KCNC1' 'KCNA1_KCND3' 'KCNA2_KCNC3'
#  'KCNA2_KCND1' 'KCNA3_KCNA10' 'KCNA3_KCND1' 'KCNA5_KCNA7' 'KCNA7_KCND1'
#  'KCNA7_KCND2' 'KCNB1_KCNG2' 'KCNB1_KCNS3' 'KCNB2_KCNG3' 'KCNB2_KCNS3'
#  'KCNC1_KCNC3' 'KCNC2_KCNC4' 'KCND2_KCND3' 'KCNF1_KCNS2' 'KCNG1_KCNS3'
#  'KCNG1_KCNV2' 'KCNG3_KCNS2' 'KCNG4_KCNS1' 'KCNH1_KCNH4' 'KCNH2_KCNH3'
#  'KCNH2_KCNH8' 'KCNH4_KCNH5' 'KCNH5_KCNH6' 'KCNN1_KCNN3' 'KCNS1_KCNV1'
#  'KCNS3_KCNV2' 'KCTD13_TNFAIP1' 'KCTD2_KCTD9' 'KCTD7_KCTD14' 'KDM4A_KDM4B'
#  'KDM4B_KDM4D' 'KDM4B_KDM4E' 'KDM5A_KDM5D' 'KDM5B_KDM5D' 'KDM7A_PHF8'
#  'KEAP1_KLHL18' 'KEAP1_KLHL5' 'KLHDC8A_KLHDC8B' 'KLHL13_KLHL31'
#  'KLHL15_KLHL26' 'KLHL17_KLHL18' 'KLHL18_KLHL28' 'KLHL1_KLHL5'
#  'KLHL1_KLHL8' 'KLHL22_KLHL36' 'KLHL26_KLHL36' 'KLHL2_KLHL28'
#  'KLHL2_KLHL8' 'KLHL3_KLHL28' 'KLHL4_KLHL12' 'KLHL5_KLHL17' 'KLHL5_KLHL20'
#  'KLHL6_KLHL24' 'KLHL8_KLHL18' 'KLHL9_KLHL26' 'KLK11_KLK13' 'KLK12_PRSS2'
#  'KLK13_KLK15' 'KLK14_PRSS1' 'KLK1_KLK2' 'KLK3_KLK7' 'KLK6_PRSS1'
#  'KLK8_KLK11' 'KLK8_PRSS2' 'KLK9_KLK12' 'KLK9_KLK15' 'KLK9_PRSS3'
#  'LALBA_SPACA5B' 'LATS2_STK38' 'LCK_SRMS' 'LDHAL6A_UEVLD' 'LDLR_LRP1'
#  'LIMD1_LPP' 'LIPA_LIPF' 'LIPA_LIPN' 'LIPF_LIPM' 'LIPH_LIPI' 'LIPJ_LIPK'
#  'LIPM_LIPN' 'LOXL3_LOXL4' 'LPA_PLAU' 'LPCAT2_LPCAT4' 'LPIN1_LPIN2'
#  'LRP1B_LRP6' 'LRP1_LRP4' 'LRP1_LRP5' 'LRP1_LRP6' 'LRP2_VLDLR' 'LRP5_LRP6'
#  'LTBP1_LTBP2' 'LTF_TF' 'LYPLA1_LYPLAL1' 'LYZ_SPACA5B' 'MAOA_MAOB'
#  'MAP2K1_MAP2K4' 'MAP2K2_MAP2K3' 'MAP2K3_MAP2K4' 'MAP2K4_MAP2K7'
#  'MAP3K11_MAP3K21' 'MAP3K6_MAP3K15' 'MAP3K9_MAP3K21' 'MAP4K1_STK26'
#  'MAP4K2_STK25' 'MAP4K3_STK24' 'MAP4K4_TNIK' 'MAP4K5_STK25'
#  'MAPK11_MAPK12' 'MAPK12_MAPK13' 'MAPK1_MAPK6' 'MAPK8_MAPK10'
#  'MAPK8_MAPK9' 'MAPKAPK2_MAPKAPK3' 'MAPKAPK3_MAPKAPK5' 'MARK1_MARK3'
#  'MARK1_SIK3' 'MARK2_NIM1K' 'MARK4_SIK3' 'MAST1_MAST4' 'MCRIP1_MCRIP2'
#  'ME2_ME3' 'MERTK_TYRO3' 'METTL2B_METTL6' 'MEX3C_MEX3D' 'MGAM2_SI'
#  'MGRN1_RNF157' 'MKRN1_MKRN2' 'MME_PHEX' 'MMP10_MMP16' 'MMP10_MMP25'
#  'MMP11_MMP17' 'MMP11_MMP25' 'MMP12_MMP16' 'MMP12_MMP27' 'MMP13_MMP24'
#  'MMP14_MMP20' 'MMP15_MMP20' 'MMP16_MMP24' 'MMP17_MMP25' 'MMP1_MMP12'
#  'MMP1_MMP14' 'MMP1_MMP24' 'MMP20_MMP25' 'MMP26_MMP28' 'MMP3_MMP14'
#  'MMP3_MMP25' 'MMP7_MMP10' 'MMP7_MMP15' 'MMP7_MMP8' 'MMP8_MMP14'
#  'MMP8_MMP24' 'MOB1B_MOB3B' 'MORN3_RSPH10B2' 'MPP2_MPP3' 'MPP3_MPP7'
#  'MPP3_PALS2' 'MTF2_PHF1' 'MTM1_MTMR3' 'MTM1_MTMR9' 'MTMR1_MTMR9'
#  'MTMR2_MTMR9' 'MTMR6_MTMR7' 'MTMR8_MTMR9' 'MX1_MX2' 'MYLK3_MYLK4'
#  'N4BP2_N4BP2L1' 'NALF1_NALF2' 'NAT1_NAT2' 'NCOR1_NCOR2' 'NEDD4_SMURF1'
#  'NEDD4_WWP1' 'NEK2_NEK4' 'NEK4_NEK7' 'NEU2_NEU3' 'NEU2_NEU4'
#  'NFE2_NFE2L1' 'NME1_NME4' 'NME8_NME9' 'NOMO1_NOMO3' 'NSD1_NSD2'
#  'NT5C3A_NT5C3B' 'NTRK1_NTRK2' 'NUAK1_NUAK2' 'NUDT3_NUDT4' 'OAS1_OASL'
#  'OTUB1_OTUB2' 'OXSR1_STK39' 'PADI1_PADI2' 'PADI2_PADI6' 'PAK1_PAK3'
#  'PAK3_PAK4' 'PANK2_PANK3' 'PARP11_PARP12' 'PASK_PIM2' 'PCGF1_PCGF6'
#  'PCK1_PCK2' 'PCSK1_PCSK7' 'PCSK4_PCSK5' 'PCYT1A_PCYT1B' 'PDK1_PDK2'
#  'PDK1_PDK3' 'PDP1_PDP2' 'PELI1_PELI3' 'PFKFB2_PFKFB4' 'PGA4_PGC'
#  'PGC_REN' 'PHACTR1_PHACTR3' 'PHACTR1_PHACTR4' 'PHC1_PHC3' 'PHKA1_PHKB'
#  'PHLPP1_PHLPP2' 'PIAS1_PIAS2' 'PIAS1_PIAS3' 'PIK3C2A_PIK3C2B'
#  'PIK3C2A_PIK3C2G' 'PIK3CD_PIK3CG' 'PIM2_PIM3' 'PIP4K2B_PIP5K1C'
#  'PKN1_PRKCD' 'PLA2G1B_PLA2G2D' 'PLA2G2A_PLA2G2E' 'PLA2G2D_PLA2G2F'
#  'PLA2G4A_PLA2G4F' 'PLA2G4D_PLA2G4F' 'PLAGL1_PLAGL2' 'PLCB1_PLCB3'
#  'PLCB2_PLCZ1' 'PLCB4_PLCD1' 'PLCD1_PLCL2' 'PLCD4_PLCH1' 'PLCH1_PLCL2'
#  'PLCH2_PLCL1' 'PLCL2_PLCZ1' 'PLPP2_PLPP3' 'PLPPR1_PLPPR5' 'PLXNA1_PLXNA2'
#  'PLXNA1_PLXNB1' 'PLXNA1_PLXND1' 'PLXNA3_PLXNA4' 'PLXNA4_PLXNB3'
#  'PLXNA4_PLXND1' 'PLXNB3_PLXND1' 'PNLIP_PNLIPRP3' 'PNPLA3_PNPLA4'
#  'PON1_PON3' 'POU2F3_POU3F2' 'PPIP5K1_PPIP5K2' 'PPM1H_PPM1J'
#  'PPP1R13L_TP53BP2' 'PPP2R2A_PPP2R2C' 'PPP2R2A_PPP2R2D' 'PPP2R2B_PPP2R2D'
#  'PPP2R5A_PPP2R5C' 'PPP2R5C_PPP2R5D' 'PPP3CB_PPP3CC' 'PRB1_PRB4'
#  'PRKACA_PRKACB' 'PRKACB_PRKACG' 'PRKAG1_PRKAG2' 'PRKCA_PRKCE'
#  'PRKCA_PRKCZ' 'PRKCB_PRKCI' 'PRKCB_PRKCQ' 'PRKCD_PRKCZ' 'PRKCG_PRKCI'
#  'PRKCI_PRKCQ' 'PRKG1_PRKG2' 'PRMT3_PRMT6' 'PRPS1L1_PRPSAP1'
#  'PRPS1_PRPSAP2' 'PRRG2_PRRG4' 'PRSS21_PRSS33' 'PRSS22_PRSS33'
#  'PRSS27_PRSS33' 'PRSS27_PRSS48' 'PRSS33_PRSS38' 'PRSS37_PRSS58'
#  'PRSS48_TPSG1' 'PRSS8_PRSS38' 'PSKH1_PSKH2' 'PSMB8_PSMB11' 'PTK2_PTK2B'
#  'PTP4A2_PTP4A3' 'PTPN18_PTPN22' 'PTPN7_PTPRR' 'PTPRA_PTPRM' 'PTPRA_PTPRS'
#  'PTPRD_PTPRS' 'PTPRE_PTPRT' 'PTPRK_PTPRU' 'PYGB_PYGL' 'RAB40AL_RAB40C'
#  'RABGAP1_RABGAP1L' 'RFPL1_RFPL3' 'RFPL1_RFPL4A' 'RFPL3_RFPL4B'
#  'RHBDL1_RHBDL2' 'RLF_ZNF292' 'RNASE2_RNASE6' 'RNASE6_RNASE7'
#  'RNF121_RNF175' 'RNF130_RNF148' 'RNF13_RNF167' 'RNF144A_RNF144B'
#  'RNF19A_RNF19B' 'ROCK1_STK38' 'RPS6KA1_RPS6KA2' 'RPS6KA1_RPS6KB2'
#  'RPS6KA2_RPS6KA4' 'RPS6KA2_SGK2' 'RPS6KA2_SGK3' 'RPS6KA3_RPS6KB2'
#  'RPS6KA4_RPS6KB1' 'RPS6KA4_SGK2' 'RPS6KA5_SGK3' 'RPS6KA6_RPS6KB2'
#  'RPS6KB1_SGK3' 'RPS6KB2_SGK2' 'SAMD8_SGMS1' 'SCAMP1_SCAMP3'
#  'SCAMP2_SCAMP5' 'SCAMP3_SCAMP5' 'SCRN2_SCRN3' 'SEMA3A_SEMA3D'
#  'SEMA3A_SEMA4D' 'SEMA3B_SEMA3G' 'SEMA3C_SEMA3G' 'SEMA3E_SEMA3F'
#  'SEMA4A_SEMA4B' 'SEMA4B_SEMA4C' 'SEMA4C_SEMA4G' 'SEMA6A_SEMA6B'
#  'SEMA6C_SEMA6D' 'SET_TSPYL1' 'SFRP1_SFRP5' 'SGMS1_SGMS2' 'SH3RF1_SH3RF2'
#  'SIAH2_SIAH3' 'SIRT2_SIRT3' 'SLC24A1_SLC24A2' 'SLC27A1_SLC27A4'
#  'SLC27A2_SLC27A5' 'SLC27A4_SLC27A6' 'SLK_STK4' 'SMURF1_WWP2'
#  'SOAT1_SOAT2' 'SOCS4_SOCS5' 'SOX9_SOX10' 'SPPL2A_SPPL2C' 'SRC_YES1'
#  'SSH2_SSH3' 'ST3GAL4_ST3GAL5' 'ST6GALNAC3_ST6GALNAC5' 'STAMBP_STAMBPL1'
#  'STK10_STK25' 'STK32A_STK32C' 'STK3_STK26' 'STRADA_STRADB'
#  'STXBP5_STXBP5L' 'SULT1A1_SULT1B1' 'SULT1A1_SULT1C3' 'SULT1A2_SULT1A4'
#  'SULT1A2_SULT1B1' 'SULT1A2_SULT2B1' 'SULT1A3_SULT2A1' 'SULT1A4_SULT1C4'
#  'SULT1B1_SULT1C3' 'SULT1C2_SULT1C4' 'SULT1C3_SULT1E1' 'SULT1C4_SULT2B1'
#  'SYNJ1_SYNJ2' 'TBC1D10A_TBC1D10B' 'TBC1D1_TBC1D4' 'TBC1D8B_TBC1D9B'
#  'TBL1X_TBL1XR1' 'TENM2_TENM3' 'TGFB2_TGFB3' 'TGM1_TGM5' 'TGM2_TGM5'
#  'TGM3_TGM4' 'TGM3_TGM7' 'TJP1_TJP2' 'TLE1_TLE2' 'TLE3_TLE4'
#  'TMPRSS11A_TMPRSS11E' 'TMPRSS11E_TMPRSS11F' 'TMPRSS2_TMPRSS5'
#  'TMPRSS3_TMPRSS5' 'TMT1A_TMT1B' 'TNK1_TNK2' 'TNS2_TNS3' 'TPSAB1_TPSB2'
#  'TRABD2A_TRABD2B' 'TRAF2_TRAF5' 'TRIB2_TRIB3' 'TSPAN17_TSPAN33'
#  'TSSK1B_TSSK6' 'TSSK4_TSSK6' 'UAP1_UAP1L1' 'UBE2D1_UBE2E3'
#  'UBE2D4_UBE2E2' 'UBE2Q2_UBE2QL1' 'UCK1_UCKL1' 'ULK1_ULK2' 'USP11_USP15'
#  'USP16_USP45' 'USP22_USP27X' 'USP27X_USP44' 'USP2_USP21' 'USP3_USP44'
#  'USP4_USP32' 'VNN1_VNN2' 'WIPI1_WIPI2' 'WSCD1_WSCD2' 'ZBTB12_ZBTB26'
#  'ZBTB3_ZBTB18' 'ZBTB3_ZBTB42' 'ZBTB8A_ZBTB46' 'ZBTB9_ZBTB22' 'ZFR_ZFR2'
#  'ZFYVE9_ZFYVE16' 'ZNF423_ZNF521']
# Repeat 1, Fold 3:
#   TRAIN groups: ['A3GALT2_ABO' 'A3GALT2_GBGT1' 'A3GALT2_GLT6D1' ... 'ZNRF1_ZNRF2'
#  'ZXDA_ZXDC' 'ZXDB_ZXDC']
#   TEST groups: ['AADACL2_AADACL3' 'AADAC_AADACL4' 'ABL1_TEC' 'ABL2_TEC' 'ABL2_TXK'
#  'ACAA2_ACAT2' 'ACAD8_ACADS' 'ACAD9_ACADVL' 'ACADM_ACADS' 'ACADS_ACADVL'
#  'ACAT1_HADHB' 'ACHE_CES2' 'ACOT11_ACOT12' 'ACP2_ACP3' 'ACSL1_ACSL5'
#  'ACSL3_ACSL4' 'ACSM1_ACSM4' 'ACSM2A_ACSM4' 'ACSM2B_ACSM4' 'ACSM3_ACSM6'
#  'ACVR1B_BMPR1A' 'ACVR1C_ACVR2B' 'ACVR1_ACVR1C' 'ACVR1_TGFBR1'
#  'ACVRL1_TGFBR1' 'ADAM12_ADAM15' 'ADAM12_ADAM28' 'ADAM19_ADAM33'
#  'ADAM21_ADAM30' 'ADAM2_ADAM18' 'ADAM8_ADAM28' 'ADAM9_ADAM30'
#  'ADAMTS12_ADAMTS16' 'ADAMTS15_ADAMTS20' 'ADAMTS1_ADAMTS9'
#  'ADAMTS4_ADAMTS15' 'ADAMTS4_ADAMTS9' 'ADAMTS5_ADAMTS20'
#  'ADAMTS6_ADAMTS10' 'ADAMTS6_ADAMTS12' 'ADAMTS6_ADAMTS18'
#  'ADAMTS7_ADAMTS16' 'ADAMTS8_ADAMTS9' 'ADGRL1_ADGRL3' 'AEBP1_CPXM1'
#  'AGBL1_AGTPBP1' 'AGBL4_AGTPBP1' 'AICDA_APOBEC3B' 'AK1_AK5' 'AKT1_AKT3'
#  'AKT1_RPS6KB1' 'AKT1_SGK3' 'AKT2_RPS6KA5' 'AKT2_SGK3' 'AKT3_RPS6KB1'
#  'ALK_LTK' 'AMHR2_BMPR2' 'AMPD2_AMPD3' 'ANG_RNASE4' 'ANP32A_ANP32D'
#  'ANPEP_ERAP2' 'AP1B1_AP2B1' 'APOBEC3A_APOBEC3B' 'APOBEC3A_APOBEC3H'
#  'APOBEC3C_APOBEC3D' 'APOBEC3C_APOBEC3H' 'APOBEC3F_APOBEC3H' 'ARG1_ARG2'
#  'ARSA_ARSD' 'ARSA_GALNS' 'ARSD_ARSL' 'ARSF_GALNS' 'ARSH_GALNS'
#  'ARSL_GALNS' 'ART4_ART5' 'ASB2_ASB14' 'ASB4_ASB18' 'ATAD2_ATAD2B'
#  'ATG4A_ATG4D' 'ATP11A_ATP11B' 'ATP13A3_ATP13A4' 'ATP1A2_ATP1A3'
#  'ATP1A4_ATP4A' 'ATP2A1_ATP2C2' 'ATP2B2_ATP2B4' 'ATP6V0A1_ATP6V0A4'
#  'ATP6V0A4_TCIRG1' 'ATP8A1_ATP8A2' 'ATP8A2_ATP11A' 'ATP8A2_ATP8B3'
#  'ATP8B1_ATP8B2' 'ATP8B2_ATP11C' 'ATP8B4_ATP11B' 'ATP8B4_ATP11C'
#  'AUH_ECHDC2' 'AWAT1_MOGAT2' 'AWAT2_DGAT2' 'AWAT2_MOGAT2'
#  'B3GALNT1_B3GALT1' 'B3GALT2_B3GALT5' 'B3GNT2_B3GNT3' 'B3GNT2_B3GNT8'
#  'B3GNT3_B3GNT7' 'B3GNT3_B3GNT9' 'B3GNT4_B3GNT9' 'BACE1_BACE2' 'BCHE_CES2'
#  'BIRC2_BIRC3' 'BIRC2_BIRC8' 'BIRC3_XIAP' 'BLK_FYN' 'BLK_YES1'
#  'BMP1_CDCP2' 'BMPR1B_TGFBR1' 'BPGM_PGAM2' 'BRSK1_BRSK2' 'BTBD1_BTBD2'
#  'BTBD1_BTBD6' 'BTD_VNN2' 'BTK_TXK' 'C1R_HPR' 'C1R_MASP1' 'CAB39_CAB39L'
#  'CABP1_CALM3' 'CABP2_CALM3' 'CABP5_CALM3' 'CALM1_TNNC2' 'CALM2_CALM3'
#  'CALM2_TNNC2' 'CALM3_CALML6' 'CAMK1D_CAMK2B' 'CAMK1D_PNCK' 'CAMK1G_CAMK4'
#  'CAMK1_CAMK1D' 'CAMK1_CAMK2G' 'CAMK1_PSKH2' 'CAMK2A_PNCK' 'CAMK2D_PNCK'
#  'CAND1_CAND2' 'CAPN12_CAPN14' 'CAPN1_CAPN14' 'CAPN2_CAPN14' 'CAPN2_CAPN9'
#  'CAPN3_CAPN12' 'CAPN3_CAPN8' 'CAPN5_CAPN9' 'CAPN8_CAPN13' 'CAPN9_CAPN14'
#  'CARD9_CARD11' 'CASK_PALS2' 'CASP3_CASP6' 'CASP6_CASP10' 'CBLL1_CBLL2'
#  'CCL2_CCL11' 'CCL3_CCL18' 'CCL3_CCL5' 'CCL5_CCL26' 'CCND2_CCND3'
#  'CD163_CD163L1' 'CD5L_DMBT1' 'CDC25A_CDC25C' 'CDC42BPA_DMPK'
#  'CDC42BPB_STK38L' 'CDK10_CDK11A' 'CDK15_CDK16' 'CDK20_CDKL2'
#  'CDK20_CDKL4' 'CDK8_CDK19' 'CDKL2_CDKL3' 'CDKN2A_CDKN2B' 'CDY1B_CDYL'
#  'CDY2B_CDYL2' 'CEACAM3_CEACAM21' 'CEACAM5_CEACAM7' 'CEACAM7_PSG3'
#  'CELA1_CELA3B' 'CELA2A_CELA2B' 'CELA2A_CTRL' 'CELA2B_CELA3A'
#  'CELA3A_CELA3B' 'CELA3A_CTRB1' 'CELA3B_CTRC' 'CES1_CES3' 'CES1_NLGN4X'
#  'CES2_NLGN2' 'CES3_CES5A' 'CES4A_NLGN1' 'CES5A_NLGN4X' 'CFD_GZMK'
#  'CHI3L1_CHI3L2' 'CHI3L1_CHIT1' 'CHI3L2_OVGP1' 'CHM_CHML' 'CHST11_CHST12'
#  'CHST8_CHST11' 'CHSY1_CHSY3' 'CIB2_CIB3' 'CILP_CILP2' 'CKMT1A_CKMT2'
#  'CLK1_CLK3' 'CMA1_GZMB' 'CNKSR1_CNKSR2' 'COQ8A_COQ8B' 'CORO1A_CORO1B'
#  'CORO1B_CORO2A' 'CORO1C_CORO6' 'CPA1_CPA3' 'CPA1_CPB1' 'CPA1_CPO'
#  'CPA2_CPA6' 'CPA3_CPB2' 'CPA3_CPO' 'CPA4_CPB2' 'CPA5_CPB2' 'CPA6_CPO'
#  'CPD_CPM' 'CPE_CPZ' 'CPM_CPZ' 'CPNE3_CPNE4' 'CPNE3_CPNE9' 'CPT1A_CPT1B'
#  'CPXM2_CPZ' 'CRMP1_DPYSL4' 'CSF1R_FLT3' 'CSF1R_PDGFRB' 'CSK_TEC'
#  'CSNK1D_TTBK2' 'CSNK2A2_CSNK2A3' 'CT47A11_CT47B1' 'CT47A4_CT47B1'
#  'CTDSP1_CTDSP2' 'CTDSP1_CTDSPL' 'CTRC_CTRL' 'CTSD_NAPSA' 'CTSD_REN'
#  'CTSE_PGA5' 'CTSF_CTSL' 'CTSG_GZMH' 'CTSH_CTSK' 'CTSH_CTSS' 'CTSK_CTSV'
#  'CUL4A_CUL4B' 'DAPK1_MYLK4' 'DAPK2_MYLK3' 'DAPK3_MYLK4' 'DCAF4L1_DCAF4L2'
#  'DCAF8_DCAF8L2' 'DCK_TK2' 'DCLK1_DCX' 'DCLK2_PHKG2' 'DENND4B_DENND4C'
#  'DGAT2_MOGAT3' 'DGKA_DGKG' 'DGKD_DGKE' 'DGKE_DGKK' 'DHH_SHH' 'DLG2_DLG4'
#  'DMPK_STK38L' 'DNAH1_DNAH3' 'DNAH2_DNAH17' 'DNAH6_DNAH10' 'DPEP1_DPEP2'
#  'DPF2_DPF3' 'DPP7_PRCP' 'DPYSL3_DPYSL4' 'DPYS_DPYSL4' 'DUSP13B_DUSP26'
#  'DUSP14_DUSP26' 'DUSP15_DUSP22' 'DUSP18_DUSP26' 'DUSP1_DUSP8'
#  'DUSP2_DUSP4' 'DUSP3_DUSP13B' 'DUSP4_DUSP6' 'DYRK2_DYRK4' 'ECE1_ECE2'
#  'ECE2_KEL' 'ECEL1_MME' 'EDIL3_NRP2' 'EFNA2_EFNA4' 'EFNB1_EFNB3'
#  'EFNB2_EFNB3' 'ELFN1_ELFN2' 'ELOA_ELOA3P' 'ELOVL2_ELOVL5' 'ELOVL5_ELOVL7'
#  'EML2_EML4' 'ENC1_KLHL24' 'ENPEP_TRHDE' 'ENPP2_ENPP4' 'ENPP5_ENPP6'
#  'ENPP5_ENPP7' 'ENTPD2_ENTPD3' 'EPB42_TGM2' 'EPHA1_EPHA4' 'EPHA1_EPHB1'
#  'EPHA2_EPHA4' 'EPHA2_EPHA7' 'EPHA3_EPHA5' 'EPHA3_EPHB3' 'EPHA3_EPHB4'
#  'EPHA4_EPHA8' 'EPHA5_EPHB1' 'EPHA5_EPHB4' 'EPHA6_EPHA7' 'EPHA7_EPHB1'
#  'EPHA8_EPHB4' 'EPHX3_EPHX4' 'EPS8_EPS8L3' 'ERAP2_LNPEP' 'EVI5_EVI5L'
#  'EYA1_EYA4' 'F10_PROZ' 'F12_PLAU' 'F13A1_TGM3' 'F9_PROC'
#  'FAM171A1_FAM171B' 'FAM20B_FAM20C' 'FBP1_FBP2' 'FBXO2_FBXO17'
#  'FBXO30_FBXO40' 'FER_FES' 'FER_MATK' 'FGFR1_FGFR3' 'FGFR1_FGFR4'
#  'FGR_FRK' 'FGR_PTK6' 'FKBP1A_FKBP3' 'FKBP1A_FKBP4' 'FLT1_KDR'
#  'FOLH1_NAALAD2' 'FRK_FYN' 'FRK_SRC' 'FURIN_PCSK1' 'FUT3_FUT4' 'FUT4_FUT6'
#  'FYN_HCK' 'FYN_SRC' 'FYN_YES1' 'GAA_MGAM' 'GALNT10_GALNT15'
#  'GALNT11_GALNT13' 'GALNT13_GALNT14' 'GALNT15_GALNTL6' 'GALNT1_GALNT12'
#  'GALNT1_GALNT16' 'GALNT1_GALNT6' 'GALNT2_GALNT12' 'GALNT2_GALNT5'
#  'GALNT3_GALNT11' 'GALNT3_GALNT13' 'GALNT3_GALNTL5' 'GALNT5_GALNT11'
#  'GALNT5_GALNT6' 'GALNT6_GALNT13' 'GALNT9_GALNT18' 'GCK_HK2' 'GCNT1_GCNT4'
#  'GDI1_GDI2' 'GDPD4_GDPD5' 'GIPC1_GIPC3' 'GLB1L_GLB1L3' 'GLB1_GLB1L'
#  'GLYATL2_GLYATL3' 'GNB1_GNB4' 'GNB2_GNB4' 'GNS_SULF2' 'GRAP_GRB2'
#  'GRIP1_GRIP2' 'GRK1_GRK5' 'GRK2_GRK4' 'GRK2_GRK5' 'GRK3_GRK7' 'GRK5_GRK6'
#  'GUCY2D_NPR2' 'GZMA_GZMB' 'GZMB_GZMK' 'GZMK_PRSS57' 'HABP2_PLAT'
#  'HABP2_PLAU' 'HCK_LCK' 'HCK_YES1' 'HDAC5_HDAC7' 'HECW1_NEDD4L'
#  'HECW1_WWP2' 'HECW2_WWP1' 'HERC3_HERC5' 'HEXA_HEXB' 'HGFAC_PLAT'
#  'HINT1_HINT2' 'HIPK2_HIPK4' 'HK2_HKDC1' 'HK3_HKDC1' 'HPN_TMPRSS13'
#  'HS6ST2_HS6ST3' 'HTRA1_HTRA3' 'HYAL1_HYAL4' 'HYAL3_SPAM1' 'IGF1R_INSR'
#  'INPP5D_INPPL1' 'IP6K1_IP6K2' 'IRAK1_IRAK4' 'ITCH_SMURF2' 'ITGB5_ITGB7'
#  'ITK_TXK' 'JAK2_JAK3' 'JAK2_TYK2' 'JOSD1_JOSD2' 'KATNAL1_VPS4B'
#  'KCNA10_KCNC1' 'KCNA1_KCNA10' 'KCNA1_KCNC3' 'KCNA2_KCNA10' 'KCNA2_KCNC2'
#  'KCNA2_KCNC4' 'KCNA3_KCNA4' 'KCNA3_KCNC3' 'KCNA5_KCNA10' 'KCNA7_KCNA10'
#  'KCNA7_KCND3' 'KCNB1_KCNG3' 'KCNB1_KCNV1' 'KCNB2_KCNG1' 'KCNB2_KCNV1'
#  'KCNC1_KCNC4' 'KCND1_KCND2' 'KCNF1_KCNV1' 'KCNG2_KCNG3' 'KCNG3_KCNG4'
#  'KCNG4_KCNS2' 'KCNH1_KCNH5' 'KCNH2_KCNH4' 'KCNH3_KCNH4' 'KCNH3_KCNH7'
#  'KCNH5_KCNH7' 'KCNN2_KCNN3' 'KCNS1_KCNV2' 'KCNS2_KCNV1' 'KCNV1_KCNV2'
#  'KCTD11_KCTD21' 'KCTD3_KCTD5' 'KCTD8_KCTD12' 'KDM4A_KDM4C' 'KDM4C_KDM4D'
#  'KDM5B_KDM5C' 'KDM6A_UTY' 'KEAP1_KLHL2' 'KIF21A_KIF21B' 'KIF4B_KIF21A'
#  'KLHL12_KLHL17' 'KLHL13_KLHL32' 'KLHL14_KLHL31' 'KLHL1_KLHL12'
#  'KLHL1_KLHL17' 'KLHL1_KLHL2' 'KLHL20_KLHL28' 'KLHL21_KLHL23'
#  'KLHL23_KLHL29' 'KLHL29_KLHL38' 'KLHL2_KLHL18' 'KLHL31_KLHL36'
#  'KLHL3_KLHL4' 'KLHL4_KLHL17' 'KLHL4_KLHL28' 'KLHL5_KLHL18' 'KLHL5_KLHL28'
#  'KLHL8_KLHL20' 'KLHL9_KLHL13' 'KLHL9_KLHL22' 'KLHL9_KLHL31' 'KLK11_KLK14'
#  'KLK11_PRSS3' 'KLK12_PRSS3' 'KLK14_PRSS2' 'KLK1_KLK3' 'KLK4_KLK5'
#  'KLK6_KLK14' 'KLK6_PRSS2' 'KLK8_KLK14' 'KLK9_KLK13' 'KMT2A_KMT2B'
#  'KMT5B_KMT5C' 'LATS1_LATS2' 'LCAT_PLA2G15' 'LCK_PTK6' 'LCMT1_LCMT2'
#  'LDHAL6B_UEVLD' 'LDLR_LRP1B' 'LDLR_VLDLR' 'LIPA_LIPJ' 'LIPF_LIPN'
#  'LIPH_PNLIP' 'LNX1_LNX2' 'LONRF2_LONRF3' 'LOX_LOXL2' 'LPIN1_LPIN3'
#  'LRP1B_LRP4' 'LRP1_LRP1B' 'LRP1_LRP8' 'LRP2_LRP5' 'LRP4_LRP6'
#  'LTBP1_LTBP4' 'LTC4S_MGST2' 'LTF_MELTF' 'LYPLA1_LYPLA2' 'LYPLA2_LYPLAL1'
#  'MAGI1_MAGI3' 'MAN2A1_MAN2A2' 'MAP2K1_MAP2K6' 'MAP2K3_MAP2K5'
#  'MAP2K4_MAP2K6' 'MAP3K12_MAP3K13' 'MAP3K3_MAP3K19' 'MAP4K1_MAP4K2'
#  'MAP4K1_STK4' 'MAP4K2_STK4' 'MAP4K4_NRK' 'MAP4K5_STK24' 'MAPK10_MAPK12'
#  'MAPK12_MAPK14' 'MAPK3_MAPK4' 'MAPK8IP3_SPAG9' 'MAPK9_MAPK10'
#  'MAPKAPK3_MKNK2' 'MARK1_MARK4' 'MARK2_SIK3' 'MARK3_MARK4' 'MARK4_NIM1K'
#  'MAST2_MAST3' 'MDM2_MDM4' 'MECOM_PRDM16' 'MEP1A_MEP1B' 'MET_MST1R'
#  'MEX3A_MEX3B' 'MEX3B_MEX3D' 'MGAM_MGAM2' 'MIB1_MIB2' 'MID1_MID2'
#  'MKRN1_MKRN3' 'MMP10_MMP11' 'MMP10_MMP15' 'MMP10_MMP27' 'MMP11_MMP24'
#  'MMP12_MMP17' 'MMP13_MMP14' 'MMP13_MMP20' 'MMP14_MMP24' 'MMP15_MMP16'
#  'MMP15_MMP27' 'MMP17_MMP20' 'MMP19_MMP26' 'MMP1_MMP11' 'MMP1_MMP17'
#  'MMP1_MMP7' 'MMP1_MMP8' 'MMP24_MMP25' 'MMP3_MMP12' 'MMP3_MMP17'
#  'MMP3_MMP7' 'MMP7_MMP13' 'MMP7_MMP24' 'MMP8_MMP12' 'MMP8_MMP17'
#  'MOB1A_MOB1B' 'MOGAT1_MOGAT3' 'MORN3_RSPH10B' 'MPP1_MPP7' 'MPP2_PALS2'
#  'MPP4_MPP7' 'MPP7_PALS1' 'MPST_TST' 'MTM1_MTMR1' 'MTM1_MTMR7'
#  'MTMR1_MTMR3' 'MTMR2_MTMR7' 'MTMR3_MTMR9' 'MTMR7_MTMR8' 'MYLK2_MYLK3'
#  'MYLK2_MYLK4' 'MYLK_MYLK4' 'NAPSA_PGA3' 'NCOA1_NCOA3' 'NEDD4L_WWP2'
#  'NEK1_NEK3' 'NEK1_NEK5' 'NEK3_NEK6' 'NEK7_NEK9' 'NEURL1_NEURL3'
#  'NIM1K_SIK1' 'NLN_THOP1' 'NME5_NME7' 'NNMT_PNMT' 'NRK_TNIK'
#  'NT5C1A_NT5C1B' 'NT5C_NT5M' 'NTRK1_NTRK3' 'NUDT3_NUDT10' 'OAS1_OAS2'
#  'OLFM1_OLFM2' 'OLFM2_OLFM3' 'OTULIN_OTULINL' 'PACSIN1_PACSIN3'
#  'PADI1_PADI6' 'PAFAH2_PLA2G7' 'PAK2_PAK4' 'PANK1_PANK2' 'PAPPA_PAPPA2'
#  'PARP2_PARP3' 'PCGF1_PCGF3' 'PCGF3_PCGF6' 'PCSK1_PCSK5' 'PCSK2_PCSK6'
#  'PCSK5_PCSK7' 'PDIA3_PDIA4' 'PDK2_PDK4' 'PDZD4_PDZRN4' 'PELI1_PELI2'
#  'PFKFB1_PFKFB4' 'PGA3_PGC' 'PGA5_REN' 'PGPEP1_PGPEP1L' 'PHACTR3_PHACTR4'
#  'PHF2_PHF8' 'PHLDA1_PHLDA2' 'PIAS2_PIAS4' 'PIK3C2B_PIK3C2G'
#  'PIK3CB_PIK3CD' 'PIK3R2_PIK3R3' 'PIP4K2B_PIP4K2C' 'PKN1_PKN2'
#  'PLA2G1B_PLA2G10' 'PLA2G2A_PLA2G10' 'PLA2G2D_PLA2G10' 'PLA2G2E_PLA2G2F'
#  'PLA2G4B_PLA2G4F' 'PLAG1_PLAGL1' 'PLAU_PLG' 'PLCB1_PLCD4' 'PLCB2_PLCB4'
#  'PLCB3_PLCD4' 'PLCB4_PLCZ1' 'PLCD1_PLCH2' 'PLCD3_PLCL1' 'PLCD4_PLCL2'
#  'PLCL1_PLCL2' 'PLK3_PLK5' 'PLPP6_PLPP7' 'PLPPR1_PLPPR3' 'PLPPR3_PLPPR5'
#  'PLXNA1_PLXNB2' 'PLXNA2_PLXNB3' 'PLXNA3_PLXND1' 'PLXNA4_PLXNB2'
#  'PLXNB2_PLXNB3' 'PNCK_PSKH2' 'PNPLA2_PNPLA4' 'POC1A_POC1B'
#  'POU2F1_POU3F2' 'POU3F2_POU3F4' 'PPM1B_PPM1N' 'PPP1R12B_PPP1R12C'
#  'PPP1R3D_PPP1R3E' 'PPP2R3A_PPP2R3B' 'PPP2R5B_PPP2R5D' 'PPP3CA_PPP3CB'
#  'PPP6R1_PPP6R3' 'PRDM1_ZNF683' 'PRKAB1_PRKAB2' 'PRKACA_PRKG2'
#  'PRKACB_PRKG1' 'PRKACG_PRKG2' 'PRKAR1A_PRKAR2A' 'PRKAR2A_PRKAR2B'
#  'PRKCA_PRKCI' 'PRKCB_PRKCG' 'PRKCD_PRKCH' 'PRKCE_PRKCI' 'PRKCE_PRKCZ'
#  'PRKCG_PRKCQ' 'PRKCH_PRKCQ' 'PRKD1_PRKD2' 'PRMT2_PRMT3' 'PROC_PROZ'
#  'PRPS1_PRPS2' 'PRPSAP1_PRPSAP2' 'PRSS21_PRSS22' 'PRSS21_TPSG1'
#  'PRSS22_TPSG1' 'PRSS27_TPSG1' 'PRSS33_TPSG1' 'PRSS41_PRSS48'
#  'PRSS8_PRSS27' 'PRSS8_TPSG1' 'PSME2_PSME3' 'PTEN_TPTE' 'PTK6_YES1'
#  'PTPN13_PTPN20' 'PTPN5_PTPN7' 'PTPRA_PTPRE' 'PTPRD_PTPRE' 'PTPRE_PTPRM'
#  'PTPRG_PTPRZ1' 'PTPRN_PTPRN2' 'PTPRT_PTPRU' 'QPCT_QPCTL' 'RAB40A_RAB40C'
#  'RFFL_RNF34' 'RFPL2_RFPL4A' 'RFPL2_RFPL4AL1' 'RFPL4A_RFPL4B'
#  'RHBDL2_RHBDL3' 'RING1_RNF2' 'RNASE1_RNASE4' 'RNASE3_RNASE6'
#  'RNF114_RNF166' 'RNF128_RNF148' 'RNF133_RNF148' 'RNF148_RNF150'
#  'RNFT1_RNFT2' 'ROR1_ROR2' 'RPS6KA1_RPS6KA4' 'RPS6KA1_RPS6KA6'
#  'RPS6KA1_SGK3' 'RPS6KA2_RPS6KB1' 'RPS6KA3_RPS6KA6' 'RPS6KA4_RPS6KA5'
#  'RPS6KA5_RPS6KB2' 'RPS6KB1_SGK1' 'RPS6KC1_RPS6KL1' 'SBK1_SBK3'
#  'SBK2_SBK3' 'SCAMP2_SCAMP3' 'SCRN1_SCRN2' 'SEC23A_SEC23B' 'SEC31A_SEC31B'
#  'SEMA3A_SEMA3G' 'SEMA3B_SEMA3D' 'SEMA3B_SEMA4G' 'SEMA3C_SEMA3F'
#  'SEMA3D_SEMA3F' 'SEMA4A_SEMA4D' 'SEMA4B_SEMA4G' 'SEMA4F_SEMA4G'
#  'SEMA6B_SEMA6C' 'SEPHS1_SEPHS2' 'SFRP1_SFRP2' 'SGK1_SGK3' 'SGPP1_SGPP2'
#  'SH3BP5_SH3BP5L' 'SHC1_SHC2' 'SIAH1_SIAH2' 'SIK2_SIK3' 'SIRT6_SIRT7'
#  'SLC24A1_SLC24A3' 'SLC27A1_SLC27A2' 'SLC27A2_SLC27A3' 'SLC27A3_SLC27A6'
#  'SLK_STK25' 'SMURF1_SMURF2' 'SMYD1_SMYD2' 'SOST_SOSTDC1' 'SPOP_SPOPL'
#  'SPSB1_SPSB4' 'SSC4D_SSC5D' 'SSH1_SSH3' 'ST3GAL3_ST3GAL4'
#  'ST6GALNAC1_ST6GALNAC2' 'STC1_STC2' 'STK25_STK26' 'STK3_STK24'
#  'STK4_STK25' 'STRN_STRN4' 'SULT1A1_SULT1A4' 'SULT1A1_SULT1C4'
#  'SULT1A1_SULT2B1' 'SULT1A2_SULT1C4' 'SULT1A2_SULT1E1' 'SULT1A3_SULT1C4'
#  'SULT1A4_SULT1C2' 'SULT1A4_SULT2B1' 'SULT1B1_SULT2A1' 'SULT1C2_SULT2B1'
#  'SULT1C4_SULT1E1' 'SULT2A1_SULT2B1' 'TAOK1_TAOK2' 'TBC1D12_TBC1D14'
#  'TBC1D2_TBC1D2B' 'TBC1D8_TBC1D9B' 'TENM1_TENM2' 'TENT4A_TENT4B'
#  'TESK1_TESK2' 'TGM1_TGM3' 'TGM2_TGM3' 'TGM3_TGM5' 'TGM4_TGM7' 'TGM5_TGM6'
#  'TINAG_TINAGL1' 'TKT_TKTL1' 'TLE2_TLE3' 'TLE2_TLE4' 'TLL1_TLL2'
#  'TMPRSS11B_TMPRSS11F' 'TMPRSS3_TMPRSS15' 'TMPRSS6_TMPRSS7' 'TNS1_TNS3'
#  'TOR1A_TOR1B' 'TPST1_TPST2' 'TRAF1_TRAF5' 'TRIB1_TRIB2' 'TRPM3_TRPM6'
#  'TSSK1B_TSSK3' 'TSSK2_TSSK3' 'TSSK3_TSSK4' 'TUBB2A_TUBB8' 'UBE2A_UBE2B'
#  'UBE2D2_UBE2L6' 'UBE2Q1_UBE2Q2' 'UCHL1_UCHL3' 'UGGT1_UGGT2' 'UNK_UNKL'
#  'USP12_USP46' 'USP17L29_USP42' 'USP26_USP29' 'USP35_USP46' 'USP4_USP11'
#  'USP9X_USP9Y' 'WDFY3_WDFY4' 'WNK3_WNK4' 'YTHDF1_YTHDF2' 'YTHDF2_YTHDF3'
#  'ZBTB2_ZBTB25' 'ZBTB7A_ZBTB7C' 'ZFAND5_ZFAND6' 'ZNF280A_ZNF280D']
# Repeat 1, Fold 4:
#   TRAIN groups: ['A3GALT2_ABO' 'A3GALT2_GBGT1' 'A3GALT2_GLT6D1' ... 'ZNF423_ZNF521'
#  'ZNRF1_ZNRF2' 'ZXDB_ZXDC']
#   TEST groups: ['AADACL2_NCEH1' 'AADAC_NCEH1' 'ABL1_CSK' 'ABL1_TXK' 'ABO_GBGT1'
#  'ACAA2_HADHB' 'ACAD8_ACADSB' 'ACAD9_IVD' 'ACADM_ACADSB' 'ACADS_GCDH'
#  'ACAT2_HADHB' 'ACHE_CES3' 'ACOX1_ACOX2' 'ACSL1_ACSL6' 'ACSM1_ACSM5'
#  'ACSM1_ACSM6' 'ACSM2B_ACSM5' 'ACSM4_ACSM5' 'ACVR1B_ACVR1C'
#  'ACVR1B_BMPR1B' 'ACVR1C_ACVRL1' 'ACVR1_ACVRL1' 'ACVR2A_ACVR2B'
#  'ACYP1_ACYP2' 'ADAM12_ADAM33' 'ADAM15_ADAM33' 'ADAM20_ADAM21'
#  'ADAM22_ADAM23' 'ADAM2_ADAM32' 'ADAM8_ADAM33' 'ADAMTS10_ADAMTS12'
#  'ADAMTS12_ADAMTS17' 'ADAMTS16_ADAMTS17' 'ADAMTS16_ADAMTS18'
#  'ADAMTS1_ADAMTS20' 'ADAMTS2_ADAMTS14' 'ADAMTS4_ADAMTS20'
#  'ADAMTS4_ADAMTS8' 'ADAMTS5_ADAMTS8' 'ADAMTS6_ADAMTS19' 'ADAMTS7_ADAMTS19'
#  'ADAMTSL4_THSD4' 'ADGRL1_ADGRL4' 'AEBP1_CPXM2' 'AGBL2_AGBL3'
#  'AGXT2_ETNPPL' 'AICDA_APOBEC3C' 'AICDA_APOBEC3G' 'AKAP13_ARHGEF2'
#  'AKT1_RPS6KA2' 'AKT1_RPS6KA5' 'AKT2_AKT3' 'AKT2_RPS6KB1' 'AKT3_RPS6KA1'
#  'AKT3_RPS6KA2' 'AKT3_RPS6KB2' 'ALPG_ALPI' 'ALPI_ALPP' 'ALS2_ALS2CL'
#  'ANKK1_RIPK4' 'ANP32B_ANP32D' 'ANPEP_ENPEP' 'AP2A1_AP2A2'
#  'APOBEC3A_APOBEC3C' 'APOBEC3B_APOBEC3D' 'APOBEC3C_APOBEC3F'
#  'APOBEC3G_APOBEC3H' 'ARHGEF10_ARHGEF10L' 'ARHGEF25_TRIO' 'ARSA_ARSF'
#  'ARSA_STS' 'ARSD_ARSG' 'ARSF_STS' 'ARSH_STS' 'AR_NR3C1' 'ASB16_ASB18'
#  'ASB2_ASB15' 'ASB5_ASB9' 'ATAD3B_ATAD3C' 'ATG4B_ATG4D' 'ATP11A_ATP11C'
#  'ATP13A3_ATP13A5' 'ATP1A2_ATP1A4' 'ATP1A3_ATP12A' 'ATP2A1_ATP2A3'
#  'ATP2A3_ATP2C1' 'ATP2B1_ATP2B3' 'ATP2B3_ATP2B4' 'ATP6V0A1_TCIRG1'
#  'ATP6V0E1_ATP6V0E2' 'ATP7A_ATP7B' 'ATP8A1_ATP8B1' 'ATP8A2_ATP11B'
#  'ATP8A2_ATP8B4' 'ATP8B1_ATP8B3' 'ATP8B2_ATP8B4' 'ATP9A_ATP9B' 'AUH_ECHS1'
#  'AWAT1_MOGAT3' 'AXL_MERTK' 'B3GALNT1_B3GALT2' 'B3GALNT1_B3GALT5'
#  'B3GAT1_B3GAT2' 'B3GNT2_B3GNT9' 'B3GNT4_B3GNT6' 'B3GNT6_B3GNT8'
#  'BACH1_BACH2' 'BCHE_CES4A' 'BIRC2_BIRC7' 'BIRC7_BIRC8' 'BLK_LCK'
#  'BMI1_PCGF1' 'BMP1_TLL1' 'BMX_ITK' 'BNIP3_BNIP3L' 'BRWD1_BRWD3'
#  'BTBD10_KCTD20' 'BTBD2_BTBD3' 'BTD_VNN3P' 'C1RL_C1S' 'C1R_C1RL'
#  'CABP1_CALM1' 'CABP4_CALM1' 'CALM1_CALM3' 'CALM1_CALML3' 'CALM2_CALML3'
#  'CALM2_CALML6' 'CALM3_TNNC1' 'CAMK1D_CAMK2D' 'CAMK1D_PSKH1'
#  'CAMK1G_CAMKV' 'CAMK1_CAMK1G' 'CAMK1_CAMK4' 'CAMK2A_CAMK2B'
#  'CAMK2B_CAMK2D' 'CAMK2G_CAMK4' 'CAPN11_CAPN12' 'CAPN1_CAPN11'
#  'CAPN1_CAPN2' 'CAPN1_CAPN3' 'CAPN2_CAPN11' 'CAPN3_CAPN11' 'CAPN3_CAPN9'
#  'CAPN6_CAPN9' 'CAPN8_CAPN14' 'CAPNS1_CAPNS2' 'CARD10_CARD11'
#  'CARM1_PRMT6' 'CASP1_CASP4' 'CASP3_CASP7' 'CASP6_CASP7' 'CBL_CBLB'
#  'CCL2_CCL13' 'CCL3_CCL26' 'CCL4_CCL5' 'CCL7_CCL8' 'CCL8_CCL24'
#  'CD163_SSC4D' 'CD5L_PRSS12' 'CDC25B_CDC25C' 'CDC42BPA_STK38L'
#  'CDC42BPG_DMPK' 'CDK10_CDK11B' 'CDK14_CDK15' 'CDK15_CDK17' 'CDK16_CDK18'
#  'CDK20_CDKL3' 'CDKL1_CDKL3' 'CDKL2_CDKL4' 'CDKN2A_CDKN2C' 'CDY1B_CDYL2'
#  'CDYL_CDYL2' 'CEACAM4_CEACAM21' 'CEACAM7_CEACAM8' 'CEACAM7_PSG8'
#  'CELA1_CELA3A' 'CELA1_CTRB1' 'CELA2A_CELA3A' 'CELA2A_CELA3B'
#  'CELA2B_CELA3B' 'CELA3A_CTRB2' 'CELA3B_CTRL' 'CES1_CES4A' 'CES1_CES5A'
#  'CES1_NLGN4Y' 'CES2_NLGN3' 'CES3_NLGN2' 'CES4A_NLGN2' 'CES5A_NLGN4Y'
#  'CFD_CTSG' 'CFD_GZMA' 'CFD_GZMM' 'CHI3L1_CHIA' 'CHIA_OVGP1' 'CHP1_CHP2'
#  'CHP1_PPP3R1' 'CHP2_PPP3R2' 'CHST11_CHST13' 'CHST8_CHST9' 'CHUK_IKBKB'
#  'CIB2_CIB4' 'CISH_SOCS2' 'CKM_CKMT1A' 'CLK1_CLK4' 'CMA1_GZMH'
#  'CNKSR2_CNKSR3' 'CORO1A_CORO2A' 'CORO1B_CORO2B' 'CORO2A_CORO2B'
#  'CPA1_CPA4' 'CPA2_CPA3' 'CPA2_CPB2' 'CPA2_CPO' 'CPA4_CPA5' 'CPA5_CPB1'
#  'CPA5_CPO' 'CPD_CPXM1' 'CPE_CPM' 'CPM_CPN1' 'CPN1_CPXM2' 'CPNE3_CPNE5'
#  'CPT1A_CPT1C' 'CRAT_CROT' 'CRMP1_DPYSL2' 'CRYAB_HSPB8'
#  'CSGALNACT1_CSGALNACT2' 'CSK_TXK' 'CSMD1_CSMD3' 'CSNK1E_TTBK1'
#  'CSRNP1_CSRNP3' 'CT47A1_CT47B1' 'CT47A5_CT47B1' 'CT47A7_CT47B1'
#  'CTDSP2_CTDSPL' 'CTSB_TINAGL1' 'CTSE_NAPSA' 'CTSE_REN' 'CTSF_CTSV'
#  'CTSG_GZMM' 'CTSH_CTSV' 'CTSL_CTSS' 'CUL7_CUL9' 'DAPK1_STK17A'
#  'DAPK2_MYLK4' 'DAPK3_STK17A' 'DCAF12_DCAF12L1' 'DCAF4_DCAF4L1'
#  'DCBLD1_DCBLD2' 'DCLK1_DCLK2' 'DDAH1_DDAH2' 'DGAT2L6_MOGAT1'
#  'DGAT2L6_MOGAT2' 'DGKA_DGKB' 'DGKD_DGKH' 'DGKE_DGKQ' 'DLAT_PDHX'
#  'DLG3_DLG4' 'DMWD_WDR20' 'DNAH1_DNAH6' 'DNAH8_DNAH10' 'DPEP1_DPEP3'
#  'DPP10_FAP' 'DPP6_FAP' 'DPP8_DPP9' 'DPYSL3_DPYSL5' 'DPYS_DPYSL5'
#  'DTX1_DTX2' 'DUSP13B_DUSP29' 'DUSP1_DUSP16' 'DUSP1_DUSP4' 'DUSP1_DUSP9'
#  'DUSP29_STYXL2' 'DUSP2_DUSP5' 'DUSP2_DUSP6' 'DUSP3_DUSP26' 'DUSP6_DUSP7'
#  'DYRK1A_DYRK4' 'DYRK3_DYRK4' 'ECE1_ECEL1' 'ECE2_MME' 'ECEL1_MMEL1'
#  'EFEMP1_EFEMP2' 'EFNA3_EFNA4' 'EGFR_ERBB3' 'ELOA_ELOA2' 'ELOVL1_ELOVL4'
#  'ELOVL1_ELOVL5' 'ELOVL2_ELOVL7' 'EML1_EML3' 'EML2_EML5' 'ENPEP_ERAP1'
#  'ENPP1_ENPP2' 'ENPP1_ENPP4' 'ENPP3_ENPP4' 'ENTPD1_ENTPD2' 'ENTPD2_ENTPD8'
#  'EPB42_TGM5' 'EPB42_TGM7' 'EPHA10_EPHB4' 'EPHA1_EPHA6' 'EPHA1_EPHB3'
#  'EPHA2_EPHA5' 'EPHA2_EPHB3' 'EPHA3_EPHA6' 'EPHA4_EPHA10' 'EPHA4_EPHB1'
#  'EPHA5_EPHB3' 'EPHA6_EPHB3' 'EPHA7_EPHB3' 'EPHB1_EPHB3' 'EPS8L1_EPS8L2'
#  'ERAP1_ERAP2' 'ERBB3_ERBB4' 'EXT1_EXTL1' 'EYA2_EYA3' 'F11_KLKB1'
#  'F13A1_TGM1' 'F13A1_TGM6' 'F9_F10' 'F9_PROZ' 'FAM177A1_FAM177B'
#  'FBXL19_KDM2B' 'FBXO2_FBXO27' 'FBXO45_SPSB4' 'FER_TXK' 'FGFR2_FGFR3'
#  'FGR_FYN' 'FGR_SRC' 'FKBP1A_FKBP5' 'FLT3_KIT' 'FN3K_FN3KRP' 'FRK_HCK'
#  'FRK_SRMS' 'FURIN_PCSK2' 'FUT3_FUT6' 'FUT5_FUT7' 'FUT6_FUT9' 'FYN_LCK'
#  'G2E3_PHF7' 'GAA_MGAM2' 'GALNT10_GALNT17' 'GALNT12_GALNT13'
#  'GALNT13_GALNT16' 'GALNT16_GALNTL5' 'GALNT17_GALNT18' 'GALNT1_GALNT2'
#  'GALNT1_GALNTL5' 'GALNT2_GALNT16' 'GALNT3_GALNT14' 'GALNT3_GALNT4'
#  'GALNT4_GALNT11' 'GALNT4_GALNT12' 'GALNT4_GALNT13' 'GALNT5_GALNT12'
#  'GALNT5_GALNTL5' 'GALNT8_GALNT17' 'GANAB_GANC' 'GCK_HK3' 'GCNT2_GCNT3'
#  'GCNT2_GCNT4' 'GDPD1_GDPD3' 'GGT1_GGTLC1' 'GGT5_GGTLC1' 'GIPC2_GIPC3'
#  'GLB1_GLB1L2' 'GLYAT_GLYATL1' 'GNB1_GNB5' 'GNB3_GNB5' 'GPAT3_GPAT4'
#  'GPT_GPT2' 'GRAP2_GRAPL' 'GRK1_GRK2' 'GRK1_GRK7' 'GRK2_GRK6' 'GRK4_GRK5'
#  'GRK5_GRK7' 'GTF2H2_GTF2H2C' 'GUCY2F_NPR1' 'GZMA_GZMH' 'GZMB_GZMM'
#  'GZMH_PRSS57' 'GZMM_PRSS57' 'HAO1_HAO2' 'HCK_LYN' 'HDAC1_HDAC2'
#  'HDAC5_HDAC9' 'HECW1_SMURF1' 'HECW2_SMURF1' 'HERC3_HERC6' 'HGFAC_PLAU'
#  'HIC1_HIC2' 'HIPK1_HIPK2' 'HIPK3_HIPK4' 'HMGCL_HMGCLL1' 'HPRT1_PRTFDC1'
#  'HSPA12A_HSPA12B' 'HTRA2_HTRA3' 'HYAL2_HYAL3' 'HYAL4_SPAM1' 'IMPA1_IMPA2'
#  'INPP4A_INPP4B' 'INPP5J_INPP5K' 'IRF2BP1_IRF2BPL' 'IRF2BP2_IRF2BPL'
#  'ITCH_NEDD4' 'ITK_MATK' 'ITPKB_ITPKC' 'JAK3_TYK2' 'KALRN_TRIO'
#  'KAT6A_KAT6B' 'KCNA10_KCNC2' 'KCNA1_KCNA4' 'KCNA1_KCNC4' 'KCNA2_KCNA3'
#  'KCNA2_KCNA4' 'KCNA2_KCNA7' 'KCNA3_KCNA7' 'KCNA4_KCNA10' 'KCNA7_KCNC1'
#  'KCNB1_KCNB2' 'KCNB1_KCNG4' 'KCNB1_KCNV2' 'KCNB2_KCNG4' 'KCNB2_KCNV2'
#  'KCNC3_KCNC4' 'KCND1_KCND3' 'KCNF1_KCNG1' 'KCNG1_KCNG2' 'KCNG2_KCNS1'
#  'KCNG3_KCNS3' 'KCNG4_KCNS3' 'KCNH1_KCNH6' 'KCNH2_KCNH5' 'KCNH3_KCNH5'
#  'KCNH4_KCNH6' 'KCNH5_KCNH8' 'KCNN3_KCNN4' 'KCNS2_KCNS3' 'KCTD10_KCTD13'
#  'KCTD1_KCTD15' 'KCTD3_SHKBP1' 'KCTD8_KCTD16' 'KDM4A_KDM4D' 'KDM4C_KDM4E'
#  'KDM4D_KDM4E' 'KDM5C_KDM5D' 'KEAP1_KLHL1' 'KEAP1_KLHL20' 'KEAP1_KLHL3'
#  'KIT_PDGFRA' 'KLHL12_KLHL18' 'KLHL12_KLHL20' 'KLHL13_KLHL14'
#  'KLHL13_KLHL36' 'KLHL17_KLHL20' 'KLHL1_KLHL20' 'KLHL1_KLHL4'
#  'KLHL21_KLHL29' 'KLHL23_KLHL24' 'KLHL24_KLHL25' 'KLHL24_KLHL38'
#  'KLHL2_KLHL12' 'KLHL2_KLHL3' 'KLHL3_KLHL12' 'KLHL3_KLHL17' 'KLHL3_KLHL5'
#  'KLHL4_KLHL18' 'KLHL4_KLHL8' 'KLHL6_KLHL35' 'KLHL8_KLHL28' 'KLHL9_KLHL32'
#  'KLK11_KLK15' 'KLK12_KLK15' 'KLK13_PRSS1' 'KLK13_PRSS2' 'KLK15_PRSS1'
#  'KLK1_KLK7' 'KLK6_KLK11' 'KLK6_KLK12' 'KLK6_KLK8' 'KLK8_KLK12'
#  'KLK8_PRSS1' 'KLK8_PRSS3' 'KLK9_KLK14' 'KMT2C_KMT2D' 'LARGE1_LARGE2'
#  'LATS2_STK38L' 'LCK_YES1' 'LDHA_UEVLD' 'LDLR_LRP4' 'LIMK1_LIMK2'
#  'LIPC_LIPG' 'LIPG_LPL' 'LIPI_PLA1A' 'LIPJ_LIPM' 'LLGL1_LLGL2'
#  'LONRF1_LONRF2' 'LOX_LOXL1' 'LPA_PLG' 'LPIN2_LPIN3' 'LRP1B_LRP8'
#  'LRP1_VLDLR' 'LRP4_LRP5' 'LRP8_VLDLR' 'LTBP2_LTBP4' 'LVRN_TRHDE'
#  'LYN_SRMS' 'LYZL4_SPACA5B' 'MAP2K1_MAP2K2' 'MAP2K2_MAP2K4'
#  'MAP2K3_MAP2K6' 'MAP2K5_MAP2K6' 'MAP2K6_MAP2K7' 'MAP3K2_MAP3K19'
#  'MAP3K9_MAP3K10' 'MAP4K1_MAP4K3' 'MAP4K1_STK24' 'MAP4K2_MAP4K5'
#  'MAP4K3_MAP4K5' 'MAP4K3_STK25' 'MAP4K3_STK26' 'MAP4K5_STK26'
#  'MAPK11_MAPK13' 'MAPK13_MAPK14' 'MAPK3_MAPK6' 'MAPK8_MAPK11'
#  'MAPK9_MAPK11' 'MAPK9_MAPK14' 'MARK1_NIM1K' 'MARK3_NIM1K' 'MASP1_MASP2'
#  'MAST2_MAST4' 'MBOAT1_MBOAT2' 'MELTF_TF' 'METTL6_METTL8' 'MEX3A_MEX3C'
#  'MFGE8_NRP1' 'MGAM_SI' 'MINK1_NRK' 'MKRN2_MKRN3' 'MMP10_MMP12'
#  'MMP10_MMP17' 'MMP11_MMP12' 'MMP11_MMP14' 'MMP11_MMP27' 'MMP12_MMP20'
#  'MMP13_MMP15' 'MMP13_MMP25' 'MMP14_MMP25' 'MMP15_MMP24' 'MMP16_MMP25'
#  'MMP17_MMP27' 'MMP1_MMP15' 'MMP1_MMP25' 'MMP1_MMP3' 'MMP20_MMP27'
#  'MMP2_MMP9' 'MMP3_MMP10' 'MMP3_MMP15' 'MMP3_MMP27' 'MMP3_MMP8'
#  'MMP7_MMP11' 'MMP7_MMP17' 'MMP8_MMP10' 'MMP8_MMP15' 'MMP8_MMP25'
#  'MOB1B_MOB3C' 'MOV10_MOV10L1' 'MPP2_MPP7' 'MPP4_PALS2' 'MTHFD1_MTHFD2'
#  'MTM1_MTMR4' 'MTMR10_MTMR12' 'MTMR2_MTMR3' 'MTMR2_MTMR4' 'MTMR3_MTMR4'
#  'MTMR6_MTMR8' 'MYBL1_MYBL2' 'MYLK_MYLK2' 'NAALAD2_NAALADL1' 'NAPSA_PGC'
#  'NBEAL1_NBEAL2' 'NEDD4L_SMURF1' 'NEDD4_NEDD4L' 'NEDD4_WWP2' 'NEK2_NEK7'
#  'NEK6_NEK7' 'NEURL1B_NEURL3' 'NFE2_NFE2L2' 'NIM1K_SNRK' 'NME3_NME4'
#  'NMNAT1_NMNAT3' 'NOMO2_NOMO3' 'NSD1_NSD3' 'NT5DC2_NT5DC3' 'NUDT10_NUDT11'
#  'NUDT4_NUDT10' 'OAS2_OAS3' 'OTUD6A_OTUD6B' 'P4HB_PDIA3' 'PADI1_PADI3'
#  'PADI3_PADI6' 'PAK1_PAK4' 'PAK1_PAK5' 'PAK3_PAK5' 'PAK4_PAK5'
#  'PANK3_PANK4' 'PARP1_PARP2' 'PASK_PIM3' 'PCGF2_PCGF3' 'PCSK1_PCSK2'
#  'PCSK2_PCSK4' 'PCSK4_PCSK7' 'PDE6G_PDE6H' 'PDK1_PDK4' 'PDXP_PGP'
#  'PELI2_PELI3' 'PFKFB3_PFKFB4' 'PFKL_PFKP' 'PGA4_REN' 'PGM1_PGM5'
#  'PHACTR2_PHACTR3' 'PHF1_PHF19' 'PHKA2_PHKB' 'PHOSPHO1_PHOSPHO2'
#  'PIAS1_PIAS4' 'PIK3CA_PIK3CB' 'PIK3R1_PIK3R2' 'PIP4K2A_PIP4K2B'
#  'PIP5K1B_PIP5K1C' 'PKN1_PRKCQ' 'PKN2_PKN3' 'PLA2G1B_PLA2G2E'
#  'PLA2G1B_PLA2G2F' 'PLA2G2A_PLA2G2F' 'PLA2G2D_PLA2G5' 'PLA2G4B_PLA2G4D'
#  'PLA2G4E_PLA2G4F' 'PLAT_PLAU' 'PLCB1_PLCB4' 'PLCB1_PLCZ1' 'PLCB3_PLCB4'
#  'PLCB4_PLCD4' 'PLCD3_PLCH1' 'PLCD4_PLCH2' 'PLCH1_PLCZ1' 'PLK2_PLK3'
#  'PLPP4_PLPP5' 'PLPPR2_PLPPR5' 'PLXNA1_PLXNA3' 'PLXNA2_PLXNB1'
#  'PLXNA3_PLXNB1' 'PLXNA3_PLXNB3' 'PLXNB1_PLXNB2' 'PLXNC1_PLXND1'
#  'PNPLA1_PNPLA4' 'PNPLA3_PNPLA5' 'PON2_PON3' 'POU3F1_POU3F2' 'PPM1A_PPM1B'
#  'PPM1H_PPM1M' 'PPP1R16A_PPP1R16B' 'PPP2R2B_PPP2R2C' 'PPP2R5A_PPP2R5D'
#  'PPP2R5C_PPP2R5E' 'PPP3R1_PPP3R2' 'PPP6R2_PPP6R3' 'PRB2_PRB3'
#  'PRKACA_PRKACG' 'PRKACB_PRKG2' 'PRKAG1_PRKAG3' 'PRKAG2_PRKAG3'
#  'PRKCA_PRKCG' 'PRKCB_PRKCD' 'PRKCB_PRKCZ' 'PRKCD_PRKCI' 'PRKCE_PRKCG'
#  'PRKCE_PRKCQ' 'PRKCG_PRKCZ' 'PRKCI_PRKCZ' 'PRKG1_PRKX' 'PRMT3_PRMT8'
#  'PRPS1L1_PRPSAP2' 'PRPS2_PRPSAP1' 'PRSS1_PRSS2' 'PRSS21_PRSS41'
#  'PRSS22_PRSS38' 'PRSS27_PRSS38' 'PRSS33_PRSS41' 'PRSS38_PRSS48'
#  'PRSS8_PRSS21' 'PRSS8_PRSS41' 'PSME1_PSME3' 'PTK6_SRC' 'PTPN12_PTPN18'
#  'PTPN1_PTPN2' 'PTPRA_PTPRC' 'PTPRA_PTPRF' 'PTPRA_PTPRT' 'PTPRE_PTPRF'
#  'PTPRE_PTPRU' 'PTPRK_PTPRT' 'PTPRM_PTPRT' 'PYGB_PYGM' 'RAB40A_RAB40AL'
#  'RC3H1_RC3H2' 'RFPL1_RFPL4B' 'RFPL4AL1_RFPL4B' 'RHBDL1_RHBDL3'
#  'RLIM_RNF6' 'RNASE2_RNASE7' 'RNASE6_RNASE8' 'RNF128_RNF130'
#  'RNF128_RNF149' 'RNF130_RNF149' 'RNF13_ZNRF4' 'RNF24_RNF122'
#  'RNPEP_RNPEPL1' 'ROCK1_STK38L' 'RPS6KA1_RPS6KA3' 'RPS6KA1_SGK1'
#  'RPS6KA2_RPS6KA5' 'RPS6KA3_RPS6KA4' 'RPS6KA3_SGK2' 'RPS6KA5_RPS6KA6'
#  'RPS6KA6_SGK2' 'RPS6KA6_SGK3' 'RPS6KB2_SGK1' 'SAMD8_SGMS2'
#  'SCAMP1_SCAMP4' 'SCAMP3_SCAMP4' 'SDS_SDSL' 'SEMA3A_SEMA3B'
# ...
#  'PAK2_PAK4' 'PALS1_PALS2' 'PANK1_PANK2' 'PARP11_PARP12' 'PASK_PIM2'
#  'PCGF2_PCGF3' 'PCMTD1_PCMTD2' 'PCSK2_PCSK4' 'PCSK2_PCSK5' 'PCSK5_PCSK6'
#  'PDIA3_PDIA4' 'PDK3_PDK4' 'PELI1_PELI3' 'PFKFB2_PFKFB4' 'PFKL_PFKM'
#  'PGA5_PGC' 'PGAM1_PGAM2' 'PGPEP1_PGPEP1L' 'PHACTR2_PHACTR4' 'PHF2_PHF8'
#  'PHOSPHO1_PHOSPHO2' 'PIAS3_PIAS4' 'PIK3CA_PIK3CG' 'PIK3R1_PIK3R3'
#  'PIP4K2A_PIP4K2C' 'PKN1_PKN2' 'PKN1_PRKCD' 'PLA2G1B_PLA2G10'
#  'PLA2G1B_PLA2G5' 'PLA2G2D_PLA2G10' 'PLA2G2E_PLA2G5' 'PLA2G4B_PLA2G4F'
#  'PLA2G4D_PLA2G4E' 'PLAT_PLAU' 'PLCB1_PLCB4' 'PLCB2_PLCZ1' 'PLCD1_PLCH2'
#  'PLCD1_PLCL1' 'PLCD3_PLCL2' 'PLCH1_PLCL2' 'PLCL1_PLCZ1' 'PLPP1_PLPP2'
#  'PLPPR1_PLPPR2' 'PLPPR3_PLPPR5' 'PLPPR4_PLPPR5' 'PLXNA1_PLXNB3'
#  'PLXNA2_PLXNB2' 'PLXNA3_PLXNB3' 'PLXNB1_PLXNB2' 'PLXNB2_PLXNB3'
#  'PLXNC1_PLXND1' 'PNLIP_PNLIPRP3' 'PNPLA3_PNPLA5' 'PON2_PON3'
#  'POU2F1_POU3F2' 'PPIP5K1_PPIP5K2' 'PPM1H_PPM1J' 'PPP1R16A_PPP1R16B'
#  'PPP2R2A_PPP2R2C' 'PPP2R5A_PPP2R5C' 'PPP2R5C_PPP2R5D' 'PPP3R1_PPP3R2'
#  'PRB1_PRB4' 'PRB2_PRB3' 'PRKACA_PRKACB' 'PRKACB_PRKG1' 'PRKAG1_PRKAG2'
#  'PRKCA_PRKCB' 'PRKCA_PRKCQ' 'PRKCB_PRKCH' 'PRKCB_PRKCI' 'PRKCD_PRKCI'
#  'PRKCE_PRKCI' 'PRKCG_PRKCZ' 'PRKCI_PRKCZ' 'PRKG1_PRKG2' 'PRMT3_PRMT8'
#  'PRPS1L1_PRPSAP2' 'PRPSAP1_PRPSAP2' 'PRSS21_PRSS22' 'PRSS22_PRSS27'
#  'PRSS23_PRSS35' 'PRSS2_PRSS3' 'PRSS36_PRSS53' 'PRSS48_TPSG1'
#  'PRSS8_PRSS38' 'PRSS8_PRSS48' 'PSME1_PSME3' 'PTK2_PTK2B' 'PTP4A1_PTP4A3'
#  'PTPN14_PTPN21' 'PTPRA_PTPRC' 'PTPRA_PTPRM' 'PTPRD_PTPRF' 'PTPRE_PTPRS'
#  'PTPRK_PTPRM' 'PTPRK_PTPRU' 'PYGB_PYGM' 'RAB40A_RAB40AL' 'RCBTB1_RCBTB2'
#  'RFPL1_RFPL4AL1' 'RFPL2_RFPL4B' 'RFPL4A_RFPL4B' 'RING1_RNF2' 'RLF_ZNF292'
#  'RNASE2_RNASE6' 'RNASE6_RNASE7' 'RNF125_RNF166' 'RNF130_RNF148'
#  'RNF13_RNF167' 'RNF148_RNF150' 'RNF19A_RNF19B' 'RNPEP_RNPEPL1'
#  'ROCK2_STK38L' 'RPS6KA1_RPS6KA4' 'RPS6KA1_SGK1' 'RPS6KA2_RPS6KA6'
#  'RPS6KA3_RPS6KA4' 'RPS6KA3_SGK2' 'RPS6KA4_RPS6KB2' 'RPS6KA5_SGK3'
#  'RPS6KA6_RPS6KB1' 'RPS6KB1_SGK1' 'RPS6KB2_SGK3' 'SBK1_SBK3'
#  'SCAMP1_SCAMP5' 'SCAMP4_SCAMP5' 'SEC11A_SEC11C' 'SEMA3A_SEMA3E'
#  'SEMA3B_SEMA3C' 'SEMA3B_SEMA4D' 'SEMA3C_SEMA3G' 'SEMA3E_SEMA3F'
#  'SEMA4A_SEMA4D' 'SEMA4B_SEMA4G' 'SEMA4D_SEMA4F' 'SEMA4F_SEMA4G'
#  'SEMA6B_SEMA6D' 'SET_SETSIP' 'SET_TSPYL1' 'SGK1_SGK2' 'SH2D4A_SH2D4B'
#  'SH3RF2_SH3RF3' 'SIAH1_SIAH2' 'SLC24A1_SLC24A2' 'SLC27A1_SLC27A3'
#  'SLC27A2_SLC27A5' 'SLC27A4_SLC27A5' 'SLK_STK25' 'SMURF1_WWP1'
#  'SMURF2_WWP1' 'SMYD1_SMYD2' 'SORCS1_SORCS2' 'SOX9_SOX10' 'SPPL2A_SPPL2C'
#  'SRMS_YES1' 'SSH1_SSH3' 'ST14_TMPRSS7' 'ST3GAL3_ST3GAL4'
#  'ST3GAL4_ST3GAL6' 'ST6GALNAC4_ST6GALNAC5' 'STK10_STK25' 'STK32A_STK32B'
#  'STK32A_STK32C' 'STK4_STK24' 'STRN_STRN4' 'SULT1A1_SULT1A2'
#  'SULT1A1_SULT1C4' 'SULT1A2_SULT1C2' 'SULT1A2_SULT1C4' 'SULT1A3_SULT1C2'
#  'SULT1A4_SULT1C3' 'SULT1B1_SULT1C2' 'SULT1B1_SULT2B1' 'SULT1C3_SULT1C4'
#  'SULT1E1_SULT2A1' 'SYNJ1_SYNJ2' 'TAOK2_TAOK3' 'TBC1D15_TBC1D17'
#  'TBC1D8B_TBC1D9B' 'TBL1X_TBL1XR1' 'TENM1_TENM3' 'TESK1_TESK2'
#  'TGFB1_TGFB2' 'TGM1_TGM6' 'TGM3_TGM5' 'TGM4_TGM6' 'TGM5_TGM6' 'TGM5_TGM7'
#  'TKTL1_TKTL2' 'TLE1_TLE4' 'TMPRSS11A_TMPRSS11B' 'TMPRSS11A_TMPRSS11D'
#  'TMPRSS11A_TMPRSS11E' 'TMPRSS11D_TMPRSS11E' 'TMPRSS2_TMPRSS5'
#  'TMPRSS3_TMPRSS15' 'TMPRSS6_TMPRSS7' 'TNS1_TNS2' 'TOR1A_TOR1B'
#  'TPTE_TPTE2' 'TRAF2_TRAF3' 'TRIB1_TRIB3' 'TSPAN5_TSPAN17' 'TSSK2_TSSK4'
#  'TTLL1_TTLL9' 'UBA6_UBA7' 'UBE2D2_UBE2E3' 'UBE2E3_UBE2L6' 'UBR1_UBR2'
#  'UCK1_UCK2' 'UHRF1_UHRF2' 'UPP1_UPP2' 'USP15_USP32' 'USP22_USP27X'
#  'USP2_USP21' 'USP35_USP46' 'USP44_USP49' 'USP9X_USP9Y' 'USP9Y_USP24'
#  'WDFY3_WDFY4' 'WSB1_WSB2' 'YTHDF1_YTHDF2' 'ZBTB20_ZBTB45' 'ZBTB3_ZBTB42'
#  'ZBTB7B_ZBTB7C' 'ZFAND5_ZFAND6' 'ZNF280A_ZNF280C' 'ZXDB_ZXDC']
# Repeat 10, Fold 5:
#   TRAIN groups: ['A3GALT2_ABO' 'A3GALT2_GBGT1' 'A3GALT2_GLT6D1' ... 'ZNRF1_ZNRF2'
#  'ZXDA_ZXDC' 'ZXDB_ZXDC']
#   TEST groups: ['AADACL2_AADACL4' 'AADAC_AADACL4' 'AADAC_NCEH1' 'ABL2_CSK' 'ABL2_MATK'
#  'ABL2_TEC' 'ACAA2_ACAT1' 'ACAD8_ACADS' 'ACADM_IVD' 'ACADS_GCDH'
#  'ACAT1_HADHB' 'ACCS_ACCSL' 'ACE_ACE2' 'ACP3_ACP4' 'ACSL3_ACSL4'
#  'ACSL5_ACSL6' 'ACSM1_ACSM2A' 'ACSM2A_ACSM6' 'ACSM3_ACSM5' 'ACVR1B_ACVR1C'
#  'ACVR1B_BMPR1A' 'ACVR1C_ACVRL1' 'ACVR1_ACVR1C' 'ACVR1_BMPR1A'
#  'ADAM11_ADAM23' 'ADAM12_ADAM28' 'ADAM20_ADAM29' 'ADAM21_ADAM29'
#  'ADAM2_ADAM32' 'ADAM9_ADAM21' 'ADAMTS10_ADAMTS16' 'ADAMTS16_ADAMTS18'
#  'ADAMTS17_ADAMTS18' 'ADAMTS1_ADAMTS20' 'ADAMTS4_ADAMTS15'
#  'ADAMTS4_ADAMTS20' 'ADAMTS4_ADAMTS8' 'ADAMTS6_ADAMTS12'
#  'ADAMTS7_ADAMTS17' 'ADAMTS8_ADAMTS20' 'ADAMTS9_ADAMTS20' 'ADGRE3_ADGRL1'
#  'ADSS1_ADSS2' 'AFF1_AFF4' 'AGBL3_AGBL4' 'AICDA_APOBEC3A' 'AICDA_APOBEC3G'
#  'AKAP8_AKAP8L' 'AKT1_RPS6KA3' 'AKT1_RPS6KB2' 'AKT2_RPS6KA1'
#  'AKT2_RPS6KB2' 'AKT3_RPS6KA3' 'AKT3_RPS6KB2' 'ALPG_ALPL' 'ALS2_ALS2CL'
#  'AMZ1_AMZ2' 'ANKRD44_ANKRD52' 'ANP32B_ANP32E' 'ANPEP_TRHDE'
#  'APOBEC2_APOBEC3C' 'APOBEC3A_APOBEC3G' 'APOBEC3B_APOBEC3H'
#  'APOBEC3D_APOBEC3G' 'APOBEC3F_APOBEC3G' 'ARID1A_ARID1B' 'ARSA_ARSH'
#  'ARSB_ARSJ' 'ARSD_STS' 'ARSF_ARSH' 'ARSI_ARSJ' 'ART3_ART5' 'ASB11_ASB13'
#  'ASB4_ASB10' 'ASB5_ASB13' 'ASB5_ASB9' 'ATG4A_ATG4B' 'ATP11A_ATP11C'
#  'ATP13A3_ATP13A4' 'ATP1A2_ATP1A3' 'ATP1A3_ATP12A' 'ATP1A4_ATP4A'
#  'ATP2B1_ATP2B3' 'ATP6V0A1_ATP6V0A2' 'ATP6V0E1_ATP6V0E2' 'ATP7A_ATP7B'
#  'ATP8A1_ATP8B1' 'ATP8A2_ATP11C' 'ATP8A2_ATP8B1' 'ATP8B1_ATP11C'
#  'ATP8B1_ATP8B3' 'ATP8B2_ATP11C' 'ATP8B4_ATP11A' 'ATRX_RAD54L'
#  'AWAT1_AWAT2' 'AWAT1_MOGAT3' 'AWAT2_DGAT2' 'AXL_TYRO3' 'B3GALT1_B3GALT2'
#  'B3GAT2_B3GAT3' 'B3GNT2_B3GNT8' 'B3GNT3_B3GNT8' 'B3GNT6_B3GNT7'
#  'B3GNT6_B3GNT9' 'B4GALNT3_B4GALNT4' 'BCHE_CES1' 'BCL6_BCL6B' 'BIRC2_XIAP'
#  'BIRC8_XIAP' 'BLK_FYN' 'BMI1_PCGF1' 'BMP1_TLL2' 'BMX_CSK' 'BPGM_PGAM2'
#  'BRD2_BRD3' 'BRWD1_PHIP' 'BTBD2_BTBD3' 'BTBD2_BTBD6' 'BTK_ITK' 'C1R_HPR'
#  'C1S_MASP2' 'CABP2_CALM1' 'CABP2_CALM3' 'CALM1_CALML4' 'CALM2_CALML3'
#  'CALM3_CALML3' 'CALM3_CALML6' 'CAMK1D_CAMK1G' 'CAMK1D_CAMK4'
#  'CAMK1G_CAMK2A' 'CAMK1G_PSKH2' 'CAMK1_CAMK2G' 'CAMK1_PSKH2' 'CAMK2A_PNCK'
#  'CAMK2D_CAMK4' 'CAMK4_PNCK' 'CAPN12_CAPN13' 'CAPN12_CAPN14'
#  'CAPN1_CAPN14' 'CAPN1_CAPN9' 'CAPN2_CAPN13' 'CAPN2_CAPN9' 'CAPN3_CAPN14'
#  'CAPN5_CAPN6' 'CAPN8_CAPN11' 'CAPN9_CAPN11' 'CAPNS1_SRI' 'CARM1_PRMT6'
#  'CASP1_CASP5' 'CASP3_CASP9' 'CASP8_CASP10' 'CBL_CBLB' 'CCL3_CCL14'
#  'CCL3_CCL4' 'CCL7_CCL8' 'CCL8_CCL11' 'CCL8_CCL24' 'CD2AP_SH3KBP1'
#  'CD5L_CD163L1' 'CDC42BPA_CDC42BPB' 'CDC42BPB_DMPK' 'CDC42BPG_STK38L'
#  'CDCP2_TLL2' 'CDK14_CDK17' 'CDK15_CDK16' 'CDK20_CDKL2' 'CDKL1_CDKL2'
#  'CDKL1_CDKL4' 'CDKL2_CDKL5' 'CDKN2B_CDKN2C' 'CDY1B_CDYL'
#  'CEACAM1_CEACAM7' 'CEACAM4_CEACAM21' 'CEACAM6_CEACAM7' 'CEACAM7_PSG6'
#  'CELA1_CTRB1' 'CELA2A_CELA3A' 'CELA2B_CELA3B' 'CELA3A_CELA3B'
#  'CELA3B_CTRL' 'CES1_CES4A' 'CES1_NLGN4X' 'CES2_NLGN2' 'CES2_NLGN3'
#  'CES2_NLGN4Y' 'CES3_NLGN2' 'CES4A_NLGN3' 'CFD_CTSG' 'CFD_GZMM'
#  'CHI3L1_CHIA' 'CHI3L2_OVGP1' 'CHP1_CHP2' 'CHP1_TESC' 'CHST11_CHST14'
#  'CHST13_CHST14' 'CHST9_CHST10' 'CIB1_CIB3' 'CISH_SOCS2' 'CKB_CKMT1B'
#  'CKM_CKMT1B' 'CLK3_CLK4' 'CMA1_GZMK' 'CNDP1_CNDP2' 'CNKSR2_IPCEF1'
#  'CORO1A_CORO7' 'CORO1B_CORO6' 'CORO1C_CORO2B' 'CPA1_CPA3' 'CPA1_CPA4'
#  'CPA2_CPA3' 'CPA3_CPA4' 'CPA4_CPA5' 'CPA5_CPB1' 'CPB1_CPB2' 'CPD_CPN1'
#  'CPD_CPZ' 'CPN1_CPXM1' 'CPN1_CPXM2' 'CPNE3_CPNE9' 'CPT1A_CRAT'
#  'CRMP1_DPYSL2' 'CSF1R_FLT3' 'CSF1R_PDGFRA' 'CSGALNACT1_CSGALNACT2'
#  'CSK_FES' 'CSK_ITK' 'CSNK1A1L_CSNK1E' 'CSNK1G1_CSNK1G3' 'CSRNP2_CSRNP3'
#  'CT47A4_CT47B1' 'CT47A6_CT47B1' 'CT47A7_CT47B1' 'CTRB2_CTRL'
#  'CTSB_TINAGL1' 'CTSD_PGA5' 'CTSE_NAPSA' 'CTSE_PGC' 'CTSF_CTSV'
#  'CTSG_GZMB' 'CTSH_CTSS' 'CTSL_CTSS' 'CUL7_CUL9' 'DAPK1_STK17B'
#  'DAPK2_MYLK4' 'DAPK3_STK17B' 'DCAF12_DCAF12L2' 'DCAF8_DCAF8L2'
#  'DCBLD1_RS1' 'DCLK1_DCX' 'DENND4A_DENND4B' 'DGKA_DGKB' 'DGKD_DGKE'
#  'DGKE_DGKQ' 'DLG1_DLG3' 'DMBT1_SSC4D' 'DMPK_STK38L' 'DNAH10_DNAH17'
#  'DNAH2_DNAH10' 'DNAH3_DNAH10' 'DNASE2_DNASE2B' 'DPF1_DPF2' 'DPP4_DPP6'
#  'DPP7_PRCP' 'DPYSL2_DPYSL3' 'DPYS_DPYSL2' 'DTX1_DTX4' 'DUSP13B_STYXL2'
#  'DUSP18_DUSP21' 'DUSP1_DUSP7' 'DUSP29_STYXL2' 'DUSP2_DUSP4' 'DUSP4_DUSP5'
#  'DYRK1A_DYRK1B' 'DYRK4_HIPK1' 'DYRK4_HIPK2' 'ECE1_PHEX' 'ECE2_KEL'
#  'EDIL3_NRP1' 'EFEMP1_EFEMP2' 'EFNA4_EFNA5' 'EGF_LRP5L' 'EHMT1_SUV39H2'
#  'ELANE_PRTN3' 'ELOVL1_ELOVL2' 'ELOVL1_ELOVL5' 'ELOVL4_ELOVL7' 'EML2_EML3'
#  'EML3_EML4' 'ENPEP_ERAP1' 'ENPEP_LNPEP' 'ENPP2_ENPP4' 'ENPP6_ENPP7'
#  'ENTPD2_ENTPD3' 'EPHA10_EPHB4' 'EPHA1_EPHA2' 'EPHA1_EPHB1' 'EPHA2_EPHA3'
#  'EPHA2_EPHB3' 'EPHA3_EPHA5' 'EPHA3_EPHA7' 'EPHA4_EPHA10' 'EPHA4_EPHB1'
#  'EPHA5_EPHA8' 'EPHA6_EPHA7' 'EPHA7_EPHA10' 'EPHA8_EPHB1' 'EPHB1_EPHB4'
#  'EPHB3_EPHB4' 'EPS8_EPS8L2' 'ERAP1_ERAP2' 'ERBB2_ERBB3' 'EVI5_EVI5L'
#  'EYA1_EYA3' 'F10_PROC' 'F12_PLAU' 'F13A1_TGM1' 'F7_F10' 'F9_PROZ'
#  'FAHD2A_FAHD2B' 'FAM20A_FAM20B' 'FBXO17_FBXO27' 'FBXO2_FBXO17'
#  'FBXO34_FBXO46' 'FBXO6_FBXO44' 'FER_TXK' 'FGFR3_FGFR4' 'FGR_LCK'
#  'FGR_YES1' 'FLT1_FLT4' 'FOLH1_NAALADL1' 'FRK_HCK' 'FRK_LCK'
#  'FRMPD2_PTPN13' 'FURIN_PCSK4' 'FUT1_FUT2' 'FUT4_FUT6' 'FUT4_FUT7'
#  'FUT6_FUT7' 'FUT6_FUT9' 'FYN_PTK6' 'G2E3_PHF7' 'G6PC1_G6PC3' 'GALNS_STS'
#  'GALNT11_GALNT13' 'GALNT12_GALNT14' 'GALNT13_GALNT14' 'GALNT1_GALNT11'
#  'GALNT1_GALNT3' 'GALNT2_GALNT12' 'GALNT2_GALNT6' 'GALNT3_GALNT14'
#  'GALNT3_GALNTL5' 'GALNT4_GALNT16' 'GALNT5_GALNT12' 'GALNT5_GALNTL5'
#  'GALNT6_GALNT16' 'GALNT6_GALNTL5' 'GALNT9_GALNT18' 'GBGT1_GLT6D1'
#  'GCK_HKDC1' 'GCNT2_GCNT4' 'GDPD2_GDPD4' 'GGT1_GGTLC1' 'GIPC2_GIPC3'
#  'GLB1_GLB1L' 'GLS_GLS2' 'GLYAT_GLYATL3' 'GNB2_GNB4' 'GNPDA1_GNPDA2'
#  'GPT_GPT2' 'GRAP2_GRB2' 'GRK1_GRK3' 'GRK2_GRK3' 'GRK3_GRK5' 'GRK4_GRK7'
#  'GTF2H2_GTF2H2C' 'GUCY2F_NPR1' 'GZMA_GZMH' 'GZMB_GZMK' 'GZMK_PRSS57'
#  'HABP2_PLAU' 'HAS1_HAS3' 'HCK_SRC' 'HDAC4_HDAC7' 'HDAC7_HDAC9'
#  'HECW1_SMURF2' 'HECW2_ITCH' 'HECW2_SMURF2' 'HERC4_HERC5' 'HGF_MST1'
#  'HIPK1_HIPK3' 'HIPK1_HIPK4' 'HK1_HK3' 'HNRNPAB_HNRNPDL' 'HPN_TMPRSS5'
#  'HPR_MASP1' 'HTRA1_HTRA2' 'HYAL1_SPAM1' 'HYAL4_SPAM1' 'IMPA1_IMPA2'
#  'INMT_PNMT' 'INPP5D_INPPL1' 'IP6K2_IP6K3' 'IRS1_IRS2' 'ITCH_NEDD4L'
#  'ITCH_WWP2' 'ITK_TXK' 'JAK1_JAK3' 'JAKMIP1_JAKMIP2' 'KALRN_TRIO'
#  'KBTBD11_KLHDC7B' 'KCNA1_KCNA10' 'KCNA1_KCNC2' 'KCNA2_KCNA3'
#  'KCNA2_KCNC2' 'KCNA3_KCNA10' 'KCNA3_KCNC3' 'KCNA4_KCNA7' 'KCNA7_KCNC2'
#  'KCNA7_KCND2' 'KCNB1_KCNB2' 'KCNB1_KCNG4' 'KCNB2_KCNF1' 'KCNB2_KCNS2'
#  'KCNC1_KCNC4' 'KCND2_KCND3' 'KCNF1_KCNV1' 'KCNG1_KCNG2' 'KCNG1_KCNG3'
#  'KCNG1_KCNV1' 'KCNG3_KCNG4' 'KCNG3_KCNV2' 'KCNG4_KCNS2' 'KCNH1_KCNH4'
#  'KCNH2_KCNH4' 'KCNH3_KCNH4' 'KCNH4_KCNH6' 'KCNH6_KCNH8' 'KCNS1_KCNS2'
#  'KCNS2_KCNV1' 'KCNS2_KCNV2' 'KCTD10_TNFAIP1' 'KCTD2_KCTD5' 'KCTD5_KCTD9'
#  'KCTD8_KCTD16' 'KDM1A_KDM1B' 'KDM4B_KDM4C' 'KDM5B_KDM5C' 'KDM7A_PHF2'
#  'KEAP1_KLHL2' 'KEAP1_KLHL5' 'KIF4B_KIF21A' 'KLHL12_KLHL18'
#  'KLHL13_KLHL22' 'KLHL14_KLHL31' 'KLHL18_KLHL20' 'KLHL1_KLHL2'
#  'KLHL1_KLHL8' 'KLHL21_KLHL30' 'KLHL23_KLHL29' 'KLHL26_KLHL31'
#  'KLHL2_KLHL18' 'KLHL2_KLHL5' 'KLHL3_KLHL17' 'KLHL3_KLHL5' 'KLHL3_KLHL8'
#  'KLHL40_KLHL41' 'KLHL4_KLHL8' 'KLHL5_KLHL8' 'KLHL8_KLHL20' 'KLHL9_KLHL22'
#  'KLK11_KLK12' 'KLK11_PRSS2' 'KLK12_PRSS3' 'KLK13_PRSS3' 'KLK15_PRSS1'
#  'KLK2_KLK3' 'KLK6_KLK13' 'KLK6_PRSS1' 'KLK8_KLK13' 'KLK8_PRSS3'
#  'KLK9_KLK14' 'KLK9_PRSS1' 'KMT2E_SETD5' 'LATS1_STK38' 'LCK_PTK6'
#  'LDHAL6B_UEVLD' 'LDLR_LRP4' 'LDLR_LRP8' 'LFNG_MFNG' 'LIPA_LIPJ'
#  'LIPA_LIPN' 'LIPF_LIPN' 'LIPJ_LIPK' 'LIPM_LIPN' 'LONRF2_LONRF3'
#  'LOXL2_LOXL4' 'LOX_LOXL4' 'LPCAT2_LPCAT4' 'LPIN1_LPIN3' 'LRP1B_LRP6'
#  'LRP1_LRP4' 'LRP2_LRP5' 'LRP4_LRP6' 'LTA4H_RNPEP' 'LTBP2_LTBP4' 'LTF_TF'
#  'LYN_SRC' 'LYPLA2_LYPLAL1' 'MAGT1_TUSC3' 'MAP2K1_MAP2K4' 'MAP2K2_MAP2K4'
#  'MAP2K3_MAP2K5' 'MAP2K4_MAP2K7' 'MAP3K2_MAP3K3' 'MAP3K9_MAP3K11'
#  'MAP4K1_STK25' 'MAP4K2_STK25' 'MAP4K2_STK26' 'MAP4K2_STK4' 'MAP4K4_MINK1'
#  'MAP4K5_STK24' 'MAPK10_MAPK13' 'MAPK12_MAPK14' 'MAPK3_MAPK6'
#  'MAPK8_MAPK11' 'MAPK9_MAPK11' 'MAPKAPK2_MAPKAPK5' 'MARK1_NIM1K'
#  'MARK3_MARK4' 'MASP1_MASP2' 'MAST2_MAST4' 'MDM2_MDM4' 'ME1_ME3'
#  'METAP1_METAP1D' 'METTL2A_METTL6' 'MEX3A_MEX3D' 'MFGE8_NRP2'
#  'MGRN1_RNF157' 'MKRN1_MKRN2' 'MMP10_MMP11' 'MMP10_MMP16' 'MMP11_MMP12'
#  'MMP11_MMP17' 'MMP11_MMP20' 'MMP12_MMP14' 'MMP12_MMP24' 'MMP13_MMP16'
#  'MMP14_MMP15' 'MMP14_MMP25' 'MMP15_MMP25' 'MMP16_MMP25' 'MMP1_MMP10'
#  'MMP1_MMP16' 'MMP1_MMP3' 'MMP24_MMP25' 'MMP3_MMP13' 'MMP3_MMP20'
#  'MMP3_MMP24' 'MMP7_MMP11' 'MMP7_MMP16' 'MMP7_MMP27' 'MMP8_MMP13'
#  'MMP8_MMP15' 'MOB1A_MOB1B' 'MOGAT1_MOGAT3' 'MPP1_MPP3' 'MPP2_PALS2'
#  'MPP4_MPP7' 'MPST_TST' 'MTHFD2_MTHFD2L' 'MTM1_MTMR6' 'MTMR1_MTMR2'
#  'MTMR2_MTMR4' 'MTMR3_MTMR4' 'MTMR4_MTMR6' 'MTMR6_MTMR7' 'MTMR7_MTMR9'
#  'MYLK2_MYLK4' 'MYO3A_MYO3B' 'NACC1_NACC2' 'NAPSA_PGA3' 'NCOA1_NCOA3'
#  'NCOA2_NCOA3' 'NEDD4L_WWP2' 'NEK1_NEK3' 'NEK3_NEK5' 'NEK6_NEK7'
#  'NEU3_NEU4' 'NFE2_NFE2L2' 'NME1_NME3' 'NME6_NME7' 'NOMO1_NOMO3'
#  'NSD1_NSD3' 'NT5C_NT5M' 'NUDT10_NUDT11' 'NUDT4_NUDT11' 'OBSCN_OBSL1'
#  'OTUD6A_OTUD6B' 'OTUD7A_OTUD7B' 'PACSIN1_PACSIN3' 'PADI2_PADI3'
#  'PAK1_PAK2' 'PAK2_PAK5' 'PANK1_PANK3' 'PANK3_PANK4' 'PARP1_PARP2'
#  'PASK_PIM3' 'PCGF3_PCGF5' 'PCSK1_PCSK2' 'PCSK1_PCSK4' 'PCSK2_PCSK6'
#  'PCSK4_PCSK6' 'PCSK5_PCSK7' 'PDIK1L_STK35' 'PDK2_PDK3' 'PDP1_PDP2'
#  'PFKFB1_PFKFB2' 'PGA3_PGC' 'PGA5_REN' 'PHACTR1_PHACTR2' 'PHACTR3_PHACTR4'
#  'PHKA1_PHKA2' 'PHKA1_PHKB' 'PI4K2A_PI4K2B' 'PIAS1_PIAS2'
#  'PIK3C2A_PIK3C2G' 'PIK3CB_PIK3CD' 'PIK3R2_PIK3R3' 'PIP4K2B_PIP4K2C'
#  'PKN1_PKN3' 'PLA2G1B_PLA2G2A' 'PLA2G2A_PLA2G10' 'PLA2G2D_PLA2G2E'
#  'PLA2G2D_PLA2G2F' 'PLA2G2F_PLA2G5' 'PLA2G4D_PLA2G4F' 'PLAT_PLG'
#  'PLCB1_PLCD4' 'PLCB3_PLCD1' 'PLCB4_PLCD1' 'PLCD1_PLCH1' 'PLCD1_PLCL2'
#  'PLCD4_PLCH1' 'PLCH1_PLCL1' 'PLCH1_PLCZ1' 'PLCL2_PLCZ1' 'PLPP1_PLPP3'
#  'PLPPR1_PLPPR3' 'PLXNA1_PLXNA2' 'PLXNA1_PLXNA3' 'PLXNA1_PLXND1'
#  'PLXNA2_PLXNB3' 'PLXNA3_PLXND1' 'PLXNB1_PLXNB3' 'PNCK_PSKH1'
#  'PNPLA1_PNPLA4' 'PNPLA6_PNPLA7' 'POU2F3_POU3F2' 'POU3F2_POU5F1'
#  'PPM1A_PPM1B' 'PPM1H_PPM1M' 'PPP1R12B_PPP1R12C' 'PPP1R1A_PPP1R1C'
#  'PPP2R2A_PPP2R2D' 'PPP2R5A_PPP2R5D' 'PPP2R5C_PPP2R5E' 'PPP6R1_PPP6R2'
#  'PRB2_PRB4' 'PRKACA_PRKACG' 'PRKACB_PRKX' 'PRKAG1_PRKAG3' 'PRKCA_PRKCD'
#  'PRKCA_PRKCZ' 'PRKCB_PRKCQ' 'PRKCD_PRKCQ' 'PRKCE_PRKCQ' 'PRKCH_PRKCI'
#  'PRKCQ_PRKCZ' 'PRKG1_PRKX' 'PRKG2_PRKX' 'PRMT6_PRMT8' 'PRPS1_PRPS1L1'
#  'PRRG1_PRRG3' 'PRSS21_PRSS33' 'PRSS21_PRSS48' 'PRSS22_PRSS33'
#  'PRSS27_PRSS33' 'PRSS33_PRSS38' 'PRSS37_PRSS58' 'PRSS41_PRSS48'
#  'PRSS8_PRSS21' 'PRSS8_PRSS22' 'PRSS8_TPSG1' 'PSME2_PSME3' 'PTK6_SRC'
#  'PTP4A2_PTP4A3' 'PTPN1_PTPN2' 'PTPRA_PTPRD' 'PTPRA_PTPRS' 'PTPRD_PTPRS'
#  'PTPRE_PTPRT' 'PTPRM_PTPRT' 'PYGL_PYGM' 'RAB40A_RAB40B' 'RFFL_RNF34'
#  'RFPL1_RFPL4B' 'RFPL3_RFPL4A' 'RFPL4A_RFPL4AL1' 'RHBDL1_RHBDL2'
#  'RLIM_RNF6' 'RNASE2_RNASE7' 'RNASE6_RNASE8' 'RNF128_RNF130'
#  'RNF128_RNF133' 'RNF130_RNF149' 'RNF13_ZNRF4' 'RNF223_RNF225'
#  'ROCK1_ROCK2' 'ROR1_ROR2' 'RPS6KA1_RPS6KA5' 'RPS6KA1_SGK2' 'RPS6KA1_SGK3'
#  'RPS6KA2_RPS6KB1' 'RPS6KA3_RPS6KA5' 'RPS6KA3_SGK3' 'RPS6KA4_SGK2'
#  'RPS6KA6_RPS6KB2' 'RPS6KB1_SGK2' 'RPS6KC1_RPS6KL1' 'SBK2_SBK3'
#  'SCAMP2_SCAMP3' 'SCRN1_SCRN2' 'SEC23A_SEC23B' 'SEMA3A_SEMA3B'
#  'SEMA3A_SEMA3G' 'SEMA3B_SEMA3E' 'SEMA3B_SEMA4G' 'SEMA3C_SEMA4B'
#  'SEMA3E_SEMA3G' 'SEMA4A_SEMA4G' 'SEMA4C_SEMA4D' 'SEMA5A_SEMA5B'
#  'SEMA6C_SEMA6D' 'SET_TSPYL2' 'SGK1_SGK3' 'SH3BP5_SH3BP5L' 'SHC1_SHC2'
#  'SIAH1_SIAH3' 'SIAH2_SIAH3' 'SLC24A1_SLC24A3' 'SLC27A1_SLC27A4'
#  'SLC27A2_SLC27A6' 'SLC27A4_SLC27A6' 'SLK_STK26' 'SMPD1_SMPDL3A'
#  'SMURF2_WWP2' 'SORCS1_SORCS3' 'SOX9_SOX15' 'SPPL2B_SPPL2C' 'SPSB1_SPSB4'
#  'SRPK1_SRPK2' 'SSH2_SSH3' 'ST6GAL1_ST6GAL2' 'ST6GALNAC5_ST6GALNAC6'
#  'STK10_STK26' 'STK38_STK38L' 'STK4_STK25' 'STK4_STK26' 'STT3A_STT3B'
#  'SULT1A1_SULT1A3' 'SULT1A1_SULT1C2' 'SULT1A1_SULT1E1' 'SULT1A2_SULT1C3'
#  'SULT1A3_SULT1C3' 'SULT1A3_SULT1C4' 'SULT1A3_SULT1E1' 'SULT1A4_SULT1C4'
#  'SULT1B1_SULT1C3' 'SULT1C2_SULT1C4' 'SULT1C3_SULT2A1' 'SULT1C3_SULT2B1'
#  'SULT1E1_SULT2B1' 'TAB2_TAB3' 'TBC1D10A_TBC1D10B' 'TBC1D1_TBC1D4'
#  'TBC1D8_TBC1D9' 'TBL1X_TBL1Y' 'TENM1_TENM4' 'TENM3_TENM4' 'TGFB2_TGFB3'
#  'TGM1_TGM2' 'TGM2_TGM3' 'TGM3_TGM6' 'TGM6_TGM7' 'TKT_TKTL1' 'TLE1_TLE5'
#  'TLE2_TLE4' 'TMPRSS11A_TMPRSS11F' 'TMPRSS11D_TMPRSS11F'
#  'TMPRSS3_TMPRSS13' 'TMPRSS9_TMPRSS11E' 'TNS1_TNS3' 'TNS3_TNS4'
#  'TOR1A_TOR3A' 'TPSAB1_TPSD1' 'TRABD2A_TRABD2B' 'TRAF2_TRAF5'
#  'TRIB2_TRIB3' 'TSSK1B_TSSK2' 'TSSK2_TSSK6' 'TTLL3_TTLL8'
#  'UBASH3A_UBASH3B' 'UBE2A_UBE2B' 'UBE2D2_UBE2L6' 'UBE2Q1_UBE2Q2'
#  'UBE2Q1_UBE2QL1' 'UCK1_UCKL1' 'ULK1_ULK2' 'USP11_USP15' 'USP16_USP45'
#  'USP25_USP28' 'USP31_USP43' 'USP4_USP15' 'USP4_USP32' 'VNN1_VNN2'
#  'WDR45_WDR45B' 'WSCD1_WSCD2' 'YTHDF2_YTHDF3' 'ZBTB22_ZBTB43'
#  'ZBTB6_ZBTB12' 'ZBTB8A_ZBTB46' 'ZFR_ZFR2' 'ZNF362_ZNF384']

# %%
# Save splits
with open('/Users/narod/Library/CloudStorage/GoogleDrive-narod.kebabci@ucdconnect.ie/My Drive/GitRepos/context_specific_SL_prediction/output/models/model_III/repeated_splits_III.pkl', 'wb') as f:
    pickle.dump(repeated_splits_III, f)

# %%
#Run cross-validation on both feature set
model_III_early_repeated = model_early_cross_validation(RF, data_1, target, repeated_splits_III, model_name="Model III Early Repeated")
model_III_late_repeated = model_late_cross_validation(RF, data_2, target, repeated_splits_III, model_name="Model III Late Repeated")
# Out:
# Fold 1: Train size = 33027, Test size = 8217
#   [Model III Early Repeated - Fold 1] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0223 (diff: 0.0009)
#     Test SL rate:    0.0269 (diff: 0.0037)
#     Train/Test diff: 0.0046
# Stratification OK
#   ROC AUC = 0.8773, Elapsed time = 54.18 seconds
# Fold 2: Train size = 32987, Test size = 8257
#   [Model III Early Repeated - Fold 2] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0002)
#     Test SL rate:    0.0224 (diff: 0.0008)
#     Train/Test diff: 0.0010
# Stratification OK
#   ROC AUC = 0.9094, Elapsed time = 107.96 seconds
# Fold 3: Train size = 32975, Test size = 8269
#   [Model III Early Repeated - Fold 3] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0002)
#     Test SL rate:    0.0224 (diff: 0.0009)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9182, Elapsed time = 156.10 seconds
# Fold 4: Train size = 32987, Test size = 8257
#   [Model III Early Repeated - Fold 4] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0239 (diff: 0.0007)
#     Test SL rate:    0.0206 (diff: 0.0026)
#     Train/Test diff: 0.0033
# Stratification OK
#   ROC AUC = 0.9188, Elapsed time = 206.57 seconds
# Fold 5: Train size = 33000, Test size = 8244
#   [Model III Early Repeated - Fold 5] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0231 (diff: 0.0002)
#     Test SL rate:    0.0239 (diff: 0.0007)
#     Train/Test diff: 0.0008
# Stratification OK
#   ROC AUC = 0.9052, Elapsed time = 255.64 seconds
# Fold 6: Train size = 32999, Test size = 8245
#   [Model III Early Repeated - Fold 6] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0227 (diff: 0.0005)
#     Test SL rate:    0.0252 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.8905, Elapsed time = 302.14 seconds
# Fold 7: Train size = 32975, Test size = 8269
#   [Model III Early Repeated - Fold 7] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0224 (diff: 0.0008)
#     Test SL rate:    0.0265 (diff: 0.0033)
#     Train/Test diff: 0.0041
# Stratification OK
#   ROC AUC = 0.9339, Elapsed time = 351.33 seconds
# Fold 8: Train size = 32979, Test size = 8265
#   [Model III Early Repeated - Fold 8] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0001)
#     Test SL rate:    0.0230 (diff: 0.0002)
#     Train/Test diff: 0.0003
# Stratification OK
#   ROC AUC = 0.8989, Elapsed time = 402.17 seconds
# Fold 9: Train size = 33010, Test size = 8234
#   [Model III Early Repeated - Fold 9] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0001)
#     Test SL rate:    0.0234 (diff: 0.0002)
#     Train/Test diff: 0.0003
# Stratification OK
#   ROC AUC = 0.9025, Elapsed time = 451.76 seconds
# Fold 10: Train size = 33013, Test size = 8231
#   [Model III Early Repeated - Fold 10] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0245 (diff: 0.0013)
#     Test SL rate:    0.0180 (diff: 0.0052)
#     Train/Test diff: 0.0066
# Stratification OK
#   ROC AUC = 0.8817, Elapsed time = 504.37 seconds
# Fold 11: Train size = 33002, Test size = 8242
#   [Model III Early Repeated - Fold 11] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0237 (diff: 0.0005)
#     Test SL rate:    0.0214 (diff: 0.0019)
#     Train/Test diff: 0.0023
# Stratification OK
#   ROC AUC = 0.9091, Elapsed time = 552.96 seconds
# Fold 12: Train size = 32987, Test size = 8257
#   [Model III Early Repeated - Fold 12] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0225 (diff: 0.0007)
#     Test SL rate:    0.0260 (diff: 0.0028)
#     Train/Test diff: 0.0035
# Stratification OK
#   ROC AUC = 0.9038, Elapsed time = 610.66 seconds
# Fold 13: Train size = 33005, Test size = 8239
#   [Model III Early Repeated - Fold 13] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0235 (diff: 0.0002)
#     Test SL rate:    0.0223 (diff: 0.0009)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9143, Elapsed time = 666.36 seconds
# Fold 14: Train size = 33014, Test size = 8230
#   [Model III Early Repeated - Fold 14] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0227 (diff: 0.0006)
#     Test SL rate:    0.0255 (diff: 0.0023)
#     Train/Test diff: 0.0029
# Stratification OK
#   ROC AUC = 0.8918, Elapsed time = 720.24 seconds
# Fold 15: Train size = 32968, Test size = 8276
#   [Model III Early Repeated - Fold 15] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0238 (diff: 0.0006)
#     Test SL rate:    0.0209 (diff: 0.0023)
#     Train/Test diff: 0.0029
# Stratification OK
#   ROC AUC = 0.9049, Elapsed time = 780.00 seconds
# Fold 16: Train size = 33025, Test size = 8219
#   [Model III Early Repeated - Fold 16] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0236 (diff: 0.0004)
#     Test SL rate:    0.0215 (diff: 0.0017)
#     Train/Test diff: 0.0021
# Stratification OK
#   ROC AUC = 0.8918, Elapsed time = 828.84 seconds
# Fold 17: Train size = 33017, Test size = 8227
#   [Model III Early Repeated - Fold 17] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0227 (diff: 0.0005)
#     Test SL rate:    0.0252 (diff: 0.0019)
#     Train/Test diff: 0.0024
# Stratification OK
#   ROC AUC = 0.9105, Elapsed time = 872.61 seconds
# Fold 18: Train size = 32994, Test size = 8250
#   [Model III Early Repeated - Fold 18] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0230 (diff: 0.0002)
#     Test SL rate:    0.0241 (diff: 0.0009)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.8963, Elapsed time = 917.45 seconds
# Fold 19: Train size = 33018, Test size = 8226
#   [Model III Early Repeated - Fold 19] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0237 (diff: 0.0004)
#     Test SL rate:    0.0215 (diff: 0.0017)
#     Train/Test diff: 0.0021
# Stratification OK
#   ROC AUC = 0.9236, Elapsed time = 962.29 seconds
# Fold 20: Train size = 32922, Test size = 8322
#   [Model III Early Repeated - Fold 20] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0231 (diff: 0.0001)
#     Test SL rate:    0.0238 (diff: 0.0006)
#     Train/Test diff: 0.0007
# Stratification OK
#   ROC AUC = 0.8911, Elapsed time = 1006.35 seconds
# Fold 21: Train size = 32982, Test size = 8262
#   [Model III Early Repeated - Fold 21] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0227 (diff: 0.0005)
#     Test SL rate:    0.0253 (diff: 0.0021)
#     Train/Test diff: 0.0026
# Stratification OK
#   ROC AUC = 0.8874, Elapsed time = 1051.08 seconds
# Fold 22: Train size = 32974, Test size = 8270
#   [Model III Early Repeated - Fold 22] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0217 (diff: 0.0015)
#     Test SL rate:    0.0291 (diff: 0.0059)
#     Train/Test diff: 0.0074
# Stratification OK
#   ROC AUC = 0.8945, Elapsed time = 1094.46 seconds
# Fold 23: Train size = 32973, Test size = 8271
#   [Model III Early Repeated - Fold 23] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0002)
#     Test SL rate:    0.0224 (diff: 0.0009)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9262, Elapsed time = 1139.16 seconds
# Fold 24: Train size = 33012, Test size = 8232
#   [Model III Early Repeated - Fold 24] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0239 (diff: 0.0007)
#     Test SL rate:    0.0205 (diff: 0.0027)
#     Train/Test diff: 0.0034
# Stratification OK
#   ROC AUC = 0.9059, Elapsed time = 1184.42 seconds
# Fold 25: Train size = 33035, Test size = 8209
#   [Model III Early Repeated - Fold 25] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0243 (diff: 0.0011)
#     Test SL rate:    0.0188 (diff: 0.0045)
#     Train/Test diff: 0.0056
# Stratification OK
#   ROC AUC = 0.9091, Elapsed time = 1228.56 seconds
# Fold 26: Train size = 32977, Test size = 8267
#   [Model III Early Repeated - Fold 26] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0239 (diff: 0.0006)
#     Test SL rate:    0.0207 (diff: 0.0025)
#     Train/Test diff: 0.0032
# Stratification OK
#   ROC AUC = 0.9156, Elapsed time = 1274.23 seconds
# Fold 27: Train size = 32993, Test size = 8251
#   [Model III Early Repeated - Fold 27] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0230 (diff: 0.0002)
#     Test SL rate:    0.0240 (diff: 0.0008)
#     Train/Test diff: 0.0010
# Stratification OK
#   ROC AUC = 0.9100, Elapsed time = 1323.50 seconds
# Fold 28: Train size = 33001, Test size = 8243
#   [Model III Early Repeated - Fold 28] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0224 (diff: 0.0008)
#     Test SL rate:    0.0264 (diff: 0.0032)
#     Train/Test diff: 0.0040
# Stratification OK
#   ROC AUC = 0.8769, Elapsed time = 1371.62 seconds
# Fold 29: Train size = 33012, Test size = 8232
#   [Model III Early Repeated - Fold 29] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0002)
#     Test SL rate:    0.0224 (diff: 0.0009)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9041, Elapsed time = 1419.38 seconds
# Fold 30: Train size = 32993, Test size = 8251
#   [Model III Early Repeated - Fold 30] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0001)
#     Test SL rate:    0.0227 (diff: 0.0006)
#     Train/Test diff: 0.0007
# Stratification OK
#   ROC AUC = 0.9182, Elapsed time = 1468.09 seconds
# Fold 31: Train size = 32941, Test size = 8303
#   [Model III Early Repeated - Fold 31] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0236 (diff: 0.0003)
#     Test SL rate:    0.0219 (diff: 0.0013)
#     Train/Test diff: 0.0016
# Stratification OK
#   ROC AUC = 0.8922, Elapsed time = 1516.28 seconds
# Fold 32: Train size = 33029, Test size = 8215
#   [Model III Early Repeated - Fold 32] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0227 (diff: 0.0005)
#     Test SL rate:    0.0252 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9114, Elapsed time = 1564.86 seconds
# Fold 33: Train size = 32996, Test size = 8248
#   [Model III Early Repeated - Fold 33] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0001)
#     Test SL rate:    0.0227 (diff: 0.0006)
#     Train/Test diff: 0.0007
# Stratification OK
#   ROC AUC = 0.9144, Elapsed time = 1613.89 seconds
# Fold 34: Train size = 33023, Test size = 8221
#   [Model III Early Repeated - Fold 34] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0001)
#     Test SL rate:    0.0230 (diff: 0.0002)
#     Train/Test diff: 0.0003
# Stratification OK
#   ROC AUC = 0.8950, Elapsed time = 1663.05 seconds
# Fold 35: Train size = 32987, Test size = 8257
#   [Model III Early Repeated - Fold 35] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0234 (diff: 0.0001)
#     Train/Test diff: 0.0002
# Stratification OK
#   ROC AUC = 0.9178, Elapsed time = 1712.66 seconds
# Fold 36: Train size = 32996, Test size = 8248
#   [Model III Early Repeated - Fold 36] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0230 (diff: 0.0002)
#     Test SL rate:    0.0241 (diff: 0.0009)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.8760, Elapsed time = 1761.29 seconds
# Fold 37: Train size = 32979, Test size = 8265
#   [Model III Early Repeated - Fold 37] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0227 (diff: 0.0005)
#     Test SL rate:    0.0252 (diff: 0.0019)
#     Train/Test diff: 0.0024
# Stratification OK
#   ROC AUC = 0.9040, Elapsed time = 1810.67 seconds
# Fold 38: Train size = 32993, Test size = 8251
#   [Model III Early Repeated - Fold 38] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.8887, Elapsed time = 1861.06 seconds
# Fold 39: Train size = 32969, Test size = 8275
#   [Model III Early Repeated - Fold 39] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0248 (diff: 0.0015)
#     Test SL rate:    0.0172 (diff: 0.0061)
#     Train/Test diff: 0.0076
# Stratification OK
#   ROC AUC = 0.9054, Elapsed time = 1909.39 seconds
# Fold 40: Train size = 33039, Test size = 8205
#   [Model III Early Repeated - Fold 40] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0224 (diff: 0.0008)
#     Test SL rate:    0.0264 (diff: 0.0032)
#     Train/Test diff: 0.0040
# Stratification OK
#   ROC AUC = 0.9283, Elapsed time = 1957.76 seconds
# Fold 41: Train size = 32989, Test size = 8255
#   [Model III Early Repeated - Fold 41] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0239 (diff: 0.0007)
#     Test SL rate:    0.0205 (diff: 0.0028)
#     Train/Test diff: 0.0034
# Stratification OK
#   ROC AUC = 0.9064, Elapsed time = 2006.91 seconds
# Fold 42: Train size = 32973, Test size = 8271
#   [Model III Early Repeated - Fold 42] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0001)
#     Test SL rate:    0.0227 (diff: 0.0005)
#     Train/Test diff: 0.0006
# Stratification OK
#   ROC AUC = 0.9379, Elapsed time = 2054.66 seconds
# Fold 43: Train size = 32975, Test size = 8269
#   [Model III Early Repeated - Fold 43] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0236 (diff: 0.0004)
#     Test SL rate:    0.0216 (diff: 0.0016)
#     Train/Test diff: 0.0020
# Stratification OK
#   ROC AUC = 0.9051, Elapsed time = 2104.07 seconds
# Fold 44: Train size = 33018, Test size = 8226
#   [Model III Early Repeated - Fold 44] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0231 (diff: 0.0001)
#     Test SL rate:    0.0237 (diff: 0.0005)
#     Train/Test diff: 0.0006
# Stratification OK
#   ROC AUC = 0.8954, Elapsed time = 2154.18 seconds
# Fold 45: Train size = 33021, Test size = 8223
#   [Model III Early Repeated - Fold 45] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0221 (diff: 0.0011)
#     Test SL rate:    0.0276 (diff: 0.0044)
#     Train/Test diff: 0.0055
# Stratification OK
#   ROC AUC = 0.8872, Elapsed time = 2202.88 seconds
# Fold 46: Train size = 33000, Test size = 8244
#   [Model III Early Repeated - Fold 46] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0235 (diff: 0.0003)
#     Test SL rate:    0.0222 (diff: 0.0010)
#     Train/Test diff: 0.0013
# Stratification OK
#   ROC AUC = 0.8731, Elapsed time = 2250.84 seconds
# Fold 47: Train size = 33006, Test size = 8238
#   [Model III Early Repeated - Fold 47] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0236 (diff: 0.0004)
#     Test SL rate:    0.0216 (diff: 0.0016)
#     Train/Test diff: 0.0020
# Stratification OK
#   ROC AUC = 0.8915, Elapsed time = 2299.18 seconds
# Fold 48: Train size = 32954, Test size = 8290
#   [Model III Early Repeated - Fold 48] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0001)
#     Test SL rate:    0.0235 (diff: 0.0003)
#     Train/Test diff: 0.0004
# Stratification OK
#   ROC AUC = 0.9381, Elapsed time = 2347.63 seconds
# Fold 49: Train size = 33022, Test size = 8222
#   [Model III Early Repeated - Fold 49] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0230 (diff: 0.0003)
#     Test SL rate:    0.0243 (diff: 0.0011)
#     Train/Test diff: 0.0014
# Stratification OK
#   ROC AUC = 0.9068, Elapsed time = 2396.76 seconds
# Fold 50: Train size = 32994, Test size = 8250
#   [Model III Early Repeated - Fold 50] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0229 (diff: 0.0003)
#     Test SL rate:    0.0245 (diff: 0.0013)
#     Train/Test diff: 0.0016
# Stratification OK
#   ROC AUC = 0.9158, Elapsed time = 2447.43 seconds
#
# === Model III Early Repeated Summary ===
# Mean ROC AUC = 0.9037 ± 0.0155
# Successful folds: 50/50
# Stratification quality:
#   Mean train deviation: 0.0005 ± 0.0004
#   Mean test deviation:  0.0018 ± 0.0015
#
# === Model III Late Repeated - Fold 1/50 ===
# Train size = 33027, Test size = 8217
#   [Model III Late Repeated - Fold 1] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0223 (diff: 0.0009)
#     Test SL rate:    0.0269 (diff: 0.0037)
#     Train/Test diff: 0.0046
# Stratification OK
#   ROC AUC = 0.8820, Elapsed time = 71.21 seconds
#
# === Model III Late Repeated - Fold 2/50 ===
# Train size = 32987, Test size = 8257
#   [Model III Late Repeated - Fold 2] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0002)
#     Test SL rate:    0.0224 (diff: 0.0008)
#     Train/Test diff: 0.0010
# Stratification OK
#   ROC AUC = 0.9069, Elapsed time = 140.79 seconds
#
# === Model III Late Repeated - Fold 3/50 ===
# Train size = 32975, Test size = 8269
#   [Model III Late Repeated - Fold 3] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0002)
#     Test SL rate:    0.0224 (diff: 0.0009)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9222, Elapsed time = 206.99 seconds
#
# === Model III Late Repeated - Fold 4/50 ===
# Train size = 32987, Test size = 8257
#   [Model III Late Repeated - Fold 4] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0239 (diff: 0.0007)
#     Test SL rate:    0.0206 (diff: 0.0026)
#     Train/Test diff: 0.0033
# Stratification OK
#   ROC AUC = 0.9210, Elapsed time = 270.61 seconds
#
# === Model III Late Repeated - Fold 5/50 ===
# Train size = 33000, Test size = 8244
#   [Model III Late Repeated - Fold 5] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0231 (diff: 0.0002)
#     Test SL rate:    0.0239 (diff: 0.0007)
#     Train/Test diff: 0.0008
# Stratification OK
#   ROC AUC = 0.9078, Elapsed time = 335.78 seconds
#
# === Model III Late Repeated - Fold 6/50 ===
# Train size = 32999, Test size = 8245
#   [Model III Late Repeated - Fold 6] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0227 (diff: 0.0005)
#     Test SL rate:    0.0252 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9019, Elapsed time = 399.75 seconds
#
# === Model III Late Repeated - Fold 7/50 ===
# Train size = 32975, Test size = 8269
#   [Model III Late Repeated - Fold 7] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0224 (diff: 0.0008)
#     Test SL rate:    0.0265 (diff: 0.0033)
#     Train/Test diff: 0.0041
# Stratification OK
#   ROC AUC = 0.9348, Elapsed time = 462.82 seconds
#
# === Model III Late Repeated - Fold 8/50 ===
# Train size = 32979, Test size = 8265
#   [Model III Late Repeated - Fold 8] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0001)
#     Test SL rate:    0.0230 (diff: 0.0002)
#     Train/Test diff: 0.0003
# Stratification OK
#   ROC AUC = 0.8971, Elapsed time = 526.95 seconds
#
# === Model III Late Repeated - Fold 9/50 ===
# Train size = 33010, Test size = 8234
#   [Model III Late Repeated - Fold 9] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0001)
#     Test SL rate:    0.0234 (diff: 0.0002)
#     Train/Test diff: 0.0003
# Stratification OK
#   ROC AUC = 0.9082, Elapsed time = 591.20 seconds
#
# === Model III Late Repeated - Fold 10/50 ===
# Train size = 33013, Test size = 8231
#   [Model III Late Repeated - Fold 10] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0245 (diff: 0.0013)
#     Test SL rate:    0.0180 (diff: 0.0052)
#     Train/Test diff: 0.0066
# Stratification OK
#   ROC AUC = 0.9009, Elapsed time = 661.29 seconds
#
# === Model III Late Repeated - Fold 11/50 ===
# Train size = 33002, Test size = 8242
#   [Model III Late Repeated - Fold 11] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0237 (diff: 0.0005)
#     Test SL rate:    0.0214 (diff: 0.0019)
#     Train/Test diff: 0.0023
# Stratification OK
#   ROC AUC = 0.9096, Elapsed time = 730.81 seconds
#
# === Model III Late Repeated - Fold 12/50 ===
# Train size = 32987, Test size = 8257
#   [Model III Late Repeated - Fold 12] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0225 (diff: 0.0007)
#     Test SL rate:    0.0260 (diff: 0.0028)
#     Train/Test diff: 0.0035
# Stratification OK
#   ROC AUC = 0.9122, Elapsed time = 798.93 seconds
#
# === Model III Late Repeated - Fold 13/50 ===
# Train size = 33005, Test size = 8239
#   [Model III Late Repeated - Fold 13] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0235 (diff: 0.0002)
#     Test SL rate:    0.0223 (diff: 0.0009)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9209, Elapsed time = 869.37 seconds
#
# === Model III Late Repeated - Fold 14/50 ===
# Train size = 33014, Test size = 8230
#   [Model III Late Repeated - Fold 14] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0227 (diff: 0.0006)
#     Test SL rate:    0.0255 (diff: 0.0023)
#     Train/Test diff: 0.0029
# Stratification OK
#   ROC AUC = 0.9051, Elapsed time = 941.73 seconds
#
# === Model III Late Repeated - Fold 15/50 ===
# Train size = 32968, Test size = 8276
#   [Model III Late Repeated - Fold 15] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0238 (diff: 0.0006)
#     Test SL rate:    0.0209 (diff: 0.0023)
#     Train/Test diff: 0.0029
# Stratification OK
#   ROC AUC = 0.9080, Elapsed time = 1011.64 seconds
#
# === Model III Late Repeated - Fold 16/50 ===
# Train size = 33025, Test size = 8219
#   [Model III Late Repeated - Fold 16] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0236 (diff: 0.0004)
#     Test SL rate:    0.0215 (diff: 0.0017)
#     Train/Test diff: 0.0021
# Stratification OK
#   ROC AUC = 0.9020, Elapsed time = 1080.83 seconds
#
# === Model III Late Repeated - Fold 17/50 ===
# Train size = 33017, Test size = 8227
#   [Model III Late Repeated - Fold 17] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0227 (diff: 0.0005)
#     Test SL rate:    0.0252 (diff: 0.0019)
#     Train/Test diff: 0.0024
# Stratification OK
#   ROC AUC = 0.9108, Elapsed time = 1151.01 seconds
#
# === Model III Late Repeated - Fold 18/50 ===
# Train size = 32994, Test size = 8250
#   [Model III Late Repeated - Fold 18] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0230 (diff: 0.0002)
#     Test SL rate:    0.0241 (diff: 0.0009)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9029, Elapsed time = 1220.92 seconds
#
# === Model III Late Repeated - Fold 19/50 ===
# Train size = 33018, Test size = 8226
#   [Model III Late Repeated - Fold 19] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0237 (diff: 0.0004)
#     Test SL rate:    0.0215 (diff: 0.0017)
#     Train/Test diff: 0.0021
# Stratification OK
#   ROC AUC = 0.9310, Elapsed time = 1291.19 seconds
#
# === Model III Late Repeated - Fold 20/50 ===
# Train size = 32922, Test size = 8322
#   [Model III Late Repeated - Fold 20] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0231 (diff: 0.0001)
#     Test SL rate:    0.0238 (diff: 0.0006)
#     Train/Test diff: 0.0007
# Stratification OK
#   ROC AUC = 0.9011, Elapsed time = 1360.67 seconds
#
# === Model III Late Repeated - Fold 21/50 ===
# Train size = 32982, Test size = 8262
#   [Model III Late Repeated - Fold 21] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0227 (diff: 0.0005)
#     Test SL rate:    0.0253 (diff: 0.0021)
#     Train/Test diff: 0.0026
# Stratification OK
#   ROC AUC = 0.8952, Elapsed time = 1431.09 seconds
#
# === Model III Late Repeated - Fold 22/50 ===
# Train size = 32974, Test size = 8270
#   [Model III Late Repeated - Fold 22] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0217 (diff: 0.0015)
#     Test SL rate:    0.0291 (diff: 0.0059)
#     Train/Test diff: 0.0074
# Stratification OK
#   ROC AUC = 0.8957, Elapsed time = 1499.85 seconds
#
# === Model III Late Repeated - Fold 23/50 ===
# Train size = 32973, Test size = 8271
#   [Model III Late Repeated - Fold 23] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0002)
#     Test SL rate:    0.0224 (diff: 0.0009)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9296, Elapsed time = 1570.66 seconds
#
# === Model III Late Repeated - Fold 24/50 ===
# Train size = 33012, Test size = 8232
#   [Model III Late Repeated - Fold 24] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0239 (diff: 0.0007)
#     Test SL rate:    0.0205 (diff: 0.0027)
#     Train/Test diff: 0.0034
# Stratification OK
#   ROC AUC = 0.9216, Elapsed time = 1642.26 seconds
#
# === Model III Late Repeated - Fold 25/50 ===
# Train size = 33035, Test size = 8209
#   [Model III Late Repeated - Fold 25] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0243 (diff: 0.0011)
#     Test SL rate:    0.0188 (diff: 0.0045)
#     Train/Test diff: 0.0056
# Stratification OK
#   ROC AUC = 0.9081, Elapsed time = 1710.75 seconds
#
# === Model III Late Repeated - Fold 26/50 ===
# Train size = 32977, Test size = 8267
#   [Model III Late Repeated - Fold 26] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0239 (diff: 0.0006)
#     Test SL rate:    0.0207 (diff: 0.0025)
#     Train/Test diff: 0.0032
# Stratification OK
#   ROC AUC = 0.9279, Elapsed time = 1782.64 seconds
#
# === Model III Late Repeated - Fold 27/50 ===
# Train size = 32993, Test size = 8251
#   [Model III Late Repeated - Fold 27] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0230 (diff: 0.0002)
#     Test SL rate:    0.0240 (diff: 0.0008)
#     Train/Test diff: 0.0010
# Stratification OK
#   ROC AUC = 0.9173, Elapsed time = 1853.94 seconds
#
# === Model III Late Repeated - Fold 28/50 ===
# Train size = 33001, Test size = 8243
#   [Model III Late Repeated - Fold 28] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0224 (diff: 0.0008)
#     Test SL rate:    0.0264 (diff: 0.0032)
#     Train/Test diff: 0.0040
# Stratification OK
#   ROC AUC = 0.8811, Elapsed time = 1921.53 seconds
#
# === Model III Late Repeated - Fold 29/50 ===
# Train size = 33012, Test size = 8232
#   [Model III Late Repeated - Fold 29] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0002)
#     Test SL rate:    0.0224 (diff: 0.0009)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9060, Elapsed time = 1989.81 seconds
#
# === Model III Late Repeated - Fold 30/50 ===
# Train size = 32993, Test size = 8251
#   [Model III Late Repeated - Fold 30] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0001)
#     Test SL rate:    0.0227 (diff: 0.0006)
#     Train/Test diff: 0.0007
# Stratification OK
#   ROC AUC = 0.9225, Elapsed time = 2059.96 seconds
#
# === Model III Late Repeated - Fold 31/50 ===
# Train size = 32941, Test size = 8303
#   [Model III Late Repeated - Fold 31] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0236 (diff: 0.0003)
#     Test SL rate:    0.0219 (diff: 0.0013)
#     Train/Test diff: 0.0016
# Stratification OK
#   ROC AUC = 0.8979, Elapsed time = 2127.12 seconds
#
# === Model III Late Repeated - Fold 32/50 ===
# Train size = 33029, Test size = 8215
#   [Model III Late Repeated - Fold 32] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0227 (diff: 0.0005)
#     Test SL rate:    0.0252 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9133, Elapsed time = 2197.82 seconds
#
# === Model III Late Repeated - Fold 33/50 ===
# Train size = 32996, Test size = 8248
#   [Model III Late Repeated - Fold 33] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0001)
#     Test SL rate:    0.0227 (diff: 0.0006)
#     Train/Test diff: 0.0007
# Stratification OK
#   ROC AUC = 0.9136, Elapsed time = 2268.45 seconds
#
# === Model III Late Repeated - Fold 34/50 ===
# Train size = 33023, Test size = 8221
#   [Model III Late Repeated - Fold 34] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0233 (diff: 0.0001)
#     Test SL rate:    0.0230 (diff: 0.0002)
#     Train/Test diff: 0.0003
# Stratification OK
#   ROC AUC = 0.9078, Elapsed time = 2338.56 seconds
#
# === Model III Late Repeated - Fold 35/50 ===
# Train size = 32987, Test size = 8257
#   [Model III Late Repeated - Fold 35] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0234 (diff: 0.0001)
#     Train/Test diff: 0.0002
# Stratification OK
#   ROC AUC = 0.9220, Elapsed time = 2409.44 seconds
#
# === Model III Late Repeated - Fold 36/50 ===
# Train size = 32996, Test size = 8248
#   [Model III Late Repeated - Fold 36] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0230 (diff: 0.0002)
#     Test SL rate:    0.0241 (diff: 0.0009)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.8880, Elapsed time = 2478.74 seconds
#
# === Model III Late Repeated - Fold 37/50 ===
# Train size = 32979, Test size = 8265
#   [Model III Late Repeated - Fold 37] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0227 (diff: 0.0005)
#     Test SL rate:    0.0252 (diff: 0.0019)
#     Train/Test diff: 0.0024
# Stratification OK
#   ROC AUC = 0.9119, Elapsed time = 2549.80 seconds
#
# === Model III Late Repeated - Fold 38/50 ===
# Train size = 32993, Test size = 8251
#   [Model III Late Repeated - Fold 38] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0000)
#     Test SL rate:    0.0233 (diff: 0.0000)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.8891, Elapsed time = 2622.56 seconds
#
# === Model III Late Repeated - Fold 39/50 ===
# Train size = 32969, Test size = 8275
#   [Model III Late Repeated - Fold 39] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0248 (diff: 0.0015)
#     Test SL rate:    0.0172 (diff: 0.0061)
#     Train/Test diff: 0.0076
# Stratification OK
#   ROC AUC = 0.9066, Elapsed time = 2692.15 seconds
#
# === Model III Late Repeated - Fold 40/50 ===
# Train size = 33039, Test size = 8205
#   [Model III Late Repeated - Fold 40] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0224 (diff: 0.0008)
#     Test SL rate:    0.0264 (diff: 0.0032)
#     Train/Test diff: 0.0040
# Stratification OK
#   ROC AUC = 0.9336, Elapsed time = 2761.02 seconds
#
# === Model III Late Repeated - Fold 41/50 ===
# Train size = 32989, Test size = 8255
#   [Model III Late Repeated - Fold 41] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0239 (diff: 0.0007)
#     Test SL rate:    0.0205 (diff: 0.0028)
#     Train/Test diff: 0.0034
# Stratification OK
#   ROC AUC = 0.9217, Elapsed time = 2830.70 seconds
#
# === Model III Late Repeated - Fold 42/50 ===
# Train size = 32973, Test size = 8271
#   [Model III Late Repeated - Fold 42] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0234 (diff: 0.0001)
#     Test SL rate:    0.0227 (diff: 0.0005)
#     Train/Test diff: 0.0006
# Stratification OK
#   ROC AUC = 0.9332, Elapsed time = 2903.10 seconds
#
# === Model III Late Repeated - Fold 43/50 ===
# Train size = 32975, Test size = 8269
#   [Model III Late Repeated - Fold 43] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0236 (diff: 0.0004)
#     Test SL rate:    0.0216 (diff: 0.0016)
#     Train/Test diff: 0.0020
# Stratification OK
#   ROC AUC = 0.9122, Elapsed time = 2977.05 seconds
#
# === Model III Late Repeated - Fold 44/50 ===
# Train size = 33018, Test size = 8226
#   [Model III Late Repeated - Fold 44] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0231 (diff: 0.0001)
#     Test SL rate:    0.0237 (diff: 0.0005)
#     Train/Test diff: 0.0006
# Stratification OK
#   ROC AUC = 0.9005, Elapsed time = 3043.83 seconds
#
# === Model III Late Repeated - Fold 45/50 ===
# Train size = 33021, Test size = 8223
#   [Model III Late Repeated - Fold 45] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0221 (diff: 0.0011)
#     Test SL rate:    0.0276 (diff: 0.0044)
#     Train/Test diff: 0.0055
# Stratification OK
#   ROC AUC = 0.8915, Elapsed time = 3108.15 seconds
#
# === Model III Late Repeated - Fold 46/50 ===
# Train size = 33000, Test size = 8244
#   [Model III Late Repeated - Fold 46] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0235 (diff: 0.0003)
#     Test SL rate:    0.0222 (diff: 0.0010)
#     Train/Test diff: 0.0013
# Stratification OK
#   ROC AUC = 0.8831, Elapsed time = 3172.38 seconds
#
# === Model III Late Repeated - Fold 47/50 ===
# Train size = 33006, Test size = 8238
#   [Model III Late Repeated - Fold 47] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0236 (diff: 0.0004)
#     Test SL rate:    0.0216 (diff: 0.0016)
#     Train/Test diff: 0.0020
# Stratification OK
#   ROC AUC = 0.8976, Elapsed time = 3236.43 seconds
#
# === Model III Late Repeated - Fold 48/50 ===
# Train size = 32954, Test size = 8290
#   [Model III Late Repeated - Fold 48] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0232 (diff: 0.0001)
#     Test SL rate:    0.0235 (diff: 0.0003)
#     Train/Test diff: 0.0004
# Stratification OK
#   ROC AUC = 0.9358, Elapsed time = 3303.98 seconds
#
# === Model III Late Repeated - Fold 49/50 ===
# Train size = 33022, Test size = 8222
#   [Model III Late Repeated - Fold 49] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0230 (diff: 0.0003)
#     Test SL rate:    0.0243 (diff: 0.0011)
#     Train/Test diff: 0.0014
# Stratification OK
#   ROC AUC = 0.9093, Elapsed time = 3369.44 seconds
#
# === Model III Late Repeated - Fold 50/50 ===
# Train size = 32994, Test size = 8250
#   [Model III Late Repeated - Fold 50] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0229 (diff: 0.0003)
#     Test SL rate:    0.0245 (diff: 0.0013)
#     Train/Test diff: 0.0016
# Stratification OK
#   ROC AUC = 0.9221, Elapsed time = 3437.11 seconds
#
# === Model III Late Repeated Summary ===
# Mean ROC AUC = 0.9092 ± 0.0139
# Successful folds: 50/50
# Stratification quality:
# Mean train deviation: 0.0005 ± 0.0004
# Mean test deviation: 0.0018 ± 0.0015

# %%
# save results of cross validation
with open(file_RF_model_III_early_repeated, 'wb') as f:
    pickle.dump(model_III_early_repeated, f)

with open(file_RF_model_III_late_repeated, 'wb') as f:
    pickle.dump(model_III_late_repeated, f)

# %% [markdown]
# ## Model IV
# #### Different paralog pairs, different cell lines

# %%
# --- Custom split functions ---
def create_disjoint_splits(df, n_splits=5, num_test_cell_lines=2, test_gene_fraction=0.25, random_state=None):
    splits = []

    # Get the unique cell lines and gene pairs
    unique_cell_lines = df['cell_line'].unique()
    unique_gene_pairs = df['genepair'].unique()

    # Set the random seed if provided
    if random_state is not None:
        np.random.seed(random_state)

    # Shuffle and split cell lines and gene pairs into mutually exclusive groups
    np.random.shuffle(unique_cell_lines)
    cell_line_splits = np.array_split(unique_cell_lines, n_splits)

    np.random.shuffle(unique_gene_pairs)
    gene_pair_splits = np.array_split(unique_gene_pairs, n_splits)

    # Create the splits
    for fold in range(n_splits):
        test_cell_lines = cell_line_splits[fold]
        test_gene_pairs = gene_pair_splits[fold]

        train_cell_lines = np.concatenate([cell_line_splits[i] for i in range(n_splits) if i != fold])
        train_gene_pairs = np.concatenate([gene_pair_splits[i] for i in range(n_splits) if i != fold])

        # Define train/test indices
        test_index = df[(df['cell_line'].isin(test_cell_lines)) & (df['genepair'].isin(test_gene_pairs))].index
        train_index = df[(df['cell_line'].isin(train_cell_lines)) & (df['genepair'].isin(train_gene_pairs))].index

        splits.append((train_index, test_index))

        print(f'[Fold {fold+1}] '
              f'# pairs (train): {df.loc[train_index, "genepair"].nunique()} | '
              f'# pairs (test): {df.loc[test_index, "genepair"].nunique()} | '
              f'# overlapping: {np.isin(df.loc[test_index, "genepair"].unique(), df.loc[train_index, "genepair"].unique()).sum()} | '
              f'# cells (train): {df.loc[train_index, "cell_line"].nunique()} | '
              f'# cells (test): {df.loc[test_index, "cell_line"].nunique()}')

        # Add validation after creating splits
        train_cells = set(df.loc[train_index, 'cell_line'].unique())
        test_cells = set(df.loc[test_index, 'cell_line'].unique())
        train_pairs = set(df.loc[train_index, 'genepair'].unique())
        test_pairs = set(df.loc[test_index, 'genepair'].unique())

        assert len(train_cells & test_cells) == 0, "Cell line leakage detected!"
        assert len(train_pairs & test_pairs) == 0, "Gene pair leakage detected!"

    return splits

def repeated_custom_cv(df, n_splits=5, n_repeats=3, num_test_cell_lines=2, test_gene_fraction=0.25, random_state=None):
    all_splits = []

    for repeat in range(n_repeats):
        current_seed = random_state + repeat if random_state is not None else None
        splits = create_disjoint_splits(
            df,
            n_splits=n_splits,
            num_test_cell_lines=num_test_cell_lines,
            test_gene_fraction=test_gene_fraction,
            random_state=current_seed
        )
        all_splits.extend(splits)

    return all_splits

# %%
splits_IV = repeated_custom_cv(df=training_df, n_splits=5, n_repeats=10, random_state=42)

# Add validation for Model IV splits
print("\n=== MODEL IV: COMBINED VALIDATION ===")
for i, (train_index, test_index) in enumerate(splits_IV[:5]):  # Just first 5 for brevity
    train_cells = training_df.loc[train_index, 'cell_line'].unique()  # Use correct column name
    test_cells = training_df.loc[test_index, 'cell_line'].unique()    # Use correct column name
    train_pairs = training_df.loc[train_index, 'genepair'].unique()
    test_pairs = training_df.loc[test_index, 'genepair'].unique()
    
    print(f"\n--- Fold {i+1} ---")
    validate_group_splits(train_cells, test_cells, i+1, "Model IV", "cell lines")
    validate_group_splits(train_pairs, test_pairs, i+1, "Model IV", "gene pairs")
# Out:
# [Fold 1] # pairs (train): 3336 | # pairs (test): 833 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 2] # pairs (train): 3336 | # pairs (test): 833 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 3] # pairs (train): 3336 | # pairs (test): 833 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 4] # pairs (train): 3336 | # pairs (test): 833 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 5] # pairs (train): 3336 | # pairs (test): 830 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 1] # pairs (train): 3336 | # pairs (test): 833 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 2] # pairs (train): 3336 | # pairs (test): 832 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 3] # pairs (train): 3336 | # pairs (test): 833 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 4] # pairs (train): 3336 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 5] # pairs (train): 3336 | # pairs (test): 833 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 1] # pairs (train): 3336 | # pairs (test): 832 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 2] # pairs (train): 3336 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 3] # pairs (train): 3336 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 4] # pairs (train): 3336 | # pairs (test): 827 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 5] # pairs (train): 3336 | # pairs (test): 829 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 1] # pairs (train): 3336 | # pairs (test): 833 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 2] # pairs (train): 3336 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 3] # pairs (train): 3336 | # pairs (test): 831 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 4] # pairs (train): 3336 | # pairs (test): 828 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 5] # pairs (train): 3336 | # pairs (test): 832 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 1] # pairs (train): 3336 | # pairs (test): 831 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 2] # pairs (train): 3336 | # pairs (test): 833 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 3] # pairs (train): 3336 | # pairs (test): 827 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 4] # pairs (train): 3336 | # pairs (test): 833 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 5] # pairs (train): 3336 | # pairs (test): 833 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 1] # pairs (train): 3336 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 2] # pairs (train): 3336 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 3] # pairs (train): 3336 | # pairs (test): 833 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 4] # pairs (train): 3336 | # pairs (test): 832 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 5] # pairs (train): 3336 | # pairs (test): 829 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 1] # pairs (train): 3336 | # pairs (test): 832 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 2] # pairs (train): 3336 | # pairs (test): 833 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 3] # pairs (train): 3336 | # pairs (test): 831 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 4] # pairs (train): 3336 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 5] # pairs (train): 3336 | # pairs (test): 825 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 1] # pairs (train): 3336 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 2] # pairs (train): 3336 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 3] # pairs (train): 3336 | # pairs (test): 831 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 4] # pairs (train): 3336 | # pairs (test): 833 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 5] # pairs (train): 3336 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 1] # pairs (train): 3336 | # pairs (test): 833 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 2] # pairs (train): 3336 | # pairs (test): 832 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 3] # pairs (train): 3336 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 4] # pairs (train): 3336 | # pairs (test): 832 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 5] # pairs (train): 3336 | # pairs (test): 831 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 1] # pairs (train): 3336 | # pairs (test): 832 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 2] # pairs (train): 3336 | # pairs (test): 829 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 3] # pairs (train): 3336 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 4] # pairs (train): 3336 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 5] # pairs (train): 3336 | # pairs (test): 833 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
#
# === MODEL IV: COMBINED VALIDATION ===
#
# --- Fold 1 ---
#   [Model IV - Fold 1] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model IV - Fold 1] Group Validation:
#     Train gene pairs: 3336
#     Test gene pairs:  833
#     Overlapping gene pairs: 0
# No group leakage
#
# --- Fold 2 ---
#   [Model IV - Fold 2] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model IV - Fold 2] Group Validation:
#     Train gene pairs: 3336
#     Test gene pairs:  833
#     Overlapping gene pairs: 0
# No group leakage
#
# --- Fold 3 ---
#   [Model IV - Fold 3] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model IV - Fold 3] Group Validation:
#     Train gene pairs: 3336
#     Test gene pairs:  833
#     Overlapping gene pairs: 0
# No group leakage
#
# --- Fold 4 ---
#   [Model IV - Fold 4] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model IV - Fold 4] Group Validation:
#     Train gene pairs: 3336
#     Test gene pairs:  833
#     Overlapping gene pairs: 0
# No group leakage
#
# --- Fold 5 ---
#   [Model IV - Fold 5] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model IV - Fold 5] Group Validation:
#     Train gene pairs: 3336
#     Test gene pairs:  830
#     Overlapping gene pairs: 0
# No group leakage

# %%
# Save splits
with open('/Users/narod/Library/CloudStorage/GoogleDrive-narod.kebabci@ucdconnect.ie/My Drive/GitRepos/context_specific_SL_prediction/output/models/model_IV/splits_IV.pkl', 'wb') as f:
    pickle.dump(splits_IV, f)

# %%
model_IV_early = model_early_cross_validation(RF, data_1, target, splits_IV, model_name="Model IV Early")
model_IV_late = model_late_cross_validation(RF, data_2, target, splits_IV, model_name="Model IV Late")
# Out:
# Fold 1: Train size = 26389, Test size = 1651
#   [Model IV Early - Fold 1] Stratification Check:
#     Overall SL rate: 0.0235
#     Train SL rate:   0.0233 (diff: 0.0002)
#     Test SL rate:    0.0267 (diff: 0.0032)
#     Train/Test diff: 0.0034
# Stratification OK
#   ROC AUC = 0.8955, Elapsed time = 35.01 seconds
# Fold 2: Train size = 26403, Test size = 1651
#   [Model IV Early - Fold 2] Stratification Check:
#     Overall SL rate: 0.0248
#     Train SL rate:   0.0252 (diff: 0.0005)
#     Test SL rate:    0.0176 (diff: 0.0072)
#     Train/Test diff: 0.0077
# Stratification OK
#   ROC AUC = 0.8375, Elapsed time = 69.02 seconds
# Fold 3: Train size = 26371, Test size = 1659
#   [Model IV Early - Fold 3] Stratification Check:
#     Overall SL rate: 0.0227
#     Train SL rate:   0.0222 (diff: 0.0004)
#     Test SL rate:    0.0295 (diff: 0.0069)
#     Train/Test diff: 0.0073
# Stratification OK
#   ROC AUC = 0.8925, Elapsed time = 102.50 seconds
# Fold 4: Train size = 26358, Test size = 1658
#   [Model IV Early - Fold 4] Stratification Check:
#     Overall SL rate: 0.0216
#     Train SL rate:   0.0209 (diff: 0.0007)
#     Test SL rate:    0.0320 (diff: 0.0104)
#     Train/Test diff: 0.0111
# Stratification OK
#   ROC AUC = 0.8496, Elapsed time = 136.26 seconds
# Fold 5: Train size = 26465, Test size = 1635
#   [Model IV Early - Fold 5] Stratification Check:
#     Overall SL rate: 0.0245
#     Train SL rate:   0.0249 (diff: 0.0005)
#     Test SL rate:    0.0171 (diff: 0.0074)
#     Train/Test diff: 0.0078
# Stratification OK
#   ROC AUC = 0.9338, Elapsed time = 170.54 seconds
# Fold 6: Train size = 26421, Test size = 1638
#   [Model IV Early - Fold 6] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0235 (diff: 0.0003)
#     Test SL rate:    0.0183 (diff: 0.0049)
#     Train/Test diff: 0.0052
# Stratification OK
#   ROC AUC = 0.8442, Elapsed time = 206.57 seconds
# Fold 7: Train size = 26410, Test size = 1645
#   [Model IV Early - Fold 7] Stratification Check:
#     Overall SL rate: 0.0237
#     Train SL rate:   0.0242 (diff: 0.0005)
#     Test SL rate:    0.0158 (diff: 0.0079)
#     Train/Test diff: 0.0084
# Stratification OK
#   ROC AUC = 0.8923, Elapsed time = 241.63 seconds
# Fold 8: Train size = 26386, Test size = 1655
#   [Model IV Early - Fold 8] Stratification Check:
#     Overall SL rate: 0.0238
#     Train SL rate:   0.0244 (diff: 0.0006)
#     Test SL rate:    0.0145 (diff: 0.0093)
#     Train/Test diff: 0.0099
# Stratification OK
#   ROC AUC = 0.8686, Elapsed time = 276.64 seconds
# Fold 9: Train size = 26375, Test size = 1652
#   [Model IV Early - Fold 9] Stratification Check:
#     Overall SL rate: 0.0206
#     Train SL rate:   0.0196 (diff: 0.0010)
#     Test SL rate:    0.0363 (diff: 0.0157)
#     Train/Test diff: 0.0167
# Stratification OK
#   ROC AUC = 0.8695, Elapsed time = 308.60 seconds
# Fold 10: Train size = 26384, Test size = 1654
#   [Model IV Early - Fold 10] Stratification Check:
#     Overall SL rate: 0.0236
#     Train SL rate:   0.0238 (diff: 0.0002)
#     Test SL rate:    0.0206 (diff: 0.0030)
#     Train/Test diff: 0.0032
# Stratification OK
#   ROC AUC = 0.8323, Elapsed time = 341.47 seconds
# Fold 11: Train size = 26364, Test size = 1658
#   [Model IV Early - Fold 11] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0230 (diff: 0.0002)
#     Test SL rate:    0.0271 (diff: 0.0039)
#     Train/Test diff: 0.0041
# Stratification OK
#   ROC AUC = 0.9233, Elapsed time = 374.78 seconds
# Fold 12: Train size = 26384, Test size = 1653
#   [Model IV Early - Fold 12] Stratification Check:
#     Overall SL rate: 0.0248
#     Train SL rate:   0.0255 (diff: 0.0008)
#     Test SL rate:    0.0127 (diff: 0.0120)
#     Train/Test diff: 0.0128
# Stratification OK
#   ROC AUC = 0.9142, Elapsed time = 409.66 seconds
# Fold 13: Train size = 26414, Test size = 1654
#   [Model IV Early - Fold 13] Stratification Check:
#     Overall SL rate: 0.0258
#     Train SL rate:   0.0264 (diff: 0.0006)
#     Test SL rate:    0.0163 (diff: 0.0095)
#     Train/Test diff: 0.0101
# Stratification OK
#   ROC AUC = 0.8914, Elapsed time = 444.91 seconds
# Fold 14: Train size = 26402, Test size = 1642
#   [Model IV Early - Fold 14] Stratification Check:
#     Overall SL rate: 0.0220
#     Train SL rate:   0.0213 (diff: 0.0007)
#     Test SL rate:    0.0329 (diff: 0.0109)
#     Train/Test diff: 0.0116
# Stratification OK
#   ROC AUC = 0.8597, Elapsed time = 478.30 seconds
# Fold 15: Train size = 26416, Test size = 1641
#   [Model IV Early - Fold 15] Stratification Check:
#     Overall SL rate: 0.0208
#     Train SL rate:   0.0201 (diff: 0.0006)
#     Test SL rate:    0.0311 (diff: 0.0103)
#     Train/Test diff: 0.0109
# Stratification OK
#   ROC AUC = 0.8342, Elapsed time = 510.57 seconds
# Fold 16: Train size = 26365, Test size = 1659
#   [Model IV Early - Fold 16] Stratification Check:
#     Overall SL rate: 0.0226
#     Train SL rate:   0.0224 (diff: 0.0002)
#     Test SL rate:    0.0259 (diff: 0.0033)
#     Train/Test diff: 0.0035
# Stratification OK
#   ROC AUC = 0.7797, Elapsed time = 543.92 seconds
# Fold 17: Train size = 26380, Test size = 1653
#   [Model IV Early - Fold 17] Stratification Check:
#     Overall SL rate: 0.0222
#     Train SL rate:   0.0221 (diff: 0.0001)
#     Test SL rate:    0.0230 (diff: 0.0008)
#     Train/Test diff: 0.0009
# Stratification OK
#   ROC AUC = 0.8738, Elapsed time = 576.87 seconds
# Fold 18: Train size = 26416, Test size = 1646
#   [Model IV Early - Fold 18] Stratification Check:
#     Overall SL rate: 0.0251
#     Train SL rate:   0.0259 (diff: 0.0008)
#     Test SL rate:    0.0115 (diff: 0.0135)
#     Train/Test diff: 0.0144
# Stratification OK
#   ROC AUC = 0.9076, Elapsed time = 612.07 seconds
# Fold 19: Train size = 26403, Test size = 1644
#   [Model IV Early - Fold 19] Stratification Check:
#     Overall SL rate: 0.0208
#     Train SL rate:   0.0201 (diff: 0.0007)
#     Test SL rate:    0.0322 (diff: 0.0115)
#     Train/Test diff: 0.0122
# Stratification OK
#   ROC AUC = 0.8967, Elapsed time = 645.76 seconds
# Fold 20: Train size = 26420, Test size = 1650
#   [Model IV Early - Fold 20] Stratification Check:
#     Overall SL rate: 0.0245
#     Train SL rate:   0.0251 (diff: 0.0006)
#     Test SL rate:    0.0152 (diff: 0.0094)
#     Train/Test diff: 0.0099
# Stratification OK
#   ROC AUC = 0.8804, Elapsed time = 680.32 seconds
# Fold 21: Train size = 26388, Test size = 1649
#   [Model IV Early - Fold 21] Stratification Check:
#     Overall SL rate: 0.0234
#     Train SL rate:   0.0233 (diff: 0.0001)
#     Test SL rate:    0.0243 (diff: 0.0009)
#     Train/Test diff: 0.0010
# Stratification OK
#   ROC AUC = 0.9130, Elapsed time = 714.95 seconds
# Fold 22: Train size = 26371, Test size = 1657
#   [Model IV Early - Fold 22] Stratification Check:
#     Overall SL rate: 0.0225
#     Train SL rate:   0.0226 (diff: 0.0001)
#     Test SL rate:    0.0205 (diff: 0.0020)
#     Train/Test diff: 0.0021
# Stratification OK
#   ROC AUC = 0.8734, Elapsed time = 749.20 seconds
# Fold 23: Train size = 26471, Test size = 1630
#   [Model IV Early - Fold 23] Stratification Check:
#     Overall SL rate: 0.0249
#     Train SL rate:   0.0255 (diff: 0.0006)
#     Test SL rate:    0.0147 (diff: 0.0102)
#     Train/Test diff: 0.0108
# Stratification OK
#   ROC AUC = 0.8890, Elapsed time = 783.91 seconds
# Fold 24: Train size = 26377, Test size = 1656
#   [Model IV Early - Fold 24] Stratification Check:
#     Overall SL rate: 0.0219
#     Train SL rate:   0.0214 (diff: 0.0005)
#     Test SL rate:    0.0302 (diff: 0.0083)
#     Train/Test diff: 0.0088
# Stratification OK
#   ROC AUC = 0.7977, Elapsed time = 815.37 seconds
# Fold 25: Train size = 26371, Test size = 1654
#   [Model IV Early - Fold 25] Stratification Check:
#     Overall SL rate: 0.0227
#     Train SL rate:   0.0229 (diff: 0.0002)
#     Test SL rate:    0.0200 (diff: 0.0028)
#     Train/Test diff: 0.0030
# Stratification OK
#   ROC AUC = 0.9079, Elapsed time = 851.39 seconds
# Fold 26: Train size = 26367, Test size = 1659
#   [Model IV Early - Fold 26] Stratification Check:
#     Overall SL rate: 0.0238
#     Train SL rate:   0.0239 (diff: 0.0001)
#     Test SL rate:    0.0217 (diff: 0.0021)
#     Train/Test diff: 0.0022
# Stratification OK
#   ROC AUC = 0.8693, Elapsed time = 888.22 seconds
# Fold 27: Train size = 26365, Test size = 1656
#   [Model IV Early - Fold 27] Stratification Check:
#     Overall SL rate: 0.0217
#     Train SL rate:   0.0207 (diff: 0.0010)
#     Test SL rate:    0.0374 (diff: 0.0158)
#     Train/Test diff: 0.0168
# Stratification OK
#   ROC AUC = 0.7973, Elapsed time = 924.14 seconds
# Fold 28: Train size = 26423, Test size = 1645
#   [Model IV Early - Fold 28] Stratification Check:
#     Overall SL rate: 0.0222
#     Train SL rate:   0.0220 (diff: 0.0002)
#     Test SL rate:    0.0249 (diff: 0.0027)
#     Train/Test diff: 0.0029
# Stratification OK
#   ROC AUC = 0.8715, Elapsed time = 961.85 seconds
# Fold 29: Train size = 26395, Test size = 1652
#   [Model IV Early - Fold 29] Stratification Check:
#     Overall SL rate: 0.0253
#     Train SL rate:   0.0262 (diff: 0.0009)
#     Test SL rate:    0.0103 (diff: 0.0150)
#     Train/Test diff: 0.0159
# Stratification OK
#   ROC AUC = 0.8784, Elapsed time = 1000.39 seconds
# Fold 30: Train size = 26435, Test size = 1641
#   [Model IV Early - Fold 30] Stratification Check:
#     Overall SL rate: 0.0235
#     Train SL rate:   0.0235 (diff: 0.0000)
#     Test SL rate:    0.0238 (diff: 0.0003)
#     Train/Test diff: 0.0003
# Stratification OK
#   ROC AUC = 0.9187, Elapsed time = 1038.39 seconds
# Fold 31: Train size = 26376, Test size = 1653
#   [Model IV Early - Fold 31] Stratification Check:
#     Overall SL rate: 0.0213
#     Train SL rate:   0.0207 (diff: 0.0006)
#     Test SL rate:    0.0302 (diff: 0.0090)
#     Train/Test diff: 0.0095
# Stratification OK
#   ROC AUC = 0.8924, Elapsed time = 1075.94 seconds
# Fold 32: Train size = 26409, Test size = 1648
#   [Model IV Early - Fold 32] Stratification Check:
#     Overall SL rate: 0.0261
#     Train SL rate:   0.0270 (diff: 0.0009)
#     Test SL rate:    0.0121 (diff: 0.0140)
#     Train/Test diff: 0.0148
# Stratification OK
#   ROC AUC = 0.9445, Elapsed time = 1113.50 seconds
# Fold 33: Train size = 26364, Test size = 1653
#   [Model IV Early - Fold 33] Stratification Check:
#     Overall SL rate: 0.0235
#     Train SL rate:   0.0234 (diff: 0.0000)
#     Test SL rate:    0.0242 (diff: 0.0007)
#     Train/Test diff: 0.0008
# Stratification OK
#   ROC AUC = 0.8676, Elapsed time = 1152.50 seconds
# Fold 34: Train size = 26394, Test size = 1655
#   [Model IV Early - Fold 34] Stratification Check:
#     Overall SL rate: 0.0215
#     Train SL rate:   0.0207 (diff: 0.0007)
#     Test SL rate:    0.0332 (diff: 0.0118)
#     Train/Test diff: 0.0125
# Stratification OK
#   ROC AUC = 0.8240, Elapsed time = 1187.03 seconds
# Fold 35: Train size = 26435, Test size = 1637
#   [Model IV Early - Fold 35] Stratification Check:
#     Overall SL rate: 0.0245
#     Train SL rate:   0.0247 (diff: 0.0002)
#     Test SL rate:    0.0214 (diff: 0.0031)
#     Train/Test diff: 0.0033
# Stratification OK
#   ROC AUC = 0.9029, Elapsed time = 1223.94 seconds
# Fold 36: Train size = 26381, Test size = 1657
#   [Model IV Early - Fold 36] Stratification Check:
#     Overall SL rate: 0.0260
#     Train SL rate:   0.0264 (diff: 0.0004)
#     Test SL rate:    0.0199 (diff: 0.0061)
#     Train/Test diff: 0.0065
# Stratification OK
#   ROC AUC = 0.9066, Elapsed time = 1261.99 seconds
# Fold 37: Train size = 26416, Test size = 1646
#   [Model IV Early - Fold 37] Stratification Check:
#     Overall SL rate: 0.0234
#     Train SL rate:   0.0232 (diff: 0.0002)
#     Test SL rate:    0.0267 (diff: 0.0034)
#     Train/Test diff: 0.0036
# Stratification OK
#   ROC AUC = 0.8219, Elapsed time = 1298.20 seconds
# Fold 38: Train size = 26367, Test size = 1655
#   [Model IV Early - Fold 38] Stratification Check:
#     Overall SL rate: 0.0227
#     Train SL rate:   0.0226 (diff: 0.0001)
#     Test SL rate:    0.0248 (diff: 0.0021)
#     Train/Test diff: 0.0022
# Stratification OK
#   ROC AUC = 0.9232, Elapsed time = 1335.63 seconds
# Fold 39: Train size = 26422, Test size = 1645
#   [Model IV Early - Fold 39] Stratification Check:
#     Overall SL rate: 0.0228
#     Train SL rate:   0.0228 (diff: 0.0000)
#     Test SL rate:    0.0231 (diff: 0.0003)
#     Train/Test diff: 0.0003
# Stratification OK
#   ROC AUC = 0.8409, Elapsed time = 1372.34 seconds
# Fold 40: Train size = 26400, Test size = 1651
#   [Model IV Early - Fold 40] Stratification Check:
#     Overall SL rate: 0.0226
#     Train SL rate:   0.0219 (diff: 0.0007)
#     Test SL rate:    0.0333 (diff: 0.0107)
#     Train/Test diff: 0.0114
# Stratification OK
#   ROC AUC = 0.8695, Elapsed time = 1409.79 seconds
# Fold 41: Train size = 26359, Test size = 1651
#   [Model IV Early - Fold 41] Stratification Check:
#     Overall SL rate: 0.0215
#     Train SL rate:   0.0208 (diff: 0.0008)
#     Test SL rate:    0.0339 (diff: 0.0124)
#     Train/Test diff: 0.0132
# Stratification OK
#   ROC AUC = 0.8339, Elapsed time = 1447.76 seconds
# Fold 42: Train size = 26400, Test size = 1647
#   [Model IV Early - Fold 42] Stratification Check:
#     Overall SL rate: 0.0267
#     Train SL rate:   0.0279 (diff: 0.0012)
#     Test SL rate:    0.0073 (diff: 0.0194)
#     Train/Test diff: 0.0206
# Stratification OK
#   ROC AUC = 0.9556, Elapsed time = 1484.80 seconds
# Fold 43: Train size = 26370, Test size = 1660
#   [Model IV Early - Fold 43] Stratification Check:
#     Overall SL rate: 0.0214
#     Train SL rate:   0.0203 (diff: 0.0011)
#     Test SL rate:    0.0386 (diff: 0.0171)
#     Train/Test diff: 0.0182
# Stratification OK
#   ROC AUC = 0.8008, Elapsed time = 1518.64 seconds
# Fold 44: Train size = 26439, Test size = 1633
#   [Model IV Early - Fold 44] Stratification Check:
#     Overall SL rate: 0.0227
#     Train SL rate:   0.0224 (diff: 0.0003)
#     Test SL rate:    0.0282 (diff: 0.0054)
#     Train/Test diff: 0.0058
# Stratification OK
#   ROC AUC = 0.8694, Elapsed time = 1555.83 seconds
# Fold 45: Train size = 26401, Test size = 1646
#   [Model IV Early - Fold 45] Stratification Check:
#     Overall SL rate: 0.0244
#     Train SL rate:   0.0251 (diff: 0.0007)
#     Test SL rate:    0.0134 (diff: 0.0111)
#     Train/Test diff: 0.0117
# Stratification OK
#   ROC AUC = 0.8580, Elapsed time = 1594.94 seconds
# Fold 46: Train size = 26401, Test size = 1647
#   [Model IV Early - Fold 46] Stratification Check:
#     Overall SL rate: 0.0222
#     Train SL rate:   0.0217 (diff: 0.0005)
#     Test SL rate:    0.0298 (diff: 0.0076)
#     Train/Test diff: 0.0080
# Stratification OK
#   ROC AUC = 0.8128, Elapsed time = 1631.00 seconds
# Fold 47: Train size = 26427, Test size = 1645
#   [Model IV Early - Fold 47] Stratification Check:
#     Overall SL rate: 0.0247
#     Train SL rate:   0.0256 (diff: 0.0010)
#     Test SL rate:    0.0091 (diff: 0.0155)
#     Train/Test diff: 0.0165
# Stratification OK
#   ROC AUC = 0.9085, Elapsed time = 1668.63 seconds
# Fold 48: Train size = 26373, Test size = 1653
#   [Model IV Early - Fold 48] Stratification Check:
#     Overall SL rate: 0.0215
#     Train SL rate:   0.0206 (diff: 0.0009)
#     Test SL rate:    0.0363 (diff: 0.0148)
#     Train/Test diff: 0.0157
# Stratification OK
#   ROC AUC = 0.9274, Elapsed time = 1705.76 seconds
# Fold 49: Train size = 26394, Test size = 1648
#   [Model IV Early - Fold 49] Stratification Check:
#     Overall SL rate: 0.0239
#     Train SL rate:   0.0243 (diff: 0.0004)
#     Test SL rate:    0.0176 (diff: 0.0063)
#     Train/Test diff: 0.0067
# Stratification OK
#   ROC AUC = 0.8743, Elapsed time = 1742.90 seconds
# Fold 50: Train size = 26385, Test size = 1655
#   [Model IV Early - Fold 50] Stratification Check:
#     Overall SL rate: 0.0235
#     Train SL rate:   0.0237 (diff: 0.0002)
#     Test SL rate:    0.0199 (diff: 0.0036)
#     Train/Test diff: 0.0038
# Stratification OK
#   ROC AUC = 0.8897, Elapsed time = 1782.32 seconds
#
# === Model IV Early Summary ===
# Mean ROC AUC = 0.8741 ± 0.0402
# Successful folds: 50/50
# Stratification quality:
#   Mean train deviation: 0.0005 ± 0.0003
#   Mean test deviation:  0.0079 ± 0.0050
#
# === Model IV Late - Fold 1/50 ===
# Train size = 26389, Test size = 1651
#   [Model IV Late - Fold 1] Stratification Check:
#     Overall SL rate: 0.0235
#     Train SL rate:   0.0233 (diff: 0.0002)
#     Test SL rate:    0.0267 (diff: 0.0032)
#     Train/Test diff: 0.0034
# Stratification OK
#   ROC AUC = 0.9078, Elapsed time = 53.75 seconds
#
# === Model IV Late - Fold 2/50 ===
# Train size = 26403, Test size = 1651
#   [Model IV Late - Fold 2] Stratification Check:
#     Overall SL rate: 0.0248
#     Train SL rate:   0.0252 (diff: 0.0005)
#     Test SL rate:    0.0176 (diff: 0.0072)
#     Train/Test diff: 0.0077
# Stratification OK
#   ROC AUC = 0.8568, Elapsed time = 109.11 seconds
#
# === Model IV Late - Fold 3/50 ===
# Train size = 26371, Test size = 1659
#   [Model IV Late - Fold 3] Stratification Check:
#     Overall SL rate: 0.0227
#     Train SL rate:   0.0222 (diff: 0.0004)
#     Test SL rate:    0.0295 (diff: 0.0069)
#     Train/Test diff: 0.0073
# Stratification OK
#   ROC AUC = 0.9115, Elapsed time = 162.90 seconds
#
# === Model IV Late - Fold 4/50 ===
# Train size = 26358, Test size = 1658
#   [Model IV Late - Fold 4] Stratification Check:
#     Overall SL rate: 0.0216
#     Train SL rate:   0.0209 (diff: 0.0007)
#     Test SL rate:    0.0320 (diff: 0.0104)
#     Train/Test diff: 0.0111
# Stratification OK
#   ROC AUC = 0.8539, Elapsed time = 216.29 seconds
#
# === Model IV Late - Fold 5/50 ===
# Train size = 26465, Test size = 1635
#   [Model IV Late - Fold 5] Stratification Check:
#     Overall SL rate: 0.0245
#     Train SL rate:   0.0249 (diff: 0.0005)
#     Test SL rate:    0.0171 (diff: 0.0074)
#     Train/Test diff: 0.0078
# Stratification OK
#   ROC AUC = 0.9500, Elapsed time = 271.80 seconds
#
# === Model IV Late - Fold 6/50 ===
# Train size = 26421, Test size = 1638
#   [Model IV Late - Fold 6] Stratification Check:
#     Overall SL rate: 0.0232
#     Train SL rate:   0.0235 (diff: 0.0003)
#     Test SL rate:    0.0183 (diff: 0.0049)
#     Train/Test diff: 0.0052
# Stratification OK
#   ROC AUC = 0.8467, Elapsed time = 328.85 seconds
#
# === Model IV Late - Fold 7/50 ===
# Train size = 26410, Test size = 1645
#   [Model IV Late - Fold 7] Stratification Check:
#     Overall SL rate: 0.0237
#     Train SL rate:   0.0242 (diff: 0.0005)
#     Test SL rate:    0.0158 (diff: 0.0079)
#     Train/Test diff: 0.0084
# Stratification OK
#   ROC AUC = 0.9037, Elapsed time = 384.67 seconds
#
# === Model IV Late - Fold 8/50 ===
# Train size = 26386, Test size = 1655
#   [Model IV Late - Fold 8] Stratification Check:
#     Overall SL rate: 0.0238
#     Train SL rate:   0.0244 (diff: 0.0006)
#     Test SL rate:    0.0145 (diff: 0.0093)
#     Train/Test diff: 0.0099
# Stratification OK
#   ROC AUC = 0.8844, Elapsed time = 439.62 seconds
#
# === Model IV Late - Fold 9/50 ===
# Train size = 26375, Test size = 1652
#   [Model IV Late - Fold 9] Stratification Check:
#     Overall SL rate: 0.0206
#     Train SL rate:   0.0196 (diff: 0.0010)
#     Test SL rate:    0.0363 (diff: 0.0157)
#     Train/Test diff: 0.0167
# Stratification OK
#   ROC AUC = 0.8890, Elapsed time = 489.83 seconds
#
# === Model IV Late - Fold 10/50 ===
# Train size = 26384, Test size = 1654
#   [Model IV Late - Fold 10] Stratification Check:
#     Overall SL rate: 0.0236
#     Train SL rate:   0.0238 (diff: 0.0002)
#     Test SL rate:    0.0206 (diff: 0.0030)
#     Train/Test diff: 0.0032
# Stratification OK
#   ROC AUC = 0.8473, Elapsed time = 541.50 seconds
#
# === Model IV Late - Fold 11/50 ===
# Train size = 26364, Test size = 1658
#   [Model IV Late - Fold 11] Stratification Check:
#     Overall SL rate: 0.0233
#     Train SL rate:   0.0230 (diff: 0.0002)
#     Test SL rate:    0.0271 (diff: 0.0039)
#     Train/Test diff: 0.0041
# Stratification OK
#   ROC AUC = 0.9293, Elapsed time = 593.19 seconds
#
# === Model IV Late - Fold 12/50 ===
# Train size = 26384, Test size = 1653
#   [Model IV Late - Fold 12] Stratification Check:
#     Overall SL rate: 0.0248
#     Train SL rate:   0.0255 (diff: 0.0008)
#     Test SL rate:    0.0127 (diff: 0.0120)
#     Train/Test diff: 0.0128
# Stratification OK
#   ROC AUC = 0.9042, Elapsed time = 644.00 seconds
#
# === Model IV Late - Fold 13/50 ===
# Train size = 26414, Test size = 1654
#   [Model IV Late - Fold 13] Stratification Check:
#     Overall SL rate: 0.0258
#     Train SL rate:   0.0264 (diff: 0.0006)
#     Test SL rate:    0.0163 (diff: 0.0095)
#     Train/Test diff: 0.0101
# Stratification OK
#   ROC AUC = 0.8984, Elapsed time = 696.24 seconds
#
# === Model IV Late - Fold 14/50 ===
# Train size = 26402, Test size = 1642
#   [Model IV Late - Fold 14] Stratification Check:
#     Overall SL rate: 0.0220
#     Train SL rate:   0.0213 (diff: 0.0007)
#     Test SL rate:    0.0329 (diff: 0.0109)
#     Train/Test diff: 0.0116
# Stratification OK
#   ROC AUC = 0.8806, Elapsed time = 743.91 seconds
#
# === Model IV Late - Fold 15/50 ===
# Train size = 26416, Test size = 1641
#   [Model IV Late - Fold 15] Stratification Check:
#     Overall SL rate: 0.0208
#     Train SL rate:   0.0201 (diff: 0.0006)
#     Test SL rate:    0.0311 (diff: 0.0103)
#     Train/Test diff: 0.0109
# Stratification OK
#   ROC AUC = 0.8285, Elapsed time = 790.46 seconds
#
# === Model IV Late - Fold 16/50 ===
# Train size = 26365, Test size = 1659
#   [Model IV Late - Fold 16] Stratification Check:
#     Overall SL rate: 0.0226
#     Train SL rate:   0.0224 (diff: 0.0002)
#     Test SL rate:    0.0259 (diff: 0.0033)
#     Train/Test diff: 0.0035
# Stratification OK
#   ROC AUC = 0.7818, Elapsed time = 838.49 seconds
#
# === Model IV Late - Fold 17/50 ===
# Train size = 26380, Test size = 1653
#   [Model IV Late - Fold 17] Stratification Check:
#     Overall SL rate: 0.0222
#     Train SL rate:   0.0221 (diff: 0.0001)
#     Test SL rate:    0.0230 (diff: 0.0008)
#     Train/Test diff: 0.0009
# Stratification OK
#   ROC AUC = 0.8880, Elapsed time = 886.67 seconds
#
# === Model IV Late - Fold 18/50 ===
# Train size = 26416, Test size = 1646
#   [Model IV Late - Fold 18] Stratification Check:
#     Overall SL rate: 0.0251
#     Train SL rate:   0.0259 (diff: 0.0008)
#     Test SL rate:    0.0115 (diff: 0.0135)
#     Train/Test diff: 0.0144
# Stratification OK
#   ROC AUC = 0.8907, Elapsed time = 939.54 seconds
#
# === Model IV Late - Fold 19/50 ===
# Train size = 26403, Test size = 1644
#   [Model IV Late - Fold 19] Stratification Check:
#     Overall SL rate: 0.0208
#     Train SL rate:   0.0201 (diff: 0.0007)
#     Test SL rate:    0.0322 (diff: 0.0115)
#     Train/Test diff: 0.0122
# Stratification OK
#   ROC AUC = 0.9040, Elapsed time = 989.14 seconds
#
# === Model IV Late - Fold 20/50 ===
# Train size = 26420, Test size = 1650
#   [Model IV Late - Fold 20] Stratification Check:
#     Overall SL rate: 0.0245
#     Train SL rate:   0.0251 (diff: 0.0006)
#     Test SL rate:    0.0152 (diff: 0.0094)
#     Train/Test diff: 0.0099
# Stratification OK
#   ROC AUC = 0.8720, Elapsed time = 1045.08 seconds
#
# === Model IV Late - Fold 21/50 ===
# Train size = 26388, Test size = 1649
#   [Model IV Late - Fold 21] Stratification Check:
#     Overall SL rate: 0.0234
#     Train SL rate:   0.0233 (diff: 0.0001)
#     Test SL rate:    0.0243 (diff: 0.0009)
#     Train/Test diff: 0.0010
# Stratification OK
#   ROC AUC = 0.9273, Elapsed time = 1100.66 seconds
#
# === Model IV Late - Fold 22/50 ===
# Train size = 26371, Test size = 1657
#   [Model IV Late - Fold 22] Stratification Check:
#     Overall SL rate: 0.0225
#     Train SL rate:   0.0226 (diff: 0.0001)
#     Test SL rate:    0.0205 (diff: 0.0020)
#     Train/Test diff: 0.0021
# Stratification OK
#   ROC AUC = 0.8857, Elapsed time = 1155.86 seconds
#
# === Model IV Late - Fold 23/50 ===
# Train size = 26471, Test size = 1630
#   [Model IV Late - Fold 23] Stratification Check:
#     Overall SL rate: 0.0249
#     Train SL rate:   0.0255 (diff: 0.0006)
#     Test SL rate:    0.0147 (diff: 0.0102)
#     Train/Test diff: 0.0108
# Stratification OK
#   ROC AUC = 0.9034, Elapsed time = 1211.81 seconds
#
# === Model IV Late - Fold 24/50 ===
# Train size = 26377, Test size = 1656
#   [Model IV Late - Fold 24] Stratification Check:
#     Overall SL rate: 0.0219
#     Train SL rate:   0.0214 (diff: 0.0005)
#     Test SL rate:    0.0302 (diff: 0.0083)
#     Train/Test diff: 0.0088
# Stratification OK
#   ROC AUC = 0.8076, Elapsed time = 1261.83 seconds
#
# === Model IV Late - Fold 25/50 ===
# Train size = 26371, Test size = 1654
#   [Model IV Late - Fold 25] Stratification Check:
#     Overall SL rate: 0.0227
#     Train SL rate:   0.0229 (diff: 0.0002)
#     Test SL rate:    0.0200 (diff: 0.0028)
#     Train/Test diff: 0.0030
# Stratification OK
#   ROC AUC = 0.9243, Elapsed time = 1316.09 seconds
#
# === Model IV Late - Fold 26/50 ===
# Train size = 26367, Test size = 1659
#   [Model IV Late - Fold 26] Stratification Check:
#     Overall SL rate: 0.0238
#     Train SL rate:   0.0239 (diff: 0.0001)
#     Test SL rate:    0.0217 (diff: 0.0021)
#     Train/Test diff: 0.0022
# Stratification OK
#   ROC AUC = 0.8782, Elapsed time = 1370.76 seconds
#
# === Model IV Late - Fold 27/50 ===
# Train size = 26365, Test size = 1656
#   [Model IV Late - Fold 27] Stratification Check:
#     Overall SL rate: 0.0217
#     Train SL rate:   0.0207 (diff: 0.0010)
#     Test SL rate:    0.0374 (diff: 0.0158)
#     Train/Test diff: 0.0168
# Stratification OK
#   ROC AUC = 0.8099, Elapsed time = 1421.43 seconds
#
# === Model IV Late - Fold 28/50 ===
# Train size = 26423, Test size = 1645
#   [Model IV Late - Fold 28] Stratification Check:
#     Overall SL rate: 0.0222
#     Train SL rate:   0.0220 (diff: 0.0002)
#     Test SL rate:    0.0249 (diff: 0.0027)
#     Train/Test diff: 0.0029
# Stratification OK
#   ROC AUC = 0.8798, Elapsed time = 1476.85 seconds
#
# === Model IV Late - Fold 29/50 ===
# Train size = 26395, Test size = 1652
#   [Model IV Late - Fold 29] Stratification Check:
#     Overall SL rate: 0.0253
#     Train SL rate:   0.0262 (diff: 0.0009)
#     Test SL rate:    0.0103 (diff: 0.0150)
#     Train/Test diff: 0.0159
# Stratification OK
#   ROC AUC = 0.8902, Elapsed time = 1533.65 seconds
#
# === Model IV Late - Fold 30/50 ===
# Train size = 26435, Test size = 1641
#   [Model IV Late - Fold 30] Stratification Check:
#     Overall SL rate: 0.0235
#     Train SL rate:   0.0235 (diff: 0.0000)
#     Test SL rate:    0.0238 (diff: 0.0003)
#     Train/Test diff: 0.0003
# Stratification OK
#   ROC AUC = 0.9305, Elapsed time = 1588.99 seconds
#
# === Model IV Late - Fold 31/50 ===
# Train size = 26376, Test size = 1653
#   [Model IV Late - Fold 31] Stratification Check:
#     Overall SL rate: 0.0213
#     Train SL rate:   0.0207 (diff: 0.0006)
#     Test SL rate:    0.0302 (diff: 0.0090)
#     Train/Test diff: 0.0095
# Stratification OK
#   ROC AUC = 0.9051, Elapsed time = 1643.28 seconds
#
# === Model IV Late - Fold 32/50 ===
# Train size = 26409, Test size = 1648
#   [Model IV Late - Fold 32] Stratification Check:
#     Overall SL rate: 0.0261
#     Train SL rate:   0.0270 (diff: 0.0009)
#     Test SL rate:    0.0121 (diff: 0.0140)
#     Train/Test diff: 0.0148
# Stratification OK
#   ROC AUC = 0.9593, Elapsed time = 1698.66 seconds
#
# === Model IV Late - Fold 33/50 ===
# Train size = 26364, Test size = 1653
#   [Model IV Late - Fold 33] Stratification Check:
#     Overall SL rate: 0.0235
#     Train SL rate:   0.0234 (diff: 0.0000)
#     Test SL rate:    0.0242 (diff: 0.0007)
#     Train/Test diff: 0.0008
# Stratification OK
#   ROC AUC = 0.8787, Elapsed time = 1756.80 seconds
#
# === Model IV Late - Fold 34/50 ===
# Train size = 26394, Test size = 1655
#   [Model IV Late - Fold 34] Stratification Check:
#     Overall SL rate: 0.0215
#     Train SL rate:   0.0207 (diff: 0.0007)
#     Test SL rate:    0.0332 (diff: 0.0118)
#     Train/Test diff: 0.0125
# Stratification OK
#   ROC AUC = 0.8362, Elapsed time = 1806.19 seconds
#
# === Model IV Late - Fold 35/50 ===
# Train size = 26435, Test size = 1637
#   [Model IV Late - Fold 35] Stratification Check:
#     Overall SL rate: 0.0245
#     Train SL rate:   0.0247 (diff: 0.0002)
#     Test SL rate:    0.0214 (diff: 0.0031)
#     Train/Test diff: 0.0033
# Stratification OK
#   ROC AUC = 0.9044, Elapsed time = 1860.58 seconds
#
# === Model IV Late - Fold 36/50 ===
# Train size = 26381, Test size = 1657
#   [Model IV Late - Fold 36] Stratification Check:
#     Overall SL rate: 0.0260
#     Train SL rate:   0.0264 (diff: 0.0004)
#     Test SL rate:    0.0199 (diff: 0.0061)
#     Train/Test diff: 0.0065
# Stratification OK
#   ROC AUC = 0.9219, Elapsed time = 1917.20 seconds
#
# === Model IV Late - Fold 37/50 ===
# Train size = 26416, Test size = 1646
#   [Model IV Late - Fold 37] Stratification Check:
#     Overall SL rate: 0.0234
#     Train SL rate:   0.0232 (diff: 0.0002)
#     Test SL rate:    0.0267 (diff: 0.0034)
#     Train/Test diff: 0.0036
# Stratification OK
#   ROC AUC = 0.8396, Elapsed time = 1971.38 seconds
#
# === Model IV Late - Fold 38/50 ===
# Train size = 26367, Test size = 1655
#   [Model IV Late - Fold 38] Stratification Check:
#     Overall SL rate: 0.0227
#     Train SL rate:   0.0226 (diff: 0.0001)
#     Test SL rate:    0.0248 (diff: 0.0021)
#     Train/Test diff: 0.0022
# Stratification OK
#   ROC AUC = 0.9370, Elapsed time = 2028.49 seconds
#
# === Model IV Late - Fold 39/50 ===
# Train size = 26422, Test size = 1645
#   [Model IV Late - Fold 39] Stratification Check:
#     Overall SL rate: 0.0228
#     Train SL rate:   0.0228 (diff: 0.0000)
#     Test SL rate:    0.0231 (diff: 0.0003)
#     Train/Test diff: 0.0003
# Stratification OK
#   ROC AUC = 0.8612, Elapsed time = 2082.39 seconds
#
# === Model IV Late - Fold 40/50 ===
# Train size = 26400, Test size = 1651
#   [Model IV Late - Fold 40] Stratification Check:
#     Overall SL rate: 0.0226
#     Train SL rate:   0.0219 (diff: 0.0007)
#     Test SL rate:    0.0333 (diff: 0.0107)
#     Train/Test diff: 0.0114
# Stratification OK
#   ROC AUC = 0.8742, Elapsed time = 2136.74 seconds
#
# === Model IV Late - Fold 41/50 ===
# Train size = 26359, Test size = 1651
#   [Model IV Late - Fold 41] Stratification Check:
#     Overall SL rate: 0.0215
#     Train SL rate:   0.0208 (diff: 0.0008)
#     Test SL rate:    0.0339 (diff: 0.0124)
#     Train/Test diff: 0.0132
# Stratification OK
#   ROC AUC = 0.8385, Elapsed time = 2190.69 seconds
#
# === Model IV Late - Fold 42/50 ===
# Train size = 26400, Test size = 1647
#   [Model IV Late - Fold 42] Stratification Check:
#     Overall SL rate: 0.0267
#     Train SL rate:   0.0279 (diff: 0.0012)
#     Test SL rate:    0.0073 (diff: 0.0194)
#     Train/Test diff: 0.0206
# Stratification OK
#   ROC AUC = 0.9615, Elapsed time = 2247.38 seconds
#
# === Model IV Late - Fold 43/50 ===
# Train size = 26370, Test size = 1660
#   [Model IV Late - Fold 43] Stratification Check:
#     Overall SL rate: 0.0214
#     Train SL rate:   0.0203 (diff: 0.0011)
#     Test SL rate:    0.0386 (diff: 0.0171)
#     Train/Test diff: 0.0182
# Stratification OK
#   ROC AUC = 0.8179, Elapsed time = 2298.32 seconds
#
# === Model IV Late - Fold 44/50 ===
# Train size = 26439, Test size = 1633
#   [Model IV Late - Fold 44] Stratification Check:
#     Overall SL rate: 0.0227
#     Train SL rate:   0.0224 (diff: 0.0003)
#     Test SL rate:    0.0282 (diff: 0.0054)
#     Train/Test diff: 0.0058
# Stratification OK
#   ROC AUC = 0.8951, Elapsed time = 2352.81 seconds
#
# === Model IV Late - Fold 45/50 ===
# Train size = 26401, Test size = 1646
#   [Model IV Late - Fold 45] Stratification Check:
#     Overall SL rate: 0.0244
#     Train SL rate:   0.0251 (diff: 0.0007)
#     Test SL rate:    0.0134 (diff: 0.0111)
#     Train/Test diff: 0.0117
# Stratification OK
#   ROC AUC = 0.8645, Elapsed time = 2405.57 seconds
#
# === Model IV Late - Fold 46/50 ===
# Train size = 26401, Test size = 1647
#   [Model IV Late - Fold 46] Stratification Check:
#     Overall SL rate: 0.0222
#     Train SL rate:   0.0217 (diff: 0.0005)
#     Test SL rate:    0.0298 (diff: 0.0076)
#     Train/Test diff: 0.0080
# Stratification OK
#   ROC AUC = 0.8118, Elapsed time = 2455.64 seconds
#
# === Model IV Late - Fold 47/50 ===
# Train size = 26427, Test size = 1645
#   [Model IV Late - Fold 47] Stratification Check:
#     Overall SL rate: 0.0247
#     Train SL rate:   0.0256 (diff: 0.0010)
#     Test SL rate:    0.0091 (diff: 0.0155)
#     Train/Test diff: 0.0165
# Stratification OK
#   ROC AUC = 0.9255, Elapsed time = 2510.57 seconds
#
# === Model IV Late - Fold 48/50 ===
# Train size = 26373, Test size = 1653
#   [Model IV Late - Fold 48] Stratification Check:
#     Overall SL rate: 0.0215
#     Train SL rate:   0.0206 (diff: 0.0009)
#     Test SL rate:    0.0363 (diff: 0.0148)
#     Train/Test diff: 0.0157
# Stratification OK
#   ROC AUC = 0.9237, Elapsed time = 2565.14 seconds
#
# === Model IV Late - Fold 49/50 ===
# Train size = 26394, Test size = 1648
#   [Model IV Late - Fold 49] Stratification Check:
#     Overall SL rate: 0.0239
#     Train SL rate:   0.0243 (diff: 0.0004)
#     Test SL rate:    0.0176 (diff: 0.0063)
#     Train/Test diff: 0.0067
# Stratification OK
#   ROC AUC = 0.8957, Elapsed time = 2620.76 seconds
#
# === Model IV Late - Fold 50/50 ===
# Train size = 26385, Test size = 1655
#   [Model IV Late - Fold 50] Stratification Check:
#     Overall SL rate: 0.0235
#     Train SL rate:   0.0237 (diff: 0.0002)
#     Test SL rate:    0.0199 (diff: 0.0036)
#     Train/Test diff: 0.0038
# Stratification OK
#   ROC AUC = 0.9005, Elapsed time = 2679.10 seconds
#
# === Model IV Late Summary ===
# Mean ROC AUC = 0.8842 ± 0.0406
# Successful folds: 50/50
# Stratification quality:
# Mean train deviation: 0.0005 ± 0.0003
# Mean test deviation: 0.0079 ± 0.0050

# %%
# save results of cross validation
with open(file_RF_model_IV_early, 'wb') as f:
    pickle.dump(model_IV_early, f)

with open(file_RF_model_IV_late, 'wb') as f:
    pickle.dump(model_IV_late, f)

# %%
def generate_validation_report(model_results, model_name):
    """Generate a comprehensive validation report for a model."""
    print(f"\n{'='*50}")
    print(f"VALIDATION REPORT: {model_name}")
    print(f"{'='*50}")
    
    # Performance summary
    print(f"Performance:")
    print(f"  Mean ROC AUC: {model_results['mean_auc']:.4f} ± {model_results['std_auc']:.4f}")
    print(f"  Mean PR AUC:  {model_results['mean_aps']:.4f} ± {model_results['std_ap']:.4f}")
    print(f"  Effective folds: {model_results['effective_folds']}")
    
    if 'skipped_folds' in model_results and model_results['skipped_folds']:
        print(f"  Skipped folds: {model_results['skipped_folds']}")
    
    # Stratification summary
    if 'stratification_results' in model_results:
        strat_results = model_results['stratification_results']
        if strat_results:
            train_diffs = [r['train_diff'] for r in strat_results]
            test_diffs = [r['test_diff'] for r in strat_results]
            warnings_count = sum(len(r['warnings']) for r in strat_results)
            
            print(f"\nStratification Quality:")
            print(f"  Mean train deviation: {np.mean(train_diffs):.4f} ± {np.std(train_diffs):.4f}")
            print(f"  Mean test deviation:  {np.mean(test_diffs):.4f} ± {np.std(test_diffs):.4f}")
            print(f"  Total warnings: {warnings_count}")
            
            if warnings_count > 0:
                print(f"Some folds had stratification issues")
            else:
                print(f"All folds passed stratification checks")

# Generate reports for all models
all_models = [
    (model_I_early, "Model I Early"),
    (model_I_late, "Model I Late"),
    (model_II_early, "Model II Early"),
    (model_II_late, "Model II Late"),
    (model_III_early, "Model III Early"),
    (model_III_late, "Model III Late"),
    (model_IV_early, "Model IV Early"),
    (model_IV_late, "Model IV Late")
]

for model_result, model_name in all_models:
    generate_validation_report(model_result, model_name)
# Out:
# ==================================================
# VALIDATION REPORT: Model I Early
# ==================================================
# Performance:
#   Mean ROC AUC: 0.9177 ± 0.0077
#   Mean PR AUC:  0.3481 ± 0.0233
#   Effective folds: 5
#
# Stratification Quality:
#   Mean train deviation: 0.0000 ± 0.0000
#   Mean test deviation:  0.0001 ± 0.0000
#   Total warnings: 0
# All folds passed stratification checks
#
# ==================================================
# VALIDATION REPORT: Model I Late
# ==================================================
# Performance:
#   Mean ROC AUC: 0.9310 ± 0.0074
#   Mean PR AUC:  0.4062 ± 0.0192
#   Effective folds: 5
#
# Stratification Quality:
#   Mean train deviation: 0.0000 ± 0.0000
#   Mean test deviation:  0.0001 ± 0.0000
#   Total warnings: 0
# All folds passed stratification checks
#
# ==================================================
# VALIDATION REPORT: Model II Early
# ==================================================
# Performance:
#   Mean ROC AUC: 0.8999 ± 0.0367
#   Mean PR AUC:  0.2924 ± 0.0756
#   Effective folds: 5
#
# Stratification Quality:
#   Mean train deviation: 0.0015 ± 0.0011
#   Mean test deviation:  0.0059 ± 0.0045
#   Total warnings: 0
# All folds passed stratification checks
#
# ==================================================
# VALIDATION REPORT: Model II Late
# ==================================================
# Performance:
#   Mean ROC AUC: 0.9182 ± 0.0339
#   Mean PR AUC:  0.3502 ± 0.0788
#   Effective folds: 5
#
# Stratification Quality:
#   Mean train deviation: 0.0015 ± 0.0011
#   Mean test deviation:  0.0059 ± 0.0045
#   Total warnings: 0
# All folds passed stratification checks
#
# ==================================================
# VALIDATION REPORT: Model III Early
# ==================================================
# Performance:
#   Mean ROC AUC: 0.9053 ± 0.0151
#   Mean PR AUC:  0.3105 ± 0.0160
#   Effective folds: 5
#
# Stratification Quality:
#   Mean train deviation: 0.0004 ± 0.0003
#   Mean test deviation:  0.0017 ± 0.0012
#   Total warnings: 0
# All folds passed stratification checks
#
# ==================================================
# VALIDATION REPORT: Model III Late
# ==================================================
# Performance:
#   Mean ROC AUC: 0.9076 ± 0.0145
#   Mean PR AUC:  0.3302 ± 0.0072
#   Effective folds: 5
#
# Stratification Quality:
#   Mean train deviation: 0.0004 ± 0.0003
#   Mean test deviation:  0.0017 ± 0.0012
#   Total warnings: 0
# All folds passed stratification checks
#
# ==================================================
# VALIDATION REPORT: Model IV Early
# ==================================================
# Performance:
#   Mean ROC AUC: 0.8741 ± 0.0402
#   Mean PR AUC:  0.2200 ± 0.0812
#   Effective folds: 50
#
# Stratification Quality:
#   Mean train deviation: 0.0005 ± 0.0003
#   Mean test deviation:  0.0079 ± 0.0050
#   Total warnings: 0
# All folds passed stratification checks
#
# ==================================================
# VALIDATION REPORT: Model IV Late
# ==================================================
# Performance:
#   Mean ROC AUC: 0.8842 ± 0.0406
#   Mean PR AUC:  0.2337 ± 0.0783
#   Effective folds: 50
#
# Stratification Quality:
#   Mean train deviation: 0.0005 ± 0.0003
#   Mean test deviation:  0.0079 ± 0.0050
#   Total warnings: 0
# All folds passed stratification checks
