# %% [markdown]
# # Random Forest Classification via cross-validation

# %%
# import modules
import os
import pandas as pd
import numpy as np
import random
import pickle

# import scikit-learn modules
from sklearn.model_selection import StratifiedKFold, StratifiedGroupKFold, RepeatedStratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import RocCurveDisplay, PrecisionRecallDisplay, roc_auc_score, average_precision_score, precision_recall_curve, auc, roc_curve

import time

# %%
cwd = os.getcwd()
BASE_DIR = os.path.abspath(os.path.join(cwd, "..", ".."))

# build paths inside the repo
get_data_path = lambda folders, fname: os.path.normpath(
    os.path.join(BASE_DIR, *folders, fname)
)

file_path_training_data = get_data_path(['data', 'output', 'models'], 'training_data.csv')

file_RF_model_I_contextualized = get_data_path(['data', 'output', 'models', 'model_I'], 'RF_model_contextualized.pickle')
file_RF_model_I_full = get_data_path(['data', 'output', 'models', 'model_I'], 'RF_model_full.pickle')
file_RF_model_I_contextualized_repeated = get_data_path(['data', 'output', 'models', 'model_I'], 'RF_model_contextualized_repeated.pickle')
file_RF_model_I_full_repeated = get_data_path(['data', 'output', 'models', 'model_I'], 'RF_model_full_repeated.pickle')

file_RF_model_II_contextualized = get_data_path(['data', 'output', 'models', 'model_II'], 'RF_model_contextualized.pickle')
file_RF_model_II_full = get_data_path(['data', 'output', 'models', 'model_II'], 'RF_model_full.pickle')
file_RF_model_II_contextualized_repeated = get_data_path(['data', 'output', 'models', 'model_II'], 'RF_model_contextualized_repeated.pickle')
file_RF_model_II_full_repeated = get_data_path(['data', 'output', 'models', 'model_II'], 'RF_model_full_repeated.pickle')

file_RF_model_III_contextualized = get_data_path(['data', 'output', 'models', 'model_III'], 'RF_model_contextualized.pickle')
file_RF_model_III_full = get_data_path(['data', 'output', 'models', 'model_III'], 'RF_model_full.pickle')
file_RF_model_III_contextualized_repeated = get_data_path(['data', 'output', 'models', 'model_III'], 'RF_model_contextualized_repeated.pickle')
file_RF_model_III_full_repeated = get_data_path(['data', 'output', 'models', 'model_III'], 'RF_model_full_repeated.pickle')

file_RF_model_IV_contextualized = get_data_path(['data', 'output', 'models', 'model_IV'], 'RF_model_contextualized.pickle')
file_RF_model_IV_full = get_data_path(['data', 'output', 'models', 'model_IV'], 'RF_model_full.pickle')

# %%
training_df = pd.read_csv(file_path_training_data)
training_df.head()
# Out:
#       genepair       A1   A2  A1_entrez  A2_entrez   DepMap_ID  \
# 0  A3GALT2_ABO  A3GALT2  ABO   127550.0       28.0  ACH-000022
# 1  A3GALT2_ABO  A3GALT2  ABO   127550.0       28.0  ACH-000307
# 2  A3GALT2_ABO  A3GALT2  ABO   127550.0       28.0  ACH-000632
# 3  A3GALT2_ABO  A3GALT2  ABO   127550.0       28.0  ACH-000681
# 4  A3GALT2_ABO  A3GALT2  ABO   127550.0       28.0  ACH-000756
#
#                     cell_line  Gemini_FDR   raw_LFC     SL  ...  \
# 0          PATU8988S_PANCREAS    0.998944  0.088856  False  ...
# 1                PK1_PANCREAS    0.986587  0.201704  False  ...
# 2                 HS944T_SKIN    1.000000  0.069772  False  ...
# 3                   A549_LUNG    0.977988  0.379455  False  ...
# 4  GI1_CENTRAL_NERVOUS_SYSTEM    0.999586 -0.077118  False  ...
#
#   colocalisation interact  n_total_ppi  fet_ppi_overlap  gtex_spearman_corr  \
# 0            0.0    False          3.0              0.0            0.114847
# 1            0.0    False          3.0              0.0            0.114847
# 2            0.0    False          3.0              0.0            0.114847
# 3            0.0    False          3.0              0.0            0.114847
# 4            0.0    False          3.0              0.0            0.114847
#
#    gtex_min_mean_expr  gtex_max_mean_expr    GEMINI       LFC  SL_new
# 0            0.258739              11.702  0.118768  0.088856   False
# 1            0.258739              11.702  0.132501  0.201704   False
# 2            0.258739              11.702  0.024593  0.069772   False
# 3            0.258739              11.702 -0.241323  0.379455   False
# 4            0.258739              11.702  0.299715 -0.077118   False
#
# [5 rows x 83 columns]

# %%
feature_columns_1 = ['rMaxExp_A1A2', 'rMinExp_A1A2',
                     'max_ranked_A1A2', 'min_ranked_A1A2',
                     'max_cn', 'min_cn', 'Protein_Altering', 'Damaging', 
                     'min_sequence_identity',
                     'prediction_score', 
                     'weighted_PPI_essentiality', 'weighted_PPI_expression',
                     'smallest_BP_GO_essentiality', 'smallest_CC_GO_essentiality',
                     'smallest_BP_GO_expression', 'go_CC_expression'
                     ]

target_column = 'SL_new'

print('num of features:', len(feature_columns_1))
# Out:
# num of features: 16

# %%
feature_columns_2 = feature_columns_1 + ['closest', 'WGD', 'family_size',
                                         'cds_length_ratio', 'shared_domains', 'has_pombe_ortholog',
                                         'has_essential_pombe_ortholog', 'has_cerevisiae_ortholog', 'has_essential_cerevisiae_ortholog', 
                                         'conservation_score', 'mean_age', 'either_in_complex', 'mean_complex_essentiality', 'colocalisation',
                                         'interact', 'n_total_ppi', 'fet_ppi_overlap',
                                         'gtex_spearman_corr', 'gtex_min_mean_expr', 'gtex_max_mean_expr']
feature_columns_2.remove('prediction_score')
print('num of features:', len(feature_columns_2))
# Out:
# num of features: 35

# %% [markdown]
# ### Model I - Random Selection

# %%
def safe_roc_auc(y_true, y_score):
    mask = ~np.isnan(y_score)
    if np.sum(mask) < 2 or len(np.unique(y_true[mask])) < 2:
        return np.nan
    return roc_auc_score(y_true[mask], y_score[mask])

def safe_average_precision(y_true, y_score):
    mask = ~np.isnan(y_score)
    if np.sum(mask) == 0:
        return np.nan
    return average_precision_score(y_true[mask], y_score[mask])

# %%
def validate_stratification(y_train, y_test, fold_num, model_name, tolerance=0.05):
    """
    Validate that stratification is working correctly across train/test splits.
    
    Parameters:
    - y_train, y_test: target arrays for train and test sets
    - fold_num: current fold number
    - model_name: name of the model for logging
    - tolerance: acceptable difference in class proportions (default 5%)
    """
    # Calculate class proportions
    train_pos_rate = y_train.mean()
    test_pos_rate = y_test.mean()
    overall_pos_rate = np.concatenate([y_train, y_test]).mean()
    
    # Calculate differences from overall rate
    train_diff = abs(train_pos_rate - overall_pos_rate)
    test_diff = abs(test_pos_rate - overall_pos_rate)
    train_test_diff = abs(train_pos_rate - test_pos_rate)
    
    # Print detailed information
    print(f"  [{model_name} - Fold {fold_num}] Stratification Check:")
    print(f"    Overall SL rate: {overall_pos_rate:.4f}")
    print(f"    Train SL rate:   {train_pos_rate:.4f} (diff: {train_diff:.4f})")
    print(f"    Test SL rate:    {test_pos_rate:.4f} (diff: {test_diff:.4f})")
    print(f"    Train/Test diff: {train_test_diff:.4f}")
    
    # Check for violations
    warnings = []
    if train_diff > tolerance:
        warnings.append(f"Train set deviation ({train_diff:.4f}) exceeds tolerance ({tolerance})")
    if test_diff > tolerance:
        warnings.append(f"Test set deviation ({test_diff:.4f}) exceeds tolerance ({tolerance})")
    if train_test_diff > tolerance:
        warnings.append(f"Train/Test difference ({train_test_diff:.4f}) exceeds tolerance ({tolerance})")
    
    if warnings:
        print(f"WARNINGS:")
        for warning in warnings:
            print(f"      - {warning}")
    else:
        print(f"Stratification OK")
    
    return {
        'train_pos_rate': train_pos_rate,
        'test_pos_rate': test_pos_rate,
        'overall_pos_rate': overall_pos_rate,
        'train_diff': train_diff,
        'test_diff': test_diff,
        'train_test_diff': train_test_diff,
        'warnings': warnings
    }

def validate_group_splits(train_groups, test_groups, fold_num, model_name, group_type="groups"):
    """
    Validate that groups don't leak between train and test sets.
    """
    train_set = set(train_groups)
    test_set = set(test_groups)
    overlap = train_set & test_set
    
    print(f"  [{model_name} - Fold {fold_num}] Group Validation:")
    print(f"    Train {group_type}: {len(train_set)}")
    print(f"    Test {group_type}:  {len(test_set)}")
    print(f"    Overlapping {group_type}: {len(overlap)}")
    
    if len(overlap) > 0:
        print(f"GROUP LEAKAGE DETECTED: {overlap}")
        return False
    else:
        print(f"No group leakage")
        return True

# %%
def model_contextualized_cross_validation(classifier, data, target, splits, verbose=True, model_name="Model"):
    tprs = []
    fprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    pred_aucs, seq_aucs, gene_expr_aucs, gene_ess_aucs = [], [], [], []
    aps, pred_aps, seq_aps, gene_expr_aps, gene_ess_aps = [], [], [], [], []

    y_real = []
    y_proba = []

    stratification_results = []
    skipped_folds = []

    total_splits = len(splits)
    start_time = time.time()

    for fold_num, (train, test) in enumerate(splits, start=1):
        print(f"Fold {fold_num}: Train size = {len(train)}, Test size = {len(test)}")

        #print(f"\n=== {model_name} - Fold {fold_num}/{total_splits} ===")
        #print(f"Train size = {len(train)}, Test size = {len(test)}")

        if len(test) == 0:
            print(f"Skipping fold {fold_num}: Empty test set")
            skipped_folds.append(fold_num)
            continue

        # Get train/test data
        y_train = target.iloc[train].values
        y_test = target.iloc[test].values

        # validate stratification
        stratification_result = validate_stratification(y_train, y_test, fold_num, model_name)
        stratification_results.append(stratification_result)

        if np.unique(y_test).size < 2:
            print(f"Skipping fold {fold_num}: Insufficient positive/negative samples in test set")
            print(f"Test set classes: {np.unique(y_test)}")
            skipped_folds.append(fold_num)
            continue

        # Train the classifier and predict probabilities
        y_pred_proba = classifier.fit(data.iloc[train], target.iloc[train]).predict_proba(data.iloc[test])[:, 1]

        fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
        tprs.append(tpr)
        fprs.append(fpr)

        aucs.append(roc_auc_score(y_test, y_pred_proba))
        aps.append(average_precision_score(y_test, y_pred_proba))

        # Scores from input data columns
        pred_aucs.append(safe_roc_auc(y_test, data.iloc[test]['prediction_score'].values))
        seq_aucs.append(safe_roc_auc(y_test, data.iloc[test]['min_sequence_identity'].values))
        gene_expr_aucs.append(safe_roc_auc(y_test, data.iloc[test]['rMinExp_A1A2'].values))
        gene_ess_aucs.append(1 - safe_roc_auc(y_test, data.iloc[test]['min_ranked_A1A2'].values))

        pred_aps.append(safe_average_precision(y_test, data.iloc[test]['prediction_score'].values))
        seq_aps.append(safe_average_precision(y_test, data.iloc[test]['min_sequence_identity'].values))
        gene_expr_aps.append(safe_average_precision(y_test, data.iloc[test]['rMinExp_A1A2'].values))
        gene_ess_aps.append(safe_average_precision(y_test, data.iloc[test]['min_ranked_A1A2'].values))

        y_real.append(y_test)
        y_proba.append(y_pred_proba)

        if verbose:
            elapsed_time = time.time() - start_time
            print(f"  ROC AUC = {aucs[-1]:.4f}, Elapsed time = {elapsed_time:.2f} seconds")

    if len(tprs) > 0:
        mean_tpr = np.mean([np.interp(mean_fpr, fprs[i], tprs[i]) for i in range(len(tprs))], axis=0)
        mean_tpr[-1] = 1.0
        mean_auc = auc(mean_fpr, mean_tpr)
        std_auc = np.std(aucs)
    else:
        mean_tpr, mean_auc, std_auc = np.array([]), np.nan, np.nan

    if len(y_real) > 0 and len(y_proba) > 0:
        y_real = np.concatenate(y_real)
        y_proba = np.concatenate(y_proba)
        precision, recall, _ = precision_recall_curve(y_real, y_proba)
    else:
        precision, recall = np.array([]), np.array([])

    # Print summary
    print(f"\n=== {model_name} Summary ===")
    if not np.isnan(mean_auc):
        print(f"Mean ROC AUC = {mean_auc:.4f} ± {std_auc:.4f}")
    print(f"Successful folds: {len(aucs)}/{total_splits}")
    if skipped_folds:
        print(f"Skipped folds: {skipped_folds}")

    # Stratification summary
    if stratification_results:
        train_diffs = [r['train_diff'] for r in stratification_results]
        test_diffs = [r['test_diff'] for r in stratification_results]
        print(f"Stratification quality:")
        print(f"  Mean train deviation: {np.mean(train_diffs):.4f} ± {np.std(train_diffs):.4f}")
        print(f"  Mean test deviation:  {np.mean(test_diffs):.4f} ± {np.std(test_diffs):.4f}")


    return {
        'tprs': tprs, 'fprs': fprs, 'aucs': aucs,
        'mean_tpr': mean_tpr, 'mean_fpr': mean_fpr, 'mean_auc': mean_auc, 'std_auc': std_auc,
        'seq_auc': np.nanmean(seq_aucs), 'seq_std_auc': np.nanstd(seq_aucs),
        'pred_auc': np.nanmean(pred_aucs), 'pred_std_auc': np.nanstd(pred_aucs),
        'gene_expr_auc': np.nanmean(gene_expr_aucs), 'gene_expr_std_auc': np.nanstd(gene_expr_aucs),
        'gene_ess_auc': np.nanmean(gene_ess_aucs), 'gene_ess_std_auc': np.nanstd(gene_ess_aucs),
        'precision': precision, 'recall': recall, 'aps': aps,
        'mean_aps': np.nanmean(aps), 'std_ap': np.nanstd(aps),
        'pred_ap': np.nanmean(pred_aps), 'pred_std_ap': np.nanstd(pred_aps),
        'seq_ap': np.nanmean(seq_aps), 'seq_std_ap': np.nanstd(seq_aps),
        'gene_expr_ap': np.nanmean(gene_expr_aps), 'gene_expr_std_ap': np.nanstd(gene_expr_aps),
        'gene_ess_ap': np.nanmean(gene_ess_aps), 'gene_ess_std_ap': np.nanstd(gene_ess_aps),
        'stratification_results': stratification_results,
        'skipped_folds': skipped_folds,
        'effective_folds': len(aucs)
    }

# %%
def model_full_cross_validation(classifier, data, target, splits, verbose=True, model_name="Model"):
    tprs = []
    fprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)
    
    y_real = []
    y_proba = []
    aps = []

    # Track stratification validation results
    stratification_results = []
    skipped_folds = []
    
    total_splits = len(splits)
    start_time = time.time()

    for fold_num, (train, test) in enumerate(splits, start=1):
        print(f"\n=== {model_name} - Fold {fold_num}/{total_splits} ===")
        print(f"Train size = {len(train)}, Test size = {len(test)}")
        
        if len(test) == 0:
            print(f"Skipping fold {fold_num}: Empty test set")
            skipped_folds.append(fold_num)
            continue

        # Get train/test data
        y_train = target.iloc[train].values
        y_test = target.iloc[test].values

        # Validate stratification
        stratification_result = validate_stratification(y_train, y_test, fold_num, model_name)
        stratification_results.append(stratification_result)

        if np.unique(y_test).size < 2:
            print(f"Skipping fold {fold_num}: Insufficient positive/negative samples in test set")
            print(f"Test set classes: {np.unique(y_test)}")
            skipped_folds.append(fold_num)
            continue

        # Train model and get predictions
        y_pred_proba = classifier.fit(data.iloc[train], target.iloc[train]).predict_proba(data.iloc[test])[:, 1]

        fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
        tprs.append(tpr)
        fprs.append(fpr)

        aucs.append(safe_roc_auc(y_test, y_pred_proba))
        aps.append(safe_average_precision(y_test, y_pred_proba))

        y_real.append(y_test)
        y_proba.append(y_pred_proba)

        if verbose:
            elapsed_time = time.time() - start_time
            print(f"  ROC AUC = {aucs[-1]:.4f}, Elapsed time = {elapsed_time:.2f} seconds")
    
    if len(tprs) > 0:
        mean_tpr = np.mean([np.interp(mean_fpr, fprs[i], tprs[i]) for i in range(len(tprs))], axis=0)
        mean_tpr[-1] = 1.0
        mean_auc = auc(mean_fpr, mean_tpr)
        std_auc = np.std(aucs)
    else:
        mean_tpr, mean_auc, std_auc = np.array([]), np.nan, np.nan
    
    if len(y_real) > 0 and len(y_proba) > 0:
        y_real = np.concatenate(y_real)
        y_proba = np.concatenate(y_proba)
        precision, recall, _ = precision_recall_curve(y_real, y_proba)
    else:
        precision, recall = np.array([]), np.array([])

    # Print summary
    print(f"\n=== {model_name} Summary ===")
    if not np.isnan(mean_auc):
        print(f"Mean ROC AUC = {mean_auc:.4f} ± {std_auc:.4f}")
    print(f"Successful folds: {len(aucs)}/{total_splits}")
    if skipped_folds:
        print(f"Skipped folds: {skipped_folds}")

    # Stratification summary
    if stratification_results:
        train_diffs = [r['train_diff'] for r in stratification_results]
        test_diffs = [r['test_diff'] for r in stratification_results]
        print(f"Stratification quality:")
        print(f"Mean train deviation: {np.mean(train_diffs):.4f} ± {np.std(train_diffs):.4f}")
        print(f"Mean test deviation: {np.mean(test_diffs):.4f} ± {np.std(test_diffs):.4f}")

    return {
        'tprs': tprs, 'fprs': fprs, 'aucs': aucs,
        'mean_tpr': mean_tpr, 'mean_fpr': mean_fpr, 'mean_auc': mean_auc, 'std_auc': std_auc,
        'precision': precision, 'recall': recall, 'aps': aps,
        'mean_aps': np.nanmean(aps), 
        'std_ap': np.nanstd(aps),
        'stratification_results': stratification_results,
        'skipped_folds': skipped_folds,
        'effective_folds': len(aucs)
    }

# %%
# Define feature sets
data_1 = training_df[feature_columns_1]
data_2 = training_df[feature_columns_2]
target = training_df[target_column]

# Define your Random Forest classifier
RF = RandomForestClassifier(n_estimators=600, random_state=42, max_features=0.2, max_depth=20, min_samples_leaf=4)

# %%
# Define number of folds
nfolds = 5

# Generate StratifiedKFold splits
kf = StratifiedKFold(n_splits=nfolds, shuffle=True, random_state=42)
splits_I = list(kf.split(training_df[feature_columns_1], training_df[target_column]))

# %%
# Save splits
splits_path = get_data_path(['data', 'output', 'models', 'model_I'], 'splits.pkl')
with open(splits_path, 'wb') as f:
    pickle.dump(splits_I, f)

# %%
#Run cross-validation on both feature set
model_I_contextualized = model_contextualized_cross_validation(RF, data_1, target, splits_I, model_name="Model I contextualized")
model_I_full = model_full_cross_validation(RF, data_2, target, splits_I, model_name="Model I full")
# Out:
# Fold 1: Train size = 33384, Test size = 8346
#   [Model I Early - Fold 1] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9510, Elapsed time = 34.02 seconds
# Fold 2: Train size = 33384, Test size = 8346
#   [Model I Early - Fold 2] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9600, Elapsed time = 66.42 seconds
# Fold 3: Train size = 33384, Test size = 8346
#   [Model I Early - Fold 3] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9599, Elapsed time = 104.13 seconds
# Fold 4: Train size = 33384, Test size = 8346
#   [Model I Early - Fold 4] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9445, Elapsed time = 138.36 seconds
# Fold 5: Train size = 33384, Test size = 8346
#   [Model I Early - Fold 5] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9575, Elapsed time = 171.14 seconds
#
# === Model I Early Summary ===
# Mean ROC AUC = 0.9534 ± 0.0060
# Successful folds: 5/5
# Stratification quality:
#   Mean train deviation: 0.0000 ± 0.0000
#   Mean test deviation:  0.0000 ± 0.0000
#
# === Model I Late - Fold 1/5 ===
# Train size = 33384, Test size = 8346
#   [Model I Late - Fold 1] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9547, Elapsed time = 48.66 seconds
#
# === Model I Late - Fold 2/5 ===
# Train size = 33384, Test size = 8346
#   [Model I Late - Fold 2] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9665, Elapsed time = 96.88 seconds
#
# === Model I Late - Fold 3/5 ===
# Train size = 33384, Test size = 8346
#   [Model I Late - Fold 3] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9481, Elapsed time = 142.51 seconds
#
# === Model I Late - Fold 4/5 ===
# Train size = 33384, Test size = 8346
#   [Model I Late - Fold 4] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9366, Elapsed time = 184.41 seconds
#
# === Model I Late - Fold 5/5 ===
# Train size = 33384, Test size = 8346
#   [Model I Late - Fold 5] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9610, Elapsed time = 226.63 seconds
#
# === Model I Late Summary ===
# Mean ROC AUC = 0.9518 ± 0.0104
# Successful folds: 5/5
# Stratification quality:
# Mean train deviation: 0.0000 ± 0.0000
# Mean test deviation: 0.0000 ± 0.0000

# %%
# save results of cross validation
with open(file_RF_model_I_contextualized, 'wb') as f:
   pickle.dump(model_I_contextualized, f)


with open(file_RF_model_I_full, 'wb') as f:
    pickle.dump(model_I_full, f)

# %%
# Define RepeatedStratifiedKFold with 5 folds and 20 repeats
nfolds = 5
n_repeats = 10

rskf = RepeatedStratifiedKFold(n_splits=nfolds, n_repeats=n_repeats, random_state=42)
repeated_splits_I = list(rskf.split(training_df[feature_columns_1], training_df[target_column]))

# %%
# Save splits
splits_path = get_data_path(['data', 'output', 'models', 'model_I'], 'repeated_splits_I.pkl')
with open(splits_path, 'wb') as f:
    pickle.dump(repeated_splits_I, f)

# %%
#Run cross-validation on both feature set
model_I_contextualized_repeated = model_contextualized_cross_validation(RF, data_1, target, repeated_splits_I, model_name="Model I contextualized Repeated")
model_I_full_repeated = model_full_cross_validation(RF, data_2, target, repeated_splits_I, model_name="Model I full Repeated")
# Out:
# Fold 1: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 1] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9510, Elapsed time = 35.54 seconds
# Fold 2: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 2] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9600, Elapsed time = 67.78 seconds
# Fold 3: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 3] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9599, Elapsed time = 99.66 seconds
# Fold 4: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 4] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9445, Elapsed time = 131.17 seconds
# Fold 5: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 5] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9575, Elapsed time = 165.56 seconds
# Fold 6: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 6] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9291, Elapsed time = 201.09 seconds
# Fold 7: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 7] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9621, Elapsed time = 236.32 seconds
# Fold 8: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 8] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9667, Elapsed time = 267.86 seconds
# Fold 9: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 9] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9555, Elapsed time = 298.89 seconds
# Fold 10: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 10] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9578, Elapsed time = 329.05 seconds
# Fold 11: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 11] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9587, Elapsed time = 361.41 seconds
# Fold 12: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 12] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9461, Elapsed time = 392.53 seconds
# Fold 13: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 13] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9474, Elapsed time = 424.29 seconds
# Fold 14: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 14] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9638, Elapsed time = 456.01 seconds
# Fold 15: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 15] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9371, Elapsed time = 487.94 seconds
# Fold 16: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 16] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9601, Elapsed time = 520.25 seconds
# Fold 17: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 17] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9494, Elapsed time = 550.95 seconds
# Fold 18: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 18] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9235, Elapsed time = 582.43 seconds
# Fold 19: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 19] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9703, Elapsed time = 616.36 seconds
# Fold 20: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 20] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9410, Elapsed time = 650.27 seconds
# Fold 21: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 21] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9268, Elapsed time = 683.46 seconds
# Fold 22: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 22] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9660, Elapsed time = 715.33 seconds
# Fold 23: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 23] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9263, Elapsed time = 746.66 seconds
# Fold 24: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 24] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9667, Elapsed time = 778.72 seconds
# Fold 25: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 25] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9713, Elapsed time = 810.72 seconds
# Fold 26: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 26] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9465, Elapsed time = 842.32 seconds
# Fold 27: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 27] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9385, Elapsed time = 874.73 seconds
# Fold 28: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 28] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9378, Elapsed time = 908.42 seconds
# Fold 29: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 29] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9508, Elapsed time = 941.76 seconds
# Fold 30: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 30] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9701, Elapsed time = 973.78 seconds
# Fold 31: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 31] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9692, Elapsed time = 1007.40 seconds
# Fold 32: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 32] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9356, Elapsed time = 1040.95 seconds
# Fold 33: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 33] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9505, Elapsed time = 1074.22 seconds
# Fold 34: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 34] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9563, Elapsed time = 1106.21 seconds
# Fold 35: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 35] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9486, Elapsed time = 1138.77 seconds
# Fold 36: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 36] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9515, Elapsed time = 1170.74 seconds
# Fold 37: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 37] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9536, Elapsed time = 1203.15 seconds
# Fold 38: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 38] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9629, Elapsed time = 1234.90 seconds
# Fold 39: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 39] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9284, Elapsed time = 1266.91 seconds
# Fold 40: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 40] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9498, Elapsed time = 1300.80 seconds
# Fold 41: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 41] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9238, Elapsed time = 1337.18 seconds
# Fold 42: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 42] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9514, Elapsed time = 1370.94 seconds
# Fold 43: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 43] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9582, Elapsed time = 1405.14 seconds
# Fold 44: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 44] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9538, Elapsed time = 1441.77 seconds
# Fold 45: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 45] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9561, Elapsed time = 1476.44 seconds
# Fold 46: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 46] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9279, Elapsed time = 1513.09 seconds
# Fold 47: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 47] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9591, Elapsed time = 1547.44 seconds
# Fold 48: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 48] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9625, Elapsed time = 1581.58 seconds
# Fold 49: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 49] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9165, Elapsed time = 1616.07 seconds
# Fold 50: Train size = 33384, Test size = 8346
#   [Model I Early Repeated - Fold 50] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9661, Elapsed time = 1649.88 seconds
#
# === Model I Early Repeated Summary ===
# Mean ROC AUC = 0.9495 ± 0.0141
# Successful folds: 50/50
# Stratification quality:
#   Mean train deviation: 0.0000 ± 0.0000
#   Mean test deviation:  0.0000 ± 0.0000
#
# === Model I Late Repeated - Fold 1/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 1] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9547, Elapsed time = 49.70 seconds
#
# === Model I Late Repeated - Fold 2/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 2] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9665, Elapsed time = 94.72 seconds
#
# === Model I Late Repeated - Fold 3/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 3] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9481, Elapsed time = 141.22 seconds
#
# === Model I Late Repeated - Fold 4/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 4] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9366, Elapsed time = 186.25 seconds
#
# === Model I Late Repeated - Fold 5/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 5] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9610, Elapsed time = 231.27 seconds
#
# === Model I Late Repeated - Fold 6/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 6] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9308, Elapsed time = 276.35 seconds
#
# === Model I Late Repeated - Fold 7/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 7] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9661, Elapsed time = 321.41 seconds
#
# === Model I Late Repeated - Fold 8/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 8] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9780, Elapsed time = 377.19 seconds
#
# === Model I Late Repeated - Fold 9/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 9] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9657, Elapsed time = 423.05 seconds
#
# === Model I Late Repeated - Fold 10/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 10] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9566, Elapsed time = 468.88 seconds
#
# === Model I Late Repeated - Fold 11/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 11] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9722, Elapsed time = 518.77 seconds
#
# === Model I Late Repeated - Fold 12/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 12] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9511, Elapsed time = 562.87 seconds
#
# === Model I Late Repeated - Fold 13/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 13] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9642, Elapsed time = 605.65 seconds
#
# === Model I Late Repeated - Fold 14/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 14] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9571, Elapsed time = 648.13 seconds
#
# === Model I Late Repeated - Fold 15/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 15] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9569, Elapsed time = 690.32 seconds
#
# === Model I Late Repeated - Fold 16/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 16] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9629, Elapsed time = 735.93 seconds
#
# === Model I Late Repeated - Fold 17/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 17] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9515, Elapsed time = 779.34 seconds
#
# === Model I Late Repeated - Fold 18/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 18] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9373, Elapsed time = 828.67 seconds
#
# === Model I Late Repeated - Fold 19/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 19] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9780, Elapsed time = 870.68 seconds
#
# === Model I Late Repeated - Fold 20/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 20] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9443, Elapsed time = 907.89 seconds
#
# === Model I Late Repeated - Fold 21/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 21] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9433, Elapsed time = 946.64 seconds
#
# === Model I Late Repeated - Fold 22/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 22] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9656, Elapsed time = 984.23 seconds
#
# === Model I Late Repeated - Fold 23/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 23] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9165, Elapsed time = 1023.26 seconds
#
# === Model I Late Repeated - Fold 24/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 24] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9571, Elapsed time = 1062.98 seconds
#
# === Model I Late Repeated - Fold 25/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 25] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9786, Elapsed time = 1101.26 seconds
#
# === Model I Late Repeated - Fold 26/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 26] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9435, Elapsed time = 1137.63 seconds
#
# === Model I Late Repeated - Fold 27/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 27] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9479, Elapsed time = 1175.75 seconds
#
# === Model I Late Repeated - Fold 28/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 28] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9457, Elapsed time = 1219.81 seconds
#
# === Model I Late Repeated - Fold 29/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 29] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9532, Elapsed time = 1262.66 seconds
#
# === Model I Late Repeated - Fold 30/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 30] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9799, Elapsed time = 1311.37 seconds
#
# === Model I Late Repeated - Fold 31/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 31] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9675, Elapsed time = 1355.48 seconds
#
# === Model I Late Repeated - Fold 32/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 32] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9405, Elapsed time = 1395.87 seconds
#
# === Model I Late Repeated - Fold 33/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 33] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9413, Elapsed time = 1955.53 seconds
#
# === Model I Late Repeated - Fold 34/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 34] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9421, Elapsed time = 14406.21 seconds
#
# === Model I Late Repeated - Fold 35/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 35] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9495, Elapsed time = 17535.29 seconds
#
# === Model I Late Repeated - Fold 36/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 36] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9608, Elapsed time = 17592.64 seconds
#
# === Model I Late Repeated - Fold 37/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 37] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9589, Elapsed time = 20367.12 seconds
#
# === Model I Late Repeated - Fold 38/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 38] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9678, Elapsed time = 24072.97 seconds
#
# === Model I Late Repeated - Fold 39/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 39] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9354, Elapsed time = 26698.53 seconds
#
# === Model I Late Repeated - Fold 40/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 40] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9629, Elapsed time = 32193.09 seconds
#
# === Model I Late Repeated - Fold 41/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 41] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9358, Elapsed time = 32865.02 seconds
#
# === Model I Late Repeated - Fold 42/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 42] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9681, Elapsed time = 36540.30 seconds
#
# === Model I Late Repeated - Fold 43/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 43] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9722, Elapsed time = 41053.00 seconds
#
# === Model I Late Repeated - Fold 44/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 44] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9414, Elapsed time = 43987.37 seconds
#
# === Model I Late Repeated - Fold 45/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 45] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9593, Elapsed time = 48578.80 seconds
#
# === Model I Late Repeated - Fold 46/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 46] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9423, Elapsed time = 54890.72 seconds
#
# === Model I Late Repeated - Fold 47/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 47] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9705, Elapsed time = 57678.67 seconds
#
# === Model I Late Repeated - Fold 48/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 48] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9671, Elapsed time = 61244.15 seconds
#
# === Model I Late Repeated - Fold 49/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 49] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9383, Elapsed time = 63028.85 seconds
#
# === Model I Late Repeated - Fold 50/50 ===
# Train size = 33384, Test size = 8346
#   [Model I Late Repeated - Fold 50] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9661, Elapsed time = 63087.12 seconds
#
# === Model I Late Repeated Summary ===
# Mean ROC AUC = 0.9537 ± 0.0141
# Successful folds: 50/50
# Stratification quality:
# Mean train deviation: 0.0000 ± 0.0000
# Mean test deviation: 0.0000 ± 0.0000

# %%
# save results of cross validation
with open(file_RF_model_I_contextualized_repeated, 'wb') as f:
    pickle.dump(model_I_contextualized_repeated, f)

with open(file_RF_model_I_full_repeated, 'wb') as f:
    pickle.dump(model_I_full_repeated, f)

# %% [markdown]
# ## Model II
# #### Same paralog pairs, different cell lines

# %%
# Define group feature for cell lines
cell_line_groups = training_df['cell_line']

sgkf = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=42)
splits_II = list(sgkf.split(training_df, target, cell_line_groups))

# Model II - Cell line validation
print("=== MODEL II: CELL LINE VALIDATION ===")
for i, (train_index, test_index) in enumerate(splits_II):
    train_cells = training_df.loc[train_index, 'cell_line'].unique()
    test_cells = training_df.loc[test_index, 'cell_line'].unique()
    validate_group_splits(train_cells, test_cells, i+1, "Model II", "cell lines")
# Out:
# === MODEL II: CELL LINE VALIDATION ===
#   [Model II - Fold 1] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 2] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 3] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 4] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model II - Fold 5] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage

# %%
# Save splits
splits_path = get_data_path(['data', 'output', 'models', 'model_II'], 'splits_II.pkl')
with open(splits_path, 'wb') as f:
    pickle.dump(splits_II, f)

# %%
model_II_contextualized = model_contextualized_cross_validation(RF, data_1, target, splits_II, model_name="Model II contextualized")
model_II_full = model_full_cross_validation(RF, data_2, target, splits_II, model_name="Model II full")
# Out:
# Fold 1: Train size = 33384, Test size = 8346
#   [Model II Early - Fold 1] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0005)
#     Test SL rate:    0.0084 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9465, Elapsed time = 38.28 seconds
# Fold 2: Train size = 33384, Test size = 8346
#   [Model II Early - Fold 2] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0062 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9549, Elapsed time = 72.69 seconds
# Fold 3: Train size = 33384, Test size = 8346
#   [Model II Early - Fold 3] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0005)
#     Test SL rate:    0.0084 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.8822, Elapsed time = 104.43 seconds
# Fold 4: Train size = 33384, Test size = 8346
#   [Model II Early - Fold 4] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0068 (diff: 0.0004)
#     Test SL rate:    0.0046 (diff: 0.0018)
#     Train/Test diff: 0.0022
# Stratification OK
#   ROC AUC = 0.8933, Elapsed time = 143.30 seconds
# Fold 5: Train size = 33384, Test size = 8346
#   [Model II Early - Fold 5] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0069 (diff: 0.0005)
#     Test SL rate:    0.0042 (diff: 0.0022)
#     Train/Test diff: 0.0027
# Stratification OK
#   ROC AUC = 0.9452, Elapsed time = 180.35 seconds
#
# === Model II Early Summary ===
# Mean ROC AUC = 0.9233 ± 0.0303
# Successful folds: 5/5
# Stratification quality:
#   Mean train deviation: 0.0004 ± 0.0002
#   Mean test deviation:  0.0016 ± 0.0008
#
# === Model II Late - Fold 1/5 ===
# Train size = 33384, Test size = 8346
#   [Model II Late - Fold 1] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0005)
#     Test SL rate:    0.0084 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9780, Elapsed time = 47.81 seconds
#
# === Model II Late - Fold 2/5 ===
# Train size = 33384, Test size = 8346
#   [Model II Late - Fold 2] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0062 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9519, Elapsed time = 91.40 seconds
#
# === Model II Late - Fold 3/5 ===
# Train size = 33384, Test size = 8346
#   [Model II Late - Fold 3] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0005)
#     Test SL rate:    0.0084 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9234, Elapsed time = 134.88 seconds
#
# === Model II Late - Fold 4/5 ===
# Train size = 33384, Test size = 8346
#   [Model II Late - Fold 4] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0068 (diff: 0.0004)
#     Test SL rate:    0.0046 (diff: 0.0018)
#     Train/Test diff: 0.0022
# Stratification OK
#   ROC AUC = 0.9248, Elapsed time = 185.24 seconds
#
# === Model II Late - Fold 5/5 ===
# Train size = 33384, Test size = 8346
#   [Model II Late - Fold 5] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0069 (diff: 0.0005)
#     Test SL rate:    0.0042 (diff: 0.0022)
#     Train/Test diff: 0.0027
# Stratification OK
#   ROC AUC = 0.9454, Elapsed time = 231.76 seconds
#
# === Model II Late Summary ===
# Mean ROC AUC = 0.9435 ± 0.0201
# Successful folds: 5/5
# Stratification quality:
# Mean train deviation: 0.0004 ± 0.0002
# Mean test deviation: 0.0016 ± 0.0008

# %%
# save results of cross validation
with open(file_RF_model_II_contextualized, 'wb') as f:
    pickle.dump(model_II_contextualized, f)

with open(file_RF_model_II_full, 'wb') as f:
    pickle.dump(model_II_full, f)

# %%
def repeated_stratified_group_kfold(data, target, groups, n_folds, n_repeats=n_repeats, random_state=42):
    
    all_splits = []
    
    for repeat in range(n_repeats):
        # Set up StratifiedGroupKFold with an incremented random state for each repeat
        sgkf = StratifiedGroupKFold(n_splits=n_folds, shuffle=True, random_state=random_state + repeat)
        splits = list(sgkf.split(data, target, groups))
        
        # Append each split (train_index, test_index) to all_splits
        for fold_num, (train_index, test_index) in enumerate(splits, start=1):
            all_splits.append((train_index, test_index))
            
            # Print fold details for tracking
            print(f"Repeat {repeat + 1}, Fold {fold_num}:")
            print(f"  TRAIN groups: {groups.iloc[train_index].unique()}")
            print(f"  TEST groups: {groups.iloc[test_index].unique()}")

    return all_splits

# Generate the repeated stratified group k-fold splits
repeated_splits_II = repeated_stratified_group_kfold(
    data=training_df,
    target=target,
    groups=cell_line_groups,
    n_folds=5,
    n_repeats=10,
    random_state=42
)
# Out:
# Repeat 1, Fold 1:
#   TRAIN groups: ['PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG' 'GI1_CENTRAL_NERVOUS_SYSTEM'
#  'HS936T_SKIN' 'MELJUSO_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['PATU8988S_PANCREAS' 'IPC298_SKIN']
# Repeat 1, Fold 2:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'HS936T_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['GI1_CENTRAL_NERVOUS_SYSTEM' 'MELJUSO_SKIN']
# Repeat 1, Fold 3:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'HS944T_SKIN' 'GI1_CENTRAL_NERVOUS_SYSTEM'
#  'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['PK1_PANCREAS' 'A549_LUNG']
# Repeat 1, Fold 4:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN']
#   TEST groups: ['HSC5_SKIN' 'MEL202_UVEA']
# Repeat 1, Fold 5:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN'
#  'MEL202_UVEA']
#   TEST groups: ['HS944T_SKIN' 'HS936T_SKIN']
# Repeat 2, Fold 1:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN'
#  'MEL202_UVEA']
#   TEST groups: ['A549_LUNG' 'HSC5_SKIN']
# Repeat 2, Fold 2:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN'
#  'HSC5_SKIN']
#   TEST groups: ['PK1_PANCREAS' 'MEL202_UVEA']
# Repeat 2, Fold 3:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN'
#  'MEL202_UVEA']
#   TEST groups: ['HS944T_SKIN' 'HS936T_SKIN']
# Repeat 2, Fold 4:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'HS936T_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['GI1_CENTRAL_NERVOUS_SYSTEM' 'MELJUSO_SKIN']
# Repeat 2, Fold 5:
#   TRAIN groups: ['PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG' 'GI1_CENTRAL_NERVOUS_SYSTEM'
#  'HS936T_SKIN' 'MELJUSO_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['PATU8988S_PANCREAS' 'IPC298_SKIN']
# Repeat 3, Fold 1:
#   TRAIN groups: ['PK1_PANCREAS' 'HS944T_SKIN' 'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN'
#  'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['PATU8988S_PANCREAS' 'A549_LUNG']
# Repeat 3, Fold 2:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'IPC298_SKIN' 'HSC5_SKIN'
#  'MEL202_UVEA']
#   TEST groups: ['PK1_PANCREAS' 'MELJUSO_SKIN']
# Repeat 3, Fold 3:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'MEL202_UVEA']
#   TEST groups: ['IPC298_SKIN' 'HSC5_SKIN']
# Repeat 3, Fold 4:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN']
# Repeat 3, Fold 5:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN'
#  'HSC5_SKIN']
#   TEST groups: ['HS944T_SKIN' 'MEL202_UVEA']
# Repeat 4, Fold 1:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'HS944T_SKIN' 'GI1_CENTRAL_NERVOUS_SYSTEM'
#  'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['PK1_PANCREAS' 'A549_LUNG']
# Repeat 4, Fold 2:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN']
# Repeat 4, Fold 3:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'HSC5_SKIN'
#  'MEL202_UVEA']
#   TEST groups: ['HS944T_SKIN' 'IPC298_SKIN']
# Repeat 4, Fold 4:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'IPC298_SKIN' 'MEL202_UVEA']
#   TEST groups: ['MELJUSO_SKIN' 'HSC5_SKIN']
# Repeat 4, Fold 5:
#   TRAIN groups: ['PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG' 'GI1_CENTRAL_NERVOUS_SYSTEM'
#  'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN']
#   TEST groups: ['PATU8988S_PANCREAS' 'MEL202_UVEA']
# Repeat 5, Fold 1:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'HSC5_SKIN']
#   TEST groups: ['IPC298_SKIN' 'MEL202_UVEA']
# Repeat 5, Fold 2:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['HS936T_SKIN' 'MELJUSO_SKIN']
# Repeat 5, Fold 3:
#   TRAIN groups: ['PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG' 'GI1_CENTRAL_NERVOUS_SYSTEM'
#  'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN' 'MEL202_UVEA']
#   TEST groups: ['PATU8988S_PANCREAS' 'HSC5_SKIN']
# Repeat 5, Fold 4:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'GI1_CENTRAL_NERVOUS_SYSTEM'
#  'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['HS944T_SKIN' 'A549_LUNG']
# Repeat 5, Fold 5:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'HS944T_SKIN' 'A549_LUNG' 'HS936T_SKIN'
#  'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['PK1_PANCREAS' 'GI1_CENTRAL_NERVOUS_SYSTEM']
# Repeat 6, Fold 1:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN'
#  'MEL202_UVEA']
#   TEST groups: ['A549_LUNG' 'HSC5_SKIN']
# Repeat 6, Fold 2:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN']
# Repeat 6, Fold 3:
#   TRAIN groups: ['PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG' 'GI1_CENTRAL_NERVOUS_SYSTEM'
#  'HS936T_SKIN' 'MELJUSO_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['PATU8988S_PANCREAS' 'IPC298_SKIN']
# Repeat 6, Fold 4:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'IPC298_SKIN' 'HSC5_SKIN'
#  'MEL202_UVEA']
#   TEST groups: ['PK1_PANCREAS' 'MELJUSO_SKIN']
# Repeat 6, Fold 5:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN'
#  'HSC5_SKIN']
#   TEST groups: ['HS944T_SKIN' 'MEL202_UVEA']
# Repeat 7, Fold 1:
#   TRAIN groups: ['PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG' 'GI1_CENTRAL_NERVOUS_SYSTEM'
#  'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['PATU8988S_PANCREAS' 'HS936T_SKIN']
# Repeat 7, Fold 2:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'IPC298_SKIN' 'HSC5_SKIN']
#   TEST groups: ['MELJUSO_SKIN' 'MEL202_UVEA']
# Repeat 7, Fold 3:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'HSC5_SKIN'
#  'MEL202_UVEA']
#   TEST groups: ['HS944T_SKIN' 'IPC298_SKIN']
# Repeat 7, Fold 4:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN'
#  'MEL202_UVEA']
#   TEST groups: ['A549_LUNG' 'HSC5_SKIN']
# Repeat 7, Fold 5:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'HS944T_SKIN' 'A549_LUNG' 'HS936T_SKIN'
#  'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['PK1_PANCREAS' 'GI1_CENTRAL_NERVOUS_SYSTEM']
# Repeat 8, Fold 1:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'MELJUSO_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['HS936T_SKIN' 'IPC298_SKIN']
# Repeat 8, Fold 2:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN'
#  'HSC5_SKIN']
#   TEST groups: ['HS944T_SKIN' 'MEL202_UVEA']
# Repeat 8, Fold 3:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'IPC298_SKIN' 'HSC5_SKIN'
#  'MEL202_UVEA']
#   TEST groups: ['PK1_PANCREAS' 'MELJUSO_SKIN']
# Repeat 8, Fold 4:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN'
#  'MEL202_UVEA']
#   TEST groups: ['A549_LUNG' 'HSC5_SKIN']
# Repeat 8, Fold 5:
#   TRAIN groups: ['PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG' 'HS936T_SKIN' 'MELJUSO_SKIN'
#  'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['PATU8988S_PANCREAS' 'GI1_CENTRAL_NERVOUS_SYSTEM']
# Repeat 9, Fold 1:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'IPC298_SKIN' 'HSC5_SKIN'
#  'MEL202_UVEA']
#   TEST groups: ['HS944T_SKIN' 'MELJUSO_SKIN']
# Repeat 9, Fold 2:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'MEL202_UVEA']
#   TEST groups: ['IPC298_SKIN' 'HSC5_SKIN']
# Repeat 9, Fold 3:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN']
# Repeat 9, Fold 4:
#   TRAIN groups: ['PK1_PANCREAS' 'HS944T_SKIN' 'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN'
#  'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['PATU8988S_PANCREAS' 'A549_LUNG']
# Repeat 9, Fold 5:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN'
#  'HSC5_SKIN']
#   TEST groups: ['PK1_PANCREAS' 'MEL202_UVEA']
# Repeat 10, Fold 1:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN'
#  'MEL202_UVEA']
#   TEST groups: ['A549_LUNG' 'HS936T_SKIN']
# Repeat 10, Fold 2:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN' 'HSC5_SKIN']
#   TEST groups: ['GI1_CENTRAL_NERVOUS_SYSTEM' 'MEL202_UVEA']
# Repeat 10, Fold 3:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'PK1_PANCREAS' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'HSC5_SKIN'
#  'MEL202_UVEA']
#   TEST groups: ['HS944T_SKIN' 'IPC298_SKIN']
# Repeat 10, Fold 4:
#   TRAIN groups: ['PATU8988S_PANCREAS' 'HS944T_SKIN' 'A549_LUNG'
#  'GI1_CENTRAL_NERVOUS_SYSTEM' 'HS936T_SKIN' 'MELJUSO_SKIN' 'IPC298_SKIN'
#  'MEL202_UVEA']
#   TEST groups: ['PK1_PANCREAS' 'HSC5_SKIN']
# Repeat 10, Fold 5:
#   TRAIN groups: ['PK1_PANCREAS' 'HS944T_SKIN' 'A549_LUNG' 'GI1_CENTRAL_NERVOUS_SYSTEM'
#  'HS936T_SKIN' 'IPC298_SKIN' 'HSC5_SKIN' 'MEL202_UVEA']
#   TEST groups: ['PATU8988S_PANCREAS' 'MELJUSO_SKIN']

# %%
# Save splits
splits_path = get_data_path(['data', 'output', 'models', 'model_II'], 'repeated_splits_II.pkl')
with open(splits_path, 'wb') as f:
    pickle.dump(repeated_splits_II, f)

# %%
#Run cross-validation on both feature set
model_II_contextualized_repeated = model_contextualized_cross_validation(RF, data_1, target, repeated_splits_II, model_name="Model II contextualized Repeated")
model_II_full_repeated = model_full_cross_validation(RF, data_2, target, repeated_splits_II, model_name="Model II full Repeated")
# Out:
# Fold 1: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 1] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0005)
#     Test SL rate:    0.0084 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9465, Elapsed time = 34.04 seconds
# Fold 2: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 2] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0062 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9549, Elapsed time = 65.20 seconds
# Fold 3: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 3] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0005)
#     Test SL rate:    0.0084 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.8822, Elapsed time = 95.40 seconds
# Fold 4: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 4] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0068 (diff: 0.0004)
#     Test SL rate:    0.0046 (diff: 0.0018)
#     Train/Test diff: 0.0022
# Stratification OK
#   ROC AUC = 0.8933, Elapsed time = 128.47 seconds
# Fold 5: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 5] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0069 (diff: 0.0005)
#     Test SL rate:    0.0042 (diff: 0.0022)
#     Train/Test diff: 0.0027
# Stratification OK
#   ROC AUC = 0.9452, Elapsed time = 160.51 seconds
# Fold 6: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 6] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0069 (diff: 0.0005)
#     Test SL rate:    0.0043 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9211, Elapsed time = 192.68 seconds
# Fold 7: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 7] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0006)
#     Test SL rate:    0.0086 (diff: 0.0023)
#     Train/Test diff: 0.0028
# Stratification OK
#   ROC AUC = 0.8623, Elapsed time = 223.34 seconds
# Fold 8: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 8] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0069 (diff: 0.0005)
#     Test SL rate:    0.0042 (diff: 0.0022)
#     Train/Test diff: 0.0027
# Stratification OK
#   ROC AUC = 0.9452, Elapsed time = 255.73 seconds
# Fold 9: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 9] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0062 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9549, Elapsed time = 287.62 seconds
# Fold 10: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 10] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0005)
#     Test SL rate:    0.0084 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9465, Elapsed time = 320.33 seconds
# Fold 11: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 11] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0071 (diff: 0.0007)
#     Test SL rate:    0.0035 (diff: 0.0029)
#     Train/Test diff: 0.0036
# Stratification OK
#   ROC AUC = 0.9136, Elapsed time = 352.58 seconds
# Fold 12: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 12] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0003)
#     Test SL rate:    0.0075 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.9105, Elapsed time = 382.17 seconds
# Fold 13: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 13] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0056 (diff: 0.0007)
#     Test SL rate:    0.0092 (diff: 0.0029)
#     Train/Test diff: 0.0036
# Stratification OK
#   ROC AUC = 0.9504, Elapsed time = 4054.08 seconds
# Fold 14: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 14] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0003)
#     Test SL rate:    0.0075 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.9292, Elapsed time = 6611.60 seconds
# Fold 15: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 15] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0069 (diff: 0.0006)
#     Test SL rate:    0.0040 (diff: 0.0024)
#     Train/Test diff: 0.0030
# Stratification OK
#   ROC AUC = 0.8870, Elapsed time = 6646.11 seconds
# Fold 16: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 16] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0005)
#     Test SL rate:    0.0084 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.8822, Elapsed time = 6673.66 seconds
# Fold 17: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 17] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0003)
#     Test SL rate:    0.0075 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.9292, Elapsed time = 6699.83 seconds
# Fold 18: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 18] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0006)
#     Test SL rate:    0.0086 (diff: 0.0023)
#     Train/Test diff: 0.0028
# Stratification OK
#   ROC AUC = 0.9531, Elapsed time = 6727.00 seconds
# Fold 19: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 19] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0071 (diff: 0.0007)
#     Test SL rate:    0.0035 (diff: 0.0029)
#     Train/Test diff: 0.0036
# Stratification OK
#   ROC AUC = 0.9726, Elapsed time = 6753.14 seconds
# Fold 20: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 20] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0070 (diff: 0.0007)
#     Test SL rate:    0.0037 (diff: 0.0026)
#     Train/Test diff: 0.0033
# Stratification OK
#   ROC AUC = 0.8704, Elapsed time = 6780.99 seconds
# Fold 21: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 21] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0053 (diff: 0.0011)
#     Test SL rate:    0.0107 (diff: 0.0043)
#     Train/Test diff: 0.0054
# Stratification OK
#   ROC AUC = 0.9052, Elapsed time = 6808.32 seconds
# Fold 22: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 22] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0066 (diff: 0.0003)
#     Test SL rate:    0.0052 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.9581, Elapsed time = 6834.68 seconds
# Fold 23: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 23] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0074 (diff: 0.0010)
#     Test SL rate:    0.0023 (diff: 0.0041)
#     Train/Test diff: 0.0051
# Stratification OK
#   ROC AUC = 0.9565, Elapsed time = 6861.69 seconds
# Fold 24: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 24] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0070 (diff: 0.0007)
#     Test SL rate:    0.0037 (diff: 0.0026)
#     Train/Test diff: 0.0033
# Stratification OK
#   ROC AUC = 0.9196, Elapsed time = 6891.53 seconds
# Fold 25: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 25] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0055 (diff: 0.0009)
#     Test SL rate:    0.0099 (diff: 0.0036)
#     Train/Test diff: 0.0045
# Stratification OK
#   ROC AUC = 0.8945, Elapsed time = 6915.31 seconds
# Fold 26: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 26] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0069 (diff: 0.0005)
#     Test SL rate:    0.0043 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9211, Elapsed time = 6942.20 seconds
# Fold 27: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 27] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0003)
#     Test SL rate:    0.0075 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.9292, Elapsed time = 6968.39 seconds
# Fold 28: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 28] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0005)
#     Test SL rate:    0.0084 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9465, Elapsed time = 6995.29 seconds
# Fold 29: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 29] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0003)
#     Test SL rate:    0.0075 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.9105, Elapsed time = 7020.32 seconds
# Fold 30: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 30] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0069 (diff: 0.0006)
#     Test SL rate:    0.0040 (diff: 0.0024)
#     Train/Test diff: 0.0030
# Stratification OK
#   ROC AUC = 0.8870, Elapsed time = 7047.84 seconds
# Fold 31: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 31] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0069 (diff: 0.0006)
#     Test SL rate:    0.0040 (diff: 0.0024)
#     Train/Test diff: 0.0030
# Stratification OK
#   ROC AUC = 0.9373, Elapsed time = 7074.51 seconds
# Fold 32: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 32] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0067 (diff: 0.0004)
#     Test SL rate:    0.0049 (diff: 0.0014)
#     Train/Test diff: 0.0018
# Stratification OK
#   ROC AUC = 0.9087, Elapsed time = 7101.81 seconds
# Fold 33: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 33] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0006)
#     Test SL rate:    0.0086 (diff: 0.0023)
#     Train/Test diff: 0.0028
# Stratification OK
#   ROC AUC = 0.9531, Elapsed time = 7129.66 seconds
# Fold 34: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 34] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0069 (diff: 0.0005)
#     Test SL rate:    0.0043 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9211, Elapsed time = 7163.91 seconds
# Fold 35: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 35] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0055 (diff: 0.0009)
#     Test SL rate:    0.0099 (diff: 0.0036)
#     Train/Test diff: 0.0045
# Stratification OK
#   ROC AUC = 0.8945, Elapsed time = 7194.24 seconds
# Fold 36: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 36] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0052 (diff: 0.0011)
#     Test SL rate:    0.0109 (diff: 0.0046)
#     Train/Test diff: 0.0057
# Stratification OK
#   ROC AUC = 0.9354, Elapsed time = 7225.86 seconds
# Fold 37: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 37] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0069 (diff: 0.0006)
#     Test SL rate:    0.0040 (diff: 0.0024)
#     Train/Test diff: 0.0030
# Stratification OK
#   ROC AUC = 0.8870, Elapsed time = 7255.91 seconds
# Fold 38: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 38] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0003)
#     Test SL rate:    0.0075 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.9105, Elapsed time = 7283.30 seconds
# Fold 39: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 39] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0069 (diff: 0.0005)
#     Test SL rate:    0.0043 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9211, Elapsed time = 7315.11 seconds
# Fold 40: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 40] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0067 (diff: 0.0003)
#     Test SL rate:    0.0050 (diff: 0.0013)
#     Train/Test diff: 0.0016
# Stratification OK
#   ROC AUC = 0.9394, Elapsed time = 7343.99 seconds
# Fold 41: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 41] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0072 (diff: 0.0009)
#     Test SL rate:    0.0029 (diff: 0.0035)
#     Train/Test diff: 0.0043
# Stratification OK
#   ROC AUC = 0.9865, Elapsed time = 7373.33 seconds
# Fold 42: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 42] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0056 (diff: 0.0007)
#     Test SL rate:    0.0092 (diff: 0.0029)
#     Train/Test diff: 0.0036
# Stratification OK
#   ROC AUC = 0.9504, Elapsed time = 7406.85 seconds
# Fold 43: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 43] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0003)
#     Test SL rate:    0.0075 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.9292, Elapsed time = 7441.83 seconds
# Fold 44: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 44] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0071 (diff: 0.0007)
#     Test SL rate:    0.0035 (diff: 0.0029)
#     Train/Test diff: 0.0036
# Stratification OK
#   ROC AUC = 0.9136, Elapsed time = 7476.90 seconds
# Fold 45: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 45] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0006)
#     Test SL rate:    0.0086 (diff: 0.0023)
#     Train/Test diff: 0.0028
# Stratification OK
#   ROC AUC = 0.8623, Elapsed time = 7509.55 seconds
# Fold 46: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 46] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0001)
#     Test SL rate:    0.0060 (diff: 0.0004)
#     Train/Test diff: 0.0004
# Stratification OK
#   ROC AUC = 0.9147, Elapsed time = 7542.15 seconds
# Fold 47: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 47] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0002)
#     Test SL rate:    0.0073 (diff: 0.0010)
#     Train/Test diff: 0.0012
# Stratification OK
#   ROC AUC = 0.8858, Elapsed time = 7575.18 seconds
# Fold 48: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 48] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0006)
#     Test SL rate:    0.0086 (diff: 0.0023)
#     Train/Test diff: 0.0028
# Stratification OK
#   ROC AUC = 0.9531, Elapsed time = 7609.33 seconds
# Fold 49: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 49] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0002)
#     Test SL rate:    0.0072 (diff: 0.0008)
#     Train/Test diff: 0.0010
# Stratification OK
#   ROC AUC = 0.8912, Elapsed time = 7640.69 seconds
# Fold 50: Train size = 33384, Test size = 8346
#   [Model II Early Repeated - Fold 50] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0073 (diff: 0.0009)
#     Test SL rate:    0.0026 (diff: 0.0037)
#     Train/Test diff: 0.0046
# Stratification OK
#   ROC AUC = 0.9857, Elapsed time = 7673.41 seconds
#
# === Model II Early Repeated Summary ===
# Mean ROC AUC = 0.9223 ± 0.0303
# Successful folds: 50/50
# Stratification quality:
#   Mean train deviation: 0.0005 ± 0.0002
#   Mean test deviation:  0.0021 ± 0.0010
#
# === Model II Late Repeated - Fold 1/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 1] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0005)
#     Test SL rate:    0.0084 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9780, Elapsed time = 43.71 seconds
#
# === Model II Late Repeated - Fold 2/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 2] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0062 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9519, Elapsed time = 87.32 seconds
#
# === Model II Late Repeated - Fold 3/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 3] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0005)
#     Test SL rate:    0.0084 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9234, Elapsed time = 128.40 seconds
#
# === Model II Late Repeated - Fold 4/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 4] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0068 (diff: 0.0004)
#     Test SL rate:    0.0046 (diff: 0.0018)
#     Train/Test diff: 0.0022
# Stratification OK
#   ROC AUC = 0.9248, Elapsed time = 172.55 seconds
#
# === Model II Late Repeated - Fold 5/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 5] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0069 (diff: 0.0005)
#     Test SL rate:    0.0042 (diff: 0.0022)
#     Train/Test diff: 0.0027
# Stratification OK
#   ROC AUC = 0.9454, Elapsed time = 218.35 seconds
#
# === Model II Late Repeated - Fold 6/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 6] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0069 (diff: 0.0005)
#     Test SL rate:    0.0043 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9479, Elapsed time = 262.73 seconds
#
# === Model II Late Repeated - Fold 7/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 7] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0006)
#     Test SL rate:    0.0086 (diff: 0.0023)
#     Train/Test diff: 0.0028
# Stratification OK
#   ROC AUC = 0.8974, Elapsed time = 307.84 seconds
#
# === Model II Late Repeated - Fold 8/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 8] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0069 (diff: 0.0005)
#     Test SL rate:    0.0042 (diff: 0.0022)
#     Train/Test diff: 0.0027
# Stratification OK
#   ROC AUC = 0.9454, Elapsed time = 354.83 seconds
#
# === Model II Late Repeated - Fold 9/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 9] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0062 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9519, Elapsed time = 399.71 seconds
#
# === Model II Late Repeated - Fold 10/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 10] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0005)
#     Test SL rate:    0.0084 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9780, Elapsed time = 444.25 seconds
#
# === Model II Late Repeated - Fold 11/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 11] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0071 (diff: 0.0007)
#     Test SL rate:    0.0035 (diff: 0.0029)
#     Train/Test diff: 0.0036
# Stratification OK
#   ROC AUC = 0.9530, Elapsed time = 486.75 seconds
#
# === Model II Late Repeated - Fold 12/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 12] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0003)
#     Test SL rate:    0.0075 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.8990, Elapsed time = 527.33 seconds
#
# === Model II Late Repeated - Fold 13/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 13] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0056 (diff: 0.0007)
#     Test SL rate:    0.0092 (diff: 0.0029)
#     Train/Test diff: 0.0036
# Stratification OK
#   ROC AUC = 0.9729, Elapsed time = 574.34 seconds
#
# === Model II Late Repeated - Fold 14/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 14] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0003)
#     Test SL rate:    0.0075 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.9288, Elapsed time = 618.67 seconds
#
# === Model II Late Repeated - Fold 15/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 15] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0069 (diff: 0.0006)
#     Test SL rate:    0.0040 (diff: 0.0024)
#     Train/Test diff: 0.0030
# Stratification OK
#   ROC AUC = 0.9454, Elapsed time = 668.09 seconds
#
# === Model II Late Repeated - Fold 16/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 16] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0005)
#     Test SL rate:    0.0084 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9234, Elapsed time = 713.12 seconds
#
# === Model II Late Repeated - Fold 17/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 17] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0003)
#     Test SL rate:    0.0075 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.9288, Elapsed time = 756.68 seconds
#
# === Model II Late Repeated - Fold 18/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 18] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0006)
#     Test SL rate:    0.0086 (diff: 0.0023)
#     Train/Test diff: 0.0028
# Stratification OK
#   ROC AUC = 0.9744, Elapsed time = 803.08 seconds
#
# === Model II Late Repeated - Fold 19/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 19] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0071 (diff: 0.0007)
#     Test SL rate:    0.0035 (diff: 0.0029)
#     Train/Test diff: 0.0036
# Stratification OK
#   ROC AUC = 0.9745, Elapsed time = 847.40 seconds
#
# === Model II Late Repeated - Fold 20/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 20] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0070 (diff: 0.0007)
#     Test SL rate:    0.0037 (diff: 0.0026)
#     Train/Test diff: 0.0033
# Stratification OK
#   ROC AUC = 0.9478, Elapsed time = 895.36 seconds
#
# === Model II Late Repeated - Fold 21/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 21] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0053 (diff: 0.0011)
#     Test SL rate:    0.0107 (diff: 0.0043)
#     Train/Test diff: 0.0054
# Stratification OK
#   ROC AUC = 0.9468, Elapsed time = 942.09 seconds
#
# === Model II Late Repeated - Fold 22/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 22] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0066 (diff: 0.0003)
#     Test SL rate:    0.0052 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.9559, Elapsed time = 987.59 seconds
#
# === Model II Late Repeated - Fold 23/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 23] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0074 (diff: 0.0010)
#     Test SL rate:    0.0023 (diff: 0.0041)
#     Train/Test diff: 0.0051
# Stratification OK
#   ROC AUC = 0.9600, Elapsed time = 1034.35 seconds
#
# === Model II Late Repeated - Fold 24/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 24] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0070 (diff: 0.0007)
#     Test SL rate:    0.0037 (diff: 0.0026)
#     Train/Test diff: 0.0033
# Stratification OK
#   ROC AUC = 0.9520, Elapsed time = 1081.98 seconds
#
# === Model II Late Repeated - Fold 25/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 25] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0055 (diff: 0.0009)
#     Test SL rate:    0.0099 (diff: 0.0036)
#     Train/Test diff: 0.0045
# Stratification OK
#   ROC AUC = 0.8948, Elapsed time = 1119.77 seconds
#
# === Model II Late Repeated - Fold 26/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 26] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0069 (diff: 0.0005)
#     Test SL rate:    0.0043 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9479, Elapsed time = 1164.51 seconds
#
# === Model II Late Repeated - Fold 27/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 27] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0003)
#     Test SL rate:    0.0075 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.9288, Elapsed time = 1210.09 seconds
#
# === Model II Late Repeated - Fold 28/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 28] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0005)
#     Test SL rate:    0.0084 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9780, Elapsed time = 1256.90 seconds
#
# === Model II Late Repeated - Fold 29/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 29] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0003)
#     Test SL rate:    0.0075 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.8990, Elapsed time = 1299.67 seconds
#
# === Model II Late Repeated - Fold 30/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 30] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0069 (diff: 0.0006)
#     Test SL rate:    0.0040 (diff: 0.0024)
#     Train/Test diff: 0.0030
# Stratification OK
#   ROC AUC = 0.9454, Elapsed time = 1344.82 seconds
#
# === Model II Late Repeated - Fold 31/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 31] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0069 (diff: 0.0006)
#     Test SL rate:    0.0040 (diff: 0.0024)
#     Train/Test diff: 0.0030
# Stratification OK
#   ROC AUC = 0.9461, Elapsed time = 1390.38 seconds
#
# === Model II Late Repeated - Fold 32/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 32] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0067 (diff: 0.0004)
#     Test SL rate:    0.0049 (diff: 0.0014)
#     Train/Test diff: 0.0018
# Stratification OK
#   ROC AUC = 0.9588, Elapsed time = 1440.29 seconds
#
# === Model II Late Repeated - Fold 33/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 33] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0006)
#     Test SL rate:    0.0086 (diff: 0.0023)
#     Train/Test diff: 0.0028
# Stratification OK
#   ROC AUC = 0.9744, Elapsed time = 1487.35 seconds
#
# === Model II Late Repeated - Fold 34/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 34] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0069 (diff: 0.0005)
#     Test SL rate:    0.0043 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9479, Elapsed time = 1534.55 seconds
#
# === Model II Late Repeated - Fold 35/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 35] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0055 (diff: 0.0009)
#     Test SL rate:    0.0099 (diff: 0.0036)
#     Train/Test diff: 0.0045
# Stratification OK
#   ROC AUC = 0.8948, Elapsed time = 1573.05 seconds
#
# === Model II Late Repeated - Fold 36/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 36] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0052 (diff: 0.0011)
#     Test SL rate:    0.0109 (diff: 0.0046)
#     Train/Test diff: 0.0057
# Stratification OK
#   ROC AUC = 0.9474, Elapsed time = 1615.38 seconds
#
# === Model II Late Repeated - Fold 37/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 37] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0069 (diff: 0.0006)
#     Test SL rate:    0.0040 (diff: 0.0024)
#     Train/Test diff: 0.0030
# Stratification OK
#   ROC AUC = 0.9454, Elapsed time = 1660.03 seconds
#
# === Model II Late Repeated - Fold 38/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 38] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0003)
#     Test SL rate:    0.0075 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.8990, Elapsed time = 1700.18 seconds
#
# === Model II Late Repeated - Fold 39/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 39] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0069 (diff: 0.0005)
#     Test SL rate:    0.0043 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9479, Elapsed time = 1742.61 seconds
#
# === Model II Late Repeated - Fold 40/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 40] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0067 (diff: 0.0003)
#     Test SL rate:    0.0050 (diff: 0.0013)
#     Train/Test diff: 0.0016
# Stratification OK
#   ROC AUC = 0.9346, Elapsed time = 1783.83 seconds
#
# === Model II Late Repeated - Fold 41/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 41] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0072 (diff: 0.0009)
#     Test SL rate:    0.0029 (diff: 0.0035)
#     Train/Test diff: 0.0043
# Stratification OK
#   ROC AUC = 0.9942, Elapsed time = 1827.00 seconds
#
# === Model II Late Repeated - Fold 42/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 42] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0056 (diff: 0.0007)
#     Test SL rate:    0.0092 (diff: 0.0029)
#     Train/Test diff: 0.0036
# Stratification OK
#   ROC AUC = 0.9729, Elapsed time = 1871.35 seconds
#
# === Model II Late Repeated - Fold 43/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 43] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0003)
#     Test SL rate:    0.0075 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.9288, Elapsed time = 1915.81 seconds
#
# === Model II Late Repeated - Fold 44/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 44] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0071 (diff: 0.0007)
#     Test SL rate:    0.0035 (diff: 0.0029)
#     Train/Test diff: 0.0036
# Stratification OK
#   ROC AUC = 0.9530, Elapsed time = 1962.17 seconds
#
# === Model II Late Repeated - Fold 45/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 45] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0006)
#     Test SL rate:    0.0086 (diff: 0.0023)
#     Train/Test diff: 0.0028
# Stratification OK
#   ROC AUC = 0.8974, Elapsed time = 2006.10 seconds
#
# === Model II Late Repeated - Fold 46/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 46] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0001)
#     Test SL rate:    0.0060 (diff: 0.0004)
#     Train/Test diff: 0.0004
# Stratification OK
#   ROC AUC = 0.9390, Elapsed time = 2050.34 seconds
#
# === Model II Late Repeated - Fold 47/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 47] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0002)
#     Test SL rate:    0.0073 (diff: 0.0010)
#     Train/Test diff: 0.0012
# Stratification OK
#   ROC AUC = 0.9215, Elapsed time = 2094.38 seconds
#
# === Model II Late Repeated - Fold 48/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 48] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0006)
#     Test SL rate:    0.0086 (diff: 0.0023)
#     Train/Test diff: 0.0028
# Stratification OK
#   ROC AUC = 0.9744, Elapsed time = 2141.34 seconds
#
# === Model II Late Repeated - Fold 49/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 49] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0002)
#     Test SL rate:    0.0072 (diff: 0.0008)
#     Train/Test diff: 0.0010
# Stratification OK
#   ROC AUC = 0.9109, Elapsed time = 2184.86 seconds
#
# === Model II Late Repeated - Fold 50/50 ===
# Train size = 33384, Test size = 8346
#   [Model II Late Repeated - Fold 50] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0073 (diff: 0.0009)
#     Test SL rate:    0.0026 (diff: 0.0037)
#     Train/Test diff: 0.0046
# Stratification OK
#   ROC AUC = 0.9955, Elapsed time = 2231.40 seconds
#
# === Model II Late Repeated Summary ===
# Mean ROC AUC = 0.9424 ± 0.0261
# Successful folds: 50/50
# Stratification quality:
# Mean train deviation: 0.0005 ± 0.0002
# Mean test deviation: 0.0021 ± 0.0010

# %%
# save results of cross validation
with open(file_RF_model_II_contextualized_repeated, 'wb') as f:
    pickle.dump(model_II_contextualized_repeated, f)

with open(file_RF_model_II_full_repeated, 'wb') as f:
    pickle.dump(model_II_full_repeated, f)

# %% [markdown]
# ## Model III
# #### Different paralog pairs, same cell lines

# %%
# Define group feature for gene pairs
gene_groups = training_df['genepair']

sgkf2 = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=42)
splits_III = list(sgkf2.split(training_df, target, gene_groups))

# Model III - Gene pair validation  
print("\n=== MODEL III: GENE PAIR VALIDATION ===")
for i, (train_index, test_index) in enumerate(splits_III):
    train_pairs = training_df.loc[train_index, 'genepair'].unique()
    test_pairs = training_df.loc[test_index, 'genepair'].unique()
    validate_group_splits(train_pairs, test_pairs, i+1, "Model III", "gene pairs")
# Out:
# === MODEL III: GENE PAIR VALIDATION ===
#   [Model III - Fold 1] Group Validation:
#     Train gene pairs: 3334
#     Test gene pairs:  839
#     Overlapping gene pairs: 0
# No group leakage
#   [Model III - Fold 2] Group Validation:
#     Train gene pairs: 3343
#     Test gene pairs:  830
#     Overlapping gene pairs: 0
# No group leakage
#   [Model III - Fold 3] Group Validation:
#     Train gene pairs: 3337
#     Test gene pairs:  836
#     Overlapping gene pairs: 0
# No group leakage
#   [Model III - Fold 4] Group Validation:
#     Train gene pairs: 3343
#     Test gene pairs:  830
#     Overlapping gene pairs: 0
# No group leakage
#   [Model III - Fold 5] Group Validation:
#     Train gene pairs: 3335
#     Test gene pairs:  838
#     Overlapping gene pairs: 0
# No group leakage

# %%
# Save splits
splits_path = get_data_path(['data', 'output', 'models', 'model_III'], 'splits_III.pkl')
with open(splits_path, 'wb') as f:
    pickle.dump(splits_III, f)

# %%
model_III_contextualized = model_contextualized_cross_validation(RF, data_1, target, splits_III, model_name="Model III contextualized")
model_III_full = model_full_cross_validation(RF, data_2, target, splits_III, model_name="Model III full")
# Out:
# Fold 1: Train size = 33340, Test size = 8390
#   [Model III Early - Fold 1] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0067 (diff: 0.0003)
#     Test SL rate:    0.0050 (diff: 0.0013)
#     Train/Test diff: 0.0017
# Stratification OK
#   ROC AUC = 0.9148, Elapsed time = 33.76 seconds
# Fold 2: Train size = 33430, Test size = 8300
#   [Model III Early - Fold 2] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0066 (diff: 0.0002)
#     Test SL rate:    0.0055 (diff: 0.0008)
#     Train/Test diff: 0.0010
# Stratification OK
#   ROC AUC = 0.9172, Elapsed time = 70.77 seconds
# Fold 3: Train size = 33370, Test size = 8360
#   [Model III Early - Fold 3] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0060 (diff: 0.0003)
#     Test SL rate:    0.0077 (diff: 0.0013)
#     Train/Test diff: 0.0016
# Stratification OK
#   ROC AUC = 0.9726, Elapsed time = 105.25 seconds
# Fold 4: Train size = 33430, Test size = 8300
#   [Model III Early - Fold 4] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0002)
#     Test SL rate:    0.0072 (diff: 0.0009)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9339, Elapsed time = 138.18 seconds
# Fold 5: Train size = 33350, Test size = 8380
#   [Model III Early - Fold 5] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0063 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9323, Elapsed time = 173.31 seconds
#
# === Model III Early Summary ===
# Mean ROC AUC = 0.9330 ± 0.0207
# Successful folds: 5/5
# Stratification quality:
#   Mean train deviation: 0.0002 ± 0.0001
#   Mean test deviation:  0.0009 ± 0.0005
#
# === Model III Late - Fold 1/5 ===
# Train size = 33340, Test size = 8390
#   [Model III Late - Fold 1] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0067 (diff: 0.0003)
#     Test SL rate:    0.0050 (diff: 0.0013)
#     Train/Test diff: 0.0017
# Stratification OK
#   ROC AUC = 0.8921, Elapsed time = 44.00 seconds
#
# === Model III Late - Fold 2/5 ===
# Train size = 33430, Test size = 8300
#   [Model III Late - Fold 2] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0066 (diff: 0.0002)
#     Test SL rate:    0.0055 (diff: 0.0008)
#     Train/Test diff: 0.0010
# Stratification OK
#   ROC AUC = 0.9130, Elapsed time = 85.65 seconds
#
# === Model III Late - Fold 3/5 ===
# Train size = 33370, Test size = 8360
#   [Model III Late - Fold 3] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0060 (diff: 0.0003)
#     Test SL rate:    0.0077 (diff: 0.0013)
#     Train/Test diff: 0.0016
# Stratification OK
#   ROC AUC = 0.9725, Elapsed time = 128.38 seconds
#
# === Model III Late - Fold 4/5 ===
# Train size = 33430, Test size = 8300
#   [Model III Late - Fold 4] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0002)
#     Test SL rate:    0.0072 (diff: 0.0009)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9385, Elapsed time = 168.23 seconds
#
# === Model III Late - Fold 5/5 ===
# Train size = 33350, Test size = 8380
#   [Model III Late - Fold 5] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0063 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9411, Elapsed time = 214.73 seconds
#
# === Model III Late Summary ===
# Mean ROC AUC = 0.9305 ± 0.0272
# Successful folds: 5/5
# Stratification quality:
# Mean train deviation: 0.0002 ± 0.0001
# Mean test deviation: 0.0009 ± 0.0005

# %%
# save results of cross validation
with open(file_RF_model_III_contextualized, 'wb') as f:
    pickle.dump(model_III_contextualized, f)

with open(file_RF_model_III_full, 'wb') as f:
    pickle.dump(model_III_full, f)

# %%
# Generate the repeated stratified group k-fold splits

repeated_splits_III = repeated_stratified_group_kfold(
    data=training_df,
    target=target,
    groups=gene_groups,
    n_folds=5,
    n_repeats=10,
    random_state=42
)
# Out:
# Repeat 1, Fold 1:
#   TRAIN groups: ['A3GALT2_ABO' 'A3GALT2_GLT6D1' 'AADACL2_AADACL3' ... 'ZNF423_ZNF521'
#  'ZNRF1_ZNRF2' 'ZXDB_ZXDC']
#   TEST groups: ['A3GALT2_GBGT1' 'AADACL3_AADACL4' 'AADAC_NCEH1' 'ABL1_MATK' 'ABL2_TEC'
#  'ACAA2_ACAT1' 'ACAD8_ACADL' 'ACAD9_ACADS' 'ACADM_ACADS' 'ACADS_ACADSB'
#  'ACAT1_ACAT2' 'ACHE_BCHE' 'ACHE_CES5A' 'ACR_TMPRSS12' 'ACSL3_ACSL4'
#  'ACSM1_ACSM5' 'ACSM2A_ACSM4' 'ACSM2B_ACSM5' 'ACSM4_ACSM5' 'ACVR1B_ACVRL1'
#  'ACVR1C_ACVR2B' 'ACVR1C_TGFBR2' 'ACVR1_BMPR1B' 'ACVRL1_BMPR1A'
#  'ACYP1_ACYP2' 'ADAM11_ADAM23' 'ADAM15_ADAM19' 'ADAM20_ADAM21'
#  'ADAM29_ADAM30' 'ADAM8_ADAM12' 'ADAM9_ADAM18' 'ADAMTS10_ADAMTS16'
#  'ADAMTS12_ADAMTS17' 'ADAMTS16_ADAMTS18' 'ADAMTS1_ADAMTS4'
#  'ADAMTS3_ADAMTS14' 'ADAMTS4_ADAMTS8' 'ADAMTS5_ADAMTS9' 'ADAMTS6_ADAMTS18'
#  'ADAMTS7_ADAMTS16' 'ADAMTS8_ADAMTS9' 'ADARB1_ADARB2' 'ADGRL1_ADGRL3'
#  'AEBP1_CPN1' 'AFF2_AFF4' 'AGBL2_AGBL4' 'AGXT2_PHYKPL' 'AICDA_APOBEC3D'
#  'AKAP13_ARHGEF2' 'AKT1_AKT3' 'AKT1_RPS6KA5' 'AKT1_SGK2' 'AKT2_RPS6KA3'
#  'AKT2_SGK1' 'AKT3_RPS6KA3' 'AKT3_RPS6KB2' 'ALK_LTK' 'ALPI_ALPP'
#  'AMPD1_AMPD3' 'ANKRD28_ANKRD44' 'ANP32A_ANP32E' 'ANPEP_ERAP1'
#  'AP1B1_AP2B1' 'APOBEC3A_APOBEC3B' 'APOBEC3A_APOBEC3H' 'APOBEC3C_APOBEC3D'
#  'APOBEC3D_APOBEC3F' 'ARAF_BRAF' 'ARHGEF25_TRIO' 'ARSA_ARSF' 'ARSB_ARSI'
#  'ARSD_ARSL' 'ARSF_ARSL' 'ARSG_GALNS' 'ARSL_GALNS' 'AR_NR3C1'
#  'ASB14_ASB15' 'ASB5_ASB11' 'ASB9_ASB13' 'ATG16L1_ATG16L2' 'ATP10A_ATP10B'
#  'ATP11A_ATP11C' 'ATP13A3_ATP13A4' 'ATP1A3_ATP12A' 'ATP1A4_ATP4A'
#  'ATP2A1_ATP2A3' 'ATP2B1_ATP2B2' 'ATP2C1_ATP2C2' 'ATP6V0A2_ATP6V0A4'
#  'ATP7A_ATP7B' 'ATP8A1_ATP8A2' 'ATP8A2_ATP11A' 'ATP8A2_ATP8B4'
#  'ATP8B1_ATP8B3' 'ATP8B2_ATP8B4' 'ATP8B4_ATP11B' 'ATXN3_ATXN3L'
#  'AWAT1_DGAT2' 'AWAT1_MOGAT3' 'AXL_MERTK' 'B3GALNT1_B3GALT2'
#  'B3GALT1_B3GNT2' 'B3GNT2_B3GNT4' 'B3GNT2_B3GNT9' 'B3GNT3_B3GNT9'
#  'B3GNT4_B3GNT8' 'B3GNT6_B3GNT8' 'BAP1_UCHL5' 'BCHE_CES2' 'BHMT_BHMT2'
#  'BIRC3_BIRC7' 'BLK_FGR' 'BLK_LYN' 'BMI1_PCGF1' 'BMPR1A_BMPR1B' 'BMX_CSK'
#  'BPGM_PGAM2' 'BRSK1_BRSK2' 'BTBD10_KCTD20' 'BTBD2_BTBD6' 'BTD_VNN3P'
#  'C1RL_C1S' 'C1R_HPR' 'C2_CFB' 'CABP1_CALM3' 'CABP4_CALM2' 'CALM1_CALM2'
#  'CALM1_CALML6' 'CALM2_CALML4' 'CALM3_CALML3' 'CALM3_TNNC2'
#  'CAMK1D_CAMK2G' 'CAMK1D_PSKH2' 'CAMK1G_PNCK' 'CAMK1_CAMK1D'
#  'CAMK1_CAMK2D' 'CAMK1_PNCK' 'CAMK2A_CAMK2D' 'CAMK2B_CAMK4' 'CAMK2G_CAMK4'
#  'CAMKK1_CAMKK2' 'CAPN12_CAPN13' 'CAPN1_CAPN13' 'CAPN1_CAPN5'
#  'CAPN2_CAPN3' 'CAPN2_CAPN9' 'CAPN3_CAPN5' 'CAPN6_CAPN8' 'CAPN8_CAPN12'
#  'CAPN9_CAPN13' 'CARD17P_CARD18' 'CASK_MPP2' 'CASP3_CASP10' 'CASP3_CASP9'
#  'CASP8_CASP10' 'CBX7_CBX8' 'CCL2_CCL8' 'CCL3_CCL3L3' 'CCL5_CCL18'
#  'CCL8_CCL13' 'CD163_SSC4D' 'CD5L_CD163L1' 'CDC14A_CDC14B'
#  'CDC42BPA_STK38' 'CDC42BPB_DMPK' 'CDC42BPG_STK38L' 'CDK14_CDK18'
#  'CDK15_CDK18' 'CDK20_CDKL3' 'CDKL1_CDKL2' 'CDKL2_CDKL3' 'CDKN2A_CDKN2C'
#  'CDY1B_CDYL' 'CDY2A_CDYL2' 'CEACAM1_CEACAM7' 'CEACAM4_CEACAM7'
#  'CEACAM6_CEACAM7' 'CEACAM7_PSG2' 'CEACAM7_PSG9' 'CELA1_CELA3B'
#  'CELA2A_CELA3B' 'CELA2A_CTRC' 'CELA2B_CTRB2' 'CELA3A_CTRL' 'CELA3B_CTRL'
#  'CES1_CES4A' 'CES1_NLGN4Y' 'CES2_CES5A' 'CES3_CES4A' 'CES3_NLGN3'
#  'CES5A_NLGN1' 'CFD_CTSG' 'CFD_GZMM' 'CHI3L1_CHIT1' 'CHIA_CHIT1'
#  'CHMP1A_CHMP1B' 'CHP2_PPP3R1' 'CHST11_CHST14' 'CHST8_CHST12' 'CIB1_CIB2'
#  'CIB2_CIB3' 'CILP_CILP2' 'CKMT1B_CKMT2' 'CLCN6_CLCN7' 'CMA1_GZMA'
#  'CNKSR2_CNKSR3' 'COQ8A_COQ8B' 'CORO1A_CORO7' 'CORO1B_CORO6'
#  'CORO2A_CORO6' 'CPA1_CPA5' 'CPA1_CPO' 'CPA2_CPA4' 'CPA2_CPO' 'CPA3_CPB2'
#  'CPA4_CPB1' 'CPA6_CPB1' 'CPB1_CPO' 'CPE_CPM' 'CPE_CPXM2' 'CPM_CPZ'
#  'CPNE2_CPNE3' 'CPNE3_CPNE9' 'CPT1B_CPT1C' 'CRAT_CROT' 'CRMP1_DPYSL4'
#  'CSF1R_PDGFRA' 'CSK_FES' 'CSK_MATK' 'CSNK1A1L_CSNK1D' 'CSNK1E_TTBK1'
#  'CSNK2A1_CSNK2A3' 'CT47A1_CT47B1' 'CT47A4_CT47B1' 'CT47A9_CT47B1'
#  'CTRB1_CTRC' 'CTSC_CTSZ' 'CTSD_PGA4' 'CTSE_PGA4' 'CTSF_CTSH' 'CTSG_GZMA'
#  'CTSH_CTSK' 'CTSK_CTSS' 'CTSS_CTSV' 'DAPK1_DAPK3' 'DAPK2_MYLK'
#  'DAPK2_STK17B' 'DAW1_WDR38' 'DCAF12_DCAF12L2' 'DCAF8_DCAF8L2' 'DCK_TK2'
#  'DDAH1_DDAH2' 'DENND4A_DENND4B' 'DGAT2_DGAT2L6' 'DGKA_DGKB' 'DGKD_DGKK'
#  'DGKE_DGKQ' 'DLAT_PDHX' 'DLG2_DLG4' 'DMPK_STK38L' 'DNAH1_DNAH2'
#  'DNAH2_DNAH3' 'DNAH6_DNAH10' 'DPEP1_DPEP2' 'DPF2_DPF3' 'DPP6_DPP10'
#  'DPYSL2_DPYSL3' 'DPYSL4_DPYSL5' 'DTX1_DTX4' 'DUSP13B_STYXL2'
#  'DUSP18_DUSP21' 'DUSP1_DUSP5' 'DUSP1_DUSP9' 'DUSP2_DUSP4' 'DUSP3_DUSP13B'
#  'DUSP4_DUSP5' 'DYRK1A_DYRK1B' 'DYRK2_DYRK4' 'ECE1_ECEL1' 'ECE2_KEL'
#  'ECEL1_MMEL1' 'EFEMP1_FBLN5' 'EFNA3_EFNA5' 'EGFR_ERBB2' 'EIF2AK2_EIF2AK3'
#  'ELOA_ELOA3BP' 'ELOVL1_ELOVL4' 'ELOVL3_ELOVL6' 'EML1_EML2' 'EML2_EML5'
#  'ENAH_EVL' 'ENPEP_LNPEP' 'ENPP1_ENPP5' 'ENPP4_ENPP6' 'ENTPD1_ENTPD2'
#  'ENTPD4_ENTPD7' 'EPB42_TGM7' 'EPHA1_EPHA4' 'EPHA1_EPHB1' 'EPHA2_EPHA4'
#  'EPHA2_EPHB3' 'EPHA3_EPHA6' 'EPHA3_EPHB3' 'EPHA4_EPHA7' 'EPHA5_EPHA6'
#  'EPHA5_EPHB4' 'EPHA6_EPHB4' 'EPHA7_EPHB3' 'EPHB1_EPHB3' 'EPHB1_EPHB4'
#  'EPS8_EPS8L1' 'ERAP1_LNPEP' 'ERBB2_ERBB4' 'EVI5_EVI5L' 'EYA1_EYA4'
#  'F10_PROC' 'F12_HGFAC' 'F13A1_TGM3' 'F7_PROC' 'FAHD1_FAHD2B'
#  'FARP1_FARP2' 'FBXL2_FBXL20' 'FBXO30_FBXO40' 'FBXO6_FBXO27' 'FER_MATK'
#  'FGFR1_FGFR3' 'FGR_FRK' 'FGR_LYN' 'FKBP1A_FKBP3' 'FLT1_KDR' 'FMN1_FMN2'
#  'FOLH1_NAALADL1' 'FRK_LCK' 'FRMPD2_PTPN13' 'FURIN_PCSK5' 'FUT10_FUT11'
#  'FUT3_FUT5' 'FUT4_FUT5' 'FUT5_FUT9' 'FUT7_FUT9' 'FYN_PTK6' 'G6PC1_G6PC2'
#  'GALNS_STS' 'GALNT11_GALNT12' 'GALNT12_GALNT14' 'GALNT13_GALNT16'
#  'GALNT14_GALNT16' 'GALNT17_GALNT18' 'GALNT1_GALNT2' 'GALNT2_GALNT12'
#  'GALNT2_GALNT3' 'GALNT3_GALNT12' 'GALNT3_GALNT4' 'GALNT4_GALNT13'
#  'GALNT4_GALNT6' 'GALNT5_GALNT14' 'GALNT6_GALNT13' 'GALNT7_GALNTL6'
#  'GALNT9_GALNT17' 'GCK_HK2' 'GCNT1_GCNT4' 'GDI1_GDI2' 'GDPD4_GDPD5'
#  'GGT1_GGTLC1' 'GIGYF1_GIGYF2' 'GLB1L_GLB1L2' 'GLS_GLS2' 'GLYAT_GLYATL2'
#  'GNB1_GNB5' 'GNB4_GNB5' 'GPAT3_GPAT4' 'GRAP_GRAP2' 'GRK1_GRK3'
#  'GRK2_GRK3' 'GRK3_GRK4' 'GRK4_GRK6' 'GTF2H2_GTF2H2C' 'GUCY2F_NPR1'
#  'GZMA_GZMB' 'GZMB_GZMM' 'GZMK_GZMM' 'HABP2_PLAT' 'HAS1_HAS3' 'HCK_PTK6'
#  'HDAC4_HDAC7' 'HDAC6_HDAC10' 'HECW1_NEDD4L' 'HECW2_ITCH' 'HECW2_WWP2'
#  'HERC5_HERC6' 'HGF_MST1' 'HIPK1_HIPK2' 'HK1_HK2' 'HK2_HKDC1'
#  'HPN_TMPRSS3' 'HP_HPR' 'HTRA1_HTRA2' 'HTRA2_HTRA4' 'HYAL1_SPAM1'
#  'HYAL3_SPAM1' 'IHH_SHH' 'INPP4A_INPP4B' 'INSR_INSRR' 'IRF2BP1_IRF2BPL'
#  'ITCH_SMURF1' 'ITGA3_ITGA5' 'ITPKA_ITPKB' 'JAK1_TYK2' 'JMJD1C_KDM3A'
#  'KAT6A_KAT7' 'KBTBD11_KLHDC7B' 'KCNA10_KCNC3' 'KCNA1_KCNA5' 'KCNA1_KCNC4'
#  'KCNA2_KCNA4' 'KCNA2_KCNC2' 'KCNA3_KCNA10' 'KCNA3_KCNC3' 'KCNA4_KCNA5'
#  'KCNA7_KCNA10' 'KCNA7_KCND2' 'KCNB1_KCNG1' 'KCNB1_KCNS3' 'KCNB2_KCNG1'
#  'KCNB2_KCNS2' 'KCNC1_KCNC3' 'KCND1_KCND2' 'KCNF1_KCNS2' 'KCNG1_KCNG4'
#  'KCNG1_KCNS1' 'KCNG2_KCNG3' 'KCNG3_KCNV1' 'KCNG4_KCNS3' 'KCNH1_KCNH7'
#  'KCNH2_KCNH5' 'KCNH2_KCNH8' 'KCNH3_KCNH7' 'KCNH5_KCNH6' 'KCNN1_KCNN3'
#  'KCNS1_KCNV1' 'KCNS3_KCNV2' 'KCTD11_KCTD21' 'KCTD2_KCTD5' 'KCTD5_SHKBP1'
#  'KDM1A_KDM1B' 'KDM4B_KDM4C' 'KDM4C_KDM4E' 'KDM5B_KDM5C' 'KDM7A_PHF8'
#  'KEAP1_KLHL2' 'KEAP1_KLHL4' 'KIT_PDGFRB' 'KLHL12_KLHL20' 'KLHL13_KLHL32'
#  'KLHL14_KLHL26' 'KLHL17_KLHL18' 'KLHL1_KLHL17' 'KLHL1_KLHL4'
#  'KLHL21_KLHL24' 'KLHL22_KLHL26' 'KLHL24_KLHL29' 'KLHL2_KLHL12'
#  'KLHL2_KLHL17' 'KLHL2_KLHL3' 'KLHL3_KLHL12' 'KLHL3_KLHL28' 'KLHL4_KLHL12'
#  'KLHL4_KLHL8' 'KLHL5_KLHL20' 'KLHL8_KLHL12' 'KLHL9_KLHL14' 'KLHL9_KLHL31'
#  'KLK11_KLK15' 'KLK12_KLK13' 'KLK12_PRSS3' 'KLK14_KLK15' 'KLK15_PRSS2'
#  'KLK2_KLK7' 'KLK6_KLK12' 'KLK6_KLK9' 'KLK8_KLK13' 'KLK8_PRSS1'
#  'KLK9_KLK13' 'KMT2A_KMT2B' 'KSR1_KSR2' 'LATS1_STK38L' 'LCK_LYN'
#  'LCMT1_LCMT2' 'LDLR_LRP1' 'LDLR_VLDLR' 'LIPA_LIPF' 'LIPC_LIPG'
#  'LIPF_LIPN' 'LIPJ_LIPK' 'LIPK_LIPN' 'LONRF1_LONRF3' 'LOX_LOXL2' 'LPA_PLG'
#  'LPIN1_LPIN2' 'LRP1B_LRP4' 'LRP1_LRP1B' 'LRP1_VLDLR' 'LRP2_VLDLR'
#  'LRP4_VLDLR' 'LTBP1_LTBP3' 'LTF_TF' 'LYN_SRMS' 'LYZL4_SPACA5B'
#  'MAGI2_MAGI3' 'MAN2A1_MAN2A2' 'MAP2K1_MAP2K5' 'MAP2K2_MAP2K6'
#  'MAP2K3_MAP2K7' 'MAP2K6_MAP2K7' 'MAP3K2_MAP3K3' 'MAP3K9_MAP3K10'
#  'MAP4K1_STK24' 'MAP4K2_MAP4K3' 'MAP4K2_STK4' 'MAP4K4_MINK1'
#  'MAP4K5_STK25' 'MAPK10_MAPK13' 'MAPK12_MAPK14' 'MAPK1_MAPK6'
#  'MAPK8_MAPK11' 'MAPK8_MAPK9' 'MAPK9_MAPK14' 'MARK1_MARK2' 'MARK1_SIK3'
#  'MARK3_NIM1K' 'MARK4_SIK3' 'MAST2_MAST3' 'MCRIP1_MCRIP2' 'ME2_ME3'
#  'METAP1_METAP1D' 'MEX3A_MEX3D' 'MFGE8_NRP1' 'MGAM_SI' 'MID1_MID2'
#  'MKRN2_MKRN3' 'MMP10_MMP13' 'MMP10_MMP20' 'MMP11_MMP13' 'MMP11_MMP14'
#  'MMP11_MMP25' 'MMP12_MMP16' 'MMP12_MMP27' 'MMP13_MMP20' 'MMP14_MMP16'
#  'MMP14_MMP27' 'MMP15_MMP27' 'MMP16_MMP27' 'MMP19_MMP26' 'MMP1_MMP13'
#  'MMP1_MMP20' 'MMP1_MMP7' 'MMP21_MMP26' 'MMP3_MMP10' 'MMP3_MMP15'
#  'MMP3_MMP25' 'MMP7_MMP11' 'MMP7_MMP16' 'MMP7_MMP27' 'MMP8_MMP13'
#  'MMP8_MMP20' 'MOB1B_MOB3A' 'MOGAT2_MOGAT3' 'MPP1_MPP3' 'MPP2_PALS1'
#  'MPP3_PALS2' 'MPPED1_MPPED2' 'MPST_TST' 'MTHFD1_MTHFD2L' 'MTM1_MTMR4'
#  'MTMR10_MTMR12' 'MTMR1_MTMR9' 'MTMR3_MTMR4' 'MTMR6_MTMR8' 'MX1_MX2'
#  'MYLK2_STK17B' 'MYO3A_MYO3B' 'N4BP2_N4BP2L1' 'NAPSA_PGA3' 'NCOA1_NCOA2'
#  'NEDD4L_SMURF2' 'NEDD4_SMURF2' 'NEK1_NEK5' 'NEK3_NEK6' 'NEK7_NEK8'
#  'NEU3_NEU4' 'NFE2_NFE2L1' 'NIM1K_SNRK' 'NME5_NME6' 'NMRK1_NMRK2'
#  'NPR1_NPR2' 'NSD1_NSD3' 'NSD2_NSD3' 'NT5DC2_NT5DC3' 'NUAK1_NUAK2'
#  'NUDT3_NUDT4' 'OAS1_OASL' 'OLFM2_OLFM3' 'OXCT1_OXCT2' 'PACSIN2_PACSIN3'
#  'PADI2_PADI3' 'PADI4_PADI6' 'PAK2_PAK3' 'PAK4_PAK5' 'PANK3_PANK4'
#  'PARP1_PARP2' 'PASK_PIM3' 'PCGF2_PCGF3' 'PCMTD1_PCMTD2' 'PCSK1_PCSK7'
#  'PCSK4_PCSK5' 'PCSK6_PCSK7' 'PDIK1L_STK35' 'PDK2_PDK4' 'PDZD4_PDZRN4'
#  'PFKFB1_PFKFB2' 'PFKFB3_PFKFB4' 'PGA3_REN' 'PGAM1_PGAM2'
#  'PHACTR1_PHACTR3' 'PHC1_PHC2' 'PHKA1_PHKA2' 'PHLPP1_PHLPP2' 'PIAS1_PIAS4'
#  'PIAS2_PIAS3' 'PIK3CA_PIK3CB' 'PIK3CD_PIK3CG' 'PIM2_PIM3'
#  'PIP4K2B_PIP5K1C' 'PKN1_PRKCD' 'PLA2G1B_PLA2G2A' 'PLA2G2A_PLA2G10'
#  'PLA2G2D_PLA2G10' 'PLA2G2D_PLA2G2F' 'PLA2G2E_PLA2G5' 'PLA2G4B_PLA2G4F'
#  'PLAG1_PLAGL1' 'PLAU_PLG' 'PLCB1_PLCZ1' 'PLCB3_PLCB4' 'PLCB4_PLCD4'
#  'PLCD1_PLCL2' 'PLCD4_PLCH2' 'PLCH1_PLCL2' 'PLCL1_PLCZ1' 'PLPP1_PLPP2'
#  'PLPPR1_PLPPR2' 'PLPPR3_PLPPR5' 'PLXNA1_PLXNB1' 'PLXNA2_PLXNA4'
#  'PLXNA3_PLXNA4' 'PLXNA4_PLXNB1' 'PLXNB1_PLXND1' 'PNCK_PSKH2'
#  'PNLIPRP1_PNLIPRP3' 'PNPLA2_PNPLA4' 'POC1A_POC1B' 'POU2F1_POU3F2'
#  'POU3F2_POU3F4' 'PPM1A_PPM1N' 'PPM1H_PPM1M' 'PPP1R13B_TP53BP2'
#  'PPP1R3D_PPP1R3G' 'PPP2R2B_PPP2R2C' 'PPP2R5A_PPP2R5C' 'PPP2R5B_PPP2R5E'
#  'PPP3CA_PPP3CC' 'PPP6R2_PPP6R3' 'PRDM1_ZNF683' 'PRKACA_PRKG1'
#  'PRKACB_PRKG2' 'PRKAG1_PRKAG2' 'PRKAR2A_PRKAR2B' 'PRKCA_PRKCI'
#  'PRKCB_PRKCG' 'PRKCD_PRKCE' 'PRKCE_PRKCG' 'PRKCG_PRKCH' 'PRKCH_PRKCZ'
#  'PRKD1_PRKD3' 'PRMT2_PRMT3' 'PROC_PROZ' 'PRPS1_PRPS2' 'PRPSAP1_PRPSAP2'
#  'PRSS21_PRSS22' 'PRSS21_PRSS48' 'PRSS22_PRSS48' 'PRSS27_PRSS48'
#  'PRSS33_PRSS48' 'PRSS41_PRSS48' 'PRSS8_PRSS38' 'PSKH1_PSKH2' 'PTEN_TPTE'
#  'PTK6_YES1' 'PTPN12_PTPN22' 'PTPN5_PTPN7' 'PTPRA_PTPRE' 'PTPRA_PTPRT'
#  'PTPRD_PTPRE' 'PTPRE_PTPRK' 'PTPRF_PTPRS' 'PTPRK_PTPRU' 'PTPRM_PTPRU'
#  'PYGL_PYGM' 'RAB40A_RAB40B' 'RCBTB1_RCBTB2' 'RFPL1_RFPL4AL1'
#  'RFPL2_RFPL4B' 'RFPL4A_RFPL4AL1' 'RHBDL2_RHBDL3' 'RLIM_RNF6'
#  'RNASE2_RNASE7' 'RNASE6_RNASE7' 'RNF125_RNF166' 'RNF128_RNF150'
#  'RNF13_ZNRF4' 'RNF167_ZNRF4' 'RNFT1_RNFT2' 'ROCK2_STK38'
#  'RPS6KA1_RPS6KA3' 'RPS6KA1_RPS6KB2' 'RPS6KA2_RPS6KA4' 'RPS6KA2_SGK1'
#  'RPS6KA3_RPS6KA6' 'RPS6KA4_RPS6KA5' 'RPS6KA5_RPS6KA6' 'RPS6KA6_RPS6KB1'
#  'RPS6KB1_SGK1' 'RPS6KC1_RPS6KL1' 'SBK1_SBK2' 'SCAMP1_SCAMP4'
#  'SCAMP2_SCAMP4' 'SCAMP3_SCAMP5' 'SDS_SDSL' 'SEMA3A_SEMA3C'
#  'SEMA3A_SEMA4C' 'SEMA3B_SEMA3F' 'SEMA3B_SEMA4G' 'SEMA3C_SEMA4B'
#  'SEMA3E_SEMA3G' 'SEMA4A_SEMA4G' 'SEMA4C_SEMA4D' 'SEMA4F_SEMA4G'
#  'SEMA6B_SEMA6C' 'SEPHS1_SEPHS2' 'SFRP1_SFRP2' 'SGMS1_SGMS2'
#  'SH3GLB1_SH3GLB2' 'SHC1_SHC3' 'SIAH2_SIAH3' 'SIRT6_SIRT7'
#  'SLC24A1_SLC24A5' 'SLC27A2_SLC27A3' 'SLC27A3_SLC27A5' 'SLK_STK10'
#  'SMARCA2_SMARCA4' 'SMURF2_WWP1' 'SOCS4_SOCS5' 'SOX8_SOX9' 'SPOP_SPOPL'
#  'SPSB1_SPSB4' 'SRMS_YES1' 'SSH1_SSH2' 'ST3GAL3_ST3GAL4'
#  'ST6GALNAC1_ST6GALNAC2' 'STAMBP_STAMBPL1' 'STK17A_STK17B' 'STK32A_STK32C'
#  'STK3_STK4' 'STRN3_STRN4' 'SUCLA2_SUCLG2' 'SULT1A1_SULT1B1'
#  'SULT1A1_SULT1C2' 'SULT1A1_SULT2B1' 'SULT1A2_SULT1C3' 'SULT1A3_SULT1B1'
#  'SULT1A3_SULT2B1' 'SULT1A4_SULT1E1' 'SULT1B1_SULT1C4' 'SULT1C2_SULT1C4'
#  'SULT1C3_SULT1E1' 'SULT1C4_SULT2B1' 'SYK_ZAP70' 'TAOK1_TAOK3'
#  'TBC1D12_TBC1D14' 'TBC1D2_TBC1D2B' 'TBC1D8_TBC1D8B' 'TBL1X_TBL1XR1'
#  'TENM1_TENM4' 'TESK1_TESK2' 'TGM1_TGM3' 'TGM2_TGM3' 'TGM3_TGM4'
#  'TGM4_TGM6' 'TINAG_TINAGL1' 'TKT_TKTL2' 'TLE2_TLE3' 'TLE4_TLE5'
#  'TMPRSS11A_TMPRSS11E' 'TMPRSS11D_TMPRSS11F' 'TMPRSS2_TMPRSS4'
#  'TMPRSS3_TMPRSS15' 'TMPRSS9_TMPRSS11E' 'TNS1_TNS3' 'TOR1A_TOR1B'
#  'TPST1_TPST2' 'TRAF1_TRAF5' 'TRIB1_TRIB2' 'TRPM3_TRPM6' 'TSSK1B_TSSK3'
#  'TSSK2_TSSK6' 'TTLL1_TTLL9' 'UBA6_UBA7' 'UBE2D1_UBE2L6' 'UBE2E1_UBE2E2'
#  'UBR1_UBR2' 'UCK2_UCKL1' 'ULK1_ULK3' 'USP11_USP32' 'USP16_USP45'
#  'USP22_USP27X' 'USP27X_USP51' 'USP35_USP46' 'USP4_USP11' 'USP9X_USP24'
#  'VNN2_VNN3P' 'WIPI1_WIPI2' 'WSCD1_WSCD2' 'YTHDF2_YTHDF3' 'ZBTB22_ZBTB43'
#  'ZBTB6_ZBTB12' 'ZBTB8A_ZBTB46' 'ZFR_ZFR2' 'ZNF280A_ZNF280C' 'ZXDA_ZXDC']
# Repeat 1, Fold 2:
#   TRAIN groups: ['A3GALT2_ABO' 'A3GALT2_GBGT1' 'AADACL2_AADACL3' ... 'ZNF423_ZNF521'
#  'ZNRF1_ZNRF2' 'ZXDA_ZXDC']
#   TEST groups: ['A3GALT2_GLT6D1' 'AADAC_AADACL2' 'AAK1_BMP2K' 'ABL1_TEC' 'ABL2_TXK'
#  'ACAA2_HADHB' 'ACAD8_ACADM' 'ACAD9_ACADSB' 'ACADM_ACADSB' 'ACADS_ACADVL'
#  'ACAT1_HADHB' 'ACHE_CES3' 'ACOT11_ACOT12' 'ACSBG1_ACSBG2' 'ACSL5_ACSL6'
#  'ACSM1_ACSM6' 'ACSM2A_ACSM5' 'ACSM2B_ACSM6' 'ACSM4_ACSM6' 'ACVR1B_BMPR1A'
#  'ACVR1C_ACVRL1' 'ACVR1_ACVR1B' 'ACVR1_TGFBR1' 'ACVRL1_BMPR1B'
#  'ADAM12_ADAM15' 'ADAM15_ADAM28' 'ADAM15_ADAM33' 'ADAM20_ADAM29'
#  'ADAM22_ADAM23' 'ADAM2_ADAM18' 'ADAM8_ADAM15' 'ADAM9_ADAM20'
#  'ADAMTS10_ADAMTS17' 'ADAMTS12_ADAMTS18' 'ADAMTS17_ADAMTS18'
#  'ADAMTS1_ADAMTS5' 'ADAMTS3_ADAMTS6' 'ADAMTS4_ADAMTS9' 'ADAMTS6_ADAMTS10'
#  'ADAMTS6_ADAMTS19' 'ADAMTS7_ADAMTS17' 'ADAMTS9_ADAMTS15' 'ADAR_ADARB2'
#  'ADGRL1_ADGRL4' 'AEBP1_CPXM1' 'AFF3_AFF4' 'AGBL3_AGBL4' 'AHCYL1_AHCYL2'
#  'AICDA_APOBEC3F' 'AKAP13_ARHGEF28' 'AKT1_RPS6KA1' 'AKT1_RPS6KA6'
#  'AKT1_SGK3' 'AKT2_RPS6KA4' 'AKT2_SGK2' 'AKT3_RPS6KA4' 'AKT3_SGK1'
#  'ALPG_ALPL' 'ALPL_ALPP' 'AMPD2_AMPD3' 'ANKRD28_ANKRD52' 'ANP32B_ANP32D'
#  'ANPEP_ERAP2' 'APC_APC2' 'APOBEC3A_APOBEC3C' 'APOBEC3B_APOBEC3D'
#  'APOBEC3C_APOBEC3F' 'APOBEC3D_APOBEC3G' 'ARAF_RAF1' 'ARID1A_ARID1B'
#  'ARSA_ARSG' 'ARSB_ARSJ' 'ARSD_GALNS' 'ARSF_GALNS' 'ARSH_ARSL' 'ARSL_STS'
#  'ASB10_ASB16' 'ASB16_ASB18' 'ASB5_ASB13' 'ASRGL1_TASP1' 'ATG4A_ATG4B'
#  'ATP10A_ATP10D' 'ATP11B_ATP11C' 'ATP13A3_ATP13A5' 'ATP1A2_ATP4A'
#  'ATP1A3_ATP1A4' 'ATP2A1_ATP2C1' 'ATP2B1_ATP2B3' 'ATP4A_ATP12A'
#  'ATP6V0A2_TCIRG1' 'ATP8A1_ATP11A' 'ATP8A1_ATP8B1' 'ATP8A2_ATP11B'
#  'ATP8A2_ATP8B2' 'ATP8B1_ATP11A' 'ATP8B1_ATP8B4' 'ATP8B3_ATP11A'
#  'ATP8B4_ATP11C' 'AUH_ECHDC2' 'AWAT1_DGAT2L6' 'AWAT2_DGAT2' 'AXL_TYRO3'
#  'B3GALNT1_B3GALT5' 'B3GALT2_B3GALT5' 'B3GNT2_B3GNT7' 'B3GNT3_B3GNT4'
#  'B3GNT4_B3GNT6' 'B3GNT7_B3GNT8' 'BAZ2A_BAZ2B' 'BCHE_CES4A' 'BIRC2_BIRC7'
#  'BIRC3_BIRC8' 'BLK_FRK' 'BLK_PTK6' 'BMI1_PCGF2' 'BMPR1A_TGFBR1' 'BMX_ITK'
#  'BRAF_RAF1' 'BRWD1_BRWD3' 'BTBD1_BTBD2' 'BTBD3_BTBD6' 'BTK_CSK'
#  'C1RL_MASP1' 'C1R_MASP1' 'CAB39_CAB39L' 'CABP2_CALM1' 'CABP5_CALM1'
#  'CALM1_CALM3' 'CALM1_TNNC1' 'CALM2_CALML5' 'CALM3_CALML4' 'CAMK1D_CAMK1G'
#  'CAMK1D_CAMK4' 'CAMK1G_CAMK2A' 'CAMK1G_PSKH2' 'CAMK1_CAMK2A'
#  'CAMK1_PSKH1' 'CAMK2A_CAMK2G' 'CAMK2B_PNCK' 'CAMK2G_PNCK' 'CAMKV_PNCK'
#  'CAPN12_CAPN14' 'CAPN1_CAPN14' 'CAPN1_CAPN8' 'CAPN2_CAPN8' 'CAPN3_CAPN11'
#  'CAPN3_CAPN6' 'CAPN5_CAPN11' 'CAPN8_CAPN11' 'CAPN8_CAPN13' 'CAPN9_CAPN14'
#  'CARM1_PRMT6' 'CASK_MPP7' 'CASP3_CASP14' 'CASP3_CASP7' 'CASP4_CASP5'
#  'CBLB_CBLC' 'CCL2_CCL11' 'CCL3L3_CCL5' 'CCL3_CCL4' 'CCL5_CCL26'
#  'CCL8_CCL24' 'CD5L_CD163' 'CD5L_DMBT1' 'CDC25A_CDC25B'
#  'CDC42BPB_CDC42BPG' 'CDC42BPB_STK38' 'CDCP2_TLL2' 'CDK15_CDK17'
#  'CDK16_CDK17' 'CDK20_CDKL4' 'CDKL1_CDKL4' 'CDKL2_CDKL5' 'CDKN2A_CDKN2D'
#  'CDY1B_CDYL2' 'CDY2B_CDYL' 'CEACAM3_CEACAM21' 'CEACAM5_CEACAM21'
#  'CEACAM7_PSG3' 'CELA1_CELA2B' 'CELA1_CTRB1' 'CELA2A_CTRB2' 'CELA2A_CTRL'
#  'CELA2B_CTRC' 'CELA3B_CTRB1' 'CEL_CES1' 'CES1_CES5A' 'CES2_CES4A'
#  'CES2_NLGN1' 'CES3_CES5A' 'CES3_NLGN4X' 'CES5A_NLGN2' 'CFD_GZMB'
#  'CFD_GZMK' 'CFD_PRSS57' 'CHI3L1_OVGP1' 'CHIA_OVGP1' 'CHM_CHML'
#  'CHP2_PPP3R2' 'CHST13_CHST14' 'CHST8_CHST9' 'CIB1_CIB4' 'CIB2_CIB4'
#  'CISH_SOCS2' 'CKM_CKMT1A' 'CLK1_CLK3' 'CMA1_GZMK' 'COMT_LRTOMT'
#  'CORO1A_CORO1B' 'CORO1B_CORO1C' 'CORO1B_CORO7' 'CORO2B_CORO6' 'CPA1_CPB1'
#  'CPA2_CPA3' 'CPA3_CPA4' 'CPA3_CPO' 'CPA4_CPB2' 'CPA6_CPB2' 'CPB2_CPO'
#  'CPE_CPN1' 'CPE_CPZ' 'CPN1_CPXM2' 'CPNE3_CPNE4' 'CPT1A_CPT1B'
#  'CPT1B_CRAT' 'CRMP1_DPYS' 'CRMP1_DPYSL5' 'CSGALNACT1_CSGALNACT2'
#  'CSK_TEC' 'CSNK1A1L_CSNK1E' 'CSNK1G1_CSNK1G2' 'CSRNP1_CSRNP3'
#  'CT47A2_CT47B1' 'CT47A5_CT47B1' 'CTDSP1_CTDSP2' 'CTRB1_CTRL' 'CTSD_CTSE'
#  'CTSD_PGA5' 'CTSE_PGA5' 'CTSF_CTSK' 'CTSG_GZMK' 'CTSH_CTSL' 'CTSK_CTSV'
#  'CTSV_CTSW' 'CUL4A_CUL4B' 'DAPK1_STK17A' 'DAPK2_MYLK2' 'DAPK3_MYLK4'
#  'DAW1_WDR5B' 'DCAF4L1_DCAF4L2' 'DCBLD1_DCBLD2' 'DCLK1_DCLK3' 'DCLK1_DCX'
#  'DDHD2_SEC23IP' 'DENND4B_DENND4C' 'DGAT2_MOGAT1' 'DGKA_DGKG' 'DGKE_DGKG'
#  'DGKH_DGKK' 'DLG1_DLG2' 'DLG3_DLG4' 'DMXL1_DMXL2' 'DNAH1_DNAH3'
#  'DNAH2_DNAH6' 'DNAH8_DNAH10' 'DPEP2_DPEP3' 'DPP10_FAP' 'DPP7_PRCP'
#  'DPYSL2_DPYSL4' 'DPYS_DPYSL2' 'DTX3_DTX3L' 'DUSP14_DUSP21'
#  'DUSP18_DUSP26' 'DUSP1_DUSP6' 'DUSP26_DUSP29' 'DUSP2_DUSP5'
#  'DUSP3_DUSP26' 'DUSP6_DUSP7' 'DYRK1A_DYRK4' 'DYRK4_HIPK1' 'ECE1_MME'
#  'ECE2_MME' 'ECHDC2_ECHS1' 'EFNA1_EFNA3' 'EFNA2_EFNA4' 'EFNA4_EFNA5'
#  'EGFR_ERBB3' 'ELANE_PRTN3' 'ELOA_ELOA3CP' 'ELOVL1_ELOVL5' 'ELOVL4_ELOVL5'
#  'EML1_EML4' 'EML2_EML6' 'ENAH_VASP' 'ENPEP_TRHDE' 'ENPP2_ENPP3'
#  'ENPP5_ENPP6' 'ENTPD1_ENTPD8' 'ENTPD5_ENTPD6' 'EPHA10_EPHB1'
#  'EPHA1_EPHA5' 'EPHA1_EPHB3' 'EPHA2_EPHA5' 'EPHA2_EPHB4' 'EPHA3_EPHA7'
#  'EPHA4_EPHA10' 'EPHA4_EPHA8' 'EPHA5_EPHA7' 'EPHA6_EPHA10' 'EPHA7_EPHA10'
#  'EPHA8_EPHA10' 'EPHB2_EPHB6' 'EPHB3_EPHB4' 'EPS8_EPS8L2' 'ERAP1_TRHDE'
#  'ERBB3_ERBB4' 'EXT1_EXT2' 'EYA2_EYA3' 'F10_PROZ' 'F12_PLAU' 'F13A1_TGM4'
#  'F9_F10' 'FAHD2A_FAHD2B' 'FARP1_FRMD7' 'FBXO25_FBXO32' 'FBXO34_FBXO46'
#  'FBXO6_FBXO44' 'FER_TXK' 'FGFR1_FGFR4' 'FGR_FYN' 'FGR_SRC' 'FKBP1A_FKBP4'
#  'FLT3_KIT' 'FOXP1_FOXP2' 'FOXP2_FOXP3' 'FRK_PTK6' 'FSTL4_FSTL5'
#  'FURIN_PCSK6' 'FUT3_FUT6' 'FUT4_FUT7' 'FYN_HCK' 'FYN_SRC' 'G6PC1_G6PC3'
#  'GALNT10_GALNT15' 'GALNT11_GALNT14' 'GALNT12_GALNT16' 'GALNT13_GALNTL5'
#  'GALNT1_GALNT11' 'GALNT1_GALNT16' 'GALNT1_GALNT3' 'GALNT2_GALNT13'
#  'GALNT2_GALNT5' 'GALNT3_GALNT13' 'GALNT3_GALNT5' 'GALNT4_GALNT14'
#  'GALNT4_GALNTL5' 'GALNT5_GALNT16' 'GALNT6_GALNT14' 'GALNT8_GALNT17'
#  'GANAB_GANC' 'GCK_HK3' 'GCNT2_GCNT3' 'GDPD1_GDPD3' 'GGT2P_GGT5'
#  'GIPC1_GIPC3' 'GLB1L_GLB1L3' 'GLYATL1_GLYATL2' 'GLYAT_GLYATL3'
#  'GNB2_GNB3' 'GNPDA1_GNPDA2' 'GPT_GPT2' 'GRAP_GRB2' 'GRK1_GRK5'
#  'GRK2_GRK4' 'GRK3_GRK5' 'GRK5_GRK6' 'GTPBP1_GTPBP2' 'GUCY2F_NPR2'
#  'GZMA_GZMK' 'GZMB_PRSS57' 'GZMH_GZMK' 'GZMK_PRSS57' 'HABP2_PLAU'
#  'HAS2_HAS3' 'HCK_SRMS' 'HDAC4_HDAC9' 'HDAC7_HDAC9' 'HECW1_SMURF1'
#  'HECW2_NEDD4L' 'HERC3_HERC4' 'HEXA_HEXB' 'HGF_PLG' 'HIPK1_HIPK3'
#  'HK1_HK3' 'HK3_HKDC1' 'HPN_TMPRSS4' 'HS6ST2_HS6ST3' 'HTRA1_HTRA3'
#  'HUS1_HUS1B' 'HYAL2_HYAL3' 'HYAL4_SPAM1' 'IKBKE_TBK1' 'INPP5B_OCRL'
#  'IP6K1_IP6K3' 'IRF2BP2_IRF2BPL' 'ITCH_SMURF2' 'ITGB5_ITGB7' 'ITPKA_ITPKC'
#  'JAK2_JAK3' 'JMJD1C_KDM3B' 'JOSD1_JOSD2' 'KAT6B_KAT7' 'KBTBD6_KBTBD7'
#  'KCNA1_KCNA10' 'KCNA1_KCNA7' 'KCNA1_KCND1' 'KCNA2_KCNA5' 'KCNA2_KCNC4'
#  'KCNA3_KCNA4' 'KCNA3_KCNC4' 'KCNA4_KCNA7' 'KCNA7_KCNC1' 'KCNA7_KCND3'
#  'KCNB1_KCNG3' 'KCNB1_KCNV1' 'KCNB2_KCNG2' 'KCNB2_KCNS3' 'KCNC1_KCNC4'
#  'KCND1_KCND3' 'KCNF1_KCNS3' 'KCNG1_KCNS2' 'KCNG2_KCNS1' 'KCNG3_KCNV2'
#  'KCNG4_KCNV1' 'KCNH1_KCNH8' 'KCNH3_KCNH4' 'KCNH3_KCNH8' 'KCNH5_KCNH7'
#  'KCNH6_KCNH8' 'KCNN2_KCNN3' 'KCNS1_KCNV2' 'KCNV1_KCNV2' 'KCTD12_KCTD16'
#  'KCTD3_KCTD5' 'KCTD7_KCTD14' 'KDM3A_KDM3B' 'KDM4B_KDM4D' 'KDM4D_KDM4E'
#  'KDM5B_KDM5D' 'KEAP1_KLHL1' 'KEAP1_KLHL20' 'KIF21A_KIF21B'
#  'KLHDC1_KLHDC2' 'KLHL12_KLHL28' 'KLHL14_KLHL31' 'KLHL17_KLHL20'
#  'KLHL1_KLHL2' 'KLHL1_KLHL5' 'KLHL21_KLHL29' 'KLHL23_KLHL24'
#  'KLHL24_KLHL35' 'KLHL2_KLHL18' 'KLHL2_KLHL4' 'KLHL3_KLHL17' 'KLHL3_KLHL5'
#  'KLHL4_KLHL17' 'KLHL5_KLHL12' 'KLHL5_KLHL28' 'KLHL8_KLHL17'
#  'KLHL9_KLHL15' 'KLHL9_KLHL32' 'KLK11_PRSS1' 'KLK12_KLK15' 'KLK13_KLK14'
#  'KLK14_PRSS1' 'KLK14_PRSS2' 'KLK15_PRSS3' 'KLK3_KLK7' 'KLK6_KLK13'
#  'KLK6_PRSS1' 'KLK8_KLK14' 'KLK8_PRSS3' 'KLK9_KLK14' 'KMT2C_KMT2D'
#  'KYAT1_KYAT3' 'LATS2_STK38' 'LCK_PTK6' 'LDHAL6A_UEVLD' 'LDLR_LRP1B'
#  'LFNG_MFNG' 'LIPA_LIPK' 'LIPC_LPL' 'LIPG_LPL' 'LIPJ_LIPM' 'LIPM_LIPN'
#  'LOXL2_LOXL3' 'LOX_LOXL3' 'LPCAT1_LPCAT2' 'LPIN2_LPIN3' 'LRP1B_LRP5'
#  'LRP1_LRP2' 'LRP2_LRP4' 'LRP4_LRP5' 'LTA4H_RNPEP' 'LTBP1_LTBP4'
#  'LVRN_TRHDE' 'LYPLA1_LYPLA2' 'LYZL6_SPACA5B' 'MAOA_MAOB' 'MAP2K1_MAP2K6'
#  'MAP2K2_MAP2K7' 'MAP2K3_MAP2K4' 'MAP2K4_MAP2K6' 'MAP3K10_MAP3K11'
#  'MAP3K5_MAP3K15' 'MAP3K9_MAP3K11' 'MAP4K1_STK25' 'MAP4K2_STK24'
#  'MAP4K3_MAP4K5' 'MAP4K4_NRK' 'MAP4K5_STK26' 'MAPK10_MAPK14'
#  'MAPK13_MAPK14' 'MAPK3_MAPK4' 'MAPK8_MAPK12' 'MAPK9_MAPK10'
#  'MAPKAPK2_MAPKAPK3' 'MARK1_MARK3' 'MARK2_MARK3' 'MARK3_SIK2'
#  'MASP1_MASP2' 'MAST2_MAST4' 'MDM2_MDM4' 'MECOM_PRDM16' 'METTL2B_METTL6'
#  'METTL6_METTL8' 'MEX3B_MEX3C' 'MFGE8_NRP2' 'MGAT5_MGAT5B' 'MINK1_TNIK'
#  'MMEL1_PHEX' 'MMP10_MMP14' 'MMP10_MMP24' 'MMP11_MMP15' 'MMP11_MMP27'
#  'MMP12_MMP17' 'MMP13_MMP14' 'MMP13_MMP24' 'MMP14_MMP17' 'MMP15_MMP16'
#  'MMP16_MMP17' 'MMP17_MMP20' 'MMP19_MMP28' 'MMP1_MMP14' 'MMP1_MMP24'
#  'MMP1_MMP8' 'MMP24_MMP25' 'MMP3_MMP11' 'MMP3_MMP16' 'MMP3_MMP27'
#  'MMP7_MMP12' 'MMP7_MMP17' 'MMP7_MMP8' 'MMP8_MMP14' 'MMP8_MMP24'
#  'MOB1B_MOB3B' 'MORN3_RSPH10B' 'MPP1_MPP7' 'MPP2_PALS2' 'MPP4_MPP7'
#  'MST1_PLG' 'MTHFD2_MTHFD2L' 'MTM1_MTMR6' 'MTMR1_MTMR2' 'MTMR2_MTMR3'
#  'MTMR3_MTMR6' 'MTMR6_MTMR9' 'MYBL1_MYBL2' 'MYLK3_MYLK4'
#  'NAALAD2_NAALADL1' 'NAPSA_PGA4' 'NCOA1_NCOA3' 'NEDD4L_WWP1' 'NEDD4_WWP1'
#  'NEK1_NEK7' 'NEK3_NEK7' 'NEK7_NEK9' 'NEURL1B_NEURL3' 'NFE2_NFE2L2'
#  'NLN_THOP1' 'NME5_NME7' 'NNMT_PNMT' 'NRIP2_NRIP3' 'NT5C1A_NT5C1B'
#  'NTMT1_NTMT2' 'NUDT10_NUDT11' 'NUDT4_NUDT10' 'OAS2_OAS3' 'OTUB1_OTUB2'
#  'OXSR1_STK39' 'PADI1_PADI2' 'PADI2_PADI4' 'PAFAH2_PLA2G7' 'PAK1_PAK3'
#  'PAK2_PAK4' 'PALS1_PALS2' 'PAOX_SMOX' 'PARP1_PARP3' 'PCGF1_PCGF2'
#  'PCGF3_PCGF5' 'PCSK1_PCSK2' 'PCSK2_PCSK4' 'PCSK4_PCSK6' 'PCYT1A_PCYT1B'
#  'PDK1_PDK2' 'PDK3_PDK4' 'PDZRN3_PDZRN4' 'PFKFB1_PFKFB3' 'PFKL_PFKM'
#  'PGA4_PGC' 'PGC_REN' 'PHACTR1_PHACTR4' 'PHC1_PHC3' 'PHKA1_PHKB'
#  'PHOSPHO1_PHOSPHO2' 'PIAS2_PIAS4' 'PIK3CA_PIK3CD' 'PIK3R1_PIK3R2'
#  'PIP4K2A_PIP4K2B' 'PIP5K1B_PIP5K1C' 'PKN1_PRKCQ' 'PLA2G1B_PLA2G2D'
#  'PLA2G2A_PLA2G2D' 'PLA2G2D_PLA2G2E' 'PLA2G2F_PLA2G5' 'PLA2G4D_PLA2G4E'
#  'PLAG1_PLAGL2' 'PLCB1_PLCB2' 'PLCB2_PLCB3' 'PLCB3_PLCD1' 'PLCB4_PLCZ1'
#  'PLCD3_PLCH1' 'PLCD4_PLCL1' 'PLCH1_PLCZ1' 'PLCL2_PLCZ1' 'PLPP1_PLPP3'
#  'PLPPR1_PLPPR3' 'PLPPR3_PLPPR4' 'PLPPR4_PLPPR5' 'PLXNA1_PLXNB2'
#  'PLXNA2_PLXNB1' 'PLXNA3_PLXNB1' 'PLXNA4_PLXNB2' 'PLXNB2_PLXND1'
#  'PNLIP_PNLIPRP1' 'PNPLA2_PNPLA5' 'PON1_PON2' 'POU2F2_POU3F2'
#  'POU3F2_POU5F1' 'PPM1B_PPM1N' 'PPP1R13L_TP53BP2' 'PPP1R9A_PPP1R9B'
#  'PPP2R2B_PPP2R2D' 'PPP2R5A_PPP2R5D' 'PPP2R5C_PPP2R5D' 'PPP3CB_PPP3CC'
#  'PRB1_PRB2' 'PRKAA1_PRKAA2' 'PRKACA_PRKG2' 'PRKACB_PRKX' 'PRKAG1_PRKAG3'
#  'PRKCA_PRKCB' 'PRKCA_PRKCQ' 'PRKCB_PRKCH' 'PRKCD_PRKCG' 'PRKCD_PRKCQ'
#  'PRKCE_PRKCH' 'PRKCG_PRKCI' 'PRKCI_PRKCQ' 'PRKD2_PRKD3' 'PRMT2_PRMT6'
#  'PRPS1L1_PRPS2' 'PRPS1_PRPSAP1' 'PRRG1_PRRG3' 'PRSS21_PRSS27'
#  'PRSS21_TPSG1' 'PRSS23_PRSS35' 'PRSS27_TPSG1' 'PRSS36_PRSS53'
#  'PRSS41_TPSG1' 'PRSS8_PRSS41' 'PSMB8_PSMB11' 'PTEN_TPTE2' 'PTP4A1_PTP4A2'
#  'PTPN13_PTPN20' 'PTPN5_PTPRR' 'PTPRA_PTPRF' 'PTPRC_PTPRE' 'PTPRE_PTPRM'
#  'PTPRG_PTPRZ1' 'PTPRN_PTPRN2' 'QPCT_QPCTL' 'RAB40A_RAB40C' 'RFFL_RNF34'
#  'RFPL1_RFPL4B' 'RFPL3_RFPL4A' 'RFPL4A_RFPL4B' 'RHOBTB1_RHOBTB2'
#  'RMND5A_RMND5B' 'RNASE2_RNASE8' 'RNASE7_RNASE8' 'RNF128_RNF130'
#  'RNF130_RNF148' 'RNF144A_RNF144B' 'RNF19A_RNF19B' 'RNPEP_RNPEPL1'
#  'ROCK2_STK38L' 'RPS6KA1_RPS6KA4' 'RPS6KA1_SGK1' 'RPS6KA2_RPS6KA5'
#  'RPS6KA2_SGK2' 'RPS6KA3_RPS6KB1' 'RPS6KA4_RPS6KA6' 'RPS6KA5_RPS6KB1'
#  'RPS6KA6_RPS6KB2' 'RPS6KB1_SGK3' 'S100A1_S100A2' 'SBK1_SBK3'
#  'SCAMP1_SCAMP5' 'SCAMP4_SCAMP5' 'SEC11A_SEC11C' 'SEMA3A_SEMA3D'
#  'SEMA3A_SEMA4G' 'SEMA3B_SEMA3G' 'SEMA3C_SEMA3D' 'SEMA3D_SEMA3E'
#  'SEMA3F_SEMA3G' 'SEMA4B_SEMA4C' 'SEMA4C_SEMA4F' 'SEMA5A_SEMA5B'
#  'SEMA6B_SEMA6D' 'SET_SETSIP' 'SFRP1_SFRP5' 'SGPP1_SGPP2' 'SH3RF1_SH3RF2'
#  'SHC1_SHC4' 'SIK1_SIK2' 'SLA_SLA2' 'SLC27A1_SLC27A2' 'SLC27A2_SLC27A4'
#  'SLC27A3_SLC27A6' 'SLK_STK24' 'SMPD1_SMPDL3A' 'SMURF2_WWP2'
#  'SORCS1_SORCS2' 'SOX9_SOX10' 'SPPL2A_SPPL2B' 'SPSB2_SPSB4' 'SRPK1_SRPK2'
#  'SSH1_SSH3' 'ST3GAL3_ST3GAL5' 'ST6GALNAC3_ST6GALNAC4' 'STC1_STC2'
#  'STK24_STK25' 'STK32B_STK32C' 'STK4_STK24' 'STRN_STRN3' 'SULF1_SULF2'
#  'SULT1A1_SULT1C3' 'SULT1A2_SULT1A3' 'SULT1A2_SULT1C4' 'SULT1A3_SULT1C2'
#  'SULT1A4_SULT1B1' 'SULT1A4_SULT2A1' 'SULT1B1_SULT1E1' 'SULT1C2_SULT1E1'
#  'SULT1C3_SULT2A1' 'SULT1E1_SULT2A1' 'SYNJ1_SYNJ2' 'TAOK2_TAOK3'
#  'TBC1D15_TBC1D17' 'TBC1D3_TBC1D28' 'TBC1D8_TBC1D9' 'TBL1X_TBL1Y'
#  'TENM2_TENM3' 'TGFB1_TGFB2' 'TGM1_TGM4' 'TGM2_TGM4' 'TGM3_TGM5'
#  'TGM4_TGM7' 'TJP1_TJP2' 'TLE1_TLE2' 'TLE2_TLE4' 'TLL1_TLL2'
#  'TMPRSS11A_TMPRSS11F' 'TMPRSS11E_TMPRSS11F' 'TMPRSS3_TMPRSS5'
#  'TMT1A_TMT1B' 'TNS1_TNS4' 'TOR1A_TOR3A' 'TPTE_TPTE2' 'TRAF2_TRAF3'
#  'TRIB1_TRIB3' 'TSPAN14_TSPAN17' 'TSSK1B_TSSK4' 'TSSK3_TSSK4'
#  'TTLL3_TTLL8' 'UBASH3A_UBASH3B' 'UBE2D2_UBE2E3' 'UBE2E3_UBE2L6'
#  'UBTD1_UBTD2' 'UFSP1_UFSP2' 'ULK2_ULK3' 'USP12_USP35' 'USP17L10_USP17L29'
#  'USP22_USP51' 'USP2_USP21' 'USP38_USP46' 'USP4_USP15' 'USP9X_USP9Y'
#  'VRK1_VRK2' 'WNK2_WNK3' 'WWP1_WWP2' 'ZBTB10_ZBTB46' 'ZBTB2_ZBTB25'
#  'ZBTB6_ZBTB26' 'ZBTB8A_ZBTB8B' 'ZFYVE16_ZFYVE21' 'ZNF280A_ZNF280D'
#  'ZXDB_ZXDC']
# Repeat 1, Fold 3:
#   TRAIN groups: ['A3GALT2_GBGT1' 'A3GALT2_GLT6D1' 'AADACL2_AADACL3' ... 'ZNRF1_ZNRF2'
#  'ZXDA_ZXDC' 'ZXDB_ZXDC']
#   TEST groups: ['A3GALT2_ABO' 'AADACL2_NCEH1' 'ABHD14A_ABHD14B' 'ABL1_CSK' 'ABL2_CSK'
#  'ABO_GLT6D1' 'ACACA_ACACB' 'ACAD8_ACADS' 'ACAD9_ACADVL' 'ACADM_IVD'
#  'ACADS_GCDH' 'ACAT2_HADHB' 'ACE_ACE2' 'ACOX1_ACOX2' 'ACSL1_ACSL5'
#  'ACSM1_ACSM2A' 'ACSM2A_ACSM2B' 'ACSM2A_ACSM6' 'ACSM3_ACSM4' 'ACSM5_ACSM6'
#  'ACVR1B_BMPR1B' 'ACVR1C_BMPR1A' 'ACVR1_ACVR1C' 'ACVR2A_ACVR2B'
#  'ACVRL1_TGFBR1' 'ADAM12_ADAM19' 'ADAM18_ADAM32' 'ADAM20_ADAM30'
#  'ADAM21_ADAM29' 'ADAM2_ADAM32' 'ADAM8_ADAM19' 'ADAM9_ADAM21'
#  'ADAMTS10_ADAMTS18' 'ADAMTS12_ADAMTS19' 'ADAMTS1_ADAMTS15'
#  'ADAMTS1_ADAMTS8' 'ADAMTS1_ADAMTS9' 'ADAMTS4_ADAMTS15' 'ADAMTS5_ADAMTS15'
#  'ADAMTS6_ADAMTS12' 'ADAMTS6_ADAMTS7' 'ADAMTS7_ADAMTS18'
#  'ADAMTS9_ADAMTS20' 'ADGRE3_ADGRL1' 'ADPRH_ADPRHL1' 'AEBP1_CPXM2'
#  'AGBL1_AGBL4' 'AGBL4_AGBL5' 'AICDA_APOBEC3A' 'AICDA_APOBEC3G'
#  'AKAP8_AKAP8L' 'AKT1_RPS6KA2' 'AKT1_RPS6KB1' 'AKT2_AKT3' 'AKT2_RPS6KB1'
#  'AKT3_RPS6KA1' 'AKT3_RPS6KA5' 'AKT3_SGK2' 'ALPG_ALPP' 'ALS2_ALS2CL'
#  'AMZ1_AMZ2' 'ANKRD44_ANKRD52' 'ANP32D_ANP32E' 'ANPEP_TRHDE'
#  'APOBEC2_APOBEC3C' 'APOBEC3A_APOBEC3D' 'APOBEC3B_APOBEC3F'
#  'APOBEC3C_APOBEC3G' 'APOBEC3F_APOBEC3G' 'ARG1_ARG2' 'ARK2C_RNF111'
#  'ARSA_ARSH' 'ARSD_ARSF' 'ARSD_STS' 'ARSF_STS' 'ARSH_GALNS' 'ART1_ART4'
#  'ART4_ART5' 'ASB2_ASB15' 'ASB5_ASB9' 'ATAD2_ATAD2B' 'ATG4A_ATG4D'
#  'ATP10B_ATP10D' 'ATP13A2_ATP13A3' 'ATP1A2_ATP12A' 'ATP1A3_ATP4A'
#  'ATP2A1_ATP2C2' 'ATP2B1_ATP2B4' 'ATP6V0A1_ATP6V0A2' 'ATP6V0E1_ATP6V0E2'
#  'ATP8A1_ATP11B' 'ATP8A1_ATP8B2' 'ATP8A2_ATP8B3' 'ATP8B1_ATP11B'
#  'ATP8B2_ATP11A' 'ATP8B3_ATP8B4' 'ATRN_ATRNL1' 'AUH_ECHS1' 'AWAT1_MOGAT1'
#  'AWAT2_MOGAT1' 'AZU1_ELANE' 'B3GALT1_B3GALT2' 'B3GAT1_B3GAT2'
#  'B3GNT2_B3GNT8' 'B3GNT3_B3GNT6' 'B3GNT4_B3GNT7' 'B3GNT7_B3GNT9'
#  'BCAT1_BCAT2' 'BCKDHB_PDHB' 'BIRC2_BIRC8' 'BIRC3_XIAP' 'BLK_FYN'
#  'BLK_SRC' 'BMI1_PCGF3' 'BMPR1B_TGFBR1' 'BMX_TEC' 'BRD2_BRD3' 'BRWD1_PHIP'
#  'BTBD1_BTBD3' 'BTD_VNN2' 'BTK_ITK' 'C1R_C1S' 'C1R_MASP2' 'CABP1_CALM1'
#  'CABP2_CALM2' 'CABP5_CALM2' 'CALM1_CALML3' 'CALM1_TNNC2' 'CALM2_CALML6'
#  'CALM3_CALML5' 'CAMK1D_CAMK2A' 'CAMK1D_CAMKV' 'CAMK1G_CAMK2B'
#  'CAMK1G_PSKH1' 'CAMK1_CAMK1G' 'CAMK1_CAMK2G' 'CAMK1_PSKH2' 'CAMK2A_CAMK4'
#  'CAMK2D_CAMK2G' 'CAMK4_PNCK' 'CAND1_CAND2' 'CAPN11_CAPN14' 'CAPN1_CAPN2'
#  'CAPN1_CAPN9' 'CAPN2_CAPN5' 'CAPN3_CAPN12' 'CAPN3_CAPN8' 'CAPN6_CAPN9'
#  'CAPN8_CAPN9' 'CAPN9_CAPN12' 'CARD16_CARD18' 'CARD9_CARD11' 'CASK_PALS2'
#  'CASP3_CASP6' 'CASP6_CASP10' 'CBL_CBLB' 'CCL2_CCL13' 'CCL3_CCL14'
#  'CCL3_CCL26' 'CCL7_CCL8' 'CCND2_CCND3' 'CD2AP_SH3KBP1' 'CD5L_PRSS12'
#  'CDC25A_CDC25C' 'CDC42BPA_STK38L' 'CDC42BPB_STK38L' 'CDK10_CDK11A'
#  'CDK15_CDK16' 'CDK17_CDK18' 'CDK20_CDKL2' 'CDKL1_CDKL3' 'CDKL3_CDKL4'
#  'CDKN2B_CDKN2C' 'CDY1_CDYL' 'CDYL_CDYL2' 'CEACAM3_CEACAM7'
#  'CEACAM5_CEACAM7' 'CEACAM7_PSG11' 'CELA1_CELA3A' 'CELA1_CTRB2'
#  'CELA2A_CTRB1' 'CELA2B_CELA3A' 'CELA2B_CTRL' 'CELA3B_CTRB2' 'CEPT1_CHPT1'
#  'CES1_NLGN1' 'CES2_CES3' 'CES2_NLGN3' 'CES3_NLGN1' 'CES4A_CES5A'
#  'CES5A_NLGN4X' 'CFD_GZMH' 'CHAT_CRAT' 'CHI3L1_CHIA' 'CHIT1_OVGP1'
#  'CHP1_CHP2' 'CHP1_TESC' 'CHST8_CHST11' 'CHST8_CHST13' 'CHST9_CHST10'
#  'CIB1_CIB3' 'CIB3_CIB4' 'CKB_CKM' 'CKM_CKMT1B' 'CLK1_CLK4' 'CMA1_GZMH'
#  'CMA1_GZMM' 'CNKSR2_IPCEF1' 'CORO1A_CORO2A' 'CORO1B_CORO2A'
#  'CORO1C_CORO2A' 'CPA1_CPA2' 'CPA1_CPB2' 'CPA2_CPA5' 'CPA2_CPB2'
#  'CPA4_CPA5' 'CPA4_CPO' 'CPA6_CPO' 'CPB1_CPB2' 'CPD_CPZ' 'CPM_CPN1'
#  'CPN1_CPZ' 'CPNE1_CPNE3' 'CPT1A_CPT1C' 'CPXM1_CPXM2' 'CRMP1_DPYSL2'
#  'CRMP1_DPYSL3' 'CSK_FER' 'CSK_TXK' 'CSNK1A1L_TTBK2' 'CSNK1G1_CSNK1G3'
#  'CSRNP2_CSRNP3' 'CT47A12_CT47B1' 'CT47A3_CT47B1' 'CTDSP1_CTDSPL'
#  'CTRB2_CTRC' 'CTSD_NAPSA' 'CTSD_PGA3' 'CTSE_PGC' 'CTSF_CTSL' 'CTSG_GZMB'
#  'CTSG_GZMM' 'CTSG_PRSS57' 'CTSL_CTSS' 'CUL7_CUL9' 'DAPK1_STK17B'
#  'DAPK2_DAPK3' 'DAPK3_STK17A' 'DCAF12L1_DCAF12L2' 'DCAF4_DCAF4L1'
#  'DCAF8_DCAF8L1' 'DCLK2_DCLK3' 'DDI1_DDI2' 'DGAT2L6_MOGAT1' 'DGAT2_MOGAT2'
#  'DGKA_DGKH' 'DGKE_DGKH' 'DGKI_DGKZ' 'DLG1_DLG3' 'DMBT1_SSC4D'
#  'DNAH10_DNAH17' 'DNAH11_DNAH17' 'DNAH3_DNAH10' 'DNAJC15_DNAJC19'
#  'DPF1_DPF2' 'DPF1_DPF3' 'DPP8_DPP9' 'DPYSL2_DPYSL5' 'DPYS_DPYSL3'
#  'DTX1_DTX2' 'DUSP14_DUSP26' 'DUSP15_DUSP22' 'DUSP1_DUSP4' 'DUSP29_STYXL2'
#  'DUSP2_DUSP6' 'DUSP2_DUSP9' 'DUSP6_DUSP9' 'DUSP8_DUSP16' 'DYRK4_HIPK2'
#  'ECE1_MMEL1' 'ECE2_MMEL1' 'ECHDC3_ECHS1' 'EFEMP1_EFEMP2' 'EFNA3_EFNA4'
#  'EGF_LRP5L' 'EHMT1_SUV39H2' 'ELOA_ELOA3P' 'ELOVL1_ELOVL7' 'ELOVL2_ELOVL7'
#  'EML1_EML6' 'EML2_EML4' 'ENC1_KLHL24' 'ENC1_KLHL25' 'ENPP1_ENPP3'
#  'ENPP2_ENPP4' 'ENPP4_ENPP5' 'ENTPD2_ENTPD3' 'ENTPD3_ENTPD8'
#  'EPHA1_EPHA10' 'EPHA1_EPHA3' 'EPHA1_EPHB4' 'EPHA2_EPHA6' 'EPHA2_EPHB1'
#  'EPHA3_EPHA5' 'EPHA4_EPHA5' 'EPHA4_EPHB1' 'EPHA4_EPHB4' 'EPHA5_EPHB1'
#  'EPHA6_EPHA7' 'EPHA6_EPHB3' 'EPHA8_EPHB1' 'EPHA8_EPHB4' 'EPS8L1_EPS8L3'
#  'ERAP2_TRHDE' 'ERN1_ERN2' 'EXT1_EXTL1' 'EYA1_EYA3' 'EZH1_EZH2'
#  'F13A1_TGM1' 'F13A1_TGM5' 'F13A1_TGM6' 'F9_PROC' 'FAM171A1_FAM171B'
#  'FAM20B_FAM20C' 'FBXO2_FBXO17' 'FBXO2_FBXO6' 'FBXO6_FBXO17' 'FES_TXK'
#  'FGFR2_FGFR3' 'FGFR3_FLT4' 'FGR_SRMS' 'FKBP1A_FKBP1B' 'FLT4_KDR'
#  'FRK_FYN' 'FRK_LYN' 'FRK_SRC' 'FUBP1_KHSRP' 'FURIN_PCSK4' 'FUT3_FUT4'
#  'FUT5_FUT6' 'FUT6_FUT9' 'FYN_SRMS' 'G6PC2_G6PC3' 'GALK1_GALK2'
#  'GALNT11_GALNT16' 'GALNT12_GALNT13' 'GALNT14_GALNTL5' 'GALNT1_GALNT13'
#  'GALNT1_GALNT4' 'GALNT1_GALNT6' 'GALNT2_GALNT11' 'GALNT2_GALNT6'
#  'GALNT3_GALNT11' 'GALNT3_GALNTL5' 'GALNT4_GALNT12' 'GALNT5_GALNT11'
#  'GALNT5_GALNT6' 'GALNT6_GALNT12' 'GALNT7_GALNT10' 'GCA_SRI' 'GCK_HKDC1'
#  'GCNT2_GCNT4' 'GDPD2_GDPD4' 'GGT1_GGT7' 'GIPC2_GIPC3' 'GLB1L2_GLB1L3'
#  'GLB1_GLB1L3' 'GNB1_GNB3' 'GNB2_GNB4' 'GNB3_GNB5' 'GRAP2_GRAPL'
#  'GRAPL_GRB2' 'GRK1_GRK6' 'GRK2_GRK5' 'GRK3_GRK6' 'GRK5_GRK7'
#  'GSPT2_HBS1L' 'GUCY2D_NPR2' 'GZMA_PRSS57' 'GZMB_GZMK' 'HABP2_HGFAC'
#  'HABP2_PLG' 'HAS1_HAS2' 'HCK_YES1' 'HDAC4_HDAC5' 'HDHD2_LHPP'
#  'HECW1_WWP1' 'HECW2_SMURF1' 'HERC3_HERC5' 'HERC4_HERC6' 'HGF_LPA'
#  'HIPK2_HIPK3' 'HIPK3_HIPK4' 'HMGCL_HMGCLL1' 'HPN_TMPRSS5' 'HPSE_HPSE2'
#  'HSPB6_HSPB8' 'HYAL1_HYAL2' 'HYAL2_HYAL4' 'IGF1R_INSR' 'IMPA1_IMPA2'
#  'INMT_PNMT' 'IP6K2_IP6K3' 'IRF2BP1_IRF2BP2' 'ITCH_NEDD4L' 'ITK_TEC'
#  'ITPKB_ITPKC' 'JAK2_TYK2' 'JAKMIP2_JAKMIP3' 'KAT6A_KAT6B' 'KCNA10_KCNC1'
#  'KCNA10_KCNC4' 'KCNA1_KCNA2' 'KCNA1_KCNC1' 'KCNA1_KCND2' 'KCNA2_KCNA3'
#  'KCNA2_KCND1' 'KCNA2_KCND3' 'KCNA3_KCNC2' 'KCNA5_KCNA10' 'KCNA7_KCNC2'
#  'KCNA7_KCND1' 'KCNB1_KCNG4' 'KCNB1_KCNS2' 'KCNB2_KCNG3' 'KCNB2_KCNV2'
#  'KCNC2_KCNC3' 'KCND2_KCND3' 'KCNF1_KCNS1' 'KCNG1_KCNG3' 'KCNG1_KCNS3'
#  'KCNG3_KCNS1' 'KCNG3_KCNS3' 'KCNH1_KCNH2' 'KCNH2_KCNH3' 'KCNH2_KCNH7'
#  'KCNH4_KCNH6' 'KCNH4_KCNH8' 'KCNN3_KCNN4' 'KCNS2_KCNV1' 'KCNS3_KCNV1'
#  'KCTD13_TNFAIP1' 'KCTD3_SHKBP1' 'KCTD5_KCTD9' 'KDM4A_KDM4C' 'KDM4A_KDM4E'
#  'KDM5A_KDM5B' 'KDM5C_KDM5D' 'KDM7A_PHF2' 'KEAP1_KLHL18' 'KIF4B_KIF21A'
#  'KLHDC8A_KLHDC8B' 'KLHL13_KLHL15' 'KLHL13_KLHL22' 'KLHL13_KLHL36'
#  'KLHL17_KLHL28' 'KLHL1_KLHL20' 'KLHL1_KLHL3' 'KLHL21_KLHL23'
#  'KLHL23_KLHL29' 'KLHL24_KLHL38' 'KLHL29_KLHL38' 'KLHL2_KLHL8'
#  'KLHL32_KLHL36' 'KLHL3_KLHL8' 'KLHL4_KLHL18' 'KLHL4_KLHL5' 'KLHL6_KLHL24'
#  'KLHL8_KLHL18' 'KLHL9_KLHL13' 'KLK11_KLK12' 'KLK11_KLK14' 'KLK12_PRSS1'
#  'KLK13_KLK15' 'KLK13_PRSS3' 'KLK1_KLK3' 'KLK2_KLK3' 'KLK6_KLK14'
#  'KLK6_PRSS3' 'KLK8_KLK12' 'KLK9_KLK11' 'KLK9_KLK15' 'KLK9_PRSS3'
#  'LARGE1_LARGE2' 'LATS1_STK38' 'LCK_SRC' 'LDHAL6B_UEVLD' 'LDHC_UEVLD'
#  'LDLR_LRP8' 'LIMK1_LIMK2' 'LIPA_LIPM' 'LIPF_LIPJ' 'LIPH_PLA1A'
#  'LIPI_PLA1A' 'LLGL1_LLGL2' 'LOXL2_LOXL4' 'LOX_LOXL1' 'LPA_PLAU'
#  'LRBA_NBEA' 'LRP1B_LRP6' 'LRP1_LRP4' 'LRP1_LRP8' 'LRP2_LRP8'
#  'LTA4H_RNPEPL1' 'LTBP2_LTBP4' 'LTF_MELTF' 'LYPLA1_LYPLAL1' 'LYZ_SPACA5B'
#  'MAP2K1_MAP2K2' 'MAP2K1_MAP2K4' 'MAP2K2_MAP2K4' 'MAP2K4_MAP2K7'
#  'MAP3K10_MAP3K21' 'MAP3K2_MAP3K19' 'MAP4K1_MAP4K2' 'MAP4K1_MAP4K5'
#  'MAP4K2_STK25' 'MAP4K3_STK24' 'MAP4K3_STK4' 'MAPK10_MAPK11'
#  'MAPK11_MAPK12' 'MAPK12_MAPK13' 'MAPK8IP1_MAPK8IP2' 'MAPK8_MAPK10'
#  'MAPK9_MAPK11' 'MAPKAPK2_MAPKAPK5' 'MAPKBP1_WDR62' 'MARK2_NIM1K'
#  'MARK3_MARK4' 'MAST1_MAST2' 'MAZ_VEZF1' 'MCCC1_PCCA' 'MELTF_TF'
#  'MET_MST1R' 'MEX3A_MEX3C' 'MFNG_RFNG' 'MGRN1_RNF157' 'MINK1_NRK'
#  'MKNK1_MKNK2' 'MME_PHEX' 'MMP10_MMP15' 'MMP10_MMP25' 'MMP11_MMP16'
#  'MMP11_MMP20' 'MMP12_MMP13' 'MMP12_MMP20' 'MMP13_MMP15' 'MMP13_MMP25'
#  'MMP14_MMP20' 'MMP15_MMP17' 'MMP16_MMP20' 'MMP17_MMP24' 'MMP1_MMP10'
#  'MMP1_MMP15' 'MMP1_MMP25' 'MMP20_MMP24' 'MMP24_MMP27' 'MMP3_MMP12'
#  'MMP3_MMP17' 'MMP3_MMP7' 'MMP7_MMP13' 'MMP7_MMP20' 'MMP8_MMP10'
#  'MMP8_MMP15' 'MMP8_MMP25' 'MOB1B_MOB3C' 'MORN3_RSPH10B2' 'MPP1_PALS2'
#  'MPP3_MPP4' 'MPP4_PALS2' 'MTF2_PHF1' 'MTM1_MTMR1' 'MTM1_MTMR7'
#  'MTMR1_MTMR3' 'MTMR2_MTMR4' 'MTMR3_MTMR9' 'MTMR7_MTMR8' 'MYB_MYBL1'
#  'MYLK_MYLK2' 'NABP1_NABP2' 'NAPSA_PGA5' 'NAPSA_PGC' 'NCOA2_NCOA3'
#  'NEDD4L_WWP2' 'NEDD4_WWP2' 'NEK2_NEK4' 'NEK4_NEK7' 'NEK8_NEK9'
#  'NEURL1_NEURL1B' 'NIM1K_SIK1' 'NME1_NME3' 'NME6_NME7' 'NOMO1_NOMO2'
#  'NRK_TNIK' 'NT5C2_NT5DC4' 'NTRK1_NTRK2' 'NUDT12_NUDT13' 'NUDT4_NUDT11'
#  'OBSCN_OBSL1' 'OTUD6A_OTUD6B' 'P4HB_PDIA3' 'PADI1_PADI3' 'PADI2_PADI6'
#  'PAK1_PAK2' 'PAK2_PAK5' 'PANK1_PANK2' 'PAPPA_PAPPA2' 'PARP2_PARP3'
#  'PCGF1_PCGF3' 'PCGF3_PCGF6' 'PCSK1_PCSK4' 'PCSK2_PCSK5' 'PCSK4_PCSK7'
#  'PDE6G_PDE6H' 'PDK1_PDK3' 'PDP1_PDP2' 'PELI1_PELI2' 'PFKFB1_PFKFB4'
#  'PFKL_PFKP' 'PGA4_REN' 'PGM2_PGM2L1' 'PHACTR2_PHACTR3' 'PHF1_PHF19'
#  'PHKA2_PHKB' 'PI4K2A_PI4K2B' 'PIAS3_PIAS4' 'PIK3C2A_PIK3C2B'
#  'PIK3CA_PIK3CG' 'PIK3R2_PIK3R3' 'PIP4K2A_PIP4K2C' 'PJA1_PJA2' 'PKN2_PKN3'
#  'PLA2G1B_PLA2G2E' 'PLA2G2A_PLA2G2E' 'PLA2G2D_PLA2G5' 'PLA2G4A_PLA2G4F'
#  'PLA2G4D_PLA2G4F' 'PLAGL1_PLAGL2' 'PLCB1_PLCB3' 'PLCB2_PLCB4'
#  'PLCB3_PLCD4' 'PLCD1_PLCH1' 'PLCD3_PLCL1' 'PLCD4_PLCL2' 'PLCH2_PLCL1'
#  'PLCL1_PLCL2' 'PLK2_PLK3' 'PLPP2_PLPP3' 'PLPPR1_PLPPR4' 'PLXNA1_PLXNA2'
#  'PLXNA1_PLXNB3' 'PLXNA2_PLXNB2' 'PLXNA3_PLXNB2' 'PLXNA4_PLXND1'
#  'PLXNB2_PLXNB3' 'PLXNB3_PLXND1' 'PNLIP_PNLIPRP3' 'PNPLA3_PNPLA4'
#  'PON1_PON3' 'POU2F3_POU3F2' 'PPEF1_PPEF2' 'PPM1H_PPM1J'
#  'PPP1R16A_PPP1R16B' 'PPP2R2A_PPP2R2B' 'PPP2R2C_PPP2R2D' 'PPP2R5A_PPP2R5E'
#  'PPP2R5C_PPP2R5E' 'PPP3R1_PPP3R2' 'PRB1_PRB4' 'PRKAB1_PRKAB2'
#  'PRKACA_PRKX' 'PRKACG_PRKG1' 'PRKAG2_PRKAG3' 'PRKCA_PRKCD' 'PRKCA_PRKCZ'
#  'PRKCB_PRKCI' 'PRKCD_PRKCH' 'PRKCE_PRKCI' 'PRKCG_PRKCQ' 'PRKCI_PRKCZ'
#  'PRKG1_PRKG2' 'PRMT3_PRMT6' 'PRPS1L1_PRPSAP1' 'PRPS1_PRPSAP2'
#  'PRRG2_PRRG4' 'PRSS21_PRSS33' 'PRSS22_PRSS27' 'PRSS22_TPSG1'
#  'PRSS27_PRSS33' 'PRSS2_PRSS3' 'PRSS33_TPSG1' 'PRSS37_PRSS58'
#  'PRSS48_TPSG1' 'PRSS8_PRSS21' 'PRSS8_PRSS48' 'PSME1_PSME3' 'PTK2_PTK2B'
#  'PTP4A1_PTP4A3' 'PTPN14_PTPN21' 'PTPN7_PTPRR' 'PTPRA_PTPRK' 'PTPRD_PTPRF'
#  'PTPRE_PTPRS' 'PTPRK_PTPRM' 'PTPRT_PTPRU' 'RAB40AL_RAB40B'
#  'RAB40B_RAB40C' 'RFPL1_RFPL2' 'RFPL2_RFPL3' 'RFPL3_RFPL4AL1'
#  'RHBDF1_RHBDF2' 'RING1_RNF2' 'RNASE1_RNASE4' 'RNASE3_RNASE6'
#  'RNF114_RNF166' 'RNF128_RNF133' 'RNF130_RNF149' 'RNF133_RNF150'
#  'RNF148_RNF149' 'RNF223_RNF225' 'ROCK1_ROCK2' 'ROR1_ROR2'
#  'RPS6KA1_RPS6KA5' 'RPS6KA1_SGK2' 'RPS6KA2_RPS6KA6' 'RPS6KA2_SGK3'
#  'RPS6KA3_RPS6KB2' 'RPS6KA4_RPS6KB1' 'RPS6KA5_RPS6KB2' 'RPS6KA6_SGK2'
#  'RPS6KB2_SGK1' 'SAMD8_SGMS1' 'SBK2_SBK3' 'SCAMP2_SCAMP3' 'SCRN1_SCRN2'
#  'SEC23A_SEC23B' 'SEMA3A_SEMA3E' 'SEMA3B_SEMA3C' 'SEMA3B_SEMA4B'
#  'SEMA3C_SEMA3E' 'SEMA3D_SEMA3F' 'SEMA4A_SEMA4B' 'SEMA4B_SEMA4D'
#  'SEMA4C_SEMA4G' 'SEMA6A_SEMA6B' 'SEMA6C_SEMA6D' 'SET_TSPYL1' 'SGK1_SGK2'
#  'SGSM1_SGSM2' 'SH3RF1_SH3RF3' 'SHMT1_SHMT2' 'SIK1_SIK3' 'SLC24A1_SLC24A2'
#  'SLC27A1_SLC27A3' 'SLC27A1_SLC27A6' 'SLC27A2_SLC27A5' 'SLC27A4_SLC27A5'
#  'SLK_STK25' 'SMURF1_SMURF2' 'SMYD1_SMYD2' 'SORCS1_SORCS3' 'SOX9_SOX15'
#  'SPPL2A_SPPL2C' 'SPTLC2_SPTLC3' 'SRPK1_SRPK3' 'SSH2_SSH3'
#  'ST3GAL4_ST3GAL5' 'ST6GALNAC3_ST6GALNAC5' 'STK10_STK24' 'STK24_STK26'
#  'STK3_STK24' 'STK4_STK25' 'STRN_STRN4' 'SULT1A1_SULT1A2'
#  'SULT1A1_SULT1C4' 'SULT1A2_SULT1A4' 'SULT1A2_SULT1E1' 'SULT1A3_SULT1C4'
#  'SULT1A4_SULT1C2' 'SULT1A4_SULT2B1' 'SULT1B1_SULT2A1' 'SULT1C2_SULT2A1'
#  'SULT1C3_SULT2B1' 'SULT1E1_SULT2B1' 'TAB2_TAB3' 'TBC1D10A_TBC1D10B'
#  'TBC1D1_TBC1D4' 'TBC1D3_USP6NL' 'TBC1D8_TBC1D9B' 'TEC_TXK' 'TEK_TIE1'
#  'TENM2_TENM4' 'TGFB2_TGFB3' 'TGM1_TGM5' 'TGM2_TGM5' 'TGM3_TGM6'
#  'TGM5_TGM6' 'TJP2_TJP3' 'TLE1_TLE3' 'TLE2_TLE5' 'TMEM59_TMEM59L'
#  'TMPRSS11B_TMPRSS11E' 'TMPRSS2_TMPRSS3' 'TMPRSS4_TMPRSS13' 'TNIP1_TNIP3'
#  'TNS2_TNS3' 'TPSAB1_TPSB2' 'TRABD2A_TRABD2B' 'TRAF2_TRAF5' 'TRIB2_TRIB3'
#  'TSPAN17_TSPAN33' 'TSSK1B_TSSK6' 'TSSK3_TSSK6' 'TUBB2A_TUBB8'
#  'UBE2A_UBE2B' 'UBE2D2_UBE2L6' 'UBE2Q1_UBE2Q2' 'UCHL1_UCHL3' 'UGGT1_UGGT2'
#  'UNK_UNKL' 'USP12_USP38' 'USP17L10_USP42' 'USP25_USP28' 'USP2_USP50'
#  'USP3_USP44' 'USP4_USP32' 'USP9Y_USP24' 'WDFY1_WDFY2' 'WNK2_WNK4'
#  'XPNPEP1_XPNPEP2' 'ZBTB12_ZBTB26' 'ZBTB34_ZBTB37' 'ZBTB7A_ZBTB7B'
#  'ZBTB8B_ZBTB46' 'ZFYVE9_ZFYVE16' 'ZNF362_ZNF384']
# Repeat 1, Fold 4:
#   TRAIN groups: ['A3GALT2_ABO' 'A3GALT2_GBGT1' 'A3GALT2_GLT6D1' ... 'ZNF423_ZNF521'
#  'ZXDA_ZXDC' 'ZXDB_ZXDC']
#   TEST groups: ['AADACL2_AADACL3' 'AADAC_AADACL3' 'ABHD4_ABHD5' 'ABL2_MATK' 'ABO_GBGT1'
#  'ABTB2_ABTB3' 'ACAD10_ACAD11' 'ACAD8_ACADSB' 'ACAD9_IVD' 'ACADSB_ACADVL'
#  'ACADS_IVD' 'ACCS_ACCSL' 'ACHE_CES4A' 'ACP2_ACP3' 'ACSL1_ACSL6'
#  'ACSM1_ACSM2B' 'ACSM2A_ACSM3' 'ACSM2B_ACSM3' 'ACSM3_ACSM5' 'ACSS1_ACSS2'
#  'ACVR1B_TGFBR1' 'ACVR1C_BMPR1B' 'ACVR1_ACVRL1' 'ACVR2A_TGFBR2'
#  'ADAM11_ADAM19' 'ADAM12_ADAM28' 'ADAM19_ADAM28' 'ADAM21_ADAM30'
#  'ADAM2_ADAM9' 'ADAM8_ADAM28' 'ADAM9_ADAM30' 'ADAMTS10_ADAMTS19'
#  'ADAMTS15_ADAMTS20' 'ADAMTS1_ADAMTS20' 'ADAMTS2_ADAMTS14'
#  'ADAMTS4_ADAMTS20' 'ADAMTS5_ADAMTS20' 'ADAMTS6_ADAMTS16'
#  'ADAMTS7_ADAMTS10' 'ADAMTS7_ADAMTS19' 'ADAMTS8_ADAMTS15'
#  'ADAMTSL1_ADAMTSL3' 'ADGRL1_ADGRL2' 'ADSS1_ADSS2' 'AEBP1_CPZ'
#  'AGBL1_AGTPBP1' 'AGBL4_AGTPBP1' 'AICDA_APOBEC3B' 'AICDA_APOBEC3H'
#  'AKT1_AKT2' 'AKT1_RPS6KA3' 'AKT1_RPS6KB2' 'AKT2_RPS6KA1' 'AKT2_RPS6KB2'
#  'AKT3_RPS6KA2' 'AKT3_RPS6KA6' 'AKT3_SGK3' 'ALPG_ALPI' 'AMHR2_BMPR2'
#  'ANG_RNASE4' 'ANP32A_ANP32B' 'ANPEP_ENPEP' 'ANXA1_ANXA2'
#  'APOBEC2_APOBEC3F' 'APOBEC3A_APOBEC3F' 'APOBEC3B_APOBEC3C'
#  'APOBEC3C_APOBEC3H' 'APOBEC3F_APOBEC3H' 'ARHGEF10_ARHGEF10L'
#  'ARPC1A_ARPC1B' 'ARSA_ARSL' 'ARSD_ARSG' 'ARSF_ARSG' 'ARSF_ARSH'
#  'ARSH_STS' 'ART1_ART5' 'ASB10_ASB18' 'ASB4_ASB10' 'ASB9_ASB11'
#  'ATAD3A_ATAD3B' 'ATG4B_ATG4D' 'ATG4C_ATG4D' 'ATP13A2_ATP13A4'
#  'ATP1A2_ATP1A3' 'ATP1A4_ATP12A' 'ATP2A3_ATP2C1' 'ATP2B2_ATP2B3'
#  'ATP6V0A1_ATP6V0A4' 'ATP6V0A4_TCIRG1' 'ATP6V1G2_ATP6V1G3' 'ATP8A1_ATP8B3'
#  'ATP8A2_ATP11C' 'ATP8B1_ATP11C' 'ATP8B2_ATP11B' 'ATP8B4_ATP11A'
#  'ATRX_RAD54L' 'AVP_OXT' 'AWAT1_MOGAT2' 'AWAT2_MOGAT2' 'AZU1_PRTN3'
#  'B3GALNT1_B3GALT1' 'B3GAT1_B3GAT3' 'B3GNT2_B3GNT3' 'B3GNT3_B3GNT7'
#  'B3GNT4_B3GNT9' 'B4GALNT3_B4GALNT4' 'BCHE_CES1' 'BCL2_BCL2L2'
#  'BIRC2_XIAP' 'BIRC8_XIAP' 'BLK_HCK' 'BLK_YES1' 'BMP1_CDCP2' 'BMX_BTK'
#  'BMX_TXK' 'BRD2_BRDT' 'BRD3_BRDT' 'BTBD1_BTBD6' 'BTD_VNN1' 'BTK_TEC'
#  'C1R_C1RL' 'C1S_HPR' 'CABP1_CALM2' 'CABP4_CALM1' 'CABP5_CALM3'
#  'CALM1_CALML5' 'CALM2_CALM3' 'CALM2_TNNC2' 'CALM3_TNNC1' 'CAMK1D_CAMK2B'
#  'CAMK1D_PSKH1' 'CAMK1G_CAMK2D' 'CAMK1G_CAMKV' 'CAMK1_CAMK4'
#  'CAMK2A_CAMK2B' 'CAMK2A_PNCK' 'CAMK2D_CAMK4' 'CAMK4_PSKH2'
#  'CAPN11_CAPN12' 'CAPN13_CAPN14' 'CAPN1_CAPN3' 'CAPN2_CAPN11'
#  'CAPN2_CAPN14' 'CAPN3_CAPN13' 'CAPN3_CAPN9' 'CAPN5_CAPN9' 'CAPN9_CAPN11'
#  'CAPNS1_CAPNS2' 'CARD16_CARD17P' 'CASP1_CASP4' 'CASP3_CASP8'
#  'CASP6_CASP7' 'CBL_CBLC' 'CCL2_CCL7' 'CCL3_CCL16' 'CCL3_CCL5'
#  'CCL8_CCL11' 'CCNE1_CCNE2' 'CD163_DMBT1' 'CD5L_SSC4D' 'CDC25B_CDC25C'
#  'CDC42BPA_DMPK' 'CDC42BPG_DMPK' 'CDK10_CDK11B' 'CDK14_CDK17'
#  'CDK20_CDKL1' 'CDK20_CDKL5' 'CDK8_CDK19' 'CDKL4_CDKL5' 'CDKN2B_CDKN2D'
#  'CDY1_CDYL2' 'CDYL_ECI2' 'CEACAM4_CEACAM21' 'CEACAM7_CEACAM8'
#  'CEACAM7_PSG4' 'CEACAM7_PSG8' 'CELA1_CTRC' 'CELA2A_CELA3A'
#  'CELA2B_CELA3B' 'CELA3A_CELA3B' 'CELA3A_CTRC' 'CES1_CES2' 'CES1_CES3'
#  'CES1_NLGN4X' 'CES2_NLGN4X' 'CES3_NLGN2' 'CES4A_NLGN1' 'CES5A_NLGN4Y'
#  'CFD_CMA1' 'CHCHD3_CHCHD6' 'CHI3L2_CHIT1' 'CHKA_CHKB' 'CHP1_PPP3R1'
#  'CHPF_CHPF2' 'CHST11_CHST13' 'CHST9_CHST11' 'CHUK_IKBKB' 'CILK1_MAK'
#  'CKB_CKMT1A' 'CKMT1A_CKMT2' 'CLK3_CLK4' 'CMA1_CTSG' 'CNKSR1_CNKSR2'
#  'CORO1A_CORO2B' 'CORO1B_CORO2B' 'CORO1C_CORO2B' 'CPA1_CPA3' 'CPA1_CPA4'
#  'CPA2_CPA6' 'CPA3_CPA6' 'CPA4_CPA6' 'CPA5_CPA6' 'CPA5_CPO' 'CPD_CPM'
#  'CPD_CPXM1' 'CPM_CPXM1' 'CPM_CPXM2' 'CPNE3_CPNE5' 'CPNE3_CPNE8'
#  'CPXM1_CPZ' 'CPXM2_CPZ' 'CRYAB_HSPB8' 'CSF1R_KIT' 'CSMD1_CSMD2'
#  'CSMD1_CSMD3' 'CSNK1D_CSNK1E' 'CSNK1G2_CSNK1G3' 'CSNK2A1_CSNK2A2'
#  'CT47A11_CT47B1' 'CT47A7_CT47B1' 'CTDSP2_CTDSPL' 'CTRB2_CTRL'
#  'CTSB_TINAGL1' 'CTSD_REN' 'CTSE_PGA3' 'CTSF_CTSV' 'CTSF_CTSW' 'CTSH_CTSS'
#  'CTSK_CTSL' 'CYFIP1_CYFIP2' 'DAPK1_DAPK2' 'DAPK2_MYLK3' 'DAPK2_STK17A'
#  'DCAF12_DCAF12L1' 'DCAF4_DCAF4L2' 'DCBLD1_RS1' 'DCK_DGUOK' 'DCLK2_PHKG2'
#  'DGAT2L6_MOGAT2' 'DGAT2L6_MOGAT3' 'DGKB_DGKE' 'DGKD_DGKH' 'DHH_IHH'
#  'DHH_SHH' 'DMPK_ROCK1' 'DMPK_STK38' 'DNAH1_DNAH6' 'DNAH2_DNAH17'
#  'DNASE2_DNASE2B' 'DNM1_DNM3' 'DPP4_DPP10' 'DPP4_FAP' 'DPYSL3_DPYSL4'
#  'DPYS_DPYSL4' 'DTX2_DTX4' 'DUSP13B_DUSP26' 'DUSP14_DUSP28' 'DUSP1_DUSP16'
#  'DUSP1_DUSP7' 'DUSP2_DUSP16' 'DUSP2_DUSP7' 'DUSP3_DUSP29' 'DUSP7_DUSP9'
#  'DYRK1B_DYRK4' 'ECE1_ECE2' 'ECE1_PHEX' 'ECE2_PHEX' 'EDIL3_NRP1'
#  'EFNA1_EFNA4' 'EFNB1_EFNB3' 'EHMT1_SUV39H1' 'ELFN1_ELFN2' 'ELOVL1_ELOVL2'
#  'ELOVL2_ELOVL4' 'ELOVL4_ELOVL7' 'EML2_EML3' 'EML3_EML4' 'ENPEP_ERAP1'
#  'ENPP1_ENPP4' 'ENPP3_ENPP4' 'ENPP5_ENPP7' 'ENTPD2_ENTPD8' 'EPB42_TGM2'
#  'EPHA1_EPHA2' 'EPHA1_EPHA7' 'EPHA2_EPHA10' 'EPHA2_EPHA7' 'EPHA3_EPHA10'
#  'EPHA3_EPHA8' 'EPHA4_EPHA6' 'EPHA4_EPHB3' 'EPHA5_EPHB3' 'EPHA6_EPHA8'
#  'EPHA7_EPHA8' 'EPHA8_EPHB3' 'EPHX3_EPHX4' 'EPS8_EPS8L3' 'ERBB2_ERBB3'
#  'ETNK1_ETNK2' 'EXT2_EXTL3' 'EYA2_EYA4' 'F11_KLKB1' 'F13A1_TGM2' 'F7_F10'
#  'F9_PROZ' 'FAM177A1_FAM177B' 'FBP1_FBP2' 'FBXO2_FBXO27' 'FBXO45_SPSB2'
#  'FBXW10_FBXW10B' 'FGFR1_FGFR2' 'FGFR2_FGFR4' 'FGR_HCK' 'FGR_YES1'
#  'FKBP1A_FKBP5' 'FN3K_FN3KRP' 'FRK_HCK' 'FRK_SRMS' 'FURIN_PCSK1'
#  'FURIN_PCSK7' 'FUT3_FUT7' 'FUT5_FUT7' 'FYN_LCK' 'FYN_YES1' 'GAA_MGAM'
#  'GALNT10_GALNT17' 'GALNT11_GALNTL5' 'GALNT12_GALNTL5' 'GALNT15_GALNTL6'
#  'GALNT1_GALNT14' 'GALNT1_GALNT5' 'GALNT2_GALNT14' 'GALNT2_GALNTL5'
#  'GALNT3_GALNT14' 'GALNT4_GALNT11' 'GALNT4_GALNT16' 'GALNT5_GALNT12'
#  'GALNT5_GALNTL5' 'GALNT6_GALNT16' 'GALNT8_GALNT18' 'GCK_HK1'
#  'GCNT1_GCNT2' 'GCNT2_GCNT7' 'GCNT3_GCNT4' 'GDPD2_GDPD5' 'GGT2P_GGTLC1'
#  'GK_GK2' 'GLB1_GLB1L' 'GLYATL2_GLYATL3' 'GNB1_GNB4' 'GNB2_GNB5'
#  'GNS_SULF1' 'GRAP2_GRB2' 'GRIP1_GRIP2' 'GRK1_GRK7' 'GRK2_GRK6'
#  'GRK3_GRK7' 'GRK4_GRK7' 'GRK6_GRK7' 'GUCY2D_GUCY2F' 'GXYLT1_GXYLT2'
#  'GZMB_GZMH' 'GZMH_GZMM' 'HABP2_LPA' 'HACD1_HACD2' 'HCK_LCK' 'HDAC1_HDAC2'
#  'HDAC5_HDAC7' 'HECW1_HECW2' 'HECW1_WWP2' 'HECW2_SMURF2' 'HERC3_HERC6'
#  'HGFAC_PLAT' 'HIC1_HIC2' 'HIPK2_HIPK4' 'HK1_HKDC1' 'HNRNPAB_HNRNPDL'
#  'HPRT1_PRTFDC1' 'HSPA12A_HSPA12B' 'HTRA1_HTRA4' 'HYAL1_HYAL4'
#  'HYAL2_SPAM1' 'IGF1R_INSRR' 'IMPDH1_IMPDH2' 'INPP5D_INPPL1' 'IRAK1_IRAK4'
#  'IRS1_IRS2' 'ITCH_WWP1' 'ITK_TXK' 'JAK1_JAK2' 'JAK3_TYK2' 'KALRN_TRIO'
#  'KATNAL1_VPS4B' 'KCNA10_KCNC2' 'KCNA1_KCNA3' 'KCNA1_KCNC2' 'KCNA1_KCND3'
#  'KCNA2_KCNA7' 'KCNA2_KCND2' 'KCNA3_KCNA5' 'KCNA3_KCND1' 'KCNA5_KCNA7'
#  'KCNA7_KCNC3' 'KCNB1_KCNB2' 'KCNB1_KCNS1' 'KCNB1_KCNV2' 'KCNB2_KCNG4'
#  'KCNC1_KCNC2' 'KCNC2_KCNC4' 'KCNF1_KCNG1' 'KCNF1_KCNV1' 'KCNG1_KCNV1'
#  'KCNG3_KCNS2' 'KCNG4_KCNS1' 'KCNH1_KCNH4' 'KCNH2_KCNH4' 'KCNH3_KCNH5'
#  'KCNH4_KCNH7' 'KCNH5_KCNH8' 'KCNS1_KCNS2' 'KCNS2_KCNV2' 'KCTD10_KCTD13'
#  'KCTD1_KCTD15' 'KCTD5_KCTD17' 'KCTD6_KCTD21' 'KCTD8_KCTD12' 'KDM4A_KDM4D'
#  'KDM4B_KDM4E' 'KDM5A_KDM5C' 'KDM6A_KDM6B' 'KEAP1_KLHL12' 'KEAP1_KLHL28'
#  'KIT_PDGFRA' 'KLHL12_KLHL17' 'KLHL13_KLHL26' 'KLHL14_KLHL36'
#  'KLHL18_KLHL20' 'KLHL1_KLHL12' 'KLHL1_KLHL28' 'KLHL1_KLHL8'
#  'KLHL21_KLHL30' 'KLHL24_KLHL25' 'KLHL26_KLHL31' 'KLHL26_KLHL36'
#  'KLHL2_KLHL20' 'KLHL31_KLHL36' 'KLHL3_KLHL18' 'KLHL40_KLHL41'
#  'KLHL4_KLHL20' 'KLHL5_KLHL17' 'KLHL6_KLHL35' 'KLHL8_KLHL20'
#  'KLHL9_KLHL22' 'KLK11_KLK13' 'KLK11_PRSS2' 'KLK12_PRSS2' 'KLK13_PRSS1'
#  'KLK14_PRSS3' 'KLK1_KLK7' 'KLK4_KLK5' 'KLK6_KLK15' 'KLK8_KLK11'
#  'KLK8_KLK15' 'KLK9_KLK12' 'KLK9_PRSS1' 'KMT2E_SETD5' 'LATS1_LATS2'
#  'LATS2_STK38L' 'LCK_SRMS' 'LCP1_PLS3' 'LDHA_UEVLD' 'LDLR_LRP2'
#  'LFNG_RFNG' 'LIPA_LIPN' 'LIPF_LIPK' 'LIPH_PNLIP' 'LIPJ_LIPN' 'LNX1_LNX2'
#  'LOXL3_LOXL4' 'LOX_LOXL4' 'LPCAT1_LPCAT4' 'LRP1B_LRP2' 'LRP1B_LRP8'
#  'LRP1_LRP5' 'LRP2_LRP5' 'LRP4_LRP6' 'LTBP1_LTBP2' 'LTBP3_LTBP4'
#  'LYN_PTK6' 'LYPLA2_LYPLAL1' 'MAGI1_MAGI2' 'MAP2K1_MAP2K3' 'MAP2K1_MAP2K7'
#  'MAP2K3_MAP2K5' 'MAP2K5_MAP2K6' 'MAP3K11_MAP3K21' 'MAP3K5_MAP3K6'
#  'MAP4K1_MAP4K3' 'MAP4K1_STK26' 'MAP4K2_STK26' 'MAP4K3_STK25'
#  'MAP4K4_TNIK' 'MAPK10_MAPK12' 'MAPK11_MAPK13' 'MAPK1_MAPK3' 'MAPK3_MAPK6'
#  'MAPK8IP3_SPAG9' 'MAPK8_MAPK13' 'MAPK9_MAPK12' 'MAPKAPK3_MAPKAPK5'
#  'MARK1_MARK4' 'MARK2_SIK3' 'MARK3_SIK3' 'MAST1_MAST3' 'MBOAT1_MBOAT2'
#  'ME1_ME2' 'MEP1A_MEP1B' 'MEX3A_MEX3B' 'MEX3B_MEX3D' 'MGAM2_SI'
#  'MIB1_MIB2' 'MKRN1_MKRN2' 'MMP10_MMP11' 'MMP10_MMP16' 'MMP10_MMP27'
#  'MMP11_MMP17' 'MMP12_MMP14' 'MMP12_MMP24' 'MMP13_MMP16' 'MMP13_MMP27'
#  'MMP14_MMP24' 'MMP15_MMP20' 'MMP15_MMP25' 'MMP16_MMP25' 'MMP17_MMP27'
#  'MMP1_MMP12' 'MMP1_MMP17' 'MMP1_MMP3' 'MMP20_MMP27' 'MMP2_MMP9'
#  'MMP3_MMP14' 'MMP3_MMP24' 'MMP7_MMP10' 'MMP7_MMP15' 'MMP7_MMP25'
#  'MMP8_MMP12' 'MMP8_MMP17' 'MOB1A_MOB1B' 'MOGAT1_MOGAT3' 'MPP1_MPP2'
#  'MPP2_MPP7' 'MPP3_PALS1' 'MPP7_PALS2' 'MTHFD1_MTHFD2' 'MTM1_MTMR3'
#  'MTM1_MTMR9' 'MTMR1_MTMR8' 'MTMR2_MTMR7' 'MTMR2_MTMR9' 'MTMR6_MTMR7'
#  'MTMR8_MTMR9' 'MYLK2_MYLK4' 'MYLK_MYLK4' 'NALF1_NALF2' 'NAT1_NAT2'
#  'NEDD4L_SMURF1' 'NEDD4_SMURF1' 'NEK1_NEK3' 'NEK3_NEK5' 'NEK6_NEK7'
#  'NEU2_NEU4' 'NFE2L1_NFE2L2' 'NIM1K_SIK3' 'NME3_NME4' 'NMNAT1_NMNAT3'
#  'NOMO2_NOMO3' 'NSD1_NSD2' 'NT5C_NT5M' 'NTRK2_NTRK3' 'NUDT3_NUDT11'
#  'OAS1_OAS3' 'OLFM1_OLFM3' 'OTULIN_OTULINL' 'PACSIN1_PACSIN3'
#  'PADI1_PADI6' 'PADI3_PADI6' 'PAK1_PAK5' 'PAK3_PAK5' 'PANK2_PANK3'
#  'PARP11_PARP12' 'PASK_PIM2' 'PCGF1_PCGF6' 'PCK1_PCK2' 'PCSK1_PCSK6'
#  'PCSK2_PCSK7' 'PCSK5_PCSK7' 'PDIA3_PDIA4' 'PDK2_PDK3' 'PDZD4_PDZRN3'
#  'PELI2_PELI3' 'PFKFB2_PFKFB4' 'PGA3_PGC' 'PGA5_REN' 'PGM1_PGM5'
#  'PHACTR1_PHACTR2' 'PHACTR3_PHACTR4' 'PHF2_PHF8' 'PHLDA1_PHLDA2'
#  'PIAS1_PIAS3' 'PIK3C2B_PIK3C2G' 'PIK3CB_PIK3CG' 'PIM1_PIM3'
#  'PIP4K2B_PIP5K1B' 'PKN1_PKN3' 'PLA2G1B_PLA2G10' 'PLA2G1B_PLA2G5'
#  'PLA2G2A_PLA2G5' 'PLA2G2E_PLA2G2F' 'PLA2G4B_PLA2G4E' 'PLA2G5_PLA2G10'
#  'PLAT_PLG' 'PLCB1_PLCD4' 'PLCB2_PLCZ1' 'PLCB4_PLCD1' 'PLCD1_PLCL1'
#  'PLCD3_PLCH2' 'PLCD4_PLCH1' 'PLCH1_PLCL1' 'PLCH2_PLCZ1' 'PLK3_PLK5'
#  'PLPP6_PLPP7' 'PLPPR2_PLPPR5' 'PLXNA1_PLXNA4' 'PLXNA2_PLXNA3'
#  'PLXNA2_PLXND1' 'PLXNA3_PLXND1' 'PLXNA4_PLXNB3' 'PLXNB1_PLXNB3'
#  'PNCK_PSKH1' 'PNPLA2_PNPLA3' 'PNPLA6_PNPLA7' 'POU1F1_POU3F2'
#  'POU3F2_POU3F3' 'PPM1A_PPM1B' 'PPP1R12B_PPP1R12C' 'PPP1R3D_PPP1R3E'
#  'PPP2R2A_PPP2R2D' 'PPP2R5A_PPP2R5B' 'PPP2R5B_PPP2R5D' 'PPP3CA_PPP3CB'
#  'PPP6R1_PPP6R3' 'PRB2_PRB4' 'PRKACA_PRKACG' 'PRKACB_PRKG1' 'PRKACG_PRKX'
#  'PRKAR1B_PRKAR2A' 'PRKCA_PRKCG' 'PRKCA_PRKCH' 'PRKCB_PRKCE' 'PRKCB_PRKCZ'
#  'PRKCD_PRKCZ' 'PRKCE_PRKCZ' 'PRKCG_PRKCZ' 'PRKCH_PRKCQ' 'PRKD1_PRKD2'
#  'PRKG2_PRKX' 'PRMT6_PRMT8' 'PRPS1_PRPS1L1' 'PRPS2_PRPSAP2' 'PRSS1_PRSS3'
#  'PRSS21_PRSS41' 'PRSS22_PRSS38' 'PRSS27_PRSS41' 'PRSS33_PRSS41'
#  'PRSS38_TPSG1' 'PRSS8_PRSS33' 'PSEN1_PSEN2' 'PTDSS1_PTDSS2' 'PTK6_SRMS'
#  'PTPN12_PTPN18' 'PTPN3_PTPN4' 'PTPRA_PTPRD' 'PTPRA_PTPRS' 'PTPRE_PTPRF'
#  'PTPRE_PTPRU' 'PTPRM_PTPRT' 'PYCARD_PYDC1' 'PYGB_PYGM' 'RAB40A_RAB40AL'
#  'RC3H1_RC3H2' 'RFPL1_RFPL4A' 'RFPL2_RFPL4AL1' 'RFPL4AL1_RFPL4B'
#  'RHBDL1_RHBDL3' 'RLF_ZNF292' 'RNASE2_RNASE6' 'RNASE3_RNASE8'
#  'RNASE6_RNASE8' 'RNF121_RNF175' 'RNF128_RNF149' 'RNF133_RNF148'
#  'RNF149_RNF150' 'RNF38_RNF44' 'ROCK1_STK38L' 'RPS6KA1_RPS6KA2'
#  'RPS6KA1_RPS6KB1' 'RPS6KA2_RPS6KA3' 'RPS6KA2_RPS6KB2' 'RPS6KA3_RPS6KA5'
#  'RPS6KA3_SGK3' 'RPS6KA4_SGK2' 'RPS6KA5_SGK3' 'RPS6KB1_RPS6KB2'
#  'RPS6KB2_SGK3' 'SBF1_SBF2' 'SCAMP1_SCAMP3' 'SCAMP3_SCAMP4' 'SCRN2_SCRN3'
# ...
#  'PARP1_PARP3' 'PCGF1_PCGF2' 'PCGF3_PCGF5' 'PCSK1_PCSK4' 'PCSK2_PCSK5'
#  'PCSK4_PCSK7' 'PDE6G_PDE6H' 'PDK1_PDK4' 'PDXP_PGP' 'PELI1_PELI3'
#  'PFKFB2_PFKFB3' 'PFKM_PFKP' 'PGA5_REN' 'PGPEP1_PGPEP1L' 'PHACTR2_PHACTR4'
#  'PHF21A_PHF21B' 'PHKG1_PHKG2' 'PIAS1_PIAS3' 'PIK3C2A_PIK3C2B'
#  'PIK3C2B_PIK3C2G' 'PIK3CB_PIK3CD' 'PIK3R2_PIK3R3' 'PIP4K2A_PIP4K2C'
#  'PJA1_PJA2' 'PKN2_PKN3' 'PLA2G1B_PLA2G2E' 'PLA2G2A_PLA2G2E'
#  'PLA2G2D_PLA2G2F' 'PLA2G2F_PLA2G5' 'PLA2G4D_PLA2G4E' 'PLAG1_PLAGL2'
#  'PLCB1_PLCB2' 'PLCB2_PLCB3' 'PLCB3_PLCD1' 'PLCB4_PLCZ1' 'PLCD3_PLCH1'
#  'PLCD4_PLCL1' 'PLCH1_PLCZ1' 'PLCL2_PLCZ1' 'PLPP1_PLPP3' 'PLPPR1_PLPPR3'
#  'PLPPR3_PLPPR5' 'PLXNA1_PLXNB1' 'PLXNA2_PLXNB1' 'PLXNA3_PLXNB1'
#  'PLXNA4_PLXNB2' 'PLXNB1_PLXND1' 'PNCK_PSKH1' 'PNPLA2_PNPLA3'
#  'PNPLA6_PNPLA7' 'POU1F1_POU3F2' 'POU3F2_POU3F3' 'PPM1A_PPM1B'
#  'PPM1H_PPM1M' 'PPP1R1A_PPP1R1C' 'PPP2R2A_PPP2R2C' 'PPP2R5A_PPP2R5B'
#  'PPP2R5B_PPP2R5E' 'PPP3CA_PPP3CC' 'PPP6R2_PPP6R3' 'PRDM1_ZNF683'
#  'PRKACA_PRKG1' 'PRKACB_PRKG2' 'PRKAG1_PRKAG2' 'PRKAR2A_PRKAR2B'
#  'PRKCA_PRKCH' 'PRKCB_PRKCE' 'PRKCD_PRKCE' 'PRKCD_PRKCZ' 'PRKCE_PRKCZ'
#  'PRKCH_PRKCI' 'PRKCQ_PRKCZ' 'PRKG1_PRKX' 'PRMT3_PRMT8' 'PRPS1L1_PRPSAP2'
#  'PRPS2_PRPSAP1' 'PRSS1_PRSS2' 'PRSS21_PRSS38' 'PRSS22_PRSS33'
#  'PRSS27_PRSS33' 'PRSS2_PRSS3' 'PRSS36_PRSS53' 'PRSS41_TPSG1'
#  'PRSS8_PRSS33' 'PRSS8_PRSS38' 'PSKH1_PSKH2' 'PTEN_TPTE' 'PTK6_YES1'
#  'PTPN12_PTPN22' 'PTPN3_PTPN4' 'PTPRA_PTPRD' 'PTPRA_PTPRS' 'PTPRD_PTPRS'
#  'PTPRE_PTPRT' 'PTPRK_PTPRT' 'PTPRT_PTPRU' 'QPCT_QPCTL' 'RAB40AL_RAB40C'
#  'RAB40B_RAB40C' 'RFPL1_RFPL2' 'RFPL2_RFPL4A' 'RFPL3_RFPL4B'
#  'RHBDL1_RHBDL2' 'RLF_ZNF292' 'RNASE2_RNASE6' 'RNASE3_RNASE8'
#  'RNF115_RNF126' 'RNF128_RNF149' 'RNF133_RNF148' 'RNF148_RNF149'
#  'RNF223_RNF225' 'RNFT1_RNFT2' 'ROCK1_STK38' 'RPS27_RPS27L'
#  'RPS6KA1_RPS6KA6' 'RPS6KA1_SGK3' 'RPS6KA2_RPS6KB2' 'RPS6KA3_RPS6KA5'
#  'RPS6KA4_RPS6KA5' 'RPS6KA5_RPS6KA6' 'RPS6KA6_RPS6KB1' 'RPS6KB1_SGK1'
#  'RPS6KB2_SGK3' 'SBF1_SBF2' 'SCAMP1_SCAMP3' 'SCAMP3_SCAMP4' 'SCRN2_SCRN3'
#  'SEMA3A_SEMA3B' 'SEMA3A_SEMA3G' 'SEMA3A_SEMA4G' 'SEMA3B_SEMA3E'
#  'SEMA3B_SEMA4D' 'SEMA3C_SEMA3G' 'SEMA3E_SEMA3F' 'SEMA4A_SEMA4D'
#  'SEMA4B_SEMA4G' 'SEMA4D_SEMA4G' 'SEMA6A_SEMA6D' 'SENP3_SENP5'
#  'SET_TSPYL4' 'SGK2_SGK3' 'SH3BP5_SH3BP5L' 'SHC1_SHC2' 'SIAH1_SIAH3'
#  'SIRT2_SIRT3' 'SLC24A1_SLC24A5' 'SLC27A1_SLC27A6' 'SLC27A3_SLC27A4'
#  'SLC27A5_SLC27A6' 'SLK_STK4' 'SMURF1_WWP2' 'SOAT1_SOAT2' 'SORCS1_SORCS2'
#  'SOX8_SOX9' 'SPOP_SPOPL' 'SPSB1_SPSB4' 'SRMS_YES1' 'SSH1_SSH2'
#  'ST3GAL3_ST3GAL4' 'ST6GALNAC1_ST6GALNAC2' 'STAMBP_STAMBPL1'
#  'STK17A_STK17B' 'STK32A_STK32C' 'STK3_STK26' 'STRN3_STRN4'
#  'SUCLA2_SUCLG2' 'SULT1A1_SULT1B1' 'SULT1A1_SULT2A1' 'SULT1A2_SULT1C2'
#  'SULT1A2_SULT2B1' 'SULT1A3_SULT2A1' 'SULT1A4_SULT1C4' 'SULT1B1_SULT1C3'
#  'SULT1C2_SULT1C3' 'SULT1C3_SULT1C4' 'SULT1C4_SULT1E1' 'SULT1C4_SULT2B1'
#  'SYK_ZAP70' 'TAOK1_TAOK3' 'TBC1D12_TBC1D14' 'TBC1D2_TBC1D2B'
#  'TBC1D8_TBC1D8B' 'TBL1X_TBL1XR1' 'TENM1_TENM3' 'TENT4A_TENT4B'
#  'TGM1_TGM2' 'TGM1_TGM7' 'TGM3_TGM6' 'TGM5_TGM6' 'TJP2_TJP3' 'TLE1_TLE3'
#  'TLE2_TLE5' 'TMEM59_TMEM59L' 'TMPRSS11B_TMPRSS11D' 'TMPRSS11E_TMPRSS11F'
#  'TMPRSS3_TMPRSS15' 'TMPRSS6_TMPRSS7' 'TNS1_TNS2' 'TNS3_TNS4'
#  'TPSB2_TPSD1' 'TRAF1_TRAF3' 'TRAF4_TRAF5' 'TRPM1_TRPM6' 'TSSK1B_TSSK3'
#  'TSSK2_TSSK6' 'TTLL1_TTLL9' 'UBA6_UBA7' 'UBE2D1_UBE2L6' 'UBE2E1_UBE2E2'
#  'UBR1_UBR2' 'UCK2_UCKL1' 'ULK1_ULK3' 'USP11_USP32' 'USP16_USP45'
#  'USP22_USP51' 'USP2_USP50' 'USP3_USP44' 'USP4_USP32' 'USP9Y_USP24'
#  'WDFY1_WDFY2' 'WNK2_WNK4' 'XPNPEP1_XPNPEP2' 'ZBTB12_ZBTB26'
#  'ZBTB34_ZBTB37' 'ZBTB7A_ZBTB7B' 'ZBTB8B_ZBTB46' 'ZFYVE9_ZFYVE16'
#  'ZNF362_ZNF384']
# Repeat 10, Fold 5:
#   TRAIN groups: ['A3GALT2_ABO' 'A3GALT2_GBGT1' 'A3GALT2_GLT6D1' ... 'ZNRF1_ZNRF2'
#  'ZXDA_ZXDC' 'ZXDB_ZXDC']
#   TEST groups: ['AADACL2_AADACL4' 'AADAC_AADACL4' 'ABL1_ABL2' 'ABL1_TXK' 'ABO_GBGT1'
#  'ACAA2_ACAT1' 'ACACA_ACACB' 'ACAD9_ACADSB' 'ACADM_ACADS' 'ACADM_ACADSB'
#  'ACADS_ACADVL' 'ACAT1_HADHB' 'ACHE_CES3' 'ACP3_ACP4' 'ACR_TMPRSS12'
#  'ACSM1_ACSM4' 'ACSM1_ACSM5' 'ACSM2B_ACSM5' 'ACSM4_ACSM5' 'ACVR1B_ACVRL1'
#  'ACVR1C_ACVR2B' 'ACVR1_ACVR1B' 'ACVR1_TGFBR1' 'ACVRL1_BMPR1B'
#  'ADAM11_ADAM23' 'ADAM15_ADAM19' 'ADAM19_ADAM33' 'ADAM21_ADAM30'
#  'ADAM2_ADAM32' 'ADAM8_ADAM19' 'ADAM9_ADAM30' 'ADAMTS10_ADAMTS19'
#  'ADAMTS15_ADAMTS20' 'ADAMTS16_ADAMTS18' 'ADAMTS17_ADAMTS19'
#  'ADAMTS2_ADAMTS14' 'ADAMTS4_ADAMTS5' 'ADAMTS5_ADAMTS8' 'ADAMTS6_ADAMTS17'
#  'ADAMTS7_ADAMTS16' 'ADAMTS8_ADAMTS20' 'ADAMTSL4_THSD4' 'ADCK1_ADCK5'
#  'AEBP1_CPE' 'AFF1_AFF4' 'AGBL2_AGBL3' 'AGXT2_ETNPPL' 'AICDA_APOBEC3C'
#  'AK1_AK5' 'AKAP13_ARHGEF18' 'AKT1_RPS6KA4' 'AKT1_SGK1' 'AKT2_RPS6KA2'
#  'AKT2_RPS6KA5' 'AKT2_SGK3' 'AKT3_RPS6KB1' 'ALAS1_ALAS2' 'ALPI_ALPL'
#  'AMPD1_AMPD2' 'ANKK1_RIPK4' 'ANP32A_ANP32D' 'ANP32B_ANP32E' 'ANPEP_LVRN'
#  'AP2A1_AP2A2' 'APOBEC3A_APOBEC3G' 'APOBEC3B_APOBEC3G' 'APOBEC3B_APOBEC3H'
#  'APOBEC3D_APOBEC3H' 'APOBEC3G_APOBEC3H' 'ARSA_ARSD' 'ARSA_GALNS'
#  'ARSA_STS' 'ARSB_ARSJ' 'ARSD_ARSL' 'ARSG_GALNS' 'ARSL_GALNS' 'ART4_ART5'
#  'ASB14_ASB15' 'ASB4_ASB18' 'ASB5_ASB13' 'ATG16L1_ATG16L2' 'ATG4A_ATG4B'
#  'ATP11B_ATP11C' 'ATP13A3_ATP13A5' 'ATP1A2_ATP1A3' 'ATP1A3_ATP1A4'
#  'ATP2B1_ATP2B2' 'ATP2B3_ATP2B4' 'ATP2C1_ATP2C2' 'ATP6V0A2_ATP6V0A4'
#  'ATP8A1_ATP8A2' 'ATP8A2_ATP11A' 'ATP8A2_ATP8B1' 'ATP8B1_ATP8B2'
#  'ATP8B2_ATP11C' 'ATP8B2_ATP8B3' 'ATP9A_ATP9B' 'ATXN1_ATXN1L'
#  'AWAT1_AWAT2' 'AWAT2_DGAT2L6' 'AWAT2_MOGAT3' 'B3GALT2_B3GALT5'
#  'B3GNT2_B3GNT4' 'B3GNT2_B3GNT8' 'B3GNT4_B3GNT6' 'B3GNT6_B3GNT8'
#  'BACE1_BACE2' 'BACH1_BACH2' 'BCL6_BCL6B' 'BIRC2_BIRC3' 'BIRC7_BIRC8'
#  'BLK_LYN' 'BLK_YES1' 'BMP1_TLL2' 'BMPR1A_BMPR1B' 'BPGM_PGAM1'
#  'BPGM_PGAM2' 'BRWD1_BRWD3' 'BTBD10_KCTD20' 'BTBD1_BTBD3' 'BTD_VNN1'
#  'C1R_C1RL' 'C1R_C1S' 'CABP1_CALM2' 'CABP1_CALM3' 'CABP5_CALM3'
#  'CALM1_CALM2' 'CALM1_CALML4' 'CALM2_CALML4' 'CALM3_CALML4' 'CALM3_TNNC2'
#  'CAMK1D_CAMK2G' 'CAMK1G_CAMK2A' 'CAMK1G_CAMK4' 'CAMK1_CAMK1G'
#  'CAMK1_CAMK2A' 'CAMK1_PSKH1' 'CAMK2A_CAMK2D' 'CAMK2D_CAMK4' 'CAMK2D_PNCK'
#  'CAMKK1_CAMKK2' 'CAPN1_CAPN11' 'CAPN1_CAPN3' 'CAPN1_CAPN5' 'CAPN2_CAPN5'
#  'CAPN2_CAPN9' 'CAPN3_CAPN11' 'CAPN5_CAPN6' 'CAPN8_CAPN11' 'CAPN8_CAPN12'
#  'CAPN8_CAPN9' 'CAPNS1_CAPNS2' 'CARM1_PRMT6' 'CASK_MPP1' 'CASP1_CASP5'
#  'CASP3_CASP8' 'CBL_CBLB' 'CCL2_CCL11' 'CCL2_CCL8' 'CCL5_CCL14'
#  'CCL8_CCL11' 'CCL8_CCL13' 'CD5L_CD163' 'CD5L_CD163L1' 'CDC42BPA_CDC42BPB'
#  'CDC42BPB_CDC42BPG' 'CDC42BPB_DMPK' 'CDK14_CDK15' 'CDK15_CDK17'
#  'CDK15_CDK18' 'CDK20_CDKL4' 'CDKL1_CDKL4' 'CDKL1_CDKL5' 'CDKL4_CDKL5'
#  'CDKN2B_CDKN2D' 'CDYL_CDYL2' 'CEACAM1_CEACAM7' 'CEACAM4_CEACAM21'
#  'CEACAM7_PSG3' 'CELA1_CELA2A' 'CELA1_CELA3B' 'CELA2A_CELA3B'
#  'CELA2A_CTRB1' 'CELA2B_CTRL' 'CELA3A_CTRL' 'CELA3B_CTRB1' 'CEPT1_CHPT1'
#  'CES1_NLGN4Y' 'CES2_CES3' 'CES2_NLGN4Y' 'CES3_NLGN1' 'CES5A_NLGN2'
#  'CES5A_NLGN4X' 'CFD_GZMK' 'CHI3L1_OVGP1' 'CHIA_CHIT1' 'CHIT1_OVGP1'
#  'CHPF_CHPF2' 'CHST13_CHST14' 'CHST8_CHST13' 'CHSY1_CHSY3' 'CIB1_CIB3'
#  'CIB1_CIB4' 'CIB2_CIB3' 'CKB_CKMT2' 'CKM_CKMT2' 'CLCN6_CLCN7' 'CMA1_GZMA'
#  'COMT_LRTOMT' 'COQ8A_COQ8B' 'CORO1B_CORO2A' 'CORO1C_CORO2A' 'CPA1_CPA5'
#  'CPA1_CPA6' 'CPA1_CPB2' 'CPA2_CPB1' 'CPA4_CPA5' 'CPA5_CPA6' 'CPA5_CPB2'
#  'CPD_CPN1' 'CPD_CPXM1' 'CPM_CPXM1' 'CPM_CPZ' 'CPNE2_CPNE3' 'CPT1A_CPT1C'
#  'CREBBP_EP300' 'CRMP1_DPYS' 'CRYAB_HSPB8' 'CSGALNACT1_CSGALNACT2'
#  'CSK_ITK' 'CSNK1A1L_TTBK2' 'CSNK1D_TTBK2' 'CSNK1G1_CSNK1G3'
#  'CT47A12_CT47B1' 'CT47A1_CT47B1' 'CT47A9_CT47B1' 'CTDSP2_CTDSPL'
#  'CTSC_CTSZ' 'CTSD_NAPSA' 'CTSE_PGA5' 'CTSE_PGC' 'CTSG_GZMB' 'CTSG_GZMK'
#  'CTSH_CTSS' 'CTSS_CTSV' 'DAPK1_MYLK4' 'DAPK1_STK17A' 'DAPK2_MYLK3'
#  'DAPK3_STK17B' 'DCAF4_DCAF4L1' 'DCAF8_DCAF8L1' 'DCAF8_DCAF8L2'
#  'DCBLD2_RS1' 'DDHD2_SEC23IP' 'DGAT2L6_MOGAT1' 'DGAT2_DGAT2L6'
#  'DGAT2_MOGAT3' 'DGKB_DGKG' 'DGKI_DGKZ' 'DLG1_DLG3' 'DMPK_ROCK1'
#  'DNAH11_DNAH17' 'DNAH2_DNAH11' 'DNAH3_DNAH6' 'DPEP1_DPEP2' 'DPF2_DPF3'
#  'DPP6_DPP10' 'DPYSL2_DPYSL4' 'DPYS_DPYSL2' 'DTX1_DTX4' 'DUSP13B_STYXL2'
#  'DUSP15_DUSP22' 'DUSP1_DUSP4' 'DUSP1_DUSP9' 'DUSP2_DUSP4' 'DUSP2_DUSP9'
#  'DUSP4_DUSP5' 'DUSP8_DUSP16' 'DYRK2_DYRK4' 'ECE1_ECEL1' 'ECE2_KEL'
#  'ECEL1_MMEL1' 'EFEMP1_EFEMP2' 'EFEMP1_FBLN5' 'EFNA3_EFNA4' 'EGFR_ERBB2'
#  'EGFR_ERBB4' 'ELANE_PRTN3' 'ELOA_ELOA3DP' 'ELOVL1_ELOVL7' 'ELOVL2_ELOVL5'
#  'ELOVL5_ELOVL7' 'EML2_EML3' 'EML5_EML6' 'ENPEP_ERAP1' 'ENPP1_ENPP3'
#  'ENPP3_ENPP4' 'ENPP5_ENPP7' 'ENTPD2_ENTPD3' 'EPB42_TGM5' 'EPHA1_EPHA10'
#  'EPHA1_EPHA6' 'EPHA1_EPHB4' 'EPHA2_EPHA6' 'EPHA3_EPHA4' 'EPHA3_EPHB3'
#  'EPHA4_EPHA7' 'EPHA5_EPHA10' 'EPHA5_EPHB3' 'EPHA6_EPHB3' 'EPHA7_EPHB3'
#  'EPHA8_EPHB4' 'EPHX3_EPHX4' 'EPS8_EPS8L3' 'ERAP2_TRHDE' 'ETNK1_ETNK2'
#  'EXT2_EXTL3' 'EYA2_EYA4' 'F11_KLKB1' 'F13A1_TGM1' 'F7_F10' 'FAHD1_FAHD2A'
#  'FAM20A_FAM20B' 'FBXL2_FBXL20' 'FBXO2_FBXO6' 'FBXO6_FBXO17' 'FER_MATK'
#  'FES_TXK' 'FGFR1_FGFR4' 'FGR_FRK' 'FGR_SRC' 'FKBP1A_FKBP4' 'FLT4_KDR'
#  'FOXP1_FOXP2' 'FRK_LCK' 'FRK_YES1' 'FURIN_PCSK2' 'FUT10_FUT11'
#  'FUT3_FUT7' 'FUT5_FUT6' 'FUT7_FUT9' 'FYN_SRC' 'G6PC1_G6PC3' 'GALK1_GALK2'
#  'GALNT11_GALNT12' 'GALNT12_GALNT13' 'GALNT13_GALNT16' 'GALNT16_GALNTL5'
#  'GALNT1_GALNT16' 'GALNT1_GALNT6' 'GALNT2_GALNT12' 'GALNT2_GALNT16'
#  'GALNT2_GALNTL5' 'GALNT3_GALNT16' 'GALNT4_GALNT11' 'GALNT4_GALNT5'
#  'GALNT5_GALNT13' 'GALNT6_GALNT11' 'GALNT6_GALNTL5' 'GALNT8_GALNT9'
#  'GCA_SRI' 'GCNT1_GCNT2' 'GCNT3_GCNT4' 'GDPD2_GDPD5' 'GGT2P_GGT5'
#  'GIPC1_GIPC3' 'GLB1L_GLB1L3' 'GLYATL2_GLYATL3' 'GNB1_GNB3' 'GNB2_GNB5'
#  'GNS_SULF1' 'GRAP2_GRAPL' 'GRIP1_GRIP2' 'GRK1_GRK7' 'GRK2_GRK7'
#  'GRK4_GRK5' 'GRK6_GRK7' 'GUCY2D_NPR1' 'GYG1_GYG2' 'GZMA_PRSS57'
#  'GZMH_GZMK' 'GZMM_PRSS57' 'HABP2_PLG' 'HAS2_HAS3' 'HCK_SRMS'
#  'HDAC4_HDAC9' 'HDHD2_LHPP' 'HECW1_SMURF2' 'HECW2_SMURF1' 'HERC3_HERC5'
#  'HGFAC_PLAT' 'HIC1_HIC2' 'HIPK2_HIPK3' 'HK1_HKDC1' 'HPN_TMPRSS13'
#  'HPSE_HPSE2' 'HSPB6_HSPB8' 'HTRA1_HTRA4' 'HTRA3_HTRA4' 'HYAL2_HYAL3'
#  'HYAL4_SPAM1' 'IKBKE_TBK1' 'INPP4A_INPP4B' 'IP6K1_IP6K3'
#  'IRF2BP2_IRF2BPL' 'ITCH_SMURF2' 'ITK_MATK' 'ITPKB_ITPKC' 'JAK2_TYK2'
#  'JMJD1C_KDM3B' 'KAT6A_KAT7' 'KBTBD2_KBTBD8' 'KCNA10_KCNC4' 'KCNA1_KCNA7'
#  'KCNA1_KCND2' 'KCNA2_KCNA5' 'KCNA2_KCNC4' 'KCNA3_KCNA4' 'KCNA3_KCNC4'
#  'KCNA4_KCNC1' 'KCNA7_KCNC2' 'KCNA7_KCND3' 'KCNB1_KCNG3' 'KCNB1_KCNV2'
#  'KCNB2_KCNG4' 'KCNB2_KCNV2' 'KCNC2_KCNC4' 'KCNF1_KCNG1' 'KCNF1_KCNV1'
#  'KCNG1_KCNS2' 'KCNG2_KCNS1' 'KCNG3_KCNS3' 'KCNG4_KCNS3' 'KCNH1_KCNH6'
#  'KCNH2_KCNH5' 'KCNH3_KCNH5' 'KCNH4_KCNH6' 'KCNH5_KCNH8' 'KCNN3_KCNN4'
#  'KCNS2_KCNS3' 'KCNV1_KCNV2' 'KCTD13_TNFAIP1' 'KCTD3_KCTD5' 'KCTD6_KCTD21'
#  'KDM3A_KDM3B' 'KDM4B_KDM4C' 'KDM5A_KDM5B' 'KDM5C_KDM5D' 'KEAP1_KLHL1'
#  'KEAP1_KLHL20' 'KIF21A_KIF21B' 'KLHDC8A_KLHDC8B' 'KLHL13_KLHL14'
#  'KLHL13_KLHL32' 'KLHL14_KLHL36' 'KLHL17_KLHL18' 'KLHL1_KLHL12'
#  'KLHL1_KLHL28' 'KLHL20_KLHL28' 'KLHL21_KLHL35' 'KLHL24_KLHL25'
#  'KLHL26_KLHL32' 'KLHL2_KLHL18' 'KLHL2_KLHL5' 'KLHL3_KLHL17' 'KLHL3_KLHL5'
#  'KLHL4_KLHL18' 'KLHL5_KLHL12' 'KLHL5_KLHL8' 'KLHL8_KLHL18' 'KLHL9_KLHL15'
#  'KLHL9_KLHL36' 'KLK11_PRSS1' 'KLK12_KLK15' 'KLK13_KLK15' 'KLK14_PRSS2'
#  'KLK1_KLK2' 'KLK3_KLK7' 'KLK6_KLK14' 'KLK6_PRSS2' 'KLK8_KLK14'
#  'KLK8_PRSS3' 'KLK9_KLK15' 'KMT2C_KMT2D' 'LALBA_SPACA5B' 'LATS2_STK38'
#  'LCK_SRC' 'LDHAL6A_UEVLD' 'LDLR_LRP1' 'LFNG_MFNG' 'LIPA_LIPJ' 'LIPC_LPL'
#  'LIPG_LPL' 'LIPJ_LIPK' 'LIPM_LIPN' 'LONRF2_LONRF3' 'LOX_LOXL2' 'LPA_PLG'
#  'LPIN1_LPIN3' 'LRP1B_LRP5' 'LRP1_LRP4' 'LRP2_LRP5' 'LRP4_LRP6'
#  'LTA4H_RNPEP' 'LTBP2_LTBP4' 'LVRN_TRHDE' 'LYPLA1_LYPLA2' 'LYZ_SPACA5B'
#  'MAN2A1_MAN2A2' 'MAP2K1_MAP2K4' 'MAP2K1_MAP2K6' 'MAP2K2_MAP2K6'
#  'MAP2K3_MAP2K7' 'MAP2K6_MAP2K7' 'MAP3K2_MAP3K19' 'MAP3K6_MAP3K15'
#  'MAP4K1_MAP4K3' 'MAP4K1_STK4' 'MAP4K2_STK26' 'MAP4K3_STK26'
#  'MAP4K5_STK24' 'MAPK10_MAPK12' 'MAPK11_MAPK14' 'MAPK1_MAPK4'
#  'MAPK8IP1_MAPK8IP2' 'MAPK8_MAPK13' 'MAPK9_MAPK12' 'MAPKAPK3_MAPKAPK5'
#  'MARK1_MARK4' 'MARK2_SIK3' 'MARK4_NIM1K' 'MAST1_MAST4' 'MBOAT1_MBOAT2'
#  'ME1_ME3' 'METAP1_METAP1D' 'MEX3A_MEX3C' 'MFGE8_NRP1' 'MGAM_SI'
#  'MID1_MID2' 'MKRN1_MKRN3' 'MMP10_MMP11' 'MMP10_MMP16' 'MMP10_MMP27'
#  'MMP11_MMP16' 'MMP11_MMP27' 'MMP12_MMP17' 'MMP13_MMP14' 'MMP13_MMP24'
#  'MMP14_MMP17' 'MMP15_MMP16' 'MMP15_MMP27' 'MMP16_MMP27' 'MMP19_MMP26'
#  'MMP1_MMP13' 'MMP1_MMP16' 'MMP1_MMP24' 'MMP1_MMP8' 'MMP24_MMP25'
#  'MMP3_MMP11' 'MMP3_MMP16' 'MMP3_MMP27' 'MMP7_MMP13' 'MMP7_MMP20'
#  'MMP8_MMP10' 'MMP8_MMP15' 'MMP8_MMP25' 'MOB1B_MOB3C' 'MOV10_MOV10L1'
#  'MPP2_MPP3' 'MPP3_MPP7' 'MPP7_PALS1' 'MTF2_PHF1' 'MTM1_MTMR1'
#  'MTM1_MTMR7' 'MTMR1_MTMR3' 'MTMR1_MTMR9' 'MTMR2_MTMR6' 'MTMR3_MTMR9'
#  'MTMR7_MTMR8' 'MYB_MYBL1' 'MYLK_MYLK2' 'NAALAD2_NAALADL1' 'NAPSA_PGA4'
#  'NBEAL1_NBEAL2' 'NEDD4L_SMURF1' 'NEDD4_SMURF2' 'NEK1_NEK5' 'NEK3_NEK6'
#  'NEK7_NEK8' 'NEU3_NEU4' 'NFE2_NFE2L1' 'NLN_THOP1' 'NME6_NME7'
#  'NOMO1_NOMO2' 'NRK_TNIK' 'NSD2_NSD3' 'NT5C2_NT5DC4' 'NTRK1_NTRK2'
#  'NUDT12_NUDT13' 'NUDT4_NUDT11' 'OBSCN_OBSL1' 'OTUD6A_OTUD6B' 'P4HB_PDIA3'
#  'PADI1_PADI4' 'PADI3_PADI4' 'PAK1_PAK3' 'PAK2_PAK5' 'PANK1_PANK2'
#  'PAPPA_PAPPA2' 'PARP2_PARP3' 'PCGF1_PCGF3' 'PCGF3_PCGF6' 'PCSK1_PCSK5'
#  'PCSK2_PCSK6' 'PCSK5_PCSK6' 'PDGFRA_PDGFRB' 'PDK2_PDK3' 'PDZD4_PDZRN3'
#  'PELI2_PELI3' 'PFKFB2_PFKFB4' 'PGA3_REN' 'PGAM1_PGAM2' 'PHACTR1_PHACTR2'
#  'PHACTR3_PHACTR4' 'PHF2_PHF8' 'PHLDA1_PHLDA2' 'PIAS1_PIAS4'
#  'PIK3C2A_PIK3C2G' 'PIK3CB_PIK3CG' 'PIM1_PIM2' 'PIP4K2B_PIP4K2C'
#  'PKN1_PKN2' 'PKN2_PRKCQ' 'PLA2G1B_PLA2G2F' 'PLA2G2A_PLA2G2F'
#  'PLA2G2D_PLA2G5' 'PLA2G4A_PLA2G4F' 'PLA2G4D_PLA2G4F' 'PLAGL1_PLAGL2'
#  'PLCB1_PLCB3' 'PLCB2_PLCB4' 'PLCB3_PLCD4' 'PLCD1_PLCH1' 'PLCD3_PLCH2'
#  'PLCD3_PLCL2' 'PLCD4_PLCL2' 'PLCH2_PLCL1' 'PLK2_PLK3' 'PLPP2_PLPP3'
#  'PLPPR1_PLPPR4' 'PLPPR4_PLPPR5' 'PLXNA1_PLXNB2' 'PLXNA2_PLXNB2'
#  'PLXNA3_PLXNB2' 'PLXNA4_PLXNB3' 'PLXNB2_PLXNB3' 'PNCK_PSKH2'
#  'PNPLA2_PNPLA4' 'POC1A_POC1B' 'POU2F1_POU3F2' 'POU3F2_POU3F4'
#  'PPM1A_PPM1N' 'PPM1J_PPM1M' 'PPP1R3D_PPP1R3E' 'PPP2R2A_PPP2R2D'
#  'PPP2R5A_PPP2R5C' 'PPP2R5C_PPP2R5D' 'PPP3CB_PPP3CC' 'PRB1_PRB2'
#  'PRKAA1_PRKAA2' 'PRKACA_PRKG2' 'PRKACB_PRKX' 'PRKAG1_PRKAG3'
#  'PRKCA_PRKCB' 'PRKCA_PRKCI' 'PRKCB_PRKCG' 'PRKCD_PRKCG' 'PRKCE_PRKCG'
#  'PRKCG_PRKCH' 'PRKCH_PRKCQ' 'PRKD1_PRKD2' 'PRKG2_PRKX' 'PRMT6_PRMT8'
#  'PRPS1_PRPS1L1' 'PRPS2_PRPSAP2' 'PRSS1_PRSS3' 'PRSS21_PRSS41'
#  'PRSS22_PRSS38' 'PRSS27_PRSS38' 'PRSS33_PRSS38' 'PRSS37_PRSS58'
#  'PRSS48_TPSG1' 'PRSS8_PRSS41' 'PSMB8_PSMB11' 'PTEN_TPTE2' 'PTP4A1_PTP4A2'
#  'PTPN13_PTPN20' 'PTPN5_PTPN7' 'PTPRA_PTPRE' 'PTPRA_PTPRT' 'PTPRE_PTPRF'
#  'PTPRE_PTPRU' 'PTPRK_PTPRU' 'PYCARD_PYDC1' 'RAB40AL_RAB40B'
#  'RABGAP1_RABGAP1L' 'RFPL1_RFPL3' 'RFPL1_RFPL4AL1' 'RFPL2_RFPL4AL1'
#  'RFPL4AL1_RFPL4B' 'RHBDL1_RHBDL3' 'RLIM_RNF6' 'RNASE2_RNASE7'
#  'RNASE6_RNASE7' 'RNF125_RNF166' 'RNF128_RNF150' 'RNF133_RNF150'
#  'RNF148_RNF150' 'RNF24_RNF122' 'ROCK1_STK38L' 'RPS6KA1_RPS6KA2'
#  'RPS6KA1_RPS6KB1' 'RPS6KA2_RPS6KA3' 'RPS6KA2_RPS6KA4' 'RPS6KA2_SGK1'
#  'RPS6KA3_RPS6KA6' 'RPS6KA4_RPS6KA6' 'RPS6KA5_RPS6KB1' 'RPS6KA6_RPS6KB2'
#  'RPS6KB1_SGK2' 'RPS6KC1_RPS6KL1' 'SBK1_SBK2' 'SCAMP1_SCAMP4'
#  'SCAMP3_SCAMP5' 'SDS_SDSL' 'SEMA3A_SEMA3C' 'SEMA3A_SEMA4C'
#  'SEMA3B_SEMA3F' 'SEMA3B_SEMA4G' 'SEMA3C_SEMA4B' 'SEMA3E_SEMA3G'
#  'SEMA4A_SEMA4G' 'SEMA4C_SEMA4D' 'SEMA4F_SEMA4G' 'SEMA6B_SEMA6C'
#  'SEPHS1_SEPHS2' 'SFRP1_SFRP2' 'SGMS1_SGMS2' 'SH3GLB1_SH3GLB2' 'SHC1_SHC3'
#  'SIAH2_SIAH3' 'SIRT6_SIRT7' 'SLC24A1_SLC24A3' 'SLC27A1_SLC27A2'
#  'SLC27A2_SLC27A3' 'SLC27A3_SLC27A5' 'SLK_STK10' 'SMARCA2_SMARCA4'
#  'SMURF2_WWP1' 'SOCS4_SOCS5' 'SOX9_SOX10' 'SPPL2A_SPPL2B' 'SPSB2_SPSB4'
#  'SRPK1_SRPK2' 'SSH1_SSH3' 'ST3GAL3_ST3GAL5' 'ST6GALNAC3_ST6GALNAC4'
#  'STC1_STC2' 'STK24_STK25' 'STK32B_STK32C' 'STK4_STK24' 'STRN_STRN3'
#  'SULF1_SULF2' 'SULT1A1_SULT1C2' 'SULT1A1_SULT2B1' 'SULT1A2_SULT1C3'
#  'SULT1A3_SULT1B1' 'SULT1A3_SULT2B1' 'SULT1A4_SULT1E1' 'SULT1B1_SULT1C4'
#  'SULT1C2_SULT1C4' 'SULT1C3_SULT1E1' 'SULT1E1_SULT2A1' 'SYNJ1_SYNJ2'
#  'TAOK2_TAOK3' 'TBC1D15_TBC1D17' 'TBC1D3_TBC1D28' 'TBC1D8_TBC1D9'
#  'TBL1X_TBL1Y' 'TENM1_TENM4' 'TESK1_TESK2' 'TGM1_TGM3' 'TGM2_TGM3'
#  'TGM2_TGM7' 'TGM3_TGM7' 'TGM5_TGM7' 'TKTL1_TKTL2' 'TLE1_TLE4' 'TLE3_TLE4'
#  'TMPRSS11A_TMPRSS11B' 'TMPRSS11B_TMPRSS11E' 'TMPRSS2_TMPRSS3'
#  'TMPRSS3_TMPRSS4' 'TMPRSS9_TMPRSS11E' 'TNS1_TNS3' 'TOR1A_TOR1B'
#  'TPST1_TPST2' 'TRAF1_TRAF5' 'TRIB1_TRIB2' 'TRPM3_TRPM6' 'TSPAN17_TSPAN33'
#  'TSSK1B_TSSK4' 'TSSK3_TSSK4' 'TTLL3_TTLL8' 'UBASH3A_UBASH3B'
#  'UBE2D2_UBE2E3' 'UBE2E3_UBE2L6' 'UBTD1_UBTD2' 'UFSP1_UFSP2' 'ULK2_ULK3'
#  'USP12_USP35' 'USP17L10_USP17L29' 'USP26_USP29' 'USP31_USP43'
#  'USP3_USP49' 'USP53_USP54' 'VNN1_VNN2' 'WDFY3_WDFY4' 'WNK3_WNK4'
#  'XYLT1_XYLT2' 'ZBTB18_ZBTB42' 'ZBTB3_ZBTB18' 'ZBTB7A_ZBTB7C'
#  'ZBTB9_ZBTB22' 'ZMIZ1_ZMIZ2' 'ZNF423_ZNF521']

# %%
# Save splits
splits_path = get_data_path(['data', 'output', 'models', 'model_III'], 'repeated_splits_III.pkl')
with open(splits_path, 'wb') as f:
    pickle.dump(repeated_splits_III, f)

# %%
#Run cross-validation on both feature set
model_III_contextualized_repeated = model_contextualized_cross_validation(RF, data_1, target, repeated_splits_III, model_name="Model III contextualized Repeated")
model_III_full_repeated = model_full_cross_validation(RF, data_2, target, repeated_splits_III, model_name="Model III full Repeated")
# Out:
# Fold 1: Train size = 33340, Test size = 8390
#   [Model III Early Repeated - Fold 1] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0067 (diff: 0.0003)
#     Test SL rate:    0.0050 (diff: 0.0013)
#     Train/Test diff: 0.0017
# Stratification OK
#   ROC AUC = 0.9148, Elapsed time = 43.28 seconds
# Fold 2: Train size = 33430, Test size = 8300
#   [Model III Early Repeated - Fold 2] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0066 (diff: 0.0002)
#     Test SL rate:    0.0055 (diff: 0.0008)
#     Train/Test diff: 0.0010
# Stratification OK
#   ROC AUC = 0.9172, Elapsed time = 79.63 seconds
# Fold 3: Train size = 33370, Test size = 8360
#   [Model III Early Repeated - Fold 3] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0060 (diff: 0.0003)
#     Test SL rate:    0.0077 (diff: 0.0013)
#     Train/Test diff: 0.0016
# Stratification OK
#   ROC AUC = 0.9726, Elapsed time = 116.66 seconds
# Fold 4: Train size = 33430, Test size = 8300
#   [Model III Early Repeated - Fold 4] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0002)
#     Test SL rate:    0.0072 (diff: 0.0009)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9339, Elapsed time = 153.74 seconds
# Fold 5: Train size = 33350, Test size = 8380
#   [Model III Early Repeated - Fold 5] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0063 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9323, Elapsed time = 190.92 seconds
# Fold 6: Train size = 33350, Test size = 8380
#   [Model III Early Repeated - Fold 6] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0006)
#     Test SL rate:    0.0087 (diff: 0.0024)
#     Train/Test diff: 0.0030
# Stratification OK
#   ROC AUC = 0.9616, Elapsed time = 223.27 seconds
# Fold 7: Train size = 33420, Test size = 8310
#   [Model III Early Repeated - Fold 7] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0063 (diff: 0.0001)
#     Test SL rate:    0.0067 (diff: 0.0004)
#     Train/Test diff: 0.0005
# Stratification OK
#   ROC AUC = 0.9239, Elapsed time = 257.19 seconds
# Fold 8: Train size = 33440, Test size = 8290
#   [Model III Early Repeated - Fold 8] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0063 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9272, Elapsed time = 290.73 seconds
# Fold 9: Train size = 33350, Test size = 8380
#   [Model III Early Repeated - Fold 9] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0067 (diff: 0.0004)
#     Test SL rate:    0.0048 (diff: 0.0016)
#     Train/Test diff: 0.0020
# Stratification OK
#   ROC AUC = 0.9484, Elapsed time = 324.22 seconds
# Fold 10: Train size = 33360, Test size = 8370
#   [Model III Early Repeated - Fold 10] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0066 (diff: 0.0003)
#     Test SL rate:    0.0053 (diff: 0.0011)
#     Train/Test diff: 0.0014
# Stratification OK
#   ROC AUC = 0.9102, Elapsed time = 359.02 seconds
# Fold 11: Train size = 33350, Test size = 8380
#   [Model III Early Repeated - Fold 11] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0062 (diff: 0.0001)
#     Test SL rate:    0.0068 (diff: 0.0005)
#     Train/Test diff: 0.0006
# Stratification OK
#   ROC AUC = 0.9394, Elapsed time = 393.31 seconds
# Fold 12: Train size = 33350, Test size = 8380
#   [Model III Early Repeated - Fold 12] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0062 (diff: 0.0001)
#     Train/Test diff: 0.0002
# Stratification OK
#   ROC AUC = 0.9533, Elapsed time = 427.44 seconds
# Fold 13: Train size = 33450, Test size = 8280
#   [Model III Early Repeated - Fold 13] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0063 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9300, Elapsed time = 461.45 seconds
# Fold 14: Train size = 33350, Test size = 8380
#   [Model III Early Repeated - Fold 14] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0003)
#     Test SL rate:    0.0074 (diff: 0.0010)
#     Train/Test diff: 0.0013
# Stratification OK
#   ROC AUC = 0.9306, Elapsed time = 495.93 seconds
# Fold 15: Train size = 33420, Test size = 8310
#   [Model III Early Repeated - Fold 15] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0067 (diff: 0.0004)
#     Test SL rate:    0.0049 (diff: 0.0014)
#     Train/Test diff: 0.0018
# Stratification OK
#   ROC AUC = 0.9553, Elapsed time = 531.49 seconds
# Fold 16: Train size = 33430, Test size = 8300
#   [Model III Early Repeated - Fold 16] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0002)
#     Test SL rate:    0.0072 (diff: 0.0009)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9401, Elapsed time = 566.48 seconds
# Fold 17: Train size = 33440, Test size = 8290
#   [Model III Early Repeated - Fold 17] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0066 (diff: 0.0003)
#     Test SL rate:    0.0052 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.9360, Elapsed time = 600.43 seconds
# Fold 18: Train size = 33340, Test size = 8390
#   [Model III Early Repeated - Fold 18] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0063 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9235, Elapsed time = 635.34 seconds
# Fold 19: Train size = 33360, Test size = 8370
#   [Model III Early Repeated - Fold 19] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0063 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9635, Elapsed time = 669.59 seconds
# Fold 20: Train size = 33350, Test size = 8380
#   [Model III Early Repeated - Fold 20] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0063 (diff: 0.0001)
#     Test SL rate:    0.0067 (diff: 0.0003)
#     Train/Test diff: 0.0004
# Stratification OK
#   ROC AUC = 0.9484, Elapsed time = 703.21 seconds
# Fold 21: Train size = 33450, Test size = 8280
#   [Model III Early Repeated - Fold 21] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0003)
#     Test SL rate:    0.0075 (diff: 0.0011)
#     Train/Test diff: 0.0014
# Stratification OK
#   ROC AUC = 0.9499, Elapsed time = 739.33 seconds
# Fold 22: Train size = 33340, Test size = 8390
#   [Model III Early Repeated - Fold 22] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0062 (diff: 0.0002)
#     Train/Test diff: 0.0002
# Stratification OK
#   ROC AUC = 0.9703, Elapsed time = 773.88 seconds
# Fold 23: Train size = 33420, Test size = 8310
#   [Model III Early Repeated - Fold 23] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0063 (diff: 0.0001)
#     Test SL rate:    0.0067 (diff: 0.0004)
#     Train/Test diff: 0.0005
# Stratification OK
#   ROC AUC = 0.9412, Elapsed time = 816.41 seconds
# Fold 24: Train size = 33360, Test size = 8370
#   [Model III Early Repeated - Fold 24] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0063 (diff: 0.0000)
#     Test SL rate:    0.0065 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.8960, Elapsed time = 850.17 seconds
# Fold 25: Train size = 33350, Test size = 8380
#   [Model III Early Repeated - Fold 25] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0067 (diff: 0.0004)
#     Test SL rate:    0.0049 (diff: 0.0015)
#     Train/Test diff: 0.0018
# Stratification OK
#   ROC AUC = 0.9201, Elapsed time = 884.33 seconds
# Fold 26: Train size = 33340, Test size = 8390
#   [Model III Early Repeated - Fold 26] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0063 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9687, Elapsed time = 918.53 seconds
# Fold 27: Train size = 33350, Test size = 8380
#   [Model III Early Repeated - Fold 27] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0062 (diff: 0.0002)
#     Test SL rate:    0.0070 (diff: 0.0007)
#     Train/Test diff: 0.0009
# Stratification OK
#   ROC AUC = 0.9289, Elapsed time = 949.51 seconds
# Fold 28: Train size = 33350, Test size = 8380
#   [Model III Early Repeated - Fold 28] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0062 (diff: 0.0001)
#     Train/Test diff: 0.0002
# Stratification OK
#   ROC AUC = 0.9216, Elapsed time = 980.07 seconds
# Fold 29: Train size = 33530, Test size = 8200
#   [Model III Early Repeated - Fold 29] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0060 (diff: 0.0004)
#     Test SL rate:    0.0078 (diff: 0.0015)
#     Train/Test diff: 0.0018
# Stratification OK
#   ROC AUC = 0.9290, Elapsed time = 1010.16 seconds
# Fold 30: Train size = 33350, Test size = 8380
#   [Model III Early Repeated - Fold 30] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0069 (diff: 0.0005)
#     Test SL rate:    0.0043 (diff: 0.0021)
#     Train/Test diff: 0.0026
# Stratification OK
#   ROC AUC = 0.9437, Elapsed time = 1040.83 seconds
# Fold 31: Train size = 33340, Test size = 8390
#   [Model III Early Repeated - Fold 31] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0067 (diff: 0.0004)
#     Test SL rate:    0.0049 (diff: 0.0015)
#     Train/Test diff: 0.0018
# Stratification OK
#   ROC AUC = 0.9623, Elapsed time = 1070.78 seconds
# Fold 32: Train size = 33440, Test size = 8290
#   [Model III Early Repeated - Fold 32] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0066 (diff: 0.0003)
#     Test SL rate:    0.0053 (diff: 0.0010)
#     Train/Test diff: 0.0013
# Stratification OK
#   ROC AUC = 0.9668, Elapsed time = 1100.02 seconds
# Fold 33: Train size = 33350, Test size = 8380
#   [Model III Early Repeated - Fold 33] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0001)
#     Test SL rate:    0.0061 (diff: 0.0003)
#     Train/Test diff: 0.0003
# Stratification OK
#   ROC AUC = 0.9323, Elapsed time = 1131.93 seconds
# Fold 34: Train size = 33440, Test size = 8290
#   [Model III Early Repeated - Fold 34] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0056 (diff: 0.0008)
#     Test SL rate:    0.0094 (diff: 0.0031)
#     Train/Test diff: 0.0038
# Stratification OK
#   ROC AUC = 0.9379, Elapsed time = 1162.45 seconds
# Fold 35: Train size = 33350, Test size = 8380
#   [Model III Early Repeated - Fold 35] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0001)
#     Test SL rate:    0.0061 (diff: 0.0003)
#     Train/Test diff: 0.0003
# Stratification OK
#   ROC AUC = 0.8928, Elapsed time = 1192.29 seconds
# Fold 36: Train size = 33340, Test size = 8390
#   [Model III Early Repeated - Fold 36] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0062 (diff: 0.0001)
#     Test SL rate:    0.0068 (diff: 0.0004)
#     Train/Test diff: 0.0006
# Stratification OK
#   ROC AUC = 0.9342, Elapsed time = 1223.14 seconds
# Fold 37: Train size = 33420, Test size = 8310
#   [Model III Early Repeated - Fold 37] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0060 (diff: 0.0004)
#     Test SL rate:    0.0079 (diff: 0.0016)
#     Train/Test diff: 0.0020
# Stratification OK
#   ROC AUC = 0.9548, Elapsed time = 1254.07 seconds
# Fold 38: Train size = 33450, Test size = 8280
#   [Model III Early Repeated - Fold 38] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0066 (diff: 0.0002)
#     Test SL rate:    0.0054 (diff: 0.0009)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9525, Elapsed time = 1283.67 seconds
# Fold 39: Train size = 33350, Test size = 8380
#   [Model III Early Repeated - Fold 39] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0069 (diff: 0.0005)
#     Test SL rate:    0.0043 (diff: 0.0021)
#     Train/Test diff: 0.0026
# Stratification OK
#   ROC AUC = 0.9187, Elapsed time = 1318.66 seconds
# Fold 40: Train size = 33360, Test size = 8370
#   [Model III Early Repeated - Fold 40] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0002)
#     Test SL rate:    0.0073 (diff: 0.0009)
#     Train/Test diff: 0.0012
# Stratification OK
#   ROC AUC = 0.9475, Elapsed time = 1349.34 seconds
# Fold 41: Train size = 33340, Test size = 8390
#   [Model III Early Repeated - Fold 41] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0067 (diff: 0.0003)
#     Test SL rate:    0.0051 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.9133, Elapsed time = 1379.38 seconds
# Fold 42: Train size = 33430, Test size = 8300
#   [Model III Early Repeated - Fold 42] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0005)
#     Test SL rate:    0.0084 (diff: 0.0021)
#     Train/Test diff: 0.0026
# Stratification OK
#   ROC AUC = 0.9582, Elapsed time = 1409.63 seconds
# Fold 43: Train size = 33440, Test size = 8290
#   [Model III Early Repeated - Fold 43] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0068 (diff: 0.0005)
#     Test SL rate:    0.0043 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9453, Elapsed time = 1440.82 seconds
# Fold 44: Train size = 33350, Test size = 8380
#   [Model III Early Repeated - Fold 44] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0060 (diff: 0.0004)
#     Test SL rate:    0.0078 (diff: 0.0014)
#     Train/Test diff: 0.0018
# Stratification OK
#   ROC AUC = 0.9386, Elapsed time = 1471.56 seconds
# Fold 45: Train size = 33360, Test size = 8370
#   [Model III Early Repeated - Fold 45] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0001)
#     Test SL rate:    0.0061 (diff: 0.0003)
#     Train/Test diff: 0.0003
# Stratification OK
#   ROC AUC = 0.9341, Elapsed time = 1502.42 seconds
# Fold 46: Train size = 33490, Test size = 8240
#   [Model III Early Repeated - Fold 46] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0063 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9384, Elapsed time = 1533.48 seconds
# Fold 47: Train size = 33340, Test size = 8390
#   [Model III Early Repeated - Fold 47] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0056 (diff: 0.0007)
#     Test SL rate:    0.0093 (diff: 0.0029)
#     Train/Test diff: 0.0037
# Stratification OK
#   ROC AUC = 0.9437, Elapsed time = 1564.22 seconds
# Fold 48: Train size = 33360, Test size = 8370
#   [Model III Early Repeated - Fold 48] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0063 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9310, Elapsed time = 1594.73 seconds
# Fold 49: Train size = 33360, Test size = 8370
#   [Model III Early Repeated - Fold 49] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0067 (diff: 0.0004)
#     Test SL rate:    0.0048 (diff: 0.0016)
#     Train/Test diff: 0.0020
# Stratification OK
#   ROC AUC = 0.9360, Elapsed time = 1625.58 seconds
# Fold 50: Train size = 33370, Test size = 8360
#   [Model III Early Repeated - Fold 50] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0067 (diff: 0.0004)
#     Test SL rate:    0.0049 (diff: 0.0014)
#     Train/Test diff: 0.0018
# Stratification OK
#   ROC AUC = 0.9333, Elapsed time = 1657.73 seconds
#
# === Model III Early Repeated Summary ===
# Mean ROC AUC = 0.9372 ± 0.0179
# Successful folds: 50/50
# Stratification quality:
#   Mean train deviation: 0.0002 ± 0.0002
#   Mean test deviation:  0.0010 ± 0.0008
#
# === Model III Late Repeated - Fold 1/50 ===
# Train size = 33340, Test size = 8390
#   [Model III Late Repeated - Fold 1] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0067 (diff: 0.0003)
#     Test SL rate:    0.0050 (diff: 0.0013)
#     Train/Test diff: 0.0017
# Stratification OK
#   ROC AUC = 0.8921, Elapsed time = 40.84 seconds
#
# === Model III Late Repeated - Fold 2/50 ===
# Train size = 33430, Test size = 8300
#   [Model III Late Repeated - Fold 2] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0066 (diff: 0.0002)
#     Test SL rate:    0.0055 (diff: 0.0008)
#     Train/Test diff: 0.0010
# Stratification OK
#   ROC AUC = 0.9130, Elapsed time = 82.35 seconds
#
# === Model III Late Repeated - Fold 3/50 ===
# Train size = 33370, Test size = 8360
#   [Model III Late Repeated - Fold 3] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0060 (diff: 0.0003)
#     Test SL rate:    0.0077 (diff: 0.0013)
#     Train/Test diff: 0.0016
# Stratification OK
#   ROC AUC = 0.9725, Elapsed time = 124.49 seconds
#
# === Model III Late Repeated - Fold 4/50 ===
# Train size = 33430, Test size = 8300
#   [Model III Late Repeated - Fold 4] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0002)
#     Test SL rate:    0.0072 (diff: 0.0009)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9385, Elapsed time = 166.03 seconds
#
# === Model III Late Repeated - Fold 5/50 ===
# Train size = 33350, Test size = 8380
#   [Model III Late Repeated - Fold 5] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0063 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9411, Elapsed time = 209.55 seconds
#
# === Model III Late Repeated - Fold 6/50 ===
# Train size = 33350, Test size = 8380
#   [Model III Late Repeated - Fold 6] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0006)
#     Test SL rate:    0.0087 (diff: 0.0024)
#     Train/Test diff: 0.0030
# Stratification OK
#   ROC AUC = 0.9795, Elapsed time = 249.05 seconds
#
# === Model III Late Repeated - Fold 7/50 ===
# Train size = 33420, Test size = 8310
#   [Model III Late Repeated - Fold 7] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0063 (diff: 0.0001)
#     Test SL rate:    0.0067 (diff: 0.0004)
#     Train/Test diff: 0.0005
# Stratification OK
#   ROC AUC = 0.9084, Elapsed time = 292.87 seconds
#
# === Model III Late Repeated - Fold 8/50 ===
# Train size = 33440, Test size = 8290
#   [Model III Late Repeated - Fold 8] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0063 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9209, Elapsed time = 333.81 seconds
#
# === Model III Late Repeated - Fold 9/50 ===
# Train size = 33350, Test size = 8380
#   [Model III Late Repeated - Fold 9] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0067 (diff: 0.0004)
#     Test SL rate:    0.0048 (diff: 0.0016)
#     Train/Test diff: 0.0020
# Stratification OK
#   ROC AUC = 0.9400, Elapsed time = 376.86 seconds
#
# === Model III Late Repeated - Fold 10/50 ===
# Train size = 33360, Test size = 8370
#   [Model III Late Repeated - Fold 10] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0066 (diff: 0.0003)
#     Test SL rate:    0.0053 (diff: 0.0011)
#     Train/Test diff: 0.0014
# Stratification OK
#   ROC AUC = 0.9033, Elapsed time = 420.39 seconds
#
# === Model III Late Repeated - Fold 11/50 ===
# Train size = 33350, Test size = 8380
#   [Model III Late Repeated - Fold 11] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0062 (diff: 0.0001)
#     Test SL rate:    0.0068 (diff: 0.0005)
#     Train/Test diff: 0.0006
# Stratification OK
#   ROC AUC = 0.9525, Elapsed time = 462.12 seconds
#
# === Model III Late Repeated - Fold 12/50 ===
# Train size = 33350, Test size = 8380
#   [Model III Late Repeated - Fold 12] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0062 (diff: 0.0001)
#     Train/Test diff: 0.0002
# Stratification OK
#   ROC AUC = 0.9580, Elapsed time = 503.13 seconds
#
# === Model III Late Repeated - Fold 13/50 ===
# Train size = 33450, Test size = 8280
#   [Model III Late Repeated - Fold 13] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0063 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9478, Elapsed time = 544.23 seconds
#
# === Model III Late Repeated - Fold 14/50 ===
# Train size = 33350, Test size = 8380
#   [Model III Late Repeated - Fold 14] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0003)
#     Test SL rate:    0.0074 (diff: 0.0010)
#     Train/Test diff: 0.0013
# Stratification OK
#   ROC AUC = 0.9176, Elapsed time = 585.59 seconds
#
# === Model III Late Repeated - Fold 15/50 ===
# Train size = 33420, Test size = 8310
#   [Model III Late Repeated - Fold 15] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0067 (diff: 0.0004)
#     Test SL rate:    0.0049 (diff: 0.0014)
#     Train/Test diff: 0.0018
# Stratification OK
#   ROC AUC = 0.9503, Elapsed time = 628.78 seconds
#
# === Model III Late Repeated - Fold 16/50 ===
# Train size = 33430, Test size = 8300
#   [Model III Late Repeated - Fold 16] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0002)
#     Test SL rate:    0.0072 (diff: 0.0009)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9397, Elapsed time = 670.83 seconds
#
# === Model III Late Repeated - Fold 17/50 ===
# Train size = 33440, Test size = 8290
#   [Model III Late Repeated - Fold 17] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0066 (diff: 0.0003)
#     Test SL rate:    0.0052 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.9169, Elapsed time = 712.67 seconds
#
# === Model III Late Repeated - Fold 18/50 ===
# Train size = 33340, Test size = 8390
#   [Model III Late Repeated - Fold 18] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0063 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9031, Elapsed time = 754.30 seconds
#
# === Model III Late Repeated - Fold 19/50 ===
# Train size = 33360, Test size = 8370
#   [Model III Late Repeated - Fold 19] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0063 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9628, Elapsed time = 795.72 seconds
#
# === Model III Late Repeated - Fold 20/50 ===
# Train size = 33350, Test size = 8380
#   [Model III Late Repeated - Fold 20] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0063 (diff: 0.0001)
#     Test SL rate:    0.0067 (diff: 0.0003)
#     Train/Test diff: 0.0004
# Stratification OK
#   ROC AUC = 0.9566, Elapsed time = 836.38 seconds
#
# === Model III Late Repeated - Fold 21/50 ===
# Train size = 33450, Test size = 8280
#   [Model III Late Repeated - Fold 21] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0003)
#     Test SL rate:    0.0075 (diff: 0.0011)
#     Train/Test diff: 0.0014
# Stratification OK
#   ROC AUC = 0.9546, Elapsed time = 876.71 seconds
#
# === Model III Late Repeated - Fold 22/50 ===
# Train size = 33340, Test size = 8390
#   [Model III Late Repeated - Fold 22] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0062 (diff: 0.0002)
#     Train/Test diff: 0.0002
# Stratification OK
#   ROC AUC = 0.9688, Elapsed time = 917.98 seconds
#
# === Model III Late Repeated - Fold 23/50 ===
# Train size = 33420, Test size = 8310
#   [Model III Late Repeated - Fold 23] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0063 (diff: 0.0001)
#     Test SL rate:    0.0067 (diff: 0.0004)
#     Train/Test diff: 0.0005
# Stratification OK
#   ROC AUC = 0.9350, Elapsed time = 960.66 seconds
#
# === Model III Late Repeated - Fold 24/50 ===
# Train size = 33360, Test size = 8370
#   [Model III Late Repeated - Fold 24] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0063 (diff: 0.0000)
#     Test SL rate:    0.0065 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9230, Elapsed time = 1002.62 seconds
#
# === Model III Late Repeated - Fold 25/50 ===
# Train size = 33350, Test size = 8380
#   [Model III Late Repeated - Fold 25] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0067 (diff: 0.0004)
#     Test SL rate:    0.0049 (diff: 0.0015)
#     Train/Test diff: 0.0018
# Stratification OK
#   ROC AUC = 0.9228, Elapsed time = 1045.77 seconds
#
# === Model III Late Repeated - Fold 26/50 ===
# Train size = 33340, Test size = 8390
#   [Model III Late Repeated - Fold 26] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0063 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9700, Elapsed time = 1088.01 seconds
#
# === Model III Late Repeated - Fold 27/50 ===
# Train size = 33350, Test size = 8380
#   [Model III Late Repeated - Fold 27] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0062 (diff: 0.0002)
#     Test SL rate:    0.0070 (diff: 0.0007)
#     Train/Test diff: 0.0009
# Stratification OK
#   ROC AUC = 0.9133, Elapsed time = 1128.58 seconds
#
# === Model III Late Repeated - Fold 28/50 ===
# Train size = 33350, Test size = 8380
#   [Model III Late Repeated - Fold 28] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0062 (diff: 0.0001)
#     Train/Test diff: 0.0002
# Stratification OK
#   ROC AUC = 0.9384, Elapsed time = 1170.91 seconds
#
# === Model III Late Repeated - Fold 29/50 ===
# Train size = 33530, Test size = 8200
#   [Model III Late Repeated - Fold 29] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0060 (diff: 0.0004)
#     Test SL rate:    0.0078 (diff: 0.0015)
#     Train/Test diff: 0.0018
# Stratification OK
#   ROC AUC = 0.9279, Elapsed time = 1211.77 seconds
#
# === Model III Late Repeated - Fold 30/50 ===
# Train size = 33350, Test size = 8380
#   [Model III Late Repeated - Fold 30] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0069 (diff: 0.0005)
#     Test SL rate:    0.0043 (diff: 0.0021)
#     Train/Test diff: 0.0026
# Stratification OK
#   ROC AUC = 0.9370, Elapsed time = 1253.66 seconds
#
# === Model III Late Repeated - Fold 31/50 ===
# Train size = 33340, Test size = 8390
#   [Model III Late Repeated - Fold 31] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0067 (diff: 0.0004)
#     Test SL rate:    0.0049 (diff: 0.0015)
#     Train/Test diff: 0.0018
# Stratification OK
#   ROC AUC = 0.9740, Elapsed time = 1294.86 seconds
#
# === Model III Late Repeated - Fold 32/50 ===
# Train size = 33440, Test size = 8290
#   [Model III Late Repeated - Fold 32] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0066 (diff: 0.0003)
#     Test SL rate:    0.0053 (diff: 0.0010)
#     Train/Test diff: 0.0013
# Stratification OK
#   ROC AUC = 0.9599, Elapsed time = 1336.02 seconds
#
# === Model III Late Repeated - Fold 33/50 ===
# Train size = 33350, Test size = 8380
#   [Model III Late Repeated - Fold 33] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0001)
#     Test SL rate:    0.0061 (diff: 0.0003)
#     Train/Test diff: 0.0003
# Stratification OK
#   ROC AUC = 0.9455, Elapsed time = 1379.56 seconds
#
# === Model III Late Repeated - Fold 34/50 ===
# Train size = 33440, Test size = 8290
#   [Model III Late Repeated - Fold 34] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0056 (diff: 0.0008)
#     Test SL rate:    0.0094 (diff: 0.0031)
#     Train/Test diff: 0.0038
# Stratification OK
#   ROC AUC = 0.9397, Elapsed time = 1421.77 seconds
#
# === Model III Late Repeated - Fold 35/50 ===
# Train size = 33350, Test size = 8380
#   [Model III Late Repeated - Fold 35] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0001)
#     Test SL rate:    0.0061 (diff: 0.0003)
#     Train/Test diff: 0.0003
# Stratification OK
#   ROC AUC = 0.8968, Elapsed time = 1462.65 seconds
#
# === Model III Late Repeated - Fold 36/50 ===
# Train size = 33340, Test size = 8390
#   [Model III Late Repeated - Fold 36] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0062 (diff: 0.0001)
#     Test SL rate:    0.0068 (diff: 0.0004)
#     Train/Test diff: 0.0006
# Stratification OK
#   ROC AUC = 0.9277, Elapsed time = 1505.20 seconds
#
# === Model III Late Repeated - Fold 37/50 ===
# Train size = 33420, Test size = 8310
#   [Model III Late Repeated - Fold 37] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0060 (diff: 0.0004)
#     Test SL rate:    0.0079 (diff: 0.0016)
#     Train/Test diff: 0.0020
# Stratification OK
#   ROC AUC = 0.9612, Elapsed time = 1548.23 seconds
#
# === Model III Late Repeated - Fold 38/50 ===
# Train size = 33450, Test size = 8280
#   [Model III Late Repeated - Fold 38] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0066 (diff: 0.0002)
#     Test SL rate:    0.0054 (diff: 0.0009)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.9443, Elapsed time = 1588.24 seconds
#
# === Model III Late Repeated - Fold 39/50 ===
# Train size = 33350, Test size = 8380
#   [Model III Late Repeated - Fold 39] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0069 (diff: 0.0005)
#     Test SL rate:    0.0043 (diff: 0.0021)
#     Train/Test diff: 0.0026
# Stratification OK
#   ROC AUC = 0.9217, Elapsed time = 1631.77 seconds
#
# === Model III Late Repeated - Fold 40/50 ===
# Train size = 33360, Test size = 8370
#   [Model III Late Repeated - Fold 40] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0061 (diff: 0.0002)
#     Test SL rate:    0.0073 (diff: 0.0009)
#     Train/Test diff: 0.0012
# Stratification OK
#   ROC AUC = 0.9340, Elapsed time = 1671.51 seconds
#
# === Model III Late Repeated - Fold 41/50 ===
# Train size = 33340, Test size = 8390
#   [Model III Late Repeated - Fold 41] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0067 (diff: 0.0003)
#     Test SL rate:    0.0051 (diff: 0.0012)
#     Train/Test diff: 0.0015
# Stratification OK
#   ROC AUC = 0.9255, Elapsed time = 1713.62 seconds
#
# === Model III Late Repeated - Fold 42/50 ===
# Train size = 33430, Test size = 8300
#   [Model III Late Repeated - Fold 42] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0058 (diff: 0.0005)
#     Test SL rate:    0.0084 (diff: 0.0021)
#     Train/Test diff: 0.0026
# Stratification OK
#   ROC AUC = 0.9457, Elapsed time = 1754.16 seconds
#
# === Model III Late Repeated - Fold 43/50 ===
# Train size = 33440, Test size = 8290
#   [Model III Late Repeated - Fold 43] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0068 (diff: 0.0005)
#     Test SL rate:    0.0043 (diff: 0.0020)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9484, Elapsed time = 1797.61 seconds
#
# === Model III Late Repeated - Fold 44/50 ===
# Train size = 33350, Test size = 8380
#   [Model III Late Repeated - Fold 44] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0060 (diff: 0.0004)
#     Test SL rate:    0.0078 (diff: 0.0014)
#     Train/Test diff: 0.0018
# Stratification OK
#   ROC AUC = 0.9268, Elapsed time = 1839.19 seconds
#
# === Model III Late Repeated - Fold 45/50 ===
# Train size = 33360, Test size = 8370
#   [Model III Late Repeated - Fold 45] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0001)
#     Test SL rate:    0.0061 (diff: 0.0003)
#     Train/Test diff: 0.0003
# Stratification OK
#   ROC AUC = 0.9500, Elapsed time = 1881.70 seconds
#
# === Model III Late Repeated - Fold 46/50 ===
# Train size = 33490, Test size = 8240
#   [Model III Late Repeated - Fold 46] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0063 (diff: 0.0000)
#     Test SL rate:    0.0064 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9407, Elapsed time = 1924.18 seconds
#
# === Model III Late Repeated - Fold 47/50 ===
# Train size = 33340, Test size = 8390
#   [Model III Late Repeated - Fold 47] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0056 (diff: 0.0007)
#     Test SL rate:    0.0093 (diff: 0.0029)
#     Train/Test diff: 0.0037
# Stratification OK
#   ROC AUC = 0.9448, Elapsed time = 1966.92 seconds
#
# === Model III Late Repeated - Fold 48/50 ===
# Train size = 33360, Test size = 8370
#   [Model III Late Repeated - Fold 48] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0064 (diff: 0.0000)
#     Test SL rate:    0.0063 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9211, Elapsed time = 2007.96 seconds
#
# === Model III Late Repeated - Fold 49/50 ===
# Train size = 33360, Test size = 8370
#   [Model III Late Repeated - Fold 49] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0067 (diff: 0.0004)
#     Test SL rate:    0.0048 (diff: 0.0016)
#     Train/Test diff: 0.0020
# Stratification OK
#   ROC AUC = 0.9001, Elapsed time = 2050.72 seconds
#
# === Model III Late Repeated - Fold 50/50 ===
# Train size = 33370, Test size = 8360
#   [Model III Late Repeated - Fold 50] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0067 (diff: 0.0004)
#     Test SL rate:    0.0049 (diff: 0.0014)
#     Train/Test diff: 0.0018
# Stratification OK
#   ROC AUC = 0.9568, Elapsed time = 2094.47 seconds
#
# === Model III Late Repeated Summary ===
# Mean ROC AUC = 0.9364 ± 0.0212
# Successful folds: 50/50
# Stratification quality:
# Mean train deviation: 0.0002 ± 0.0002
# Mean test deviation: 0.0010 ± 0.0008

# %%
# save results of cross validation
with open(file_RF_model_III_contextualized_repeated, 'wb') as f:
    pickle.dump(model_III_contextualized_repeated, f)

with open(file_RF_model_III_full_repeated, 'wb') as f:
    pickle.dump(model_III_full_repeated, f)

# %% [markdown]
# ## Model IV
# #### Different paralog pairs, different cell lines

# %%
# --- Custom split functions ---
def create_disjoint_splits(df, n_splits=5, num_test_cell_lines=2, test_gene_fraction=0.25, random_state=None):
    splits = []

    # Get the unique cell lines and gene pairs
    unique_cell_lines = df['cell_line'].unique()
    unique_gene_pairs = df['genepair'].unique()

    # Set the random seed if provided
    if random_state is not None:
        np.random.seed(random_state)

    # Shuffle and split cell lines and gene pairs into mutually exclusive groups
    np.random.shuffle(unique_cell_lines)
    cell_line_splits = np.array_split(unique_cell_lines, n_splits)

    np.random.shuffle(unique_gene_pairs)
    gene_pair_splits = np.array_split(unique_gene_pairs, n_splits)

    # Create the splits
    for fold in range(n_splits):
        test_cell_lines = cell_line_splits[fold]
        test_gene_pairs = gene_pair_splits[fold]

        train_cell_lines = np.concatenate([cell_line_splits[i] for i in range(n_splits) if i != fold])
        train_gene_pairs = np.concatenate([gene_pair_splits[i] for i in range(n_splits) if i != fold])

        # Define train/test indices
        test_index = df[(df['cell_line'].isin(test_cell_lines)) & (df['genepair'].isin(test_gene_pairs))].index
        train_index = df[(df['cell_line'].isin(train_cell_lines)) & (df['genepair'].isin(train_gene_pairs))].index

        splits.append((train_index, test_index))

        print(f'[Fold {fold+1}] '
              f'# pairs (train): {df.loc[train_index, "genepair"].nunique()} | '
              f'# pairs (test): {df.loc[test_index, "genepair"].nunique()} | '
              f'# overlapping: {np.isin(df.loc[test_index, "genepair"].unique(), df.loc[train_index, "genepair"].unique()).sum()} | '
              f'# cells (train): {df.loc[train_index, "cell_line"].nunique()} | '
              f'# cells (test): {df.loc[test_index, "cell_line"].nunique()}')

        # Add validation after creating splits
        train_cells = set(df.loc[train_index, 'cell_line'].unique())
        test_cells = set(df.loc[test_index, 'cell_line'].unique())
        train_pairs = set(df.loc[train_index, 'genepair'].unique())
        test_pairs = set(df.loc[test_index, 'genepair'].unique())

        assert len(train_cells & test_cells) == 0, "Cell line leakage detected!"
        assert len(train_pairs & test_pairs) == 0, "Gene pair leakage detected!"

    return splits

def repeated_custom_cv(df, n_splits=5, n_repeats=3, num_test_cell_lines=2, test_gene_fraction=0.25, random_state=None):
    all_splits = []

    for repeat in range(n_repeats):
        current_seed = random_state + repeat if random_state is not None else None
        splits = create_disjoint_splits(
            df,
            n_splits=n_splits,
            num_test_cell_lines=num_test_cell_lines,
            test_gene_fraction=test_gene_fraction,
            random_state=current_seed
        )
        all_splits.extend(splits)

    return all_splits

# %%
splits_IV = repeated_custom_cv(df=training_df, n_splits=5, n_repeats=10, random_state=42)

# Add validation for Model IV splits
print("\n=== MODEL IV: COMBINED VALIDATION ===")
for i, (train_index, test_index) in enumerate(splits_IV[:5]):  # Just first 5 for brevity
    train_cells = training_df.loc[train_index, 'cell_line'].unique()  # Use correct column name
    test_cells = training_df.loc[test_index, 'cell_line'].unique()    # Use correct column name
    train_pairs = training_df.loc[train_index, 'genepair'].unique()
    test_pairs = training_df.loc[test_index, 'genepair'].unique()
    
    print(f"\n--- Fold {i+1} ---")
    validate_group_splits(train_cells, test_cells, i+1, "Model IV", "cell lines")
    validate_group_splits(train_pairs, test_pairs, i+1, "Model IV", "gene pairs")
# Out:
# [Fold 1] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 2] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 3] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 4] # pairs (train): 3339 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 5] # pairs (train): 3339 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 1] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 2] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 3] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 4] # pairs (train): 3339 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 5] # pairs (train): 3339 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 1] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 2] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 3] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 4] # pairs (train): 3339 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 5] # pairs (train): 3339 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 1] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 2] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 3] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 4] # pairs (train): 3339 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 5] # pairs (train): 3339 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 1] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 2] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 3] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 4] # pairs (train): 3339 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 5] # pairs (train): 3339 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 1] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 2] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 3] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 4] # pairs (train): 3339 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 5] # pairs (train): 3339 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 1] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 2] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 3] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 4] # pairs (train): 3339 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 5] # pairs (train): 3339 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 1] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 2] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 3] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 4] # pairs (train): 3339 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 5] # pairs (train): 3339 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 1] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 2] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 3] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 4] # pairs (train): 3339 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 5] # pairs (train): 3339 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 1] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 2] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 3] # pairs (train): 3338 | # pairs (test): 835 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 4] # pairs (train): 3339 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
# [Fold 5] # pairs (train): 3339 | # pairs (test): 834 | # overlapping: 0 | # cells (train): 8 | # cells (test): 2
#
# === MODEL IV: COMBINED VALIDATION ===
#
# --- Fold 1 ---
#   [Model IV - Fold 1] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model IV - Fold 1] Group Validation:
#     Train gene pairs: 3338
#     Test gene pairs:  835
#     Overlapping gene pairs: 0
# No group leakage
#
# --- Fold 2 ---
#   [Model IV - Fold 2] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model IV - Fold 2] Group Validation:
#     Train gene pairs: 3338
#     Test gene pairs:  835
#     Overlapping gene pairs: 0
# No group leakage
#
# --- Fold 3 ---
#   [Model IV - Fold 3] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model IV - Fold 3] Group Validation:
#     Train gene pairs: 3338
#     Test gene pairs:  835
#     Overlapping gene pairs: 0
# No group leakage
#
# --- Fold 4 ---
#   [Model IV - Fold 4] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model IV - Fold 4] Group Validation:
#     Train gene pairs: 3339
#     Test gene pairs:  834
#     Overlapping gene pairs: 0
# No group leakage
#
# --- Fold 5 ---
#   [Model IV - Fold 5] Group Validation:
#     Train cell lines: 8
#     Test cell lines:  2
#     Overlapping cell lines: 0
# No group leakage
#   [Model IV - Fold 5] Group Validation:
#     Train gene pairs: 3339
#     Test gene pairs:  834
#     Overlapping gene pairs: 0
# No group leakage

# %%
# Save splits
splits_path = get_data_path(['data', 'output', 'models', 'model_IV'], 'splits_IV.pkl')
with open(splits_path, 'wb') as f:
    pickle.dump(splits_IV, f)

# %%
model_IV_contextualized = model_contextualized_cross_validation(RF, data_1, target, splits_IV, model_name="Model IV contextualized")
model_IV_full = model_full_cross_validation(RF, data_2, target, splits_IV, model_name="Model IV full")
# Out:
# Fold 1: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 1] Stratification Check:
#     Overall SL rate: 0.0061
#     Train SL rate:   0.0061 (diff: 0.0001)
#     Test SL rate:    0.0072 (diff: 0.0011)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.7838, Elapsed time = 27.86 seconds
# Fold 2: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 2] Stratification Check:
#     Overall SL rate: 0.0069
#     Train SL rate:   0.0071 (diff: 0.0002)
#     Test SL rate:    0.0042 (diff: 0.0028)
#     Train/Test diff: 0.0029
# Stratification OK
#   ROC AUC = 0.9010, Elapsed time = 56.40 seconds
# Fold 3: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 3] Stratification Check:
#     Overall SL rate: 0.0061
#     Train SL rate:   0.0060 (diff: 0.0001)
#     Test SL rate:    0.0072 (diff: 0.0011)
#     Train/Test diff: 0.0012
# Stratification OK
#   ROC AUC = 0.9035, Elapsed time = 83.06 seconds
# Fold 4: Train size = 26712, Test size = 1668
#   [Model IV Early - Fold 4] Stratification Check:
#     Overall SL rate: 0.0057
#     Train SL rate:   0.0054 (diff: 0.0002)
#     Test SL rate:    0.0096 (diff: 0.0039)
#     Train/Test diff: 0.0042
# Stratification OK
#   ROC AUC = 0.8434, Elapsed time = 107.95 seconds
# Fold 5: Train size = 26712, Test size = 1668
#   [Model IV Early - Fold 5] Stratification Check:
#     Overall SL rate: 0.0068
#     Train SL rate:   0.0071 (diff: 0.0002)
#     Test SL rate:    0.0030 (diff: 0.0038)
#     Train/Test diff: 0.0041
# Stratification OK
#   ROC AUC = 0.9169, Elapsed time = 136.57 seconds
# Fold 6: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 6] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0066 (diff: 0.0001)
#     Test SL rate:    0.0048 (diff: 0.0017)
#     Train/Test diff: 0.0018
# Stratification OK
#   ROC AUC = 0.8196, Elapsed time = 166.08 seconds
# Fold 7: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 7] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0066 (diff: 0.0002)
#     Test SL rate:    0.0036 (diff: 0.0028)
#     Train/Test diff: 0.0030
# Stratification OK
#   ROC AUC = 0.9792, Elapsed time = 189.63 seconds
# Fold 8: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 8] Stratification Check:
#     Overall SL rate: 0.0068
#     Train SL rate:   0.0070 (diff: 0.0002)
#     Test SL rate:    0.0036 (diff: 0.0032)
#     Train/Test diff: 0.0034
# Stratification OK
#   ROC AUC = 0.9758, Elapsed time = 217.30 seconds
# Fold 9: Train size = 26712, Test size = 1668
#   [Model IV Early - Fold 9] Stratification Check:
#     Overall SL rate: 0.0048
#     Train SL rate:   0.0042 (diff: 0.0006)
#     Test SL rate:    0.0138 (diff: 0.0090)
#     Train/Test diff: 0.0096
# Stratification OK
#   ROC AUC = 0.8517, Elapsed time = 244.46 seconds
# Fold 10: Train size = 26712, Test size = 1668
#   [Model IV Early - Fold 10] Stratification Check:
#     Overall SL rate: 0.0069
#     Train SL rate:   0.0072 (diff: 0.0002)
#     Test SL rate:    0.0030 (diff: 0.0039)
#     Train/Test diff: 0.0042
# Stratification OK
#   ROC AUC = 0.9325, Elapsed time = 277.47 seconds
# Fold 11: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 11] Stratification Check:
#     Overall SL rate: 0.0060
#     Train SL rate:   0.0058 (diff: 0.0001)
#     Test SL rate:    0.0084 (diff: 0.0024)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9107, Elapsed time = 307.65 seconds
# Fold 12: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 12] Stratification Check:
#     Overall SL rate: 0.0063
#     Train SL rate:   0.0065 (diff: 0.0001)
#     Test SL rate:    0.0042 (diff: 0.0022)
#     Train/Test diff: 0.0023
# Stratification OK
#   ROC AUC = 0.8754, Elapsed time = 335.35 seconds
# Fold 13: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 13] Stratification Check:
#     Overall SL rate: 0.0072
#     Train SL rate:   0.0075 (diff: 0.0002)
#     Test SL rate:    0.0036 (diff: 0.0036)
#     Train/Test diff: 0.0039
# Stratification OK
#   ROC AUC = 0.9531, Elapsed time = 361.18 seconds
# Fold 14: Train size = 26712, Test size = 1668
#   [Model IV Early - Fold 14] Stratification Check:
#     Overall SL rate: 0.0057
#     Train SL rate:   0.0056 (diff: 0.0001)
#     Test SL rate:    0.0078 (diff: 0.0021)
#     Train/Test diff: 0.0022
# Stratification OK
#   ROC AUC = 0.8193, Elapsed time = 384.44 seconds
# Fold 15: Train size = 26712, Test size = 1668
#   [Model IV Early - Fold 15] Stratification Check:
#     Overall SL rate: 0.0066
#     Train SL rate:   0.0064 (diff: 0.0001)
#     Test SL rate:    0.0084 (diff: 0.0018)
#     Train/Test diff: 0.0020
# Stratification OK
#   ROC AUC = 0.8572, Elapsed time = 409.19 seconds
# Fold 16: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 16] Stratification Check:
#     Overall SL rate: 0.0067
#     Train SL rate:   0.0069 (diff: 0.0002)
#     Test SL rate:    0.0030 (diff: 0.0037)
#     Train/Test diff: 0.0039
# Stratification OK
#   ROC AUC = 0.9849, Elapsed time = 434.40 seconds
# Fold 17: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 17] Stratification Check:
#     Overall SL rate: 0.0065
#     Train SL rate:   0.0065 (diff: 0.0000)
#     Test SL rate:    0.0066 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.8401, Elapsed time = 459.93 seconds
# Fold 18: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 18] Stratification Check:
#     Overall SL rate: 0.0068
#     Train SL rate:   0.0069 (diff: 0.0001)
#     Test SL rate:    0.0048 (diff: 0.0020)
#     Train/Test diff: 0.0021
# Stratification OK
#   ROC AUC = 0.9025, Elapsed time = 487.15 seconds
# Fold 19: Train size = 26712, Test size = 1668
#   [Model IV Early - Fold 19] Stratification Check:
#     Overall SL rate: 0.0051
#     Train SL rate:   0.0045 (diff: 0.0007)
#     Test SL rate:    0.0162 (diff: 0.0110)
#     Train/Test diff: 0.0117
# Stratification OK
#   ROC AUC = 0.9128, Elapsed time = 513.82 seconds
# Fold 20: Train size = 26712, Test size = 1668
#   [Model IV Early - Fold 20] Stratification Check:
#     Overall SL rate: 0.0069
#     Train SL rate:   0.0071 (diff: 0.0002)
#     Test SL rate:    0.0036 (diff: 0.0033)
#     Train/Test diff: 0.0035
# Stratification OK
#   ROC AUC = 0.8238, Elapsed time = 542.90 seconds
# Fold 21: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 21] Stratification Check:
#     Overall SL rate: 0.0059
#     Train SL rate:   0.0060 (diff: 0.0001)
#     Test SL rate:    0.0048 (diff: 0.0011)
#     Train/Test diff: 0.0012
# Stratification OK
#   ROC AUC = 0.9462, Elapsed time = 570.43 seconds
# Fold 22: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 22] Stratification Check:
#     Overall SL rate: 0.0059
#     Train SL rate:   0.0056 (diff: 0.0003)
#     Test SL rate:    0.0102 (diff: 0.0043)
#     Train/Test diff: 0.0046
# Stratification OK
#   ROC AUC = 0.8567, Elapsed time = 595.04 seconds
# Fold 23: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 23] Stratification Check:
#     Overall SL rate: 0.0067
#     Train SL rate:   0.0067 (diff: 0.0000)
#     Test SL rate:    0.0060 (diff: 0.0007)
#     Train/Test diff: 0.0007
# Stratification OK
#   ROC AUC = 0.8889, Elapsed time = 620.67 seconds
# Fold 24: Train size = 26712, Test size = 1668
#   [Model IV Early - Fold 24] Stratification Check:
#     Overall SL rate: 0.0070
#     Train SL rate:   0.0071 (diff: 0.0000)
#     Test SL rate:    0.0066 (diff: 0.0005)
#     Train/Test diff: 0.0005
# Stratification OK
#   ROC AUC = 0.9330, Elapsed time = 644.93 seconds
# Fold 25: Train size = 26712, Test size = 1668
#   [Model IV Early - Fold 25] Stratification Check:
#     Overall SL rate: 0.0063
#     Train SL rate:   0.0064 (diff: 0.0001)
#     Test SL rate:    0.0042 (diff: 0.0021)
#     Train/Test diff: 0.0022
# Stratification OK
#   ROC AUC = 0.9707, Elapsed time = 668.51 seconds
# Fold 26: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 26] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0066 (diff: 0.0002)
#     Test SL rate:    0.0036 (diff: 0.0029)
#     Train/Test diff: 0.0030
# Stratification OK
#   ROC AUC = 0.9260, Elapsed time = 691.40 seconds
# Fold 27: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 27] Stratification Check:
#     Overall SL rate: 0.0060
#     Train SL rate:   0.0059 (diff: 0.0001)
#     Test SL rate:    0.0072 (diff: 0.0012)
#     Train/Test diff: 0.0013
# Stratification OK
#   ROC AUC = 0.9349, Elapsed time = 714.73 seconds
# Fold 28: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 28] Stratification Check:
#     Overall SL rate: 0.0062
#     Train SL rate:   0.0061 (diff: 0.0001)
#     Test SL rate:    0.0078 (diff: 0.0015)
#     Train/Test diff: 0.0016
# Stratification OK
#   ROC AUC = 0.8853, Elapsed time = 740.16 seconds
# Fold 29: Train size = 26712, Test size = 1668
#   [Model IV Early - Fold 29] Stratification Check:
#     Overall SL rate: 0.0067
#     Train SL rate:   0.0070 (diff: 0.0003)
#     Test SL rate:    0.0018 (diff: 0.0049)
#     Train/Test diff: 0.0052
# Stratification OK
#   ROC AUC = 0.6429, Elapsed time = 766.42 seconds
# Fold 30: Train size = 26712, Test size = 1668
#   [Model IV Early - Fold 30] Stratification Check:
#     Overall SL rate: 0.0057
#     Train SL rate:   0.0057 (diff: 0.0000)
#     Test SL rate:    0.0054 (diff: 0.0003)
#     Train/Test diff: 0.0003
# Stratification OK
#   ROC AUC = 0.9313, Elapsed time = 792.02 seconds
# Fold 31: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 31] Stratification Check:
#     Overall SL rate: 0.0060
#     Train SL rate:   0.0055 (diff: 0.0004)
#     Test SL rate:    0.0132 (diff: 0.0072)
#     Train/Test diff: 0.0076
# Stratification OK
#   ROC AUC = 0.9412, Elapsed time = 816.75 seconds
# Fold 32: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 32] Stratification Check:
#     Overall SL rate: 0.0072
#     Train SL rate:   0.0075 (diff: 0.0003)
#     Test SL rate:    0.0024 (diff: 0.0048)
#     Train/Test diff: 0.0051
# Stratification OK
#   ROC AUC = 0.9644, Elapsed time = 842.57 seconds
# Fold 33: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 33] Stratification Check:
#     Overall SL rate: 0.0065
#     Train SL rate:   0.0066 (diff: 0.0000)
#     Test SL rate:    0.0060 (diff: 0.0005)
#     Train/Test diff: 0.0006
# Stratification OK
#   ROC AUC = 0.9440, Elapsed time = 867.58 seconds
# Fold 34: Train size = 26712, Test size = 1668
#   [Model IV Early - Fold 34] Stratification Check:
#     Overall SL rate: 0.0054
#     Train SL rate:   0.0052 (diff: 0.0002)
#     Test SL rate:    0.0078 (diff: 0.0024)
#     Train/Test diff: 0.0026
# Stratification OK
#   ROC AUC = 0.7970, Elapsed time = 889.79 seconds
# Fold 35: Train size = 26712, Test size = 1668
#   [Model IV Early - Fold 35] Stratification Check:
#     Overall SL rate: 0.0067
#     Train SL rate:   0.0070 (diff: 0.0002)
#     Test SL rate:    0.0030 (diff: 0.0037)
#     Train/Test diff: 0.0040
# Stratification OK
#   ROC AUC = 0.8848, Elapsed time = 917.46 seconds
# Fold 36: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 36] Stratification Check:
#     Overall SL rate: 0.0066
#     Train SL rate:   0.0066 (diff: 0.0001)
#     Test SL rate:    0.0054 (diff: 0.0012)
#     Train/Test diff: 0.0012
# Stratification OK
#   ROC AUC = 0.5007, Elapsed time = 943.51 seconds
# Fold 37: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 37] Stratification Check:
#     Overall SL rate: 0.0060
#     Train SL rate:   0.0060 (diff: 0.0000)
#     Test SL rate:    0.0060 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.8645, Elapsed time = 968.02 seconds
# Fold 38: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 38] Stratification Check:
#     Overall SL rate: 0.0063
#     Train SL rate:   0.0062 (diff: 0.0001)
#     Test SL rate:    0.0078 (diff: 0.0015)
#     Train/Test diff: 0.0016
# Stratification OK
#   ROC AUC = 0.9422, Elapsed time = 994.66 seconds
# Fold 39: Train size = 26712, Test size = 1668
#   [Model IV Early - Fold 39] Stratification Check:
#     Overall SL rate: 0.0066
#     Train SL rate:   0.0066 (diff: 0.0000)
#     Test SL rate:    0.0066 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9129, Elapsed time = 1021.43 seconds
# Fold 40: Train size = 26712, Test size = 1668
#   [Model IV Early - Fold 40] Stratification Check:
#     Overall SL rate: 0.0066
#     Train SL rate:   0.0065 (diff: 0.0001)
#     Test SL rate:    0.0078 (diff: 0.0012)
#     Train/Test diff: 0.0013
# Stratification OK
#   ROC AUC = 0.9048, Elapsed time = 1046.80 seconds
# Fold 41: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 41] Stratification Check:
#     Overall SL rate: 0.0057
#     Train SL rate:   0.0056 (diff: 0.0001)
#     Test SL rate:    0.0072 (diff: 0.0015)
#     Train/Test diff: 0.0016
# Stratification OK
#   ROC AUC = 0.8817, Elapsed time = 1075.05 seconds
# Fold 42: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 42] Stratification Check:
#     Overall SL rate: 0.0069
#     Train SL rate:   0.0073 (diff: 0.0004)
#     Test SL rate:    0.0006 (diff: 0.0063)
#     Train/Test diff: 0.0067
# Stratification OK
#   ROC AUC = 0.9994, Elapsed time = 1104.86 seconds
# Fold 43: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 43] Stratification Check:
#     Overall SL rate: 0.0054
#     Train SL rate:   0.0052 (diff: 0.0002)
#     Test SL rate:    0.0090 (diff: 0.0036)
#     Train/Test diff: 0.0038
# Stratification OK
#   ROC AUC = 0.8307, Elapsed time = 1128.62 seconds
# Fold 44: Train size = 26712, Test size = 1668
#   [Model IV Early - Fold 44] Stratification Check:
#     Overall SL rate: 0.0059
#     Train SL rate:   0.0059 (diff: 0.0000)
#     Test SL rate:    0.0060 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9247, Elapsed time = 1155.76 seconds
# Fold 45: Train size = 26712, Test size = 1668
#   [Model IV Early - Fold 45] Stratification Check:
#     Overall SL rate: 0.0069
#     Train SL rate:   0.0073 (diff: 0.0004)
#     Test SL rate:    0.0006 (diff: 0.0063)
#     Train/Test diff: 0.0067
# Stratification OK
#   ROC AUC = 0.4595, Elapsed time = 1183.68 seconds
# Fold 46: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 46] Stratification Check:
#     Overall SL rate: 0.0060
#     Train SL rate:   0.0059 (diff: 0.0001)
#     Test SL rate:    0.0072 (diff: 0.0012)
#     Train/Test diff: 0.0013
# Stratification OK
#   ROC AUC = 0.9844, Elapsed time = 1209.29 seconds
# Fold 47: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 47] Stratification Check:
#     Overall SL rate: 0.0068
#     Train SL rate:   0.0070 (diff: 0.0002)
#     Test SL rate:    0.0036 (diff: 0.0032)
#     Train/Test diff: 0.0034
# Stratification OK
#   ROC AUC = 0.9778, Elapsed time = 1236.79 seconds
# Fold 48: Train size = 26704, Test size = 1670
#   [Model IV Early - Fold 48] Stratification Check:
#     Overall SL rate: 0.0060
#     Train SL rate:   0.0057 (diff: 0.0002)
#     Test SL rate:    0.0096 (diff: 0.0036)
#     Train/Test diff: 0.0039
# Stratification OK
#   ROC AUC = 0.8922, Elapsed time = 1267.75 seconds
# Fold 49: Train size = 26712, Test size = 1668
#   [Model IV Early - Fold 49] Stratification Check:
#     Overall SL rate: 0.0063
#     Train SL rate:   0.0064 (diff: 0.0001)
#     Test SL rate:    0.0048 (diff: 0.0015)
#     Train/Test diff: 0.0016
# Stratification OK
#   ROC AUC = 0.9057, Elapsed time = 1293.27 seconds
# Fold 50: Train size = 26712, Test size = 1668
#   [Model IV Early - Fold 50] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0066 (diff: 0.0001)
#     Test SL rate:    0.0042 (diff: 0.0022)
#     Train/Test diff: 0.0024
# Stratification OK
#   ROC AUC = 0.9765, Elapsed time = 1318.21 seconds
#
# === Model IV Early Summary ===
# Mean ROC AUC = 0.8835 ± 0.1043
# Successful folds: 50/50
# Stratification quality:
#   Mean train deviation: 0.0002 ± 0.0001
#   Mean test deviation:  0.0027 ± 0.0022
#
# === Model IV Late - Fold 1/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 1] Stratification Check:
#     Overall SL rate: 0.0061
#     Train SL rate:   0.0061 (diff: 0.0001)
#     Test SL rate:    0.0072 (diff: 0.0011)
#     Train/Test diff: 0.0011
# Stratification OK
#   ROC AUC = 0.8762, Elapsed time = 30.34 seconds
#
# === Model IV Late - Fold 2/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 2] Stratification Check:
#     Overall SL rate: 0.0069
#     Train SL rate:   0.0071 (diff: 0.0002)
#     Test SL rate:    0.0042 (diff: 0.0028)
#     Train/Test diff: 0.0029
# Stratification OK
#   ROC AUC = 0.9238, Elapsed time = 67.22 seconds
#
# === Model IV Late - Fold 3/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 3] Stratification Check:
#     Overall SL rate: 0.0061
#     Train SL rate:   0.0060 (diff: 0.0001)
#     Test SL rate:    0.0072 (diff: 0.0011)
#     Train/Test diff: 0.0012
# Stratification OK
#   ROC AUC = 0.9295, Elapsed time = 103.10 seconds
#
# === Model IV Late - Fold 4/50 ===
# Train size = 26712, Test size = 1668
#   [Model IV Late - Fold 4] Stratification Check:
#     Overall SL rate: 0.0057
#     Train SL rate:   0.0054 (diff: 0.0002)
#     Test SL rate:    0.0096 (diff: 0.0039)
#     Train/Test diff: 0.0042
# Stratification OK
#   ROC AUC = 0.8883, Elapsed time = 140.55 seconds
#
# === Model IV Late - Fold 5/50 ===
# Train size = 26712, Test size = 1668
#   [Model IV Late - Fold 5] Stratification Check:
#     Overall SL rate: 0.0068
#     Train SL rate:   0.0071 (diff: 0.0002)
#     Test SL rate:    0.0030 (diff: 0.0038)
#     Train/Test diff: 0.0041
# Stratification OK
#   ROC AUC = 0.9450, Elapsed time = 179.51 seconds
#
# === Model IV Late - Fold 6/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 6] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0066 (diff: 0.0001)
#     Test SL rate:    0.0048 (diff: 0.0017)
#     Train/Test diff: 0.0018
# Stratification OK
#   ROC AUC = 0.8665, Elapsed time = 216.46 seconds
#
# === Model IV Late - Fold 7/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 7] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0066 (diff: 0.0002)
#     Test SL rate:    0.0036 (diff: 0.0028)
#     Train/Test diff: 0.0030
# Stratification OK
#   ROC AUC = 0.9949, Elapsed time = 252.85 seconds
#
# === Model IV Late - Fold 8/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 8] Stratification Check:
#     Overall SL rate: 0.0068
#     Train SL rate:   0.0070 (diff: 0.0002)
#     Test SL rate:    0.0036 (diff: 0.0032)
#     Train/Test diff: 0.0034
# Stratification OK
#   ROC AUC = 0.9762, Elapsed time = 291.92 seconds
#
# === Model IV Late - Fold 9/50 ===
# Train size = 26712, Test size = 1668
#   [Model IV Late - Fold 9] Stratification Check:
#     Overall SL rate: 0.0048
#     Train SL rate:   0.0042 (diff: 0.0006)
#     Test SL rate:    0.0138 (diff: 0.0090)
#     Train/Test diff: 0.0096
# Stratification OK
#   ROC AUC = 0.9001, Elapsed time = 325.20 seconds
#
# === Model IV Late - Fold 10/50 ===
# Train size = 26712, Test size = 1668
#   [Model IV Late - Fold 10] Stratification Check:
#     Overall SL rate: 0.0069
#     Train SL rate:   0.0072 (diff: 0.0002)
#     Test SL rate:    0.0030 (diff: 0.0039)
#     Train/Test diff: 0.0042
# Stratification OK
#   ROC AUC = 0.9491, Elapsed time = 362.22 seconds
#
# === Model IV Late - Fold 11/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 11] Stratification Check:
#     Overall SL rate: 0.0060
#     Train SL rate:   0.0058 (diff: 0.0001)
#     Test SL rate:    0.0084 (diff: 0.0024)
#     Train/Test diff: 0.0025
# Stratification OK
#   ROC AUC = 0.9359, Elapsed time = 402.91 seconds
#
# === Model IV Late - Fold 12/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 12] Stratification Check:
#     Overall SL rate: 0.0063
#     Train SL rate:   0.0065 (diff: 0.0001)
#     Test SL rate:    0.0042 (diff: 0.0022)
#     Train/Test diff: 0.0023
# Stratification OK
#   ROC AUC = 0.8663, Elapsed time = 446.46 seconds
#
# === Model IV Late - Fold 13/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 13] Stratification Check:
#     Overall SL rate: 0.0072
#     Train SL rate:   0.0075 (diff: 0.0002)
#     Test SL rate:    0.0036 (diff: 0.0036)
#     Train/Test diff: 0.0039
# Stratification OK
#   ROC AUC = 0.9748, Elapsed time = 486.77 seconds
#
# === Model IV Late - Fold 14/50 ===
# Train size = 26712, Test size = 1668
#   [Model IV Late - Fold 14] Stratification Check:
#     Overall SL rate: 0.0057
#     Train SL rate:   0.0056 (diff: 0.0001)
#     Test SL rate:    0.0078 (diff: 0.0021)
#     Train/Test diff: 0.0022
# Stratification OK
#   ROC AUC = 0.8972, Elapsed time = 527.58 seconds
#
# === Model IV Late - Fold 15/50 ===
# Train size = 26712, Test size = 1668
#   [Model IV Late - Fold 15] Stratification Check:
#     Overall SL rate: 0.0066
#     Train SL rate:   0.0064 (diff: 0.0001)
#     Test SL rate:    0.0084 (diff: 0.0018)
#     Train/Test diff: 0.0020
# Stratification OK
#   ROC AUC = 0.8685, Elapsed time = 564.67 seconds
#
# === Model IV Late - Fold 16/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 16] Stratification Check:
#     Overall SL rate: 0.0067
#     Train SL rate:   0.0069 (diff: 0.0002)
#     Test SL rate:    0.0030 (diff: 0.0037)
#     Train/Test diff: 0.0039
# Stratification OK
#   ROC AUC = 0.9683, Elapsed time = 600.45 seconds
#
# === Model IV Late - Fold 17/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 17] Stratification Check:
#     Overall SL rate: 0.0065
#     Train SL rate:   0.0065 (diff: 0.0000)
#     Test SL rate:    0.0066 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9288, Elapsed time = 632.69 seconds
#
# === Model IV Late - Fold 18/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 18] Stratification Check:
#     Overall SL rate: 0.0068
#     Train SL rate:   0.0069 (diff: 0.0001)
#     Test SL rate:    0.0048 (diff: 0.0020)
#     Train/Test diff: 0.0021
# Stratification OK
#   ROC AUC = 0.9598, Elapsed time = 666.92 seconds
#
# === Model IV Late - Fold 19/50 ===
# Train size = 26712, Test size = 1668
#   [Model IV Late - Fold 19] Stratification Check:
#     Overall SL rate: 0.0051
#     Train SL rate:   0.0045 (diff: 0.0007)
#     Test SL rate:    0.0162 (diff: 0.0110)
#     Train/Test diff: 0.0117
# Stratification OK
#   ROC AUC = 0.9598, Elapsed time = 700.49 seconds
#
# === Model IV Late - Fold 20/50 ===
# Train size = 26712, Test size = 1668
#   [Model IV Late - Fold 20] Stratification Check:
#     Overall SL rate: 0.0069
#     Train SL rate:   0.0071 (diff: 0.0002)
#     Test SL rate:    0.0036 (diff: 0.0033)
#     Train/Test diff: 0.0035
# Stratification OK
#   ROC AUC = 0.8042, Elapsed time = 737.64 seconds
#
# === Model IV Late - Fold 21/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 21] Stratification Check:
#     Overall SL rate: 0.0059
#     Train SL rate:   0.0060 (diff: 0.0001)
#     Test SL rate:    0.0048 (diff: 0.0011)
#     Train/Test diff: 0.0012
# Stratification OK
#   ROC AUC = 0.9468, Elapsed time = 770.71 seconds
#
# === Model IV Late - Fold 22/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 22] Stratification Check:
#     Overall SL rate: 0.0059
#     Train SL rate:   0.0056 (diff: 0.0003)
#     Test SL rate:    0.0102 (diff: 0.0043)
#     Train/Test diff: 0.0046
# Stratification OK
#   ROC AUC = 0.8119, Elapsed time = 812.18 seconds
#
# === Model IV Late - Fold 23/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 23] Stratification Check:
#     Overall SL rate: 0.0067
#     Train SL rate:   0.0067 (diff: 0.0000)
#     Test SL rate:    0.0060 (diff: 0.0007)
#     Train/Test diff: 0.0007
# Stratification OK
#   ROC AUC = 0.9927, Elapsed time = 851.97 seconds
#
# === Model IV Late - Fold 24/50 ===
# Train size = 26712, Test size = 1668
#   [Model IV Late - Fold 24] Stratification Check:
#     Overall SL rate: 0.0070
#     Train SL rate:   0.0071 (diff: 0.0000)
#     Test SL rate:    0.0066 (diff: 0.0005)
#     Train/Test diff: 0.0005
# Stratification OK
#   ROC AUC = 0.8395, Elapsed time = 892.39 seconds
#
# === Model IV Late - Fold 25/50 ===
# Train size = 26712, Test size = 1668
#   [Model IV Late - Fold 25] Stratification Check:
#     Overall SL rate: 0.0063
#     Train SL rate:   0.0064 (diff: 0.0001)
#     Test SL rate:    0.0042 (diff: 0.0021)
#     Train/Test diff: 0.0022
# Stratification OK
#   ROC AUC = 0.9799, Elapsed time = 930.27 seconds
#
# === Model IV Late - Fold 26/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 26] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0066 (diff: 0.0002)
#     Test SL rate:    0.0036 (diff: 0.0029)
#     Train/Test diff: 0.0030
# Stratification OK
#   ROC AUC = 0.9216, Elapsed time = 969.36 seconds
#
# === Model IV Late - Fold 27/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 27] Stratification Check:
#     Overall SL rate: 0.0060
#     Train SL rate:   0.0059 (diff: 0.0001)
#     Test SL rate:    0.0072 (diff: 0.0012)
#     Train/Test diff: 0.0013
# Stratification OK
#   ROC AUC = 0.9512, Elapsed time = 1000.44 seconds
#
# === Model IV Late - Fold 28/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 28] Stratification Check:
#     Overall SL rate: 0.0062
#     Train SL rate:   0.0061 (diff: 0.0001)
#     Test SL rate:    0.0078 (diff: 0.0015)
#     Train/Test diff: 0.0016
# Stratification OK
#   ROC AUC = 0.9220, Elapsed time = 1035.46 seconds
#
# === Model IV Late - Fold 29/50 ===
# Train size = 26712, Test size = 1668
#   [Model IV Late - Fold 29] Stratification Check:
#     Overall SL rate: 0.0067
#     Train SL rate:   0.0070 (diff: 0.0003)
#     Test SL rate:    0.0018 (diff: 0.0049)
#     Train/Test diff: 0.0052
# Stratification OK
#   ROC AUC = 0.8909, Elapsed time = 1070.53 seconds
#
# === Model IV Late - Fold 30/50 ===
# Train size = 26712, Test size = 1668
#   [Model IV Late - Fold 30] Stratification Check:
#     Overall SL rate: 0.0057
#     Train SL rate:   0.0057 (diff: 0.0000)
#     Test SL rate:    0.0054 (diff: 0.0003)
#     Train/Test diff: 0.0003
# Stratification OK
#   ROC AUC = 0.9642, Elapsed time = 1104.30 seconds
#
# === Model IV Late - Fold 31/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 31] Stratification Check:
#     Overall SL rate: 0.0060
#     Train SL rate:   0.0055 (diff: 0.0004)
#     Test SL rate:    0.0132 (diff: 0.0072)
#     Train/Test diff: 0.0076
# Stratification OK
#   ROC AUC = 0.9839, Elapsed time = 1137.10 seconds
#
# === Model IV Late - Fold 32/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 32] Stratification Check:
#     Overall SL rate: 0.0072
#     Train SL rate:   0.0075 (diff: 0.0003)
#     Test SL rate:    0.0024 (diff: 0.0048)
#     Train/Test diff: 0.0051
# Stratification OK
#   ROC AUC = 0.9928, Elapsed time = 1174.72 seconds
#
# === Model IV Late - Fold 33/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 33] Stratification Check:
#     Overall SL rate: 0.0065
#     Train SL rate:   0.0066 (diff: 0.0000)
#     Test SL rate:    0.0060 (diff: 0.0005)
#     Train/Test diff: 0.0006
# Stratification OK
#   ROC AUC = 0.9440, Elapsed time = 1211.01 seconds
#
# === Model IV Late - Fold 34/50 ===
# Train size = 26712, Test size = 1668
#   [Model IV Late - Fold 34] Stratification Check:
#     Overall SL rate: 0.0054
#     Train SL rate:   0.0052 (diff: 0.0002)
#     Test SL rate:    0.0078 (diff: 0.0024)
#     Train/Test diff: 0.0026
# Stratification OK
#   ROC AUC = 0.7902, Elapsed time = 1241.30 seconds
#
# === Model IV Late - Fold 35/50 ===
# Train size = 26712, Test size = 1668
#   [Model IV Late - Fold 35] Stratification Check:
#     Overall SL rate: 0.0067
#     Train SL rate:   0.0070 (diff: 0.0002)
#     Test SL rate:    0.0030 (diff: 0.0037)
#     Train/Test diff: 0.0040
# Stratification OK
#   ROC AUC = 0.9560, Elapsed time = 1276.33 seconds
#
# === Model IV Late - Fold 36/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 36] Stratification Check:
#     Overall SL rate: 0.0066
#     Train SL rate:   0.0066 (diff: 0.0001)
#     Test SL rate:    0.0054 (diff: 0.0012)
#     Train/Test diff: 0.0012
# Stratification OK
#   ROC AUC = 0.8394, Elapsed time = 1311.07 seconds
#
# === Model IV Late - Fold 37/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 37] Stratification Check:
#     Overall SL rate: 0.0060
#     Train SL rate:   0.0060 (diff: 0.0000)
#     Test SL rate:    0.0060 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9688, Elapsed time = 1342.55 seconds
#
# === Model IV Late - Fold 38/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 38] Stratification Check:
#     Overall SL rate: 0.0063
#     Train SL rate:   0.0062 (diff: 0.0001)
#     Test SL rate:    0.0078 (diff: 0.0015)
#     Train/Test diff: 0.0016
# Stratification OK
#   ROC AUC = 0.9570, Elapsed time = 1376.32 seconds
#
# === Model IV Late - Fold 39/50 ===
# Train size = 26712, Test size = 1668
#   [Model IV Late - Fold 39] Stratification Check:
#     Overall SL rate: 0.0066
#     Train SL rate:   0.0066 (diff: 0.0000)
#     Test SL rate:    0.0066 (diff: 0.0000)
#     Train/Test diff: 0.0000
# Stratification OK
#   ROC AUC = 0.9112, Elapsed time = 1406.51 seconds
#
# === Model IV Late - Fold 40/50 ===
# Train size = 26712, Test size = 1668
#   [Model IV Late - Fold 40] Stratification Check:
#     Overall SL rate: 0.0066
#     Train SL rate:   0.0065 (diff: 0.0001)
#     Test SL rate:    0.0078 (diff: 0.0012)
#     Train/Test diff: 0.0013
# Stratification OK
#   ROC AUC = 0.9100, Elapsed time = 1439.81 seconds
#
# === Model IV Late - Fold 41/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 41] Stratification Check:
#     Overall SL rate: 0.0057
#     Train SL rate:   0.0056 (diff: 0.0001)
#     Test SL rate:    0.0072 (diff: 0.0015)
#     Train/Test diff: 0.0016
# Stratification OK
#   ROC AUC = 0.9178, Elapsed time = 1473.36 seconds
#
# === Model IV Late - Fold 42/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 42] Stratification Check:
#     Overall SL rate: 0.0069
#     Train SL rate:   0.0073 (diff: 0.0004)
#     Test SL rate:    0.0006 (diff: 0.0063)
#     Train/Test diff: 0.0067
# Stratification OK
#   ROC AUC = 0.9934, Elapsed time = 1505.95 seconds
#
# === Model IV Late - Fold 43/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 43] Stratification Check:
#     Overall SL rate: 0.0054
#     Train SL rate:   0.0052 (diff: 0.0002)
#     Test SL rate:    0.0090 (diff: 0.0036)
#     Train/Test diff: 0.0038
# Stratification OK
#   ROC AUC = 0.8672, Elapsed time = 1533.32 seconds
#
# === Model IV Late - Fold 44/50 ===
# Train size = 26712, Test size = 1668
#   [Model IV Late - Fold 44] Stratification Check:
#     Overall SL rate: 0.0059
#     Train SL rate:   0.0059 (diff: 0.0000)
#     Test SL rate:    0.0060 (diff: 0.0001)
#     Train/Test diff: 0.0001
# Stratification OK
#   ROC AUC = 0.9444, Elapsed time = 1569.24 seconds
#
# === Model IV Late - Fold 45/50 ===
# Train size = 26712, Test size = 1668
#   [Model IV Late - Fold 45] Stratification Check:
#     Overall SL rate: 0.0069
#     Train SL rate:   0.0073 (diff: 0.0004)
#     Test SL rate:    0.0006 (diff: 0.0063)
#     Train/Test diff: 0.0067
# Stratification OK
#   ROC AUC = 0.9622, Elapsed time = 1604.18 seconds
#
# === Model IV Late - Fold 46/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 46] Stratification Check:
#     Overall SL rate: 0.0060
#     Train SL rate:   0.0059 (diff: 0.0001)
#     Test SL rate:    0.0072 (diff: 0.0012)
#     Train/Test diff: 0.0013
# Stratification OK
#   ROC AUC = 0.9743, Elapsed time = 1636.45 seconds
#
# === Model IV Late - Fold 47/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 47] Stratification Check:
#     Overall SL rate: 0.0068
#     Train SL rate:   0.0070 (diff: 0.0002)
#     Test SL rate:    0.0036 (diff: 0.0032)
#     Train/Test diff: 0.0034
# Stratification OK
#   ROC AUC = 0.9949, Elapsed time = 1670.54 seconds
#
# === Model IV Late - Fold 48/50 ===
# Train size = 26704, Test size = 1670
#   [Model IV Late - Fold 48] Stratification Check:
#     Overall SL rate: 0.0060
#     Train SL rate:   0.0057 (diff: 0.0002)
#     Test SL rate:    0.0096 (diff: 0.0036)
#     Train/Test diff: 0.0039
# Stratification OK
#   ROC AUC = 0.9059, Elapsed time = 1711.04 seconds
#
# === Model IV Late - Fold 49/50 ===
# Train size = 26712, Test size = 1668
#   [Model IV Late - Fold 49] Stratification Check:
#     Overall SL rate: 0.0063
#     Train SL rate:   0.0064 (diff: 0.0001)
#     Test SL rate:    0.0048 (diff: 0.0015)
#     Train/Test diff: 0.0016
# Stratification OK
#   ROC AUC = 0.8954, Elapsed time = 1745.30 seconds
#
# === Model IV Late - Fold 50/50 ===
# Train size = 26712, Test size = 1668
#   [Model IV Late - Fold 50] Stratification Check:
#     Overall SL rate: 0.0064
#     Train SL rate:   0.0066 (diff: 0.0001)
#     Test SL rate:    0.0042 (diff: 0.0022)
#     Train/Test diff: 0.0024
# Stratification OK
#   ROC AUC = 0.9881, Elapsed time = 1781.14 seconds
#
# === Model IV Late Summary ===
# Mean ROC AUC = 0.9263 ± 0.0524
# Successful folds: 50/50
# Stratification quality:
# Mean train deviation: 0.0002 ± 0.0001
# Mean test deviation: 0.0027 ± 0.0022

# %%
# save results of cross validation
with open(file_RF_model_IV_contextualized, 'wb') as f:
    pickle.dump(model_IV_contextualized, f)

with open(file_RF_model_IV_full, 'wb') as f:
    pickle.dump(model_IV_full, f)

# %%
def generate_validation_report(model_results, model_name):
    """Generate a comprehensive validation report for a model."""
    print(f"\n{'='*50}")
    print(f"VALIDATION REPORT: {model_name}")
    print(f"{'='*50}")
    
    # Performance summary
    print(f"Performance:")
    print(f"  Mean ROC AUC: {model_results['mean_auc']:.4f} ± {model_results['std_auc']:.4f}")
    print(f"  Mean PR AUC:  {model_results['mean_aps']:.4f} ± {model_results['std_ap']:.4f}")
    print(f"  Effective folds: {model_results['effective_folds']}")
    
    if 'skipped_folds' in model_results and model_results['skipped_folds']:
        print(f"  Skipped folds: {model_results['skipped_folds']}")
    
    # Stratification summary
    if 'stratification_results' in model_results:
        strat_results = model_results['stratification_results']
        if strat_results:
            train_diffs = [r['train_diff'] for r in strat_results]
            test_diffs = [r['test_diff'] for r in strat_results]
            warnings_count = sum(len(r['warnings']) for r in strat_results)
            
            print(f"\nStratification Quality:")
            print(f"  Mean train deviation: {np.mean(train_diffs):.4f} ± {np.std(train_diffs):.4f}")
            print(f"  Mean test deviation:  {np.mean(test_diffs):.4f} ± {np.std(test_diffs):.4f}")
            print(f"  Total warnings: {warnings_count}")
            
            if warnings_count > 0:
                print(f"Some folds had stratification issues")
            else:
                print(f"All folds passed stratification checks")

# Generate reports for all models
all_models = [
    (model_I_econtextualized, "Model I contextualized"),
    (model_I_full, "Model I full"),
    (model_II_contextualized, "Model II contextualized"),
    (model_II_full, "Model II full"),
    (model_III_contextualized, "Model III contextualized"),
    (model_III_full, "Model III full"),
    (model_IV_contextualized, "Model IV contextualized"),
    (model_IV_full, "Model IV full")
]

for model_result, model_name in all_models:
    generate_validation_report(model_result, model_name)
# Out:
# ==================================================
# VALIDATION REPORT: Model I Early
# ==================================================
# Performance:
#   Mean ROC AUC: 0.9534 ± 0.0060
#   Mean PR AUC:  0.3599 ± 0.0475
#   Effective folds: 5
#
# Stratification Quality:
#   Mean train deviation: 0.0000 ± 0.0000
#   Mean test deviation:  0.0000 ± 0.0000
#   Total warnings: 0
# All folds passed stratification checks
#
# ==================================================
# VALIDATION REPORT: Model I Late
# ==================================================
# Performance:
#   Mean ROC AUC: 0.9518 ± 0.0104
#   Mean PR AUC:  0.4550 ± 0.0715
#   Effective folds: 5
#
# Stratification Quality:
#   Mean train deviation: 0.0000 ± 0.0000
#   Mean test deviation:  0.0000 ± 0.0000
#   Total warnings: 0
# All folds passed stratification checks
#
# ==================================================
# VALIDATION REPORT: Model II Early
# ==================================================
# Performance:
#   Mean ROC AUC: 0.9233 ± 0.0303
#   Mean PR AUC:  0.2554 ± 0.0511
#   Effective folds: 5
#
# Stratification Quality:
#   Mean train deviation: 0.0004 ± 0.0002
#   Mean test deviation:  0.0016 ± 0.0008
#   Total warnings: 0
# All folds passed stratification checks
#
# ==================================================
# VALIDATION REPORT: Model II Late
# ==================================================
# Performance:
#   Mean ROC AUC: 0.9435 ± 0.0201
#   Mean PR AUC:  0.3731 ± 0.0476
#   Effective folds: 5
#
# Stratification Quality:
#   Mean train deviation: 0.0004 ± 0.0002
#   Mean test deviation:  0.0016 ± 0.0008
#   Total warnings: 0
# All folds passed stratification checks
#
# ==================================================
# VALIDATION REPORT: Model III Early
# ==================================================
# Performance:
#   Mean ROC AUC: 0.9330 ± 0.0207
#   Mean PR AUC:  0.2529 ± 0.1241
#   Effective folds: 5
#
# Stratification Quality:
#   Mean train deviation: 0.0002 ± 0.0001
#   Mean test deviation:  0.0009 ± 0.0005
#   Total warnings: 0
# All folds passed stratification checks
#
# ==================================================
# VALIDATION REPORT: Model III Late
# ==================================================
# Performance:
#   Mean ROC AUC: 0.9305 ± 0.0272
#   Mean PR AUC:  0.3093 ± 0.1003
#   Effective folds: 5
#
# Stratification Quality:
#   Mean train deviation: 0.0002 ± 0.0001
#   Mean test deviation:  0.0009 ± 0.0005
#   Total warnings: 0
# All folds passed stratification checks
#
# ==================================================
# VALIDATION REPORT: Model IV Early
# ==================================================
# Performance:
#   Mean ROC AUC: 0.8835 ± 0.1043
#   Mean PR AUC:  0.1671 ± 0.1226
#   Effective folds: 50
#
# Stratification Quality:
#   Mean train deviation: 0.0002 ± 0.0001
#   Mean test deviation:  0.0027 ± 0.0022
#   Total warnings: 0
# All folds passed stratification checks
#
# ==================================================
# VALIDATION REPORT: Model IV Late
# ==================================================
# Performance:
#   Mean ROC AUC: 0.9263 ± 0.0524
#   Mean PR AUC:  0.2174 ± 0.1458
#   Effective folds: 50
#
# Stratification Quality:
#   Mean train deviation: 0.0002 ± 0.0001
#   Mean test deviation:  0.0027 ± 0.0022
#   Total warnings: 0
# All folds passed stratification checks
