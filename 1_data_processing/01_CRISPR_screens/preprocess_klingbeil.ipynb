# %% [markdown]
# ### Klingbeil et al Screen
#
# This notebook preprocesses CRISPR screen data from *Klingbeil et al., 2024*
# It loads GEMINI data from the paper’s supplementary tables (Excel format), cleans and formats the data, and prepares the dataset for downstream feature annotation and training of the Random Forest classifier.
#
# **Inputs:**
# - Excel file(s) containing GEMINI scores from the *Klingbeil et al., 2024* supplementary materials.
#
# **Outputs:**
# - A cleaned and processed dataset saved as a CSV file, ready for feature annotation and model training.

# %%
# import modules
import os
import pandas as pd
import numpy as np
from natsort import natsorted

# %%
# set the base directory for the project
cwd = os.getcwd()
BASE_DIR = os.path.abspath(os.path.join(cwd, "..", ".."))

# build paths inside the repo
get_data_path = lambda folders, fname: os.path.normpath(
    os.path.join(BASE_DIR, *folders, fname)
)

file_path_gemini_data = get_data_path(['input', 'CRISPR_screens'], 'cd-23-1529_supplementary_table_s4_suppst4.xlsx')
file_path_lfc = get_data_path(['input', 'CRISPR_screens'], 'cd-23-1529_supplementary_table_s2_suppst2.xlsx')
file_path_fdr = get_data_path(['input', 'CRISPR_screens'], 'cd-23-1529_supplementary_table_s6_suppst6.xlsx')

file_path_genenames = get_data_path(['input', 'other'], 'approved_and_previous_symbols.csv')

file_path_sample_info = get_data_path(['input', 'DepMap22Q4'], 'sample_info.csv')

file_path_processed_klingbeil_df = get_data_path(['output', 'processed_CRISPR_screens'], 'processed_klingbeil_df.csv')

# %% [markdown]
# ### Load and Parse Raw Data
#
# **Load GEMINI scores and parse gene combinations:**
# - Extract individual gene symbols (A1, A2) from GENE_COMBINATION column
# - Extract domain information for each gene pair

# %%
klingbeil_gemini_data = pd.read_excel(file_path_gemini_data, header=0)
klingbeil_gemini_data.head()
# Out:
#                          GENE_COMBINATION      A549     ASPC1   CORL311  \
# 0  AAK1:Kinase_domain;BMP2K:Kinase_domain  0.149179  0.013571 -1.197798
# 1    AAK1:Kinase_domain;GAK:Kinase_domain -0.138258  0.090206  0.798102
# 2  AATK:Kinase_domain;LMTK2:Kinase_domain  0.135116  0.431222  1.929479
# 3  AATK:Kinase_domain;LMTK3:Kinase_domain  0.719263  0.327775  1.239107
# 4   ABL1:Kinase_domain;ABL2:Kinase_domain  0.167744 -0.075911 -0.372658
#
#       H1048     H1299     H1436     H1836      H209      H211  ...  MDAMB231  \
# 0  0.261443  0.023990 -0.441891 -0.034478 -0.386031  0.185165  ...  0.324981
# 1  0.215741 -0.441030 -0.296563  0.079513 -0.882233 -0.432478  ...  0.203387
# 2  0.275190  0.588202  0.076160 -0.112620 -0.279744  0.418585  ...  0.107870
# 3  0.964623  0.491682  0.405034  0.254769  0.419086  0.354852  ...  0.214340
# 4  0.116252  0.119891  0.391952  0.046169  0.074462  0.064427  ...  0.348412
#
#      MOLM13     NOMO1  PATU8902        RD      RH30      SET2      T3M4  \
# 0  0.042842  0.148144  0.303483  0.292166 -0.400358  0.303414  0.205641
# 1 -0.017059 -0.285411  0.678253 -0.194935 -0.436718 -0.049500 -0.283085
# 2  0.160368  0.269045  0.522920  0.643115 -0.360885  0.101280  0.054210
# 3  0.322302  0.157412  0.377417 -0.046904  0.934033  0.233265  0.468751
# 4  0.285462  0.345206 -0.405309  0.271277 -0.090763  0.159590  0.137751
#
#        THP1      YAPC
# 0  0.031737  0.631192
# 1  0.372368  0.368154
# 2 -0.248565  0.013551
# 3  0.371488  0.240569
# 4 -0.022266  0.308193
#
# [5 rows x 23 columns]

# %%
klingbeil_gemini_data[['A1', 'A2']] = klingbeil_gemini_data['GENE_COMBINATION'].str.split(';', expand=True)
klingbeil_gemini_data['A1'] = klingbeil_gemini_data['A1'].str.split(':').str[0]
klingbeil_gemini_data['A2'] = klingbeil_gemini_data['A2'].str.split(':').str[0]
klingbeil_gemini_data[:1]
# Out:
#                          GENE_COMBINATION      A549     ASPC1   CORL311  \
# 0  AAK1:Kinase_domain;BMP2K:Kinase_domain  0.149179  0.013571 -1.197798
#
#       H1048    H1299     H1436     H1836      H209      H211  ...     NOMO1  \
# 0  0.261443  0.02399 -0.441891 -0.034478 -0.386031  0.185165  ...  0.148144
#
#    PATU8902        RD      RH30      SET2      T3M4      THP1      YAPC    A1  \
# 0  0.303483  0.292166 -0.400358  0.303414  0.205641  0.031737  0.631192  AAK1
#
#       A2
# 0  BMP2K
#
# [1 rows x 25 columns]

# %%
klingbeil_gemini_data[['domain_1', 'domain_2']] = klingbeil_gemini_data['GENE_COMBINATION'].str.split(';', expand=True)
klingbeil_gemini_data['domain_1'] = klingbeil_gemini_data['domain_1'].str.split(':').str[1]
klingbeil_gemini_data['domain_2'] = klingbeil_gemini_data['domain_2'].str.split(':').str[1]
klingbeil_gemini_data['domain_combination'] = klingbeil_gemini_data['domain_1'] + '_' + klingbeil_gemini_data['domain_2']
klingbeil_gemini_data[:1]
# Out:
#                          GENE_COMBINATION      A549     ASPC1   CORL311  \
# 0  AAK1:Kinase_domain;BMP2K:Kinase_domain  0.149179  0.013571 -1.197798
#
#       H1048    H1299     H1436     H1836      H209      H211  ...      RH30  \
# 0  0.261443  0.02399 -0.441891 -0.034478 -0.386031  0.185165  ... -0.400358
#
#        SET2      T3M4      THP1      YAPC    A1     A2       domain_1  \
# 0  0.303414  0.205641  0.031737  0.631192  AAK1  BMP2K  Kinase_domain
#
#         domain_2           domain_combination
# 0  Kinase_domain  Kinase_domain_Kinase_domain
#
# [1 rows x 28 columns]

# %%
klingbeil_lfc_data = pd.read_excel(file_path_lfc, header=0)
klingbeil_lfc_data = klingbeil_lfc_data.rename(columns={'GENE 1':'A1', 'GENE 2':'A2'})
klingbeil_lfc_data['domain_combination'] = klingbeil_lfc_data['domain_1'] + '_' + klingbeil_lfc_data['domain_2']
klingbeil_lfc_data.head()
# Out:
#       A1             domain_1                  A2             domain_2  \
# 0  ACAA1  acetyltransf_domain               ACAT2  acetyltransf_domain
# 1  ACAA1  acetyltransf_domain     CUTTING_CONTROL             nodomain
# 2  ACAA1  acetyltransf_domain               HADHB  acetyltransf_domain
# 3  ACAA1  acetyltransf_domain  NONCUTTING_CONTROL             nodomain
# 4  ACAA2  acetyltransf_domain               ACAT2  acetyltransf_domain
#
#        A549     ASPC1   CORL311     H1048     H1299     H1436  ...    MOLM13  \
# 0  0.142126  0.241221 -0.106777  0.229456 -0.107029  0.104877  ... -0.234771
# 1  0.431196  0.111248  0.489067  0.615033 -0.568595  0.420573  ...  0.318320
# 2 -0.314980  0.188896 -0.071631  0.278144 -0.029604  0.525712  ...  0.312417
# 3  0.846503  0.670848  1.505050  0.907308  0.073176  0.762751  ...  0.681280
# 4  0.501288  0.047508 -0.576668  0.434734  0.386746 -0.399537  ... -0.358370
#
#       NOMO1  PATU8902        RD      RH30      SET2      T3M4      THP1  \
# 0  0.033042 -0.548081  0.206175 -0.437077 -0.054353  0.323201  0.111964
# 1  0.008801 -1.806178 -0.108865  1.880924 -0.057810  0.037888  0.480528
# 2  0.148599 -1.801456 -0.053281 -0.494690  0.016748  0.075818 -0.785397
# 3  0.806813 -0.786907  0.445177  1.429772  0.259646  0.326572  0.395359
# 4 -0.136637  1.217597  0.176455 -0.418444 -0.040247  0.171509  0.147735
#
#        YAPC                       domain_combination
# 0  0.481936  acetyltransf_domain_acetyltransf_domain
# 1  0.596389             acetyltransf_domain_nodomain
# 2 -0.110980  acetyltransf_domain_acetyltransf_domain
# 3  0.998877             acetyltransf_domain_nodomain
# 4  0.470465  acetyltransf_domain_acetyltransf_domain
#
# [5 rows x 27 columns]

# %%
#klingbeil_lfc_data.loc[klingbeil_lfc_data['A1'] == 'CUTTING_CONTROL',][:3]
#klingbeil_lfc_data.loc[klingbeil_lfc_data['A1'] == 'NONCUTTING_CONTROL',][:3]

# %%
klingbeil_fdr_data = pd.read_excel(file_path_fdr, header=0)
klingbeil_fdr_data.head()
# Out:
#                          GENE_COMBINATION      A549     ASPC1   CORL311  \
# 0  AAK1:Kinase_domain;BMP2K:Kinase_domain  0.998805  1.000000  0.990087
# 1    AAK1:Kinase_domain;GAK:Kinase_domain  0.999240  0.929591  0.939242
# 2  AATK:Kinase_domain;LMTK2:Kinase_domain  0.998805  0.639809  0.939242
# 3  AATK:Kinase_domain;LMTK3:Kinase_domain  0.974176  0.639809  0.939242
# 4   ABL1:Kinase_domain;ABL2:Kinase_domain  0.998805  1.000000  0.987293
#
#       H1048     H1299     H1436     H1836      H209      H211  ...  MDAMB231  \
# 0  0.999833  0.998710  0.984006  1.000000  1.000000  0.779760  ...  0.999043
# 1  0.999833  0.998710  0.967486  0.983954  1.000000  0.944687  ...  0.999043
# 2  0.999833  0.906256  0.911471  1.000000  0.985080  0.719806  ...  0.999043
# 3  0.504708  0.997423  0.898025  0.922539  0.430594  0.737916  ...  0.999043
# 4  0.999833  0.998710  0.898025  0.984334  0.803632  0.813953  ...  0.999043
#
#      MOLM13     NOMO1  PATU8902        RD      RH30      SET2      T3M4  \
# 0  0.913584  0.890476  0.976135  1.000000  0.992589  0.796562  0.844509
# 1  0.950717  0.987791  0.911162  1.000000  0.992589  0.992691  0.997798
# 2  0.810098  0.822935  0.947698  0.926708  0.992589  0.949712  0.968886
# 3  0.715139  0.886476  0.968578  1.000000  0.779967  0.862029  0.626180
# 4  0.733614  0.764939  0.999081  1.000000  0.981676  0.914717  0.922679
#
#        THP1      YAPC
# 0  0.994081  0.872423
# 1  0.719461  0.879377
# 2  1.000000  0.988758
# 3  0.720471  0.910421
# 4  1.000000  0.896882
#
# [5 rows x 23 columns]

# %%
klingbeil_fdr_data[['A1', 'A2']] = klingbeil_fdr_data['GENE_COMBINATION'].str.split(';', expand=True)
klingbeil_fdr_data['A1'] = klingbeil_fdr_data['A1'].str.split(':').str[0]
klingbeil_fdr_data['A2'] = klingbeil_fdr_data['A2'].str.split(':').str[0]
klingbeil_fdr_data[:1]
# Out:
#                          GENE_COMBINATION      A549  ASPC1   CORL311  \
# 0  AAK1:Kinase_domain;BMP2K:Kinase_domain  0.998805    1.0  0.990087
#
#       H1048    H1299     H1436  H1836  H209     H211  ...     NOMO1  PATU8902  \
# 0  0.999833  0.99871  0.984006    1.0   1.0  0.77976  ...  0.890476  0.976135
#
#     RD      RH30      SET2      T3M4      THP1      YAPC    A1     A2
# 0  1.0  0.992589  0.796562  0.844509  0.994081  0.872423  AAK1  BMP2K
#
# [1 rows x 25 columns]

# %%
klingbeil_fdr_data[['domain_1', 'domain_2']] = klingbeil_fdr_data['GENE_COMBINATION'].str.split(';', expand=True)
klingbeil_fdr_data['domain_1'] = klingbeil_fdr_data['domain_1'].str.split(':').str[1]
klingbeil_fdr_data['domain_2'] = klingbeil_fdr_data['domain_2'].str.split(':').str[1]
klingbeil_fdr_data['domain_combination'] = klingbeil_fdr_data['domain_1'] + '_' + klingbeil_fdr_data['domain_2']
klingbeil_fdr_data[:1]
# Out:
#                          GENE_COMBINATION      A549  ASPC1   CORL311  \
# 0  AAK1:Kinase_domain;BMP2K:Kinase_domain  0.998805    1.0  0.990087
#
#       H1048    H1299     H1436  H1836  H209     H211  ...      RH30      SET2  \
# 0  0.999833  0.99871  0.984006    1.0   1.0  0.77976  ...  0.992589  0.796562
#
#        T3M4      THP1      YAPC    A1     A2       domain_1       domain_2  \
# 0  0.844509  0.994081  0.872423  AAK1  BMP2K  Kinase_domain  Kinase_domain
#
#             domain_combination
# 0  Kinase_domain_Kinase_domain
#
# [1 rows x 28 columns]

# %% [markdown]
# ### Reshape Data from Wide to Long Format
#
# **Melt data to long format for all three datasets:**
# - Convert wide format (one column per cell line) to long format
# - Create separate DataFrames for GEMINI, LFC, and FDR scores

# %%
klingbeil_gemini_df = klingbeil_gemini_data.melt(id_vars=['GENE_COMBINATION', 'domain_combination', 'A1', 'A2'], 
                                                 value_vars=['A549', 'ASPC1', 'CORL311', 'H1048', 'H1299',
                                                             'H1436', 'H1836', 'H209', 'H211', 'HEL', 'HPAFII', 'K562', 'MDAMB231',
                                                             'MOLM13', 'NOMO1', 'PATU8902', 'RD', 'RH30', 'SET2', 'T3M4', 'THP1',
                                                             'YAPC'], 
                                                var_name='cell_line', value_name='GEMINI')

klingbeil_lfc_df = klingbeil_lfc_data.melt(id_vars=['domain_combination', 'A1', 'A2'], 
                                           value_vars=['A549', 'ASPC1', 'CORL311', 'H1048', 'H1299',
                                                        'H1436', 'H1836', 'H209', 'H211', 'HEL', 'HPAFII', 'K562', 'MDAMB231',
                                                        'MOLM13', 'NOMO1', 'PATU8902', 'RD', 'RH30', 'SET2', 'T3M4', 'THP1',
                                                        'YAPC'], 
                                            var_name='cell_line', value_name='LFC')

klingbeil_fdr_df = klingbeil_fdr_data.melt(id_vars=['GENE_COMBINATION', 'domain_combination', 'A1', 'A2'], 
                                           value_vars=['A549', 'ASPC1', 'CORL311', 'H1048', 'H1299',
                                                             'H1436', 'H1836', 'H209', 'H211', 'HEL', 'HPAFII', 'K562', 'MDAMB231',
                                                             'MOLM13', 'NOMO1', 'PATU8902', 'RD', 'RH30', 'SET2', 'T3M4', 'THP1',
                                                             'YAPC'], 
                                            var_name='cell_line', value_name='FDR')

# %% [markdown]
# ### Merge Datasets
#
# **Combine GEMINI, FDR, and LFC data:**

# %%
klingbeil_df = pd.merge(klingbeil_gemini_df, klingbeil_fdr_df, on=['GENE_COMBINATION', 'domain_combination', 'A1', 'A2', 'cell_line'], how='inner')
klingbeil_df[:3]
# Out:
#                          GENE_COMBINATION           domain_combination    A1  \
# 0  AAK1:Kinase_domain;BMP2K:Kinase_domain  Kinase_domain_Kinase_domain  AAK1
# 1    AAK1:Kinase_domain;GAK:Kinase_domain  Kinase_domain_Kinase_domain  AAK1
# 2  AATK:Kinase_domain;LMTK2:Kinase_domain  Kinase_domain_Kinase_domain  AATK
#
#       A2 cell_line    GEMINI       FDR
# 0  BMP2K      A549  0.149179  0.998805
# 1    GAK      A549 -0.138258  0.999240
# 2  LMTK2      A549  0.135116  0.998805

# %%
klingbeil_df = pd.merge(klingbeil_df, klingbeil_lfc_df, on=['domain_combination', 'A1', 'A2', 'cell_line'], how='left')
klingbeil_df[:3]
# Out:
#                          GENE_COMBINATION           domain_combination    A1  \
# 0  AAK1:Kinase_domain;BMP2K:Kinase_domain  Kinase_domain_Kinase_domain  AAK1
# 1    AAK1:Kinase_domain;GAK:Kinase_domain  Kinase_domain_Kinase_domain  AAK1
# 2  AATK:Kinase_domain;LMTK2:Kinase_domain  Kinase_domain_Kinase_domain  AATK
#
#       A2 cell_line    GEMINI       FDR       LFC
# 0  BMP2K      A549  0.149179  0.998805  0.662254
# 1    GAK      A549 -0.138258  0.999240 -0.442264
# 2  LMTK2      A549  0.135116  0.998805  0.231514

# %%
klingbeil_df['GENE_COMBINATION'].nunique() == klingbeil_fdr_data.shape[0]
# Out:
# True

# %% [markdown]
# ### Map Gene Symbols to Entrez IDs
#
# **Load gene mapping data and create mapping dictionaries:**

# %%
# read the gene names mapping file
id_map = pd.read_csv(file_path_genenames)

# create dictionaries to map gene symbols to Entrez IDs
approved_sym_to_entrez_id = dict(zip(id_map['Approved symbol'], id_map['entrez_id']))
prev_sym_to_entrez_id = dict(zip(id_map['Previous symbol'], id_map['entrez_id']))

# %%
# Assign mapped NCBI Gene IDs to A1 and A2
klingbeil_df = klingbeil_df.assign(
    A1_entrez = klingbeil_df['A1'].map(approved_sym_to_entrez_id),
    A2_entrez = klingbeil_df['A2'].map(approved_sym_to_entrez_id))

# %%
display(klingbeil_df.loc[klingbeil_df['A1_entrez'].isna(), 'A1'].unique())
display(klingbeil_df.loc[klingbeil_df['A2_entrez'].isna(), 'A2'].unique())
missing_gene_symbols = set(klingbeil_df.loc[klingbeil_df['A1_entrez'].isna(), 'A1'].unique()).union(set(klingbeil_df.loc[klingbeil_df['A2_entrez'].isna(), 'A2'].unique()))
# Out:
# array(['ACPP', 'C16orf13', 'C19orf35', 'C3orf58', 'COL4A3BP', 'DUPD1',
#        'DUSP13', 'FAM109A', 'FAM69A', 'G6PC', 'GRAMD2', 'GSG2', 'HDGFRP2',
#        'HDGFRP3', 'ICK', 'KIAA1456', 'KIAA1804', 'LOC100996792',
#        'LOC102724428', 'LOC107986532', 'METTL11B', 'METTL7A', 'MUM1'],
#       dtype=object)
# array(['LOC107984026', 'ACPP', 'ACPT', 'KIAA1456', 'ALPPL2', 'IMPAD1',
#        'KIAA2026', 'WBSCR22', 'WBSCR27', 'CXorf36', 'PRPF4B', 'DUSP13',
#        'DUSP27', 'METTL12', 'FAM109B', 'FAM69B', 'FAM69C', 'HDGFRP3',
#        'GRAMD3', 'ZAK', 'RRNAD1', 'METTL7A', 'METTL7B', 'MUM1L1',
#        'PPP5D1', 'SGK494'], dtype=object)

# %%
klingbeil_df = klingbeil_df.assign(
    A1_entrez = klingbeil_df['A1_entrez'].fillna(klingbeil_df['A1'].map(prev_sym_to_entrez_id)),
    A2_entrez = klingbeil_df['A2_entrez'].fillna(klingbeil_df['A2'].map(prev_sym_to_entrez_id)))

# %%
display(klingbeil_df.loc[klingbeil_df['A1_entrez'].isna(), 'A1'].unique())
display(klingbeil_df.loc[klingbeil_df['A2_entrez'].isna(), 'A2'].unique())
# Out:
# array(['HDGFRP2', 'HDGFRP3', 'KIAA1804', 'LOC100996792', 'LOC102724428',
#        'LOC107986532'], dtype=object)
# array(['LOC107984026', 'HDGFRP3', 'ZAK', 'SGK494'], dtype=object)

# %% [markdown]
# ### Standardize Gene Symbols
#
# **Convert Entrez IDs back to approved gene symbols for consistency:**

# %%
klingbeil_df = klingbeil_df.rename(columns={'A1': 'org_A1', 'A2': 'org_A2'})

entrezid_to_symbol = dict(zip(id_map['entrez_id'], id_map['Approved symbol']))

klingbeil_df = klingbeil_df.assign(
    A1 = klingbeil_df['A1_entrez'].map(entrezid_to_symbol),
    A2 = klingbeil_df['A2_entrez'].map(entrezid_to_symbol))

klingbeil_df = klingbeil_df.dropna(subset=['A1_entrez', 'A2_entrez'], how='any').reset_index(drop=True)

# %% [markdown]
# ### Create Sorted Gene Pairs
#
# **Generate standardized gene pair identifiers:**

# %%
list_c = [[x, y] for x, y in zip(klingbeil_df.A1, klingbeil_df.A2)]
genepairs = ['_'.join(natsorted(pair)) for pair in list_c]
klingbeil_df.insert(2, 'sorted_genepair', genepairs, True)

# %%
klingbeil_df[:3]
# Out:
#                          GENE_COMBINATION           domain_combination  \
# 0  AAK1:Kinase_domain;BMP2K:Kinase_domain  Kinase_domain_Kinase_domain
# 1    AAK1:Kinase_domain;GAK:Kinase_domain  Kinase_domain_Kinase_domain
# 2  AATK:Kinase_domain;LMTK2:Kinase_domain  Kinase_domain_Kinase_domain
#
#   sorted_genepair org_A1 org_A2 cell_line    GEMINI       FDR       LFC  \
# 0      AAK1_BMP2K   AAK1  BMP2K      A549  0.149179  0.998805  0.662254
# 1        AAK1_GAK   AAK1    GAK      A549 -0.138258  0.999240 -0.442264
# 2      AATK_LMTK2   AATK  LMTK2      A549  0.135116  0.998805  0.231514
#
#    A1_entrez  A2_entrez    A1     A2
# 0    22848.0    55589.0  AAK1  BMP2K
# 1    22848.0     2580.0  AAK1    GAK
# 2     9625.0    22853.0  AATK  LMTK2

# %% [markdown]
# **Test specific gene pairs:**

# %%
klingbeil_df.loc[klingbeil_df['sorted_genepair'] == 'AKT1_AKT2', ]
# Out:
#                                         GENE_COMBINATION  \
# 140                AKT1:Kinase_domain;AKT2:Kinase_domain
# 150    AKT1:phosphatase_and_phosphat_signalling_domai...
# 2830               AKT1:Kinase_domain;AKT2:Kinase_domain
# 2840   AKT1:phosphatase_and_phosphat_signalling_domai...
# 5520               AKT1:Kinase_domain;AKT2:Kinase_domain
# 5530   AKT1:phosphatase_and_phosphat_signalling_domai...
# 8210               AKT1:Kinase_domain;AKT2:Kinase_domain
# 8220   AKT1:phosphatase_and_phosphat_signalling_domai...
# 10900              AKT1:Kinase_domain;AKT2:Kinase_domain
# 10910  AKT1:phosphatase_and_phosphat_signalling_domai...
# 13590              AKT1:Kinase_domain;AKT2:Kinase_domain
# 13600  AKT1:phosphatase_and_phosphat_signalling_domai...
# 16280              AKT1:Kinase_domain;AKT2:Kinase_domain
# 16290  AKT1:phosphatase_and_phosphat_signalling_domai...
# 18970              AKT1:Kinase_domain;AKT2:Kinase_domain
# 18980  AKT1:phosphatase_and_phosphat_signalling_domai...
# 21660              AKT1:Kinase_domain;AKT2:Kinase_domain
# 21670  AKT1:phosphatase_and_phosphat_signalling_domai...
# 24350              AKT1:Kinase_domain;AKT2:Kinase_domain
# 24360  AKT1:phosphatase_and_phosphat_signalling_domai...
# 27040              AKT1:Kinase_domain;AKT2:Kinase_domain
# 27050  AKT1:phosphatase_and_phosphat_signalling_domai...
# 29730              AKT1:Kinase_domain;AKT2:Kinase_domain
# 29740  AKT1:phosphatase_and_phosphat_signalling_domai...
# 32420              AKT1:Kinase_domain;AKT2:Kinase_domain
# 32430  AKT1:phosphatase_and_phosphat_signalling_domai...
# 35110              AKT1:Kinase_domain;AKT2:Kinase_domain
# 35120  AKT1:phosphatase_and_phosphat_signalling_domai...
# 37800              AKT1:Kinase_domain;AKT2:Kinase_domain
# 37810  AKT1:phosphatase_and_phosphat_signalling_domai...
# 40490              AKT1:Kinase_domain;AKT2:Kinase_domain
# 40500  AKT1:phosphatase_and_phosphat_signalling_domai...
# 43180              AKT1:Kinase_domain;AKT2:Kinase_domain
# 43190  AKT1:phosphatase_and_phosphat_signalling_domai...
# 45870              AKT1:Kinase_domain;AKT2:Kinase_domain
# 45880  AKT1:phosphatase_and_phosphat_signalling_domai...
# 48560              AKT1:Kinase_domain;AKT2:Kinase_domain
# 48570  AKT1:phosphatase_and_phosphat_signalling_domai...
# 51250              AKT1:Kinase_domain;AKT2:Kinase_domain
# 51260  AKT1:phosphatase_and_phosphat_signalling_domai...
# 53940              AKT1:Kinase_domain;AKT2:Kinase_domain
# 53950  AKT1:phosphatase_and_phosphat_signalling_domai...
# 56630              AKT1:Kinase_domain;AKT2:Kinase_domain
# 56640  AKT1:phosphatase_and_phosphat_signalling_domai...
#
#                                       domain_combination sorted_genepair  \
# 140                          Kinase_domain_Kinase_domain       AKT1_AKT2
# 150    phosphatase_and_phosphat_signalling_domain_pho...       AKT1_AKT2
# 2830                         Kinase_domain_Kinase_domain       AKT1_AKT2
# 2840   phosphatase_and_phosphat_signalling_domain_pho...       AKT1_AKT2
# 5520                         Kinase_domain_Kinase_domain       AKT1_AKT2
# 5530   phosphatase_and_phosphat_signalling_domain_pho...       AKT1_AKT2
# 8210                         Kinase_domain_Kinase_domain       AKT1_AKT2
# 8220   phosphatase_and_phosphat_signalling_domain_pho...       AKT1_AKT2
# 10900                        Kinase_domain_Kinase_domain       AKT1_AKT2
# 10910  phosphatase_and_phosphat_signalling_domain_pho...       AKT1_AKT2
# 13590                        Kinase_domain_Kinase_domain       AKT1_AKT2
# 13600  phosphatase_and_phosphat_signalling_domain_pho...       AKT1_AKT2
# 16280                        Kinase_domain_Kinase_domain       AKT1_AKT2
# 16290  phosphatase_and_phosphat_signalling_domain_pho...       AKT1_AKT2
# 18970                        Kinase_domain_Kinase_domain       AKT1_AKT2
# 18980  phosphatase_and_phosphat_signalling_domain_pho...       AKT1_AKT2
# 21660                        Kinase_domain_Kinase_domain       AKT1_AKT2
# 21670  phosphatase_and_phosphat_signalling_domain_pho...       AKT1_AKT2
# 24350                        Kinase_domain_Kinase_domain       AKT1_AKT2
# 24360  phosphatase_and_phosphat_signalling_domain_pho...       AKT1_AKT2
# 27040                        Kinase_domain_Kinase_domain       AKT1_AKT2
# 27050  phosphatase_and_phosphat_signalling_domain_pho...       AKT1_AKT2
# 29730                        Kinase_domain_Kinase_domain       AKT1_AKT2
# 29740  phosphatase_and_phosphat_signalling_domain_pho...       AKT1_AKT2
# 32420                        Kinase_domain_Kinase_domain       AKT1_AKT2
# 32430  phosphatase_and_phosphat_signalling_domain_pho...       AKT1_AKT2
# 35110                        Kinase_domain_Kinase_domain       AKT1_AKT2
# 35120  phosphatase_and_phosphat_signalling_domain_pho...       AKT1_AKT2
# 37800                        Kinase_domain_Kinase_domain       AKT1_AKT2
# 37810  phosphatase_and_phosphat_signalling_domain_pho...       AKT1_AKT2
# 40490                        Kinase_domain_Kinase_domain       AKT1_AKT2
# 40500  phosphatase_and_phosphat_signalling_domain_pho...       AKT1_AKT2
# 43180                        Kinase_domain_Kinase_domain       AKT1_AKT2
# 43190  phosphatase_and_phosphat_signalling_domain_pho...       AKT1_AKT2
# 45870                        Kinase_domain_Kinase_domain       AKT1_AKT2
# 45880  phosphatase_and_phosphat_signalling_domain_pho...       AKT1_AKT2
# 48560                        Kinase_domain_Kinase_domain       AKT1_AKT2
# 48570  phosphatase_and_phosphat_signalling_domain_pho...       AKT1_AKT2
# 51250                        Kinase_domain_Kinase_domain       AKT1_AKT2
# 51260  phosphatase_and_phosphat_signalling_domain_pho...       AKT1_AKT2
# 53940                        Kinase_domain_Kinase_domain       AKT1_AKT2
# 53950  phosphatase_and_phosphat_signalling_domain_pho...       AKT1_AKT2
# 56630                        Kinase_domain_Kinase_domain       AKT1_AKT2
# 56640  phosphatase_and_phosphat_signalling_domain_pho...       AKT1_AKT2
#
#       org_A1 org_A2 cell_line    GEMINI           FDR       LFC  A1_entrez  \
# 140     AKT1   AKT2      A549  1.002888  9.741756e-01 -1.301688      207.0
# 150     AKT1   AKT2      A549  0.797873  9.741756e-01 -0.963037      207.0
# 2830    AKT1   AKT2     ASPC1  3.431455  2.591273e-15 -3.806678      207.0
# 2840    AKT1   AKT2     ASPC1  2.621750  1.409003e-08 -2.620907      207.0
# 5520    AKT1   AKT2   CORL311 -0.626738  9.899218e-01 -0.418664      207.0
# 5530    AKT1   AKT2   CORL311 -0.748804  9.899218e-01 -0.022227      207.0
# 8210    AKT1   AKT2     H1048  2.613706  3.390035e-08 -3.675110      207.0
# 8220    AKT1   AKT2     H1048  1.934156  3.238647e-04 -2.308090      207.0
# 10900   AKT1   AKT2     H1299 -0.074551  9.987095e-01 -1.378366      207.0
# 10910   AKT1   AKT2     H1299  0.529044  9.741154e-01 -1.350943      207.0
# 13590   AKT1   AKT2     H1436  1.093292  2.383375e-01 -0.996176      207.0
# 13600   AKT1   AKT2     H1436  0.423533  8.980246e-01 -0.246226      207.0
# 16280   AKT1   AKT2     H1836  0.757589  2.045728e-01 -0.542554      207.0
# 16290   AKT1   AKT2     H1836  0.143101  9.604092e-01 -0.221153      207.0
# 18970   AKT1   AKT2      H209  0.274831  6.261587e-01 -0.683965      207.0
# 18980   AKT1   AKT2      H209  0.200029  7.061864e-01 -0.189176      207.0
# 21660   AKT1   AKT2      H211 -0.473232  9.515233e-01 -0.513238      207.0
# 21670   AKT1   AKT2      H211  0.347073  7.405457e-01 -0.358023      207.0
# 24350   AKT1   AKT2       HEL  0.288270  4.591891e-01 -0.050211      207.0
# 24360   AKT1   AKT2       HEL  0.068387  7.811913e-01 -0.003157      207.0
# 27040   AKT1   AKT2    HPAFII  3.289536  3.470557e-05 -3.115813      207.0
# 27050   AKT1   AKT2    HPAFII  1.848551  1.006155e-01 -1.875004      207.0
# 29730   AKT1   AKT2      K562  0.793897  3.460894e-02 -0.942174      207.0
# 29740   AKT1   AKT2      K562  0.535876  3.046984e-01 -0.660501      207.0
# 32420   AKT1   AKT2  MDAMB231  0.650442  9.504291e-01 -0.536148      207.0
# 32430   AKT1   AKT2  MDAMB231  0.162585  9.990426e-01 -0.298904      207.0
# 35110   AKT1   AKT2    MOLM13  0.926606  3.507070e-01 -1.510504      207.0
# 35120   AKT1   AKT2    MOLM13  0.730508  6.032596e-01 -1.134227      207.0
# 37800   AKT1   AKT2     NOMO1  1.392973  1.633139e-02 -1.255263      207.0
# 37810   AKT1   AKT2     NOMO1  1.111387  9.833163e-02 -0.998508      207.0
# 40490   AKT1   AKT2  PATU8902  3.319096  2.488958e-02 -3.862725      207.0
# 40500   AKT1   AKT2  PATU8902  2.555216  2.076477e-01 -2.671424      207.0
# 43180   AKT1   AKT2        RD  0.783456  8.946978e-01 -1.701723      207.0
# 43190   AKT1   AKT2        RD  0.720121  9.053244e-01 -0.698685      207.0
# 45870   AKT1   AKT2      RH30  0.446100  8.975543e-01 -0.973363      207.0
# 45880   AKT1   AKT2      RH30  0.038506  9.590074e-01 -0.162764      207.0
# 48560   AKT1   AKT2      SET2  1.215378  2.669743e-02 -1.055471      207.0
# 48570   AKT1   AKT2      SET2  0.940298  1.581222e-01 -0.809923      207.0
# 51250   AKT1   AKT2      T3M4  2.041708  5.072679e-10 -2.304390      207.0
# 51260   AKT1   AKT2      T3M4  1.482628  6.751971e-05 -1.537617      207.0
# 53940   AKT1   AKT2      THP1  1.781768  3.703339e-10 -2.791077      207.0
# 53950   AKT1   AKT2      THP1  1.618841  2.738119e-08 -2.003228      207.0
# 56630   AKT1   AKT2      YAPC  1.912639  3.861830e-01 -2.475821      207.0
# 56640   AKT1   AKT2      YAPC  1.297465  8.724227e-01 -1.514966      207.0
#
#        A2_entrez    A1    A2
# 140        208.0  AKT1  AKT2
# 150        208.0  AKT1  AKT2
# 2830       208.0  AKT1  AKT2
# 2840       208.0  AKT1  AKT2
# 5520       208.0  AKT1  AKT2
# 5530       208.0  AKT1  AKT2
# 8210       208.0  AKT1  AKT2
# 8220       208.0  AKT1  AKT2
# 10900      208.0  AKT1  AKT2
# 10910      208.0  AKT1  AKT2
# 13590      208.0  AKT1  AKT2
# 13600      208.0  AKT1  AKT2
# 16280      208.0  AKT1  AKT2
# 16290      208.0  AKT1  AKT2
# 18970      208.0  AKT1  AKT2
# 18980      208.0  AKT1  AKT2
# 21660      208.0  AKT1  AKT2
# 21670      208.0  AKT1  AKT2
# 24350      208.0  AKT1  AKT2
# 24360      208.0  AKT1  AKT2
# 27040      208.0  AKT1  AKT2
# 27050      208.0  AKT1  AKT2
# 29730      208.0  AKT1  AKT2
# 29740      208.0  AKT1  AKT2
# 32420      208.0  AKT1  AKT2
# 32430      208.0  AKT1  AKT2
# 35110      208.0  AKT1  AKT2
# 35120      208.0  AKT1  AKT2
# 37800      208.0  AKT1  AKT2
# 37810      208.0  AKT1  AKT2
# 40490      208.0  AKT1  AKT2
# 40500      208.0  AKT1  AKT2
# 43180      208.0  AKT1  AKT2
# 43190      208.0  AKT1  AKT2
# 45870      208.0  AKT1  AKT2
# 45880      208.0  AKT1  AKT2
# 48560      208.0  AKT1  AKT2
# 48570      208.0  AKT1  AKT2
# 51250      208.0  AKT1  AKT2
# 51260      208.0  AKT1  AKT2
# 53940      208.0  AKT1  AKT2
# 53950      208.0  AKT1  AKT2
# 56630      208.0  AKT1  AKT2
# 56640      208.0  AKT1  AKT2

# %%
klingbeil_df.loc[klingbeil_df['sorted_genepair'] == 'KMT2A_KMT2B', ]
# Out:
#                             GENE_COMBINATION         domain_combination  \
# 1556   KMT2A:BROMO_domain;KMT2B:BROMO_domain  BROMO_domain_BROMO_domain
# 1557     KMT2A:CXXC_domain;KMT2B:CXXC_domain    CXXC_domain_CXXC_domain
# 1559       KMT2A:PHD_domain;KMT2B:PHD_domain      PHD_domain_PHD_domain
# 4246   KMT2A:BROMO_domain;KMT2B:BROMO_domain  BROMO_domain_BROMO_domain
# 4247     KMT2A:CXXC_domain;KMT2B:CXXC_domain    CXXC_domain_CXXC_domain
# ...                                      ...                        ...
# 55357    KMT2A:CXXC_domain;KMT2B:CXXC_domain    CXXC_domain_CXXC_domain
# 55359      KMT2A:PHD_domain;KMT2B:PHD_domain      PHD_domain_PHD_domain
# 58046  KMT2A:BROMO_domain;KMT2B:BROMO_domain  BROMO_domain_BROMO_domain
# 58047    KMT2A:CXXC_domain;KMT2B:CXXC_domain    CXXC_domain_CXXC_domain
# 58049      KMT2A:PHD_domain;KMT2B:PHD_domain      PHD_domain_PHD_domain
#
#       sorted_genepair org_A1 org_A2 cell_line    GEMINI       FDR       LFC  \
# 1556      KMT2A_KMT2B  KMT2A  KMT2B      A549  1.470380  0.621634 -1.343546
# 1557      KMT2A_KMT2B  KMT2A  KMT2B      A549  1.763172  0.226488 -1.904824
# 1559      KMT2A_KMT2B  KMT2A  KMT2B      A549  1.314344  0.832033 -1.633927
# 4246      KMT2A_KMT2B  KMT2A  KMT2B     ASPC1  0.725337  0.564369 -1.575733
# 4247      KMT2A_KMT2B  KMT2A  KMT2B     ASPC1  0.804111  0.466182 -2.295248
# ...               ...    ...    ...       ...       ...       ...       ...
# 55357     KMT2A_KMT2B  KMT2A  KMT2B      THP1       NaN       NaN -3.077443
# 55359     KMT2A_KMT2B  KMT2A  KMT2B      THP1  0.379737  0.710570 -1.129063
# 58046     KMT2A_KMT2B  KMT2A  KMT2B      YAPC  0.833282  0.872423 -1.622147
# 58047     KMT2A_KMT2B  KMT2A  KMT2B      YAPC  1.517005  0.872423 -2.978127
# 58049     KMT2A_KMT2B  KMT2A  KMT2B      YAPC  1.755032  0.577348 -2.662205
#
#        A1_entrez  A2_entrez     A1     A2
# 1556      4297.0     9757.0  KMT2A  KMT2B
# 1557      4297.0     9757.0  KMT2A  KMT2B
# 1559      4297.0     9757.0  KMT2A  KMT2B
# 4246      4297.0     9757.0  KMT2A  KMT2B
# 4247      4297.0     9757.0  KMT2A  KMT2B
# ...          ...        ...    ...    ...
# 55357     4297.0     9757.0  KMT2A  KMT2B
# 55359     4297.0     9757.0  KMT2A  KMT2B
# 58046     4297.0     9757.0  KMT2A  KMT2B
# 58047     4297.0     9757.0  KMT2A  KMT2B
# 58049     4297.0     9757.0  KMT2A  KMT2B
#
# [66 rows x 13 columns]

# %% [markdown]
# ### Add Synthetic Lethality Labels
#
# **Define synthetic lethality based on FDR threshold:**

# %%
klingbeil_df.loc[klingbeil_df['FDR'].isna()]
# Out:
#                                         GENE_COMBINATION  \
# 51     ACAP3:phosphatase_and_phosphat_signalling_doma...
# 97     AGAP1:phosphatase_and_phosphat_signalling_doma...
# 103    AGAP11:phosphatase_and_phosphat_signalling_dom...
# 108    AGAP2:phosphatase_and_phosphat_signalling_doma...
# 112    AGAP3:phosphatase_and_phosphat_signalling_doma...
# ...                                                  ...
# 59165              WNK1:Kinase_domain;WNK2:Kinase_domain
# 59166              WNK1:Kinase_domain;WNK3:Kinase_domain
# 59167              WNK1:Kinase_domain;WNK4:Kinase_domain
# 59171            YEATS2:YEATS_domain;YEATS4:YEATS_domain
# 59179             ZMYND11:PWWP_domain;ZMYND8:PWWP_domain
#
#                                       domain_combination sorted_genepair  \
# 51     phosphatase_and_phosphat_signalling_domain_pho...     ACAP3_AGAP5
# 97     phosphatase_and_phosphat_signalling_domain_pho...     AGAP1_AGAP5
# 103    phosphatase_and_phosphat_signalling_domain_pho...    AGAP5_AGAP11
# 108    phosphatase_and_phosphat_signalling_domain_pho...     AGAP2_AGAP5
# 112    phosphatase_and_phosphat_signalling_domain_pho...     AGAP3_AGAP5
# ...                                                  ...             ...
# 59165                        Kinase_domain_Kinase_domain       WNK1_WNK2
# 59166                        Kinase_domain_Kinase_domain       WNK1_WNK3
# 59167                        Kinase_domain_Kinase_domain       WNK1_WNK4
# 59171                          YEATS_domain_YEATS_domain   YEATS2_YEATS4
# 59179                            PWWP_domain_PWWP_domain  ZMYND8_ZMYND11
#
#         org_A1  org_A2 cell_line  GEMINI  FDR       LFC  A1_entrez  A2_entrez  \
# 51       ACAP3   AGAP5      A549     NaN  NaN -3.874116   116983.0   729092.0
# 97       AGAP1   AGAP5      A549     NaN  NaN -3.481294   116987.0   729092.0
# 103     AGAP11   AGAP5      A549     NaN  NaN -3.299841   119385.0   729092.0
# 108      AGAP2   AGAP5      A549     NaN  NaN -3.850253   116986.0   729092.0
# 112      AGAP3   AGAP5      A549     NaN  NaN -3.451532   116988.0   729092.0
# ...        ...     ...       ...     ...  ...       ...        ...        ...
# 59165     WNK1    WNK2      YAPC     NaN  NaN -5.383580    65125.0    65268.0
# 59166     WNK1    WNK3      YAPC     NaN  NaN -3.895242    65125.0    65267.0
# 59167     WNK1    WNK4      YAPC     NaN  NaN -5.139171    65125.0    65266.0
# 59171   YEATS2  YEATS4      YAPC     NaN  NaN -4.083892    55689.0     8089.0
# 59179  ZMYND11  ZMYND8      YAPC     NaN  NaN -2.188485    10771.0    23613.0
#
#             A1      A2
# 51       ACAP3   AGAP5
# 97       AGAP1   AGAP5
# 103     AGAP11   AGAP5
# 108      AGAP2   AGAP5
# 112      AGAP3   AGAP5
# ...        ...     ...
# 59165     WNK1    WNK2
# 59166     WNK1    WNK3
# 59167     WNK1    WNK4
# 59171   YEATS2  YEATS4
# 59179  ZMYND11  ZMYND8
#
# [3431 rows x 13 columns]

# %%
SL_condition = (klingbeil_df['FDR'] < 0.05)
klingbeil_df['SL'] = SL_condition

# %%
klingbeil_df['SL'].value_counts()
# Out:
# SL
# False    58277
# True       903
# Name: count, dtype: int64

# %%
# Function to sort each pair of gene symbols and their Entrez IDs
def sort_gene_pairs(row):
    # Sort the genes alphabetically and determine new order
    sorted_genes = natsorted([row['A1'], row['A2']])
    
    # Match the sorted genes to the original ones and rearrange Entrez IDs accordingly
    if sorted_genes[0] == row['A1']:
        return pd.Series([sorted_genes[0], sorted_genes[1], row['A1_entrez'], row['A2_entrez']])
    else:
        return pd.Series([sorted_genes[0], sorted_genes[1], row['A2_entrez'], row['A1_entrez']])

# Apply the sorting to each row
df = klingbeil_df.copy()
df[['A1_sorted', 'A2_sorted', 'A1_entrez_sorted', 'A2_entrez_sorted']] = df.apply(sort_gene_pairs, axis=1)

# Drop the old columns and rename the new ones
klingbeil_df_labelled = df.drop(columns=['A1', 'A2', 'A1_entrez', 'A2_entrez']).copy()
klingbeil_df_labelled = klingbeil_df_labelled.rename(columns={
    'A1_sorted': 'A1',
    'A2_sorted': 'A2',
    'A1_entrez_sorted': 'A1_entrez',
    'A2_entrez_sorted': 'A2_entrez'
})

# %%
#test pair
klingbeil_df_labelled.loc[klingbeil_df_labelled['sorted_genepair'] == 'ZMYND8_ZMYND11']
# Out:
#                                GENE_COMBINATION         domain_combination  \
# 2686       ZMYND11:ADD_domain;ZMYND8:ADD_domain      ADD_domain_ADD_domain
# 2687   ZMYND11:BROMO_domain;ZMYND8:BROMO_domain  BROMO_domain_BROMO_domain
# 2688       ZMYND11:PHD_domain;ZMYND8:PHD_domain      PHD_domain_PHD_domain
# 2689     ZMYND11:PWWP_domain;ZMYND8:PWWP_domain    PWWP_domain_PWWP_domain
# 5376       ZMYND11:ADD_domain;ZMYND8:ADD_domain      ADD_domain_ADD_domain
# ...                                         ...                        ...
# 56489    ZMYND11:PWWP_domain;ZMYND8:PWWP_domain    PWWP_domain_PWWP_domain
# 59176      ZMYND11:ADD_domain;ZMYND8:ADD_domain      ADD_domain_ADD_domain
# 59177  ZMYND11:BROMO_domain;ZMYND8:BROMO_domain  BROMO_domain_BROMO_domain
# 59178      ZMYND11:PHD_domain;ZMYND8:PHD_domain      PHD_domain_PHD_domain
# 59179    ZMYND11:PWWP_domain;ZMYND8:PWWP_domain    PWWP_domain_PWWP_domain
#
#       sorted_genepair   org_A1  org_A2 cell_line    GEMINI       FDR  \
# 2686   ZMYND8_ZMYND11  ZMYND11  ZMYND8      A549  0.097400  0.998805
# 2687   ZMYND8_ZMYND11  ZMYND11  ZMYND8      A549  0.260723  0.988616
# 2688   ZMYND8_ZMYND11  ZMYND11  ZMYND8      A549 -0.334091  0.999240
# 2689   ZMYND8_ZMYND11  ZMYND11  ZMYND8      A549 -0.245971  0.999240
# 5376   ZMYND8_ZMYND11  ZMYND11  ZMYND8     ASPC1  0.771619  0.505559
# ...               ...      ...     ...       ...       ...       ...
# 56489  ZMYND8_ZMYND11  ZMYND11  ZMYND8      THP1 -0.104612  1.000000
# 59176  ZMYND8_ZMYND11  ZMYND11  ZMYND8      YAPC -0.478275  1.000000
# 59177  ZMYND8_ZMYND11  ZMYND11  ZMYND8      YAPC -0.279498  1.000000
# 59178  ZMYND8_ZMYND11  ZMYND11  ZMYND8      YAPC  0.012366  0.989382
# 59179  ZMYND8_ZMYND11  ZMYND11  ZMYND8      YAPC       NaN       NaN
#
#             LFC     SL      A1       A2  A1_entrez  A2_entrez
# 2686  -0.200981  False  ZMYND8  ZMYND11    23613.0    10771.0
# 2687  -0.167358  False  ZMYND8  ZMYND11    23613.0    10771.0
# 2688  -0.132602  False  ZMYND8  ZMYND11    23613.0    10771.0
# 2689  -0.212266  False  ZMYND8  ZMYND11    23613.0    10771.0
# 5376  -1.179333  False  ZMYND8  ZMYND11    23613.0    10771.0
# ...         ...    ...     ...      ...        ...        ...
# 56489 -1.954398  False  ZMYND8  ZMYND11    23613.0    10771.0
# 59176 -1.460720  False  ZMYND8  ZMYND11    23613.0    10771.0
# 59177 -1.920873  False  ZMYND8  ZMYND11    23613.0    10771.0
# 59178 -1.866205  False  ZMYND8  ZMYND11    23613.0    10771.0
# 59179 -2.188485  False  ZMYND8  ZMYND11    23613.0    10771.0
#
# [88 rows x 14 columns]

# %% [markdown]
# ### Add Cell Line Mapping
#
# **Map cell line names to DepMap IDs:**

# %%
sample_info = pd.read_csv(file_path_sample_info)
sample_info[:2]
# Out:
#     DepMap_ID cell_line_name stripped_cell_line_name  \
# 0  ACH-000001    NIH:OVCAR-3               NIHOVCAR3
# 1  ACH-000002          HL-60                    HL60
#
#                                  CCLE_Name   alias  COSMICID     sex source  \
# 0                          NIHOVCAR3_OVARY  OVCAR3  905933.0  Female   ATCC
# 1  HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     NaN  905938.0  Female   ATCC
#
#         RRID  WTSI_Master_Cell_ID  ... primary_disease  \
# 0  CVCL_0465               2201.0  ...  Ovarian Cancer
# 1  CVCL_0002                 55.0  ...        Leukemia
#
#                                              Subtype   age Sanger_Model_ID  \
# 0                  Adenocarcinoma, high grade serous  60.0       SIDM00105
# 1  Acute Myelogenous Leukemia (AML), M3 (Promyelo...  35.0       SIDM00829
#
#    depmap_public_comments lineage       lineage_subtype lineage_sub_subtype  \
# 0                     NaN   ovary  ovary_adenocarcinoma   high_grade_serous
# 1                     NaN   blood                   AML                  M3
#
#   lineage_molecular_subtype culture_type
# 0                       NaN     Adherent
# 1                       NaN   Suspension
#
# [2 rows x 22 columns]

# %%
CCLE_name_to_DepMapID = dict(zip(sample_info.stripped_cell_line_name, sample_info.DepMap_ID))

# update dictionary with renamed values
CCLE_name_to_DepMapID.update({'H1048': 'ACH-000866', 
                              'H1299': 'ACH-000510',
                              'H1436':'ACH-000830',
                              'H1836':'ACH-000559',
                              'H209':'ACH-000290',
                              'H211':'ACH-000639'
                              })

# %%
klingbeil_df_labelled.insert(5, "DepMap_ID", klingbeil_df_labelled["cell_line"].map(CCLE_name_to_DepMapID))

# %%
klingbeil_df_labelled = klingbeil_df_labelled[['GENE_COMBINATION', 'domain_combination', 'sorted_genepair', 'A1', 'A2', 'A1_entrez', 'A2_entrez', 'cell_line', 'DepMap_ID', 
                                               'GEMINI', 'LFC', 'FDR', 'SL', 'org_A1', 'org_A2']].copy()
klingbeil_df_labelled = klingbeil_df_labelled.rename(columns={'sorted_genepair':'genepair'})
klingbeil_df_labelled = klingbeil_df_labelled.sort_values(by=['GENE_COMBINATION', 'domain_combination', 'genepair', 'cell_line']).reset_index(drop=True)

# %%
print(klingbeil_df_labelled.loc[klingbeil_df_labelled['genepair'] == 'AKT1_AKT2', ['domain_combination']].value_counts())
print(klingbeil_df_labelled.loc[klingbeil_df_labelled['genepair'] == 'AKT1_AKT2'].shape[0])
# Out:
# domain_combination
# Kinase_domain_Kinase_domain                                                              22
# phosphatase_and_phosphat_signalling_domain_phosphatase_and_phosphat_signalling_domain    22
# Name: count, dtype: int64
# 44

# %%
klingbeil_df_labelled.isna().sum()
# Out:
# GENE_COMBINATION         0
# domain_combination       0
# genepair                 0
# A1                       0
# A2                       0
# A1_entrez                0
# A2_entrez                0
# cell_line                0
# DepMap_ID                0
# GEMINI                3431
# LFC                      0
# FDR                   3431
# SL                       0
# org_A1                   0
# org_A2                   0
# dtype: int64

# %% [markdown]
# ### Save Processed Data
#
# **Export the final processed dataset:**

# %%
klingbeil_df_labelled.to_csv(file_path_processed_klingbeil_df, index=False)
