# %%
# import modules
import os
import pandas as pd
import numpy as np
import pyarrow.parquet as pq
from natsort import natsorted

# %%
# save pathnames to gemini files in a list
folder = '/Users/narod/Documents/GitHub/context_specific_SL_prediction/input_files/GEMINI'

gemini_files = list()

for file in os.listdir(folder):
    if file.endswith('.csv'):
        file_directory = os.path.join(folder, file)
        gemini_files.append(file_directory)
    else:
        continue

sorted_gemini_files = sorted(gemini_files)

# %%
# save pathnames to lfc_files in a list
folder = '/Users/narod/Documents/GitHub/context_specific_SL_prediction/input_files/lfc'

lfc_files = list()

for file in os.listdir(folder):
    if file.endswith('.csv'):
        file_directory = os.path.join(folder, file)
        lfc_files.append(file_directory)
    else:
        continue

sorted_lfc_files = sorted(lfc_files)

# %% [markdown]
# ##### Processing GEMINI scores of the datasets

# %%
# read GEMINI scores for Ito Screen
gemini_ito = pd.read_csv(sorted_gemini_files[3])

gemini_ito_df = gemini_ito.rename(columns={'Unnamed: 0':'genepair',
                                'Meljuso':'ACH-000881', 
                                'GI1_004':'ACH-000756',
                                'MEL202_003':'ACH-001554',
                                'PK1':'ACH-000307',
                                'MEWO':'ACH-000987',
                                'HS944T':'ACH-000632',
                                'IPC298':'ACH-000915',
                                'A549':'ACH-000681',
                                'HSC5':'ACH-001524',
                                'HS936T':'ACH-000801',
                                'PATU8988S':'ACH-000022'})
gemini_ito_df['genepair'] = gemini_ito_df['genepair'].apply(lambda x: x.replace(';', '_'))
gemini_ito_df = pd.melt(gemini_ito_df, id_vars=['genepair'], var_name='DepMap_ID', value_name='GEMINI').sort_values(by='genepair').reset_index(drop=True)
gemini_ito_df.head()
# Out:
#       genepair   DepMap_ID    GEMINI
# 0  A3GALT2_ABO  ACH-000881 -0.137329
# 1  A3GALT2_ABO  ACH-000307  0.132501
# 2  A3GALT2_ABO  ACH-000915  0.083927
# 3  A3GALT2_ABO  ACH-001554 -0.077458
# 4  A3GALT2_ABO  ACH-001524  0.218901

# %%
gemini_ito_df.genepair.nunique()
# Out:
# 5065

# %%
# read GEMINI socres for Parrish Screen
gemini_hela = pd.read_csv(sorted_gemini_files[6])
gemini_pc9 = pd.read_csv(sorted_gemini_files[7])

print(gemini_hela.shape[0], gemini_pc9.shape[0])
gemini_parrish = pd.merge(gemini_hela, gemini_pc9, how='left')
gemini_parrish_df = gemini_parrish.rename(columns={'Unnamed: 0': 'genepair',
                                                   'HeLa_LTP':'ACH-001086',
                                                   'PC9_LTP':'ACH-000779'})
gemini_parrish_df['genepair'] = gemini_parrish_df['genepair'].apply(lambda x: x.replace(':', '_'))
gemini_parrish_df = pd.melt(gemini_parrish_df, id_vars=['genepair'], var_name='DepMap_ID', value_name='GEMINI').sort_values(by='genepair').reset_index(drop=True)
gemini_parrish_df[:3]
# Out:
# 1030 1030
#           genepair   DepMap_ID    GEMINI
# 0          A2M_PZP  ACH-000779 -0.249934
# 1          A2M_PZP  ACH-001086 -0.038689
# 2  AADACL3_AADACL4  ACH-001086 -0.252247

# %%
# check the genepair naming
display(gemini_parrish_df.loc[gemini_parrish_df['genepair'] == 'ARHGAP35_ARHGAP5'])
# Out:
#              genepair   DepMap_ID    GEMINI
# 128  ARHGAP35_ARHGAP5  ACH-001086 -0.168143
# 129  ARHGAP35_ARHGAP5  ACH-000779 -0.039776

# %% [markdown]
# #### Processing LFC of the datasets

# %%
# Read LFC for Chymera Screen
lfc_chymera = pd.read_csv(sorted_lfc_files[0], index_col=0)
lfc_chymera[:3]
# Out:
#         gene_pair  HAP1.Torin.T12  HAP1.Torin.T18  HAP1.T12  HAP1.T18  \
# 1  ABHD12_ABHD12B        0.061818        0.131736  0.174883  0.216066
# 2       ABL1_ABL2       -0.064491       -0.075265  0.136001  0.157626
# 3     ACBD3_TMED8        0.145367        0.240747  0.305939  0.353277
#
#    RPE1.T18  RPE1.T24
# 1  0.049935  0.128769
# 2  0.272344  0.445456
# 3  0.091730  0.203648

# %%
# read GEMINI scores for Ito Screen
lfc_ito = pd.read_csv(sorted_lfc_files[2], index_col=0)

lfc_ito_df = lfc_ito.rename(columns={'gene_pair':'genepair',
                                'Meljuso':'ACH-000881', 
                                'GI1_004':'ACH-000756',
                                'MEL202_003':'ACH-001554',
                                'PK1':'ACH-000307',
                                'MEWO':'ACH-000987',
                                'HS944T':'ACH-000632',
                                'IPC298':'ACH-000915',
                                'A549':'ACH-000681',
                                'HSC5':'ACH-001524',
                                'HS936T':'ACH-000801',
                                'PATU8988S':'ACH-000022'})

lfc_ito_df = pd.melt(lfc_ito_df, id_vars=['genepair'], var_name='DepMap_ID', value_name='LFC').sort_values(by='genepair').reset_index(drop=True)
lfc_ito_df[:3]
# Out:
#         genepair   DepMap_ID       LFC
# 0  A3GALT2_AAVS1  ACH-000881  0.343378
# 1  A3GALT2_AAVS1  ACH-000681  0.166162
# 2  A3GALT2_AAVS1  ACH-000987  0.216834

# %%
# read GEMINI socres for Parrish Screen
lfc_parrish = pd.read_csv(sorted_lfc_files[3], index_col=0)

lfc_parrish_df = lfc_parrish.rename(columns={'gene_pair':'genepair',
                                            'HeLa_LTP':'ACH-001086',
                                            'PC9_LTP':'ACH-000779'})

lfc_parrish_df = pd.melt(lfc_parrish_df, id_vars=['genepair'], var_name='DepMap_ID', value_name='LFC').sort_values(by='genepair').reset_index(drop=True)
lfc_parrish_df[:3]
# Out:
#           genepair   DepMap_ID       LFC
# 0          A2M_PZP  ACH-000779  0.333503
# 1          A2M_PZP  ACH-001086 -0.115678
# 2  AADACL3_AADACL4  ACH-000779 -0.106713

# %%
# check the genepair naming
display(lfc_parrish_df.loc[lfc_parrish_df['genepair'] == 'ARHGAP35_ARHGAP5'])
# Out:
#              genepair   DepMap_ID       LFC
# 128  ARHGAP35_ARHGAP5  ACH-001086 -0.071899
# 129  ARHGAP35_ARHGAP5  ACH-000779 -0.061434

# %%
#chymera_df = pd.merge(gemini_chymera_df, lfc_chymera_df, on=['genepair', 'DepMap_ID'], how='left')
#dede_df = pd.merge(gemini_dede_df, lfc_dede_df, on=['genepair', 'DepMap_ID'], how='left')
ito_df = pd.merge(gemini_ito_df, lfc_ito_df, on=['genepair', 'DepMap_ID'], how='left')
#parrish_df = pd.merge(gemini_parrish_df, lfc_parrish_df, on=['genepair', 'DepMap_ID'], how='left')
#thompson_df = pd.merge(gemini_thompson_df, lfc_thompson_df, on=['genepair', 'DepMap_ID'], how='left')

# %%
# check the genepair naming
#display(parrish_df.loc[parrish_df['genepair'] == 'ARHGAP35_ARHGAP5'])
#display(thompson_df.loc[thompson_df['genepair'] == 'ADSS_ADSSL1'])
# Out:
#              genepair   DepMap_ID    GEMINI       LFC
# 128  ARHGAP35_ARHGAP5  ACH-001086 -0.168143 -0.071899
# 129  ARHGAP35_ARHGAP5  ACH-000779 -0.039776 -0.061434

# %%
# read the genenames table for mapping
id_map_raw = pd.read_table("/Users/narod/Documents/GitHub/context_specific_SL_prediction/input_files/genenames.txt", dtype = "str")

id_map = id_map_raw[['HGNC ID', 'Approved symbol', 'NCBI Gene ID', 'NCBI Gene ID(supplied by NCBI)', 'Ensembl gene ID', 'Ensembl ID(supplied by Ensembl)', 'Previous symbols']]

# Define a function to process the previous symbols column
def process_value(value):
    if isinstance(value, str) and value != 'NA':
        if ',' in value:
            return value.split(',')
    return value
    
id_map.loc[:,'Previous symbols'] = id_map['Previous symbols'].apply(process_value)
id_map = id_map.explode('Previous symbols')
id_map['Previous symbols'] = id_map['Previous symbols'].str.strip()
id_map = id_map.reset_index(drop = True)

id_map = id_map.copy()
id_map['entrez_id'] = id_map['NCBI Gene ID(supplied by NCBI)'].combine_first(id_map['NCBI Gene ID'])
id_map['ensembl_id'] = id_map['Ensembl ID(supplied by Ensembl)'].combine_first(id_map['Ensembl gene ID'])

id_map.head()
# Out:
#       HGNC ID Approved symbol NCBI Gene ID NCBI Gene ID(supplied by NCBI)  \
# 0      HGNC:5            A1BG            1                              1
# 1  HGNC:37133        A1BG-AS1       503538                         503538
# 2  HGNC:37133        A1BG-AS1       503538                         503538
# 3  HGNC:37133        A1BG-AS1       503538                         503538
# 4  HGNC:24086            A1CF        29974                          29974
#
#    Ensembl gene ID Ensembl ID(supplied by Ensembl) Previous symbols entrez_id  \
# 0  ENSG00000121410                 ENSG00000121410              NaN         1
# 1  ENSG00000268895                 ENSG00000268895       NCRNA00181    503538
# 2  ENSG00000268895                 ENSG00000268895           A1BGAS    503538
# 3  ENSG00000268895                 ENSG00000268895          A1BG-AS    503538
# 4  ENSG00000148584                 ENSG00000148584              NaN     29974
#
#         ensembl_id
# 0  ENSG00000121410
# 1  ENSG00000268895
# 2  ENSG00000268895
# 3  ENSG00000268895
# 4  ENSG00000148584

# %%
""" def process_gene_symbols(gemini_df, id_map):
    # Split gene pairs into two columns
    gemini_df.insert(1, "A1", gemini_df['genepair'].apply(lambda x: x.split("_", 1)[0]))
    gemini_df.insert(2, "A2", gemini_df['genepair'].apply(lambda x: x.split("_", 1)[1]))

    # Build dictionary for mapping Approved symbols to NCBI Gene IDs
    id_map_approved = id_map.dropna(subset=['Approved symbol', 'NCBI Gene ID(supplied by NCBI)'], how='any').reset_index(drop=True)
    symbol_to_entrezid = dict(zip(id_map_approved['Approved symbol'], id_map_approved['NCBI Gene ID(supplied by NCBI)']))

    # Assign mapped NCBI Gene IDs to A1 and A2
    gemini_df = gemini_df.assign(
        A1_entrez = gemini_df['A1'].map(symbol_to_entrezid),
        A2_entrez = gemini_df['A2'].map(symbol_to_entrezid))

    # Map previous symbols to NCBI Gene IDs if the approved symbol mapping resulted in NA values
    id_map_previous = id_map.dropna(subset=['Previous symbols', 'NCBI Gene ID(supplied by NCBI)'], how='any').reset_index(drop=True)
    prev_sym_to_entrez_id = dict(zip(id_map_previous['Previous symbols'], id_map_previous['NCBI Gene ID(supplied by NCBI)']))

    gemini_df['A1_entrez'] = gemini_df['A1_entrez'].fillna(gemini_df['A1'].map(prev_sym_to_entrez_id))
    gemini_df['A2_entrez'] = gemini_df['A2_entrez'].fillna(gemini_df['A2'].map(prev_sym_to_entrez_id))

    # Drop rows with unresolved NCBI Gene IDs
    gemini_df = gemini_df.dropna(subset=['A1_entrez', 'A2_entrez'], how='any').reset_index(drop=True)
    gemini_df = gemini_df.drop('genepair', axis=1)

    # Dynamically determine value_vars: all columns except for the specified id_vars
    id_vars = ['A1', 'A2', 'A1_entrez', 'A2_entrez']
    value_vars = [col for col in gemini_df.columns if col not in id_vars]

    # Melt the DataFrame using dynamic value_vars
    gemini_df_melt = pd.melt(gemini_df, id_vars=id_vars,
                             value_vars=value_vars,
                             var_name='DepMap_ID', value_name='GEMINI_score')
    
    # Continue with renaming, remapping, and natural sorting as previously described
    gemini_df_melt.rename(columns={'A1': 'org_A1', 'A2': 'org_A2'}, inplace=True)
    id_map_approved = id_map.dropna(subset=['Approved symbol', 'NCBI Gene ID(supplied by NCBI)'], how='any').reset_index(drop=True)
    entrezid_to_symbol = dict(zip(id_map_approved['NCBI Gene ID(supplied by NCBI)'], id_map_approved['Approved symbol']))

    gemini_df_melt.insert(1, 'A1', gemini_df_melt['A1_entrez'].map(entrezid_to_symbol))
    gemini_df_melt.insert(2, 'A2', gemini_df_melt['A2_entrez'].map(entrezid_to_symbol))

    list_c = [[x, y] for x, y in zip(gemini_df_melt.A1, gemini_df_melt.A2)]
    genepairs = ['_'.join(natsorted(pair)) for pair in list_c]
    gemini_df_melt.insert(0, 'genepair', genepairs, True)

    gemini_df_melt = gemini_df_melt[['genepair', 'A1', 'A2', 'A1_entrez', 'A2_entrez', 'DepMap_ID', 'GEMINI_score', 'org_A1', 'org_A2']]
    return gemini_df_melt """

# %%
def process_gene_symbols(gemini_df, id_map):
    # Split gene pairs into two columns
    gemini_df.insert(1, "A1", gemini_df['genepair'].apply(lambda x: x.split("_", 1)[0]))
    gemini_df.insert(2, "A2", gemini_df['genepair'].apply(lambda x: x.split("_", 1)[1]))

    # Build dictionary for mapping Approved symbols to NCBI Gene IDs
    id_map_approved = id_map.dropna(subset=['Approved symbol', 'entrez_id'], how='any').reset_index(drop=True)
    symbol_to_entrezid = dict(zip(id_map_approved['Approved symbol'], id_map_approved['entrez_id']))

    # Assign mapped NCBI Gene IDs to A1 and A2
    gemini_df = gemini_df.assign(
        A1_entrez = gemini_df['A1'].map(symbol_to_entrezid),
        A2_entrez = gemini_df['A2'].map(symbol_to_entrezid))

    # Map previous symbols to NCBI Gene IDs if the approved symbol mapping resulted in NA values
    id_map_previous = id_map.dropna(subset=['Previous symbols', 'entrez_id'], how='any').reset_index(drop=True)
    prev_sym_to_entrez_id = dict(zip(id_map_previous['Previous symbols'], id_map_previous['entrez_id']))

    gemini_df['A1_entrez'] = gemini_df['A1_entrez'].fillna(gemini_df['A1'].map(prev_sym_to_entrez_id))
    gemini_df['A2_entrez'] = gemini_df['A2_entrez'].fillna(gemini_df['A2'].map(prev_sym_to_entrez_id))

    # Drop rows with unresolved NCBI Gene IDs
    gemini_df = gemini_df.dropna(subset=['A1_entrez', 'A2_entrez'], how='any').reset_index(drop=True)
    gemini_df = gemini_df.drop('genepair', axis=1)

    gemini_df.rename(columns={'A1': 'org_A1', 'A2': 'org_A2'}, inplace=True)
    id_map_approved = id_map.dropna(subset=['Approved symbol', 'entrez_id'], how='any').reset_index(drop=True)
    entrezid_to_symbol = dict(zip(id_map_approved['entrez_id'], id_map_approved['Approved symbol']))

    gemini_df.insert(1, 'A1', gemini_df['A1_entrez'].map(entrezid_to_symbol))
    gemini_df.insert(2, 'A2', gemini_df['A2_entrez'].map(entrezid_to_symbol))

    list_c = [[x, y] for x, y in zip(gemini_df.A1, gemini_df.A2)]
    genepairs = ['_'.join(natsorted(pair)) for pair in list_c]
    gemini_df.insert(0, 'genepair', genepairs, True)

    gemini_df = gemini_df[['genepair', 'A1', 'A2', 'A1_entrez', 'A2_entrez', 'DepMap_ID', 'GEMINI', 'LFC', 'org_A1', 'org_A2']]
    return gemini_df

# %%
gemini_ito_df_melt = process_gene_symbols(ito_df, id_map).sort_values(by='genepair').reset_index(drop=True)
#gemini_dede_df_melt = process_gene_symbols(dede_df, id_map).sort_values(by='genepair').reset_index(drop=True)
#gemini_parrish_df_melt = process_gene_symbols(parrish_df, id_map).sort_values(by='genepair').reset_index(drop=True)
#gemini_chymera_df_melt = process_gene_symbols(chymera_df, id_map).sort_values(by='genepair').reset_index(drop=True)
#gemini_thompson_df_melt = process_gene_symbols(thompson_df, id_map).sort_values(by='genepair').reset_index(drop=True)

# %%
# check the genepair naming
#display(gemini_thompson_df_melt.loc[gemini_thompson_df_melt['genepair'] == 'ADSS1_ADSS2'])
#display(gemini_parrish_df_melt.loc[gemini_parrish_df_melt['genepair'] == 'ARHGAP5_ARHGAP35'])
# Out:
#              genepair        A1       A2 A1_entrez A2_entrez   DepMap_ID  \
# 128  ARHGAP5_ARHGAP35  ARHGAP35  ARHGAP5      2909       394  ACH-001086
# 129  ARHGAP5_ARHGAP35  ARHGAP35  ARHGAP5      2909       394  ACH-000779
#
#        GEMINI       LFC    org_A1   org_A2
# 128 -0.168143 -0.071899  ARHGAP35  ARHGAP5
# 129 -0.039776 -0.061434  ARHGAP35  ARHGAP5

# %%
# Function to sort each pair of gene symbols and their Entrez IDs
def sort_gene_pairs(row):
    # Sort the genes alphabetically and determine new order
    sorted_genes = natsorted([row['A1'], row['A2']])
    
    # Match the sorted genes to the original ones and rearrange Entrez IDs accordingly
    if sorted_genes[0] == row['A1']:
        return pd.Series([sorted_genes[0], sorted_genes[1], row['A1_entrez'], row['A2_entrez']])
    else:
        return pd.Series([sorted_genes[0], sorted_genes[1], row['A2_entrez'], row['A1_entrez']])

# %%
# Define the function to process the DataFrame
def process_dataframe(df):
    # Apply the sorting to each row
    df[['A1_sorted', 'A2_sorted', 'A1_entrez_sorted', 'A2_entrez_sorted']] = df.apply(sort_gene_pairs, axis=1)
    
    # Drop the old columns and rename the new ones
    df = df.drop(columns=['A1', 'A2', 'A1_entrez', 'A2_entrez']).copy()
    df = df.rename(columns={
        'A1_sorted': 'A1',
        'A2_sorted': 'A2',
        'A1_entrez_sorted': 'A1_entrez',
        'A2_entrez_sorted': 'A2_entrez'
    })
    
    return df

# %%
gemini_ito_df = process_dataframe(gemini_ito_df_melt)
#gemini_parrish_df = process_dataframe(gemini_parrish_df_melt)

# %%
#display(gemini_parrish_df.loc[gemini_parrish_df['genepair'] == 'ARHGAP5_ARHGAP35'])
display(gemini_ito_df.loc[gemini_ito_df['genepair'] == 'ADAM8_ADAM12'])
# Out:
#           genepair   DepMap_ID    GEMINI       LFC  org_A1 org_A2     A1  \
# 1661  ADAM8_ADAM12  ACH-000801  0.542718 -0.401475  ADAM12  ADAM8  ADAM8
# 1662  ADAM8_ADAM12  ACH-000881  0.138926 -0.043630  ADAM12  ADAM8  ADAM8
# 1663  ADAM8_ADAM12  ACH-001554  0.222868 -0.064732  ADAM12  ADAM8  ADAM8
# 1664  ADAM8_ADAM12  ACH-001524  0.372903 -0.209467  ADAM12  ADAM8  ADAM8
# 1665  ADAM8_ADAM12  ACH-000681  0.482500 -0.513740  ADAM12  ADAM8  ADAM8
# 1666  ADAM8_ADAM12  ACH-000632  0.298943 -0.170243  ADAM12  ADAM8  ADAM8
# 1667  ADAM8_ADAM12  ACH-000987  0.189274 -0.063444  ADAM12  ADAM8  ADAM8
# 1668  ADAM8_ADAM12  ACH-000756  0.041007  0.049023  ADAM12  ADAM8  ADAM8
# 1669  ADAM8_ADAM12  ACH-000915  0.133910  0.010868  ADAM12  ADAM8  ADAM8
# 1670  ADAM8_ADAM12  ACH-000307  0.079471 -0.104993  ADAM12  ADAM8  ADAM8
# 1671  ADAM8_ADAM12  ACH-000022  0.252727 -0.114212  ADAM12  ADAM8  ADAM8
#
#           A2 A1_entrez A2_entrez
# 1661  ADAM12       101      8038
# 1662  ADAM12       101      8038
# 1663  ADAM12       101      8038
# 1664  ADAM12       101      8038
# 1665  ADAM12       101      8038
# 1666  ADAM12       101      8038
# 1667  ADAM12       101      8038
# 1668  ADAM12       101      8038
# 1669  ADAM12       101      8038
# 1670  ADAM12       101      8038
# 1671  ADAM12       101      8038

# %%
gemini_ito_df.genepair.nunique()
# Out:
# 5063

# %%
ito_annotated = pd.read_csv('/Users/narod/Documents/GitHub/context_specific_SL_prediction/1_feature_calculation/annotations/output_files/ito_pairs_ranked_ess.csv')
ito_annotated.head()
# Out:
#       genepair       A1   A2  A1_entrez  A2_entrez   DepMap_ID  \
# 0  A3GALT2_ABO  A3GALT2  ABO     127550         28  ACH-000022
# 1  A3GALT2_ABO  A3GALT2  ABO     127550         28  ACH-000307
# 2  A3GALT2_ABO  A3GALT2  ABO     127550         28  ACH-000632
# 3  A3GALT2_ABO  A3GALT2  ABO     127550         28  ACH-000681
# 4  A3GALT2_ABO  A3GALT2  ABO     127550         28  ACH-000756
#
#                     cell_line  Gemini_FDR   raw_LFC     SL  ...  \
# 0          PATU8988S_PANCREAS    0.998944  0.088856  False  ...
# 1                PK1_PANCREAS    0.986587  0.201704  False  ...
# 2                 HS944T_SKIN    1.000000  0.069772  False  ...
# 3                   A549_LUNG    0.977988  0.379455  False  ...
# 4  GI1_CENTRAL_NERVOUS_SYSTEM    0.999586 -0.077118  False  ...
#
#   smallest_gene_expression smallest_GO_CC_ranked_ess  A1_rank  zA1_rank  \
# 0                      NaN                       NaN   5108.0 -0.759628
# 1                      NaN                       NaN   9125.0  0.303431
# 2                      NaN                       NaN   4063.0 -1.036177
# 3                      NaN                       NaN  15434.0  1.973047
# 4                      NaN                       NaN   6507.0 -0.389397
#
#    A2_rank  zA2_rank  max_ranked_A1A2  min_ranked_A1A2  z_max_ranked_A1A2  \
# 0      NaN       NaN           5108.0           5108.0          -0.759628
# 1      NaN       NaN           9125.0           9125.0           0.303431
# 2      NaN       NaN           4063.0           4063.0          -1.036177
# 3      NaN       NaN          15434.0          15434.0           1.973047
# 4      NaN       NaN           6507.0           6507.0          -0.389397
#
#    z_min_ranked_A1A2
# 0          -0.759628
# 1           0.303431
# 2          -1.036177
# 3           1.973047
# 4          -0.389397
#
# [5 rows x 56 columns]

# %%
ito_annotated.shape
# Out:
# (49753, 56)

# %%
parrish_annotated = pd.read_csv('/Users/narod/Documents/GitHub/context_specific_SL_prediction/1_feature_calculation/annotations/output_files/parrish_pairs/parrish_pairs_all.csv')
parrish_annotated.head()
# Out:
#           genepair       A1       A2  A1_entrez  A2_entrez   DepMap_ID  \
# 0          A2M_PZP      A2M      PZP          2       5858  ACH-000779
# 1          A2M_PZP      A2M      PZP          2       5858  ACH-001086
# 2  AADACL3_AADACL4  AADACL3  AADACL4     126767     343066  ACH-000779
# 3  AADACL3_AADACL4  AADACL3  AADACL4     126767     343066  ACH-001086
# 4    AADAC_AADACL2    AADAC  AADACL2         13     344752  ACH-000779
#
#      cell_line  GI_score       FDR     SL  ... max_seq_id  A1_rank  zA1_rank  \
# 0     PC9_LUNG  0.264313  0.138809  False  ...   0.725237  16883.0  1.674342
# 1  HELA_CERVIX -0.154320  0.424612  False  ...   0.725237  10395.0 -0.314143
# 2     PC9_LUNG -0.000281  0.992873  False  ...   0.550369  16788.0  1.267634
# 3  HELA_CERVIX  0.120862  0.433194  False  ...   0.550369  13937.0  0.457862
# 4     PC9_LUNG -0.299150  0.066517  False  ...   0.516291   8156.0 -1.574113
#
#    A2_rank  zA2_rank  max_ranked_A1A2  min_ranked_A1A2  z_max_ranked_A1A2  \
# 0  12682.0  0.654290          16883.0          12682.0           1.674342
# 1  16473.0  1.716150          16473.0          10395.0           1.716150
# 2  17756.0  1.523027          17756.0          16788.0           1.523027
# 3  17009.0  1.273850          17009.0          13937.0           1.273850
# 4  10463.0 -0.310646          10463.0           8156.0          -0.310646
#
#    z_min_ranked_A1A2  prediction_score
# 0           0.654290          0.041682
# 1          -0.314143          0.041682
# 2           1.267634          0.062883
# 3           0.457862          0.062883
# 4          -1.574113          0.052701
#
# [5 rows x 60 columns]

# %%
klingbeil_df = pd.read_csv('/Users/narod/Documents/GitHub/context_specific_SL_prediction/1_feature_calculation/annotations/output_files/klingbeil_pairs/klingbeil_pairs_all.csv')
klingbeil_df.head()
# Out:
#                          GENE_COMBINATION           domain_combination  \
# 0  AAK1:Kinase_domain;BMP2K:Kinase_domain  Kinase_domain_Kinase_domain
# 1  AAK1:Kinase_domain;BMP2K:Kinase_domain  Kinase_domain_Kinase_domain
# 2  AAK1:Kinase_domain;BMP2K:Kinase_domain  Kinase_domain_Kinase_domain
# 3  AAK1:Kinase_domain;BMP2K:Kinase_domain  Kinase_domain_Kinase_domain
# 4  AAK1:Kinase_domain;BMP2K:Kinase_domain  Kinase_domain_Kinase_domain
#
#      genepair    A1     A2  A1_entrez  A2_entrez cell_line   DepMap_ID  \
# 0  AAK1_BMP2K  AAK1  BMP2K      22848      55589       HEL  ACH-000004
# 1  AAK1_BMP2K  AAK1  BMP2K      22848      55589      T3M4  ACH-000085
# 2  AAK1_BMP2K  AAK1  BMP2K      22848      55589    HPAFII  ACH-000094
# 3  AAK1_BMP2K  AAK1  BMP2K      22848      55589      THP1  ACH-000146
# 4  AAK1_BMP2K  AAK1  BMP2K      22848      55589     NOMO1  ACH-000168
#
#      GEMINI  ...  max_seq_id  A1_rank  zA1_rank  A2_rank  zA2_rank  \
# 0  0.218665  ...    0.413111  15404.0  3.163858  10522.0  0.250715
# 1  0.205641  ...    0.413111   8578.0  0.800919  10295.0  0.190424
# 2  0.044486  ...    0.413111   9466.0  1.108315  11125.0  0.410871
# 3  0.031737  ...    0.413111   6874.0  0.211049  11215.0  0.434775
# 4  0.148144  ...    0.413111   3492.0 -0.959689   5153.0 -1.175283
#
#    max_ranked_A1A2  min_ranked_A1A2  z_max_ranked_A1A2  z_min_ranked_A1A2  \
# 0          15404.0          10522.0           3.163858           0.250715
# 1          10295.0           8578.0           0.800919           0.190424
# 2          11125.0           9466.0           1.108315           0.410871
# 3          11215.0           6874.0           0.434775           0.211049
# 4           5153.0           3492.0          -0.959689          -1.175283
#
#    prediction_score
# 0          0.054249
# 1          0.054249
# 2          0.054249
# 3          0.054249
# 4          0.054249
#
# [5 rows x 62 columns]

# %%
# Read each CSV file into a pandas DataFrame and store them in a list
target_pairs_df = [ito_annotated, parrish_annotated]

# %%
# Dictionary to store the annotated_target_pairs DataFrames
gemini_df = [gemini_ito_df, gemini_parrish_df]

# %%
target_pairs_df = [ito_annotated]
gemini_df = [gemini_ito_df]

# %%
def merge_datasets(target_pairs_list, df_melt_list):
    merged_datasets = []
    for target_pairs, df_melt in zip(target_pairs_list, df_melt_list):
        # Make sure to drop the specified columns from df_melt before merging
        df_melt_modified = df_melt.drop(['A1', 'A2', 'org_A2', 'org_A1', 'A1_entrez', 'A2_entrez'], axis=1)
        # Perform the merge operation
        annotated_target_pairs = pd.merge(target_pairs, df_melt_modified, how='left', on=['genepair', 'DepMap_ID'])
        # Append the result to the list of merged datasets
        merged_datasets.append(annotated_target_pairs)
    return merged_datasets

# %%
annotated_target_pairs = merge_datasets(target_pairs_df, gemini_df)

# %%
annotated_target_pairs.append(klingbeil_df)

# %%
def label_top_10(df, lfc_threshold, label):
    
    # Drop rows where GEMINI is NaN
    df = df.dropna(subset=['GEMINI']).copy()

    # Check if the DataFrame is empty after dropping NaN values
    if df.empty:
        raise ValueError("The DataFrame is empty after dropping rows with NaN values in 'GEMINI'.")
    
    # Calculate the threshold for top 10%  
    percentile = 90
    threshold = np.percentile(df['GEMINI'], percentile)

    # Label the top 10% 
    df[label] = (df['GEMINI'] >= threshold) & (df['LFC'] < lfc_threshold)

    return df

# %%
# annotated_target_pairs = pd.merge(ito_annotated, gemini_ito_df[['genepair', 'DepMap_ID', 'GEMINI', 'LFC']], how='left', on=['genepair', 'DepMap_ID'])

# # ito
# ito_lfc_threshold = -0.51
# annotated_target_pairs = label_top_10(annotated_target_pairs, ito_lfc_threshold, 'SL_new')

# print('ito')
# display(annotated_target_pairs[:3])
# display(annotated_target_pairs.SL_new.value_counts())
# print('')

#os.chdir('/Users/narod/Documents/GitHub/context_specific_SL_prediction/1_feature_calculation/annotations/output_files')

#annotated_target_pairs.to_csv('./ito_pairs/ito_pairs_all.csv', index=False)

# %%
ito_lfc_threshold = -0.51
annotated_target_pairs[0] = label_top_10(annotated_target_pairs[0], ito_lfc_threshold, 'SL_new')

# %%
# ito
ito_lfc_threshold = -0.51
annotated_target_pairs[0] = label_top_10(annotated_target_pairs[0], ito_lfc_threshold, 'SL_new')

print('ito')
display(annotated_target_pairs[0][:3])
print('')

# parrish
parrish_lfc_threshold = -0.63
annotated_target_pairs[1] = label_top_10(annotated_target_pairs[1], parrish_lfc_threshold, 'SL_new')

print('parrish')
display(annotated_target_pairs[1][:3])
print('')

# kln
kln_lfc_threshold = -1.03
annotated_target_pairs[2] = label_top_10(annotated_target_pairs[2], kln_lfc_threshold, 'SL_new')

print('Kln')
display(annotated_target_pairs[2][:3])
print('')
# Out:
# ito
#       genepair       A1   A2  A1_entrez  A2_entrez   DepMap_ID  \
# 0  A3GALT2_ABO  A3GALT2  ABO     127550         28  ACH-000022
# 1  A3GALT2_ABO  A3GALT2  ABO     127550         28  ACH-000307
# 2  A3GALT2_ABO  A3GALT2  ABO     127550         28  ACH-000632
#
#             cell_line  Gemini_FDR   raw_LFC     SL  ... A2_rank zA2_rank  \
# 0  PATU8988S_PANCREAS    0.998944  0.088856  False  ...     NaN      NaN
# 1        PK1_PANCREAS    0.986587  0.201704  False  ...     NaN      NaN
# 2         HS944T_SKIN    1.000000  0.069772  False  ...     NaN      NaN
#
#    max_ranked_A1A2  min_ranked_A1A2  z_max_ranked_A1A2  z_min_ranked_A1A2  \
# 0           5108.0           5108.0          -0.759628          -0.759628
# 1           9125.0           9125.0           0.303431           0.303431
# 2           4063.0           4063.0          -1.036177          -1.036177
#
#    prediction_score    GEMINI       LFC  SL_new
# 0          0.012559  0.118768  0.088856   False
# 1          0.012559  0.132501  0.201704   False
# 2          0.012559  0.024593  0.069772   False
#
# [3 rows x 62 columns]
# parrish
#           genepair       A1       A2  A1_entrez  A2_entrez   DepMap_ID  \
# 0          A2M_PZP      A2M      PZP          2       5858  ACH-000779
# 1          A2M_PZP      A2M      PZP          2       5858  ACH-001086
# 2  AADACL3_AADACL4  AADACL3  AADACL4     126767     343066  ACH-000779
#
#      cell_line  GI_score       FDR     SL  ...  A2_rank  zA2_rank  \
# 0     PC9_LUNG  0.264313  0.138809  False  ...  12682.0  0.654290
# 1  HELA_CERVIX -0.154320  0.424612  False  ...  16473.0  1.716150
# 2     PC9_LUNG -0.000281  0.992873  False  ...  17756.0  1.523027
#
#   max_ranked_A1A2  min_ranked_A1A2  z_max_ranked_A1A2  z_min_ranked_A1A2  \
# 0         16883.0          12682.0           1.674342           0.654290
# 1         16473.0          10395.0           1.716150          -0.314143
# 2         17756.0          16788.0           1.523027           1.267634
#
#    prediction_score    GEMINI       LFC  SL_new
# 0          0.041682 -0.249934  0.333503   False
# 1          0.041682 -0.038689 -0.115678   False
# 2          0.062883  0.022368 -0.106713   False
#
# [3 rows x 63 columns]
# Kln
#                          GENE_COMBINATION           domain_combination  \
# 0  AAK1:Kinase_domain;BMP2K:Kinase_domain  Kinase_domain_Kinase_domain
# 1  AAK1:Kinase_domain;BMP2K:Kinase_domain  Kinase_domain_Kinase_domain
# 2  AAK1:Kinase_domain;BMP2K:Kinase_domain  Kinase_domain_Kinase_domain
#
#      genepair    A1     A2  A1_entrez  A2_entrez cell_line   DepMap_ID  \
# 0  AAK1_BMP2K  AAK1  BMP2K      22848      55589       HEL  ACH-000004
# 1  AAK1_BMP2K  AAK1  BMP2K      22848      55589      T3M4  ACH-000085
# 2  AAK1_BMP2K  AAK1  BMP2K      22848      55589    HPAFII  ACH-000094
#
#      GEMINI  ...  A1_rank  zA1_rank  A2_rank  zA2_rank max_ranked_A1A2  \
# 0  0.218665  ...  15404.0  3.163858  10522.0  0.250715         15404.0
# 1  0.205641  ...   8578.0  0.800919  10295.0  0.190424         10295.0
# 2  0.044486  ...   9466.0  1.108315  11125.0  0.410871         11125.0
#
#    min_ranked_A1A2  z_max_ranked_A1A2  z_min_ranked_A1A2  prediction_score  \
# 0          10522.0           3.163858           0.250715          0.054249
# 1           8578.0           0.800919           0.190424          0.054249
# 2           9466.0           1.108315           0.410871          0.054249
#
#    SL_new
# 0   False
# 1   False
# 2   False
#
# [3 rows x 63 columns]

# %%
print('ito')
display(annotated_target_pairs[0]['SL_new'].value_counts())
print('')
# Out:
# ito
# SL_new
# False    48138
# True      1018
# Name: count, dtype: int64

# %%
print('ito')
display(annotated_target_pairs[0]['SL_new'].value_counts())
print('')

print('parrish')
display(annotated_target_pairs[1]['SL_new'].value_counts())
print('')

print('Kln')
display(annotated_target_pairs[2]['SL_new'].value_counts())
print('')
# Out:
# ito
# SL_new
# False    48138
# True      1018
# Name: count, dtype: int64
# parrish
# SL_new
# False    1654
# True      141
# Name: count, dtype: int64
# Kln
# SL_new
# False    50878
# True      2009
# Name: count, dtype: int64

# %%
os.chdir('/Users/narod/Documents/GitHub/context_specific_SL_prediction/1_feature_calculation/annotations/output_files')

annotated_target_pairs[0].to_csv('ito_pairs_annotated.csv', index=False)

# %%
# List of names you want to use for your files
names = ['ito', 'parrish', 'klingbeil']

folder_path = '/Users/narod/Documents/GitHub/context_specific_SL_prediction/1_feature_calculation/annotations/output_files/NEW'
#folder_path = '/Users/narod/Documents/GitHub/context_specific_SL_prediction/1_feature_calculation/annotations/output_files'
#folder_path = '/Users/narod/Library/CloudStorage/GoogleDrive-narod.kebabci@ucdconnect.ie/My Drive/SL PRED/input'

# Ensure the length of names matches the number of datasets you have
assert len(names) == len(annotated_target_pairs), "The number of names and datasets do not match."

# Loop through each dataset and its corresponding name to save it
for name, dataset in zip(names, annotated_target_pairs):
    filename = os.path.join(folder_path, f'{name}_pairs_annotated.csv')
    dataset.to_csv(filename, index=False)  # Saves the DataFrame to CSV without the index column
